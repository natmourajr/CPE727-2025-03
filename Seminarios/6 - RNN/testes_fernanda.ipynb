# %%
import re
import json

# 1. Coloque aqui o log bruto de reconstrução
log_text = r"""
GRUPOS (total): {0: 6372, 1: 12, 4: 361}
GRUPOS (train): {0: 5098, 1: 10, 4: 289}
GRUPOS (test):  {0: 1274, 1: 2, 4: 72}
Epoch 1/500 | Train(sampled) L1:6.890694 L2:0.000000 L4:0.790462 | 
          >> Test macro:222.710870 ± 220.738840 | micro:1.276708 ± 0.556993          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 2/500 | Train(sampled) L1:5.756873 L2:0.000000 L4:0.761961 | 
          >> Test macro:134.956219 ± 133.158738 | micro:1.414828 ± 0.539688          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 3/500 | Train(sampled) L1:4.222535 L2:0.000000 L4:0.711108 | 
          >> Test macro:148.643504 ± 146.887736 | micro:1.424993 ± 0.545572          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 4/500 | Train(sampled) L1:2.965774 L2:0.000000 L4:0.642307 | 
          >> Test macro:198.065833 ± 196.004269 | micro:1.748378 ± 0.612760          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 5/500 | Train(sampled) L1:2.401832 L2:0.000000 L4:0.516356 | 
          >> Test macro:178.805106 ± 176.528494 | micro:2.028863 ± 0.575091          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 6/500 | Train(sampled) L1:2.051112 L2:0.000000 L4:0.404298 | 
          >> Test macro:158.265935 ± 156.507327 | micro:1.638097 ± 0.587317          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 7/500 | Train(sampled) L1:1.662771 L2:0.000000 L4:0.330769 | 
          >> Test macro:139.073748 ± 137.799111 | micro:1.038702 ± 0.450742          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 8/500 | Train(sampled) L1:1.388678 L2:0.000000 L4:0.274460 | 
          >> Test macro:81.329110 ± 80.099247 | micro:0.944904 ± 0.331624          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 9/500 | Train(sampled) L1:1.202030 L2:0.000000 L4:0.233963 | 
          >> Test macro:118.207863 ± 117.205159 | micro:0.870027 ± 0.407802          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 10/500 | Train(sampled) L1:1.050039 L2:0.000000 L4:0.207733 | 
          >> Test macro:75.383059 ± 74.439771 | micro:0.703981 ± 0.273109          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 11/500 | Train(sampled) L1:0.880302 L2:0.000000 L4:0.189080 | 
          >> Test macro:54.077396 ± 53.253410 | micro:0.575456 ± 0.214270          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 12/500 | Train(sampled) L1:0.755654 L2:0.000000 L4:0.176803 | 
          >> Test macro:44.188499 ± 43.410537 | micro:0.448411 ± 0.147798          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 13/500 | Train(sampled) L1:0.620222 L2:0.000000 L4:0.161947 | 
          >> Test macro:28.664851 ± 27.882242 | micro:0.405403 ± 0.103991          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 14/500 | Train(sampled) L1:0.512785 L2:0.000000 L4:0.147225 | 
          >> Test macro:20.558159 ± 19.921200 | micro:0.278855 ± 0.056940          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 15/500 | Train(sampled) L1:0.469387 L2:0.000000 L4:0.132329 | 
          >> Test macro:11.300571 ± 10.663843 | micro:0.267432 ± 0.040016          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 16/500 | Train(sampled) L1:0.415871 L2:0.000000 L4:0.119049 | 
          >> Test macro:3.779559 ± 2.887837 | micro:0.248187 ± 0.034586          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 17/500 | Train(sampled) L1:0.375231 L2:0.000000 L4:0.102441 | 
          >> Test macro:3.575933 ± 2.973353 | micro:0.207820 ± 0.036043          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 18/500 | Train(sampled) L1:0.362833 L2:0.000000 L4:0.089112 | 
          >> Test macro:5.376341 ± 4.841526 | micro:0.225251 ± 0.029419          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 19/500 | Train(sampled) L1:0.349876 L2:0.000000 L4:0.075209 | 
          >> Test macro:4.535274 ± 3.847037 | micro:0.214719 ± 0.029859          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 20/500 | Train(sampled) L1:0.343779 L2:0.000000 L4:0.064832 | 
          >> Test macro:2.613663 ± 2.095244 | micro:0.185433 ± 0.036703          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 21/500 | Train(sampled) L1:0.348616 L2:0.000000 L4:0.057105 | 
          >> Test macro:5.433734 ± 4.976523 | micro:0.197459 ± 0.032234          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 22/500 | Train(sampled) L1:0.349079 L2:0.000000 L4:0.050745 | 
          >> Test macro:3.130887 ± 2.585278 | micro:0.191712 ± 0.032475          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 23/500 | Train(sampled) L1:0.332441 L2:0.000000 L4:0.042709 | 
          >> Test macro:0.620961 ± 0.307369 | micro:0.188336 ± 0.038481          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 24/500 | Train(sampled) L1:0.335406 L2:0.000000 L4:0.038481 | 
          >> Test macro:4.824997 ± 4.297052 | micro:0.180164 ± 0.031118          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 25/500 | Train(sampled) L1:0.302375 L2:0.000000 L4:0.033245 | 
          >> Test macro:2.248635 ± 1.646815 | micro:0.182573 ± 0.035105          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 26/500 | Train(sampled) L1:0.318090 L2:0.000000 L4:0.029661 | 
          >> Test macro:1.225318 ± 0.673377 | micro:0.181378 ± 0.039190          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 27/500 | Train(sampled) L1:0.325498 L2:0.000000 L4:0.027435 | 
          >> Test macro:5.412322 ± 4.901239 | micro:0.181492 ± 0.036401          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 28/500 | Train(sampled) L1:0.298422 L2:0.000000 L4:0.023534 | 
          >> Test macro:1.868829 ± 1.366923 | micro:0.164147 ± 0.040641          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 29/500 | Train(sampled) L1:0.316819 L2:0.000000 L4:0.021381 | 
          >> Test macro:4.728950 ± 4.130760 | micro:0.182417 ± 0.039091          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 30/500 | Train(sampled) L1:0.314723 L2:0.000000 L4:0.019227 | 
          >> Test macro:2.779077 ± 2.166535 | micro:0.177684 ± 0.031739          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 31/500 | Train(sampled) L1:0.308591 L2:0.000000 L4:0.017488 | 
          >> Test macro:6.522011 ± 6.041059 | micro:0.178606 ± 0.037213          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 32/500 | Train(sampled) L1:0.297964 L2:0.000000 L4:0.015439 | 
          >> Test macro:0.990201 ± 0.472298 | micro:0.168063 ± 0.036591          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 33/500 | Train(sampled) L1:0.298758 L2:0.000000 L4:0.014006 | 
          >> Test macro:2.826963 ± 2.234177 | micro:0.173132 ± 0.038684          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 34/500 | Train(sampled) L1:0.300457 L2:0.000000 L4:0.012481 | 
          >> Test macro:2.777657 ± 2.155152 | micro:0.169070 ± 0.041723          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 35/500 | Train(sampled) L1:0.301058 L2:0.000000 L4:0.010813 | 
          >> Test macro:1.716242 ± 1.107519 | micro:0.184568 ± 0.041568          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 36/500 | Train(sampled) L1:0.320568 L2:0.000000 L4:0.009684 | 
          >> Test macro:1.024287 ± 0.526468 | micro:0.164365 ± 0.041698          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 37/500 | Train(sampled) L1:0.327655 L2:0.000000 L4:0.008614 | 
          >> Test macro:3.838273 ± 3.255837 | micro:0.169460 ± 0.041485          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 38/500 | Train(sampled) L1:0.331852 L2:0.000000 L4:0.009331 | 
          >> Test macro:3.175318 ± 2.535759 | micro:0.183920 ± 0.041114          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 39/500 | Train(sampled) L1:0.292454 L2:0.000000 L4:0.008398 | 
          >> Test macro:1.501650 ± 0.902244 | micro:0.165018 ± 0.046109          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 40/500 | Train(sampled) L1:0.293732 L2:0.000000 L4:0.007199 | 
          >> Test macro:5.299707 ± 4.736698 | micro:0.174753 ± 0.038279          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 41/500 | Train(sampled) L1:0.323546 L2:0.000000 L4:0.006261 | 
          >> Test macro:4.548506 ± 3.932976 | micro:0.177375 ± 0.038269          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 42/500 | Train(sampled) L1:0.288685 L2:0.000000 L4:0.005523 | 
          >> Test macro:2.080885 ± 1.509511 | micro:0.160932 ± 0.062286          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 43/500 | Train(sampled) L1:0.293811 L2:0.000000 L4:0.005519 | 
          >> Test macro:3.847857 ± 3.263724 | micro:0.166129 ± 0.046244          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 44/500 | Train(sampled) L1:0.301902 L2:0.000000 L4:0.004665 | 
          >> Test macro:2.520691 ± 1.916487 | micro:0.171644 ± 0.036981          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 45/500 | Train(sampled) L1:0.302891 L2:0.000000 L4:0.004280 | 
          >> Test macro:2.718979 ± 2.146967 | micro:0.166375 ± 0.045518          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 46/500 | Train(sampled) L1:0.299585 L2:0.000000 L4:0.004252 | 
          >> Test macro:0.782161 ± 0.338497 | micro:0.155023 ± 0.047162          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 47/500 | Train(sampled) L1:0.307863 L2:0.000000 L4:0.003769 | 
          >> Test macro:4.982468 ± 4.380298 | micro:0.188277 ± 0.034829          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 48/500 | Train(sampled) L1:0.298598 L2:0.000000 L4:0.003435 | 
          >> Test macro:0.545696 ± 0.272213 | micro:0.149888 ± 0.049848          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 49/500 | Train(sampled) L1:0.285235 L2:0.000000 L4:0.003062 | 
          >> Test macro:1.960840 ± 1.333792 | micro:0.178509 ± 0.046997          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 50/500 | Train(sampled) L1:0.301215 L2:0.000000 L4:0.002953 | 
          >> Test macro:5.557881 ± 4.948622 | micro:0.169141 ± 0.046464          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 51/500 | Train(sampled) L1:0.300338 L2:0.000000 L4:0.002836 | 
          >> Test macro:4.310683 ± 3.679426 | micro:0.178023 ± 0.039183          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 52/500 | Train(sampled) L1:0.291341 L2:0.000000 L4:0.002359 | 
          >> Test macro:3.829390 ± 3.184245 | micro:0.171101 ± 0.038946          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 53/500 | Train(sampled) L1:0.286539 L2:0.000000 L4:0.002242 | 
          >> Test macro:3.451925 ± 2.909042 | micro:0.162298 ± 0.037400          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 54/500 | Train(sampled) L1:0.270399 L2:0.000000 L4:0.002042 | 
          >> Test macro:3.320930 ± 2.746885 | micro:0.163056 ± 0.040331          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 55/500 | Train(sampled) L1:0.282222 L2:0.000000 L4:0.001898 | 
          >> Test macro:0.801072 ± 0.353674 | micro:0.151256 ± 0.050046          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 56/500 | Train(sampled) L1:0.279783 L2:0.000000 L4:0.002021 | 
          >> Test macro:3.361174 ± 2.742155 | micro:0.164217 ± 0.042697          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 57/500 | Train(sampled) L1:0.289157 L2:0.000000 L4:0.001850 | 
          >> Test macro:0.958123 ± 0.447907 | micro:0.150784 ± 0.048539          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 58/500 | Train(sampled) L1:0.290921 L2:0.000000 L4:0.001737 | 
          >> Test macro:2.471430 ± 1.853650 | micro:0.169678 ± 0.036629          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 59/500 | Train(sampled) L1:0.286973 L2:0.000000 L4:0.001691 | 
          >> Test macro:3.514125 ± 2.878826 | micro:0.163820 ± 0.038431          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 60/500 | Train(sampled) L1:0.281884 L2:0.000000 L4:0.001562 | 
          >> Test macro:1.179910 ± 0.657622 | micro:0.156564 ± 0.044467          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 61/500 | Train(sampled) L1:0.292543 L2:0.000000 L4:0.001491 | 
          >> Test macro:4.429590 ± 3.880254 | micro:0.165653 ± 0.035225          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 62/500 | Train(sampled) L1:0.286517 L2:0.000000 L4:0.001204 | 
          >> Test macro:4.756609 ± 4.109521 | micro:0.170381 ± 0.039043          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 63/500 | Train(sampled) L1:0.286845 L2:0.000000 L4:0.001308 | 
          >> Test macro:3.443212 ± 2.843188 | micro:0.167858 ± 0.039704          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 64/500 | Train(sampled) L1:0.274713 L2:0.000000 L4:0.001262 | 
          >> Test macro:5.936482 ± 5.372098 | micro:0.164449 ± 0.041172          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 65/500 | Train(sampled) L1:0.292397 L2:0.000000 L4:0.001196 | 
          >> Test macro:1.061891 ± 0.565583 | micro:0.149476 ± 0.047812          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 66/500 | Train(sampled) L1:0.285335 L2:0.000000 L4:0.001122 | 
          >> Test macro:0.867758 ± 0.397442 | micro:0.150422 ± 0.046401          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 67/500 | Train(sampled) L1:0.299035 L2:0.000000 L4:0.001086 | 
          >> Test macro:2.242987 ± 1.699714 | micro:0.152674 ± 0.046606          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 68/500 | Train(sampled) L1:0.285392 L2:0.000000 L4:0.000979 | 
          >> Test macro:3.273571 ± 2.635580 | micro:0.163832 ± 0.037691          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 69/500 | Train(sampled) L1:0.291185 L2:0.000000 L4:0.000952 | 
          >> Test macro:3.451519 ± 2.846652 | micro:0.179485 ± 0.038290          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 70/500 | Train(sampled) L1:0.295956 L2:0.000000 L4:0.000873 | 
          >> Test macro:4.224513 ± 3.605114 | micro:0.187413 ± 0.055193          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 71/500 | Train(sampled) L1:0.293353 L2:0.000000 L4:0.000901 | 
          >> Test macro:1.069198 ± 0.573214 | micro:0.149774 ± 0.051510          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 72/500 | Train(sampled) L1:0.276331 L2:0.000000 L4:0.000794 | 
          >> Test macro:3.910048 ± 3.309692 | micro:0.163911 ± 0.033737          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 73/500 | Train(sampled) L1:0.298832 L2:0.000000 L4:0.000804 | 
          >> Test macro:4.385522 ± 3.864183 | micro:0.157100 ± 0.049847          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 74/500 | Train(sampled) L1:0.287568 L2:0.000000 L4:0.000850 | 
          >> Test macro:5.848972 ± 5.193392 | micro:0.160318 ± 0.039990          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 75/500 | Train(sampled) L1:0.291893 L2:0.000000 L4:0.000735 | 
          >> Test macro:5.021540 ± 4.475901 | micro:0.165366 ± 0.043038          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 76/500 | Train(sampled) L1:0.283260 L2:0.000000 L4:0.000799 | 
          >> Test macro:2.265623 ± 1.703131 | micro:0.154162 ± 0.042687          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 77/500 | Train(sampled) L1:0.282458 L2:0.000000 L4:0.000678 | 
          >> Test macro:2.539951 ± 2.011315 | micro:0.151399 ± 0.046663          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 78/500 | Train(sampled) L1:0.294891 L2:0.000000 L4:0.000721 | 
          >> Test macro:4.493015 ± 3.940693 | micro:0.156436 ± 0.044348          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 79/500 | Train(sampled) L1:0.293184 L2:0.000000 L4:0.000677 | 
          >> Test macro:3.080684 ± 2.520312 | micro:0.163400 ± 0.039993          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 80/500 | Train(sampled) L1:0.298148 L2:0.000000 L4:0.000652 | 
          >> Test macro:3.364211 ± 2.743116 | micro:0.158943 ± 0.046113          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 81/500 | Train(sampled) L1:0.276236 L2:0.000000 L4:0.000656 | 
          >> Test macro:2.187865 ± 1.666185 | micro:0.152028 ± 0.053806          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 82/500 | Train(sampled) L1:0.274983 L2:0.000000 L4:0.000591 | 
          >> Test macro:0.979631 ± 0.488330 | micro:0.146275 ± 0.051277          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 83/500 | Train(sampled) L1:0.293572 L2:0.000000 L4:0.000574 | 
          >> Test macro:1.853370 ± 1.282619 | micro:0.147301 ± 0.054439          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 84/500 | Train(sampled) L1:0.297220 L2:0.000000 L4:0.000509 | 
          >> Test macro:0.712527 ± 0.307306 | micro:0.146303 ± 0.043287          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 85/500 | Train(sampled) L1:0.283763 L2:0.000000 L4:0.000486 | 
          >> Test macro:4.788564 ± 4.220318 | micro:0.164936 ± 0.038586          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 86/500 | Train(sampled) L1:0.290404 L2:0.000000 L4:0.000512 | 
          >> Test macro:6.238322 ± 5.645451 | micro:0.164608 ± 0.046335          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 87/500 | Train(sampled) L1:0.275640 L2:0.000000 L4:0.000502 | 
          >> Test macro:4.262861 ± 3.755025 | micro:0.153304 ± 0.045969          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 88/500 | Train(sampled) L1:0.290511 L2:0.000000 L4:0.000459 | 
          >> Test macro:9.224646 ± 8.638497 | micro:0.179516 ± 0.048951          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 89/500 | Train(sampled) L1:0.270289 L2:0.000000 L4:0.000420 | 
          >> Test macro:3.903539 ± 3.355898 | micro:0.155838 ± 0.033556          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 90/500 | Train(sampled) L1:0.293002 L2:0.000000 L4:0.000468 | 
          >> Test macro:3.718586 ± 3.123332 | micro:0.155571 ± 0.044616          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 91/500 | Train(sampled) L1:0.290698 L2:0.000000 L4:0.000465 | 
          >> Test macro:8.443208 ± 7.854723 | micro:0.175370 ± 0.043205          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 92/500 | Train(sampled) L1:0.269596 L2:0.000000 L4:0.000441 | 
          >> Test macro:3.421281 ± 2.881291 | micro:0.152899 ± 0.032943          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 93/500 | Train(sampled) L1:0.112872 L2:0.000000 L4:0.000596 | 
          >> Test macro:5.756635 ± 5.250285 | micro:0.161175 ± 0.034809          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 94/500 | Train(sampled) L1:0.055149 L2:0.000000 L4:0.000535 | 
          >> Test macro:4.309060 ± 3.750087 | micro:0.151200 ± 0.037038          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 95/500 | Train(sampled) L1:0.048507 L2:0.000000 L4:0.000585 | 
          >> Test macro:3.320403 ± 2.683708 | micro:0.149276 ± 0.044135          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 96/500 | Train(sampled) L1:0.044744 L2:0.000000 L4:0.000596 | 
          >> Test macro:1.774932 ± 1.306676 | micro:0.138239 ± 0.039596          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 97/500 | Train(sampled) L1:0.041428 L2:0.000000 L4:0.000582 | 
          >> Test macro:2.184656 ± 1.712581 | micro:0.140852 ± 0.042794          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 98/500 | Train(sampled) L1:0.038294 L2:0.000000 L4:0.000542 | 
          >> Test macro:5.148134 ± 4.622490 | micro:0.146628 ± 0.032611          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 99/500 | Train(sampled) L1:0.038093 L2:0.000000 L4:0.000519 | 
          >> Test macro:0.625058 ± 0.270676 | micro:0.139147 ± 0.046535          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 100/500 | Train(sampled) L1:0.046712 L2:0.000000 L4:0.000562 | 
          >> Test macro:0.716812 ± 0.311675 | micro:0.138423 ± 0.050404          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 101/500 | Train(sampled) L1:0.036566 L2:0.000000 L4:0.000518 | 
          >> Test macro:3.717897 ± 3.209154 | micro:0.159281 ± 0.039317          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 102/500 | Train(sampled) L1:0.036683 L2:0.000000 L4:0.000682 | 
          >> Test macro:3.453629 ± 2.924780 | micro:0.161245 ± 0.039769          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 103/500 | Train(sampled) L1:0.038103 L2:0.000000 L4:0.000547 | 
          >> Test macro:3.076107 ± 2.488920 | micro:0.152127 ± 0.040031          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 104/500 | Train(sampled) L1:0.037096 L2:0.000000 L4:0.000514 | 
          >> Test macro:0.931376 ± 0.446865 | micro:0.141075 ± 0.047292          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 105/500 | Train(sampled) L1:0.039022 L2:0.000000 L4:0.000512 | 
          >> Test macro:3.013714 ± 2.453377 | micro:0.152149 ± 0.042840          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 106/500 | Train(sampled) L1:0.042375 L2:0.000000 L4:0.000510 | 
          >> Test macro:2.044582 ± 1.517848 | micro:0.158379 ± 0.038030          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 107/500 | Train(sampled) L1:0.042213 L2:0.000000 L4:0.000451 | 
          >> Test macro:4.158108 ± 3.645864 | micro:0.148569 ± 0.038894          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 108/500 | Train(sampled) L1:0.039895 L2:0.000000 L4:0.000525 | 
          >> Test macro:0.532671 ± 0.256078 | micro:0.130616 ± 0.053239          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 109/500 | Train(sampled) L1:0.035100 L2:0.000000 L4:0.000471 | 
          >> Test macro:1.180843 ± 0.650306 | micro:0.150987 ± 0.042136          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 110/500 | Train(sampled) L1:0.034197 L2:0.000000 L4:0.000420 | 
          >> Test macro:4.413561 ± 3.889081 | micro:0.153302 ± 0.034724          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 111/500 | Train(sampled) L1:0.034321 L2:0.000000 L4:0.000515 | 
          >> Test macro:4.790221 ± 4.234499 | micro:0.161687 ± 0.035388          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 112/500 | Train(sampled) L1:0.034394 L2:0.000000 L4:0.000475 | 
          >> Test macro:0.983859 ± 0.473564 | micro:0.143134 ± 0.047939          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 113/500 | Train(sampled) L1:0.034237 L2:0.000000 L4:0.000460 | 
          >> Test macro:0.708774 ± 0.314659 | micro:0.136222 ± 0.046517          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 114/500 | Train(sampled) L1:0.041433 L2:0.000000 L4:0.000457 | 
          >> Test macro:1.378475 ± 0.840713 | micro:0.152548 ± 0.039496          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 115/500 | Train(sampled) L1:0.045218 L2:0.000000 L4:0.000434 | 
          >> Test macro:7.510163 ± 7.002078 | micro:0.179095 ± 0.039152          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 116/500 | Train(sampled) L1:0.035592 L2:0.000000 L4:0.000417 | 
          >> Test macro:9.993869 ± 9.556233 | micro:0.147054 ± 0.039910          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 117/500 | Train(sampled) L1:0.031743 L2:0.000000 L4:0.000441 | 
          >> Test macro:3.904439 ± 3.410359 | micro:0.141630 ± 0.040534          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 118/500 | Train(sampled) L1:0.032436 L2:0.000000 L4:0.000452 | 
          >> Test macro:2.051694 ± 1.591180 | micro:0.149100 ± 0.033551          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 119/500 | Train(sampled) L1:0.040535 L2:0.000000 L4:0.000419 | 
          >> Test macro:5.525849 ± 4.997686 | micro:0.150687 ± 0.046055          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 120/500 | Train(sampled) L1:0.043890 L2:0.000000 L4:0.000438 | 
          >> Test macro:4.445583 ± 3.871858 | micro:0.175451 ± 0.035723          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 121/500 | Train(sampled) L1:0.036620 L2:0.000000 L4:0.000434 | 
          >> Test macro:2.883396 ± 2.377123 | micro:0.137952 ± 0.042992          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 122/500 | Train(sampled) L1:0.031844 L2:0.000000 L4:0.000458 | 
          >> Test macro:5.956191 ± 5.473542 | micro:0.145110 ± 0.038927          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 123/500 | Train(sampled) L1:0.031417 L2:0.000000 L4:0.000431 | 
          >> Test macro:5.794463 ± 5.316553 | micro:0.156034 ± 0.043253          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 124/500 | Train(sampled) L1:0.030420 L2:0.000000 L4:0.000362 | 
          >> Test macro:4.706642 ± 4.175228 | micro:0.151998 ± 0.040946          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 125/500 | Train(sampled) L1:0.030381 L2:0.000000 L4:0.000371 | 
          >> Test macro:6.691880 ± 6.178662 | micro:0.149961 ± 0.040286          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 126/500 | Train(sampled) L1:0.031383 L2:0.000000 L4:0.000377 | 
          >> Test macro:4.425302 ± 3.909520 | micro:0.149736 ± 0.038163          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 127/500 | Train(sampled) L1:0.029712 L2:0.000000 L4:0.000389 | 
          >> Test macro:5.050500 ± 4.540374 | micro:0.149056 ± 0.038866          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 128/500 | Train(sampled) L1:0.033655 L2:0.000000 L4:0.000351 | 
          >> Test macro:2.514637 ± 1.961266 | micro:0.149058 ± 0.033787          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 129/500 | Train(sampled) L1:0.033374 L2:0.000000 L4:0.000334 | 
          >> Test macro:3.332924 ± 2.719735 | micro:0.147113 ± 0.040795          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 130/500 | Train(sampled) L1:0.030959 L2:0.000000 L4:0.000312 | 
          >> Test macro:11.973981 ± 11.414809 | micro:0.182556 ± 0.057628          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 131/500 | Train(sampled) L1:0.033095 L2:0.000000 L4:0.000305 | 
          >> Test macro:5.628949 ± 5.091451 | micro:0.151147 ± 0.038206          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 132/500 | Train(sampled) L1:0.030586 L2:0.000000 L4:0.000330 | 
          >> Test macro:0.469539 ± 0.298030 | micro:0.138693 ± 0.047543          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 133/500 | Train(sampled) L1:0.030123 L2:0.000000 L4:0.000366 | 
          >> Test macro:4.095319 ± 3.531945 | micro:0.151273 ± 0.039813          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 134/500 | Train(sampled) L1:0.036576 L2:0.000000 L4:0.000282 | 
          >> Test macro:5.515317 ± 4.928943 | micro:0.170105 ± 0.041893          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 135/500 | Train(sampled) L1:0.031870 L2:0.000000 L4:0.000285 | 
          >> Test macro:3.448994 ± 2.910342 | micro:0.147165 ± 0.041946          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 136/500 | Train(sampled) L1:0.032506 L2:0.000000 L4:0.000343 | 
          >> Test macro:3.926758 ± 3.436856 | micro:0.143857 ± 0.039084          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 137/500 | Train(sampled) L1:0.029566 L2:0.000000 L4:0.000321 | 
          >> Test macro:4.665120 ± 4.029353 | micro:0.160280 ± 0.038672          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 138/500 | Train(sampled) L1:0.030749 L2:0.000000 L4:0.000355 | 
          >> Test macro:1.404697 ± 0.907020 | micro:0.134808 ± 0.047605          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 139/500 | Train(sampled) L1:0.029213 L2:0.000000 L4:0.000311 | 
          >> Test macro:4.041725 ± 3.490493 | micro:0.145242 ± 0.039488          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 140/500 | Train(sampled) L1:0.035124 L2:0.000000 L4:0.000265 | 
          >> Test macro:2.107686 ± 1.558305 | micro:0.146204 ± 0.039383          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 141/500 | Train(sampled) L1:0.031543 L2:0.000000 L4:0.000312 | 
          >> Test macro:0.391185 ± 0.272904 | micro:0.128712 ± 0.047325          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 142/500 | Train(sampled) L1:0.030665 L2:0.000000 L4:0.000306 | 
          >> Test macro:7.316031 ± 6.783316 | micro:0.153673 ± 0.039372          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 143/500 | Train(sampled) L1:0.030484 L2:0.000000 L4:0.000409 | 
          >> Test macro:0.492301 ± 0.272149 | micro:0.134380 ± 0.038249          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 144/500 | Train(sampled) L1:0.030406 L2:0.000000 L4:0.000265 | 
          >> Test macro:3.747085 ± 3.242068 | micro:0.156708 ± 0.038645          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 145/500 | Train(sampled) L1:0.028712 L2:0.000000 L4:0.000323 | 
          >> Test macro:3.648234 ± 3.104165 | micro:0.150295 ± 0.040956          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 146/500 | Train(sampled) L1:0.029255 L2:0.000000 L4:0.000285 | 
          >> Test macro:2.199083 ± 1.729532 | micro:0.132292 ± 0.053632          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 147/500 | Train(sampled) L1:0.028450 L2:0.000000 L4:0.000266 | 
          >> Test macro:2.974716 ± 2.483219 | micro:0.143103 ± 0.048231          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 148/500 | Train(sampled) L1:0.032489 L2:0.000000 L4:0.000281 | 
          >> Test macro:0.982998 ± 0.544879 | micro:0.132523 ± 0.042566          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 149/500 | Train(sampled) L1:0.029037 L2:0.000000 L4:0.000264 | 
          >> Test macro:5.366278 ± 4.861253 | micro:0.156737 ± 0.035272          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 150/500 | Train(sampled) L1:0.029645 L2:0.000000 L4:0.000211 | 
          >> Test macro:2.226117 ± 1.691348 | micro:0.136617 ± 0.039987          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 151/500 | Train(sampled) L1:0.027641 L2:0.000000 L4:0.000272 | 
          >> Test macro:8.517543 ± 7.973632 | micro:0.160680 ± 0.039837          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 152/500 | Train(sampled) L1:0.028868 L2:0.000000 L4:0.000308 | 
          >> Test macro:0.465847 ± 0.285121 | micro:0.137612 ± 0.041478          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 153/500 | Train(sampled) L1:0.029080 L2:0.000000 L4:0.000275 | 
          >> Test macro:4.713224 ± 4.141147 | micro:0.155054 ± 0.042481          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 154/500 | Train(sampled) L1:0.028655 L2:0.000000 L4:0.000226 | 
          >> Test macro:0.777760 ± 0.352401 | micro:0.140397 ± 0.043556          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 155/500 | Train(sampled) L1:0.028522 L2:0.000000 L4:0.000264 | 
          >> Test macro:0.418589 ± 0.328052 | micro:0.134253 ± 0.044391          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 156/500 | Train(sampled) L1:0.028381 L2:0.000000 L4:0.000244 | 
          >> Test macro:0.544512 ± 0.303434 | micro:0.133985 ± 0.042407          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 157/500 | Train(sampled) L1:0.027951 L2:0.000000 L4:0.000243 | 
          >> Test macro:2.024920 ± 1.509314 | micro:0.134494 ± 0.047760          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 158/500 | Train(sampled) L1:0.027785 L2:0.000000 L4:0.000211 | 
          >> Test macro:2.214354 ± 1.625472 | micro:0.145329 ± 0.038308          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 159/500 | Train(sampled) L1:0.028419 L2:0.000000 L4:0.000239 | 
          >> Test macro:3.074190 ± 2.525511 | micro:0.145999 ± 0.035034          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 160/500 | Train(sampled) L1:0.029203 L2:0.000000 L4:0.000194 | 
          >> Test macro:6.239108 ± 5.777972 | micro:0.153041 ± 0.039880          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 161/500 | Train(sampled) L1:0.032615 L2:0.000000 L4:0.000232 | 
          >> Test macro:2.589303 ± 2.085131 | micro:0.134893 ± 0.048475          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 162/500 | Train(sampled) L1:0.029579 L2:0.000000 L4:0.000233 | 
          >> Test macro:6.399187 ± 5.930436 | micro:0.160351 ± 0.042989          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 163/500 | Train(sampled) L1:0.028259 L2:0.000000 L4:0.000221 | 
          >> Test macro:1.236857 ± 0.684250 | micro:0.139059 ± 0.046398          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 164/500 | Train(sampled) L1:0.028593 L2:0.000000 L4:0.000216 | 
          >> Test macro:0.433592 ± 0.301041 | micro:0.130965 ± 0.048142          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 165/500 | Train(sampled) L1:0.028556 L2:0.000000 L4:0.000226 | 
          >> Test macro:2.366491 ± 1.846761 | micro:0.141252 ± 0.041575          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 166/500 | Train(sampled) L1:0.033109 L2:0.000000 L4:0.000240 | 
          >> Test macro:4.523015 ± 3.994273 | micro:0.155897 ± 0.038620          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 167/500 | Train(sampled) L1:0.028823 L2:0.000000 L4:0.000256 | 
          >> Test macro:6.505756 ± 5.983052 | micro:0.152986 ± 0.053086          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 168/500 | Train(sampled) L1:0.028314 L2:0.000000 L4:0.000225 | 
          >> Test macro:3.035426 ± 2.544420 | micro:0.136768 ± 0.040682          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 169/500 | Train(sampled) L1:0.027569 L2:0.000000 L4:0.000218 | 
          >> Test macro:4.207767 ± 3.687844 | micro:0.151804 ± 0.048621          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 170/500 | Train(sampled) L1:0.028773 L2:0.000000 L4:0.000269 | 
          >> Test macro:1.290840 ± 0.804272 | micro:0.132165 ± 0.042397          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 171/500 | Train(sampled) L1:0.027192 L2:0.000000 L4:0.000212 | 
          >> Test macro:5.956782 ± 5.417942 | micro:0.154299 ± 0.044984          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 172/500 | Train(sampled) L1:0.026582 L2:0.000000 L4:0.000208 | 
          >> Test macro:1.986607 ± 1.426625 | micro:0.150837 ± 0.049076          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 173/500 | Train(sampled) L1:0.028343 L2:0.000000 L4:0.000215 | 
          >> Test macro:0.475554 ± 0.291532 | micro:0.136312 ± 0.041878          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 174/500 | Train(sampled) L1:0.027018 L2:0.000000 L4:0.000206 | 
          >> Test macro:4.724265 ± 4.163449 | micro:0.159044 ± 0.036221          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 175/500 | Train(sampled) L1:0.026103 L2:0.000000 L4:0.000246 | 
          >> Test macro:4.018228 ± 3.508890 | micro:0.137136 ± 0.043543          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 176/500 | Train(sampled) L1:0.028985 L2:0.000000 L4:0.000205 | 
          >> Test macro:1.222613 ± 0.714806 | micro:0.135828 ± 0.066754          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 177/500 | Train(sampled) L1:0.027650 L2:0.000000 L4:0.000209 | 
          >> Test macro:5.526115 ± 4.952570 | micro:0.157756 ± 0.041124          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 178/500 | Train(sampled) L1:0.027895 L2:0.000000 L4:0.000166 | 
          >> Test macro:4.527929 ± 4.006077 | micro:0.149797 ± 0.036895          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 179/500 | Train(sampled) L1:0.027449 L2:0.000000 L4:0.000181 | 
          >> Test macro:7.045836 ± 6.558955 | micro:0.152731 ± 0.044689          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 180/500 | Train(sampled) L1:0.026721 L2:0.000000 L4:0.000192 | 
          >> Test macro:8.570122 ± 7.988448 | micro:0.159019 ± 0.046223          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 181/500 | Train(sampled) L1:0.033436 L2:0.000000 L4:0.000187 | 
          >> Test macro:3.408724 ± 2.858419 | micro:0.149708 ± 0.041713          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 182/500 | Train(sampled) L1:0.027373 L2:0.000000 L4:0.000180 | 
          >> Test macro:7.240898 ± 6.718237 | micro:0.147556 ± 0.044943          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 183/500 | Train(sampled) L1:0.027865 L2:0.000000 L4:0.000206 | 
          >> Test macro:1.663662 ± 1.160885 | micro:0.140301 ± 0.042122          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 184/500 | Train(sampled) L1:0.027112 L2:0.000000 L4:0.000176 | 
          >> Test macro:2.355180 ± 1.807636 | micro:0.141962 ± 0.040663          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 185/500 | Train(sampled) L1:0.027148 L2:0.000000 L4:0.000189 | 
          >> Test macro:3.658081 ± 3.133035 | micro:0.141863 ± 0.050172          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 186/500 | Train(sampled) L1:0.026231 L2:0.000000 L4:0.000173 | 
          >> Test macro:0.489973 ± 0.324950 | micro:0.137326 ± 0.036681          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 187/500 | Train(sampled) L1:0.025840 L2:0.000000 L4:0.000204 | 
          >> Test macro:1.192178 ± 0.684873 | micro:0.128133 ± 0.040772          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 188/500 | Train(sampled) L1:0.028912 L2:0.000000 L4:0.000196 | 
          >> Test macro:8.768375 ± 8.272883 | micro:0.167868 ± 0.050716          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 189/500 | Train(sampled) L1:0.027718 L2:0.000000 L4:0.000177 | 
          >> Test macro:3.833757 ± 3.363142 | micro:0.144737 ± 0.035264          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 190/500 | Train(sampled) L1:0.026640 L2:0.000000 L4:0.000178 | 
          >> Test macro:6.328150 ± 5.781380 | micro:0.155033 ± 0.043016          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 191/500 | Train(sampled) L1:0.026101 L2:0.000000 L4:0.000186 | 
          >> Test macro:1.768896 ± 1.223604 | micro:0.138685 ± 0.047820          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 192/500 | Train(sampled) L1:0.028733 L2:0.000000 L4:0.000204 | 
          >> Test macro:1.696057 ± 1.177478 | micro:0.132019 ± 0.043430          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 193/500 | Train(sampled) L1:0.027633 L2:0.000000 L4:0.000166 | 
          >> Test macro:1.308721 ± 0.812123 | micro:0.140522 ± 0.053901          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 194/500 | Train(sampled) L1:0.027058 L2:0.000000 L4:0.000186 | 
          >> Test macro:2.265030 ± 1.745684 | micro:0.138792 ± 0.041746          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 195/500 | Train(sampled) L1:0.026634 L2:0.000000 L4:0.000166 | 
          >> Test macro:0.660706 ± 0.290670 | micro:0.138004 ± 0.054737          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 196/500 | Train(sampled) L1:0.025410 L2:0.000000 L4:0.000155 | 
          >> Test macro:11.544821 ± 11.049038 | micro:0.152205 ± 0.050091          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 197/500 | Train(sampled) L1:0.027087 L2:0.000000 L4:0.000159 | 
          >> Test macro:2.165907 ± 1.622044 | micro:0.141253 ± 0.043726          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 198/500 | Train(sampled) L1:0.025803 L2:0.000000 L4:0.000174 | 
          >> Test macro:1.092802 ± 0.597962 | micro:0.135276 ± 0.043000          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 199/500 | Train(sampled) L1:0.025970 L2:0.000000 L4:0.000165 | 
          >> Test macro:2.926770 ± 2.418255 | micro:0.137108 ± 0.069134          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 200/500 | Train(sampled) L1:0.028085 L2:0.000000 L4:0.000184 | 
          >> Test macro:0.470468 ± 0.238287 | micro:0.125444 ± 0.050331          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 201/500 | Train(sampled) L1:0.024997 L2:0.000000 L4:0.000186 | 
          >> Test macro:0.583980 ± 0.283292 | micro:0.132331 ± 0.039114          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 202/500 | Train(sampled) L1:0.025859 L2:0.000000 L4:0.000157 | 
          >> Test macro:11.384027 ± 10.844001 | micro:0.158314 ± 0.045773          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 203/500 | Train(sampled) L1:0.025578 L2:0.000000 L4:0.000146 | 
          >> Test macro:2.035736 ± 1.514847 | micro:0.139905 ± 0.047734          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 204/500 | Train(sampled) L1:0.026125 L2:0.000000 L4:0.000143 | 
          >> Test macro:4.916846 ± 4.342491 | micro:0.160816 ± 0.041200          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 205/500 | Train(sampled) L1:0.028981 L2:0.000000 L4:0.000166 | 
          >> Test macro:3.495795 ± 3.013065 | micro:0.137249 ± 0.043104          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 206/500 | Train(sampled) L1:0.025992 L2:0.000000 L4:0.000144 | 
          >> Test macro:0.826227 ± 0.379603 | micro:0.133428 ± 0.042485          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 207/500 | Train(sampled) L1:0.025220 L2:0.000000 L4:0.000133 | 
          >> Test macro:1.418112 ± 0.908637 | micro:0.133886 ± 0.035452          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 208/500 | Train(sampled) L1:0.025044 L2:0.000000 L4:0.000133 | 
          >> Test macro:1.675656 ± 1.149914 | micro:0.136368 ± 0.046132          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 209/500 | Train(sampled) L1:0.025597 L2:0.000000 L4:0.000149 | 
          >> Test macro:0.631353 ± 0.273098 | micro:0.127206 ± 0.058971          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 210/500 | Train(sampled) L1:0.024744 L2:0.000000 L4:0.000113 | 
          >> Test macro:2.089572 ± 1.517066 | micro:0.150737 ± 0.037892          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 211/500 | Train(sampled) L1:0.025872 L2:0.000000 L4:0.000164 | 
          >> Test macro:1.313172 ± 0.843531 | micro:0.135978 ± 0.051893          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 212/500 | Train(sampled) L1:0.026567 L2:0.000000 L4:0.000172 | 
          >> Test macro:3.599082 ± 3.026499 | micro:0.146097 ± 0.045646          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 213/500 | Train(sampled) L1:0.023437 L2:0.000000 L4:0.000178 | 
          >> Test macro:4.833451 ± 4.306459 | micro:0.159479 ± 0.040815          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 214/500 | Train(sampled) L1:0.025037 L2:0.000000 L4:0.000137 | 
          >> Test macro:4.263268 ± 3.723850 | micro:0.152958 ± 0.034651          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 215/500 | Train(sampled) L1:0.025034 L2:0.000000 L4:0.000176 | 
          >> Test macro:3.797432 ± 3.260666 | micro:0.147981 ± 0.035578          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 216/500 | Train(sampled) L1:0.025026 L2:0.000000 L4:0.000177 | 
          >> Test macro:4.548202 ± 4.026408 | micro:0.142402 ± 0.040032          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 217/500 | Train(sampled) L1:0.026322 L2:0.000000 L4:0.000154 | 
          >> Test macro:1.180122 ± 0.706530 | micro:0.130040 ± 0.049915          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 218/500 | Train(sampled) L1:0.025122 L2:0.000000 L4:0.000158 | 
          >> Test macro:2.453931 ± 1.932163 | micro:0.133883 ± 0.042857          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 219/500 | Train(sampled) L1:0.025333 L2:0.000000 L4:0.000168 | 
          >> Test macro:0.670341 ± 0.296906 | micro:0.131443 ± 0.051066          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 220/500 | Train(sampled) L1:0.023991 L2:0.000000 L4:0.000175 | 
          >> Test macro:1.633792 ± 1.135301 | micro:0.138137 ± 0.047831          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 221/500 | Train(sampled) L1:0.024888 L2:0.000000 L4:0.000142 | 
          >> Test macro:6.920736 ± 6.401076 | micro:0.147065 ± 0.038695          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 222/500 | Train(sampled) L1:0.024166 L2:0.000000 L4:0.000152 | 
          >> Test macro:4.476015 ± 3.969097 | micro:0.141545 ± 0.038802          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 223/500 | Train(sampled) L1:0.025576 L2:0.000000 L4:0.000156 | 
          >> Test macro:4.952715 ± 4.422997 | micro:0.141747 ± 0.040044          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 224/500 | Train(sampled) L1:0.025320 L2:0.000000 L4:0.000191 | 
          >> Test macro:2.446754 ± 1.918359 | micro:0.149266 ± 0.038908          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 225/500 | Train(sampled) L1:0.024330 L2:0.000000 L4:0.000128 | 
          >> Test macro:7.661699 ± 7.126442 | micro:0.158632 ± 0.046643          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 226/500 | Train(sampled) L1:0.024563 L2:0.000000 L4:0.000145 | 
          >> Test macro:3.214085 ± 2.645512 | micro:0.138637 ± 0.040104          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 227/500 | Train(sampled) L1:0.024838 L2:0.000000 L4:0.000165 | 
          >> Test macro:3.734576 ± 3.226534 | micro:0.146003 ± 0.036716          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 228/500 | Train(sampled) L1:0.025229 L2:0.000000 L4:0.000132 | 
          >> Test macro:1.036992 ± 0.567354 | micro:0.132331 ± 0.042703          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 229/500 | Train(sampled) L1:0.024275 L2:0.000000 L4:0.000129 | 
          >> Test macro:1.276051 ± 0.777301 | micro:0.127393 ± 0.043249          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 230/500 | Train(sampled) L1:0.023788 L2:0.000000 L4:0.000186 | 
          >> Test macro:7.249311 ± 6.683194 | micro:0.155748 ± 0.041816          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 231/500 | Train(sampled) L1:0.023943 L2:0.000000 L4:0.000167 | 
          >> Test macro:0.898522 ± 0.432156 | micro:0.126523 ± 0.055267          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 232/500 | Train(sampled) L1:0.025166 L2:0.000000 L4:0.000142 | 
          >> Test macro:4.090921 ± 3.594229 | micro:0.153644 ± 0.032919          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 233/500 | Train(sampled) L1:0.025467 L2:0.000000 L4:0.000127 | 
          >> Test macro:1.365471 ± 0.852708 | micro:0.132732 ± 0.045858          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 234/500 | Train(sampled) L1:0.024900 L2:0.000000 L4:0.000110 | 
          >> Test macro:5.472152 ± 4.887638 | micro:0.156955 ± 0.042885          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 235/500 | Train(sampled) L1:0.024229 L2:0.000000 L4:0.000132 | 
          >> Test macro:0.520927 ± 0.240031 | micro:0.122826 ± 0.053074          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 236/500 | Train(sampled) L1:0.024416 L2:0.000000 L4:0.000140 | 
          >> Test macro:4.119281 ± 3.623794 | micro:0.144948 ± 0.038284          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 237/500 | Train(sampled) L1:0.023677 L2:0.000000 L4:0.000122 | 
          >> Test macro:0.459639 ± 0.256723 | micro:0.130413 ± 0.044612          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 238/500 | Train(sampled) L1:0.023850 L2:0.000000 L4:0.000145 | 
          >> Test macro:6.977565 ± 6.442912 | micro:0.146601 ± 0.035188          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 239/500 | Train(sampled) L1:0.024388 L2:0.000000 L4:0.000091 | 
          >> Test macro:0.549648 ± 0.291298 | micro:0.132217 ± 0.040170          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 240/500 | Train(sampled) L1:0.024764 L2:0.000000 L4:0.000162 | 
          >> Test macro:11.967885 ± 11.438976 | micro:0.145522 ± 0.046663          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 241/500 | Train(sampled) L1:0.024404 L2:0.000000 L4:0.000171 | 
          >> Test macro:2.957314 ± 2.431103 | micro:0.137499 ± 0.034102          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 242/500 | Train(sampled) L1:0.024621 L2:0.000000 L4:0.000107 | 
          >> Test macro:4.449670 ± 3.908937 | micro:0.149607 ± 0.037726          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 243/500 | Train(sampled) L1:0.024477 L2:0.000000 L4:0.000110 | 
          >> Test macro:1.093573 ± 0.602760 | micro:0.131850 ± 0.050884          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 244/500 | Train(sampled) L1:0.024100 L2:0.000000 L4:0.000117 | 
          >> Test macro:4.737194 ± 4.275374 | micro:0.145340 ± 0.041816          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 245/500 | Train(sampled) L1:0.023970 L2:0.000000 L4:0.000166 | 
          >> Test macro:6.739305 ± 6.235978 | micro:0.144550 ± 0.035690          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 246/500 | Train(sampled) L1:0.024227 L2:0.000000 L4:0.000152 | 
          >> Test macro:6.051783 ± 5.567225 | micro:0.146880 ± 0.041905          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 247/500 | Train(sampled) L1:0.024623 L2:0.000000 L4:0.000182 | 
          >> Test macro:0.899488 ± 0.430109 | micro:0.126143 ± 0.051794          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 248/500 | Train(sampled) L1:0.023661 L2:0.000000 L4:0.000120 | 
          >> Test macro:1.764728 ± 1.313618 | micro:0.128759 ± 0.041562          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 249/500 | Train(sampled) L1:0.023463 L2:0.000000 L4:0.000154 | 
          >> Test macro:6.788872 ± 6.237671 | micro:0.149242 ± 0.051448          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 250/500 | Train(sampled) L1:0.024458 L2:0.000000 L4:0.000115 | 
          >> Test macro:6.178160 ± 5.688819 | micro:0.149912 ± 0.047545          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 251/500 | Train(sampled) L1:0.023212 L2:0.000000 L4:0.000165 | 
          >> Test macro:6.419052 ± 5.852481 | micro:0.150427 ± 0.052202          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 252/500 | Train(sampled) L1:0.024416 L2:0.000000 L4:0.000105 | 
          >> Test macro:2.081075 ± 1.545723 | micro:0.138465 ± 0.039813          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 253/500 | Train(sampled) L1:0.025686 L2:0.000000 L4:0.000135 | 
          >> Test macro:4.493119 ± 3.987742 | micro:0.147558 ± 0.041647          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 254/500 | Train(sampled) L1:0.023665 L2:0.000000 L4:0.000107 | 
          >> Test macro:6.523779 ± 6.014697 | micro:0.149079 ± 0.040289          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 255/500 | Train(sampled) L1:0.025415 L2:0.000000 L4:0.000130 | 
          >> Test macro:8.270352 ± 7.681221 | micro:0.151800 ± 0.040122          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 256/500 | Train(sampled) L1:0.024950 L2:0.000000 L4:0.000166 | 
          >> Test macro:3.154700 ± 2.622840 | micro:0.141713 ± 0.035250          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 257/500 | Train(sampled) L1:0.023994 L2:0.000000 L4:0.000114 | 
          >> Test macro:0.438982 ± 0.257498 | micro:0.126842 ± 0.058896          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Early stopping at epoch 257/500 (best test score: 0.184310 @ epoch 207)
TEST RESULTS | macro: 5.929245 ± 5.404019 | micro: 0.139286 ± 0.042170macro (noise): 0.000000 ± 0.000000 | micro (noise): 0.000000 ± 0.000000
          >> per_group (weighted SE): {0: '0.084133 ± 0.001796 (n=1274)', 1: '0.293177 ± 0.093652 (n=2)', 4: '0.939636 ± 1.139487 (n=72)'}
          >> per_group (weighted SE): {0: '0.000000 ± 0.000000 (n=1274)', 1: '0.000000 ± 0.000000 (n=2)', 4: '0.000000 ± 0.000000 (n=72)'}


"""

# 2. Regex para cada bloco Epoch ... (duas linhas)
# Grupos nomeados pra ficar claro.
pattern = re.compile(
    r"Epoch\s+(?P<epoch>\d+)/\d+\s*\|\s*Train\(sampled\)\s*"
    r"L1:(?P<L1>\d+\.\d+)\s*L2:(?P<L2>\d+\.\d+)\s*L4:(?P<L4>\d+\.\d+)\s*\|\s*"
    r"\s*>>\s*Test\s+macro:(?P<test_macro_mean>\d+\.\d+)\s*±\s*(?P<test_macro_std>\d+\.\d+)\s*\|\s*micro:(?P<test_micro_mean>\d+\.\d+)\s*±\s*(?P<test_micro_std>\d+\.\d+)\s*"
    r">>\s*Test\s*\(Noise\)\s*macro:(?P<noise_macro_mean>\d+\.\d+)\s*±\s*(?P<noise_macro_std>\d+\.\d+)\s*\|\s*micro:(?P<noise_micro_mean>\d+\.\d+)\s*±\s*(?P<noise_micro_std>\d+\.\d+)",
    re.IGNORECASE
)

epochs_data = []

for m in pattern.finditer(log_text):
    epochs_data.append({
        "epoch": int(m.group("epoch")),
        "train_L1": float(m.group("L1")),
        "train_L2": float(m.group("L2")),
        "train_L4": float(m.group("L4")),

        "test_macro_mean": float(m.group("test_macro_mean")),
        "test_macro_std": float(m.group("test_macro_std")),
        "test_micro_mean": float(m.group("test_micro_mean")),
        "test_micro_std": float(m.group("test_micro_std")),

        "test_noise_macro_mean": float(m.group("noise_macro_mean")),
        "test_noise_macro_std": float(m.group("noise_macro_std")),
        "test_noise_micro_mean": float(m.group("noise_micro_mean")),
        "test_noise_micro_std": float(m.group("noise_micro_std")),
    })

# 3. Ordenar por época (só por higiene, caso regex leia fora de ordem)
epochs_data = sorted(epochs_data, key=lambda x: x["epoch"])

# 4. Salvar em JSON
with open("resultados_reconstrucao.json", "w") as f:
    json.dump(epochs_data, f, indent=2)

print(f"Extraídas {len(epochs_data)} épocas")
print("Exemplo de entrada salva:")
print(json.dumps(epochs_data[min(0, len(epochs_data)-1)], indent=2))
