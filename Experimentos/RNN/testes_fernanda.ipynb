# %% [markdown]
# json reconstrução

# %%
import re
import json

# 1. Coloque aqui o log bruto de reconstrução
log_text = r"""
GRUPOS (total): {0: 6372, 1: 12, 4: 361}
GRUPOS (train): {0: 5098, 1: 10, 4: 289}
GRUPOS (test):  {0: 1274, 1: 2, 4: 72}
Epoch 1/500 | Train(sampled) L1:6.826607 L2:0.000000 L4:0.834998 | 
          >> Test macro:145.900542 ± 143.961274 | micro:1.435329 ± 0.578073          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 2/500 | Train(sampled) L1:5.782731 L2:0.000000 L4:0.813049 | 
          >> Test macro:156.046815 ± 153.966873 | micro:1.286497 ± 0.483855          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 3/500 | Train(sampled) L1:4.625397 L2:0.000000 L4:0.761590 | 
          >> Test macro:181.382788 ± 179.477195 | micro:1.206270 ± 0.506087          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 4/500 | Train(sampled) L1:3.017502 L2:0.000000 L4:0.672330 | 
          >> Test macro:171.784005 ± 170.012612 | micro:1.226488 ± 0.550361          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 5/500 | Train(sampled) L1:2.401595 L2:0.000000 L4:0.547174 | 
          >> Test macro:153.902422 ± 152.103165 | micro:1.379610 ± 0.558804          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 6/500 | Train(sampled) L1:2.046012 L2:0.000000 L4:0.467798 | 
          >> Test macro:142.659019 ± 141.236642 | micro:1.060836 ± 0.473316          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 7/500 | Train(sampled) L1:1.821872 L2:0.000000 L4:0.407867 | 
          >> Test macro:124.771968 ± 123.257240 | micro:1.039424 ± 0.418219          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 8/500 | Train(sampled) L1:1.600265 L2:0.000000 L4:0.365318 | 
          >> Test macro:114.615961 ± 113.387750 | micro:0.938690 ± 0.433706          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 9/500 | Train(sampled) L1:1.359135 L2:0.000000 L4:0.331482 | 
          >> Test macro:105.320545 ± 104.349465 | micro:0.874760 ± 0.395017          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 10/500 | Train(sampled) L1:1.204954 L2:0.000000 L4:0.302090 | 
          >> Test macro:111.335991 ± 110.465970 | micro:0.813442 ± 0.389090          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 11/500 | Train(sampled) L1:1.078461 L2:0.000000 L4:0.276020 | 
          >> Test macro:99.172431 ± 98.270826 | micro:0.565541 ± 0.307021          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 12/500 | Train(sampled) L1:0.950773 L2:0.000000 L4:0.257951 | 
          >> Test macro:88.236166 ± 87.478402 | micro:0.530373 ± 0.244520          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 13/500 | Train(sampled) L1:0.862202 L2:0.000000 L4:0.242502 | 
          >> Test macro:64.470364 ± 63.733238 | micro:0.572166 ± 0.240736          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 14/500 | Train(sampled) L1:0.760263 L2:0.000000 L4:0.216137 | 
          >> Test macro:54.236830 ± 53.411694 | micro:0.464741 ± 0.178977          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 15/500 | Train(sampled) L1:0.633360 L2:0.000000 L4:0.194874 | 
          >> Test macro:36.347574 ± 35.584682 | micro:0.379323 ± 0.137542          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 16/500 | Train(sampled) L1:0.560826 L2:0.000000 L4:0.183896 | 
          >> Test macro:27.133196 ± 26.422223 | micro:0.344157 ± 0.100895          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 17/500 | Train(sampled) L1:0.484961 L2:0.000000 L4:0.163113 | 
          >> Test macro:12.971272 ± 12.183369 | micro:0.278855 ± 0.060565          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 18/500 | Train(sampled) L1:0.425145 L2:0.000000 L4:0.144487 | 
          >> Test macro:11.483438 ± 10.880990 | micro:0.229524 ± 0.043694          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 19/500 | Train(sampled) L1:0.378079 L2:0.000000 L4:0.133229 | 
          >> Test macro:7.262339 ± 6.673299 | micro:0.218752 ± 0.042742          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 20/500 | Train(sampled) L1:0.353799 L2:0.000000 L4:0.113919 | 
          >> Test macro:1.375898 ± 0.750964 | micro:0.193827 ± 0.043663          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 21/500 | Train(sampled) L1:0.348410 L2:0.000000 L4:0.098623 | 
          >> Test macro:11.088311 ± 10.481307 | micro:0.212850 ± 0.039790          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 22/500 | Train(sampled) L1:0.340496 L2:0.000000 L4:0.083772 | 
          >> Test macro:6.840583 ± 6.257303 | micro:0.207731 ± 0.035204          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 23/500 | Train(sampled) L1:0.325458 L2:0.000000 L4:0.068137 | 
          >> Test macro:1.642056 ± 0.981098 | micro:0.198229 ± 0.035593          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 24/500 | Train(sampled) L1:0.325884 L2:0.000000 L4:0.054953 | 
          >> Test macro:3.866417 ± 3.239098 | micro:0.183908 ± 0.038029          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 25/500 | Train(sampled) L1:0.323695 L2:0.000000 L4:0.044746 | 
          >> Test macro:1.239711 ± 0.662579 | micro:0.184658 ± 0.038637          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 26/500 | Train(sampled) L1:0.337625 L2:0.000000 L4:0.040850 | 
          >> Test macro:0.954102 ± 0.434199 | micro:0.175733 ± 0.042002          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 27/500 | Train(sampled) L1:0.326388 L2:0.000000 L4:0.033149 | 
          >> Test macro:2.853067 ± 2.264917 | micro:0.187562 ± 0.041808          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 28/500 | Train(sampled) L1:0.326762 L2:0.000000 L4:0.029276 | 
          >> Test macro:1.910070 ± 1.340177 | micro:0.176393 ± 0.041173          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 29/500 | Train(sampled) L1:0.302582 L2:0.000000 L4:0.026447 | 
          >> Test macro:6.761914 ± 6.192816 | micro:0.188538 ± 0.042955          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 30/500 | Train(sampled) L1:0.305297 L2:0.000000 L4:0.021773 | 
          >> Test macro:2.694169 ± 2.092684 | micro:0.182735 ± 0.036119          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 31/500 | Train(sampled) L1:0.323523 L2:0.000000 L4:0.019386 | 
          >> Test macro:0.706173 ± 0.291653 | micro:0.169042 ± 0.040797          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 32/500 | Train(sampled) L1:0.328780 L2:0.000000 L4:0.016868 | 
          >> Test macro:0.727736 ± 0.303616 | micro:0.167501 ± 0.039346          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 33/500 | Train(sampled) L1:0.318026 L2:0.000000 L4:0.015640 | 
          >> Test macro:1.571174 ± 1.035122 | micro:0.167014 ± 0.033490          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 34/500 | Train(sampled) L1:0.289245 L2:0.000000 L4:0.015695 | 
          >> Test macro:1.479780 ± 0.839558 | micro:0.175625 ± 0.043551          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 35/500 | Train(sampled) L1:0.300994 L2:0.000000 L4:0.012497 | 
          >> Test macro:1.857086 ± 1.256346 | micro:0.195412 ± 0.034469          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 36/500 | Train(sampled) L1:0.315395 L2:0.000000 L4:0.012477 | 
          >> Test macro:0.758058 ± 0.356183 | micro:0.176970 ± 0.039939          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 37/500 | Train(sampled) L1:0.308575 L2:0.000000 L4:0.011410 | 
          >> Test macro:2.311827 ± 1.706486 | micro:0.170324 ± 0.038811          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 38/500 | Train(sampled) L1:0.297666 L2:0.000000 L4:0.010166 | 
          >> Test macro:0.539481 ± 0.251408 | micro:0.164066 ± 0.040784          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 39/500 | Train(sampled) L1:0.299129 L2:0.000000 L4:0.009273 | 
          >> Test macro:4.722140 ± 4.153551 | micro:0.181649 ± 0.038646          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 40/500 | Train(sampled) L1:0.292357 L2:0.000000 L4:0.008395 | 
          >> Test macro:2.101336 ± 1.521093 | micro:0.179567 ± 0.039421          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 41/500 | Train(sampled) L1:0.291168 L2:0.000000 L4:0.007390 | 
          >> Test macro:1.356291 ± 0.793832 | micro:0.169794 ± 0.052644          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 42/500 | Train(sampled) L1:0.304264 L2:0.000000 L4:0.007162 | 
          >> Test macro:2.802355 ± 2.283000 | micro:0.168786 ± 0.038283          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 43/500 | Train(sampled) L1:0.293127 L2:0.000000 L4:0.006664 | 
          >> Test macro:5.080410 ± 4.534678 | micro:0.182538 ± 0.035976          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 44/500 | Train(sampled) L1:0.306982 L2:0.000000 L4:0.006138 | 
          >> Test macro:3.734578 ± 3.234144 | micro:0.161727 ± 0.040655          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 45/500 | Train(sampled) L1:0.294599 L2:0.000000 L4:0.005548 | 
          >> Test macro:2.771568 ± 2.258735 | micro:0.165716 ± 0.034327          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 46/500 | Train(sampled) L1:0.296428 L2:0.000000 L4:0.004876 | 
          >> Test macro:2.590857 ± 1.966269 | micro:0.170605 ± 0.038117          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 47/500 | Train(sampled) L1:0.289778 L2:0.000000 L4:0.004514 | 
          >> Test macro:0.953331 ± 0.424981 | micro:0.174173 ± 0.040346          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 48/500 | Train(sampled) L1:0.310696 L2:0.000000 L4:0.004683 | 
          >> Test macro:0.838150 ± 0.357342 | micro:0.174875 ± 0.052520          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 49/500 | Train(sampled) L1:0.289956 L2:0.000000 L4:0.004100 | 
          >> Test macro:3.008484 ± 2.410082 | micro:0.164049 ± 0.038855          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 50/500 | Train(sampled) L1:0.282476 L2:0.000000 L4:0.003846 | 
          >> Test macro:3.056076 ± 2.513298 | micro:0.163529 ± 0.040362          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 51/500 | Train(sampled) L1:0.283993 L2:0.000000 L4:0.003843 | 
          >> Test macro:2.065862 ± 1.392790 | micro:0.250298 ± 0.045543          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 52/500 | Train(sampled) L1:0.303241 L2:0.000000 L4:0.003750 | 
          >> Test macro:2.192649 ± 1.575972 | micro:0.176658 ± 0.047779          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 53/500 | Train(sampled) L1:0.305688 L2:0.000000 L4:0.003407 | 
          >> Test macro:6.111210 ± 5.589316 | micro:0.165132 ± 0.040851          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 54/500 | Train(sampled) L1:0.282485 L2:0.000000 L4:0.002967 | 
          >> Test macro:1.123842 ± 0.605845 | micro:0.168504 ± 0.038792          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 55/500 | Train(sampled) L1:0.292153 L2:0.000000 L4:0.003260 | 
          >> Test macro:0.741555 ± 0.320966 | micro:0.153031 ± 0.045534          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 56/500 | Train(sampled) L1:0.293192 L2:0.000000 L4:0.002782 | 
          >> Test macro:5.549713 ± 4.969419 | micro:0.177799 ± 0.043570          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 57/500 | Train(sampled) L1:0.299400 L2:0.000000 L4:0.002616 | 
          >> Test macro:1.374128 ± 0.834189 | micro:0.155330 ± 0.035379          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 58/500 | Train(sampled) L1:0.302448 L2:0.000000 L4:0.002572 | 
          >> Test macro:4.876037 ± 4.328839 | micro:0.163397 ± 0.035534          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 59/500 | Train(sampled) L1:0.294633 L2:0.000000 L4:0.002232 | 
          >> Test macro:5.533495 ± 4.945695 | micro:0.193361 ± 0.037206          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 60/500 | Train(sampled) L1:0.306005 L2:0.000000 L4:0.002410 | 
          >> Test macro:5.725536 ± 5.150671 | micro:0.175080 ± 0.035529          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 61/500 | Train(sampled) L1:0.288083 L2:0.000000 L4:0.002027 | 
          >> Test macro:2.315028 ± 1.745413 | micro:0.165637 ± 0.044026          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 62/500 | Train(sampled) L1:0.286694 L2:0.000000 L4:0.002093 | 
          >> Test macro:2.718735 ± 2.169258 | micro:0.159242 ± 0.043936          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 63/500 | Train(sampled) L1:0.290295 L2:0.000000 L4:0.001951 | 
          >> Test macro:1.727443 ± 1.121369 | micro:0.165875 ± 0.040055          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 64/500 | Train(sampled) L1:0.302047 L2:0.000000 L4:0.001747 | 
          >> Test macro:4.147714 ± 3.553828 | micro:0.171221 ± 0.036056          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 65/500 | Train(sampled) L1:0.305064 L2:0.000000 L4:0.001777 | 
          >> Test macro:2.313016 ± 1.769831 | micro:0.160889 ± 0.042977          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 66/500 | Train(sampled) L1:0.296073 L2:0.000000 L4:0.001850 | 
          >> Test macro:3.325766 ± 2.786334 | micro:0.166977 ± 0.034446          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 67/500 | Train(sampled) L1:0.278518 L2:0.000000 L4:0.001640 | 
          >> Test macro:0.427086 ± 0.274830 | micro:0.146325 ± 0.038838          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 68/500 | Train(sampled) L1:0.279000 L2:0.000000 L4:0.001531 | 
          >> Test macro:1.415481 ± 0.849773 | micro:0.153580 ± 0.045040          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 69/500 | Train(sampled) L1:0.283984 L2:0.000000 L4:0.001507 | 
          >> Test macro:3.889321 ± 3.313995 | micro:0.155681 ± 0.044090          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 70/500 | Train(sampled) L1:0.289566 L2:0.000000 L4:0.001569 | 
          >> Test macro:1.458484 ± 0.937694 | micro:0.160124 ± 0.041294          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 71/500 | Train(sampled) L1:0.284149 L2:0.000000 L4:0.001438 | 
          >> Test macro:2.265931 ± 1.688529 | micro:0.163958 ± 0.048673          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 72/500 | Train(sampled) L1:0.280935 L2:0.000000 L4:0.001303 | 
          >> Test macro:0.566999 ± 0.269402 | micro:0.142488 ± 0.053341          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 73/500 | Train(sampled) L1:0.286720 L2:0.000000 L4:0.001255 | 
          >> Test macro:1.282181 ± 0.718362 | micro:0.160001 ± 0.039757          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 74/500 | Train(sampled) L1:0.288068 L2:0.000000 L4:0.001302 | 
          >> Test macro:2.388292 ± 1.787747 | micro:0.165460 ± 0.037570          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 75/500 | Train(sampled) L1:0.286326 L2:0.000000 L4:0.001150 | 
          >> Test macro:5.231097 ± 4.666177 | micro:0.173835 ± 0.042732          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 76/500 | Train(sampled) L1:0.285249 L2:0.000000 L4:0.001267 | 
          >> Test macro:1.553649 ± 1.022136 | micro:0.149899 ± 0.041699          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 77/500 | Train(sampled) L1:0.294805 L2:0.000000 L4:0.001135 | 
          >> Test macro:3.467211 ± 2.900817 | micro:0.163875 ± 0.050225          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 78/500 | Train(sampled) L1:0.298486 L2:0.000000 L4:0.001167 | 
          >> Test macro:1.039974 ± 0.517428 | micro:0.149829 ± 0.037779          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 79/500 | Train(sampled) L1:0.273260 L2:0.000000 L4:0.001137 | 
          >> Test macro:3.409594 ± 2.847897 | micro:0.168101 ± 0.041739          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 80/500 | Train(sampled) L1:0.284511 L2:0.000000 L4:0.001140 | 
          >> Test macro:3.337386 ± 2.744172 | micro:0.176899 ± 0.042834          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 81/500 | Train(sampled) L1:0.287009 L2:0.000000 L4:0.001130 | 
          >> Test macro:3.180241 ± 2.600092 | micro:0.166922 ± 0.039838          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 82/500 | Train(sampled) L1:0.281866 L2:0.000000 L4:0.001212 | 
          >> Test macro:1.307487 ± 0.777896 | micro:0.153738 ± 0.047171          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 83/500 | Train(sampled) L1:0.283535 L2:0.000000 L4:0.000942 | 
          >> Test macro:3.695591 ± 3.107164 | micro:0.163151 ± 0.037276          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 84/500 | Train(sampled) L1:0.273118 L2:0.000000 L4:0.000827 | 
          >> Test macro:0.503653 ± 0.284592 | micro:0.141967 ± 0.046761          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 85/500 | Train(sampled) L1:0.274645 L2:0.000000 L4:0.000872 | 
          >> Test macro:3.653952 ± 3.077251 | micro:0.174943 ± 0.045880          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 86/500 | Train(sampled) L1:0.292271 L2:0.000000 L4:0.000942 | 
          >> Test macro:2.157867 ± 1.616105 | micro:0.152784 ± 0.046396          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 87/500 | Train(sampled) L1:0.284710 L2:0.000000 L4:0.000900 | 
          >> Test macro:3.145408 ± 2.594376 | micro:0.151157 ± 0.038525          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 88/500 | Train(sampled) L1:0.280829 L2:0.000000 L4:0.000931 | 
          >> Test macro:1.038757 ± 0.503627 | micro:0.148356 ± 0.048335          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 89/500 | Train(sampled) L1:0.288624 L2:0.000000 L4:0.000991 | 
          >> Test macro:8.283147 ± 7.740460 | micro:0.166683 ± 0.042371          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 90/500 | Train(sampled) L1:0.281996 L2:0.000000 L4:0.000799 | 
          >> Test macro:0.593657 ± 0.324503 | micro:0.187071 ± 0.045911          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 91/500 | Train(sampled) L1:0.294408 L2:0.000000 L4:0.000829 | 
          >> Test macro:3.345481 ± 2.788157 | micro:0.153976 ± 0.040189          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 92/500 | Train(sampled) L1:0.280835 L2:0.000000 L4:0.000842 | 
          >> Test macro:1.370485 ± 0.806736 | micro:0.150347 ± 0.043593          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 93/500 | Train(sampled) L1:0.297691 L2:0.000000 L4:0.000708 | 
          >> Test macro:0.571006 ± 0.280115 | micro:0.144839 ± 0.050065          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 94/500 | Train(sampled) L1:0.283155 L2:0.000000 L4:0.000729 | 
          >> Test macro:2.690706 ± 2.066991 | micro:0.152757 ± 0.042416          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 95/500 | Train(sampled) L1:0.297545 L2:0.000000 L4:0.000686 | 
          >> Test macro:4.089852 ± 3.491701 | micro:0.159073 ± 0.038635          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 96/500 | Train(sampled) L1:0.306359 L2:0.000000 L4:0.000663 | 
          >> Test macro:2.748971 ± 2.170974 | micro:0.150571 ± 0.064309          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 97/500 | Train(sampled) L1:0.296864 L2:0.000000 L4:0.000900 | 
          >> Test macro:0.998957 ± 0.459623 | micro:0.152085 ± 0.038063          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 98/500 | Train(sampled) L1:0.290646 L2:0.000000 L4:0.000784 | 
          >> Test macro:2.255691 ± 1.685037 | micro:0.155070 ± 0.039935          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 99/500 | Train(sampled) L1:0.281819 L2:0.000000 L4:0.000626 | 
          >> Test macro:6.592131 ± 6.017215 | micro:0.155603 ± 0.051732          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 100/500 | Train(sampled) L1:0.281715 L2:0.000000 L4:0.000519 | 
          >> Test macro:0.455076 ± 0.295580 | micro:0.138177 ± 0.052922          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 101/500 | Train(sampled) L1:0.281479 L2:0.000000 L4:0.000735 | 
          >> Test macro:0.570208 ± 0.280952 | micro:0.153091 ± 0.051370          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 102/500 | Train(sampled) L1:0.272165 L2:0.000000 L4:0.000570 | 
          >> Test macro:3.638082 ± 3.037524 | micro:0.158367 ± 0.047334          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 103/500 | Train(sampled) L1:0.281503 L2:0.000000 L4:0.000666 | 
          >> Test macro:0.480007 ± 0.346202 | micro:0.145270 ± 0.060813          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 104/500 | Train(sampled) L1:0.285074 L2:0.000000 L4:0.000515 | 
          >> Test macro:0.492480 ± 0.324062 | micro:0.142685 ± 0.053373          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 105/500 | Train(sampled) L1:0.291547 L2:0.000000 L4:0.000497 | 
          >> Test macro:1.488979 ± 0.935337 | micro:0.149144 ± 0.049844          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 106/500 | Train(sampled) L1:0.276483 L2:0.000000 L4:0.000559 | 
          >> Test macro:6.821136 ± 6.277564 | micro:0.159415 ± 0.048447          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 107/500 | Train(sampled) L1:0.281036 L2:0.000000 L4:0.000535 | 
          >> Test macro:6.839905 ± 6.224727 | micro:0.173142 ± 0.043950          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 108/500 | Train(sampled) L1:0.279616 L2:0.000000 L4:0.000518 | 
          >> Test macro:2.303852 ± 1.760329 | micro:0.148512 ± 0.051125          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 109/500 | Train(sampled) L1:0.279764 L2:0.000000 L4:0.000529 | 
          >> Test macro:0.702788 ± 0.305684 | micro:0.147633 ± 0.039932          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 110/500 | Train(sampled) L1:0.295231 L2:0.000000 L4:0.000580 | 
          >> Test macro:4.564530 ± 3.973511 | micro:0.159527 ± 0.038605          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 111/500 | Train(sampled) L1:0.286561 L2:0.000000 L4:0.000476 | 
          >> Test macro:3.147613 ± 2.606429 | micro:0.151914 ± 0.037161          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 112/500 | Train(sampled) L1:0.289750 L2:0.000000 L4:0.000437 | 
          >> Test macro:2.871572 ± 2.318703 | micro:0.147416 ± 0.044144          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 113/500 | Train(sampled) L1:0.278578 L2:0.000000 L4:0.000490 | 
          >> Test macro:0.587339 ± 0.292130 | micro:0.137556 ± 0.050203          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 114/500 | Train(sampled) L1:0.303542 L2:0.000000 L4:0.000515 | 
          >> Test macro:4.575757 ± 3.966223 | micro:0.156955 ± 0.039434          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 115/500 | Train(sampled) L1:0.292316 L2:0.000000 L4:0.000438 | 
          >> Test macro:0.461432 ± 0.295525 | micro:0.142005 ± 0.044718          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 116/500 | Train(sampled) L1:0.276783 L2:0.000000 L4:0.000473 | 
          >> Test macro:8.578542 ± 8.042555 | micro:0.161452 ± 0.044661          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 117/500 | Train(sampled) L1:0.286562 L2:0.000000 L4:0.000381 | 
          >> Test macro:2.417255 ± 1.896159 | micro:0.149849 ± 0.040899          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Early stopping at epoch 117/500 (best test score: 0.201601 @ epoch 67)
TEST RESULTS | macro: 4.596699 ± 4.026169 | micro: 0.164282 ± 0.047398macro (noise): 0.000000 ± 0.000000 | micro (noise): 0.000000 ± 0.000000
          >> per_group (weighted SE): {0: '0.095875 ± 0.002015 (n=1274)', 1: '6.174992 ± 2.910449 (n=2)', 4: '0.980899 ± 0.759452 (n=72)'}
          >> per_group (weighted SE): {0: '0.000000 ± 0.000000 (n=1274)', 1: '0.000000 ± 0.000000 (n=2)', 4: '0.000000 ± 0.000000 (n=72)'}

"""

# 2. Regex para cada bloco Epoch ... (duas linhas)
# Grupos nomeados pra ficar claro.
pattern = re.compile(
    r"Epoch\s+(?P<epoch>\d+)/\d+\s*\|\s*Train\(sampled\)\s*"
    r"L1:(?P<L1>\d+\.\d+)\s*L2:(?P<L2>\d+\.\d+)\s*L4:(?P<L4>\d+\.\d+)\s*\|\s*"
    r"\s*>>\s*Test\s+macro:(?P<test_macro_mean>\d+\.\d+)\s*±\s*(?P<test_macro_std>\d+\.\d+)\s*\|\s*micro:(?P<test_micro_mean>\d+\.\d+)\s*±\s*(?P<test_micro_std>\d+\.\d+)\s*"
    r">>\s*Test\s*\(Noise\)\s*macro:(?P<noise_macro_mean>\d+\.\d+)\s*±\s*(?P<noise_macro_std>\d+\.\d+)\s*\|\s*micro:(?P<noise_micro_mean>\d+\.\d+)\s*±\s*(?P<noise_micro_std>\d+\.\d+)",
    re.IGNORECASE
)

epochs_data = []

for m in pattern.finditer(log_text):
    epochs_data.append({
        "epoch": int(m.group("epoch")),
        "train_L1": float(m.group("L1")),
        "train_L2": float(m.group("L2")),
        "train_L4": float(m.group("L4")),

        "test_macro_mean": float(m.group("test_macro_mean")),
        "test_macro_std": float(m.group("test_macro_std")),
        "test_micro_mean": float(m.group("test_micro_mean")),
        "test_micro_std": float(m.group("test_micro_std")),

        "test_noise_macro_mean": float(m.group("noise_macro_mean")),
        "test_noise_macro_std": float(m.group("noise_macro_std")),
        "test_noise_micro_mean": float(m.group("noise_micro_mean")),
        "test_noise_micro_std": float(m.group("noise_micro_std")),
    })

# 3. Ordenar por época (só por higiene, caso regex leia fora de ordem)
epochs_data = sorted(epochs_data, key=lambda x: x["epoch"])

# 4. Salvar em JSON
with open("resultados_reconstrucao.json", "w") as f:
    json.dump(epochs_data, f, indent=2)

print(f"Extraídas {len(epochs_data)} épocas")
print("Exemplo de entrada salva:")
print(json.dumps(epochs_data[min(0, len(epochs_data)-1)], indent=2))
# Out:
# Extraídas 117 épocas
# Exemplo de entrada salva:
# {
#   "epoch": 1,
#   "train_L1": 6.826607,
#   "train_L2": 0.0,
#   "train_L4": 0.834998,
#   "test_macro_mean": 145.900542,
#   "test_macro_std": 143.961274,
#   "test_micro_mean": 1.435329,
#   "test_micro_std": 0.578073,
#   "test_noise_macro_mean": 0.0,
#   "test_noise_macro_std": 0.0,
#   "test_noise_micro_mean": 0.0,
#   "test_noise_micro_std": 0.0
# }

# %% [markdown]
# json predição

# %%
import re
import json
import pandas as pd

# ==========================================================
# COLE AQUI O TEXTO DO LOG BRUTO
# ==========================================================
raw_text = """
GRUPOS (total): {0: 6372, 1: 12, 4: 361}
GRUPOS (train): {0: 5098, 1: 10, 4: 289}
GRUPOS (test):  {0: 1274, 1: 2, 4: 72}
Epoch 1/500 | Train(sampled) L1:6.826607 L2:0.000000 L4:0.834998 | 
          >> Test macro:145.900542 ± 143.961274 | micro:1.435329 ± 0.578073          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 2/500 | Train(sampled) L1:5.782731 L2:0.000000 L4:0.813049 | 
          >> Test macro:156.046815 ± 153.966873 | micro:1.286497 ± 0.483855          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 3/500 | Train(sampled) L1:4.625397 L2:0.000000 L4:0.761590 | 
          >> Test macro:181.382788 ± 179.477195 | micro:1.206270 ± 0.506087          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 4/500 | Train(sampled) L1:3.017502 L2:0.000000 L4:0.672330 | 
          >> Test macro:171.784005 ± 170.012612 | micro:1.226488 ± 0.550361          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 5/500 | Train(sampled) L1:2.401595 L2:0.000000 L4:0.547174 | 
          >> Test macro:153.902422 ± 152.103165 | micro:1.379610 ± 0.558804          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 6/500 | Train(sampled) L1:2.046012 L2:0.000000 L4:0.467798 | 
          >> Test macro:142.659019 ± 141.236642 | micro:1.060836 ± 0.473316          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 7/500 | Train(sampled) L1:1.821872 L2:0.000000 L4:0.407867 | 
          >> Test macro:124.771968 ± 123.257240 | micro:1.039424 ± 0.418219          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 8/500 | Train(sampled) L1:1.600265 L2:0.000000 L4:0.365318 | 
          >> Test macro:114.615961 ± 113.387750 | micro:0.938690 ± 0.433706          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 9/500 | Train(sampled) L1:1.359135 L2:0.000000 L4:0.331482 | 
          >> Test macro:105.320545 ± 104.349465 | micro:0.874760 ± 0.395017          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 10/500 | Train(sampled) L1:1.204954 L2:0.000000 L4:0.302090 | 
          >> Test macro:111.335991 ± 110.465970 | micro:0.813442 ± 0.389090          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 11/500 | Train(sampled) L1:1.078461 L2:0.000000 L4:0.276020 | 
          >> Test macro:99.172431 ± 98.270826 | micro:0.565541 ± 0.307021          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 12/500 | Train(sampled) L1:0.950773 L2:0.000000 L4:0.257951 | 
          >> Test macro:88.236166 ± 87.478402 | micro:0.530373 ± 0.244520          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 13/500 | Train(sampled) L1:0.862202 L2:0.000000 L4:0.242502 | 
          >> Test macro:64.470364 ± 63.733238 | micro:0.572166 ± 0.240736          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 14/500 | Train(sampled) L1:0.760263 L2:0.000000 L4:0.216137 | 
          >> Test macro:54.236830 ± 53.411694 | micro:0.464741 ± 0.178977          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 15/500 | Train(sampled) L1:0.633360 L2:0.000000 L4:0.194874 | 
          >> Test macro:36.347574 ± 35.584682 | micro:0.379323 ± 0.137542          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 16/500 | Train(sampled) L1:0.560826 L2:0.000000 L4:0.183896 | 
          >> Test macro:27.133196 ± 26.422223 | micro:0.344157 ± 0.100895          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 17/500 | Train(sampled) L1:0.484961 L2:0.000000 L4:0.163113 | 
          >> Test macro:12.971272 ± 12.183369 | micro:0.278855 ± 0.060565          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 18/500 | Train(sampled) L1:0.425145 L2:0.000000 L4:0.144487 | 
          >> Test macro:11.483438 ± 10.880990 | micro:0.229524 ± 0.043694          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 19/500 | Train(sampled) L1:0.378079 L2:0.000000 L4:0.133229 | 
          >> Test macro:7.262339 ± 6.673299 | micro:0.218752 ± 0.042742          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 20/500 | Train(sampled) L1:0.353799 L2:0.000000 L4:0.113919 | 
          >> Test macro:1.375898 ± 0.750964 | micro:0.193827 ± 0.043663          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 21/500 | Train(sampled) L1:0.348410 L2:0.000000 L4:0.098623 | 
          >> Test macro:11.088311 ± 10.481307 | micro:0.212850 ± 0.039790          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 22/500 | Train(sampled) L1:0.340496 L2:0.000000 L4:0.083772 | 
          >> Test macro:6.840583 ± 6.257303 | micro:0.207731 ± 0.035204          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 23/500 | Train(sampled) L1:0.325458 L2:0.000000 L4:0.068137 | 
          >> Test macro:1.642056 ± 0.981098 | micro:0.198229 ± 0.035593          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 24/500 | Train(sampled) L1:0.325884 L2:0.000000 L4:0.054953 | 
          >> Test macro:3.866417 ± 3.239098 | micro:0.183908 ± 0.038029          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 25/500 | Train(sampled) L1:0.323695 L2:0.000000 L4:0.044746 | 
          >> Test macro:1.239711 ± 0.662579 | micro:0.184658 ± 0.038637          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 26/500 | Train(sampled) L1:0.337625 L2:0.000000 L4:0.040850 | 
          >> Test macro:0.954102 ± 0.434199 | micro:0.175733 ± 0.042002          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 27/500 | Train(sampled) L1:0.326388 L2:0.000000 L4:0.033149 | 
          >> Test macro:2.853067 ± 2.264917 | micro:0.187562 ± 0.041808          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 28/500 | Train(sampled) L1:0.326762 L2:0.000000 L4:0.029276 | 
          >> Test macro:1.910070 ± 1.340177 | micro:0.176393 ± 0.041173          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 29/500 | Train(sampled) L1:0.302582 L2:0.000000 L4:0.026447 | 
          >> Test macro:6.761914 ± 6.192816 | micro:0.188538 ± 0.042955          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 30/500 | Train(sampled) L1:0.305297 L2:0.000000 L4:0.021773 | 
          >> Test macro:2.694169 ± 2.092684 | micro:0.182735 ± 0.036119          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 31/500 | Train(sampled) L1:0.323523 L2:0.000000 L4:0.019386 | 
          >> Test macro:0.706173 ± 0.291653 | micro:0.169042 ± 0.040797          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 32/500 | Train(sampled) L1:0.328780 L2:0.000000 L4:0.016868 | 
          >> Test macro:0.727736 ± 0.303616 | micro:0.167501 ± 0.039346          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 33/500 | Train(sampled) L1:0.318026 L2:0.000000 L4:0.015640 | 
          >> Test macro:1.571174 ± 1.035122 | micro:0.167014 ± 0.033490          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 34/500 | Train(sampled) L1:0.289245 L2:0.000000 L4:0.015695 | 
          >> Test macro:1.479780 ± 0.839558 | micro:0.175625 ± 0.043551          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 35/500 | Train(sampled) L1:0.300994 L2:0.000000 L4:0.012497 | 
          >> Test macro:1.857086 ± 1.256346 | micro:0.195412 ± 0.034469          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 36/500 | Train(sampled) L1:0.315395 L2:0.000000 L4:0.012477 | 
          >> Test macro:0.758058 ± 0.356183 | micro:0.176970 ± 0.039939          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 37/500 | Train(sampled) L1:0.308575 L2:0.000000 L4:0.011410 | 
          >> Test macro:2.311827 ± 1.706486 | micro:0.170324 ± 0.038811          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 38/500 | Train(sampled) L1:0.297666 L2:0.000000 L4:0.010166 | 
          >> Test macro:0.539481 ± 0.251408 | micro:0.164066 ± 0.040784          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 39/500 | Train(sampled) L1:0.299129 L2:0.000000 L4:0.009273 | 
          >> Test macro:4.722140 ± 4.153551 | micro:0.181649 ± 0.038646          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 40/500 | Train(sampled) L1:0.292357 L2:0.000000 L4:0.008395 | 
          >> Test macro:2.101336 ± 1.521093 | micro:0.179567 ± 0.039421          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 41/500 | Train(sampled) L1:0.291168 L2:0.000000 L4:0.007390 | 
          >> Test macro:1.356291 ± 0.793832 | micro:0.169794 ± 0.052644          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 42/500 | Train(sampled) L1:0.304264 L2:0.000000 L4:0.007162 | 
          >> Test macro:2.802355 ± 2.283000 | micro:0.168786 ± 0.038283          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 43/500 | Train(sampled) L1:0.293127 L2:0.000000 L4:0.006664 | 
          >> Test macro:5.080410 ± 4.534678 | micro:0.182538 ± 0.035976          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 44/500 | Train(sampled) L1:0.306982 L2:0.000000 L4:0.006138 | 
          >> Test macro:3.734578 ± 3.234144 | micro:0.161727 ± 0.040655          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 45/500 | Train(sampled) L1:0.294599 L2:0.000000 L4:0.005548 | 
          >> Test macro:2.771568 ± 2.258735 | micro:0.165716 ± 0.034327          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 46/500 | Train(sampled) L1:0.296428 L2:0.000000 L4:0.004876 | 
          >> Test macro:2.590857 ± 1.966269 | micro:0.170605 ± 0.038117          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 47/500 | Train(sampled) L1:0.289778 L2:0.000000 L4:0.004514 | 
          >> Test macro:0.953331 ± 0.424981 | micro:0.174173 ± 0.040346          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 48/500 | Train(sampled) L1:0.310696 L2:0.000000 L4:0.004683 | 
          >> Test macro:0.838150 ± 0.357342 | micro:0.174875 ± 0.052520          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 49/500 | Train(sampled) L1:0.289956 L2:0.000000 L4:0.004100 | 
          >> Test macro:3.008484 ± 2.410082 | micro:0.164049 ± 0.038855          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 50/500 | Train(sampled) L1:0.282476 L2:0.000000 L4:0.003846 | 
          >> Test macro:3.056076 ± 2.513298 | micro:0.163529 ± 0.040362          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 51/500 | Train(sampled) L1:0.283993 L2:0.000000 L4:0.003843 | 
          >> Test macro:2.065862 ± 1.392790 | micro:0.250298 ± 0.045543          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 52/500 | Train(sampled) L1:0.303241 L2:0.000000 L4:0.003750 | 
          >> Test macro:2.192649 ± 1.575972 | micro:0.176658 ± 0.047779          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 53/500 | Train(sampled) L1:0.305688 L2:0.000000 L4:0.003407 | 
          >> Test macro:6.111210 ± 5.589316 | micro:0.165132 ± 0.040851          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 54/500 | Train(sampled) L1:0.282485 L2:0.000000 L4:0.002967 | 
          >> Test macro:1.123842 ± 0.605845 | micro:0.168504 ± 0.038792          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 55/500 | Train(sampled) L1:0.292153 L2:0.000000 L4:0.003260 | 
          >> Test macro:0.741555 ± 0.320966 | micro:0.153031 ± 0.045534          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 56/500 | Train(sampled) L1:0.293192 L2:0.000000 L4:0.002782 | 
          >> Test macro:5.549713 ± 4.969419 | micro:0.177799 ± 0.043570          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 57/500 | Train(sampled) L1:0.299400 L2:0.000000 L4:0.002616 | 
          >> Test macro:1.374128 ± 0.834189 | micro:0.155330 ± 0.035379          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 58/500 | Train(sampled) L1:0.302448 L2:0.000000 L4:0.002572 | 
          >> Test macro:4.876037 ± 4.328839 | micro:0.163397 ± 0.035534          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 59/500 | Train(sampled) L1:0.294633 L2:0.000000 L4:0.002232 | 
          >> Test macro:5.533495 ± 4.945695 | micro:0.193361 ± 0.037206          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 60/500 | Train(sampled) L1:0.306005 L2:0.000000 L4:0.002410 | 
          >> Test macro:5.725536 ± 5.150671 | micro:0.175080 ± 0.035529          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 61/500 | Train(sampled) L1:0.288083 L2:0.000000 L4:0.002027 | 
          >> Test macro:2.315028 ± 1.745413 | micro:0.165637 ± 0.044026          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 62/500 | Train(sampled) L1:0.286694 L2:0.000000 L4:0.002093 | 
          >> Test macro:2.718735 ± 2.169258 | micro:0.159242 ± 0.043936          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 63/500 | Train(sampled) L1:0.290295 L2:0.000000 L4:0.001951 | 
          >> Test macro:1.727443 ± 1.121369 | micro:0.165875 ± 0.040055          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 64/500 | Train(sampled) L1:0.302047 L2:0.000000 L4:0.001747 | 
          >> Test macro:4.147714 ± 3.553828 | micro:0.171221 ± 0.036056          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 65/500 | Train(sampled) L1:0.305064 L2:0.000000 L4:0.001777 | 
          >> Test macro:2.313016 ± 1.769831 | micro:0.160889 ± 0.042977          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 66/500 | Train(sampled) L1:0.296073 L2:0.000000 L4:0.001850 | 
          >> Test macro:3.325766 ± 2.786334 | micro:0.166977 ± 0.034446          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 67/500 | Train(sampled) L1:0.278518 L2:0.000000 L4:0.001640 | 
          >> Test macro:0.427086 ± 0.274830 | micro:0.146325 ± 0.038838          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 68/500 | Train(sampled) L1:0.279000 L2:0.000000 L4:0.001531 | 
          >> Test macro:1.415481 ± 0.849773 | micro:0.153580 ± 0.045040          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 69/500 | Train(sampled) L1:0.283984 L2:0.000000 L4:0.001507 | 
          >> Test macro:3.889321 ± 3.313995 | micro:0.155681 ± 0.044090          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 70/500 | Train(sampled) L1:0.289566 L2:0.000000 L4:0.001569 | 
          >> Test macro:1.458484 ± 0.937694 | micro:0.160124 ± 0.041294          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 71/500 | Train(sampled) L1:0.284149 L2:0.000000 L4:0.001438 | 
          >> Test macro:2.265931 ± 1.688529 | micro:0.163958 ± 0.048673          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 72/500 | Train(sampled) L1:0.280935 L2:0.000000 L4:0.001303 | 
          >> Test macro:0.566999 ± 0.269402 | micro:0.142488 ± 0.053341          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 73/500 | Train(sampled) L1:0.286720 L2:0.000000 L4:0.001255 | 
          >> Test macro:1.282181 ± 0.718362 | micro:0.160001 ± 0.039757          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 74/500 | Train(sampled) L1:0.288068 L2:0.000000 L4:0.001302 | 
          >> Test macro:2.388292 ± 1.787747 | micro:0.165460 ± 0.037570          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 75/500 | Train(sampled) L1:0.286326 L2:0.000000 L4:0.001150 | 
          >> Test macro:5.231097 ± 4.666177 | micro:0.173835 ± 0.042732          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 76/500 | Train(sampled) L1:0.285249 L2:0.000000 L4:0.001267 | 
          >> Test macro:1.553649 ± 1.022136 | micro:0.149899 ± 0.041699          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 77/500 | Train(sampled) L1:0.294805 L2:0.000000 L4:0.001135 | 
          >> Test macro:3.467211 ± 2.900817 | micro:0.163875 ± 0.050225          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 78/500 | Train(sampled) L1:0.298486 L2:0.000000 L4:0.001167 | 
          >> Test macro:1.039974 ± 0.517428 | micro:0.149829 ± 0.037779          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 79/500 | Train(sampled) L1:0.273260 L2:0.000000 L4:0.001137 | 
          >> Test macro:3.409594 ± 2.847897 | micro:0.168101 ± 0.041739          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 80/500 | Train(sampled) L1:0.284511 L2:0.000000 L4:0.001140 | 
          >> Test macro:3.337386 ± 2.744172 | micro:0.176899 ± 0.042834          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 81/500 | Train(sampled) L1:0.287009 L2:0.000000 L4:0.001130 | 
          >> Test macro:3.180241 ± 2.600092 | micro:0.166922 ± 0.039838          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 82/500 | Train(sampled) L1:0.281866 L2:0.000000 L4:0.001212 | 
          >> Test macro:1.307487 ± 0.777896 | micro:0.153738 ± 0.047171          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 83/500 | Train(sampled) L1:0.283535 L2:0.000000 L4:0.000942 | 
          >> Test macro:3.695591 ± 3.107164 | micro:0.163151 ± 0.037276          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 84/500 | Train(sampled) L1:0.273118 L2:0.000000 L4:0.000827 | 
          >> Test macro:0.503653 ± 0.284592 | micro:0.141967 ± 0.046761          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 85/500 | Train(sampled) L1:0.274645 L2:0.000000 L4:0.000872 | 
          >> Test macro:3.653952 ± 3.077251 | micro:0.174943 ± 0.045880          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 86/500 | Train(sampled) L1:0.292271 L2:0.000000 L4:0.000942 | 
          >> Test macro:2.157867 ± 1.616105 | micro:0.152784 ± 0.046396          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 87/500 | Train(sampled) L1:0.284710 L2:0.000000 L4:0.000900 | 
          >> Test macro:3.145408 ± 2.594376 | micro:0.151157 ± 0.038525          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 88/500 | Train(sampled) L1:0.280829 L2:0.000000 L4:0.000931 | 
          >> Test macro:1.038757 ± 0.503627 | micro:0.148356 ± 0.048335          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 89/500 | Train(sampled) L1:0.288624 L2:0.000000 L4:0.000991 | 
          >> Test macro:8.283147 ± 7.740460 | micro:0.166683 ± 0.042371          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 90/500 | Train(sampled) L1:0.281996 L2:0.000000 L4:0.000799 | 
          >> Test macro:0.593657 ± 0.324503 | micro:0.187071 ± 0.045911          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 91/500 | Train(sampled) L1:0.294408 L2:0.000000 L4:0.000829 | 
          >> Test macro:3.345481 ± 2.788157 | micro:0.153976 ± 0.040189          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 92/500 | Train(sampled) L1:0.280835 L2:0.000000 L4:0.000842 | 
          >> Test macro:1.370485 ± 0.806736 | micro:0.150347 ± 0.043593          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 93/500 | Train(sampled) L1:0.297691 L2:0.000000 L4:0.000708 | 
          >> Test macro:0.571006 ± 0.280115 | micro:0.144839 ± 0.050065          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 94/500 | Train(sampled) L1:0.283155 L2:0.000000 L4:0.000729 | 
          >> Test macro:2.690706 ± 2.066991 | micro:0.152757 ± 0.042416          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 95/500 | Train(sampled) L1:0.297545 L2:0.000000 L4:0.000686 | 
          >> Test macro:4.089852 ± 3.491701 | micro:0.159073 ± 0.038635          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 96/500 | Train(sampled) L1:0.306359 L2:0.000000 L4:0.000663 | 
          >> Test macro:2.748971 ± 2.170974 | micro:0.150571 ± 0.064309          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 97/500 | Train(sampled) L1:0.296864 L2:0.000000 L4:0.000900 | 
          >> Test macro:0.998957 ± 0.459623 | micro:0.152085 ± 0.038063          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 98/500 | Train(sampled) L1:0.290646 L2:0.000000 L4:0.000784 | 
          >> Test macro:2.255691 ± 1.685037 | micro:0.155070 ± 0.039935          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 99/500 | Train(sampled) L1:0.281819 L2:0.000000 L4:0.000626 | 
          >> Test macro:6.592131 ± 6.017215 | micro:0.155603 ± 0.051732          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 100/500 | Train(sampled) L1:0.281715 L2:0.000000 L4:0.000519 | 
          >> Test macro:0.455076 ± 0.295580 | micro:0.138177 ± 0.052922          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 101/500 | Train(sampled) L1:0.281479 L2:0.000000 L4:0.000735 | 
          >> Test macro:0.570208 ± 0.280952 | micro:0.153091 ± 0.051370          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 102/500 | Train(sampled) L1:0.272165 L2:0.000000 L4:0.000570 | 
          >> Test macro:3.638082 ± 3.037524 | micro:0.158367 ± 0.047334          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 103/500 | Train(sampled) L1:0.281503 L2:0.000000 L4:0.000666 | 
          >> Test macro:0.480007 ± 0.346202 | micro:0.145270 ± 0.060813          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 104/500 | Train(sampled) L1:0.285074 L2:0.000000 L4:0.000515 | 
          >> Test macro:0.492480 ± 0.324062 | micro:0.142685 ± 0.053373          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 105/500 | Train(sampled) L1:0.291547 L2:0.000000 L4:0.000497 | 
          >> Test macro:1.488979 ± 0.935337 | micro:0.149144 ± 0.049844          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 106/500 | Train(sampled) L1:0.276483 L2:0.000000 L4:0.000559 | 
          >> Test macro:6.821136 ± 6.277564 | micro:0.159415 ± 0.048447          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 107/500 | Train(sampled) L1:0.281036 L2:0.000000 L4:0.000535 | 
          >> Test macro:6.839905 ± 6.224727 | micro:0.173142 ± 0.043950          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 108/500 | Train(sampled) L1:0.279616 L2:0.000000 L4:0.000518 | 
          >> Test macro:2.303852 ± 1.760329 | micro:0.148512 ± 0.051125          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 109/500 | Train(sampled) L1:0.279764 L2:0.000000 L4:0.000529 | 
          >> Test macro:0.702788 ± 0.305684 | micro:0.147633 ± 0.039932          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 110/500 | Train(sampled) L1:0.295231 L2:0.000000 L4:0.000580 | 
          >> Test macro:4.564530 ± 3.973511 | micro:0.159527 ± 0.038605          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 111/500 | Train(sampled) L1:0.286561 L2:0.000000 L4:0.000476 | 
          >> Test macro:3.147613 ± 2.606429 | micro:0.151914 ± 0.037161          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 112/500 | Train(sampled) L1:0.289750 L2:0.000000 L4:0.000437 | 
          >> Test macro:2.871572 ± 2.318703 | micro:0.147416 ± 0.044144          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 113/500 | Train(sampled) L1:0.278578 L2:0.000000 L4:0.000490 | 
          >> Test macro:0.587339 ± 0.292130 | micro:0.137556 ± 0.050203          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 114/500 | Train(sampled) L1:0.303542 L2:0.000000 L4:0.000515 | 
          >> Test macro:4.575757 ± 3.966223 | micro:0.156955 ± 0.039434          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 115/500 | Train(sampled) L1:0.292316 L2:0.000000 L4:0.000438 | 
          >> Test macro:0.461432 ± 0.295525 | micro:0.142005 ± 0.044718          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 116/500 | Train(sampled) L1:0.276783 L2:0.000000 L4:0.000473 | 
          >> Test macro:8.578542 ± 8.042555 | micro:0.161452 ± 0.044661          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Epoch 117/500 | Train(sampled) L1:0.286562 L2:0.000000 L4:0.000381 | 
          >> Test macro:2.417255 ± 1.896159 | micro:0.149849 ± 0.040899          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
Early stopping at epoch 117/500 (best test score: 0.201601 @ epoch 67)
TEST RESULTS | macro: 4.596699 ± 4.026169 | micro: 0.164282 ± 0.047398macro (noise): 0.000000 ± 0.000000 | micro (noise): 0.000000 ± 0.000000
          >> per_group (weighted SE): {0: '0.095875 ± 0.002015 (n=1274)', 1: '6.174992 ± 2.910449 (n=2)', 4: '0.980899 ± 0.759452 (n=72)'}
          >> per_group (weighted SE): {0: '0.000000 ± 0.000000 (n=1274)', 1: '0.000000 ± 0.000000 (n=2)', 4: '0.000000 ± 0.000000 (n=72)'}

"""


# ==========================================================
# REGEX PARA EXTRAIR OS VALORES
# ==========================================================

pattern = re.compile(
    r"Epoch\s+(\d+)/\d+\s*\|\s*Train\(sampled\)\s*L1:([\d\.]+)\s*L4:([\d\.]+)\s*\|"
    r"(?:\s*>>)?\s*Test\s+macro:([\d\.]+)\s*±\s*([\d\.]+)\s*\|\s*micro:([\d\.]+)\s*±\s*([\d\.]+)",
    re.MULTILINE
)

entries = []

for match in pattern.findall(raw_text):
    epoch, train_L1, train_L4, macro_mean, macro_std, micro_mean, micro_std = match

    entries.append({
        "epoch": int(epoch),
        "train_L1": float(train_L1),
        "train_L4": float(train_L4),
        "test_macro_mean": float(macro_mean),
        "test_macro_std": float(macro_std),
        "test_micro_mean": float(micro_mean),
        "test_micro_std": float(micro_std)
    })

# ==========================================================
# MOSTRAR RESULTADO E SALVAR JSON
# ==========================================================

df = pd.DataFrame(entries)
print(df)

output_json = "model_output.json"
with open(output_json, "w") as f:
    json.dump(entries, f, indent=2)

print(f"\nJSON salvo como: {output_json}")
# Out:
# Empty DataFrame
# Columns: []
# Index: []
#
# JSON salvo como: model_output.json
