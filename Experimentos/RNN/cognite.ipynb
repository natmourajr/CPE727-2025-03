# %% [markdown]
# # Notebook de Análise, Pré-processamento e Modelagem
# ## Foco: Compressor da Base Cognite Open Industrial Data
#
# **Objetivo:** Este notebook guia a exploração de dados do compressor, no pré-processamento e na construção de um modelo LSTM-Autoencoder para detecção de anomalias.
#
# **Passos:**
# 1.  **Configuração:** Instalação e importação das bibliotecas.
# 2.  **Conexão:** Autenticação na API da Cognite.
# 3.  **Identificação do Ativo:** Localização do compressor e justificativa.
# 4.  **Exploração de Documentos:** Busca por P&IDs.
# 5.  **Análise de Séries Temporais:** Listagem e recuperação dos dados dos sensores.
# 6.  **Análise Exploratória (EDA):** Análise estatística, visualização e técnicas adicionais.
# 7.  **Pré-processamento:** Limpeza, normalização e criação de sequências.
# 8.  **Construção do Modelo:** Arquitetura do LSTM-Autoencoder.
# 9.  **Treinamento do Modelo:** Treino com dados de operação normal.
# 10. **Análise de Anomalias:** Cálculo do erro e definição de limiar.
# 11. **Visualização de Anomalias:** Plotagem dos pontos anômalos identificados.

# %% [markdown]
# ### 1. Configuração do Ambiente

# %%
#!pip install "cognite-sdk[pandas]" matplotlib seaborn tensorflow plotly -q

import os
from datetime import datetime, timedelta
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from cognite.client import CogniteClient, ClientConfig
from cognite.client.credentials import OAuthClientCredentials
from IPython.display import display
from sklearn.preprocessing import MinMaxScaler,StandardScaler,RobustScaler
from statsmodels.tsa.stattools import acf
import json
#import tensorflow as tf
#from tensorflow import keras

print("Bibliotecas importadas com sucesso!")
# Out:
# Bibliotecas importadas com sucesso!

# %%
import debugpy
debugpy.listen(('0.0.0.0', 5678))
# Out:
# ('0.0.0.0', 5678)

# %% [markdown]
# ### 2. Conexão com a Cognite Data Fusion (CDF)
#
# Para acessar o projeto `publicdata`, a autenticação é feita via `OAuthClientCredentials`. É necessário inserir o `CLIENT_ID` e `CLIENT_SECRET` gerados no [Hub do Open Industrial Data](https://hub.cognite.com/open-industrial-data-211/index2.html).

# %%
# --- CREDENCIAIS ---
CLIENT_ID = "1b90ede3-271e-401b-81a0-a4d52bea3273"
CLIENT_SECRET = "Znb8Q~EIOfVZ6bfTCVv5GUmJVGqcuFv7ba1rlbdH"
# ----------------------------------

# Configurações do projeto publicdata
TENANT_ID = "48d5043c-cf70-4c49-881c-c638f5796997"
COGNITE_PROJECT = "publicdata"
BASE_URL = "https://api.cognitedata.com"

# Configuração das credenciais
creds = OAuthClientCredentials(
    token_url=f"https://login.microsoftonline.com/{TENANT_ID}/oauth2/v2.0/token",
    client_id=CLIENT_ID,
    client_secret=CLIENT_SECRET,
    scopes=[f"{BASE_URL}/.default"],
)

# Instanciação do client Cognite
cdf_config = ClientConfig(client_name="eda-compressor-analysis", project=COGNITE_PROJECT, credentials=creds, base_url=BASE_URL)
client = CogniteClient(cdf_config)

# Status da conexão
try:
    token_status = client.iam.token.inspect()
    print(f"Conexão bem-sucedida ao projeto: {token_status.projects[0].project_url_name}")
except Exception as e:
    print(f"Falha na conexão: {e}")
# Out:
# Conexão bem-sucedida ao projeto: publicdatacdm

# %% [markdown]
# ### 3. Identificação do Compressor

# %%
# Listar séries temporais e descrições
time_series_list = client.time_series.list(limit=None)

# Exibir nome e descrição das séries
for ts in time_series_list:
    print(f"ID: {ts.external_id}")
    print(f"Nome: {ts.name}")
    print(f"Descrição: {ts.description}")
    print("-" * 40)
# Out:
# ID: pi:160627
# Nome: VAL_23-PDT-92501:X.Value
# Descrição: PH 1stStgSuctCool Gas In ESDV
# ----------------------------------------
# ID: pi:161021
# Nome: VAL_23-YA-96118-02:Z.X.Value
# Descrição: PH 1stStg Gear1 Journ BRG NDE
# ----------------------------------------
# ID: pi:160252
# Nome: VAL_23-KA-9101-M01_OC_low stage_NOC3low:VALUE
# Descrição: PH (SwitchGear) MV-COMP.M. FEEDER/ 51-protection (trip 3I>)
# ----------------------------------------
# ID: test_1720820924110_TS
# Nome: test
# Descrição: test
# ----------------------------------------
# ID: houston.ro.REMOTE_AI[27]
# Nome: FIT85-27
# Descrição: Flow Rate Permeate Pass 2
# ----------------------------------------
# ID: pi:160731
# Nome: VAL_23-PT-96186:Z.X1.Value
# Descrição: PH 1st Stg Oil Header
# ----------------------------------------
# ID: pi:160031
# Nome: VAL_23_FIC_92543_02:Z.X.Value
# Descrição: PH 1stStgComp AntSrg Act CntrlMod
# ----------------------------------------
# ID: pi:161024
# Nome: VAL_23-YA-96120-01:Z.X.Value
# Descrição: PH 1stStg Gear2 Journ BRG DE
# ----------------------------------------
# ID: pi:160920
# Nome: VAL_23-TT-96115-01:Z.X.Value
# Descrição: PH 1stStg Gear Thrust BRG IN
# ----------------------------------------
# ID: pi:160574
# Nome: VAL_23-LY-92529_SILch0_SC0_TYSP:VALUE
# Descrição: PH (Profiler) Shutdown Channel 0 - Tube y Setpoint
# ----------------------------------------
# ID: pi:160061
# Nome: VAL_23_FT_92537_03:Z.X.Value
# Descrição: PH 1stStgComp Flow
# ----------------------------------------
# ID: pi:160060
# Nome: VAL_23_FT_92537_02:Z.X.Value
# Descrição: PH 1stStgComp Discharge
# ----------------------------------------
# ID: pi:160072
# Nome: VAL_23_PIC_92538_02:Z.X.Value
# Descrição: PH 1stStgComp STV Perf Act CtrlMod
# ----------------------------------------
# ID: pi:160919
# Nome: VAL_23-TT-96114-03:Z.X.Value
# Descrição: PH 1stStg Gear2 Journ BRG DE
# ----------------------------------------
# ID: Schedule_Multiply_1754999257280_TS
# Nome: Schedule Multiply
# Descrição: None
# ----------------------------------------
# ID: pi:160623
# Nome: VAL_23-PDI-96249:X.Value
# Descrição: PH 1st Stg Comp Over Inner Seal
# ----------------------------------------
# ID: pi:160244
# Nome: VAL_23-KA-9101-M01_Motor_Winding_Temp_Trip:VALUE
# Descrição: PH (SwitchGear) MV-COMP.M. FEEDER/ motor winding warning trip
# ----------------------------------------
# ID: pi:160836
# Nome: VAL_23-TIC-96147:Z.Y.Value
# Descrição: PH 1stStg Comp Seal Gas Output
# ----------------------------------------
# ID: pi:160259
# Nome: VAL_23-KA-9101-M01_TCS_Protection_Trip:VALUE
# Descrição: PH (SwitchGear) MV-COMP.M. FEEDER/ TCS Protection Trip
# ----------------------------------------
# ID: pi:161062
# Nome: VAL_23-YZSL-92545-F:X.Value
# Descrição: PH 1st Stg Comp Disch BDV SOV ZSL Flt
# ----------------------------------------
# ID: pi:160670
# Nome: VAL_23-PIC-96153:Control Module:YR
# Descrição: PH 1stStg Comp Inner Seal Working Setpoint
# ----------------------------------------
# ID: pi:160566
# Nome: VAL_23-LY-92529_Setpoints_SP_waterHi:VALUE
# Descrição: PH (Profiler) Water deadband high setpoint
# ----------------------------------------
# ID: pi:160030
# Nome: VAL_23_FIC_92543_01:Z.X.Value
# Descrição: PH 1stStgComp AntiSrg Cntrl OP
# ----------------------------------------
# ID: pi:160765
# Nome: VAL_23-TE-96137-01:X.Value
# Descrição: PH 1stStg Mtr Cold Air
# ----------------------------------------
# ID: houston.ro.REMOTE_AI[23]
# Nome: FIT40-23
# Descrição: Flow Rate Retentate Pass 1
# ----------------------------------------
# ID: pi:160785
# Nome: VAL_23-TIC-92604:Control Module:PD
# Descrição: PH 1stStgDiscCool Gas Out Derivate time
# ----------------------------------------
# ID: pi:160223
# Nome: VAL_23-KA-9101_EPR:VALUE
# Descrição: PH (CBM) 1st Stage ExpPress Ratio
# ----------------------------------------
# ID: Valve_position_1722455890734_TS
# Nome: Valve position
# Descrição: None
# ----------------------------------------
# ID: pi:163659
# Nome: VAL_45-TT-92607B:X.Value
# Descrição: PH 1stStgDiscClr CoolMed Out
# ----------------------------------------
# ID: pi:160179
# Nome: VAL_23-FI-92512A:X.Value
# Descrição: PH 1stStgSuctCool Gas In (Norm)
# ----------------------------------------
# ID: pi:160775
# Nome: VAL_23-TIC-92504:Control Module:BX
# Descrição: PH 1stStgSuctCool Gas Out External
# ----------------------------------------
# ID: pi:160632
# Nome: VAL_23-PDT-92551:X.Value
# Descrição: PH 1stStgDiscCool Gas Out ESDV
# ----------------------------------------
# ID: pi:160560
# Nome: VAL_23-LY-92529_Outputs_sandLevel:VALUE
# Descrição: PH (Profiler) % Scaled Level Output for Level F or Sand
# ----------------------------------------
# ID: pi:160182
# Nome: VAL_23-FT-92512:X.Value
# Descrição: PH 1stStgSuctCool Gas In
# ----------------------------------------
# ID: pi:160729
# Nome: VAL_23-PT-96160:Z.X2.Value
# Descrição: PH 1st Stg Comp Separation Gas
# ----------------------------------------
# ID: pi:160886
# Nome: VAL_23-TT-92539:X.Value
# Descrição: PH 1stStgComp Discharge
# ----------------------------------------
# ID: pi:160925
# Nome: VAL_23-TT-96132-01:Z.X.Value
# Descrição: PH 1stStg Journ BRG DE
# ----------------------------------------
# ID: pi:163523
# Nome: VAL_45-PDT-92606:X.Value
# Descrição: PH 1stStgDiscCool CM
# ----------------------------------------
# ID: pi:160732
# Nome: VAL_23-PT-96186:Z.X2.Value
# Descrição: PH 1st Stg Oil Header
# ----------------------------------------
# ID: pi:160261
# Nome: VAL_23-KA-9101-M01_Winding_Temperature_U1:VALUE
# Descrição: PH (SwitchGear)
# ----------------------------------------
# ID: pi:160068
# Nome: VAL_23_KA_9101_M01_62C:Z.X.Value
# Descrição: PH 1stStg Comp Mtr Current
# ----------------------------------------
# ID: pi:160500
# Nome: VAL_23-LIC-92521:Z.Y.Value
# Descrição: PH 1stStgSuctScrubber Level Output
# ----------------------------------------
# ID: houston.smb.MainProgram\RO_ACID_PUMP_RUNNING
# Nome: RO_ACID_PUMP_RUNNING
# Descrição:
# ----------------------------------------
# ID: pi:160545
# Nome: VAL_23-LY-92529_DensityBands_02foamLL:VALUE
# Descrição: PH (Profiler) Density Band 5 Lower Limit (FOAM)
# ----------------------------------------
# ID: pi:160912
# Nome: VAL_23-TT-96111-01:Z.X.Value
# Descrição: PH 1stStg Comp 1 Journ BRG DE
# ----------------------------------------
# ID: pi:160929
# Nome: VAL_23-TT-96147-02:X.Value
# Descrição: PH 1st Stg Comp Sealgas Heater
# ----------------------------------------
# ID: pi:161069
# Nome: VAL_23-ZA-96121-01:Z.X.Value
# Descrição: PH 1stStg Gear Schaft Axial
# ----------------------------------------
# ID: pi:160725
# Nome: VAL_23-PT-96156:Z.X2.Value
# Descrição: PH 1st Stg Outer Seal DE
# ----------------------------------------
# ID: houston.ro.REMOTE_AI[18]
# Nome: LIT201-18
# Descrição: Tank Level PWST201
# ----------------------------------------
# ID: pi:160260
# Nome: VAL_23-KA-9101-M01_Thermal_overload_TOL3dev:VALUE
# Descrição: PH (SwitchGear)
# ----------------------------------------
# ID: pi:160577
# Nome: VAL_23-NY-96144-02:VALUE
# Descrição: PH (CBM) Phase B Negative NQN
# ----------------------------------------
# ID: pi:160171
# Nome: VAL_23-FE-9122-H01-F:Z.Y.Value
# Descrição: PH 1stStg Seal Gas Heater
# ----------------------------------------
# ID: houston.ro.FIT_40_TOTAL_FLOW_GAL_A
# Nome: FIT_40_TOTAL_FLOW_GAL_A
# Descrição: Totalized Flow from FIT40-23
# ----------------------------------------
# ID: pi:160696
# Nome: VAL_23-PT-92504:X.Value
# Descrição: PH 1stStgSuctCool Gas Out
# ----------------------------------------
# ID: pi:160576
# Nome: VAL_23-NY-96144-01:VALUE
# Descrição: PH (CBM) Phase A Negative NQN
# ----------------------------------------
# ID: pi:160192
# Nome: VAL_23-FT-96158:X.Value
# Descrição: PH 1stStg Comp Buffer Gas DE
# ----------------------------------------
# ID: houston.smb.MainProgram\RO_WATER_OK
# Nome: RO_WATER_OK
# Descrição:
# ----------------------------------------
# ID: pi:160667
# Nome: VAL_23-PIC-96153:Control Module:PD
# Descrição: PH 1stStg Comp Inner Seal Derivate time
# ----------------------------------------
# ID: houston.ro.REMOTE_AI[19]
# Nome: AIT201-19
# Descrição: TBD
# ----------------------------------------
# ID: pi:160918
# Nome: VAL_23-TT-96114-01:Z.X.Value
# Descrição: PH 1stStg Gear2 Journ BRG DE
# ----------------------------------------
# ID: houston.ro.REMOTE_AI[22]
# Nome: FIT20-22
# Descrição: Flow Rate City Water Feed
# ----------------------------------------
# ID: pi:160119
# Nome: VAL_23_TT_96132_02:Z.X.Value
# Descrição: PH 1stStg Journ BRG DE
# ----------------------------------------
# ID: pi:160613
# Nome: VAL_23-PC-9109-M01-39:X.Value
# Descrição: PH 1st Stg Aux Oil Pump Running
# ----------------------------------------
# ID: pi:160248
# Nome: VAL_23-KA-9101-M01_OC_high stage_NOC3high:VALUE
# Descrição: PH (SwitchGear) MV-COMP.M. FEEDER/ 50/51/51B-protection (trip 3I>>)
# ----------------------------------------
# ID: houston.ro.REMOTE_AI[17]
# Nome: LT301-17
# Descrição: Tank Level PWST301
# ----------------------------------------
# ID: pi:160845
# Nome: VAL_23-TIC-96148:Z.Y.Value
# Descrição: PH 1stStg Comp Seal Gas Output
# ----------------------------------------
# ID: pi:160555
# Nome: VAL_23-LY-92529_NON-SILStatus_Heartbeat:VALUE
# Descrição: PH (Profiler) System Heartbeat/Watchdog
# ----------------------------------------
# ID: pi:160118
# Nome: VAL_23_TT_96131_02:Z.X.Value
# Descrição: PH 1stStg Journ BRG NDE
# ----------------------------------------
# ID: pi:160671
# Nome: VAL_23-PIC-96153:MODE
# Descrição: PH 1stStg Comp Inner Seal Mode
# ----------------------------------------
# ID: houston.ro.REMOTE_AI[21]
# Nome: TIT202-21
# Descrição: Temperature Transmitter to PWST201
# ----------------------------------------
# ID: houston.ro.REMOTE_AI[35]
# Nome: AIT51-35
# Descrição: pH Pass1 Permeate
# ----------------------------------------
# ID: pi:160563
# Nome: VAL_23-LY-92529_Setpoints_SP_foamHi:VALUE
# Descrição: PH (Profiler) Foam deadband high setpoint
# ----------------------------------------
# ID: pi:161057
# Nome: VAL_23-YZSH-92545-F:X.Value
# Descrição: PH 1st Stg Comp Disch BDV SOV ZSH Flt
# ----------------------------------------
# ID: pi:160565
# Nome: VAL_23-LY-92529_Setpoints_SP_oilHi:VALUE
# Descrição: PH (Profiler) Oil deadband high setpoint
# ----------------------------------------
# ID: pi:163364
# Nome: VAL_45-FT-92139A:X.Value
# Descrição: PH 1stStg Mtr Cooler CW
# ----------------------------------------
# ID: pi:160829
# Nome: VAL_23-TIC-96147:Control Module:BX
# Descrição: PH 1stStg Comp Seal Gas External
# ----------------------------------------
# ID: test_1720821053096_TS
# Nome: test
# Descrição: test
# ----------------------------------------
# ID: pi:160924
# Nome: VAL_23-TT-96131-01:Z.X.Value
# Descrição: PH 1stStg Journ BRG NDE
# ----------------------------------------
# ID: pi:160170
# Nome: VAL_23-FE-9122-39:X.Value
# Descrição: PH 1st Stg Seal Gas Heater Running
# ----------------------------------------
# ID: pi:160885
# Nome: VAL_23-TT-92537:X.Value
# Descrição: PH 1stStgComp Discharge
# ----------------------------------------
# ID: pi:160913
# Nome: VAL_23-TT-96111-03:Z.X.Value
# Descrição: PH 1stStg Comp 1 Journ BRG DE
# ----------------------------------------
# ID: houston.ro.REMOTE_AI[5]
# Nome: PIT25-5
# Descrição: Pressure Transmitter Pass 1 Feed
# ----------------------------------------
# ID: Valhala_Valve_Distance_Calculations_1742581399614_TS
# Nome: Valhala Valve Distance Calculations
# Descrição: None
# ----------------------------------------
# ID: pi:160226
# Nome: VAL_23-KA-9101_PHD:VALUE
# Descrição: PH (CBM) 1st Stage Poly Head Dev
# ----------------------------------------
# ID: houston.smb.MainProgram\RO_BASE_PUMP_AVAILABLE_TIME
# Nome: RO_BASE_PUMP_AVAILABLE_TIME
# Descrição:
# ----------------------------------------
# ID: pi:160556
# Nome: VAL_23-LY-92529_Outputs_emulsionLevel:VALUE
# Descrição: PH (Profiler) % Scaled Level Output for Level D or Emulsion
# ----------------------------------------
# ID: pi:160180
# Nome: VAL_23-FI-92512B:X.Value
# Descrição: PH 1stStgSuctCool Gas In (Std)
# ----------------------------------------
# ID: pi:160202
# Nome: VAL_23-FZSL-92542:X.Value
# Descrição: PH 1st Stg Comp HGB Closed
# ----------------------------------------
# ID: pi:160783
# Nome: VAL_23-TIC-92604:Control Module:BA
# Descrição: PH 1stStgDiscCool Gas Out Auto
# ----------------------------------------
# ID: pi:160568
# Nome: VAL_23-LY-92529_SILch0_SC0_TX1SP:VALUE
# Descrição: PH (Profiler) Shutdown Channel 0 - Tube x1 Setpoint
# ----------------------------------------
# ID: pi:160116
# Nome: VAL_23_TT_96101_01:Z.X.Value
# Descrição: PH 1stStg Comp Journ BRG DE
# ----------------------------------------
# ID: pi:160933
# Nome: VAL_23-TT-96181-03:X.Value
# Descrição: PH 1stStg Lube Oil System Header
# ----------------------------------------
# ID: pi:160247
# Nome: VAL_23-KA-9101-M01_OC_high stage_negative_seq_NPShigh:VALUE
# Descrição: PH (SwitchGear)
# ----------------------------------------
# ID: pi:160703
# Nome: VAL_23-PT-92539:X.Value
# Descrição: PH 1stStgComp Discharge
# ----------------------------------------
# ID: Vishal_Testing_1753193323233_TS
# Nome: Vishal Testing
# Descrição: None
# ----------------------------------------
# ID: pi:160521
# Nome: VAL_23-LT-92529-02:X.Value
# Descrição: PH 1stStgScrub I-face TopLiq
# ----------------------------------------
# ID: houston.ro.REMOTE_AI[73]
# Nome: DPT25-73
# Descrição: Differential Pressure Pass 1
# ----------------------------------------
# ID: pi:160542
# Nome: VAL_23-LY-92529_Alarms_PNTA:VALUE
# Descrição: PH (Profiler) Number of Active Tube Alarms
# ----------------------------------------
# ID: pi:160270
# Nome: VAL_23-KA-9101-M01-EL:XS.CoreStatus.XGL.Signal.Value
# Descrição: PH Circuit Breaker Open (OFF)
# ----------------------------------------
# ID: pi:160537
# Nome: VAL_23-LV-92521B:Y.Value
# Descrição: PH 1stStgSuctScrubber Level
# ----------------------------------------
# ID: pi:160567
# Nome: VAL_23-LY-92529_SILch0_SC0_TX1PSP:VALUE
# Descrição: PH (Profiler) Shutdown Channel 0 - Tube x1 Position Setpoint
# ----------------------------------------
# ID: pi:160835
# Nome: VAL_23-TIC-96147:Z.X.Value
# Descrição: PH 1stStg Comp Seal Gas Measured Value
# ----------------------------------------
# ID: pi:160543
# Nome: VAL_23-LY-92529_DensityBands_01gasLL:VALUE
# Descrição: PH (Profiler) Density Band 6 Lower Limit (GAS)
# ----------------------------------------
# ID: pi:161017
# Nome: VAL_23-YA-96106-02:Z.X.Value
# Descrição: PH 1stStg Comp1 Journ BRG NDE
# ----------------------------------------
# ID: pi:160587
# Nome: VAL_23-NY-96144-12:VALUE
# Descrição: PH (CBM) Phase C Positive Qmax
# ----------------------------------------
# ID: houston.smb.MainProgram\RO_ACID_PUMP_READY
# Nome: RO_ACID_PUMP_READY
# Descrição:
# ----------------------------------------
# ID: pi:160117
# Nome: VAL_23_TT_96102_01:Z.X.Value
# Descrição: PH 1stStg Comp Journ BRG NDE
# ----------------------------------------
# ID: pi:160647
# Nome: VAL_23-PDT-96161:X.Value
# Descrição: PH 1st Stg Comp Booster Filter
# ----------------------------------------
# ID: pi:160546
# Nome: VAL_23-LY-92529_DensityBands_02foamUL:VALUE
# Descrição: PH (Profiler) Density Band 5 Upper Limit (FOAM)
# ----------------------------------------
# ID: pi:160492
# Nome: VAL_23-LIC-92521:Control Module:BA
# Descrição: PH 1stStgSuctScrubber Level Auto
# ----------------------------------------
# ID: pi:160586
# Nome: VAL_23-NY-96144-11:VALUE
# Descrição: PH (CBM) Phase B Positive Qmax
# ----------------------------------------
# ID: pi:191153
# Nome: VAL_23-TIC-92604B:Z.Y.Value
# Descrição: PH 1stStgDiscCool Gas Out Output
# ----------------------------------------
# ID: pi:160105
# Nome: VAL_23_PT_92537:Z.X.Value
# Descrição: PH 1stStgComp Discharge
# ----------------------------------------
# ID: pi:160882
# Nome: VAL_23-TT-92502:X.Value
# Descrição: PH 1stStgSuctCool Gas In
# ----------------------------------------
# ID: pi:160930
# Nome: VAL_23-TT-96168:X.Value
# Descrição: PH 1st Stg Comp Inner Seal
# ----------------------------------------
# ID: pi:160191
# Nome: VAL_23-FT-96152:X.Value
# Descrição: PH 1stStg Comp Inner Seal NDE
# ----------------------------------------
# ID: pi:160840
# Nome: VAL_23-TIC-96148:Control Module:PI
# Descrição: PH 1stStg Comp Seal Gas Integral time
# ----------------------------------------
# ID: pi:160229
# Nome: VAL_23-KA-9101-M01:HSI.StatusMotorOn
# Descrição: PH 1st Stage Compressor Running
# ----------------------------------------
# ID: pi:160529
# Nome: VAL_23-LT-96182-03:X.Value
# Descrição: PH 1stStg Lube Oil Reservoir
# ----------------------------------------
# ID: pi:160832
# Nome: VAL_23-TIC-96147:Control Module:PP
# Descrição: PH 1stStg Comp Seal Gas Gain
# ----------------------------------------
# ID: pi:160075
# Nome: VAL_23_PIC_92538_05:Z.X.Value
# Descrição: PH 1stStgComp STV Perf Prim SP
# ----------------------------------------
# ID: pi:160077
# Nome: VAL_23_PIC_92538_07:Z.X.Value
# Descrição: PH 1stStgComp Perf Limit 1 SP
# ----------------------------------------
# ID: pi:160730
# Nome: VAL_23-PT-96160-03:X.Value
# Descrição: PH 1st Stg Comp Separation Gas
# ----------------------------------------
# ID: pi:160493
# Nome: VAL_23-LIC-92521:Control Module:BX
# Descrição: PH 1stStgSuctScrubber Level External
# ----------------------------------------
# ID: pi:160926
# Nome: VAL_23-TT-96136-02:Z.X.Value
# Descrição: PH 1stStg Mtr Winding U1
# ----------------------------------------
# ID: pi:160269
# Nome: VAL_23-KA-9101-M01-EL:XS.CoreStatus.XGH.Signal.Value
# Descrição: PH Circuit Breaker Closed (ON)
# ----------------------------------------
# ID: pi:160841
# Nome: VAL_23-TIC-96148:Control Module:PP
# Descrição: PH 1stStg Comp Seal Gas Gain
# ----------------------------------------
# ID: pi:160722
# Nome: VAL_23-PT-96150:Z.X1.Value
# Descrição: PH 1st Stg Inner Seal NDE
# ----------------------------------------
# ID: pi:160570
# Nome: VAL_23-LY-92529_SILch0_SC0_TXSP:VALUE
# Descrição: PH (Profiler) Shutdown Channel 0 - Tube x Setpoint
# ----------------------------------------
# ID: pi:160554
# Nome: VAL_23-LY-92529_DensityBands_06sandUL:VALUE
# Descrição: PH (Profiler) Density Band 1 Upper Limit (SAND)
# ----------------------------------------
# ID: pi:160569
# Nome: VAL_23-LY-92529_SILch0_SC0_TXPSP:VALUE
# Descrição: PH (Profiler) Shutdown Channel 0 - Tube x Position Setpoint
# ----------------------------------------
# ID: pi:160629
# Nome: VAL_23-PDT-92522:X.Value
# Descrição: PH 1stStgSuctScrubber Gas Out
# ----------------------------------------
# ID: pi:160238
# Nome: VAL_23-KA-9101-M01_E_stop_active:VALUE
# Descrição: PH (SwitchGear)
# ----------------------------------------
# ID: pi:160111
# Nome: VAL_23_TT_92536:Z.X.Value
# Descrição: PH 1stStgComp Discharge Temp
# ----------------------------------------
# ID: pi:161004
# Nome: VAL_23-XA-96125-A:Z.X.Value
# Descrição: PH 1stStg KEYPH Gear2 Shaft
# ----------------------------------------
# ID: pi:160073
# Nome: VAL_23_PIC_92538_03:Z.X.Value
# Descrição: PH 1stStgComp STV Perf State
# ----------------------------------------
# ID: pi:160148
# Nome: VAL_23-ESDV-92521-PST:VALUE
# Descrição: PH
# ----------------------------------------
# ID: cdf1_1758435644258_TS
# Nome: cdf1
# Descrição: None
# ----------------------------------------
# ID: pi:161025
# Nome: VAL_23-YA-96120-02:Z.X.Value
# Descrição: PH 1stStg Gear2 Journ BRG DE
# ----------------------------------------
# ID: pi:160081
# Nome: VAL_23_PIC_92538_13:Z.X.Value
# Descrição: PH Limit Loop 3 Set Point
# ----------------------------------------
# ID: pi:163655
# Nome: VAL_45-TT-92506:X.Value
# Descrição: PH 1stStgSuctClr CoolMed Sply
# ----------------------------------------
# ID: pi:160614
# Nome: VAL_23-PC-9109-M01-EL:XS.MeasuredValues.CurrentL2.Value.Value
# Descrição: PH 1stStg Comp Lube Oil Pump
# ----------------------------------------
# ID: pi:160665
# Nome: VAL_23-PIC-96153:Control Module:BA
# Descrição: PH 1stStg Comp Inner Seal Auto
# ----------------------------------------
# ID: pi:195975
# Nome: VAL_23-FT-92537-04:X.Value
# Descrição: PH 1stStgComp Vol Flow
# ----------------------------------------
# ID: houston.ro.AUTO_MODE_A
# Nome: RO1Auto Mode
# Descrição: Auto Mode Pass 1
# ----------------------------------------
# ID: pi:161061
# Nome: VAL_23-YZSL-92526-F:X.Value
# Descrição: PH 1st Stg Comp Suct BDV SOV ZSL Flt
# ----------------------------------------
# ID: pi:161027
# Nome: VAL_23-YA-96123:Z.X.Value
# Descrição: PH 1stStg Gear2 Velocimeter
# ----------------------------------------
# ID: pi:160928
# Nome: VAL_23-TT-96136-08:Z.X.Value
# Descrição: PH 1stStgMtr Winding W
# ----------------------------------------
# ID: houston.ro.REMOTE_AI[12]
# Nome: PIT70-12
# Descrição: Pressure Transmitter Pass 2 Retentate
# ----------------------------------------
# ID: pi:160220
# Nome: VAL_23-KA-9101_ASP:VALUE
# Descrição: PH (CBM) 1st Stage ActShaft Power
# ----------------------------------------
# ID: pi:160080
# Nome: VAL_23_PIC_92538_12:Z.X.Value
# Descrição: PH Limit Loop 3 Process Variable
# ----------------------------------------
# ID: pi:160922
# Nome: VAL_23-TT-96116-01:Z.X.Value
# Descrição: PH 1stStg Gear Thrust BRG OUT
# ----------------------------------------
# ID: pi:160520
# Nome: VAL_23-LT-92523:Z.X2.Value
# Descrição: PH 1stStgSuctScrubber
# ----------------------------------------
# ID: houston.ro.REMOTE_AI[76]
# Nome: DPT65-76
# Descrição: Differential Pressure Pass 2
# ----------------------------------------
# ID: pi:160156
# Nome: VAL_23-FE-9106-H01-EL:XS.MeasuredValues.CurrentL2.Value.Value
# Descrição: PH 1stStgComp OIL HEATER
# ----------------------------------------
# ID: pi:161056
# Nome: VAL_23-YZSH-92526-F:X.Value
# Descrição: PH 1st Stg Comp Suct BDV SOV ZSH Flt
# ----------------------------------------
# ID: pi:160147
# Nome: VAL_23-ESDV-92501B-PST:VALUE
# Descrição: PH
# ----------------------------------------
# ID: pi:161005
# Nome: VAL_23-XA-96135-A:Z.X.Value
# Descrição: PH 1stStg KEYPH Mtr Shaft
# ----------------------------------------
# ID: pi:160536
# Nome: VAL_23-LV-92521A:Y.Value
# Descrição: PH 1stStgSuctScrubber Level
# ----------------------------------------
# ID: pi:160130
# Nome: VAL_23_YT_96134_01:Z.X.Value
# Descrição: PH 1stStg Mtr Journ BRG DE
# ----------------------------------------
# ID: houston.ro.REMOTE_AI[36]
# Nome: AIT90-36
# Descrição: pH CIP Tank
# ----------------------------------------
# ID: pi:160140
# Nome: VAL_23_ZT_92538:Z.X.Value
# Descrição: PH 1stStgComp Valve Position
# ----------------------------------------
# ID: pi:160628
# Nome: VAL_23-PDT-92502:X.Value
# Descrição: PH 1stStgSuctCool Tubes
# ----------------------------------------
# ID: pi:160995
# Nome: VAL_23-VA-9110-M01-EL:XS.MeasuredValues.CurrentL2.Value.Value
# Descrição: PH 1stStgComp Oil Mist Fan
# ----------------------------------------
# ID: pi:160697
# Nome: VAL_23-PT-92512:X.Value
# Descrição: PH 1stStgSuctCool Gas In
# ----------------------------------------
# ID: pi:160666
# Nome: VAL_23-PIC-96153:Control Module:BX
# Descrição: PH 1stStg Comp Inner Seal External
# ----------------------------------------
# ID: pi:160227
# Nome: VAL_23-KA-9101_PRD:VALUE
# Descrição: PH (CBM) 1st Stage Press Rat Dev
# ----------------------------------------
# ID: pi:160552
# Nome: VAL_23-LY-92529_DensityBands_05waterUL:VALUE
# Descrição: PH (Profiler) Density Band 2 Upper Limit (WATER)
# ----------------------------------------
# ID: houston.ro.REMOTE_AI[10]
# Nome: PIT65-10
# Descrição: Pressure Transmitter Pass 2 Feed
# ----------------------------------------
# ID: pi:160257
# Nome: VAL_23-KA-9101-M01_Selector_switch_local_remote:VALUE
# Descrição: PH (SwitchGear) MV-COMP.M. FEEDER/ Selector switch local / remote
# ----------------------------------------
# ID: pi:160146
# Nome: VAL_23-ESDV-92501A-PST:VALUE
# Descrição: PH
# ----------------------------------------
# ID: pi:160272
# Nome: VAL_23-KA-9101-M01-EL:XS.CoreStatus.XZ.Signal.Value
# Descrição: PH Truck in Test
# ----------------------------------------
# ID: pi:160702
# Nome: VAL_23-PT-92536:X.Value
# Descrição: PH 1stStgComp Discharge
# ----------------------------------------
# ID: pi:160559
# Nome: VAL_23-LY-92529_Outputs_oilLevel:VALUE
# Descrição: PH (Profiler) % Scaled Level Output for Level C or Oil
# ----------------------------------------
# ID: pi:160218
# Nome: VAL_23-KA-9101_APH:VALUE
# Descrição: PH (CBM) 1st Stg ActCompr Poly Head
# ----------------------------------------
# ID: pi:160917
# Nome: VAL_23-TT-96113-03:Z.X.Value
# Descrição: PH 1stStg Gear2 Journ BRG NDE
# ----------------------------------------
# ID: pi:160499
# Nome: VAL_23-LIC-92521:Z.X.Value
# Descrição: PH 1stStgSuctScrubber Level Measured Value
# ----------------------------------------
# ID: pi:160923
# Nome: VAL_23-TT-96116-03:Z.X.Value
# Descrição: PH 1stStg Gear Thrust BRG OUT
# ----------------------------------------
# ID: pi:160791
# Nome: VAL_23-TIC-92604:Z.Y.Value
# Descrição: PH 1stStgDiscCool Gas Out Output
# ----------------------------------------
# ID: pi:160141
# Nome: VAL_23_ZT_92543:Z.X.Value
# Descrição: PH 1stStgComp Valve Pos
# ----------------------------------------
# ID: cdf1_1758435648772_TS
# Nome: cdf1
# Descrição: None
# ----------------------------------------
# ID: pi:160728
# Nome: VAL_23-PT-96160:Z.X1.Value
# Descrição: PH 1st Stg Comp Separation Gas
# ----------------------------------------
# ID: pi:161084
# Nome: VAL_23-ZS-96142A:X.Value
# Descrição: PH 1stStgComp Encl Door A
# ----------------------------------------
# ID: houston.ro.AUTO_MODE_B
# Nome: RO2Auto Mode
# Descrição: Auto Mode Pass 2
# ----------------------------------------
# ID: pi:160927
# Nome: VAL_23-TT-96136-05:Z.X.Value
# Descrição: PH 1stStg Mtr Winding V
# ----------------------------------------
# ID: pi:161019
# Nome: VAL_23-YA-96117-02:Z.X.Value
# Descrição: PH 1stStg Gear1 Journ BRG DE
# ----------------------------------------
# ID: ts_1722139890460_TS
# Nome: ts
# Descrição: None
# ----------------------------------------
# ID: houston.ro.REMOTE_AI[25]
# Nome: PTD90-25
# Descrição: Level Transmitter CIP T-90
# ----------------------------------------
# ID: Test_1725453565898_TS
# Nome: Test
# Descrição: None
# ----------------------------------------
# ID: pi:160557
# Nome: VAL_23-LY-92529_Outputs_foamLevel:VALUE
# Descrição: PH (Profiler) % Scaled Level Output for Level B or Foam
# ----------------------------------------
# ID: pi:160548
# Nome: VAL_23-LY-92529_DensityBands_03oilUL:VALUE
# Descrição: PH (Profiler) Density Band 4 Upper Limit (OIL)
# ----------------------------------------
# ID: pi:160578
# Nome: VAL_23-NY-96144-03:VALUE
# Descrição: PH (CBM) Phase C Negative NQN
# ----------------------------------------
# ID: pi:160527
# Nome: VAL_23-LT-96182:Z.X1.Value
# Descrição: PH 1st Stg Oil Reservoir
# ----------------------------------------
# ID: pi:160727
# Nome: VAL_23-PT-96157:Z.X2.Value
# Descrição: PH 1st Stg Outer Seal NDE
# ----------------------------------------
# ID: Vishal_Testing_1753194432276_TS
# Nome: Vishal Testing
# Descrição: None
# ----------------------------------------
# ID: pi:160779
# Nome: VAL_23-TIC-92504:Control Module:YR
# Descrição: PH 1stStgSuctCool Gas Out Working Setpoint
# ----------------------------------------
# ID: pi:161023
# Nome: VAL_23-YA-96119-02:Z.X.Value
# Descrição: PH 1stStg Gear2 Journ BRG NDE
# ----------------------------------------
# ID: pi:191091
# Nome: VAL_23-TIC-92604B:Z.X.Value
# Descrição: PH 1stStgDiscCool Gas Out Measured Value
# ----------------------------------------
# ID: pi:160786
# Nome: VAL_23-TIC-92604:Control Module:PI
# Descrição: PH 1stStgDiscCool Gas Out Integral time
# ----------------------------------------
# ID: pi:160776
# Nome: VAL_23-TIC-92504:Control Module:PD
# Descrição: PH 1stStgSuctCool Gas Out Derivate time
# ----------------------------------------
# ID: pi:160777
# Nome: VAL_23-TIC-92504:Control Module:PI
# Descrição: PH 1stStgSuctCool Gas Out Integral time
# ----------------------------------------
# ID: pi:160906
# Nome: VAL_23-TT-96101-03:Z.X.Value
# Descrição: PH 1stStg Comp Journ BRG DE
# ----------------------------------------
# ID: pi:160074
# Nome: VAL_23_PIC_92538_04:Z.X.Value
# Descrição: PH 1stStgComp STV Perf Prim PV
# ----------------------------------------
# ID: pi:160225
# Nome: VAL_23-KA-9101_PED:VALUE
# Descrição: PH (CBM) 1st Stage Poly Eff Dev
# ----------------------------------------
# ID: pi:161085
# Nome: VAL_23-ZS-96142B:X.Value
# Descrição: PH 1stStgComp Encl Door B
# ----------------------------------------
# ID: houston.ro.REMOTE_AI[37]
# Nome: AIT86-37
# Descrição: TBD
# ----------------------------------------
# ID: Vishal_Testing_1753193159694_TS
# Nome: Vishal Testing
# Descrição: None
# ----------------------------------------
# ID: Schedule_Multiply_1754999253819_TS
# Nome: Schedule Multiply
# Descrição: None
# ----------------------------------------
# ID: pi:160888
# Nome: VAL_23-TT-92603:X.Value
# Descrição: PH 1stStgDiscCool Gas Out
# ----------------------------------------
# ID: houston.ro.FIT_85_TOTAL_FLOW_KGAL_B
# Nome: FIT_85_TOTAL_FLOW_KGAL_B
# Descrição:
# ----------------------------------------
# ID: pi:160668
# Nome: VAL_23-PIC-96153:Control Module:PI
# Descrição: PH 1stStg Comp Inner Seal Integral time
# ----------------------------------------
# ID: pi:160079
# Nome: VAL_23_PIC_92538_09:Z.X.Value
# Descrição: PH 1stStgComp STV Perf Limit 2 SP
# ----------------------------------------
# ID: pi:160622
# Nome: VAL_23-PDI-96150:X.Value
# Descrição: PH 1st Stg Comp Over Inner Seal
# ----------------------------------------
# ID: pi:160782
# Nome: VAL_23-TIC-92504:Z.Y.Value
# Descrição: PH 1stStgSuctCool Gas Out Output
# ----------------------------------------
# ID: houston.ro.REMOTE_AI[7]
# Nome: PIT40-7
# Descrição: Pressure Transmitter Pass 1 Retentate
# ----------------------------------------
# ID: pi:160612
# Nome: VAL_23-PC-9109-M01:Z.Y.Value
# Descrição: PH 1stStg Comp Lube Oil Pump
# ----------------------------------------
# ID: pi:160129
# Nome: VAL_23_YT_96133_02:Z.X.Value
# Descrição: PH 1stStg MtrJourn BRG NDE
# ----------------------------------------
# ID: SANKETBHAGWATPATIL_1754905978869_TS
# Nome: SANKETBHAGWATPATIL
# Descrição: None
# ----------------------------------------
# ID: pi:160067
# Nome: VAL_23_KA_9101_M01_60A:Z.X.Value
# Descrição: PH 1stStg Comp Mtr Current
# ----------------------------------------
# ID: pi:160262
# Nome: VAL_23-KA-9101-M01_Winding_Temperature_V1:VALUE
# Descrição: PH (SwitchGear)
# ----------------------------------------
# ID: pi:160149
# Nome: VAL_23-ESDV-92551A-PST:VALUE
# Descrição: PH
# ----------------------------------------
# ID: pi:161003
# Nome: VAL_23-XA-96124-A:Z.X.Value
# Descrição: PH 1stStg KEYPH Gear1 Shaft
# ----------------------------------------
# ID: pi:160921
# Nome: VAL_23-TT-96115-03:Z.X.Value
# Descrição: PH 1stStg Gear Thrust BRG IN
# ----------------------------------------
# ID: pi:160581
# Nome: VAL_23-NY-96144-06:VALUE
# Descrição: PH (CBM) Phase C Positive NQN
# ----------------------------------------
# ID: pi:163583
# Nome: VAL_45-PT-92609:X.Value
# Descrição: PH 1stStgDiscCool CM Out
# ----------------------------------------
# ID: pi:160131
# Nome: VAL_23_YT_96134_02:Z.X.Value
# Descrição: PH 1stStg Mtr Journ BRG DE
# ----------------------------------------
# ID: pi:160833
# Nome: VAL_23-TIC-96147:Control Module:YR
# Descrição: PH 1stStg Comp Seal Gas Working Setpoint
# ----------------------------------------
# ID: pi:163374
# Nome: VAL_45-FT-92606:X.Value
# Descrição: PH 1stStgDiscCool CoolMed In
# ----------------------------------------
# ID: pi:163522
# Nome: VAL_45-PDT-92506:X.Value
# Descrição: PH 1stStgSuctCool Shell
# ----------------------------------------
# ID: pi:160258
# Nome: VAL_23-KA-9101-M01_Spring_Charging_Alarm:VALUE
# Descrição: PH (SwitchGear) MV-COMP.M. FEEDER/ Spring Charging Alarm
# ----------------------------------------
# ID: houston.ro.REMOTE_AI[20]
# Nome: TIT201-20
# Descrição: Temperature Transmitter from PWST201
# ----------------------------------------
# ID: pi:160150
# Nome: VAL_23-ESDV-92551B-PST:VALUE
# Descrição: PH
# ----------------------------------------
# ID: pi:160528
# Nome: VAL_23-LT-96182:Z.X2.Value
# Descrição: PH 1st Stg Oil Reservoir
# ----------------------------------------
# ID: pi:160645
# Nome: VAL_23-PDT-96146:X.Value
# Descrição: PH 1st Stg Comp Gas Filter
# ----------------------------------------
# ID: pi:160032
# Nome: VAL_23_FIC_92543_03:Z.X.Value
# Descrição: PH 1stStgComp First AntSrgStat
# ----------------------------------------
# ID: pi:160787
# Nome: VAL_23-TIC-92604:Control Module:PP
# Descrição: PH 1stStgDiscCool Gas Out Gain
# ----------------------------------------
# ID: pi:160243
# Nome: VAL_23-KA-9101-M01_Motor_startup_supervision_MOTstart:VALUE
# Descrição: PH (SwitchGear)
# ----------------------------------------
# ID: pi:161014
# Nome: VAL_23-YA-96105-01:Z.X.Value
# Descrição: PH 1stStg Comp 1 JournBRG DE
# ----------------------------------------
# ID: pi:160883
# Nome: VAL_23-TT-92512:X.Value
# Descrição: PH 1stStgSuctCool Gas In
# ----------------------------------------
# ID: pi:163658
# Nome: VAL_45-TT-92607A:X.Value
# Descrição: PH 1stStgDiscClr CoolMed Out
# ----------------------------------------
# ID: pi:160547
# Nome: VAL_23-LY-92529_DensityBands_03oilLL:VALUE
# Descrição: PH (Profiler) Density Band 4 Lower Limit (OIL)
# ----------------------------------------
# ID: pi:160228
# Nome: VAL_23-KA-9101_SPD:VALUE
# Descrição: PH (CBM) 1st Stage Shft Pwr Dev
# ----------------------------------------
# ID: pi:163657
# Nome: VAL_45-TT-92606:X.Value
# Descrição: PH 1stStgDiscClr CoolMed Sply
# ----------------------------------------
# ID: pi:160644
# Nome: VAL_23-PDT-96143:X.Value
# Descrição: PH 1st Stg Encl Coalesar Filter
# ----------------------------------------
# ID: pi:160519
# Nome: VAL_23-LT-92523:Z.X1.Value
# Descrição: PH 1stStgSuctScrubber
# ----------------------------------------
# ID: houston.ro.REMOTE_AI[34]
# Nome: AIT21-34
# Descrição: Chlorine Indicator from City Water
# ----------------------------------------
# ID: pi:160496
# Nome: VAL_23-LIC-92521:Control Module:PP
# Descrição: PH 1stStgSuctScrubber Level Gain
# ----------------------------------------
# ID: pi:160549
# Nome: VAL_23-LY-92529_DensityBands_04emulsionLL:VALUE
# Descrição: PH (Profiler) Density Band 3 Lower Limit (EMULSION)
# ----------------------------------------
# ID: pi:160884
# Nome: VAL_23-TT-92533:X.Value
# Descrição: PH 1stStgComp Suction
# ----------------------------------------
# ID: houston.smb.MainProgram\RO_ACID_BASE_SUPPLY_ALLOWED
# Nome: RO_ACID_BASE_SUPPLY_ALLOWED
# Descrição:
# ----------------------------------------
# ID: pi:160193
# Nome: VAL_23-FT-96159:X.Value
# Descrição: PH 1stStg Comp Buffer Gas NDE
# ----------------------------------------
# ID: houston.ro.REMOTE_AI[24]
# Nome: FIT50-24
# Descrição: Flow Rate Permeate Pass 1
# ----------------------------------------
# ID: pi:160844
# Nome: VAL_23-TIC-96148:Z.X.Value
# Descrição: PH 1stStg Comp Seal Gas Measured Value
# ----------------------------------------
# ID: pi:160038
# Nome: VAL_23_FIC_92543_09:Z.X.Value
# Descrição: PH 1stStgComp AntSrg Limit 2 SP
# ----------------------------------------
# ID: pi:160553
# Nome: VAL_23-LY-92529_DensityBands_06sandLL:VALUE
# Descrição: PH (Profiler) Density Band 1 Lower Limit (SAND)
# ----------------------------------------
# ID: pi:160934
# Nome: VAL_23-TT-96183:X.Value
# Descrição: PH 1stStg Lube Oil Reservoir
# ----------------------------------------
# ID: pi:160914
# Nome: VAL_23-TT-96112-01:Z.X.Value
# Descrição: PH 1stStg Comp 1 Journ BRG NDE
# ----------------------------------------
# ID: houston.ro.REMOTE_AI[72]
# Nome: DPT10-72
# Descrição: Differential Pressure Filter of City Water Feed
# ----------------------------------------
# ID: pi:160217
# Nome: VAL_23-KA-9101_APE:VALUE
# Descrição: PH (CBM) 1st Stage ActCompr Poly Eff
# ----------------------------------------
# ID: pi:160887
# Nome: VAL_23-TT-92602:X.Value
# Descrição: PH 1stStgDiscCool Gas In
# ----------------------------------------
# ID: pi:160648
# Nome: VAL_23-PDT-96162:X.Value
# Descrição: PH 1st Stg Comp Booster
# ----------------------------------------
# ID: pi:160911
# Nome: VAL_23-TT-96104-03:Z.X.Value
# Descrição: PH 1stStg Comp Thrust BRG OUT
# ----------------------------------------
# ID: pi:160789
# Nome: VAL_23-TIC-92604:MODE
# Descrição: PH 1stStgDiscCool Gas Out Mode
# ----------------------------------------
# ID: houston.ro.REMOTE_AI[74]
# Nome: REC25-74
# Descrição: Recovery Pass 1
# ----------------------------------------
# ID: pi:160254
# Nome: VAL_23-KA-9101-M01_Reactive_power_kVAr:VALUE
# Descrição: PH (SwitchGear)
# ----------------------------------------
# ID: pi:160837
# Nome: VAL_23-TIC-96148:Control Module:BA
# Descrição: PH 1stStg Comp Seal Gas Auto
# ----------------------------------------
# ID: pi:160236
# Nome: VAL_23-KA-9101-M01_Current_L2:VALUE
# Descrição: PH (SwitchGear) MV-COMP.M. FEEDER/ Current (L2)
# ----------------------------------------
# ID: houston.ro.REMOTE_AI[32]
# Nome: AIT50-32
# Descrição: Conductivity Pass 1 Permeate
# ----------------------------------------
# ID: pi:160780
# Nome: VAL_23-TIC-92504:MODE
# Descrição: PH 1stStgSuctCool Gas Out Mode
# ----------------------------------------
# ID: pi:160580
# Nome: VAL_23-NY-96144-05:VALUE
# Descrição: PH (CBM) Phase B Positive NQN
# ----------------------------------------
# ID: pi:160497
# Nome: VAL_23-LIC-92521:Control Module:YR
# Descrição: PH 1stStgSuctScrubber Level Working Setpoint
# ----------------------------------------
# ID: pi:160033
# Nome: VAL_23_FIC_92543_04:Z.X.Value
# Descrição: PH 1stStgComp First AntSrg Dev
# ----------------------------------------
# ID: pi:160237
# Nome: VAL_23-KA-9101-M01_Current_L3:VALUE
# Descrição: PH (SwitchGear) MV-COMP.M. FEEDER/ Current (L3)
# ----------------------------------------
# ID: houston.ro.REMOTE_AI[16]
# Nome: LT202-16
# Descrição: Tank Level PWST202
# ----------------------------------------
# ID: pi:160621
# Nome: VAL_23-PDI-96149:X.Value
# Descrição: PH 1st Stg Comp Over Inner Seal
# ----------------------------------------
# ID: pi:160701
# Nome: VAL_23-PT-92535:X.Value
# Descrição: PH 1stStgComp Suction
# ----------------------------------------
# ID: pi:160190
# Nome: VAL_23-FT-96151:X.Value
# Descrição: PH 1stStg Comp Inner Seal DE
# ----------------------------------------
# ID: pi:160767
# Nome: VAL_23-TE-96137-03:X.Value
# Descrição: PH 1stStg Mtr Hot Air
# ----------------------------------------
# ID: pi:160550
# Nome: VAL_23-LY-92529_DensityBands_04emulsionUL:VALUE
# Descrição: PH (Profiler) Density Band 3 Upper Limit (EMULSION)
# ----------------------------------------
# ID: pi:160253
# Nome: VAL_23-KA-9101-M01_OC_low_stage_residual_NEF1low:VALUE
# Descrição: PH (SwitchGear) MV-COMP.M. FEEDER/ 51-1 Non Directional Earth Fault (trip Io>)
# ----------------------------------------
# ID: pi:160242
# Nome: VAL_23-KA-9101-M01_MCB_failure-Motor_Tripping:VALUE
# Descrição: PH (SwitchGear) MV-COMP.M. FEEDER/ MCB failure - Motor, Tripping
# ----------------------------------------
# ID: pi:160558
# Nome: VAL_23-LY-92529_Outputs_gasLevel:VALUE
# Descrição: PH (Profiler) % Scaled Level Output for Level A or Gas
# ----------------------------------------
# ID: pi:161015
# Nome: VAL_23-YA-96105-02:Z.X.Value
# Descrição: PH 1stStg Comp 1 JournBRG DE
# ----------------------------------------
# ID: pi:163656
# Nome: VAL_45-TT-92508:X.Value
# Descrição: PH 1stStgSuctClr CoolMed Out
# ----------------------------------------
# ID: pi:160154
# Nome: VAL_23-FE-9106-39:X.Value
# Descrição: PH 1st Stg Lube Oil Heater Running
# ----------------------------------------
# ID: pi:160035
# Nome: VAL_23_FIC_92543_06:Z.X.Value
# Descrição: PH 1stStgComp AntSrg Limit 1 PV
# ----------------------------------------
# ID: pi:160263
# Nome: VAL_23-KA-9101-M01_Winding_Temperature_W1:VALUE
# Descrição: PH (SwitchGear)
# ----------------------------------------
# ID: pi:161066
# Nome: VAL_23-ZA-96107-01:Z.X.Value
# Descrição: PH 1stStg Comp Schaft Axial
# ----------------------------------------
# ID: pi:160828
# Nome: VAL_23-TIC-96147:Control Module:BA
# Descrição: PH 1stStg Comp Seal Gas Auto
# ----------------------------------------
# ID: pi:160183
# Nome: VAL_23-FT-92521:X.Value
# Descrição: PH 1stStgSuctScrubber Liq Out
# ----------------------------------------
# ID: pi:160498
# Nome: VAL_23-LIC-92521:MODE
# Descrição: PH 1stStgSuctScrubber Level Mode
# ----------------------------------------
# ID: pi:160495
# Nome: VAL_23-LIC-92521:Control Module:PI
# Descrição: PH 1stStgSuctScrubber Level Integral time
# ----------------------------------------
# ID: pi:160790
# Nome: VAL_23-TIC-92604:Z.X.Value
# Descrição: PH 1stStgDiscCool Gas Out Measured Value
# ----------------------------------------
# ID: Valhala_Valve_Distance_Calculations_1742581397195_TS
# Nome: Valhala Valve Distance Calculations
# Descrição: None
# ----------------------------------------
# ID: pi:160932
# Nome: VAL_23-TT-96181:Z.X2.Value
# Descrição: PH 1st Stg Oil System Header
# ----------------------------------------
# ID: pi:160271
# Nome: VAL_23-KA-9101-M01-EL:XS.CoreStatus.Xservice.Signal.Value
# Descrição: PH Truck in Service
# ----------------------------------------
# ID: pi:160266
# Nome: VAL_23-KA-9101-M01-39B:X.Value
# Descrição: PH 1st Stage Compressor Motor Running
# ----------------------------------------
# ID: pi:160774
# Nome: VAL_23-TIC-92504:Control Module:BA
# Descrição: PH 1stStgSuctCool Gas Out Auto
# ----------------------------------------
# ID: pi:160221
# Nome: VAL_23-KA-9101_EPE:VALUE
# Descrição: PH (CBM) 1st Stage ExpCompr Poly Eff
# ----------------------------------------
# ID: pi:160078
# Nome: VAL_23_PIC_92538_08:Z.X.Value
# Descrição: PH 1stStgComp STV Perf Limit 2 PV
# ----------------------------------------
# ID: pi:160931
# Nome: VAL_23-TT-96181:Z.X1.Value
# Descrição: PH 1st Stg Oil System Header
# ----------------------------------------
# ID: pi:161071
# Nome: VAL_23-ZA-96121-03:Z.X.Value
# Descrição: PH 1stStg Gear Schaft Axial
# ----------------------------------------
# ID: pi:160830
# Nome: VAL_23-TIC-96147:Control Module:PD
# Descrição: PH 1stStg Comp Seal Gas Derivate time
# ----------------------------------------
# ID: pi:160993
# Nome: VAL_23-VA-9110-M01:Z.Y.Value
# Descrição: PH 1stStgComp Oil Mist Fan
# ----------------------------------------
# ID: pi:160579
# Nome: VAL_23-NY-96144-04:VALUE
# Descrição: PH (CBM) Phase A Positive NQN
# ----------------------------------------
# ID: pi:160036
# Nome: VAL_23_FIC_92543_07:Z.X.Value
# Descrição: PH 1stStgComp AntSrg Limit 1 SP
# ----------------------------------------
# ID: pi:160704
# Nome: VAL_23-PT-92540:X.Value
# Descrição: PH 1st Stg Comp Suction
# ----------------------------------------
# ID: pi:160633
# Nome: VAL_23-PDT-92602:X.Value
# Descrição: PH 1st Stg Disch Gas Coolers
# ----------------------------------------
# ID: pi:161068
# Nome: VAL_23-ZA-96107-03:Z.X.Value
# Descrição: PH 1stStg Comp Schaft Axial
# ----------------------------------------
# ID: pi:161016
# Nome: VAL_23-YA-96106-01:Z.X.Value
# Descrição: PH 1stStg Comp1 Journ BRG NDE
# ----------------------------------------
# ID: houston.smb.MainProgram\RO_BASE_PUMP_RUNNING
# Nome: RO_BASE_PUMP_RUNNING
# Descrição:
# ----------------------------------------
# ID: test_1720820914111_TS
# Nome: test
# Descrição: test
# ----------------------------------------
# ID: pi:160241
# Nome: VAL_23-KA-9101-M01_Internal_Relay_Fault:VALUE
# Descrição: PH (SwitchGear) MV-COMP.M. FEEDER/  IRF error REM543 (internal relay fault)
# ----------------------------------------
# ID: pi:160268
# Nome: VAL_23-KA-9101-M01-EL:XS.Alarms.Alarm1.Signal.Value
# Descrição: PH Common Alarm
# ----------------------------------------
# ID: pi:160208
# Nome: VAL_23-GK-9107B-M01-EL:XS.MeasuredValues.CurrentL2.Value.Value
# Descrição: PH 1stStg Comp Encl Cooling UnitB
# ----------------------------------------
# ID: pi:160544
# Nome: VAL_23-LY-92529_DensityBands_01gasUL:VALUE
# Descrição: PH (Profiler) Density Band 6 Upper Limit (GAS)
# ----------------------------------------
# ID: pi:160698
# Nome: VAL_23-PT-92521:X.Value
# Descrição: PH 1stStgSuctScrubber
# ----------------------------------------
# ID: pi:160582
# Nome: VAL_23-NY-96144-07:VALUE
# Descrição: PH (CBM) Phase A Negative Qmax
# ----------------------------------------
# ID: pi:160264
# Nome: VAL_23-KA-9101-M01-36A:X.Value
# Descrição: PH Common Trip
# ----------------------------------------
# ID: houston.smb.MainProgram\RO_TK165_LEVEL
# Nome: RO_TK165_LEVEL
# Descrição: Reverse osmosis tk-165 level
# ----------------------------------------
# ID: pi:160172
# Nome: VAL_23-FE-9122-H01-F-EL:XS.MeasuredValues.CurrentL2.Value.Value
# Descrição: PH 1stStg Seal Gas Heater
# ----------------------------------------
# ID: pi:160778
# Nome: VAL_23-TIC-92504:Control Module:PP
# Descrição: PH 1stStgSuctCool Gas Out Gain
# ----------------------------------------
# ID: pi:160834
# Nome: VAL_23-TIC-96147:MODE
# Descrição: PH 1stStg Comp Seal Gas Mode
# ----------------------------------------
# ID: pi:160723
# Nome: VAL_23-PT-96150:Z.X2.Value
# Descrição: PH 1st Stg Inner Seal NDE
# ----------------------------------------
# ID: pi:163582
# Nome: VAL_45-PT-92608:X.Value
# Descrição: PH 1stStgDiscCool CM Out
# ----------------------------------------
# ID: pi:160646
# Nome: VAL_23-PDT-96155:X.Value
# Descrição: PH 1st Stg Comp SEP. Gas Filter
# ----------------------------------------
# ID: pi:160631
# Nome: VAL_23-PDT-92534:X.Value
# Descrição: PH 1stStgComp Suction
# ----------------------------------------
# ID: pi:160583
# Nome: VAL_23-NY-96144-08:VALUE
# Descrição: PH (CBM) Phase B Negative Qmax
# ----------------------------------------
# ID: pi:160573
# Nome: VAL_23-LY-92529_SILch0_SC0_TYPSP:VALUE
# Descrição: PH (Profiler) Shutdown Channel 0 - Tube y Position Setpoint
# ----------------------------------------
# ID: Vyshnav_1730871553309_TS
# Nome: Vyshnav
# Descrição: None
# ----------------------------------------
# ID: pi:160669
# Nome: VAL_23-PIC-96153:Control Module:PP
# Descrição: PH 1stStg Comp Inner Seal Gain
# ----------------------------------------
# ID: pi:160561
# Nome: VAL_23-LY-92529_Outputs_waterLevel:VALUE
# Descrição: PH (Profiler) % Scaled Level Output for Level E or Water
# ----------------------------------------
# ID: Vishal_Testing_1753193144380_TS
# Nome: Vishal Testing
# Descrição: None
# ----------------------------------------
# ID: pi:160781
# Nome: VAL_23-TIC-92504:Z.X.Value
# Descrição: PH 1stStgSuctCool Gas Out Measured Value
# ----------------------------------------
# ID: pi:160831
# Nome: VAL_23-TIC-96147:Control Module:PI
# Descrição: PH 1stStg Comp Seal Gas Integral time
# ----------------------------------------
# ID: houston.ro.ALWAYS_ON
# Nome: Ro.HeartBeat
# Descrição:
# ----------------------------------------
# ID: pi:160224
# Nome: VAL_23-KA-9101_ESP:VALUE
# Descrição: PH (CBM) 1st Stage ExpShaft Power
# ----------------------------------------
# ID: pi:163373
# Nome: VAL_45-FT-92506:X.Value
# Descrição: PH 1stStgSuctCool CoolMed In
# ----------------------------------------
# ID: pi:160250
# Nome: VAL_23-KA-9101-M01_OC_instantaneous_residual_NEF1inst:VALUE
# Descrição: PH (SwitchGear) MV-COMP.M. FEEDER/ 51-3  Non Directional Earth Fault (trip Io>>>)
# ----------------------------------------
# ID: pi:160207
# Nome: VAL_23-GK-9107B-M01:Z.Y.Value
# Descrição: PH 1stStg Comp Encl Cooling UnitB
# ----------------------------------------
# ID: pi:160232
# Nome: VAL_23-KA-9101-M01_CB_Mechanical_Fault:VALUE
# Descrição: PH (SwitchGear) MV-COMP.M. FEEDER/ CB Mechanical Fault
# ----------------------------------------
# ID: pi:160037
# Nome: VAL_23_FIC_92543_08:Z.X.Value
# Descrição: PH 1stStgComp AntSrg Limit 2 PV
# ----------------------------------------
# ID: pi:160249
# Nome: VAL_23-KA-9101-M01_OC_instantaneous_NOC3inst:VALUE
# Descrição: PH (SwitchGear) MV-COMP.M. FEEDER/ 50/51B-protection (trip 3I>>>)
# ----------------------------------------
# ID: pi:161002
# Nome: VAL_23-XA-96108-A:Z.X.Value
# Descrição: PH 1stStg KEYPH Comp Shaft
# ----------------------------------------
# ID: pi:160233
# Nome: VAL_23-KA-9101-M01_CB_multiple_plug_out:VALUE
# Descrição: PH (SwitchGear) MV-COMP.M. FEEDER/ CB multiple plug out
# ----------------------------------------
# ID: Valhala_Valve_Distance_Calculations_1742581401794_TS
# Nome: Valhala Valve Distance Calculations
# Descrição: None
# ----------------------------------------
# ID: pi:160039
# Nome: VAL_23_FIC_92543_11:Z.X.Value
# Descrição: PH Surge Counter
# ----------------------------------------
# ID: pi:160733
# Nome: VAL_23-PT-96186-03:X.Value
# Descrição: PH 1st Stg Lube Lube Oil Header
# ----------------------------------------
# ID: pi:160205
# Nome: VAL_23-GK-9107A-M01:Z.Y.Value
# Descrição: PH 1stStg Comp Encl Cooling UnitA
# ----------------------------------------
# ID: pi:160246
# Nome: VAL_23-KA-9101-M01_Number_of_CB_Operations:VALUE
# Descrição: PH (SwitchGear) MV-COMP.M. FEEDER/ Number of CB Operations
# ----------------------------------------
# ID: pi:160240
# Nome: VAL_23-KA-9101-M01_Interlock_active:VALUE
# Descrição: PH (SwitchGear)
# ----------------------------------------
# ID: houston.smb.MainProgram\RO_ACID_PUMP_AVAILABLE_TIME
# Nome: RO_ACID_PUMP_AVAILABLE_TIME
# Descrição:
# ----------------------------------------
# ID: pi:160230
# Nome: VAL_23-KA-9101-M01:Z.Y.Value
# Descrição: PH 1stStg Comp Driving Mtr
# ----------------------------------------
# ID: houston.ro.REMOTE_AI[26]
# Nome: FIT75-26
# Descrição: Flow Rate Retentate Pass 2
# ----------------------------------------
# ID: pi:160564
# Nome: VAL_23-LY-92529_Setpoints_SP_gasHi:VALUE
# Descrição: PH (Profiler) Gas deadband high setpoint
# ----------------------------------------
# ID: pi:160562
# Nome: VAL_23-LY-92529_Setpoints_SP_emulsionHi:VALUE
# Descrição: PH (Profiler) Emulsion deadband high setpoint
# ----------------------------------------
# ID: pi:160245
# Nome: VAL_23-KA-9101-M01_Motor_Winding_Temp_Warning:VALUE
# Descrição: PH (SwitchGear) MV-COMP.M. FEEDER/ motor winding warning
# ----------------------------------------
# ID: pi:160784
# Nome: VAL_23-TIC-92604:Control Module:BX
# Descrição: PH 1stStgDiscCool Gas Out External
# ----------------------------------------
# ID: pi:160071
# Nome: VAL_23_PIC_92538_01:Z.X.Value
# Descrição: PH 1stStgComp STV Perf OP
# ----------------------------------------
# ID: houston.smb.MainProgram\RO_BASE_PUMP_READY
# Nome: RO_BASE_PUMP_READY
# Descrição:
# ----------------------------------------
# ID: pi:160788
# Nome: VAL_23-TIC-92604:Control Module:YR
# Descrição: PH 1stStgDiscCool Gas Out Working Setpoint
# ----------------------------------------
# ID: pi:160251
# Nome: VAL_23-KA-9101-M01_OC_low stage_negative_seq_NPSlow:VALUE
# Descrição: PH (SwitchGear)
# ----------------------------------------
# ID: pi:160575
# Nome: VAL_23-LY-92529_SILch0_SC0_WATCHDOG:VALUE
# Descrição: PH (Profiler) Shutdown Channel 0 - Watchdog
# ----------------------------------------
# ID: pi:160184
# Nome: VAL_23-FT-92537-01:X.Value
# Descrição: PH 1stStgComp Discharge
# ----------------------------------------
# ID: pi:161022
# Nome: VAL_23-YA-96119-01:Z.X.Value
# Descrição: PH 1stStg Gear2 Journ BRG NDE
# ----------------------------------------
# ID: houston.ro.FIT_75_TOTAL_FLOW_KGAL_B
# Nome: FIT_75_TOTAL_FLOW_KGAL_B
# Descrição:
# ----------------------------------------
# ID: pi:161020
# Nome: VAL_23-YA-96118-01:Z.X.Value
# Descrição: PH 1stStg Gear1 Journ BRG NDE
# ----------------------------------------
# ID: pi:160255
# Nome: VAL_23-KA-9101-M01_REM543_in_test_mode:VALUE
# Descrição: PH (SwitchGear) MV-COMP.M. FEEDER/ REM543 in test mode
# ----------------------------------------
# ID: pi:160726
# Nome: VAL_23-PT-96157:Z.X1.Value
# Descrição: PH 1st Stg Outer Seal NDE
# ----------------------------------------
# ID: pi:160585
# Nome: VAL_23-NY-96144-10:VALUE
# Descrição: PH (CBM) Phase A Positive Qmax
# ----------------------------------------
# ID: pi:160907
# Nome: VAL_23-TT-96102-03:Z.X.Value
# Descrição: PH 1stStg Comp Journ BRG NDE
# ----------------------------------------
# ID: pi:160267
# Nome: VAL_23-KA-9101-M01-62B:X.Value
# Descrição: PH HV SWGR 1stStg Comp Mtr
# ----------------------------------------
# ID: pi:160206
# Nome: VAL_23-GK-9107A-M01-EL:XS.MeasuredValues.CurrentL2.Value.Value
# Descrição: PH 1stStg Comp Encl Cooling UnitA
# ----------------------------------------
# ID: pi:160219
# Nome: VAL_23-KA-9101_APR:VALUE
# Descrição: PH (CBM) 1st Stage ActPress Ratio
# ----------------------------------------
# ID: pi:160700
# Nome: VAL_23-PT-92532:X.Value
# Descrição: PH 1stStgComp Suction
# ----------------------------------------
# ID: pi:161018
# Nome: VAL_23-YA-96117-01:Z.X.Value
# Descrição: PH 1stStg Gear1 Journ BRG DE
# ----------------------------------------
# ID: pi:160104
# Nome: VAL_23_PT_92531:Z.X.Value
# Descrição: PH 1stStgComp Suction
# ----------------------------------------
# ID: pi:160522
# Nome: VAL_23-LT-92529-03:X.Value
# Descrição: PH 1stStgScrub I-face TopFoam
# ----------------------------------------
# ID: pi:160720
# Nome: VAL_23-PT-96149:Z.X1.Value
# Descrição: PH 1st Stage Comp Inner Seal DE
# ----------------------------------------
# ID: pi:160034
# Nome: VAL_23_FIC_92543_05:Z.X.Value
# Descrição: PH 1stStgComp First AntSrg CountTot
# ----------------------------------------
# ID: SANKETBHAGWATPATIL_1754905984569_TS
# Nome: SANKETBHAGWATPATIL
# Descrição: None
# ----------------------------------------
# ID: pi:160572
# Nome: VAL_23-LY-92529_SILch0_SC0_TY1SP:VALUE
# Descrição: PH (Profiler) Shutdown Channel 0 - Tube y1 Setpoint
# ----------------------------------------
# ID: test1_1720821188402_TS
# Nome: test1
# Descrição: test
# ----------------------------------------
# ID: pi:191092
# Nome: VAL_23-TT-92604A:X.Value
# Descrição: PH 1stStgDiscCool Gas Out Output
# ----------------------------------------
# ID: pi:160649
# Nome: VAL_23-PDT-96167:X.Value
# Descrição: PH 1stStg Comp Balance Piston
# ----------------------------------------
# ID: pi:160235
# Nome: VAL_23-KA-9101-M01_Current_L1:VALUE
# Descrição: PH (SwitchGear) MV-COMP.M. FEEDER/ Current (L1)
# ----------------------------------------
# ID: pi:160910
# Nome: VAL_23-TT-96104-01:Z.X.Value
# Descrição: PH 1stStg Comp Thrust BRG OUT
# ----------------------------------------
# ID: pi:160650
# Nome: VAL_23-PDT-96180:X.Value
# Descrição: PH 1st Stg Lube Oil Filter
# ----------------------------------------
# ID: pi:160915
# Nome: VAL_23-TT-96112-03:Z.X.Value
# Descrição: PH 1stStg Comp 1 Journ BRG NDE
# ----------------------------------------
# ID: pi:160494
# Nome: VAL_23-LIC-92521:Control Module:PD
# Descrição: PH 1stStgSuctScrubber Level Derivate time
# ----------------------------------------
# ID: pi:160724
# Nome: VAL_23-PT-96156:Z.X1.Value
# Descrição: PH 1st Stg Outer Seal DE
# ----------------------------------------
# ID: houston.ro.FIT_50_TOTAL_FLOW_GAL_A
# Nome: FIT_50_TOTAL_FLOW_GAL_A
# Descrição:
# ----------------------------------------
# ID: pi:160234
# Nome: VAL_23-KA-9101-M01_CB_travel_alarm:VALUE
# Descrição: PH (SwitchGear)
# ----------------------------------------
# ID: pi:160110
# Nome: VAL_23_TT_92532:Z.X.Value
# Descrição: PH 1stStgComp Suction Temp
# ----------------------------------------
# ID: pi:160908
# Nome: VAL_23-TT-96103-01:Z.X.Value
# Descrição: PH 1stStg Comp Thrust BRG IN
# ----------------------------------------
# ID: pi:161067
# Nome: VAL_23-ZA-96107-02:Z.X.Value
# Descrição: PH 1stStg Comp Schaft Axial
# ----------------------------------------
# ID: pi:160994
# Nome: VAL_23-VA-9110-M01-39:X.Value
# Descrição: PH 1st Stg Oil Seperator Running
# ----------------------------------------
# ID: pi:160839
# Nome: VAL_23-TIC-96148:Control Module:PD
# Descrição: PH 1stStg Comp Seal Gas Derivate time
# ----------------------------------------
# ID: pi:160630
# Nome: VAL_23-PDT-92530:X.Value
# Descrição: PH 1stStgComp Suct Str
# ----------------------------------------
# ID: pi:160231
# Nome: VAL_23-KA-9101-M01_Active_power_kW:VALUE
# Descrição: PH (SwitchGear)
# ----------------------------------------
# ID: pi:160673
# Nome: VAL_23-PIC-96153:Z.Y.Value
# Descrição: PH 1stStg Comp Inner Seal Output
# ----------------------------------------
# ID: pi:160838
# Nome: VAL_23-TIC-96148:Control Module:BX
# Descrição: PH 1stStg Comp Seal Gas External
# ----------------------------------------
# ID: pi:160721
# Nome: VAL_23-PT-96149:Z.X2.Value
# Descrição: PH 1st Stage Comp Inner Seal DE
# ----------------------------------------
# ID: houston.ro.REMOTE_AI[33]
# Nome: AIT85-33
# Descrição: Conductivity Pass 2 Permeate
# ----------------------------------------
# ID: pi:160584
# Nome: VAL_23-NY-96144-09:VALUE
# Descrição: PH (CBM) Phase C Negative Qmax
# ----------------------------------------
# ID: test_1720820935241_TS
# Nome: test
# Descrição: test
# ----------------------------------------
# ID: pi:160842
# Nome: VAL_23-TIC-96148:Control Module:YR
# Descrição: PH 1stStg Comp Seal Gas Working Setpoint
# ----------------------------------------
# ID: pi:163581
# Nome: VAL_45-PT-92508:X.Value
# Descrição: PH 1stStgSuctCool CoolMed Out
# ----------------------------------------
# ID: pi:161070
# Nome: VAL_23-ZA-96121-02:Z.X.Value
# Descrição: PH 1stStg Gear Schaft Axial
# ----------------------------------------
# ID: houston.ro.REMOTE_AI[3]
# Nome: PIT19-3
# Descrição: Pressure Transmitter City Water Feed
# ----------------------------------------
# ID: pi:160128
# Nome: VAL_23_YT_96133_01:Z.X.Value
# Descrição: PH 1stStg MtrJourn BRG NDE
# ----------------------------------------
# ID: pi:160916
# Nome: VAL_23-TT-96113-01:Z.X.Value
# Descrição: PH 1stStg Gear2 Journ BRG NDE
# ----------------------------------------
# ID: pi:160155
# Nome: VAL_23-FE-9106-H01:Z.Y.Value
# Descrição: PH 1stStgComp OIL HEATER
# ----------------------------------------
# ID: pi:160909
# Nome: VAL_23-TT-96103-03:Z.X.Value
# Descrição: PH 1stStg Comp Thrust BRG IN
# ----------------------------------------
# ID: pi:160239
# Nome: VAL_23-KA-9101-M01_Earth_current:VALUE
# Descrição: PH (SwitchGear) MV-COMP.M. FEEDER/ Earth current
# ----------------------------------------
# ID: pi:160076
# Nome: VAL_23_PIC_92538_06:Z.X.Value
# Descrição: PH 1stStgComp STV Perf Limit 1 PV
# ----------------------------------------
# ID: pi:163365
# Nome: VAL_45-FT-92139B:X.Value
# Descrição: PH 1stStg LO Cooler CW
# ----------------------------------------
# ID: pi:160843
# Nome: VAL_23-TIC-96148:MODE
# Descrição: PH 1stStg Comp Seal Gas Mode
# ----------------------------------------
# ID: pi:160273
# Nome: VAL_23-KA-9101-M01-EL:XS.MeasuredValues.CurrentL2.Value.Value
# Descrição: PH 1st Stage Comp
# ----------------------------------------
# ID: pi:160571
# Nome: VAL_23-LY-92529_SILch0_SC0_TY1PSP:VALUE
# Descrição: PH (Profiler) Shutdown Channel 0 - Tube y1 Position Setpoint
# ----------------------------------------
# ID: pi:160699
# Nome: VAL_23-PT-92523:X.Value
# Descrição: PH 1stStgSuctScrubber
# ----------------------------------------
# ID: pi:160265
# Nome: VAL_23-KA-9101-M01-39A:X.Value
# Descrição: PH 1st Stg Mtr RUNNING
# ----------------------------------------
# ID: pi:161026
# Nome: VAL_23-YA-96122:Z.X.Value
# Descrição: PH 1stStg Gear1 Velocimeter
# ----------------------------------------
# ID: houston.ro.REMOTE_AI[4]
# Nome: PIT20-4
# Descrição: Pressure Transmitter City Water Feed
# ----------------------------------------
# ID: pi:160551
# Nome: VAL_23-LY-92529_DensityBands_05waterLL:VALUE
# Descrição: PH (Profiler) Density Band 2 Lower Limit (WATER)
# ----------------------------------------
# ID: houston.ro.REMOTE_AI[75]
# Nome: REC75-75
# Descrição: Recovery Pass 2
# ----------------------------------------
# ID: pi:160672
# Nome: VAL_23-PIC-96153:Z.X.Value
# Descrição: PH 1stStg Comp Inner Seal Measured Value
# ----------------------------------------
# ID: pi:160222
# Nome: VAL_23-KA-9101_EPH:VALUE
# Descrição: PH (CBM) 1st Stg ExpCompr Poly Head
# ----------------------------------------
# ID: pi:160766
# Nome: VAL_23-TE-96137-02:X.Value
# Descrição: PH 1stStg Mtr Cold Air
# ----------------------------------------
# ID: pi:160256
# Nome: VAL_23-KA-9101-M01_Running_hours:VALUE
# Descrição: PH (SwitchGear)
# ----------------------------------------

# %%
# Procura ativo que tem compressor como descrição
search_compressor = client.assets.search(description="compressor", limit=None)
print(search_compressor)
# Out:
# [
#     {
#         "external_id": "WMT:23-KA-9101",
#         "name": "23-KA-9101",
#         "parent_id": 4856008121737468,
#         "parent_external_id": "WMT:23-XX-9106",
#         "description": "VRD - 1ST STAGE COMPRESSOR",
#         "metadata": {
#             "ELC_STATUS_ID": "1211",
#             "RES_ID": "583453",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1600",
#             "WMT_CATEGORY_ID": "1120",
#             "WMT_CONTRACTOR_ID": "1686",
#             "WMT_FUNC_CODE_ID": "6284",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_PO_ID": "8309",
#             "WMT_SYSTEM_ID": "4440",
#             "WMT_TAG_COMMENT": "Compressor casing is designed for 170 MMSCFD.  Export capacity is limited by installed impeller set and motor (available for upgrade to full capacity)., Capacity: 143 MMSCFD Export Gas / Base Case (4): 200,561 SM3/hr, Size: RB71-5, Operating conditions: I",
#             "WMT_TAG_CREATED_DATE": "2009-06-26 15:36:37",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "VRD - 1ST STAGE COMPRESSOR",
#             "WMT_TAG_GLOBALID": "1000000000707341",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "346064",
#             "WMT_TAG_ID_ANCESTOR": "346906",
#             "WMT_TAG_ISACTIVE": "1",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "23-KA-9101",
#             "WMT_TAG_STATUSCHGDATE": "2017-05-05 09:41:21",
#             "WMT_TAG_UPDATED_BY": "8137",
#             "WMT_TAG_UPDATED_DATE": "2017-05-05 09:41:21"
#         },
#         "id": 3047932288982463,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:39:32.771+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:23-KA-9101-J04",
#         "name": "23-KA-9101-J04",
#         "parent_id": 3047932288982463,
#         "parent_external_id": "WMT:23-KA-9101",
#         "description": "CENTRIFUGAL COMPRESSOR JUNCTION BOX",
#         "metadata": {
#             "ELC_STATUS_ID": "1211",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1600",
#             "WMT_CATEGORY_ID": "1120",
#             "WMT_FUNC_CODE_ID": "6284",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_SYSTEM_ID": "4440",
#             "WMT_TAG_CREATED_DATE": "2016-08-08 12:58:22",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "CENTRIFUGAL COMPRESSOR JUNCTION BOX",
#             "WMT_TAG_GLOBALID": "1000000000964385",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "780201",
#             "WMT_TAG_ID_ANCESTOR": "346064",
#             "WMT_TAG_ISACTIVE": "1",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "23-KA-9101-J04",
#             "WMT_TAG_STATUSCHGDATE": "2016-10-14 07:32:11",
#             "WMT_TAG_UPDATED_BY": "8137",
#             "WMT_TAG_UPDATED_DATE": "2016-10-14 07:32:11"
#         },
#         "id": 3499848301350792,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:39:38.053+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:23-KA-9101-M01",
#         "name": "23-KA-9101-M01",
#         "parent_id": 3047932288982463,
#         "parent_external_id": "WMT:23-KA-9101",
#         "description": "VRD - 1ST STAGE COMPRESSOR",
#         "metadata": {
#             "ELC_STATUS_ID": "1211",
#             "RES_ID": "490712",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1600",
#             "WMT_CATEGORY_ID": "1114",
#             "WMT_CONTRACTOR_ID": "1686",
#             "WMT_FUNC_CODE_ID": "4280",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_PO_ID": "8718",
#             "WMT_SAFETYCRITICALELEMENT_ID": "1060",
#             "WMT_SYSTEM_ID": "4440",
#             "WMT_TAG_CREATED_DATE": "2009-06-26 15:36:37",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "VRD - 1ST STAGE COMPRESSOR",
#             "WMT_TAG_GLOBALID": "1000000000707343",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "346066",
#             "WMT_TAG_ID_ANCESTOR": "346064",
#             "WMT_TAG_ISACTIVE": "1",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "23-KA-9101-M01",
#             "WMT_TAG_UPDATED_BY": "1001",
#             "WMT_TAG_UPDATED_DATE": "2015-10-09 11:56:23"
#         },
#         "id": 6191827428964450,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:40:05.087+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:23-1ST STAGE COMPRESSOR-PH",
#         "name": "23-1ST STAGE COMPRESSOR-PH",
#         "parent_id": 4518112062673878,
#         "parent_external_id": "WMT:23-1ST STAGE COMPRESSION-PH",
#         "description": "1ST STAGE COMPRESSOR ON PH",
#         "metadata": {
#             "ELC_STATUS_ID": "1211",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1444",
#             "WMT_CATEGORY_ID": "1157",
#             "WMT_FUNC_CODE_ID": "6593",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_SYSTEM_ID": "4440",
#             "WMT_TAG_CREATED_DATE": "2012-12-13 10:17:23",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "1ST STAGE COMPRESSOR ON PH",
#             "WMT_TAG_GLOBALID": "1000000000249708",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "681824",
#             "WMT_TAG_ID_ANCESTOR": "681792",
#             "WMT_TAG_ISACTIVE": "1",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "23-1ST STAGE COMPRESSOR-PH",
#             "WMT_TAG_STATUSCHGDATE": "2013-05-08 12:52:29",
#             "WMT_TAG_UPDATED_BY": "8137",
#             "WMT_TAG_UPDATED_DATE": "2013-12-11 14:35:29"
#         },
#         "id": 7372310232665628,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:40:17.493+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:23-2ND STAGE COMPRESSOR-PH",
#         "name": "23-2ND STAGE COMPRESSOR-PH",
#         "parent_id": 5786472304680477,
#         "parent_external_id": "WMT:23-2ND STAGE COMPRESSION-PH",
#         "description": "2ND STAGE COMPRESSOR ON PH",
#         "metadata": {
#             "ELC_STATUS_ID": "1211",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1444",
#             "WMT_CATEGORY_ID": "1157",
#             "WMT_FUNC_CODE_ID": "6593",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_SYSTEM_ID": "4440",
#             "WMT_TAG_CREATED_DATE": "2012-12-13 10:17:23",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "2ND STAGE COMPRESSOR ON PH",
#             "WMT_TAG_GLOBALID": "1000000000249709",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "681825",
#             "WMT_TAG_ID_ANCESTOR": "681794",
#             "WMT_TAG_ISACTIVE": "1",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "23-2ND STAGE COMPRESSOR-PH",
#             "WMT_TAG_STATUSCHGDATE": "2013-05-08 12:52:29",
#             "WMT_TAG_UPDATED_BY": "8137",
#             "WMT_TAG_UPDATED_DATE": "2013-12-11 14:35:29"
#         },
#         "id": 4074033093163622,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:39:44.193+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:23-XX-9106",
#         "name": "23-XX-9106",
#         "parent_id": 7372310232665628,
#         "parent_external_id": "WMT:23-1ST STAGE COMPRESSOR-PH",
#         "description": "VRD - 1ST STAGE COMPRESSOR SKID",
#         "metadata": {
#             "ELC_STATUS_ID": "1211",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1600",
#             "WMT_CATEGORY_ID": "1120",
#             "WMT_CONTRACTOR_ID": "1686",
#             "WMT_FUNC_CODE_ID": "6340",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_PO_ID": "8309",
#             "WMT_SYSTEM_ID": "4440",
#             "WMT_TAG_COMMENT": "Compressor and auxilliaries (excluding motor) are designed for 170 MMSCFD.  Export capacity is limited by installed impeller set and motor.  Baseplate is sized to allow motor upgrade for full design production., Capacity: 143 MMSCFD Export Gas / Base Case",
#             "WMT_TAG_CREATED_DATE": "2009-06-26 15:36:37",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "VRD - 1ST STAGE COMPRESSOR SKID",
#             "WMT_TAG_GLOBALID": "1000000000717627",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "346906",
#             "WMT_TAG_ID_ANCESTOR": "681824",
#             "WMT_TAG_ISACTIVE": "1",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "23-XX-9106",
#             "WMT_TAG_UPDATED_BY": "1001",
#             "WMT_TAG_UPDATED_DATE": "2015-10-08 15:05:17"
#         },
#         "id": 4856008121737468,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:39:52.059+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:23-XX-9114",
#         "name": "23-XX-9114",
#         "parent_id": 4074033093163622,
#         "parent_external_id": "WMT:23-2ND STAGE COMPRESSOR-PH",
#         "description": "VRD - 2ND STAGE COMPRESSOR SKID",
#         "metadata": {
#             "ELC_STATUS_ID": "1211",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1600",
#             "WMT_CATEGORY_ID": "1120",
#             "WMT_CONTRACTOR_ID": "1686",
#             "WMT_FUNC_CODE_ID": "6340",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_PO_ID": "8309",
#             "WMT_SYSTEM_ID": "4440",
#             "WMT_TAG_COMMENT": "Compressor and auxilliaries (excluding motor) are designed for 170 MMSCFD.  Export capacity is limited by installed impeller set and motor.  Baseplate is sized to allow motor upgrade for full design production., Capacity: 143 MMSCFD Export Gas / Base Case",
#             "WMT_TAG_CREATED_DATE": "2009-06-26 15:36:37",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "VRD - 2ND STAGE COMPRESSOR SKID",
#             "WMT_TAG_GLOBALID": "1000000000717629",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "346908",
#             "WMT_TAG_ID_ANCESTOR": "681825",
#             "WMT_TAG_ISACTIVE": "1",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "23-XX-9114",
#             "WMT_TAG_UPDATED_BY": "1001",
#             "WMT_TAG_UPDATED_DATE": "2015-10-08 15:05:08"
#         },
#         "id": 4222791488928479,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:39:46.051+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:23-CX-9101",
#         "name": "23-CX-9101",
#         "parent_id": 7372310232665628,
#         "parent_external_id": "WMT:23-1ST STAGE COMPRESSOR-PH",
#         "description": "VRD - 1ST STAGE COMPRESSOR PURGE UNIT",
#         "metadata": {
#             "ELC_STATUS_ID": "1211",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1603",
#             "WMT_CATEGORY_ID": "1120",
#             "WMT_CONTRACTOR_ID": "1686",
#             "WMT_FUNC_CODE_ID": "6238",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_SYSTEM_ID": "4440",
#             "WMT_TAG_CREATED_DATE": "2013-04-05 15:12:54",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "VRD - 1ST STAGE COMPRESSOR PURGE UNIT",
#             "WMT_TAG_GLOBALID": "1000000000280835",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "694627",
#             "WMT_TAG_ID_ANCESTOR": "681824",
#             "WMT_TAG_ISACTIVE": "1",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "23-CX-9101",
#             "WMT_TAG_UPDATED_BY": "1001",
#             "WMT_TAG_UPDATED_DATE": "2015-10-08 15:05:18"
#         },
#         "id": 6800693372982143,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:40:11.687+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:23-DB-9101",
#         "name": "23-DB-9101",
#         "parent_id": 3047932288982463,
#         "parent_external_id": "WMT:23-KA-9101",
#         "description": "VRD - 1ST STAGE COMPRESSOR GEAR UNIT",
#         "metadata": {
#             "ELC_STATUS_ID": "1211",
#             "RES_ID": "490395",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1600",
#             "WMT_CATEGORY_ID": "1120",
#             "WMT_CONTRACTOR_ID": "1686",
#             "WMT_FUNC_CODE_ID": "4729",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_PO_ID": "8309",
#             "WMT_SYSTEM_ID": "4440",
#             "WMT_TAG_COMMENT": "Manufacturer: RENK / Model: TA63XI, Capacity: 13,500 kW @ 1784 to 6273 rpm, Size: 2090 mm L x 2081 mm W x 2097 mm H (shipping), Operating conditions: 9,430 kW @ 1784 / 6273 rpm",
#             "WMT_TAG_CREATED_DATE": "2009-06-26 15:36:37",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "VRD - 1ST STAGE COMPRESSOR GEAR UNIT",
#             "WMT_TAG_GLOBALID": "1000000000707631",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "345637",
#             "WMT_TAG_ID_ANCESTOR": "346064",
#             "WMT_TAG_ISACTIVE": "1",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "23-DB-9101",
#             "WMT_TAG_UPDATED_BY": "1001",
#             "WMT_TAG_UPDATED_DATE": "2015-10-08 15:05:08"
#         },
#         "id": 3117826349444493,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:39:33.879+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:23-KA-9101-H01",
#         "name": "23-KA-9101-H01",
#         "parent_id": 3047932288982463,
#         "parent_external_id": "WMT:23-KA-9101",
#         "description": "VRD - 1ST STAGE COMPRESSOR SPACE HEATER",
#         "metadata": {
#             "ELC_STATUS_ID": "1211",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1600",
#             "WMT_CATEGORY_ID": "1114",
#             "WMT_CONTRACTOR_ID": "1686",
#             "WMT_FUNC_CODE_ID": "4268",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_PO_ID": "8309",
#             "WMT_SAFETYCRITICALELEMENT_ID": "1060",
#             "WMT_SYSTEM_ID": "4440",
#             "WMT_TAG_COMMENT": "P900106",
#             "WMT_TAG_CREATED_DATE": "2009-06-26 15:36:37",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "VRD - 1ST STAGE COMPRESSOR SPACE HEATER",
#             "WMT_TAG_GLOBALID": "1000000000707342",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "346065",
#             "WMT_TAG_ID_ANCESTOR": "346064",
#             "WMT_TAG_ISACTIVE": "1",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "23-KA-9101-H01",
#             "WMT_TAG_UPDATED_BY": "1001",
#             "WMT_TAG_UPDATED_DATE": "2015-10-09 11:56:23"
#         },
#         "id": 3497989157395964,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:39:37.971+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:23-TB-9159",
#         "name": "23-TB-9159",
#         "parent_id": 6406206875482180,
#         "parent_external_id": "WMT:23-SU-9113",
#         "description": "VRD - 1ST STAGE COMPRESSOR WATER TANK",
#         "metadata": {
#             "ELC_STATUS_ID": "1225",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1600",
#             "WMT_CATEGORY_ID": "1120",
#             "WMT_CONTRACTOR_ID": "1686",
#             "WMT_FUNC_CODE_ID": "6324",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_PO_ID": "8309",
#             "WMT_SAFETYCRITICALELEMENT_ID": "1033",
#             "WMT_SYSTEM_ID": "4440",
#             "WMT_TAG_COMMENT": "PID - 1st Stage Comp. Water Mist System",
#             "WMT_TAG_CREATED_DATE": "2009-06-26 15:36:37",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "VRD - 1ST STAGE COMPRESSOR WATER TANK",
#             "WMT_TAG_GLOBALID": "1000000000683305",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "346386",
#             "WMT_TAG_ID_ANCESTOR": "346383",
#             "WMT_TAG_ISACTIVE": "0",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "23-TB-9159",
#             "WMT_TAG_STATUSCHGDATE": "2018-01-02 09:26:56",
#             "WMT_TAG_UPDATED_BY": "2829",
#             "WMT_TAG_UPDATED_DATE": "2018-01-02 09:26:56"
#         },
#         "id": 2249244529682744,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:39:25.073+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:23-TE-96147",
#         "name": "23-TE-96147",
#         "parent_id": 2539007469802785,
#         "parent_external_id": "WMT:23-FE-9122",
#         "description": "VRD - COMPRESSOR SEAL GAS HEATER TEMPERATURE",
#         "metadata": {
#             "ELC_STATUS_ID": "1225",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1600",
#             "WMT_CATEGORY_ID": "1116",
#             "WMT_CONTRACTOR_ID": "1327",
#             "WMT_FUNC_CODE_ID": "4564",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_SYSTEM_ID": "4440",
#             "WMT_TAG_CREATED_DATE": "2010-09-22 17:10:17",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "VRD - COMPRESSOR SEAL GAS HEATER TEMPERATURE",
#             "WMT_TAG_GLOBALID": "1000000000930230",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "526509",
#             "WMT_TAG_ID_ANCESTOR": "345716",
#             "WMT_TAG_ISACTIVE": "0",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "23-TE-96147",
#             "WMT_TAG_STATUSCHGDATE": "2013-07-16 10:56:35",
#             "WMT_TAG_UPDATED_BY": "1001",
#             "WMT_TAG_UPDATED_DATE": "2015-10-08 10:03:59"
#         },
#         "id": 6807309360116750,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:40:11.871+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:23-TSHH-96147",
#         "name": "23-TSHH-96147",
#         "parent_id": 2539007469802785,
#         "parent_external_id": "WMT:23-FE-9122",
#         "description": "VRD - COMPRESSOR SEAL GAS HEATER OVERTEMPERATURE",
#         "metadata": {
#             "ELC_STATUS_ID": "1225",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1600",
#             "WMT_CATEGORY_ID": "1116",
#             "WMT_CONTRACTOR_ID": "1327",
#             "WMT_FUNC_CODE_ID": "4575",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_SAFETYCRITICALELEMENT_ID": "1060",
#             "WMT_SYSTEM_ID": "4440",
#             "WMT_TAG_CREATED_DATE": "2010-09-22 17:10:16",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "VRD - COMPRESSOR SEAL GAS HEATER OVERTEMPERATURE",
#             "WMT_TAG_GLOBALID": "1000000000930101",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "526379",
#             "WMT_TAG_ID_ANCESTOR": "345716",
#             "WMT_TAG_ISACTIVE": "0",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "23-TSHH-96147",
#             "WMT_TAG_STATUSCHGDATE": "2013-07-16 10:56:35",
#             "WMT_TAG_UPDATED_BY": "1001",
#             "WMT_TAG_UPDATED_DATE": "2015-10-08 10:03:59"
#         },
#         "id": 650646241084062,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:39:09.514+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:23-VA-9110",
#         "name": "23-VA-9110",
#         "parent_id": 2357112351749647,
#         "parent_external_id": "WMT:23-TX-9103",
#         "description": "VRD - 1ST STAGE COMPRESSOR OIL SEPARATOR",
#         "metadata": {
#             "ELC_STATUS_ID": "1211",
#             "RES_ID": "758235",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1600",
#             "WMT_CATEGORY_ID": "1120",
#             "WMT_CONTRACTOR_ID": "1686",
#             "WMT_FUNC_CODE_ID": "6327",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_PO_ID": "8309",
#             "WMT_SYSTEM_ID": "4440",
#             "WMT_TAG_COMMENT": "Size: 400 mm L x 672 mm W x 1225 mm H",
#             "WMT_TAG_CREATED_DATE": "2009-06-26 15:36:37",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "VRD - 1ST STAGE COMPRESSOR OIL SEPARATOR",
#             "WMT_TAG_GLOBALID": "1000000000716785",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "346855",
#             "WMT_TAG_ID_ANCESTOR": "346682",
#             "WMT_TAG_ISACTIVE": "1",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "23-VA-9110",
#             "WMT_TAG_STATUSCHGDATE": "2017-05-09 06:07:43",
#             "WMT_TAG_UPDATED_BY": "5774",
#             "WMT_TAG_UPDATED_DATE": "2017-05-09 06:07:43"
#         },
#         "id": 4461000379624497,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:39:48.486+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:60-EH-9000A+H00",
#         "name": "60-EH-9000A+H00",
#         "parent_id": 6191827428964450,
#         "parent_external_id": "WMT:23-KA-9101-M01",
#         "description": "VRD - MOTOR STARTER 1ST STAGE COMPRESSOR",
#         "metadata": {
#             "ELC_STATUS_ID": "1211",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1654",
#             "WMT_CATEGORY_ID": "1115",
#             "WMT_CONTRACTOR_ID": "1686",
#             "WMT_FUNC_CODE_ID": "6183",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_SAFETYCRITICALELEMENT_ID": "1069",
#             "WMT_SYSTEM_ID": "3118",
#             "WMT_TAG_CREATED_DATE": "2013-05-28 11:16:05",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "VRD - MOTOR STARTER 1ST STAGE COMPRESSOR",
#             "WMT_TAG_GLOBALID": "1000000000298238",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "702497",
#             "WMT_TAG_ID_ANCESTOR": "346066",
#             "WMT_TAG_ISACTIVE": "1",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "60-EH-9000A+H00",
#             "WMT_TAG_STATUSCHGDATE": "2017-01-26 08:47:10",
#             "WMT_TAG_UPDATED_BY": "8137",
#             "WMT_TAG_UPDATED_DATE": "2017-01-26 08:47:10"
#         },
#         "id": 7886783194876402,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:40:22.553+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:23-CB-9129A",
#         "name": "23-CB-9129A",
#         "parent_id": 3904753668320840,
#         "parent_external_id": "WMT:23-1ST STAGE COMP DRY GAS SEAL SYS-PH",
#         "description": "VRD - 1ST STAGE COMPRESSOR NITROGEN FILTER A",
#         "metadata": {
#             "ELC_STATUS_ID": "1211",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1600",
#             "WMT_CATEGORY_ID": "1120",
#             "WMT_CONTRACTOR_ID": "1686",
#             "WMT_FUNC_CODE_ID": "6230",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_PO_ID": "8309",
#             "WMT_SYSTEM_ID": "4440",
#             "WMT_TAG_COMMENT": "Manufacturer: Indufil / Model: IDGH-1-85-3/4, Size: 0.6 liter, Operating conditions: 7 to 10 barg",
#             "WMT_TAG_CREATED_DATE": "2009-06-26 15:36:37",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "VRD - 1ST STAGE COMPRESSOR NITROGEN FILTER A",
#             "WMT_TAG_GLOBALID": "1000000000707621",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "345627",
#             "WMT_TAG_ID_ANCESTOR": "682540",
#             "WMT_TAG_ISACTIVE": "1",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "23-CB-9129A",
#             "WMT_TAG_SUFFIX": "A",
#             "WMT_TAG_UPDATED_BY": "1001",
#             "WMT_TAG_UPDATED_DATE": "2015-10-08 15:05:08"
#         },
#         "id": 5062762658885662,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:39:54.091+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:23-CB-9129B",
#         "name": "23-CB-9129B",
#         "parent_id": 3904753668320840,
#         "parent_external_id": "WMT:23-1ST STAGE COMP DRY GAS SEAL SYS-PH",
#         "description": "VRD - 1ST STAGE COMPRESSOR NITROGEN FILTER B",
#         "metadata": {
#             "ELC_STATUS_ID": "1211",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1600",
#             "WMT_CATEGORY_ID": "1120",
#             "WMT_CONTRACTOR_ID": "1686",
#             "WMT_FUNC_CODE_ID": "6230",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_PO_ID": "8309",
#             "WMT_SYSTEM_ID": "4440",
#             "WMT_TAG_COMMENT": "Manufacturer: Indufil / Model: IDGH-1-85-3/4, Size: 0.6 liter, Operating conditions: 7 to 10 barg",
#             "WMT_TAG_CREATED_DATE": "2009-06-26 15:36:37",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "VRD - 1ST STAGE COMPRESSOR NITROGEN FILTER B",
#             "WMT_TAG_GLOBALID": "1000000000707622",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "345628",
#             "WMT_TAG_ID_ANCESTOR": "682540",
#             "WMT_TAG_ISACTIVE": "1",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "23-CB-9129B",
#             "WMT_TAG_SUFFIX": "B",
#             "WMT_TAG_UPDATED_BY": "1001",
#             "WMT_TAG_UPDATED_DATE": "2015-10-08 15:05:08"
#         },
#         "id": 928299407571359,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:39:11.785+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:23-FE-9106",
#         "name": "23-FE-9106",
#         "parent_id": 2357112351749647,
#         "parent_external_id": "WMT:23-TX-9103",
#         "description": "VRD - 1ST STAGE COMPRESSOR LUBE OIL HEATER",
#         "metadata": {
#             "ELC_STATUS_ID": "1211",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1603",
#             "WMT_CATEGORY_ID": "1114",
#             "WMT_CONTRACTOR_ID": "1686",
#             "WMT_FUNC_CODE_ID": "4268",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_PO_ID": "8718",
#             "WMT_SAFETYCRITICALELEMENT_ID": "1060",
#             "WMT_SYSTEM_ID": "4440",
#             "WMT_TAG_COMMENT": "P901021",
#             "WMT_TAG_CREATED_DATE": "2009-06-26 15:36:37",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "VRD - 1ST STAGE COMPRESSOR LUBE OIL HEATER",
#             "WMT_TAG_GLOBALID": "1000000000708502",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "345702",
#             "WMT_TAG_ID_ANCESTOR": "346682",
#             "WMT_TAG_ISACTIVE": "1",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "23-FE-9106",
#             "WMT_TAG_UPDATED_BY": "1001",
#             "WMT_TAG_UPDATED_DATE": "2015-10-09 11:56:23"
#         },
#         "id": 2083333183637273,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:39:23.085+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:23-FE-9106A",
#         "name": "23-FE-9106A",
#         "parent_id": 2357112351749647,
#         "parent_external_id": "WMT:23-TX-9103",
#         "description": "VRD - 1ST STAGE COMPRESSOR LUBE OIL HEATER",
#         "metadata": {
#             "ELC_STATUS_ID": "1225",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1600",
#             "WMT_CATEGORY_ID": "1120",
#             "WMT_FUNC_CODE_ID": "6255",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_SAFETYCRITICALELEMENT_ID": "1060",
#             "WMT_SYSTEM_ID": "4440",
#             "WMT_TAG_CREATED_DATE": "2010-09-22 17:10:16",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "VRD - 1ST STAGE COMPRESSOR LUBE OIL HEATER",
#             "WMT_TAG_GLOBALID": "1000000000930091",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "526369",
#             "WMT_TAG_ID_ANCESTOR": "346682",
#             "WMT_TAG_ISACTIVE": "0",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "23-FE-9106A",
#             "WMT_TAG_STATUSCHGDATE": "2013-07-16 10:56:35",
#             "WMT_TAG_UPDATED_BY": "8137",
#             "WMT_TAG_UPDATED_DATE": "2014-01-27 13:42:56"
#         },
#         "id": 243723133129244,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:39:05.660+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:23-FE-9106B",
#         "name": "23-FE-9106B",
#         "parent_id": 2357112351749647,
#         "parent_external_id": "WMT:23-TX-9103",
#         "description": "VRD - 1ST STAGE COMPRESSOR LUBE OIL HEATER",
#         "metadata": {
#             "ELC_STATUS_ID": "1225",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1600",
#             "WMT_CATEGORY_ID": "1120",
#             "WMT_FUNC_CODE_ID": "6255",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_SAFETYCRITICALELEMENT_ID": "1060",
#             "WMT_SYSTEM_ID": "4440",
#             "WMT_TAG_CREATED_DATE": "2010-09-22 17:10:16",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "VRD - 1ST STAGE COMPRESSOR LUBE OIL HEATER",
#             "WMT_TAG_GLOBALID": "1000000000930092",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "526370",
#             "WMT_TAG_ID_ANCESTOR": "346682",
#             "WMT_TAG_ISACTIVE": "0",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "23-FE-9106B",
#             "WMT_TAG_STATUSCHGDATE": "2013-07-16 10:56:35",
#             "WMT_TAG_UPDATED_BY": "8137",
#             "WMT_TAG_UPDATED_DATE": "2014-01-27 13:42:56"
#         },
#         "id": 6668670388016019,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:40:10.460+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:23-FE-9189",
#         "name": "23-FE-9189",
#         "parent_id": 6406206875482180,
#         "parent_external_id": "WMT:23-SU-9113",
#         "description": "VRD - 1ST STAGE COMPRESSOR WATER TANK HEATER",
#         "metadata": {
#             "ELC_STATUS_ID": "1225",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1642",
#             "WMT_CATEGORY_ID": "1114",
#             "WMT_CONTRACTOR_ID": "1327",
#             "WMT_FUNC_CODE_ID": "6177",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_PO_ID": "8309",
#             "WMT_SAFETYCRITICALELEMENT_ID": "1060",
#             "WMT_SYSTEM_ID": "4440",
#             "WMT_TAG_CREATED_DATE": "2009-06-26 15:36:37",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "VRD - 1ST STAGE COMPRESSOR WATER TANK HEATER",
#             "WMT_TAG_GLOBALID": "1000000000706012",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "345722",
#             "WMT_TAG_ID_ANCESTOR": "346383",
#             "WMT_TAG_ISACTIVE": "0",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "23-FE-9189",
#             "WMT_TAG_STATUSCHGDATE": "2013-07-16 10:56:35",
#             "WMT_TAG_UPDATED_BY": "1001",
#             "WMT_TAG_UPDATED_DATE": "2015-10-09 11:56:23"
#         },
#         "id": 8799203232100313,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:40:31.273+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:23-GK-9107A-A01",
#         "name": "23-GK-9107A-A01",
#         "parent_id": 6274025936172610,
#         "parent_external_id": "WMT:23-GK-9107A",
#         "description": "VRD - 1ST STAGE COMPRESSOR ENCLOSURE COOLING UNIT",
#         "metadata": {
#             "ELC_STATUS_ID": "1211",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1600",
#             "WMT_CATEGORY_ID": "1114",
#             "WMT_CONTRACTOR_ID": "1686",
#             "WMT_FUNC_CODE_ID": "9860",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_PO_ID": "8309",
#             "WMT_SAFETYCRITICALELEMENT_ID": "1060",
#             "WMT_SYSTEM_ID": "4440",
#             "WMT_TAG_COMMENT": "C901003",
#             "WMT_TAG_CREATED_DATE": "2010-03-19 20:38:50",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "VRD - 1ST STAGE COMPRESSOR ENCLOSURE COOLING UNIT",
#             "WMT_TAG_GLOBALID": "1000000000822102",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "475057",
#             "WMT_TAG_ID_ANCESTOR": "345925",
#             "WMT_TAG_ISACTIVE": "1",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "23-GK-9107A-A01",
#             "WMT_TAG_UPDATED_BY": "1001",
#             "WMT_TAG_UPDATED_DATE": "2015-10-09 11:56:24"
#         },
#         "id": 1628123687639760,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:39:19.101+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:23-PC-9109-M01",
#         "name": "23-PC-9109-M01",
#         "parent_id": 7480049662945478,
#         "parent_external_id": "WMT:23-PC-9109",
#         "description": "VRD - 1ST STAGE COMPRESSOR BACKUP L.O. PUMP",
#         "metadata": {
#             "ELC_STATUS_ID": "1211",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1600",
#             "WMT_CATEGORY_ID": "1114",
#             "WMT_CONTRACTOR_ID": "1686",
#             "WMT_FUNC_CODE_ID": "4280",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_PO_ID": "8718",
#             "WMT_SAFETYCRITICALELEMENT_ID": "1060",
#             "WMT_SYSTEM_ID": "4440",
#             "WMT_TAG_CREATED_DATE": "2009-06-26 15:36:37",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "VRD - 1ST STAGE COMPRESSOR BACKUP L.O. PUMP",
#             "WMT_TAG_GLOBALID": "1000000000705722",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "346156",
#             "WMT_TAG_ID_ANCESTOR": "346154",
#             "WMT_TAG_ISACTIVE": "1",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "23-PC-9109-M01",
#             "WMT_TAG_UPDATED_BY": "1001",
#             "WMT_TAG_UPDATED_DATE": "2015-10-09 11:56:23"
#         },
#         "id": 2152173685593388,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:39:23.884+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:23-VA-9114",
#         "name": "23-VA-9114",
#         "parent_id": 2499711953216311,
#         "parent_external_id": "WMT:23-1ST STAGE COMP ENCLOSURE-PH",
#         "description": "VRD - 1ST STAGE COMPRESSOR MARINE VANE SEPARATOR",
#         "metadata": {
#             "ELC_STATUS_ID": "1211",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1600",
#             "WMT_CATEGORY_ID": "1120",
#             "WMT_CONTRACTOR_ID": "1686",
#             "WMT_FUNC_CODE_ID": "6327",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_PO_ID": "8309",
#             "WMT_SYSTEM_ID": "4440",
#             "WMT_TAG_COMMENT": "Manufacturer: Altair Filter / Model: ABX084 / Part of 23-EC-9102, Capacity: 5 m3/sec (max), Size: 1235 mm L x 1400 mm H x 150 mm D, Operating conditions: atm @ amb",
#             "WMT_TAG_CREATED_DATE": "2009-06-26 15:36:37",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "VRD - 1ST STAGE COMPRESSOR MARINE VANE SEPARATOR",
#             "WMT_TAG_GLOBALID": "1000000000716794",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "346864",
#             "WMT_TAG_ID_ANCESTOR": "682542",
#             "WMT_TAG_ISACTIVE": "1",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "23-VA-9114",
#             "WMT_TAG_UPDATED_BY": "1001",
#             "WMT_TAG_UPDATED_DATE": "2015-10-08 15:05:17"
#         },
#         "id": 8820916275841408,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:40:31.550+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:48-SU-9113",
#         "name": "48-SU-9113",
#         "parent_id": 2499711953216311,
#         "parent_external_id": "WMT:23-1ST STAGE COMP ENCLOSURE-PH",
#         "description": "VRD - 1ST STAGE COMPRESSOR WATER MIST SYSTEM",
#         "metadata": {
#             "ELC_STATUS_ID": "1211",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1600",
#             "WMT_CATEGORY_ID": "1120",
#             "WMT_CONTRACTOR_ID": "1686",
#             "WMT_FUNC_CODE_ID": "6320",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_PO_ID": "8309",
#             "WMT_SAFETYCRITICALELEMENT_ID": "1033",
#             "WMT_SYSTEM_ID": "2491",
#             "WMT_TAG_COMMENT": "2 shot system, designed for 2 minutes spray, one minute pause, 2 minute spray, Operating conditions: Upstream PCV: amb @ 200 barg / Downstream PCV: amb @ 5.0 barg",
#             "WMT_TAG_CREATED_DATE": "2009-11-20 14:54:49",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "VRD - 1ST STAGE COMPRESSOR WATER MIST SYSTEM",
#             "WMT_TAG_GLOBALID": "1000000000771748",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "411403",
#             "WMT_TAG_ID_ANCESTOR": "682542",
#             "WMT_TAG_ISACTIVE": "1",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "48-SU-9113",
#             "WMT_TAG_UPDATED_BY": "1001",
#             "WMT_TAG_UPDATED_DATE": "2015-10-08 13:37:54"
#         },
#         "id": 3476609559144829,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:39:37.704+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:48-TB-9159",
#         "name": "48-TB-9159",
#         "parent_id": 3476609559144829,
#         "parent_external_id": "WMT:48-SU-9113",
#         "description": "VRD - 1ST STAGE COMPRESSOR WATER MIST VESSEL",
#         "metadata": {
#             "ELC_STATUS_ID": "1211",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1600",
#             "WMT_CATEGORY_ID": "1120",
#             "WMT_CONTRACTOR_ID": "1686",
#             "WMT_FUNC_CODE_ID": "6324",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_PO_ID": "8309",
#             "WMT_SAFETYCRITICALELEMENT_ID": "1033",
#             "WMT_SYSTEM_ID": "2491",
#             "WMT_TAG_COMMENT": "Capacity: 400 L, Operating conditions: amb @ 5 barg",
#             "WMT_TAG_CREATED_DATE": "2010-03-19 20:38:50",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "VRD - 1ST STAGE COMPRESSOR WATER MIST VESSEL",
#             "WMT_TAG_GLOBALID": "1000000000822331",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "475108",
#             "WMT_TAG_ID_ANCESTOR": "411403",
#             "WMT_TAG_ISACTIVE": "1",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "48-TB-9159",
#             "WMT_TAG_UPDATED_BY": "1001",
#             "WMT_TAG_UPDATED_DATE": "2015-10-08 13:37:54"
#         },
#         "id": 8171126796201393,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:40:25.397+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:60-EN-9010A+24B1",
#         "name": "60-EN-9010A+24B1",
#         "parent_id": 2083333183637273,
#         "parent_external_id": "WMT:23-FE-9106",
#         "description": "VRD - 1ST STAGE COMPRESSOR LUBE OIL HEATER",
#         "metadata": {
#             "ELC_STATUS_ID": "1211",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1650",
#             "WMT_CATEGORY_ID": "1115",
#             "WMT_CONTRACTOR_ID": "1686",
#             "WMT_FUNC_CODE_ID": "6185",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_SYSTEM_ID": "3118",
#             "WMT_TAG_CREATED_DATE": "2013-05-28 11:16:05",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "VRD - 1ST STAGE COMPRESSOR LUBE OIL HEATER",
#             "WMT_TAG_GLOBALID": "1000000000297905",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "702164",
#             "WMT_TAG_ID_ANCESTOR": "345702",
#             "WMT_TAG_ISACTIVE": "1",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "60-EN-9010A+24B1",
#             "WMT_TAG_STATUSCHGDATE": "2017-07-25 10:12:15",
#             "WMT_TAG_UPDATED_BY": "8137",
#             "WMT_TAG_UPDATED_DATE": "2017-07-25 10:12:15"
#         },
#         "id": 7200619527605764,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:40:15.590+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:60-EN-9010B+27G1",
#         "name": "60-EN-9010B+27G1",
#         "parent_id": 2152173685593388,
#         "parent_external_id": "WMT:23-PC-9109-M01",
#         "description": "VRD - 1ST STAGE COMPRESSOR BACKUP LO. PUMP",
#         "metadata": {
#             "ELC_STATUS_ID": "1211",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1650",
#             "WMT_CATEGORY_ID": "1115",
#             "WMT_CONTRACTOR_ID": "1686",
#             "WMT_FUNC_CODE_ID": "6185",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_SYSTEM_ID": "3118",
#             "WMT_TAG_CREATED_DATE": "2013-05-28 11:16:05",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "VRD - 1ST STAGE COMPRESSOR BACKUP LO. PUMP",
#             "WMT_TAG_GLOBALID": "1000000000297583",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "701844",
#             "WMT_TAG_ID_ANCESTOR": "346156",
#             "WMT_TAG_ISACTIVE": "1",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "60-EN-9010B+27G1",
#             "WMT_TAG_UPDATED_BY": "1001",
#             "WMT_TAG_UPDATED_DATE": "2015-10-08 11:47:33"
#         },
#         "id": 2179240149049404,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:39:24.315+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:23-CB-9103A",
#         "name": "23-CB-9103A",
#         "parent_id": 2137557577165478,
#         "parent_external_id": "WMT:23-1ST STAGE COMP LUBE OIL SYS-PH",
#         "description": "VRD - 1ST STAGE COMPRESSOR LUBE OIL FILTER A",
#         "metadata": {
#             "ELC_STATUS_ID": "1211",
#             "RES_ID": "746776",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1600",
#             "WMT_CATEGORY_ID": "1120",
#             "WMT_CONTRACTOR_ID": "1686",
#             "WMT_FUNC_CODE_ID": "6230",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_PO_ID": "8309",
#             "WMT_SYSTEM_ID": "4440",
#             "WMT_TAG_COMMENT": "Manufacturer: Indufil / Model: IDGL-4-880-3, Capacity: 31.63 m3/hr, Size: 14 liter, Operating conditions: 7.4 barg @ 50?C",
#             "WMT_TAG_CREATED_DATE": "2009-06-26 15:36:37",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "VRD - 1ST STAGE COMPRESSOR LUBE OIL FILTER A",
#             "WMT_TAG_GLOBALID": "1000000000706800",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "345603",
#             "WMT_TAG_ID_ANCESTOR": "682544",
#             "WMT_TAG_ISACTIVE": "1",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "23-CB-9103A",
#             "WMT_TAG_SUFFIX": "A",
#             "WMT_TAG_UPDATED_BY": "1001",
#             "WMT_TAG_UPDATED_DATE": "2015-10-08 15:05:08"
#         },
#         "id": 8790823573167638,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:40:31.121+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:23-CB-9103B",
#         "name": "23-CB-9103B",
#         "parent_id": 2137557577165478,
#         "parent_external_id": "WMT:23-1ST STAGE COMP LUBE OIL SYS-PH",
#         "description": "VRD - 1ST STAGE COMPRESSOR LUBE OIL FILTER B",
#         "metadata": {
#             "ELC_STATUS_ID": "1211",
#             "RES_ID": "746776",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1600",
#             "WMT_CATEGORY_ID": "1120",
#             "WMT_CONTRACTOR_ID": "1686",
#             "WMT_FUNC_CODE_ID": "6230",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_PO_ID": "8309",
#             "WMT_SYSTEM_ID": "4440",
#             "WMT_TAG_COMMENT": "Manufacturer: Indufil / Model: IDGL-4-880-3, Capacity: 31.63 m3/hr, Size: 14 liter, Operating conditions: 7.4 barg @ 50?C",
#             "WMT_TAG_CREATED_DATE": "2009-06-26 15:36:37",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "VRD - 1ST STAGE COMPRESSOR LUBE OIL FILTER B",
#             "WMT_TAG_GLOBALID": "1000000000707441",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "345604",
#             "WMT_TAG_ID_ANCESTOR": "682544",
#             "WMT_TAG_ISACTIVE": "1",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "23-CB-9103B",
#             "WMT_TAG_SUFFIX": "B",
#             "WMT_TAG_UPDATED_BY": "1001",
#             "WMT_TAG_UPDATED_DATE": "2015-10-08 15:05:19"
#         },
#         "id": 379497117972793,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:39:06.960+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:23-CB-9104A",
#         "name": "23-CB-9104A",
#         "parent_id": 3904753668320840,
#         "parent_external_id": "WMT:23-1ST STAGE COMP DRY GAS SEAL SYS-PH",
# ...
#             "WMT_PO_ID": "8309",
#             "WMT_SYSTEM_ID": "4440",
#             "WMT_TAG_COMMENT": "Manufacturer: Altair Filter / Model: ABX084, Capacity: 5 m3/sec (max), Size: 1235 mm L x 1400 mm H x 150 mm D, Operating conditions: atm @ amb",
#             "WMT_TAG_CREATED_DATE": "2009-06-26 15:36:37",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "VRD - 1ST STAGE COMPPRESSOR ENCLOSURE COALESCER FILTER PANEL",
#             "WMT_TAG_GLOBALID": "1000000000707637",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "345643",
#             "WMT_TAG_ID_ANCESTOR": "682542",
#             "WMT_TAG_ISACTIVE": "1",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "23-EC-9102",
#             "WMT_TAG_UPDATED_BY": "1001",
#             "WMT_TAG_UPDATED_DATE": "2015-10-08 15:05:08"
#         },
#         "id": 6849981120182174,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:40:12.265+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:23-GG-9105",
#         "name": "23-GG-9105",
#         "parent_id": 2499711953216311,
#         "parent_external_id": "WMT:23-1ST STAGE COMP ENCLOSURE-PH",
#         "description": "VRD - 1ST STAGE COMPPRESSOR ENCLOSURE INLET AIR SILENCER",
#         "metadata": {
#             "ELC_STATUS_ID": "1211",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1600",
#             "WMT_CATEGORY_ID": "1120",
#             "WMT_CONTRACTOR_ID": "1686",
#             "WMT_FUNC_CODE_ID": "6260",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_PO_ID": "8309",
#             "WMT_SAFETYCRITICALELEMENT_ID": "1033",
#             "WMT_SYSTEM_ID": "4440",
#             "WMT_TAG_COMMENT": "Capacity: 2.8 m3/sec",
#             "WMT_TAG_CREATED_DATE": "2009-06-26 15:36:37",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "VRD - 1ST STAGE COMPPRESSOR ENCLOSURE INLET AIR SILENCER",
#             "WMT_TAG_GLOBALID": "1000000000705453",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "345919",
#             "WMT_TAG_ID_ANCESTOR": "682542",
#             "WMT_TAG_ISACTIVE": "1",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "23-GG-9105",
#             "WMT_TAG_UPDATED_BY": "1001",
#             "WMT_TAG_UPDATED_DATE": "2015-10-08 15:05:08"
#         },
#         "id": 8435484236540595,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:40:27.730+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:23-PC-9101",
#         "name": "23-PC-9101",
#         "parent_id": 2137557577165478,
#         "parent_external_id": "WMT:23-1ST STAGE COMP LUBE OIL SYS-PH",
#         "description": "VRD - 1ST STAGE COMPPRESSOR MAIN LUBE OIL PUMP",
#         "metadata": {
#             "ELC_STATUS_ID": "1211",
#             "RES_ID": "813493",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1600",
#             "WMT_CATEGORY_ID": "1120",
#             "WMT_CONTRACTOR_ID": "1686",
#             "WMT_FUNC_CODE_ID": "6300",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_PO_ID": "8309",
#             "WMT_SYSTEM_ID": "4440",
#             "WMT_TAG_COMMENT": "Capacity: 31.62 m3/h, Operating conditions: 9.2 barg @ 70 deg C",
#             "WMT_TAG_CREATED_DATE": "2009-06-26 15:36:37",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "VRD - 1ST STAGE COMPPRESSOR MAIN LUBE OIL PUMP",
#             "WMT_TAG_GLOBALID": "1000000000705705",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "346139",
#             "WMT_TAG_ID_ANCESTOR": "682544",
#             "WMT_TAG_ISACTIVE": "1",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "23-PC-9101",
#             "WMT_TAG_STATUSCHGDATE": "2017-01-12 10:30:45",
#             "WMT_TAG_UPDATED_BY": "2829",
#             "WMT_TAG_UPDATED_DATE": "2017-01-12 10:30:45"
#         },
#         "id": 3869476400931933,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:39:41.932+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:23-PC-9109",
#         "name": "23-PC-9109",
#         "parent_id": 2357112351749647,
#         "parent_external_id": "WMT:23-TX-9103",
#         "description": "VRD - 1ST STAGE COMPPRESSOR AUXILIARY LUBE OIL PUMP",
#         "metadata": {
#             "ELC_STATUS_ID": "1211",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1600",
#             "WMT_CATEGORY_ID": "1120",
#             "WMT_CONTRACTOR_ID": "1686",
#             "WMT_FUNC_CODE_ID": "6300",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_PO_ID": "8309",
#             "WMT_SYSTEM_ID": "4440",
#             "WMT_TAG_COMMENT": "Manufacturer: Plently Mirlees / Model: KCA80-4NL, Capacity: 31.62 m3/h, Operating conditions: 9.2 barg @ 70 deg C",
#             "WMT_TAG_CREATED_DATE": "2009-06-26 15:36:37",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "VRD - 1ST STAGE COMPPRESSOR AUXILIARY LUBE OIL PUMP",
#             "WMT_TAG_GLOBALID": "1000000000705720",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "346154",
#             "WMT_TAG_ID_ANCESTOR": "346682",
#             "WMT_TAG_ISACTIVE": "1",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "23-PC-9109",
#             "WMT_TAG_UPDATED_BY": "1001",
#             "WMT_TAG_UPDATED_DATE": "2015-10-08 15:05:08"
#         },
#         "id": 7480049662945478,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:40:18.303+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:23-GE-9110A",
#         "name": "23-GE-9110A",
#         "parent_id": 2499711953216311,
#         "parent_external_id": "WMT:23-1ST STAGE COMP ENCLOSURE-PH",
#         "description": "VRD - 1ST STAGE COMPPRESSOR ENCLOSURE NON RETURN DAMPER A",
#         "metadata": {
#             "ELC_STATUS_ID": "1211",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1600",
#             "WMT_CATEGORY_ID": "1120",
#             "WMT_CONTRACTOR_ID": "1686",
#             "WMT_FUNC_CODE_ID": "9248",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_PO_ID": "8309",
#             "WMT_SYSTEM_ID": "4440",
#             "WMT_TAG_COMMENT": "Manufacturer: Flamgard / Model: BD02, Capacity: 2.8 m3/sec, Size: 508 mm L x 566 mm H x 200 mm D, Operating conditions: 435 Pa @ amb",
#             "WMT_TAG_CREATED_DATE": "2009-06-26 15:36:37",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "VRD - 1ST STAGE COMPPRESSOR ENCLOSURE NON RETURN DAMPER A",
#             "WMT_TAG_GLOBALID": "1000000000705438",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "345904",
#             "WMT_TAG_ID_ANCESTOR": "682542",
#             "WMT_TAG_ISACTIVE": "1",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "23-GE-9110A",
#             "WMT_TAG_SUFFIX": "A",
#             "WMT_TAG_UPDATED_BY": "1001",
#             "WMT_TAG_UPDATED_DATE": "2015-10-08 15:05:08"
#         },
#         "id": 5708613036372741,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:39:59.850+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:23-GE-9110B",
#         "name": "23-GE-9110B",
#         "parent_id": 2499711953216311,
#         "parent_external_id": "WMT:23-1ST STAGE COMP ENCLOSURE-PH",
#         "description": "VRD - 1ST STAGE COMPPRESSOR ENCLOSURE NON RETURN DAMPER B",
#         "metadata": {
#             "ELC_STATUS_ID": "1211",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1600",
#             "WMT_CATEGORY_ID": "1120",
#             "WMT_CONTRACTOR_ID": "1686",
#             "WMT_FUNC_CODE_ID": "9248",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_PO_ID": "8309",
#             "WMT_SYSTEM_ID": "4440",
#             "WMT_TAG_COMMENT": "Manufacturer: Flamgard / Model: BD02, Capacity: 2.8 m3/sec, Size: 508 mm L x 566 mm H x 200 mm D, Operating conditions: 435 Pa @ amb",
#             "WMT_TAG_CREATED_DATE": "2009-06-26 15:36:37",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "VRD - 1ST STAGE COMPPRESSOR ENCLOSURE NON RETURN DAMPER B",
#             "WMT_TAG_GLOBALID": "1000000000705439",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "345905",
#             "WMT_TAG_ID_ANCESTOR": "682542",
#             "WMT_TAG_ISACTIVE": "1",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "23-GE-9110B",
#             "WMT_TAG_SUFFIX": "B",
#             "WMT_TAG_UPDATED_BY": "1001",
#             "WMT_TAG_UPDATED_DATE": "2015-10-08 15:05:19"
#         },
#         "id": 3854717707482355,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:39:41.858+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:23-GE-9122",
#         "name": "23-GE-9122",
#         "parent_id": 2499711953216311,
#         "parent_external_id": "WMT:23-1ST STAGE COMP ENCLOSURE-PH",
#         "description": "VRD - 1ST STAGE COMPPRESSOR ENCLOSURE MANUAL VOL CONTR DAMPER",
#         "metadata": {
#             "ELC_STATUS_ID": "1211",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1600",
#             "WMT_CATEGORY_ID": "1120",
#             "WMT_CONTRACTOR_ID": "1686",
#             "WMT_FUNC_CODE_ID": "9248",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_PO_ID": "8309",
#             "WMT_SYSTEM_ID": "4440",
#             "WMT_TAG_COMMENT": "Manufacturer: Flamgard / Model: BD02, Capacity: 2.8 m3/sec, Size: 508 mm L x 566 mm H x 200 mm D, Operating conditions: 435 Pa @ amb",
#             "WMT_TAG_CREATED_DATE": "2009-06-26 15:36:37",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "VRD - 1ST STAGE COMPPRESSOR ENCLOSURE MANUAL VOL CONTR DAMPER",
#             "WMT_TAG_GLOBALID": "1000000000705450",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "345916",
#             "WMT_TAG_ID_ANCESTOR": "682542",
#             "WMT_TAG_ISACTIVE": "1",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "23-GE-9122",
#             "WMT_TAG_UPDATED_BY": "1001",
#             "WMT_TAG_UPDATED_DATE": "2015-10-08 15:05:08"
#         },
#         "id": 1932780752811136,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:39:21.882+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:23-GO-9114",
#         "name": "23-GO-9114",
#         "parent_id": 2499711953216311,
#         "parent_external_id": "WMT:23-1ST STAGE COMP ENCLOSURE-PH",
#         "description": "VRD - 1ST STAGE COMPPRESSOR ENCLOSURE INLET AIR FIRE DAMPER",
#         "metadata": {
#             "ELC_STATUS_ID": "1211",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1600",
#             "WMT_CATEGORY_ID": "1120",
#             "WMT_CONTRACTOR_ID": "1686",
#             "WMT_FUNC_CODE_ID": "6265",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_PO_ID": "8309",
#             "WMT_SAFETYCRITICALELEMENT_ID": "1069",
#             "WMT_SYSTEM_ID": "4440",
#             "WMT_TAG_COMMENT": "Manufacturer: Flamgard / Model: SD02, Capacity: 2.8 m3/sec, Size: 1000 mm L x 1000 mm H x 300 mm D, Operating conditions: atm @ amb",
#             "WMT_TAG_CREATED_DATE": "2009-06-26 15:36:37",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "VRD - 1ST STAGE COMPPRESSOR ENCLOSURE INLET AIR FIRE DAMPER",
#             "WMT_TAG_GLOBALID": "1000000000705444",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "345910",
#             "WMT_TAG_ID_ANCESTOR": "682542",
#             "WMT_TAG_ISACTIVE": "1",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "23-GO-9114",
#             "WMT_TAG_UPDATED_BY": "4332",
#             "WMT_TAG_UPDATED_DATE": "2017-05-22 10:33:55"
#         },
#         "id": 1308676097270399,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:39:15.613+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:23-GO-9115",
#         "name": "23-GO-9115",
#         "parent_id": 2499711953216311,
#         "parent_external_id": "WMT:23-1ST STAGE COMP ENCLOSURE-PH",
#         "description": "VRD - 1ST STAGE COMPPRESSOR ENCLOSURE OUTLET AIR FIRE DAMPER",
#         "metadata": {
#             "ELC_STATUS_ID": "1211",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1600",
#             "WMT_CATEGORY_ID": "1120",
#             "WMT_CONTRACTOR_ID": "1686",
#             "WMT_FUNC_CODE_ID": "6265",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_PO_ID": "8309",
#             "WMT_SAFETYCRITICALELEMENT_ID": "1069",
#             "WMT_SYSTEM_ID": "4440",
#             "WMT_TAG_COMMENT": "Manufacturer: Flamgard / Model: SD02, Capacity: 2.8 m3/sec, Size: 1000 mm L x 1000 mm H x 300 mm D, Operating conditions: atm @ amb",
#             "WMT_TAG_CREATED_DATE": "2009-06-26 15:36:37",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "VRD - 1ST STAGE COMPPRESSOR ENCLOSURE OUTLET AIR FIRE DAMPER",
#             "WMT_TAG_GLOBALID": "1000000000705445",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "345911",
#             "WMT_TAG_ID_ANCESTOR": "682542",
#             "WMT_TAG_ISACTIVE": "1",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "23-GO-9115",
#             "WMT_TAG_UPDATED_BY": "4332",
#             "WMT_TAG_UPDATED_DATE": "2017-05-22 10:33:55"
#         },
#         "id": 3019092566968936,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:39:32.617+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:230900",
#         "name": "230900",
#         "parent_id": 3111454725058294,
#         "parent_external_id": "WMT:23",
#         "description": "GAS COMPRESSION AND RE-INJECTION ON PH",
#         "metadata": {
#             "ELC_STATUS_ID": "1211",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1444",
#             "WMT_CATEGORY_ID": "1157",
#             "WMT_FUNC_CODE_ID": "6593",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_SYSTEM_ID": "4440",
#             "WMT_TAG_CREATED_DATE": "2012-12-13 10:07:51",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "GAS COMPRESSION AND RE-INJECTION ON PH",
#             "WMT_TAG_GLOBALID": "1000000000249646",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "681760",
#             "WMT_TAG_ISACTIVE": "1",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "230900",
#             "WMT_TAG_STATUSCHGDATE": "2013-05-08 12:52:26",
#             "WMT_TAG_UPDATED_BY": "8137",
#             "WMT_TAG_UPDATED_DATE": "2013-12-11 14:35:29"
#         },
#         "id": 6895991969886325,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:40:12.482+00:00",
#         "root_id": 6687602007296940
#     }
# ]

# %%
print(client.assets.search(description="ExpPress Ratio", limit=None))
# Out:
# [
#     {
#         "external_id": "WMT:23-KA-9101-EPR",
#         "name": "23-KA-9101-EPR",
#         "parent_id": 3047932288982463,
#         "parent_external_id": "WMT:23-KA-9101",
#         "description": "VRD - PH 1ST STAGE EXPPRESS RATIO",
#         "metadata": {
#             "ELC_STATUS_ID": "1211",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1600",
#             "WMT_CATEGORY_ID": "1120",
#             "WMT_CONTRACTOR_ID": "1686",
#             "WMT_FUNC_CODE_ID": "6284",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_SYSTEM_ID": "4440",
#             "WMT_TAG_CREATED_DATE": "2009-08-31 19:25:02",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "VRD - PH 1ST STAGE EXPPRESS RATIO",
#             "WMT_TAG_GLOBALID": "1000000000712756",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "358614",
#             "WMT_TAG_ID_ANCESTOR": "346064",
#             "WMT_TAG_ISACTIVE": "1",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "23-KA-9101-EPR",
#             "WMT_TAG_UPDATED_BY": "1001",
#             "WMT_TAG_UPDATED_DATE": "2015-10-08 15:05:09"
#         },
#         "id": 4451907191066263,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:39:48.409+00:00",
#         "root_id": 6687602007296940
#     },
#     {
#         "external_id": "WMT:23-KA-9101-APR",
#         "name": "23-KA-9101-APR",
#         "parent_id": 3047932288982463,
#         "parent_external_id": "WMT:23-KA-9101",
#         "description": "VRD - PH 1ST STAGE ACTPRESS RATIO",
#         "metadata": {
#             "ELC_STATUS_ID": "1211",
#             "SOURCE_DB": "workmate",
#             "SOURCE_TABLE": "wmate_dba.wmt_tag",
#             "WMT_AREA_ID": "1600",
#             "WMT_CATEGORY_ID": "1120",
#             "WMT_CONTRACTOR_ID": "1686",
#             "WMT_FUNC_CODE_ID": "6284",
#             "WMT_LOCATION_ID": "1004",
#             "WMT_SYSTEM_ID": "4440",
#             "WMT_TAG_CREATED_DATE": "2009-08-31 19:25:02",
#             "WMT_TAG_CRITICALLINE": "N",
#             "WMT_TAG_DESC": "VRD - PH 1ST STAGE ACTPRESS RATIO",
#             "WMT_TAG_GLOBALID": "1000000000712752",
#             "WMT_TAG_HISTORYREQUIRED": "Y",
#             "WMT_TAG_ID": "358610",
#             "WMT_TAG_ID_ANCESTOR": "346064",
#             "WMT_TAG_ISACTIVE": "1",
#             "WMT_TAG_ISOWNEDBYPROJECT": "0",
#             "WMT_TAG_MAINID": "681760",
#             "WMT_TAG_NAME": "23-KA-9101-APR",
#             "WMT_TAG_UPDATED_BY": "1001",
#             "WMT_TAG_UPDATED_DATE": "2015-10-08 15:05:09"
#         },
#         "id": 2350154718230402,
#         "created_time": "1970-01-01 00:00:00.000+00:00",
#         "last_updated_time": "2022-07-29 14:39:25.999+00:00",
#         "root_id": 6687602007296940
#     }
# ]

# %%
# Busca pelo ativo do compressor first stage

try:
    # 'search' retorna uma AssetList. Com limit=1, o resultado é uma lista.
    compressor_asset_list = client.assets.search(name="23-KA-9101", limit=1)

    # Verifica se está vazia
    if compressor_asset_list:
        # Pega o primeiro/único item da lista. A chamada search retorna o objeto completo.
        compressor_asset = compressor_asset_list[0]

        print(f"Ativo encontrado: {compressor_asset.name}")
        print(f"ID do Ativo: {compressor_asset.id}")
        print(f"Descrição: {compressor_asset.description}")

        # Exibindo metadados
        if compressor_asset.metadata:
            print("\nMetadados do Ativo:")
            for key, value in compressor_asset.metadata.items():
                print(f"  - {key}: {value}")
    else:
        # Se a lista estiver vazia, o ativo não foi encontrado
        compressor_asset = None # Garantimos que a variável seja None
        print("Ativo do compressor com o nome '23-KA-9101' não encontrado.")
except Exception as e:
    print(f"Ocorreu um erro ao buscar o ativo: {e}")
# Out:
# Ativo encontrado: 23-KA-9101
# ID do Ativo: 3047932288982463
# Descrição: VRD - 1ST STAGE COMPRESSOR
#
# Metadados do Ativo:
#   - ELC_STATUS_ID: 1211
#   - RES_ID: 583453
#   - SOURCE_DB: workmate
#   - SOURCE_TABLE: wmate_dba.wmt_tag
#   - WMT_AREA_ID: 1600
#   - WMT_CATEGORY_ID: 1120
#   - WMT_CONTRACTOR_ID: 1686
#   - WMT_FUNC_CODE_ID: 6284
#   - WMT_LOCATION_ID: 1004
#   - WMT_PO_ID: 8309
#   - WMT_SYSTEM_ID: 4440
#   - WMT_TAG_COMMENT: Compressor casing is designed for 170 MMSCFD.  Export capacity is limited by installed impeller set and motor (available for upgrade to full capacity)., Capacity: 143 MMSCFD Export Gas / Base Case (4): 200,561 SM3/hr, Size: RB71-5, Operating conditions: I
#   - WMT_TAG_CREATED_DATE: 2009-06-26 15:36:37
#   - WMT_TAG_CRITICALLINE: N
#   - WMT_TAG_DESC: VRD - 1ST STAGE COMPRESSOR
#   - WMT_TAG_GLOBALID: 1000000000707341
#   - WMT_TAG_HISTORYREQUIRED: Y
#   - WMT_TAG_ID: 346064
#   - WMT_TAG_ID_ANCESTOR: 346906
#   - WMT_TAG_ISACTIVE: 1
#   - WMT_TAG_ISOWNEDBYPROJECT: 0
#   - WMT_TAG_MAINID: 681760
#   - WMT_TAG_NAME: 23-KA-9101
#   - WMT_TAG_STATUSCHGDATE: 2017-05-05 09:41:21
#   - WMT_TAG_UPDATED_BY: 8137
#   - WMT_TAG_UPDATED_DATE: 2017-05-05 09:41:21

# %% [markdown]
# ### 4. Explorar Documentos Associados (P&ID)

# %%
# Verifica se o ativo do compressor foi encontrado na célula anterior
if 'compressor_asset' in locals() and compressor_asset:
    try:
        # Cria o diretório para os P&IDs, se não existir
        os.makedirs("./pids", exist_ok=True)

        # Lista os arquivos associados ao ativo, filtrando por PDF (comum para P&IDs)
        pid_files = client.files.list(asset_ids=[compressor_asset.id], mime_type="application/pdf", limit=None)

        if pid_files:
            print(f"\nEncontrados {len(pid_files)} arquivos P&ID (PDF) para o compressor.")

            for pid in pid_files:
                print(f"Baixando '{pid.name}'...")
                download_path = f"./pids/{pid.name}"
                client.files.download_to_path(path=download_path, id=pid.id)
                print(f"Arquivo '{pid.name}' baixado com sucesso.")
        else:
            print("Nenhum arquivo P&ID (PDF) encontrado para este ativo.")

    except Exception as e:
        print(f"Ocorreu um erro ao buscar os P&IDs: {e}")
else:
    print("Ativo do compressor não encontrado.")
# Out:
# Encontrados 4 arquivos P&ID (PDF) para o compressor.
# Baixando 'PH-ME-P-0156-002.pdf'...
# Arquivo 'PH-ME-P-0156-002.pdf' baixado com sucesso.
# Baixando 'PH-ME-P-0003-001.pdf'...
# Arquivo 'PH-ME-P-0003-001.pdf' baixado com sucesso.
# Baixando 'PH-ME-P-0153-001.pdf'...
# Arquivo 'PH-ME-P-0153-001.pdf' baixado com sucesso.
# Baixando 'PH-25578-P-4110010-001.pdf'...
# Arquivo 'PH-25578-P-4110010-001.pdf' baixado com sucesso.

# %% [markdown]
# ### 5. Análise de Séries Temporais

# %% [markdown]
# #### 5.1. Listar Séries Temporais e Mapear Nomes

# %%
id_to_description = {}

if 'compressor_asset' in locals() and compressor_asset:
    try:
        ts_list = client.time_series.list(asset_ids=[compressor_asset.id], limit=None)

        if ts_list:
            print(f"\nTotal de {len(ts_list)} séries temporais encontradas para o compressor.")
            df_ts_info = ts_list.to_pandas()
            print("\nAmostra das séries temporais disponíveis:")
            display(df_ts_info[['name', 'external_id', 'description', 'unit']])

            # Criar dicionário para mapeamento
            id_to_description = {ts.external_id: ts.description for ts in ts_list if ts.description}

            print("\nMapeamento de IDs para Descrições (Amostra):")
            for i, (ext_id, desc) in enumerate(id_to_description.items()):
                if i >= 12: break
                print(f"  - {ext_id}: {desc}")
        else:
            df_ts_info = pd.DataFrame()
            print("\nNenhuma série temporal encontrada para este ativo.")
    except Exception as e:
        print(f"Ocorreu um erro ao listar as séries temporais: {e}")
else:
    print("Ativo do compressor não encontrado. Pule a listagem de séries temporais.")
# Out:
# Total de 12 séries temporais encontradas para o compressor.
#
# Amostra das séries temporais disponíveis:
#                         name external_id  \
# 0   VAL_23-KA-9101_EPR:VALUE   pi:160223
# 1   VAL_23-KA-9101_PHD:VALUE   pi:160226
# 2   VAL_23-KA-9101_ASP:VALUE   pi:160220
# 3   VAL_23-KA-9101_PRD:VALUE   pi:160227
# 4   VAL_23-KA-9101_APH:VALUE   pi:160218
# 5   VAL_23-KA-9101_PED:VALUE   pi:160225
# 6   VAL_23-KA-9101_SPD:VALUE   pi:160228
# 7   VAL_23-KA-9101_APE:VALUE   pi:160217
# 8   VAL_23-KA-9101_EPE:VALUE   pi:160221
# 9   VAL_23-KA-9101_ESP:VALUE   pi:160224
# 10  VAL_23-KA-9101_APR:VALUE   pi:160219
# 11  VAL_23-KA-9101_EPH:VALUE   pi:160222
#
#                              description   unit
# 0      PH (CBM) 1st Stage ExpPress Ratio    NaN
# 1       PH (CBM) 1st Stage Poly Head Dev    NaN
# 2      PH (CBM) 1st Stage ActShaft Power     kw
# 3       PH (CBM) 1st Stage Press Rat Dev      %
# 4    PH (CBM) 1st Stg ActCompr Poly Head    NaN
# 5        PH (CBM) 1st Stage Poly Eff Dev    NaN
# 6        PH (CBM) 1st Stage Shft Pwr Dev    NaN
# 7   PH (CBM) 1st Stage ActCompr Poly Eff    NaN
# 8   PH (CBM) 1st Stage ExpCompr Poly Eff    NaN
# 9      PH (CBM) 1st Stage ExpShaft Power     kw
# 10     PH (CBM) 1st Stage ActPress Ratio  ratio
# 11   PH (CBM) 1st Stg ExpCompr Poly Head    NaN
# Mapeamento de IDs para Descrições (Amostra):
#   - pi:160223: PH (CBM) 1st Stage ExpPress Ratio
#   - pi:160226: PH (CBM) 1st Stage Poly Head Dev
#   - pi:160220: PH (CBM) 1st Stage ActShaft Power
#   - pi:160227: PH (CBM) 1st Stage Press Rat Dev
#   - pi:160218: PH (CBM) 1st Stg ActCompr Poly Head
#   - pi:160225: PH (CBM) 1st Stage Poly Eff Dev
#   - pi:160228: PH (CBM) 1st Stage Shft Pwr Dev
#   - pi:160217: PH (CBM) 1st Stage ActCompr Poly Eff
#   - pi:160221: PH (CBM) 1st Stage ExpCompr Poly Eff
#   - pi:160224: PH (CBM) 1st Stage ExpShaft Power
#   - pi:160219: PH (CBM) 1st Stage ActPress Ratio
#   - pi:160222: PH (CBM) 1st Stg ExpCompr Poly Head

# %% [markdown]
# #### 5.2. Recuperar Dados das Séries Temporais

# %%
df_data = pd.DataFrame()

# Verifica se o DataFrame de informações de séries temporais da célula anterior existe e não está vazio
if 'df_ts_info' in locals() and not df_ts_info.empty:
    # Seleciona dinamicamente TODOS os external_id da lista de séries temporais do ativo
    external_ids_interesse = df_ts_info['external_id'].tolist()

    try:
        print(f"\nBuscando dados para as {len(external_ids_interesse)} séries temporais encontradas.")

        # Define o período de tempo para a análise usando objetos datetime.
        start_time = datetime(2019, 9, 1) # Tempo disponível no dataset (3 meses)
        end_time = datetime(2019, 12, 1)

        # Recupera os dados com uma granularidade de 5 minutos
        df_data = client.time_series.data.retrieve_dataframe(
            external_id=external_ids_interesse,
            start=start_time,
            end=end_time, # Período de 3 meses
            granularity="2s", # 5 minutos entre cada ponto de dados
            aggregates=["average"], # Média para granulidade
            ignore_unknown_ids=True # Ignora IDs não encontrados
        )

        # Renomeia as colunas para remover o sufixo do agregado e usar a descrição
        df_data.columns = [col.split('|')[0] for col in df_data.columns]
        df_data_descriptive = df_data.rename(columns=id_to_description)

        if not df_data_descriptive.empty:
            print("\nDados recuperados com sucesso! Colunas renomeadas para melhor legibilidade.")
            display(df_data_descriptive.head())
        else:
            print("\nNão foi possível recuperar dados para os IDs selecionados.")
    except Exception as e:
        print(f"Ocorreu um erro ao recuperar os dados: {e}")
else:
    print("Nenhuma informação de série temporal encontrada.")
# Out:
# Buscando dados para as 12 séries temporais encontradas.
#
# Dados recuperados com sucesso! Colunas renomeadas para melhor legibilidade.
#                      PH (CBM) 1st Stage ExpPress Ratio  \
# 2019-09-01 03:00:16                           2.456634
# 2019-09-01 03:00:46                           2.759697
# 2019-09-01 03:01:16                           2.790394
# 2019-09-01 03:01:46                           2.687855
# 2019-09-01 03:02:16                           2.883779
#
#                      PH (CBM) 1st Stage Poly Head Dev  \
# 2019-09-01 03:00:16                         45.805852
# 2019-09-01 03:00:46                         27.699256
# 2019-09-01 03:01:16                         26.776273
# 2019-09-01 03:01:46                         32.325390
# 2019-09-01 03:02:16                         23.333442
#
#                      PH (CBM) 1st Stage ActShaft Power  \
# 2019-09-01 03:00:16                        9958.569963
# 2019-09-01 03:00:46                        9668.425164
# 2019-09-01 03:01:16                        9451.902760
# 2019-09-01 03:01:46                        9694.464210
# 2019-09-01 03:02:16                        9341.617943
#
#                      PH (CBM) 1st Stage Press Rat Dev  \
# 2019-09-01 03:00:16                         47.197033
# 2019-09-01 03:00:46                         31.174316
# 2019-09-01 03:01:16                         30.580677
# 2019-09-01 03:01:46                         36.000144
# 2019-09-01 03:02:16                         27.574142
#
#                      PH (CBM) 1st Stg ActCompr Poly Head  \
# 2019-09-01 03:00:16                           164.911430
# 2019-09-01 03:00:46                           164.883598
# 2019-09-01 03:01:16                           165.711263
# 2019-09-01 03:01:46                           166.057506
# 2019-09-01 03:02:16                           166.865335
#
#                      PH (CBM) 1st Stage Poly Eff Dev  \
# 2019-09-01 03:00:16                              NaN
# 2019-09-01 03:00:46                              NaN
# 2019-09-01 03:01:16                              NaN
# 2019-09-01 03:01:46                              NaN
# 2019-09-01 03:02:16                              NaN
#
#                      PH (CBM) 1st Stage Shft Pwr Dev  \
# 2019-09-01 03:00:16                        23.392063
# 2019-09-01 03:00:46                        16.258794
# 2019-09-01 03:01:16                        15.160198
# 2019-09-01 03:01:46                        17.569377
# 2019-09-01 03:02:16                        13.026628
#
#                      PH (CBM) 1st Stage ActCompr Poly Eff  \
# 2019-09-01 03:00:16                             84.924300
# 2019-09-01 03:00:46                             85.298456
# 2019-09-01 03:01:16                             85.971392
# 2019-09-01 03:01:46                             86.240174
# 2019-09-01 03:02:16                             86.594766
#
#                      PH (CBM) 1st Stage ExpCompr Poly Eff  \
# 2019-09-01 03:00:16                             71.880656
# 2019-09-01 03:00:46                             77.669125
# 2019-09-01 03:01:16                             78.092475
# 2019-09-01 03:01:46                             76.625686
# 2019-09-01 03:02:16                             79.361364
#
#                      PH (CBM) 1st Stage ExpShaft Power  \
# 2019-09-01 03:00:16                        8070.759442
# 2019-09-01 03:00:46                        8317.204760
# 2019-09-01 03:01:16                        8207.480677
# 2019-09-01 03:01:46                        8245.924425
# 2019-09-01 03:02:16                        8265.644980
#
#                      PH (CBM) 1st Stage ActPress Ratio  \
# 2019-09-01 03:00:16                           3.615265
# 2019-09-01 03:00:46                           3.619116
# 2019-09-01 03:01:16                           3.643826
# 2019-09-01 03:01:46                           3.655214
# 2019-09-01 03:02:16                           3.678543
#
#                      PH (CBM) 1st Stg ExpCompr Poly Head
# 2019-09-01 03:00:16                           113.136062
# 2019-09-01 03:00:46                           129.159221
# 2019-09-01 03:01:16                           130.708173
# 2019-09-01 03:01:46                           125.502683
# 2019-09-01 03:02:16                           135.314128

# %% [markdown]
# ### 6. Análise Exploratória dos Dados (EDA)
#
# Com os dados coletados e as colunas renomeadas, podemos realizar uma análise mais clara e informativa.

# %% [markdown]
# #### 6.1. Informações e Estatísticas Descritivas

# %%
if not df_data_descriptive.empty:
    print("Informações Gerais do DataFrame:")
    df_data_descriptive.info()

    print("\n\nEstatísticas Descritivas:")
    display(df_data_descriptive.describe())
else:
    print("DataFrame de dados está vazio.")
# Out:
# Informações Gerais do DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 269839 entries, 2019-09-01 03:00:16 to 2019-12-01 02:59:44
# Data columns (total 12 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   PH (CBM) 1st Stage ExpPress Ratio     257255 non-null  float64
#  1   PH (CBM) 1st Stage Poly Head Dev      257253 non-null  float64
#  2   PH (CBM) 1st Stage ActShaft Power     257236 non-null  float64
#  3   PH (CBM) 1st Stage Press Rat Dev      257260 non-null  float64
#  4   PH (CBM) 1st Stg ActCompr Poly Head   257217 non-null  float64
#  5   PH (CBM) 1st Stage Poly Eff Dev       0 non-null       float64
#  6   PH (CBM) 1st Stage Shft Pwr Dev       257262 non-null  float64
#  7   PH (CBM) 1st Stage ActCompr Poly Eff  257216 non-null  float64
#  8   PH (CBM) 1st Stage ExpCompr Poly Eff  257223 non-null  float64
#  9   PH (CBM) 1st Stage ExpShaft Power     257252 non-null  float64
#  10  PH (CBM) 1st Stage ActPress Ratio     257061 non-null  float64
#  11  PH (CBM) 1st Stg ExpCompr Poly Head   257258 non-null  float64
# dtypes: float64(12)
# memory usage: 26.8 MB
#
#
# Estatísticas Descritivas:
#        PH (CBM) 1st Stage ExpPress Ratio  PH (CBM) 1st Stage Poly Head Dev  \
# count                      257255.000000                     257253.000000
# mean                            3.076307                         14.520669
# std                             0.179577                          7.287387
# min                             0.000000                        -50.689212
# 25%                             2.995667                          9.168954
# 50%                             3.110276                         13.412327
# 75%                             3.196055                         18.339821
# max                             3.438750                         98.038000
#
#        PH (CBM) 1st Stage ActShaft Power  PH (CBM) 1st Stage Press Rat Dev  \
# count                      257236.000000                     257260.000000
# mean                         9104.748515                         18.471073
# std                           464.143433                          7.521333
# min                          -494.728680                        -37.411146
# 25%                          8870.935623                         12.919221
# 50%                          9086.923283                         17.638435
# 75%                          9319.782020                         22.727275
# max                         13490.593928                         89.471926
#
#        PH (CBM) 1st Stg ActCompr Poly Head  PH (CBM) 1st Stage Poly Eff Dev  \
# count                        257217.000000                              0.0
# mean                            164.708772                              NaN
# std                               5.609775                              NaN
# min                               0.000000                              NaN
# 25%                             163.009630                              NaN
# 50%                             164.896875                              NaN
# 75%                             166.831316                              NaN
# max                             176.638488                              NaN
#
#        PH (CBM) 1st Stage Shft Pwr Dev  PH (CBM) 1st Stage ActCompr Poly Eff  \
# count                    257262.000000                         257216.000000
# mean                          9.840381                             83.518240
# std                           3.985381                             12.106087
# min                        -104.442267                           -742.348504
# 25%                           6.998704                             82.141883
# 50%                           9.219533                             83.467486
# 75%                          12.245757                             84.896949
# max                          34.117310                           5879.049525
#
#        PH (CBM) 1st Stage ExpCompr Poly Eff  \
# count                         257223.000000
# mean                              80.171772
# std                                2.568145
# min                                0.000000
# 25%                               80.335574
# 50%                               80.667845
# 75%                               80.806424
# max                               80.873058
#
#        PH (CBM) 1st Stage ExpShaft Power  PH (CBM) 1st Stage ActPress Ratio  \
# count                      257252.000000                      257061.000000
# mean                         8290.870876                           3.633772
# std                           357.941311                           0.128815
# min                             0.000000                           0.000000
# 25%                          8125.594702                           3.589597
# 50%                          8276.866840                           3.639629
# 75%                          8443.368370                           3.687220
# max                         11967.419481                           3.957146
#
#        PH (CBM) 1st Stg ExpCompr Poly Head
# count                        257258.000000
# mean                            144.266041
# std                               8.456894
# min                               0.000000
# 25%                             140.683485
# 50%                             145.987586
# 75%                             149.842072
# max                             159.482564

# %% [markdown]
# #### 6.2. Visualização dos Dados

# %% [markdown]
# **a) Gráfico das Séries Temporais**

# %%
if not df_data_descriptive.empty:
    # Interpola valores nulos para melhor visualização
    df_plot = df_data_descriptive.interpolate()
    df_plot.plot(figsize=(15, 12), subplots=True, layout=(-1, 2), sharex=True, grid=True)
    plt.suptitle("Séries Temporais do Compressor", y=0.92, fontsize=16)
    plt.tight_layout(rect=[0, 0, 1, 0.9]) # Ajuste de layout para evitar sobreposição do título
    plt.show()
else:
    print("DataFrame de dados está vazio.")

# %% [markdown]
# **b) Distribuição das Variáveis (Histogramas)**

# %%
if not df_data_descriptive.empty:
    df_data_descriptive.hist(figsize=(12, 10), bins=50, layout=(-1, 3), sharex=False, sharey=False)
    plt.suptitle("Histogramas de Distribuição dos Sensores", y=1.02, fontsize=16)
    plt.tight_layout()
    plt.show()
else:
    print("DataFrame de dados está vazio.")

# %% [markdown]
# **c) Matriz de Correlação**

# %%
if not df_data_descriptive.empty:
    # Renomeia colunas para serem mais curtas para o gráfico de correlação
    correlation_df = df_data.rename(columns=lambda c: c.replace('PH (CBM)', '').replace(':VALUE', ''))
    # Usamos os nomes descritivos para a matriz de correlação
    correlation_matrix = df_data_descriptive.corr()

    plt.figure(figsize=(12, 10))
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
    plt.title("Matriz de Correlação")
    plt.show()
else:
    print("DataFrame de dados está vazio.")

# %% [markdown]
# #### 6.3. Análise Exploratória Adicional (Gemini)
#
# Para aprofundar a análise, técnicas adicionais foram incluídas pelo Gemini para entender a distribuição dos dados e suas tendências temporais.
#
# * **Box Plots:** Ajudam a identificar a dispersão, a mediana e os outliers em cada sensor, oferecendo uma visão clara da variabilidade.
# * **Estatísticas Móveis:** O cálculo da média e do desvio padrão em janelas de tempo deslizantes revela tendências e mudanças na volatilidade dos sinais, que são difíceis de perceber em gráficos estáticos.
# * **Gráficos Interativos:** Permitem uma exploração mais detalhada e flexível dos dados, com zoom e informações pontuais.

# %% [markdown]
# **d) Box Plots para Distribuição e Outliers**

# %%
if not df_data_descriptive.empty:
    # Usa o dataframe com nomes descritivos
    df_melt = df_data_descriptive.drop(columns=['PH (CBM) 1st Stage Poly Eff Dev']).melt() # Remove a coluna vazia

    fig = px.box(df_melt, x='variable', y='value', color='variable',
                 title="Distribuição e Outliers por Sensor")
    fig.update_xaxes(title_text="Sensor")
    fig.update_yaxes(title_text="Valor")
    fig.show()
else:
    print("DataFrame de dados está vazio.")

# %% [markdown]
# **e) Análise de Tendências com Estatísticas Móveis**

# %%
power_sensor = 'PH (CBM) 1st Stage ActShaft Power' # Usando o nome descritivo
if power_sensor in df_data_descriptive.columns:
    window = 288 # Janela de 1 dia (288 pontos de 5min)

    rolling_mean = df_data_descriptive[power_sensor].rolling(window=window).mean()
    rolling_std = df_data_descriptive[power_sensor].rolling(window=window).std()

    plt.figure(figsize=(15, 7))
    plt.title(f'Média e Desvio Padrão Móveis para: {power_sensor}')
    plt.plot(df_data_descriptive.index, df_data_descriptive[power_sensor], label='Original', color='gray', alpha=0.5)
    plt.plot(rolling_mean, label='Média Móvel', color='blue')
    plt.plot(rolling_std, label='Desvio Padrão Móvel', color='red')
    plt.legend()
    plt.show()
else:
    print(f"A coluna '{power_sensor}' não foi encontrada.")

# %% [markdown]
# **f) Gráfico Interativo das Séries Temporais**

# %%
if not df_data_descriptive.empty:
    fig = px.line(df_data_descriptive.interpolate(), title='Séries Temporais Interativas do Compressor')
    fig.update_xaxes(title_text="Data e Hora")
    fig.update_yaxes(title_text="Valor do Sensor")
    fig.show()
else:
    print("DataFrame de dados está vazio.")

# %% [markdown]
# ---

# %% [markdown]
# ## Fase 2: Pré-processamento e Construção do Modelo

# %% [markdown]
# ### 7. Pré-processamento dos Dados

# %%
if not df_data_descriptive.empty:
    # 1. Tratamento de valores ausentes e seleção de colunas
    df_processed = df_data_descriptive.drop(columns=['PH (CBM) 1st Stage Poly Eff Dev']) # Coluna vazia

    #df_processed.ffill(inplace=True)
    #df_processed.bfill(inplace=True)

    print(f"Total de valores nulos após tratamento: {df_processed.isnull().sum().sum()}")

    # 2. Escalonamento dos dados
    scaler = RobustScaler()
    df_scaled = pd.DataFrame(scaler.fit_transform(df_processed), columns=df_processed.columns, index=df_processed.index)

else:
    print("DataFrame de dados está vazio.")
# Out:
# Total de valores nulos após tratamento: 138736

# %%
df_scaled.describe()
# Out:
#        PH (CBM) 1st Stage ExpPress Ratio  PH (CBM) 1st Stage Poly Head Dev  \
# count                      257255.000000                     257253.000000
# mean                           -0.169514                          0.120855
# std                             0.896149                          0.794624
# min                           -15.521274                         -6.989692
# 25%                            -0.571935                         -0.462701
# 50%                             0.000000                          0.000000
# 75%                             0.428065                          0.537299
# max                             1.639192                          9.227663
#
#        PH (CBM) 1st Stage ActShaft Power  PH (CBM) 1st Stage Press Rat Dev  \
# count                      257236.000000                      2.572600e+05
# mean                            0.039713                      8.489324e-02
# std                             1.034081                      7.668528e-01
# min                           -21.347285                     -5.612692e+00
# 25%                            -0.481206                     -4.811570e-01
# 50%                             0.000000                      1.811126e-16
# 75%                             0.518794                      5.188430e-01
# max                             9.811086                      7.323929e+00
#
#        PH (CBM) 1st Stg ActCompr Poly Head  PH (CBM) 1st Stage Shft Pwr Dev  \
# count                        257217.000000                    257262.000000
# mean                             -0.049220                         0.118323
# std                               1.467879                         0.759546
# min                             -43.147670                       -21.662024
# 25%                              -0.493825                        -0.423253
# 50%                               0.000000                         0.000000
# 75%                               0.506175                         0.576747
# max                               3.072364                         4.745097
#
#        PH (CBM) 1st Stage ActCompr Poly Eff  \
# count                          2.572160e+05
# mean                           1.842197e-02
# std                            4.394119e+00
# min                           -2.997446e+02
# 25%                           -4.811512e-01
# 50%                           -2.579041e-15
# 75%                            5.188488e-01
# max                            2.103609e+03
#
#        PH (CBM) 1st Stage ExpCompr Poly Eff  \
# count                         257223.000000
# mean                              -1.053567
# std                                5.454269
# min                             -171.323708
# 25%                               -0.705682
# 50%                                0.000000
# 75%                                0.294318
# max                                0.435837
#
#        PH (CBM) 1st Stage ExpShaft Power  PH (CBM) 1st Stage ActPress Ratio  \
# count                       2.572520e+05                      257061.000000
# mean                        4.406921e-02                          -0.060002
# std                         1.126403e+00                           1.319511
# min                        -2.604642e+01                         -37.282463
# 25%                        -4.760374e-01                          -0.512509
# 50%                        -2.862083e-15                           0.000000
# 75%                         5.239626e-01                           0.487491
# max                         1.161378e+01                           3.252479
#
#        PH (CBM) 1st Stg ExpCompr Poly Head
# count                         2.572580e+05
# mean                         -1.879705e-01
# std                           9.233841e-01
# min                          -1.593997e+01
# 25%                          -5.791396e-01
# 50%                           1.551642e-15
# 75%                           4.208604e-01
# max                           1.473478e+00

# %% [markdown]
# ### 8. Análise de janela ideal

# %%
acf_values = acf(df_scaled['PH (CBM) 1st Stage ExpPress Ratio'], nlags=100, fft=True)
lags = np.arange(len(acf_values))

plt.figure(figsize=(10, 5))
markerline, stemlines, baseline = plt.stem(lags, acf_values)
plt.setp(markerline, 'markerfacecolor', 'blue')  # cor padrão

# Destacar lag=30
plt.scatter(30, acf_values[30], color='red', s=100, zorder=3, label='Lag 30')

plt.title('Função de Autocorrelação (ACF) - PH (CBM) 1st Stage ExpPress Ratio')
plt.xlabel('Lags')
plt.ylabel('Autocorrelação')
plt.grid()
plt.legend()
plt.show()

# %%
acf_values
# Out:
# array([1.        , 0.86572344, 0.79857837, 0.77295138, 0.7405092 ,
#        0.72222942, 0.71416467, 0.70239512, 0.69431519, 0.69026236,
#        0.68701246, 0.68658659, 0.68735286, 0.68588506, 0.68466143,
#        0.68381952, 0.682724  , 0.68113859, 0.67871776, 0.67668146,
#        0.67482642, 0.67085144, 0.66730393, 0.66390432, 0.66097039,
#        0.65691328, 0.65332821, 0.65019595, 0.64668769, 0.64260064,
#        0.63922844, 0.63592973, 0.63307379, 0.63032302, 0.6289309 ,
#        0.62764192, 0.6271863 , 0.62668784, 0.62645679, 0.62614562,
#        0.62435482, 0.62267467, 0.6205257 , 0.61784182, 0.6150619 ,
#        0.61113755, 0.60821716, 0.60485083, 0.60235104, 0.5985684 ,
#        0.59536669, 0.59281485, 0.59040135, 0.58775386, 0.58568386,
#        0.58383828, 0.58276894, 0.58186883, 0.58093602, 0.57938368,
#        0.57718194, 0.57458691, 0.57128159, 0.56929879, 0.56791142,
#        0.56584464, 0.56503909, 0.56360576, 0.56255356, 0.56174492,
#        0.56071002, 0.55932568, 0.55850665, 0.55795256, 0.55637375,
#        0.55596218, 0.55494444, 0.55441836, 0.55440255, 0.55386423,
#        0.55346045, 0.55282183, 0.55187278, 0.54993535, 0.54858013,
#        0.5458483 , 0.54371906, 0.54175742, 0.53941996, 0.53708328,
#        0.53503574, 0.53311061, 0.5316829 , 0.53100064, 0.5301195 ,
#        0.5287907 , 0.52827076, 0.52753938, 0.52682968, 0.52639568,
#        0.5254377 ])

# %% [markdown]
# ### 9. Segmentação de estados

# %%
import sys
sys.path.append('/root/coppe/tp_esp_ap_mq/CPE883-2025-02/models')

# %%
from tsdiffusion_transformed.segmenter import UnsupervisedStateSegmenter
import importlib
#importlib.reload(sys.modules['tsdiffusion_transformed.segmenter'])
# Out:
# Updated: UnsupervisedStateSegmenter now supports multi-channel (multivariate) series.

# %% [markdown]
# ### 9.1 6 estados

# %%
seg = UnsupervisedStateSegmenter(k_states=6, window=30, step=30, device='cuda', min_slice_windows=30)
seg.fit(df_processed)
res = seg.predict(df_processed)

# %%
seg.save("cognite_segmenter.pkl")

# %%
seg = UnsupervisedStateSegmenter(k_states=6, window=30, step=30, device='cuda', min_slice_windows=30)
seg = seg.load("cognite_segmenter.pkl")
res = seg.predict(df_processed)

# %%
series = np.asarray(df_processed['PH (CBM) 1st Stage ExpPress Ratio'])  # sua série original
idx = res["window_indices"]  # lista de (start, end) das janelas
states = res["states_per_window"]       # estado por janela
k = len(np.unique(states))   # número de estados únicos

plt.figure(figsize=(14, 5))

for (start, end), state in zip(idx, states):
    plt.plot(
        range(start, end),
        series[start:end],
        label=f"Estado {state}",
        color=plt.cm.tab10(state % 10)  # cores automáticas
    )

plt.title("Segmentação em 6 Estados - PH (CBM) 1st Stage ExpPress Ratio")
plt.xlabel("Tempo")
plt.ylabel("Valor")
# legenda compacta sem duplicados
handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys(), ncol=k)
plt.show()
# Out:
# /root/coppe/3Wve/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### 9.2 5 estados

# %%
seg = UnsupervisedStateSegmenter(k_states=5, window=30, step=30, device='cuda', min_slice_windows=30)
seg.fit(df_processed)
res = seg.predict(df_processed)

# %%
series = np.asarray(df_processed['PH (CBM) 1st Stage ExpPress Ratio'])  # sua série original
idx = res["window_indices"]  # lista de (start, end) das janelas
states = res["states_per_window"]       # estado por janela
k = len(np.unique(states))   # número de estados únicos

plt.figure(figsize=(14, 5))

for (start, end), state in zip(idx, states):
    plt.plot(
        range(start, end),
        series[start:end],
        label=f"Estado {state}",
        color=plt.cm.tab10(state % 10)  # cores automáticas
    )

plt.title("Segmentação em 5 Estados - PH (CBM) 1st Stage ExpPress Ratio")
plt.xlabel("Tempo")
plt.ylabel("Valor")
# legenda compacta sem duplicados
handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys(), ncol=k)
plt.show()
# Out:
# /root/coppe/3Wve/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning:
#
# Creating legend with loc="best" can be slow with large amounts of data.

# %% [markdown]
# ### 9.3 7 estados

# %%
seg = UnsupervisedStateSegmenter(k_states=7, window=30, step=30, device='cuda', min_slice_windows=30)
seg.fit(df_processed)
res = seg.predict(df_processed)

# %%
series = np.asarray(df_processed['PH (CBM) 1st Stage ExpPress Ratio'])  # sua série original
idx = res["window_indices"]  # lista de (start, end) das janelas
states = res["states_per_window"]       # estado por janela
k = len(np.unique(states))   # número de estados únicos

plt.figure(figsize=(14, 5))

for (start, end), state in zip(idx, states):
    plt.plot(
        range(start, end),
        series[start:end],
        label=f"Estado {state}",
        color=plt.cm.tab10(state % 10)  # cores automáticas
    )

plt.title("Segmentação em 7 Estados - PH (CBM) 1st Stage ExpPress Ratio")
plt.xlabel("Tempo")
plt.ylabel("Valor")
# legenda compacta sem duplicados
handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys(), ncol=k)
plt.show()
# Out:
# /root/coppe/3Wve/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning:
#
# Creating legend with loc="best" can be slow with large amounts of data.

# %%
res.keys()
# Out:
# dict_keys(['window_indices', 'features', 'features_z', 'states', 'loglike_per_window', 'anomaly_state', 'anomaly_mask', 'slices', 'feature_names'])

# %% [markdown]
# ### 10 Preprocessamento

# %%
df_scaled = df_scaled[:len(res['states'])]
df_scaled['states'] = res['states']
df_scaled['states'].replace(2, 1, inplace=True) # Merge states 1 and 2
df_scaled['states'].replace(3, 1, inplace=True)
df_scaled['states'].replace(4, 1, inplace=True)  
df_scaled['states'].replace(6, 1, inplace=True)
# Out:
# /tmp/ipykernel_1128/644231126.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_scaled['states'].replace(2, 1, inplace=True) # Merge states 1 and 2
# /tmp/ipykernel_1128/644231126.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_scaled['states'].replace(3, 1, inplace=True)
# /tmp/ipykernel_1128/644231126.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_scaled['states'].replace(4, 1, inplace=True)
# /tmp/ipykernel_1128/644231126.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_scaled['states'].replace(6, 1, inplace=True)

# %%
importlib.reload(sys.modules['tsdiffusion_transformed.lstm'])
importlib.reload(sys.modules['tsdiffusion_transformed.ode_jump'])
from tsdiffusion_transformed.ode_jump import ODEJump
from tsdiffusion_transformed.lstm import TS_LSTM

# %% [markdown]
# ### 11. LSTM e ODEJump

# %%
lstm = TS_LSTM(
    in_channels=11,
    hidden_dim=11*32,
    denoised=True,
    cost_columns=[
        'PH (CBM) 1st Stg ActCompr Poly Head',
        'PH (CBM) 1st Stage ActShaft Power',
        'PH (CBM) 1st Stg ActCompr Poly Head',
        'PH (CBM) 1st Stage ActPress Ratio'
        ],
)

# %%
res_lstm = lstm.train_cognite(
    df=df_scaled,
    feature_cols=list(df_scaled.columns[:-1]),
    static_features_cols=None,
    timestamp_col='index',
    states_col='states',
    batch_size=256,
    window_size=30,
    window_step=30,
    epochs = 300,
    validate=False
)
res_lstm = [r for r in res_lstm if r is not None]  # remove None results
# Out:
# GRUPOS (total): {0: 3886, 1: 15, 5: 5093}
# GRUPOS (train): {0: 3109, 1: 12, 5: 4074}
# GRUPOS (test):  {0: 777, 1: 3, 5: 1019}
# Epoch 1/300 | Train(sampled) L1:43.427495 L4:0.698891 |
#           >> Test macro:244.545627 ± 243.889680 | micro:1.338527 ± 0.691632
# Epoch 2/300 | Train(sampled) L1:39.671923 L4:0.667040 |
#           >> Test macro:240.940004 ± 240.288076 | micro:1.322030 ± 0.681418
# Epoch 3/300 | Train(sampled) L1:42.790637 L4:0.593507 |
#           >> Test macro:236.018546 ± 235.369712 | micro:1.300672 ± 0.667457
# Epoch 4/300 | Train(sampled) L1:40.577115 L4:0.483269 |
#           >> Test macro:229.961358 ± 229.320511 | micro:1.270712 ± 0.650275
# Epoch 5/300 | Train(sampled) L1:41.141251 L4:0.366656 |
#           >> Test macro:223.157482 ± 222.552433 | micro:1.214441 ± 0.631022
# Epoch 6/300 | Train(sampled) L1:36.685499 L4:0.276424 |
#           >> Test macro:216.202901 ± 215.712198 | micro:1.089184 ± 0.611528
# Epoch 7/300 | Train(sampled) L1:37.097619 L4:0.208313 |
#           >> Test macro:209.501806 ± 209.069304 | micro:1.016579 ± 0.592657
# Epoch 8/300 | Train(sampled) L1:35.292270 L4:0.175541 |
#           >> Test macro:203.706067 ± 203.305354 | micro:0.970902 ± 0.576309
# Epoch 9/300 | Train(sampled) L1:33.880629 L4:0.155915 |
#           >> Test macro:198.055248 ± 197.675365 | micro:0.935275 ± 0.560346
# Epoch 10/300 | Train(sampled) L1:33.362551 L4:0.147717 |
#           >> Test macro:192.416495 ± 192.049721 | micro:0.906821 ± 0.544411
# Epoch 11/300 | Train(sampled) L1:31.095222 L4:0.141569 |
#           >> Test macro:186.453758 ± 186.106260 | micro:0.871333 ± 0.527551
# Epoch 12/300 | Train(sampled) L1:29.148701 L4:0.135158 |
#           >> Test macro:179.971457 ± 179.639720 | micro:0.837588 ± 0.509232
# Epoch 13/300 | Train(sampled) L1:30.001481 L4:0.128730 |
#           >> Test macro:172.777256 ± 172.452933 | micro:0.809784 ± 0.488877
# Epoch 14/300 | Train(sampled) L1:28.971334 L4:0.121700 |
#           >> Test macro:165.438042 ± 165.123370 | micro:0.779301 ± 0.468139
# Epoch 15/300 | Train(sampled) L1:27.739617 L4:0.114557 |
#           >> Test macro:158.012148 ± 157.710608 | micro:0.745981 ± 0.447106
# Epoch 16/300 | Train(sampled) L1:26.456539 L4:0.106451 |
#           >> Test macro:150.383749 ± 150.088748 | micro:0.717282 ± 0.425543
# Epoch 17/300 | Train(sampled) L1:23.884323 L4:0.096689 |
#           >> Test macro:143.037837 ± 142.749375 | micro:0.690061 ± 0.404762
# Epoch 18/300 | Train(sampled) L1:22.661037 L4:0.087519 |
#           >> Test macro:134.385426 ± 134.106036 | micro:0.656848 ± 0.380277
# Epoch 19/300 | Train(sampled) L1:20.935347 L4:0.077510 |
#           >> Test macro:126.312224 ± 126.032592 | micro:0.633237 ± 0.357429
# Epoch 20/300 | Train(sampled) L1:20.464393 L4:0.066792 |
#           >> Test macro:117.847302 ± 117.574317 | micro:0.603372 ± 0.333509
# Epoch 21/300 | Train(sampled) L1:19.283878 L4:0.058741 |
#           >> Test macro:109.031508 ± 108.767224 | micro:0.569093 ± 0.308578
# Epoch 22/300 | Train(sampled) L1:17.284084 L4:0.051396 |
#           >> Test macro:100.376116 ± 100.110009 | micro:0.545557 ± 0.284114
# Epoch 23/300 | Train(sampled) L1:16.535480 L4:0.040868 |
#           >> Test macro:91.795715 ± 91.521252 | micro:0.531287 ± 0.259775
# Epoch 24/300 | Train(sampled) L1:14.222167 L4:0.034620 |
#           >> Test macro:83.841269 ± 83.585722 | micro:0.487844 ± 0.237349
# Epoch 25/300 | Train(sampled) L1:12.473295 L4:0.029543 |
#           >> Test macro:75.726548 ± 75.471586 | micro:0.464382 ± 0.214449
# Epoch 26/300 | Train(sampled) L1:11.301983 L4:0.024275 |
#           >> Test macro:66.963683 ± 66.713274 | micro:0.434281 ± 0.189720
# Epoch 27/300 | Train(sampled) L1:10.582849 L4:0.018560 |
#           >> Test macro:59.007389 ± 58.749519 | micro:0.419891 ± 0.167267
# Epoch 28/300 | Train(sampled) L1:8.907725 L4:0.015247 |
#           >> Test macro:50.730760 ± 50.485474 | micro:0.383117 ± 0.143879
# Epoch 29/300 | Train(sampled) L1:8.176042 L4:0.011983 |
#           >> Test macro:43.328224 ± 43.083614 | micro:0.360661 ± 0.123068
# Epoch 30/300 | Train(sampled) L1:6.515877 L4:0.010049 |
#           >> Test macro:36.664472 ± 36.430686 | micro:0.331627 ± 0.104273
# Epoch 31/300 | Train(sampled) L1:5.512075 L4:0.008840 |
#           >> Test macro:30.503303 ± 30.250487 | micro:0.332010 ± 0.086903
# Epoch 32/300 | Train(sampled) L1:4.516431 L4:0.007687 |
#           >> Test macro:24.251258 ± 24.019102 | micro:0.293770 ± 0.069665
# Epoch 33/300 | Train(sampled) L1:3.591039 L4:0.006964 |
#           >> Test macro:19.740110 ± 19.508255 | micro:0.280785 ± 0.057065
# Epoch 34/300 | Train(sampled) L1:2.795231 L4:0.007046 |
#           >> Test macro:14.688731 ± 14.459074 | micro:0.263988 ± 0.043406
# Epoch 35/300 | Train(sampled) L1:2.155164 L4:0.006047 |
#           >> Test macro:10.793316 ± 10.557640 | micro:0.258655 ± 0.032924
# Epoch 36/300 | Train(sampled) L1:1.644134 L4:0.005244 |
#           >> Test macro:7.556685 ± 7.320924 | micro:0.249611 ± 0.024994
# Epoch 37/300 | Train(sampled) L1:0.997806 L4:0.004460 |
#           >> Test macro:4.839154 ± 4.608844 | micro:0.236987 ± 0.019013
# Epoch 38/300 | Train(sampled) L1:0.709160 L4:0.004086 |
#           >> Test macro:3.108278 ± 2.881614 | micro:0.228242 ± 0.015397
# Epoch 39/300 | Train(sampled) L1:0.388234 L4:0.003465 |
#           >> Test macro:1.474491 ± 1.239965 | micro:0.231215 ± 0.013674
# Epoch 40/300 | Train(sampled) L1:0.198033 L4:0.003250 |
#           >> Test macro:0.713432 ± 0.483232 | micro:0.225783 ± 0.013364
# Epoch 41/300 | Train(sampled) L1:0.098159 L4:0.002843 |
#           >> Test macro:0.302505 ± 0.088894 | micro:0.211932 ± 0.013069
# Epoch 42/300 | Train(sampled) L1:0.057561 L4:0.002680 |
#           >> Test macro:0.183788 ± 0.055432 | micro:0.223847 ± 0.012883
# Epoch 43/300 | Train(sampled) L1:0.043615 L4:0.002734 |
#           >> Test macro:0.151607 ± 0.077141 | micro:0.217168 ± 0.012657
# Epoch 44/300 | Train(sampled) L1:0.040805 L4:0.002343 |
#           >> Test macro:0.156818 ± 0.082312 | micro:0.227074 ± 0.013605
# Epoch 45/300 | Train(sampled) L1:0.040798 L4:0.002218 |
#           >> Test macro:0.145989 ± 0.076821 | micro:0.211251 ± 0.013073
# Epoch 46/300 | Train(sampled) L1:0.038929 L4:0.001853 |
#           >> Test macro:0.148805 ± 0.077628 | micro:0.215755 ± 0.012959
# Epoch 47/300 | Train(sampled) L1:0.038642 L4:0.001646 |
#           >> Test macro:0.144500 ± 0.076058 | micro:0.209202 ± 0.012791
# Epoch 48/300 | Train(sampled) L1:0.040211 L4:0.001682 |
#           >> Test macro:0.142283 ± 0.074748 | micro:0.206693 ± 0.012382
# Epoch 49/300 | Train(sampled) L1:0.040343 L4:0.001640 |
#           >> Test macro:0.156245 ± 0.071587 | micro:0.215510 ± 0.012712
# Epoch 50/300 | Train(sampled) L1:0.039685 L4:0.001480 |
#           >> Test macro:0.151172 ± 0.072451 | micro:0.213219 ± 0.012178
# Epoch 51/300 | Train(sampled) L1:0.038664 L4:0.001193 |
#           >> Test macro:0.145003 ± 0.076020 | micro:0.210799 ± 0.012032
# Epoch 52/300 | Train(sampled) L1:0.041146 L4:0.001280 |
#           >> Test macro:0.145600 ± 0.075629 | micro:0.209551 ± 0.012378
# Epoch 53/300 | Train(sampled) L1:0.039833 L4:0.001181 |
#           >> Test macro:0.141275 ± 0.073245 | micro:0.205031 ± 0.012476
# Epoch 54/300 | Train(sampled) L1:0.039208 L4:0.001153 |
#           >> Test macro:0.142476 ± 0.074173 | micro:0.207622 ± 0.011864
# Epoch 55/300 | Train(sampled) L1:0.037866 L4:0.001126 |
#           >> Test macro:0.143510 ± 0.074219 | micro:0.206383 ± 0.012409
# Epoch 56/300 | Train(sampled) L1:0.037346 L4:0.000975 |
#           >> Test macro:0.150372 ± 0.079529 | micro:0.217581 ± 0.012633
# Epoch 57/300 | Train(sampled) L1:0.038271 L4:0.001047 |
#           >> Test macro:0.146733 ± 0.075905 | micro:0.212471 ± 0.012034
# Epoch 58/300 | Train(sampled) L1:0.038142 L4:0.000941 |
#           >> Test macro:0.142214 ± 0.074649 | micro:0.206365 ± 0.012066
# Epoch 59/300 | Train(sampled) L1:0.035631 L4:0.000887 |
#           >> Test macro:0.141642 ± 0.074597 | micro:0.205606 ± 0.011792
# Epoch 60/300 | Train(sampled) L1:0.036230 L4:0.000808 |
#           >> Test macro:0.154238 ± 0.081184 | micro:0.222030 ± 0.012085
# Epoch 61/300 | Train(sampled) L1:0.035667 L4:0.000869 |
#           >> Test macro:0.142508 ± 0.074617 | micro:0.207406 ± 0.011948
# Epoch 62/300 | Train(sampled) L1:0.034479 L4:0.000754 |
#           >> Test macro:0.148674 ± 0.079394 | micro:0.215284 ± 0.012471
# Epoch 63/300 | Train(sampled) L1:0.035938 L4:0.000757 |
#           >> Test macro:0.146908 ± 0.077517 | micro:0.212070 ± 0.012207
# Early stopping at epoch 63/300 (best test macro-MSE: 0.141275 @ epoch 53)
# TEST RESULTS | macro: 0.146908 ± 0.077517 | micro: 0.212070 ± 0.012207
#           >> per_group (weighted SE): {0: '0.268500 ± 0.025649 (n=777)', 1: '0.002815 ± 0.001327 (n=3)', 5: '0.169409 ± 0.008797 (n=1019)'}

# %%
res_lstm = lstm.train_cognite(
    df=df_scaled_rebuilt,
    feature_cols=list(df_scaled.columns[:-1]),
    static_features_cols=None,
    timestamp_col='index',
    states_col='states',
    batch_size=256,
    window_size=30,
    window_step=30,
    epochs = 300,
    validate=False
)
res_lstm = [r for r in res_lstm if r is not None]  # remove None results
# Out:
# GRUPOS (total): {0: 3886, 1: 15, 5: 5093}
# GRUPOS (train): {0: 3109, 1: 12, 5: 4074}
# GRUPOS (test):  {0: 777, 1: 3, 5: 1019}
# Epoch 1/300 | Train(sampled) L1:56.242490 L4:0.691354 |
#           >> Test macro:405.451257 ± 404.785863 | micro:2.663570 ± 1.168607
# Epoch 2/300 | Train(sampled) L1:57.711808 L4:0.672278 |
#           >> Test macro:399.923585 ± 399.253668 | micro:2.637896 ± 1.152634
# Epoch 3/300 | Train(sampled) L1:57.265518 L4:0.620821 |
#           >> Test macro:391.526736 ± 390.838970 | micro:2.608084 ± 1.128338
# Epoch 4/300 | Train(sampled) L1:51.711428 L4:0.535014 |
#           >> Test macro:380.986338 ± 380.265882 | micro:2.579971 ± 1.097807
# Epoch 5/300 | Train(sampled) L1:52.715960 L4:0.412964 |
#           >> Test macro:366.601588 ± 365.949108 | micro:2.444683 ± 1.056441
# Epoch 6/300 | Train(sampled) L1:49.390940 L4:0.300256 |
#           >> Test macro:353.525384 ± 353.024368 | micro:2.240636 ± 1.019084
# Epoch 7/300 | Train(sampled) L1:48.478330 L4:0.227241 |
#           >> Test macro:342.182405 ± 341.760397 | micro:2.112594 ± 0.986556
# Epoch 8/300 | Train(sampled) L1:46.973332 L4:0.178433 |
#           >> Test macro:331.561019 ± 331.168378 | micro:2.032948 ± 0.955972
# Epoch 9/300 | Train(sampled) L1:46.916961 L4:0.153780 |
#           >> Test macro:320.724437 ± 320.352564 | micro:1.959061 ± 0.924756
# Epoch 10/300 | Train(sampled) L1:42.538635 L4:0.142892 |
#           >> Test macro:309.788684 ± 309.439553 | micro:1.883196 ± 0.893259
# Epoch 11/300 | Train(sampled) L1:40.783444 L4:0.134376 |
#           >> Test macro:299.152046 ± 298.819571 | micro:1.814441 ± 0.862605
# Epoch 12/300 | Train(sampled) L1:40.436934 L4:0.126727 |
#           >> Test macro:288.203899 ± 287.883081 | micro:1.748670 ± 0.831047
# Epoch 13/300 | Train(sampled) L1:37.318673 L4:0.118486 |
#           >> Test macro:276.683435 ± 276.376142 | micro:1.678215 ± 0.797831
# Epoch 14/300 | Train(sampled) L1:37.106121 L4:0.110214 |
#           >> Test macro:264.684593 ± 264.376078 | micro:1.619748 ± 0.763211
# Epoch 15/300 | Train(sampled) L1:35.420054 L4:0.101445 |
#           >> Test macro:252.139127 ± 251.850783 | micro:1.537474 ± 0.727066
# Epoch 16/300 | Train(sampled) L1:34.067816 L4:0.091632 |
#           >> Test macro:239.188844 ± 238.906178 | micro:1.467875 ± 0.689709
# Epoch 17/300 | Train(sampled) L1:30.847218 L4:0.080417 |
#           >> Test macro:225.832964 ± 225.558918 | micro:1.392786 ± 0.651187
# Epoch 18/300 | Train(sampled) L1:30.171451 L4:0.069357 |
#           >> Test macro:210.882000 ± 210.612166 | micro:1.313508 ± 0.608058
# Epoch 19/300 | Train(sampled) L1:27.220815 L4:0.058131 |
#           >> Test macro:196.600125 ± 196.325865 | micro:1.246166 ± 0.566868
# Epoch 20/300 | Train(sampled) L1:25.430751 L4:0.046347 |
#           >> Test macro:182.157330 ± 181.895644 | micro:1.161849 ± 0.525230
# Epoch 21/300 | Train(sampled) L1:24.663568 L4:0.036078 |
#           >> Test macro:167.750493 ± 167.496910 | micro:1.082568 ± 0.483679
# Epoch 22/300 | Train(sampled) L1:21.027704 L4:0.027084 |
#           >> Test macro:153.467861 ± 153.202841 | micro:1.023149 ± 0.442473
# Epoch 23/300 | Train(sampled) L1:19.967789 L4:0.023788 |
#           >> Test macro:138.471971 ± 138.219396 | micro:0.935144 ± 0.399252
# Epoch 24/300 | Train(sampled) L1:18.193254 L4:0.018392 |
#           >> Test macro:124.382024 ± 124.142442 | micro:0.852593 ± 0.358622
# Epoch 25/300 | Train(sampled) L1:15.739388 L4:0.013537 |
#           >> Test macro:110.553960 ± 110.310887 | micro:0.786110 ± 0.318753
# Epoch 26/300 | Train(sampled) L1:13.926438 L4:0.011231 |
#           >> Test macro:97.281275 ± 97.037402 | micro:0.722919 ± 0.280449
# Epoch 27/300 | Train(sampled) L1:12.342595 L4:0.009531 |
#           >> Test macro:84.470801 ± 84.233645 | micro:0.650411 ± 0.243542
# Epoch 28/300 | Train(sampled) L1:10.611599 L4:0.007674 |
#           >> Test macro:72.008275 ± 71.777780 | micro:0.582520 ± 0.207647
# Epoch 29/300 | Train(sampled) L1:8.950372 L4:0.005996 |
#           >> Test macro:60.438616 ± 60.211009 | micro:0.521173 ± 0.174390
# Epoch 30/300 | Train(sampled) L1:7.258128 L4:0.004812 |
#           >> Test macro:48.951335 ± 48.728357 | micro:0.459908 ± 0.141310
# Epoch 31/300 | Train(sampled) L1:5.947544 L4:0.003912 |
#           >> Test macro:38.994462 ± 38.747428 | micro:0.433410 ± 0.112821
# Epoch 32/300 | Train(sampled) L1:4.612428 L4:0.003239 |
#           >> Test macro:30.212564 ± 29.986656 | micro:0.368854 ± 0.087663
# Epoch 33/300 | Train(sampled) L1:3.634480 L4:0.002663 |
#           >> Test macro:22.599910 ± 22.374379 | micro:0.330999 ± 0.065953
# Epoch 34/300 | Train(sampled) L1:2.561295 L4:0.002222 |
#           >> Test macro:16.192525 ± 15.953058 | micro:0.310909 ± 0.048216
# Epoch 35/300 | Train(sampled) L1:1.784136 L4:0.002076 |
#           >> Test macro:10.794449 ± 10.529112 | micro:0.311406 ± 0.033301
# Epoch 36/300 | Train(sampled) L1:1.122455 L4:0.001889 |
#           >> Test macro:6.580371 ± 6.356701 | micro:0.248593 ± 0.022797
# Epoch 37/300 | Train(sampled) L1:0.649904 L4:0.001469 |
#           >> Test macro:3.529490 ± 3.293351 | micro:0.247069 ± 0.015858
# Epoch 38/300 | Train(sampled) L1:0.339040 L4:0.001261 |
#           >> Test macro:1.453467 ± 1.237607 | micro:0.216609 ± 0.012977
# Epoch 39/300 | Train(sampled) L1:0.129197 L4:0.001083 |
#           >> Test macro:0.488389 ± 0.267779 | micro:0.216786 ± 0.013741
# Epoch 40/300 | Train(sampled) L1:0.059211 L4:0.000968 |
#           >> Test macro:0.213466 ± 0.034509 | micro:0.219641 ± 0.013047
# Epoch 41/300 | Train(sampled) L1:0.040477 L4:0.000819 |
#           >> Test macro:0.154150 ± 0.063529 | micro:0.205702 ± 0.012498
# Epoch 42/300 | Train(sampled) L1:0.038583 L4:0.000617 |
#           >> Test macro:0.152695 ± 0.069154 | micro:0.209024 ± 0.012487
# Epoch 43/300 | Train(sampled) L1:0.039147 L4:0.000537 |
#           >> Test macro:0.173925 ± 0.061852 | micro:0.225323 ± 0.012156
# Epoch 44/300 | Train(sampled) L1:0.038760 L4:0.000491 |
#           >> Test macro:0.153669 ± 0.063415 | micro:0.205175 ± 0.012591
# Epoch 45/300 | Train(sampled) L1:0.038609 L4:0.000418 |
#           >> Test macro:0.160853 ± 0.069339 | micro:0.218059 ± 0.013127
# Epoch 46/300 | Train(sampled) L1:0.039592 L4:0.000469 |
#           >> Test macro:0.154586 ± 0.069279 | micro:0.212358 ± 0.013078
# Epoch 47/300 | Train(sampled) L1:0.036638 L4:0.000396 |
#           >> Test macro:0.150903 ± 0.065615 | micro:0.204117 ± 0.012936
# Epoch 48/300 | Train(sampled) L1:0.037797 L4:0.000314 |
#           >> Test macro:0.146526 ± 0.062311 | micro:0.198276 ± 0.012321
# Epoch 49/300 | Train(sampled) L1:0.036753 L4:0.000304 |
#           >> Test macro:0.169388 ± 0.072879 | micro:0.232857 ± 0.011854
# Epoch 50/300 | Train(sampled) L1:0.039853 L4:0.000261 |
#           >> Test macro:0.141794 ± 0.066671 | micro:0.197668 ± 0.011652
# Epoch 51/300 | Train(sampled) L1:0.036200 L4:0.000257 |
#           >> Test macro:0.142590 ± 0.065845 | micro:0.198995 ± 0.011495
# Epoch 52/300 | Train(sampled) L1:0.038003 L4:0.000235 |
#           >> Test macro:0.145392 ± 0.065613 | micro:0.201038 ± 0.012372
# Epoch 53/300 | Train(sampled) L1:0.036354 L4:0.000230 |
#           >> Test macro:0.144686 ± 0.066435 | micro:0.200321 ± 0.012065
# Epoch 54/300 | Train(sampled) L1:0.035576 L4:0.000212 |
#           >> Test macro:0.142705 ± 0.064984 | micro:0.198002 ± 0.011973
# Epoch 55/300 | Train(sampled) L1:0.035868 L4:0.000230 |
#           >> Test macro:0.142893 ± 0.064729 | micro:0.197489 ± 0.011339
# Epoch 56/300 | Train(sampled) L1:0.034848 L4:0.000173 |
#           >> Test macro:0.150271 ± 0.070892 | micro:0.209308 ± 0.012905
# Epoch 57/300 | Train(sampled) L1:0.035938 L4:0.000153 |
#           >> Test macro:0.142956 ± 0.065120 | micro:0.197813 ± 0.011992
# Epoch 58/300 | Train(sampled) L1:0.034202 L4:0.000155 |
#           >> Test macro:0.144333 ± 0.065379 | micro:0.199670 ± 0.011951
# Epoch 59/300 | Train(sampled) L1:0.035711 L4:0.000143 |
#           >> Test macro:0.145047 ± 0.067849 | micro:0.202914 ± 0.011503
# Epoch 60/300 | Train(sampled) L1:0.034682 L4:0.000123 |
#           >> Test macro:0.141814 ± 0.066747 | micro:0.198045 ± 0.011696
# Early stopping at epoch 60/300 (best test macro-MSE: 0.141794 @ epoch 50)
# TEST RESULTS | macro: 0.141814 ± 0.066747 | micro: 0.198045 ± 0.011696
#           >> per_group (weighted SE): {0: '0.245990 ± 0.024775 (n=777)', 1: '0.017434 ± 0.006844 (n=3)', 5: '0.162019 ± 0.008151 (n=1019)'}

# %%
odejump = ODEJump(
    in_channels=11,
    hidden_dim=11*32,
    denoised=True,    
    cost_columns=[
        'PH (CBM) 1st Stg ActCompr Poly Head',
        'PH (CBM) 1st Stage ActShaft Power',
        'PH (CBM) 1st Stg ActCompr Poly Head',
        'PH (CBM) 1st Stage ActPress Ratio'
        ],
)

# %%
res_odejump = odejump.train_cognite(
    df=df_scaled,
    feature_cols=list(df_scaled.columns[:-1]),
    static_features_cols=None,
    timestamp_col='index',
    states_col='states',
    batch_size=256,
    window_size=30,
    window_step=30,
    epochs = 200,
    validate=False
)
res_odejump = [r for r in res_odejump if r is not None]  # remove None results
# Out:
# GRUPOS (total): {0: 3886, 1: 15, 5: 5093}
# GRUPOS (train): {0: 3109, 1: 12, 5: 4074}
# GRUPOS (test):  {0: 777, 1: 3, 5: 1019}
# Epoch 1/200 | Train(sampled) L1:39.336474 L4:0.734248 |
#           >> Test macro:217.278238 ± 216.710613 | micro:1.168971 ± 0.614504
# Epoch 2/200 | Train(sampled) L1:37.409245 L4:0.488641 |
#           >> Test macro:203.018658 ± 202.502220 | micro:1.077644 ± 0.574217
# Epoch 3/200 | Train(sampled) L1:34.361342 L4:0.231226 |
#           >> Test macro:199.245060 ± 198.814763 | micro:0.987719 ± 0.563692
# Epoch 4/200 | Train(sampled) L1:33.667860 L4:0.158367 |
#           >> Test macro:196.408153 ± 196.007166 | micro:0.950889 ± 0.555709
# Epoch 5/200 | Train(sampled) L1:33.204266 L4:0.127452 |
#           >> Test macro:192.916791 ± 192.534292 | micro:0.922478 ± 0.545823
# Epoch 6/200 | Train(sampled) L1:32.191046 L4:0.115622 |
#           >> Test macro:188.662324 ± 188.300878 | micro:0.891407 ± 0.533773
# Epoch 7/200 | Train(sampled) L1:30.456072 L4:0.106847 |
#           >> Test macro:183.514015 ± 183.184554 | micro:0.845739 ± 0.519247
# Epoch 8/200 | Train(sampled) L1:31.092471 L4:0.099746 |
#           >> Test macro:177.524672 ± 177.215576 | micro:0.809429 ± 0.502299
# Epoch 9/200 | Train(sampled) L1:28.046736 L4:0.090491 |
#           >> Test macro:170.728351 ± 170.437319 | micro:0.772846 ± 0.483062
# Epoch 10/200 | Train(sampled) L1:27.248850 L4:0.080681 |
#           >> Test macro:163.164462 ± 162.886890 | micro:0.738278 ± 0.461691
# Epoch 11/200 | Train(sampled) L1:27.035926 L4:0.069368 |
#           >> Test macro:154.888043 ± 154.617067 | micro:0.708204 ± 0.438252
# Epoch 12/200 | Train(sampled) L1:25.179988 L4:0.056063 |
#           >> Test macro:145.970754 ± 145.629304 | micro:0.750391 ± 0.412903
# Epoch 13/200 | Train(sampled) L1:21.872632 L4:0.055830 |
#           >> Test macro:136.369447 ± 136.111827 | micro:0.641614 ± 0.385862
# Epoch 14/200 | Train(sampled) L1:22.040646 L4:0.042502 |
#           >> Test macro:126.307058 ± 126.051565 | micro:0.611902 ± 0.357374
# Epoch 15/200 | Train(sampled) L1:19.980001 L4:0.030606 |
#           >> Test macro:115.812886 ± 115.558687 | micro:0.579501 ± 0.327714
# Epoch 16/200 | Train(sampled) L1:17.940170 L4:0.023038 |
#           >> Test macro:105.010031 ± 104.756940 | micro:0.548144 ± 0.297089
# Epoch 17/200 | Train(sampled) L1:15.776211 L4:0.019207 |
#           >> Test macro:93.974106 ± 93.707195 | micro:0.527842 ± 0.266027
# Epoch 18/200 | Train(sampled) L1:14.244535 L4:0.014803 |
#           >> Test macro:82.812260 ± 82.561957 | micro:0.480025 ± 0.234525
# Epoch 19/200 | Train(sampled) L1:12.551052 L4:0.010058 |
#           >> Test macro:71.722931 ± 71.473661 | micro:0.448635 ± 0.203040
# Epoch 20/200 | Train(sampled) L1:11.131819 L4:0.008823 |
#           >> Test macro:60.860064 ± 60.584042 | micro:0.442320 ± 0.172698
# Epoch 21/200 | Train(sampled) L1:9.070849 L4:0.007011 |
#           >> Test macro:50.612208 ± 50.372052 | micro:0.377323 ± 0.143809
# Epoch 22/200 | Train(sampled) L1:7.449541 L4:0.005756 |
#           >> Test macro:41.354429 ± 41.108916 | micro:0.355689 ± 0.117583
# Epoch 23/200 | Train(sampled) L1:6.219543 L4:0.006282 |
#           >> Test macro:33.033828 ± 32.784887 | micro:0.335448 ± 0.094442
# Epoch 24/200 | Train(sampled) L1:4.772728 L4:0.005550 |
#           >> Test macro:25.647191 ± 25.411521 | micro:0.300912 ± 0.073885
# Epoch 25/200 | Train(sampled) L1:3.849226 L4:0.004243 |
#           >> Test macro:19.135549 ± 18.883459 | micro:0.297555 ± 0.055443
# Epoch 26/200 | Train(sampled) L1:2.784347 L4:0.003412 |
#           >> Test macro:13.563902 ± 13.267940 | micro:0.325843 ± 0.042098
# Epoch 27/200 | Train(sampled) L1:1.738349 L4:0.003953 |
#           >> Test macro:8.835314 ± 8.588715 | micro:0.262777 ± 0.030330
# Epoch 28/200 | Train(sampled) L1:1.158849 L4:0.003038 |
#           >> Test macro:5.140042 ± 4.886200 | micro:0.260161 ± 0.019905
# Epoch 29/200 | Train(sampled) L1:0.640862 L4:0.003138 |
#           >> Test macro:2.477151 ± 2.239998 | micro:0.235627 ± 0.020654
# Epoch 30/200 | Train(sampled) L1:0.279045 L4:0.002530 |
#           >> Test macro:0.903101 ± 0.638739 | micro:0.259581 ± 0.013797
# Epoch 31/200 | Train(sampled) L1:0.093541 L4:0.001967 |
#           >> Test macro:0.234432 ± 0.033604 | micro:0.210349 ± 0.012427
# Epoch 32/200 | Train(sampled) L1:0.043053 L4:0.001834 |
#           >> Test macro:0.152865 ± 0.081003 | micro:0.219690 ± 0.012730
# Epoch 33/200 | Train(sampled) L1:0.041664 L4:0.002157 |
#           >> Test macro:0.150388 ± 0.081012 | micro:0.218142 ± 0.013450
# Epoch 34/200 | Train(sampled) L1:0.039753 L4:0.001531 |
#           >> Test macro:0.142627 ± 0.075727 | micro:0.207375 ± 0.012492
# Epoch 35/200 | Train(sampled) L1:0.039565 L4:0.001513 |
#           >> Test macro:0.144936 ± 0.077788 | micro:0.210584 ± 0.012435
# Epoch 36/200 | Train(sampled) L1:0.037535 L4:0.001533 |
#           >> Test macro:0.143446 ± 0.076270 | micro:0.208626 ± 0.012342
# Epoch 37/200 | Train(sampled) L1:0.038206 L4:0.001649 |
#           >> Test macro:0.145842 ± 0.077550 | micro:0.210998 ± 0.012876
# Epoch 38/200 | Train(sampled) L1:0.037608 L4:0.001426 |
#           >> Test macro:0.151945 ± 0.082904 | micro:0.219686 ± 0.012739
# Epoch 39/200 | Train(sampled) L1:0.034842 L4:0.001181 |
#           >> Test macro:0.144520 ± 0.077442 | micro:0.210002 ± 0.012047
# Epoch 40/200 | Train(sampled) L1:0.035466 L4:0.001139 |
#           >> Test macro:0.160163 ± 0.086526 | micro:0.232100 ± 0.013251
# Epoch 41/200 | Train(sampled) L1:0.036757 L4:0.001499 |
#           >> Test macro:0.146415 ± 0.078290 | micro:0.211633 ± 0.012349
# Epoch 42/200 | Train(sampled) L1:0.034373 L4:0.000929 |
#           >> Test macro:0.143537 ± 0.076532 | micro:0.207894 ± 0.011856
# Epoch 43/200 | Train(sampled) L1:0.036558 L4:0.000828 |
#           >> Test macro:0.147405 ± 0.079430 | micro:0.213730 ± 0.012310
# Epoch 44/200 | Train(sampled) L1:0.037544 L4:0.001034 |
#           >> Test macro:0.156151 ± 0.082958 | micro:0.226605 ± 0.013408
# Early stopping at epoch 44/200 (best test macro-MSE: 0.142627 @ epoch 34)
# TEST RESULTS | macro: 0.156151 ± 0.082958 | micro: 0.226605 ± 0.013408
#           >> per_group (weighted SE): {0: '0.284723 ± 0.028565 (n=777)', 1: '0.001047 ± 0.000493 (n=3)', 5: '0.182684 ± 0.009003 (n=1019)'}

# %%
res_odejump = odejump.train_cognite(
    df=df_scaled_rebuilt,
    feature_cols=list(df_scaled.columns[:-1]),
    static_features_cols=None,
    timestamp_col='index',
    states_col='states',
    batch_size=256,
    window_size=30,
    window_step=30,
    epochs = 200,
    validate=False,
    
)
res_odejump = [r for r in res_odejump if r is not None]  # remove None results
# Out:
# GRUPOS (total): {0: 3886, 1: 15, 5: 5093}
# GRUPOS (train): {0: 3109, 1: 12, 5: 4074}
# GRUPOS (test):  {0: 777, 1: 3, 5: 1019}
# Epoch 1/200 | Train(sampled) L1:55.524038 L4:0.448187 |
#           >> Test macro:368.493302 ± 367.743875 | micro:2.560618 ± 1.061679
# Epoch 2/200 | Train(sampled) L1:51.335411 L4:0.342341 |
#           >> Test macro:343.146442 ± 342.659889 | micro:2.180976 ± 0.989249
# Epoch 3/200 | Train(sampled) L1:46.498538 L4:0.213164 |
#           >> Test macro:336.423276 ± 335.998332 | micro:2.087906 ± 0.969964
# Epoch 4/200 | Train(sampled) L1:45.925819 L4:0.150979 |
#           >> Test macro:331.373578 ± 330.992038 | micro:2.021612 ± 0.955468
# Epoch 5/200 | Train(sampled) L1:44.459623 L4:0.126520 |
#           >> Test macro:325.176137 ± 324.828333 | micro:1.958537 ± 0.937651
# Epoch 6/200 | Train(sampled) L1:43.454841 L4:0.111674 |
#           >> Test macro:317.625925 ± 317.304623 | micro:1.896087 ± 0.915918
# Epoch 7/200 | Train(sampled) L1:42.690689 L4:0.096709 |
#           >> Test macro:308.664506 ± 308.364867 | micro:1.830481 ± 0.890105
# Epoch 8/200 | Train(sampled) L1:41.333386 L4:0.082000 |
#           >> Test macro:298.297317 ± 297.994249 | micro:1.782698 ± 0.860157
# Epoch 9/200 | Train(sampled) L1:40.467566 L4:0.072804 |
#           >> Test macro:286.544634 ± 286.271794 | micro:1.695105 ± 0.826322
# Epoch 10/200 | Train(sampled) L1:37.341935 L4:0.059490 |
#           >> Test macro:273.498243 ± 273.241509 | micro:1.614776 ± 0.788720
# Epoch 11/200 | Train(sampled) L1:35.764860 L4:0.045805 |
#           >> Test macro:259.266447 ± 259.009235 | micro:1.544087 ± 0.747654
# Epoch 12/200 | Train(sampled) L1:34.927362 L4:0.034062 |
#           >> Test macro:243.923841 ± 243.645951 | micro:1.489409 ± 0.703330
# Epoch 13/200 | Train(sampled) L1:31.314198 L4:0.029264 |
#           >> Test macro:227.547193 ± 227.309895 | micro:1.366734 ± 0.656170
# Epoch 14/200 | Train(sampled) L1:29.249717 L4:0.020519 |
#           >> Test macro:210.319930 ± 210.088932 | micro:1.274838 ± 0.606476
# Epoch 15/200 | Train(sampled) L1:27.560696 L4:0.014864 |
#           >> Test macro:192.362234 ± 192.130382 | micro:1.185792 ± 0.554671
# Epoch 16/200 | Train(sampled) L1:24.176818 L4:0.011619 |
#           >> Test macro:173.877820 ± 173.636547 | micro:1.101045 ± 0.501317
# Epoch 17/200 | Train(sampled) L1:21.930346 L4:0.007647 |
#           >> Test macro:155.057347 ± 154.814774 | micro:1.010361 ± 0.446987
# Epoch 18/200 | Train(sampled) L1:19.774961 L4:0.007063 |
#           >> Test macro:136.042773 ± 135.809284 | micro:0.906702 ± 0.392186
# Epoch 19/200 | Train(sampled) L1:17.529799 L4:0.004667 |
#           >> Test macro:117.194204 ± 116.959521 | micro:0.813680 ± 0.337797
# Epoch 20/200 | Train(sampled) L1:15.021163 L4:0.004869 |
#           >> Test macro:98.747826 ± 98.528676 | micro:0.705229 ± 0.284682
# Epoch 21/200 | Train(sampled) L1:12.598275 L4:0.003403 |
#           >> Test macro:81.512857 ± 81.282880 | micro:0.629613 ± 0.234959
# Epoch 22/200 | Train(sampled) L1:9.639031 L4:0.002624 |
#           >> Test macro:65.964327 ± 65.732187 | micro:0.555028 ± 0.190174
# Epoch 23/200 | Train(sampled) L1:7.989888 L4:0.001928 |
#           >> Test macro:52.143926 ± 51.906437 | micro:0.488642 ± 0.150459
# Epoch 24/200 | Train(sampled) L1:5.993813 L4:0.001609 |
#           >> Test macro:39.960777 ± 39.737785 | micro:0.415384 ± 0.115505
# Epoch 25/200 | Train(sampled) L1:4.711328 L4:0.001347 |
#           >> Test macro:29.352315 ± 29.121482 | micro:0.369182 ± 0.085430
# Epoch 26/200 | Train(sampled) L1:3.335660 L4:0.001022 |
#           >> Test macro:20.306324 ± 20.089946 | micro:0.310305 ± 0.059446
# Epoch 27/200 | Train(sampled) L1:2.147438 L4:0.000794 |
#           >> Test macro:12.928150 ± 12.714827 | micro:0.270754 ± 0.038816
# Epoch 28/200 | Train(sampled) L1:1.327967 L4:0.000608 |
#           >> Test macro:7.422809 ± 7.094059 | micro:0.355891 ± 0.024827
# Epoch 29/200 | Train(sampled) L1:0.737881 L4:0.001100 |
#           >> Test macro:3.502947 ± 3.281344 | micro:0.231626 ± 0.016128
# Epoch 30/200 | Train(sampled) L1:0.298371 L4:0.000693 |
#           >> Test macro:1.199567 ± 0.975986 | micro:0.223241 ± 0.013093
# Epoch 31/200 | Train(sampled) L1:0.094280 L4:0.000395 |
#           >> Test macro:0.265425 ± 0.042760 | micro:0.228874 ± 0.013828
# Epoch 32/200 | Train(sampled) L1:0.040985 L4:0.000270 |
#           >> Test macro:0.157191 ± 0.072541 | micro:0.214826 ± 0.013513
# Epoch 33/200 | Train(sampled) L1:0.037477 L4:0.000233 |
#           >> Test macro:0.160444 ± 0.074338 | micro:0.220942 ± 0.012396
# Epoch 34/200 | Train(sampled) L1:0.037818 L4:0.000184 |
#           >> Test macro:0.144877 ± 0.073121 | micro:0.205217 ± 0.012482
# Epoch 35/200 | Train(sampled) L1:0.034267 L4:0.000141 |
#           >> Test macro:0.151719 ± 0.072877 | micro:0.210142 ± 0.012467
# Epoch 36/200 | Train(sampled) L1:0.037231 L4:0.000124 |
#           >> Test macro:0.149308 ± 0.072624 | micro:0.210444 ± 0.012667
# Epoch 37/200 | Train(sampled) L1:0.036210 L4:0.000113 |
#           >> Test macro:0.153271 ± 0.073477 | micro:0.214604 ± 0.011964
# Epoch 38/200 | Train(sampled) L1:0.034969 L4:0.000106 |
#           >> Test macro:0.148132 ± 0.072211 | micro:0.206575 ± 0.012745
# Epoch 39/200 | Train(sampled) L1:0.034283 L4:0.000098 |
#           >> Test macro:0.138344 ± 0.068226 | micro:0.195190 ± 0.012128
# Epoch 40/200 | Train(sampled) L1:0.034331 L4:0.000080 |
#           >> Test macro:0.144266 ± 0.070012 | micro:0.202593 ± 0.011794
# Epoch 41/200 | Train(sampled) L1:0.034738 L4:0.000060 |
#           >> Test macro:0.154880 ± 0.076986 | micro:0.216761 ± 0.012754
# Epoch 42/200 | Train(sampled) L1:0.034572 L4:0.000077 |
#           >> Test macro:0.155947 ± 0.072371 | micro:0.215479 ± 0.012011
# Epoch 43/200 | Train(sampled) L1:0.033881 L4:0.000065 |
#           >> Test macro:0.141664 ± 0.066804 | micro:0.196652 ± 0.011101
# Epoch 44/200 | Train(sampled) L1:0.034256 L4:0.000103 |
#           >> Test macro:0.143559 ± 0.068912 | micro:0.201790 ± 0.012125
# Epoch 45/200 | Train(sampled) L1:0.031764 L4:0.000045 |
#           >> Test macro:0.141357 ± 0.068609 | micro:0.199100 ± 0.011701
# Epoch 46/200 | Train(sampled) L1:0.031997 L4:0.000054 |
#           >> Test macro:0.138218 ± 0.067146 | micro:0.194373 ± 0.011599
# Epoch 47/200 | Train(sampled) L1:0.034899 L4:0.000036 |
#           >> Test macro:0.141522 ± 0.070383 | micro:0.200790 ± 0.011562
# Epoch 48/200 | Train(sampled) L1:0.034427 L4:0.000042 |
#           >> Test macro:0.142487 ± 0.063997 | micro:0.195683 ± 0.011656
# Epoch 49/200 | Train(sampled) L1:0.032543 L4:0.000034 |
#           >> Test macro:0.142720 ± 0.067439 | micro:0.198050 ± 0.011299
# Epoch 50/200 | Train(sampled) L1:0.031520 L4:0.000036 |
#           >> Test macro:0.146240 ± 0.072795 | micro:0.206868 ± 0.012449
# Epoch 51/200 | Train(sampled) L1:0.030669 L4:0.000026 |
#           >> Test macro:0.149910 ± 0.075619 | micro:0.211424 ± 0.012268
# Epoch 52/200 | Train(sampled) L1:0.033462 L4:0.000029 |
#           >> Test macro:0.151060 ± 0.072348 | micro:0.211246 ± 0.012104
# Epoch 53/200 | Train(sampled) L1:0.033706 L4:0.000033 |
#           >> Test macro:0.143919 ± 0.069909 | micro:0.201418 ± 0.011927
# Epoch 54/200 | Train(sampled) L1:0.032434 L4:0.000031 |
#           >> Test macro:0.137745 ± 0.067370 | micro:0.195755 ± 0.010740
# Epoch 55/200 | Train(sampled) L1:0.032253 L4:0.000020 |
#           >> Test macro:0.150856 ± 0.068665 | micro:0.207735 ± 0.011791
# Epoch 56/200 | Train(sampled) L1:0.030356 L4:0.000024 |
#           >> Test macro:0.145998 ± 0.070321 | micro:0.204266 ± 0.011061
# Epoch 57/200 | Train(sampled) L1:0.030262 L4:0.000023 |
#           >> Test macro:0.145696 ± 0.067803 | micro:0.202223 ± 0.011145
# Epoch 58/200 | Train(sampled) L1:0.031516 L4:0.000020 |
#           >> Test macro:0.144668 ± 0.069693 | micro:0.202131 ± 0.011880
# Epoch 59/200 | Train(sampled) L1:0.031623 L4:0.000019 |
#           >> Test macro:0.153876 ± 0.078659 | micro:0.217931 ± 0.012975
# Epoch 60/200 | Train(sampled) L1:0.030283 L4:0.000025 |
#           >> Test macro:0.152046 ± 0.074002 | micro:0.215214 ± 0.011974
# Epoch 61/200 | Train(sampled) L1:0.030007 L4:0.000027 |
#           >> Test macro:0.142356 ± 0.069741 | micro:0.201061 ± 0.011365
# Epoch 62/200 | Train(sampled) L1:0.030407 L4:0.000028 |
#           >> Test macro:0.143906 ± 0.070610 | micro:0.202350 ± 0.011528
# Epoch 63/200 | Train(sampled) L1:0.030564 L4:0.000015 |
#           >> Test macro:0.153305 ± 0.077890 | micro:0.214449 ± 0.011881
# Epoch 64/200 | Train(sampled) L1:0.029686 L4:0.000060 |
#           >> Test macro:0.140796 ± 0.069020 | micro:0.200396 ± 0.010555
# Early stopping at epoch 64/200 (best test macro-MSE: 0.137745 @ epoch 54)
# TEST RESULTS | macro: 0.140796 ± 0.069020 | micro: 0.200396 ± 0.010555
#           >> per_group (weighted SE): {0: '0.245208 ± 0.021594 (n=777)', 1: '0.010392 ± 0.004775 (n=3)', 5: '0.166786 ± 0.008568 (n=1019)'}

# %%
res_odejump = odejump.train_cognite(
    df=df_scaled_rebuilt,
    feature_cols=list(df_scaled.columns[:-1]),
    static_features_cols=None,
    timestamp_col='index',
    states_col='states',
    batch_size=256,
    window_size=30,
    window_step=30,
    epochs = 200,
    validate=False,
    df_denoised=df_scaled_denoised
)
res_odejump = [r for r in res_odejump if r is not None]  # remove None results
# Out:
# GRUPOS (total): {0: 3886, 1: 15, 5: 5093}
# GRUPOS (train): {0: 3109, 1: 12, 5: 4074}
# GRUPOS (test):  {0: 777, 1: 3, 5: 1019}
# Epoch 1/200 | Train(sampled) L1:54.770924 L4:0.473250 |
#           >> Test macro:374.689966 ± 373.883891 | micro:2.627481 ± 1.079610
# Epoch 2/200 | Train(sampled) L1:52.155258 L4:0.262898 |
#           >> Test macro:351.558412 ± 350.987425 | micro:2.293409 ± 1.013459
# Epoch 3/200 | Train(sampled) L1:46.197730 L4:0.156766 |
#           >> Test macro:333.896348 ± 333.414314 | micro:2.122763 ± 0.962764
# Epoch 4/200 | Train(sampled) L1:44.285556 L4:0.116868 |
#           >> Test macro:311.275189 ± 310.816150 | micro:1.986171 ± 0.897660
# Epoch 5/200 | Train(sampled) L1:41.083051 L4:0.092300 |
#           >> Test macro:281.314610 ± 280.856388 | micro:1.837684 ± 0.811488
# Epoch 6/200 | Train(sampled) L1:37.164252 L4:0.064856 |
#           >> Test macro:242.988083 ± 242.503884 | micro:1.670567 ± 0.701819
# Epoch 7/200 | Train(sampled) L1:31.174904 L4:0.067222 |
#           >> Test macro:196.039022 ± 195.392590 | micro:1.590600 ± 0.567981
# Epoch 8/200 | Train(sampled) L1:23.280443 L4:0.053183 |
#           >> Test macro:141.129921 ± 140.742719 | micro:1.073278 ± 0.407618
# Epoch 9/200 | Train(sampled) L1:16.493573 L4:0.092610 |
#           >> Test macro:86.289768 ± 85.684298 | micro:0.994719 ± 0.261044
# Epoch 10/200 | Train(sampled) L1:9.087966 L4:0.093441 |
#           >> Test macro:36.254169 ± 35.510336 | micro:0.904397 ± 0.107371
# Epoch 11/200 | Train(sampled) L1:2.721010 L4:0.056764 |
#           >> Test macro:4.953038 ± 4.517204 | micro:0.439909 ± 0.023285
# Epoch 12/200 | Train(sampled) L1:0.519651 L4:0.042713 |
#           >> Test macro:0.362073 ± 0.144835 | micro:0.478869 ± 0.042738
# Epoch 13/200 | Train(sampled) L1:0.336626 L4:0.036187 |
#           >> Test macro:0.305405 ± 0.084257 | micro:0.367276 ± 0.018277
# Epoch 14/200 | Train(sampled) L1:0.097250 L4:0.018313 |
#           >> Test macro:0.244403 ± 0.105153 | micro:0.319865 ± 0.017509
# Epoch 15/200 | Train(sampled) L1:0.101701 L4:0.019049 |
#           >> Test macro:0.259913 ± 0.096437 | micro:0.330256 ± 0.018354
# Epoch 16/200 | Train(sampled) L1:0.068991 L4:0.008478 |
#           >> Test macro:0.244735 ± 0.103047 | micro:0.324017 ± 0.017267
# Epoch 17/200 | Train(sampled) L1:0.111339 L4:0.008451 |
#           >> Test macro:0.278119 ± 0.099852 | micro:0.337184 ± 0.018822
# Epoch 18/200 | Train(sampled) L1:0.066156 L4:0.004423 |
#           >> Test macro:0.293773 ± 0.058412 | micro:0.310024 ± 0.021466
# Epoch 19/200 | Train(sampled) L1:0.541836 L4:0.010237 |
#           >> Test macro:0.335307 ± 0.061203 | micro:0.378017 ± 0.015721
# Epoch 20/200 | Train(sampled) L1:0.086840 L4:0.006474 |
#           >> Test macro:0.226612 ± 0.094255 | micro:0.299428 ± 0.015740
# Epoch 21/200 | Train(sampled) L1:0.075600 L4:0.005769 |
#           >> Test macro:0.281544 ± 0.054061 | micro:0.292033 ± 0.015414
# Epoch 22/200 | Train(sampled) L1:0.068823 L4:0.003980 |
#           >> Test macro:0.348962 ± 0.060531 | micro:0.363984 ± 0.018085
# Epoch 23/200 | Train(sampled) L1:0.072811 L4:0.002169 |
#           >> Test macro:0.204606 ± 0.093173 | micro:0.275828 ± 0.014268
# Epoch 24/200 | Train(sampled) L1:0.059960 L4:0.001503 |
#           >> Test macro:0.208176 ± 0.092733 | micro:0.278416 ± 0.016659
# Epoch 25/200 | Train(sampled) L1:0.065196 L4:0.002714 |
#           >> Test macro:0.213529 ± 0.101423 | micro:0.293591 ± 0.013670
# Epoch 26/200 | Train(sampled) L1:0.203334 L4:0.002996 |
#           >> Test macro:0.292448 ± 0.171905 | micro:0.392979 ± 0.096305
# Epoch 27/200 | Train(sampled) L1:0.164531 L4:0.002595 |
#           >> Test macro:0.615433 ± 0.471403 | micro:0.796168 ± 0.521427
# Epoch 28/200 | Train(sampled) L1:0.068366 L4:0.002626 |
#           >> Test macro:0.213462 ± 0.081767 | micro:0.275028 ± 0.014736
# Epoch 29/200 | Train(sampled) L1:0.068428 L4:0.002726 |
#           >> Test macro:0.199824 ± 0.094795 | micro:0.277175 ± 0.015126
# Epoch 30/200 | Train(sampled) L1:0.065757 L4:0.003656 |
#           >> Test macro:0.216219 ± 0.079371 | micro:0.277826 ± 0.013805
# Epoch 31/200 | Train(sampled) L1:0.067509 L4:0.002720 |
#           >> Test macro:0.209653 ± 0.096992 | micro:0.285480 ± 0.015176
# Epoch 32/200 | Train(sampled) L1:0.060703 L4:0.002473 |
#           >> Test macro:0.229006 ± 0.106692 | micro:0.318291 ± 0.014332
# Epoch 33/200 | Train(sampled) L1:0.062934 L4:0.002618 |
#           >> Test macro:0.212581 ± 0.098774 | micro:0.291189 ± 0.016019
# Early stopping at epoch 33/200 (best test macro-MSE: 0.304365 @ epoch 23)
# TEST RESULTS | macro: 0.212581 ± 0.098774 | micro: 0.291189 ± 0.016019
#           >> per_group (weighted SE): {0: '0.375722 ± 0.033864 (n=777)', 1: '0.034533 ± 0.012540 (n=3)', 5: '0.227487 ± 0.011114 (n=1019)'}

# %%
with open("cognite_odejump_results.json", "w") as f:
    json.dump(res_odejump, f)

# %% [markdown]
# ### 12. ODEJump + Attention

# %%
importlib.reload(sys.modules['tsdiffusion_transformed.ode_jump_encoder'])
importlib.reload(sys.modules['tsdiffusion_transformed.ode_jump'])
from tsdiffusion_transformed.ode_jump import ODEJump
from tsdiffusion_transformed.ode_jump_encoder import ODEJumpEncoder

# %%
odejump_encoder = ODEJumpEncoder(
    in_channels=11,
    hidden_dim=11*32,
    n_layers=12,
    denoised=True,
    cost_columns=[
    'PH (CBM) 1st Stg ActCompr Poly Head',
    'PH (CBM) 1st Stage ActShaft Power',
    'PH (CBM) 1st Stg ActCompr Poly Head',
    'PH (CBM) 1st Stage ActPress Ratio'
    ],
)
# Out:
# /root/coppe/3Wve/lib/python3.12/site-packages/torch/nn/modules/transformer.py:382: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(

# %%
res_odejump_encoder = odejump_encoder.train_cognite(
    df=df_scaled,
    feature_cols=list(df_scaled.columns[:-1]),
    static_features_cols=None,
    timestamp_col='index',
    states_col='states',
    batch_size=256,
    window_size=30,
    window_step=30,
    epochs = 200,
    validate=False,
    #lr=2e-4
)
res_odejump_encoder = [r for r in res_odejump_encoder if r is not None]  # remove None results
# Out:
# GRUPOS (total): {0: 3886, 1: 15, 5: 5093}
# GRUPOS (train): {0: 3109, 1: 12, 5: 4074}
# GRUPOS (test):  {0: 777, 1: 3, 5: 1019}
# Epoch 1/200 | Train(sampled) L1:41.901613 L4:0.765137 |
#           >> Test macro:229.201415 ± 228.183011 | micro:1.621736 ± 0.647371
# Epoch 2/200 | Train(sampled) L1:36.739232 L4:0.465220 |
#           >> Test macro:202.454349 ± 201.470469 | micro:1.502411 ± 0.571747
# Epoch 3/200 | Train(sampled) L1:32.950532 L4:0.248410 |
#           >> Test macro:192.934887 ± 192.431211 | micro:1.038175 ± 0.545735
# Epoch 4/200 | Train(sampled) L1:32.317282 L4:0.162244 |
#           >> Test macro:187.970379 ± 187.522054 | micro:0.971479 ± 0.531746
# Epoch 5/200 | Train(sampled) L1:31.830472 L4:0.136885 |
#           >> Test macro:183.721273 ± 183.304025 | micro:0.930637 ± 0.519719
# Epoch 6/200 | Train(sampled) L1:28.879550 L4:0.124981 |
#           >> Test macro:178.950753 ± 178.563793 | micro:0.888887 ± 0.506234
# Epoch 7/200 | Train(sampled) L1:30.245101 L4:0.114994 |
#           >> Test macro:173.740129 ± 173.379897 | micro:0.847205 ± 0.491539
# Epoch 8/200 | Train(sampled) L1:28.849371 L4:0.105742 |
#           >> Test macro:167.772203 ± 167.434926 | micro:0.809068 ± 0.474673
# Epoch 9/200 | Train(sampled) L1:27.899702 L4:0.093534 |
#           >> Test macro:161.124997 ± 160.797422 | micro:0.779796 ± 0.455888
# Epoch 10/200 | Train(sampled) L1:25.759802 L4:0.080694 |
#           >> Test macro:153.891914 ± 153.583689 | micro:0.741109 ± 0.435441
# Epoch 11/200 | Train(sampled) L1:24.686090 L4:0.065478 |
#           >> Test macro:145.922019 ± 145.629963 | micro:0.703220 ± 0.412881
# Epoch 12/200 | Train(sampled) L1:23.642664 L4:0.049554 |
#           >> Test macro:137.445466 ± 137.141630 | micro:0.689532 ± 0.388891
# Epoch 13/200 | Train(sampled) L1:22.380552 L4:0.036081 |
#           >> Test macro:128.547707 ± 128.269634 | micro:0.639136 ± 0.363711
# Epoch 14/200 | Train(sampled) L1:19.783636 L4:0.026139 |
#           >> Test macro:119.777180 ± 119.441944 | micro:0.672320 ± 0.338748
# Epoch 15/200 | Train(sampled) L1:19.015228 L4:0.024218 |
#           >> Test macro:110.880985 ± 110.601618 | micro:0.588472 ± 0.313753
# Epoch 16/200 | Train(sampled) L1:17.763259 L4:0.015902 |
#           >> Test macro:100.879399 ± 100.616241 | micro:0.544550 ± 0.285483
# Epoch 17/200 | Train(sampled) L1:16.192626 L4:0.011874 |
#           >> Test macro:90.649156 ± 90.367155 | micro:0.533278 ± 0.256517
# Epoch 18/200 | Train(sampled) L1:14.401907 L4:0.009259 |
#           >> Test macro:81.274486 ± 81.020577 | micro:0.479637 ± 0.230013
# Epoch 19/200 | Train(sampled) L1:13.040023 L4:0.008348 |
#           >> Test macro:71.949278 ± 71.645698 | micro:0.500783 ± 0.203690
# Epoch 20/200 | Train(sampled) L1:11.268393 L4:0.009327 |
#           >> Test macro:63.047898 ± 62.775027 | micro:0.444415 ± 0.178749
# Epoch 21/200 | Train(sampled) L1:9.665163 L4:0.006502 |
#           >> Test macro:53.555691 ± 53.311527 | micro:0.389995 ± 0.151753
# Epoch 22/200 | Train(sampled) L1:7.928174 L4:0.004452 |
#           >> Test macro:44.961393 ± 44.710688 | micro:0.371189 ± 0.127811
# Epoch 23/200 | Train(sampled) L1:6.912086 L4:0.004266 |
#           >> Test macro:37.238380 ± 36.980632 | micro:0.354769 ± 0.105982
# Epoch 24/200 | Train(sampled) L1:5.813399 L4:0.003837 |
#           >> Test macro:30.370009 ± 30.101434 | micro:0.345466 ± 0.087400
# Epoch 25/200 | Train(sampled) L1:4.539745 L4:0.003193 |
#           >> Test macro:24.287848 ± 24.004398 | micro:0.345743 ± 0.069942
# Epoch 26/200 | Train(sampled) L1:3.638697 L4:0.003768 |
#           >> Test macro:19.915122 ± 19.673032 | micro:0.289793 ± 0.058182
# Epoch 27/200 | Train(sampled) L1:2.867675 L4:0.003571 |
#           >> Test macro:15.230811 ± 14.983615 | micro:0.280764 ± 0.045705
# Epoch 28/200 | Train(sampled) L1:2.235860 L4:0.002839 |
#           >> Test macro:11.010215 ± 10.741107 | micro:0.289136 ± 0.036853
# Epoch 29/200 | Train(sampled) L1:1.558599 L4:0.002913 |
#           >> Test macro:7.764315 ± 7.495001 | micro:0.280188 ± 0.028988
# Epoch 30/200 | Train(sampled) L1:1.089106 L4:0.003416 |
#           >> Test macro:4.942833 ± 4.685493 | micro:0.262566 ± 0.022022
# Epoch 31/200 | Train(sampled) L1:0.636273 L4:0.002343 |
#           >> Test macro:2.973847 ± 2.724834 | micro:0.249027 ± 0.016587
# Epoch 32/200 | Train(sampled) L1:0.391231 L4:0.002542 |
#           >> Test macro:1.660490 ± 1.409203 | micro:0.247265 ± 0.015588
# Epoch 33/200 | Train(sampled) L1:0.206692 L4:0.002088 |
#           >> Test macro:0.817968 ± 0.558370 | micro:0.253409 ± 0.014793
# Epoch 34/200 | Train(sampled) L1:0.109321 L4:0.002373 |
#           >> Test macro:0.380082 ± 0.131066 | micro:0.246439 ± 0.015173
# Epoch 35/200 | Train(sampled) L1:0.054354 L4:0.002617 |
#           >> Test macro:0.242439 ± 0.073512 | micro:0.290919 ± 0.014761
# Epoch 36/200 | Train(sampled) L1:0.044073 L4:0.002043 |
#           >> Test macro:0.164252 ± 0.078944 | micro:0.229077 ± 0.013720
# Epoch 37/200 | Train(sampled) L1:0.043130 L4:0.002309 |
#           >> Test macro:0.159311 ± 0.086019 | micro:0.228495 ± 0.014637
# Epoch 38/200 | Train(sampled) L1:0.038318 L4:0.001665 |
#           >> Test macro:0.156207 ± 0.083730 | micro:0.225574 ± 0.013385
# Epoch 39/200 | Train(sampled) L1:0.037858 L4:0.001598 |
#           >> Test macro:0.153604 ± 0.083206 | micro:0.222068 ± 0.013624
# Epoch 40/200 | Train(sampled) L1:0.039161 L4:0.002159 |
#           >> Test macro:0.162393 ± 0.087533 | micro:0.234172 ± 0.012717
# Epoch 41/200 | Train(sampled) L1:0.038528 L4:0.002181 |
#           >> Test macro:0.159098 ± 0.083249 | micro:0.227864 ± 0.014637
# Epoch 42/200 | Train(sampled) L1:0.036672 L4:0.002088 |
#           >> Test macro:0.157943 ± 0.083445 | micro:0.227761 ± 0.013104
# Epoch 43/200 | Train(sampled) L1:0.038229 L4:0.002506 |
#           >> Test macro:0.156004 ± 0.082469 | micro:0.226423 ± 0.012539
# Epoch 44/200 | Train(sampled) L1:0.037173 L4:0.001646 |
#           >> Test macro:0.178993 ± 0.096539 | micro:0.257974 ± 0.012830
# Epoch 45/200 | Train(sampled) L1:0.038865 L4:0.001295 |
#           >> Test macro:0.147499 ± 0.078018 | micro:0.212639 ± 0.012759
# Epoch 46/200 | Train(sampled) L1:0.037283 L4:0.001201 |
#           >> Test macro:0.162808 ± 0.086126 | micro:0.232353 ± 0.013706
# Epoch 47/200 | Train(sampled) L1:0.034999 L4:0.001246 |
#           >> Test macro:0.163751 ± 0.088908 | micro:0.234827 ± 0.013227
# Epoch 48/200 | Train(sampled) L1:0.034417 L4:0.002158 |
#           >> Test macro:0.153834 ± 0.079704 | micro:0.222075 ± 0.012466
# Epoch 49/200 | Train(sampled) L1:0.034237 L4:0.001445 |
#           >> Test macro:0.170058 ± 0.091512 | micro:0.243018 ± 0.014013
# Epoch 50/200 | Train(sampled) L1:0.036991 L4:0.001312 |
#           >> Test macro:0.169080 ± 0.090889 | micro:0.243093 ± 0.013747
# Epoch 51/200 | Train(sampled) L1:0.034333 L4:0.001048 |
#           >> Test macro:0.152054 ± 0.080645 | micro:0.218966 ± 0.012668
# Epoch 52/200 | Train(sampled) L1:0.030629 L4:0.001200 |
#           >> Test macro:0.156578 ± 0.083881 | micro:0.227311 ± 0.012653
# Epoch 53/200 | Train(sampled) L1:0.032337 L4:0.001002 |
#           >> Test macro:0.168121 ± 0.085705 | micro:0.243413 ± 0.012437
# Epoch 54/200 | Train(sampled) L1:0.031430 L4:0.001442 |
#           >> Test macro:0.169454 ± 0.091658 | micro:0.244986 ± 0.012456
# Epoch 55/200 | Train(sampled) L1:0.031026 L4:0.001133 |
#           >> Test macro:0.157621 ± 0.085035 | micro:0.225687 ± 0.013066
# Early stopping at epoch 55/200 (best test macro-MSE: 0.147499 @ epoch 45)
# TEST RESULTS | macro: 0.157621 ± 0.085035 | micro: 0.225687 ± 0.013066
#           >> per_group (weighted SE): {0: '0.297639 ± 0.027856 (n=777)', 1: '0.004011 ± 0.001891 (n=3)', 5: '0.171214 ± 0.008587 (n=1019)'}

# %%
res_odejump_encoder = odejump_encoder.train_cognite(
    df=df_scaled_rebuilt,
    feature_cols=list(df_scaled.columns[:-1]),
    static_features_cols=None,
    timestamp_col='index',
    states_col='states',
    batch_size=256,
    window_size=30,
    window_step=30,
    epochs = 200,
    validate=False,
    df_denoised=df_scaled_denoised,
    patience=20
    #lr=2e-4
)
res_odejump_encoder = [r for r in res_odejump_encoder if r is not None]  # remove None results
# Out:
# GRUPOS (total): {0: 3886, 1: 15, 5: 5093}
# GRUPOS (train): {0: 3109, 1: 12, 5: 4074}
# GRUPOS (test):  {0: 777, 1: 3, 5: 1019}
# Epoch 1/200 | Train(sampled) L1:57.067328 L4:0.583869 |
#           >> Test macro:382.081857 ± 380.894182 | micro:3.023139 ± 1.099880
# Epoch 2/200 | Train(sampled) L1:49.915896 L4:0.407712 |
#           >> Test macro:354.225127 ± 353.321775 | micro:2.615464 ± 1.020199
# Epoch 3/200 | Train(sampled) L1:50.741729 L4:0.265860 |
#           >> Test macro:329.017265 ± 328.547368 | micro:2.093906 ± 0.948573
# Epoch 4/200 | Train(sampled) L1:43.939428 L4:0.182928 |
#           >> Test macro:299.871538 ± 299.422963 | micro:1.930211 ± 0.864515
# Epoch 5/200 | Train(sampled) L1:38.452493 L4:0.156334 |
#           >> Test macro:265.958413 ± 265.525401 | micro:1.744976 ± 0.766771
# Epoch 6/200 | Train(sampled) L1:34.382060 L4:0.142386 |
#           >> Test macro:226.662093 ± 226.245679 | micro:1.531307 ± 0.653561
# Epoch 7/200 | Train(sampled) L1:27.354396 L4:0.129453 |
#           >> Test macro:176.954310 ± 176.560278 | micro:1.262410 ± 0.510108
# Epoch 8/200 | Train(sampled) L1:21.293091 L4:0.120482 |
#           >> Test macro:124.847482 ± 124.447338 | micro:1.009752 ± 0.359871
# Epoch 9/200 | Train(sampled) L1:13.662945 L4:0.114142 |
#           >> Test macro:75.312065 ± 74.856345 | micro:0.818054 ± 0.217204
# Epoch 10/200 | Train(sampled) L1:7.652921 L4:0.110623 |
#           >> Test macro:34.204827 ± 33.801677 | micro:0.560209 ± 0.099781
# Epoch 11/200 | Train(sampled) L1:3.103520 L4:0.106086 |
#           >> Test macro:8.961375 ± 8.495225 | micro:0.492125 ± 0.033221
# Epoch 12/200 | Train(sampled) L1:0.550185 L4:0.099547 |
#           >> Test macro:0.339025 ± 0.057147 | micro:0.339302 ± 0.019600
# Epoch 13/200 | Train(sampled) L1:0.105885 L4:0.077540 |
#           >> Test macro:0.279257 ± 0.104578 | micro:0.345658 ± 0.022401
# Epoch 14/200 | Train(sampled) L1:0.095956 L4:0.060294 |
#           >> Test macro:0.278077 ± 0.098699 | micro:0.345639 ± 0.017998
# Epoch 15/200 | Train(sampled) L1:0.085128 L4:0.038208 |
#           >> Test macro:0.261520 ± 0.116267 | micro:0.345975 ± 0.018866
# Epoch 16/200 | Train(sampled) L1:0.107916 L4:0.038493 |
#           >> Test macro:0.333136 ± 0.054246 | micro:0.337815 ± 0.016840
# Epoch 17/200 | Train(sampled) L1:0.088926 L4:0.029288 |
#           >> Test macro:0.368348 ± 0.075112 | micro:0.299497 ± 0.016148
# Epoch 18/200 | Train(sampled) L1:0.117995 L4:0.015544 |
#           >> Test macro:0.303470 ± 0.067860 | micro:0.345144 ± 0.017131
# Epoch 19/200 | Train(sampled) L1:0.164538 L4:0.019687 |
#           >> Test macro:1.687938 ± 1.362204 | micro:0.322569 ± 0.018321
# Epoch 20/200 | Train(sampled) L1:0.081435 L4:0.024307 |
#           >> Test macro:0.839746 ± 0.527162 | micro:0.306090 ± 0.016805
# Epoch 21/200 | Train(sampled) L1:0.078493 L4:0.013787 |
#           >> Test macro:0.659717 ± 0.370968 | micro:0.282772 ± 0.015569
# Epoch 22/200 | Train(sampled) L1:0.063733 L4:0.007335 |
#           >> Test macro:0.766808 ± 0.470884 | micro:0.289509 ± 0.015904
# Epoch 23/200 | Train(sampled) L1:0.066203 L4:0.005854 |
#           >> Test macro:2.342657 ± 2.050312 | micro:0.292281 ± 0.018798
# Epoch 24/200 | Train(sampled) L1:0.077714 L4:0.005261 |
#           >> Test macro:4.778348 ± 4.486932 | micro:0.304689 ± 0.027019
# Epoch 25/200 | Train(sampled) L1:0.067042 L4:0.010714 |
#           >> Test macro:2.965600 ± 2.666952 | micro:0.305545 ± 0.019331
# Epoch 26/200 | Train(sampled) L1:0.063290 L4:0.003426 |
#           >> Test macro:4.239683 ± 3.946903 | micro:0.305945 ± 0.024787
# Epoch 27/200 | Train(sampled) L1:0.062870 L4:0.002244 |
#           >> Test macro:3.757897 ± 3.478601 | micro:0.287037 ± 0.023239
# Epoch 28/200 | Train(sampled) L1:0.066784 L4:0.005481 |
#           >> Test macro:3.303912 ± 2.971705 | micro:0.339224 ± 0.022304
# Epoch 29/200 | Train(sampled) L1:0.064880 L4:0.001569 |
#           >> Test macro:3.172780 ± 2.892681 | micro:0.284847 ± 0.021014
# Epoch 30/200 | Train(sampled) L1:0.052797 L4:0.003486 |
#           >> Test macro:2.519812 ± 2.254067 | micro:0.269744 ± 0.018204
# Epoch 31/200 | Train(sampled) L1:0.058039 L4:0.001555 |
#           >> Test macro:4.009230 ± 3.698329 | micro:0.324726 ± 0.023325
# Epoch 32/200 | Train(sampled) L1:0.065436 L4:0.001905 |
#           >> Test macro:2.444251 ± 2.166885 | micro:0.277678 ± 0.020212
# Epoch 33/200 | Train(sampled) L1:0.048989 L4:0.000976 |
#           >> Test macro:2.287628 ± 2.007137 | micro:0.282455 ± 0.018437
# Epoch 34/200 | Train(sampled) L1:0.051643 L4:0.000919 |
#           >> Test macro:1.095907 ± 0.823657 | micro:0.267631 ± 0.016061
# Epoch 35/200 | Train(sampled) L1:0.049582 L4:0.002161 |
#           >> Test macro:2.029667 ± 1.772127 | micro:0.259064 ± 0.017231
# Epoch 36/200 | Train(sampled) L1:0.053717 L4:0.004181 |
#           >> Test macro:1.046072 ± 0.707054 | micro:0.330290 ± 0.016700
# Epoch 37/200 | Train(sampled) L1:0.053292 L4:0.000708 |
#           >> Test macro:2.737818 ± 2.487668 | micro:0.255127 ± 0.018834
# Epoch 38/200 | Train(sampled) L1:0.048910 L4:0.000610 |
#           >> Test macro:1.443053 ± 1.181001 | micro:0.259836 ± 0.017312
# Epoch 39/200 | Train(sampled) L1:0.050904 L4:0.001085 |
#           >> Test macro:1.207407 ± 0.940356 | micro:0.262065 ± 0.015904
# Epoch 40/200 | Train(sampled) L1:0.045825 L4:0.000395 |
#           >> Test macro:1.160706 ± 0.884929 | micro:0.273350 ± 0.014639
# Epoch 41/200 | Train(sampled) L1:0.053304 L4:0.000789 |
#           >> Test macro:1.208670 ± 0.953300 | micro:0.253118 ± 0.016001
# Epoch 42/200 | Train(sampled) L1:0.049050 L4:0.001075 |
#           >> Test macro:0.941241 ± 0.650051 | micro:0.285891 ± 0.014184
# Epoch 43/200 | Train(sampled) L1:0.046701 L4:0.000594 |
#           >> Test macro:0.865479 ± 0.612174 | micro:0.249288 ± 0.014885
# Epoch 44/200 | Train(sampled) L1:0.043909 L4:0.000704 |
#           >> Test macro:0.913149 ± 0.653390 | micro:0.256379 ± 0.015022
# Epoch 45/200 | Train(sampled) L1:0.052428 L4:0.000617 |
#           >> Test macro:0.859868 ± 0.596582 | micro:0.259450 ± 0.013707
# Epoch 46/200 | Train(sampled) L1:0.049586 L4:0.000630 |
#           >> Test macro:0.926158 ± 0.675647 | micro:0.246145 ± 0.016296
# Epoch 47/200 | Train(sampled) L1:0.046356 L4:0.000340 |
#           >> Test macro:1.086827 ± 0.783995 | micro:0.300469 ± 0.015026
# Epoch 48/200 | Train(sampled) L1:0.045830 L4:0.000331 |
#           >> Test macro:1.088129 ± 0.833962 | micro:0.249784 ± 0.015704
# Epoch 49/200 | Train(sampled) L1:0.051833 L4:0.000309 |
#           >> Test macro:0.856887 ± 0.524464 | micro:0.327080 ± 0.017772
# Epoch 50/200 | Train(sampled) L1:0.048682 L4:0.000529 |
#           >> Test macro:0.858677 ± 0.601033 | micro:0.252600 ± 0.016555
# Epoch 51/200 | Train(sampled) L1:0.040290 L4:0.000458 |
#           >> Test macro:0.761413 ± 0.514978 | micro:0.241825 ± 0.015343
# Epoch 52/200 | Train(sampled) L1:0.043638 L4:0.000286 |
#           >> Test macro:1.142964 ± 0.886865 | micro:0.253319 ± 0.015002
# Epoch 53/200 | Train(sampled) L1:0.043629 L4:0.000212 |
#           >> Test macro:0.957139 ± 0.708252 | micro:0.245983 ± 0.013910
# Epoch 54/200 | Train(sampled) L1:0.043396 L4:0.000233 |
#           >> Test macro:0.525753 ± 0.272798 | micro:0.248914 ± 0.014403
# Epoch 55/200 | Train(sampled) L1:0.042808 L4:0.000240 |
#           >> Test macro:0.426277 ± 0.179658 | micro:0.242739 ± 0.014878
# Epoch 56/200 | Train(sampled) L1:0.040006 L4:0.000235 |
#           >> Test macro:0.546267 ± 0.309150 | micro:0.232516 ± 0.014578
# Epoch 57/200 | Train(sampled) L1:0.043535 L4:0.000197 |
#           >> Test macro:0.365766 ± 0.120919 | micro:0.242442 ± 0.014370
# Epoch 58/200 | Train(sampled) L1:0.043588 L4:0.000390 |
#           >> Test macro:0.436363 ± 0.180623 | micro:0.252058 ± 0.013536
# Epoch 59/200 | Train(sampled) L1:0.041383 L4:0.000179 |
#           >> Test macro:0.453797 ± 0.211170 | micro:0.238219 ± 0.013200
# Epoch 60/200 | Train(sampled) L1:0.039943 L4:0.000138 |
#           >> Test macro:0.433718 ± 0.201781 | micro:0.228384 ± 0.012292
# Epoch 61/200 | Train(sampled) L1:0.039063 L4:0.000134 |
#           >> Test macro:0.462793 ± 0.196984 | micro:0.261712 ± 0.013115
# Epoch 62/200 | Train(sampled) L1:0.046107 L4:0.000281 |
#           >> Test macro:0.376033 ± 0.120129 | micro:0.253373 ± 0.013632
# Epoch 63/200 | Train(sampled) L1:0.036327 L4:0.000169 |
#           >> Test macro:0.415239 ± 0.172767 | micro:0.238805 ± 0.013191
# Epoch 64/200 | Train(sampled) L1:0.038801 L4:0.000178 |
#           >> Test macro:0.468806 ± 0.217800 | micro:0.246784 ± 0.013377
# Epoch 65/200 | Train(sampled) L1:0.035356 L4:0.000105 |
#           >> Test macro:0.276200 ± 0.052893 | micro:0.226713 ± 0.012902
# Epoch 66/200 | Train(sampled) L1:0.034269 L4:0.000123 |
#           >> Test macro:0.356651 ± 0.117555 | micro:0.236621 ± 0.012690
# Epoch 67/200 | Train(sampled) L1:0.038282 L4:0.000262 |
#           >> Test macro:0.377062 ± 0.127765 | micro:0.246735 ± 0.015120
# Epoch 68/200 | Train(sampled) L1:0.037790 L4:0.000194 |
#           >> Test macro:0.364957 ± 0.107120 | micro:0.256550 ± 0.014546
# Epoch 69/200 | Train(sampled) L1:0.033061 L4:0.000240 |
#           >> Test macro:0.357865 ± 0.121121 | micro:0.234639 ± 0.014783
# Epoch 70/200 | Train(sampled) L1:0.035974 L4:0.000103 |
#           >> Test macro:0.361165 ± 0.130185 | micro:0.228230 ± 0.014012
# Epoch 71/200 | Train(sampled) L1:0.032507 L4:0.000138 |
#           >> Test macro:0.397061 ± 0.150039 | micro:0.243762 ± 0.014621
# Epoch 72/200 | Train(sampled) L1:0.034250 L4:0.000130 |
#           >> Test macro:0.339539 ± 0.093463 | micro:0.245877 ± 0.013336
# Epoch 73/200 | Train(sampled) L1:0.040980 L4:0.000129 |
#           >> Test macro:0.328671 ± 0.085958 | micro:0.242302 ± 0.013790
# Epoch 74/200 | Train(sampled) L1:0.039053 L4:0.000147 |
#           >> Test macro:0.378879 ± 0.112308 | micro:0.264396 ± 0.012335
# Epoch 75/200 | Train(sampled) L1:0.033479 L4:0.000142 |
#           >> Test macro:0.262593 ± 0.040745 | micro:0.230914 ± 0.013558
# Epoch 76/200 | Train(sampled) L1:0.030817 L4:0.000111 |
#           >> Test macro:0.336047 ± 0.093080 | micro:0.241983 ± 0.012858
# Epoch 77/200 | Train(sampled) L1:0.032093 L4:0.000111 |
#           >> Test macro:0.300271 ± 0.059160 | micro:0.244512 ± 0.012953
# Epoch 78/200 | Train(sampled) L1:0.030799 L4:0.000105 |
#           >> Test macro:0.336067 ± 0.089552 | micro:0.247074 ± 0.015207
# Epoch 79/200 | Train(sampled) L1:0.030597 L4:0.000152 |
#           >> Test macro:0.307469 ± 0.066258 | micro:0.241199 ± 0.011834
# Epoch 80/200 | Train(sampled) L1:0.030789 L4:0.000114 |
#           >> Test macro:0.339396 ± 0.086593 | micro:0.253854 ± 0.015607
# Epoch 81/200 | Train(sampled) L1:0.028927 L4:0.000112 |
#           >> Test macro:0.294190 ± 0.051750 | micro:0.244172 ± 0.012075
# Epoch 82/200 | Train(sampled) L1:0.028716 L4:0.000177 |
#           >> Test macro:0.314393 ± 0.074025 | micro:0.240323 ± 0.011692
# Epoch 83/200 | Train(sampled) L1:0.029744 L4:0.000108 |
#           >> Test macro:0.297084 ± 0.050389 | micro:0.253457 ± 0.011807
# Epoch 84/200 | Train(sampled) L1:0.030351 L4:0.000157 |
#           >> Test macro:0.303593 ± 0.054449 | micro:0.253891 ± 0.012853
# Epoch 85/200 | Train(sampled) L1:0.030327 L4:0.000187 |
#           >> Test macro:0.321544 ± 0.079699 | micro:0.241251 ± 0.011211
# Early stopping at epoch 85/200 (best test macro-MSE: 0.252518 @ epoch 65)
# TEST RESULTS | macro: 0.321544 ± 0.079699 | micro: 0.241251 ± 0.011211
#           >> per_group (weighted SE): {0: '0.301649 ± 0.022444 (n=777)', 1: '0.468455 ± 0.335274 (n=3)', 5: '0.194528 ± 0.009636 (n=1019)'}

# %%
df_scaled.columns[:-1]
# Out:
# Index(['PH (CBM) 1st Stage ExpPress Ratio', 'PH (CBM) 1st Stage Poly Head Dev',
#        'PH (CBM) 1st Stage ActShaft Power', 'PH (CBM) 1st Stage Press Rat Dev',
#        'PH (CBM) 1st Stg ActCompr Poly Head',
#        'PH (CBM) 1st Stage Shft Pwr Dev',
#        'PH (CBM) 1st Stage ActCompr Poly Eff',
#        'PH (CBM) 1st Stage ExpCompr Poly Eff',
#        'PH (CBM) 1st Stage ExpShaft Power',
#        'PH (CBM) 1st Stage ActPress Ratio',
#        'PH (CBM) 1st Stg ExpCompr Poly Head'],
#       dtype='object')

# %%
with open("cognite_odejump_encoder_results.json", "w") as f:
    json.dump(res_odejump_encoder, f)

# %% [markdown]
# ### 13. TSDiffusion

# %%
import sys
importlib.reload(sys.modules['tsdiffusion_transformed.tsdiffusion'])
#importlib.reload(sys.modules['tsdiffusion_transformed.ode_jump_encoder'])
#importlib.reload(sys.modules['tsdiffusion_transformed.ode_jump'])
from tsdiffusion_transformed.tsdiffusion import TSDiffusion
from tsdiffusion_transformed.ode_jump import ODEJump
from tsdiffusion_transformed.ode_jump_encoder import ODEJumpEncoder

# %%
tsdiffusion = TSDiffusion(
    in_channels=11,
    hidden_dim=11*32,
    lam=[0.45,0.5,0.05],
    n_layers=12,
    n_layers_g=2
)
# Out:
# /root/coppe/3Wve/lib/python3.12/site-packages/torch/nn/modules/transformer.py:382: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(

# %%
#Only GRU test
tsdiffusion.lam=[0.95,0,0.05]
res_tsdiffusion = tsdiffusion.train_cognite(
    df=df_scaled,
    feature_cols=list(df_scaled.columns[:-1]),
    static_features_cols=None,
    timestamp_col='index',
    states_col='states',
    batch_size=256,
    window_size=30,
    window_step=30,
    epochs = 500,
    validate=False,
    only_gru=True,
    patience=50
)
res_tsdiffusion = [r for r in res_tsdiffusion if r is not None]  # remove None results
# Out:
# GRUPOS (total): {0: 3886, 1: 15, 5: 5093}
# GRUPOS (train): {0: 3109, 1: 12, 5: 4074}
# GRUPOS (test):  {0: 777, 1: 3, 5: 1019}
# Epoch 1/500 | Train(sampled) L1:322.292871 L2:0.000000 L4:1.075919 |
#           >> Test macro:842.210322 ± 840.622945 | micro:3.859192 ± 2.076391          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 2/500 | Train(sampled) L1:311.082658 L2:0.000000 L4:1.074560 |
#           >> Test macro:963.598668 ± 961.963821 | micro:3.548680 ± 1.937765          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 3/500 | Train(sampled) L1:256.666220 L2:0.000000 L4:1.068995 |
#           >> Test macro:935.640391 ± 934.019519 | micro:4.574914 ± 2.257601          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 4/500 | Train(sampled) L1:181.903271 L2:0.000000 L4:1.075144 |
#           >> Test macro:893.068868 ± 891.460207 | micro:4.626952 ± 2.172204          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 5/500 | Train(sampled) L1:118.582038 L2:0.000000 L4:1.090538 |
#           >> Test macro:929.187464 ± 927.616603 | micro:4.710875 ± 2.278805          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 6/500 | Train(sampled) L1:72.307994 L2:0.000000 L4:1.097865 |
#           >> Test macro:901.305994 ± 899.828231 | micro:3.245240 ± 1.687128          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 7/500 | Train(sampled) L1:31.282471 L2:0.000000 L4:1.016573 |
#           >> Test macro:874.656808 ± 873.232940 | micro:4.453085 ± 2.196470          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 8/500 | Train(sampled) L1:11.569836 L2:0.000000 L4:0.866102 |
#           >> Test macro:905.540449 ± 904.043552 | micro:3.048606 ± 1.607697          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 9/500 | Train(sampled) L1:5.628568 L2:0.000000 L4:0.715394 |
#           >> Test macro:953.338124 ± 951.914631 | micro:4.540899 ± 2.304057          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 10/500 | Train(sampled) L1:3.553996 L2:0.000000 L4:0.589926 |
#           >> Test macro:964.782139 ± 963.420499 | micro:4.385779 ± 2.261844          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 11/500 | Train(sampled) L1:3.040457 L2:0.000000 L4:0.525543 |
#           >> Test macro:920.488287 ± 919.281120 | micro:3.906433 ± 2.123759          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 12/500 | Train(sampled) L1:2.856964 L2:0.000000 L4:0.493345 |
#           >> Test macro:966.315785 ± 965.182397 | micro:3.784741 ± 2.199638          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 13/500 | Train(sampled) L1:2.643691 L2:0.000000 L4:0.471435 |
#           >> Test macro:921.291688 ± 920.228239 | micro:4.675453 ± 2.386359          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 14/500 | Train(sampled) L1:2.565962 L2:0.000000 L4:0.469838 |
#           >> Test macro:926.814104 ± 925.831285 | micro:4.513972 ± 2.406187          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 15/500 | Train(sampled) L1:2.480390 L2:0.000000 L4:0.457936 |
#           >> Test macro:867.376713 ± 866.414026 | micro:3.337929 ± 1.919401          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 16/500 | Train(sampled) L1:2.529443 L2:0.000000 L4:0.453312 |
#           >> Test macro:979.379537 ± 978.521615 | micro:4.081526 ± 2.416728          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 17/500 | Train(sampled) L1:2.391140 L2:0.000000 L4:0.440123 |
#           >> Test macro:922.953140 ± 922.106065 | micro:5.048783 ± 2.577499          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 18/500 | Train(sampled) L1:2.253079 L2:0.000000 L4:0.434865 |
#           >> Test macro:962.520315 ± 961.710205 | micro:3.849713 ± 2.275722          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 19/500 | Train(sampled) L1:2.519441 L2:0.000000 L4:0.425163 |
#           >> Test macro:959.509648 ± 958.653805 | micro:4.415382 ± 2.414844          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 20/500 | Train(sampled) L1:2.125676 L2:0.000000 L4:0.415783 |
#           >> Test macro:892.283680 ± 891.496471 | micro:4.569381 ± 2.417834          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 21/500 | Train(sampled) L1:2.317300 L2:0.000000 L4:0.406641 |
#           >> Test macro:882.357846 ± 881.587843 | micro:3.458546 ± 2.051782          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 22/500 | Train(sampled) L1:2.035378 L2:0.000000 L4:0.398152 |
#           >> Test macro:996.214113 ± 995.469358 | micro:4.320972 ± 2.469027          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 23/500 | Train(sampled) L1:2.070935 L2:0.000000 L4:0.388778 |
#           >> Test macro:934.966700 ± 934.232935 | micro:3.496386 ± 2.223359          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 24/500 | Train(sampled) L1:2.024953 L2:0.000000 L4:0.374470 |
#           >> Test macro:925.122012 ± 924.441331 | micro:4.775386 ± 2.644369          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 25/500 | Train(sampled) L1:2.057507 L2:0.000000 L4:0.363162 |
#           >> Test macro:913.339318 ± 912.675514 | micro:2.351881 ± 1.643718          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 26/500 | Train(sampled) L1:1.886172 L2:0.000000 L4:0.351107 |
#           >> Test macro:894.026638 ± 893.368031 | micro:2.830629 ± 1.832500          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 27/500 | Train(sampled) L1:1.791883 L2:0.000000 L4:0.339458 |
#           >> Test macro:896.168180 ± 895.544880 | micro:2.793999 ± 1.862109          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 28/500 | Train(sampled) L1:1.811595 L2:0.000000 L4:0.323065 |
#           >> Test macro:936.130193 ± 935.533968 | micro:2.324703 ± 1.724440          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 29/500 | Train(sampled) L1:1.711482 L2:0.000000 L4:0.304852 |
#           >> Test macro:815.872173 ± 815.256804 | micro:2.552159 ± 1.691362          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 30/500 | Train(sampled) L1:1.717743 L2:0.000000 L4:0.288832 |
#           >> Test macro:801.425475 ± 800.847383 | micro:2.181738 ± 1.500057          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 31/500 | Train(sampled) L1:1.671444 L2:0.000000 L4:0.267059 |
#           >> Test macro:908.232296 ± 907.681412 | micro:2.597766 ± 1.986827          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 32/500 | Train(sampled) L1:1.687613 L2:0.000000 L4:0.249470 |
#           >> Test macro:929.682897 ± 929.117994 | micro:4.675818 ± 2.636967          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 33/500 | Train(sampled) L1:1.644171 L2:0.000000 L4:0.231193 |
#           >> Test macro:849.761956 ± 849.242353 | micro:3.106860 ± 1.956803          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 34/500 | Train(sampled) L1:1.907245 L2:0.000000 L4:0.212763 |
#           >> Test macro:911.732293 ± 911.190387 | micro:3.952197 ± 2.449764          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 35/500 | Train(sampled) L1:1.549038 L2:0.000000 L4:0.193743 |
#           >> Test macro:921.776168 ± 921.218358 | micro:3.268219 ± 2.272378          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 36/500 | Train(sampled) L1:1.754670 L2:0.000000 L4:0.174576 |
#           >> Test macro:895.526349 ± 895.039276 | micro:3.196430 ± 2.331053          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 37/500 | Train(sampled) L1:1.547279 L2:0.000000 L4:0.160016 |
#           >> Test macro:889.869685 ± 889.347632 | micro:3.340883 ± 2.111317          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 38/500 | Train(sampled) L1:1.528752 L2:0.000000 L4:0.143317 |
#           >> Test macro:904.012137 ± 903.564356 | micro:4.379990 ± 2.508374          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 39/500 | Train(sampled) L1:1.548562 L2:0.000000 L4:0.122665 |
#           >> Test macro:885.046988 ± 884.584141 | micro:3.350873 ± 2.133708          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 40/500 | Train(sampled) L1:1.574250 L2:0.000000 L4:0.112171 |
#           >> Test macro:895.250045 ± 894.803399 | micro:4.366531 ± 2.507450          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 41/500 | Train(sampled) L1:1.553283 L2:0.000000 L4:0.099843 |
#           >> Test macro:992.266657 ± 991.794025 | micro:3.078328 ± 2.157694          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 42/500 | Train(sampled) L1:1.464717 L2:0.000000 L4:0.090943 |
#           >> Test macro:925.348980 ± 924.904232 | micro:4.852767 ± 2.706049          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 43/500 | Train(sampled) L1:1.516963 L2:0.000000 L4:0.081441 |
#           >> Test macro:958.307355 ± 957.849036 | micro:3.351031 ± 2.182651          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 44/500 | Train(sampled) L1:1.458760 L2:0.000000 L4:0.071668 |
#           >> Test macro:809.506031 ± 809.110736 | micro:2.433267 ± 1.715121          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 45/500 | Train(sampled) L1:1.447138 L2:0.000000 L4:0.063804 |
#           >> Test macro:849.820392 ± 849.402222 | micro:3.339198 ± 2.139901          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 46/500 | Train(sampled) L1:1.391874 L2:0.000000 L4:0.057230 |
#           >> Test macro:834.890208 ± 834.504951 | micro:3.746101 ± 2.347036          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 47/500 | Train(sampled) L1:1.414559 L2:0.000000 L4:0.049490 |
#           >> Test macro:810.499789 ± 810.110598 | micro:1.449007 ± 1.274927          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 48/500 | Train(sampled) L1:1.437884 L2:0.000000 L4:0.044578 |
#           >> Test macro:840.537200 ± 840.133710 | micro:4.001199 ± 2.376436          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 49/500 | Train(sampled) L1:1.399136 L2:0.000000 L4:0.041225 |
#           >> Test macro:826.168628 ± 825.783829 | micro:3.566577 ± 2.353842          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 50/500 | Train(sampled) L1:1.434227 L2:0.000000 L4:0.036670 |
#           >> Test macro:891.536552 ± 891.152142 | micro:3.384356 ± 2.238405          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 51/500 | Train(sampled) L1:1.419357 L2:0.000000 L4:0.034677 |
#           >> Test macro:854.889512 ± 854.523609 | micro:4.544552 ± 2.455728          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 52/500 | Train(sampled) L1:1.401710 L2:0.000000 L4:0.032038 |
#           >> Test macro:772.527753 ± 772.177336 | micro:3.161269 ± 1.989868          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 53/500 | Train(sampled) L1:1.371801 L2:0.000000 L4:0.028335 |
#           >> Test macro:825.592201 ± 825.254746 | micro:2.866822 ± 1.892919          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 54/500 | Train(sampled) L1:1.353672 L2:0.000000 L4:0.027327 |
#           >> Test macro:756.361167 ± 756.008150 | micro:2.247507 ± 1.832680          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 55/500 | Train(sampled) L1:1.370571 L2:0.000000 L4:0.024944 |
#           >> Test macro:754.206681 ± 753.851514 | micro:3.510059 ± 2.149258          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 56/500 | Train(sampled) L1:1.400113 L2:0.000000 L4:0.023730 |
#           >> Test macro:763.009580 ± 762.678417 | micro:2.438012 ± 1.675631          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 57/500 | Train(sampled) L1:1.377232 L2:0.000000 L4:0.021935 |
#           >> Test macro:877.298631 ± 876.927397 | micro:3.810587 ± 2.299361          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 58/500 | Train(sampled) L1:1.452682 L2:0.000000 L4:0.019744 |
#           >> Test macro:785.411130 ± 785.074377 | micro:2.793311 ± 1.806728          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 59/500 | Train(sampled) L1:1.375644 L2:0.000000 L4:0.018968 |
#           >> Test macro:783.105525 ± 782.788397 | micro:3.176964 ± 2.032722          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 60/500 | Train(sampled) L1:1.345728 L2:0.000000 L4:0.018137 |
#           >> Test macro:806.694354 ± 806.342927 | micro:2.138545 ± 1.710908          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 61/500 | Train(sampled) L1:1.315182 L2:0.000000 L4:0.016162 |
#           >> Test macro:721.524909 ± 721.186868 | micro:3.533023 ± 1.969820          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 62/500 | Train(sampled) L1:1.326109 L2:0.000000 L4:0.016458 |
#           >> Test macro:804.706313 ± 804.383205 | micro:3.467662 ± 2.130810          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 63/500 | Train(sampled) L1:1.349160 L2:0.000000 L4:0.015800 |
#           >> Test macro:745.931252 ± 745.580949 | micro:2.159879 ± 1.755976          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 64/500 | Train(sampled) L1:1.317107 L2:0.000000 L4:0.014745 |
#           >> Test macro:769.281956 ± 768.958302 | micro:3.240944 ± 1.973948          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 65/500 | Train(sampled) L1:1.324118 L2:0.000000 L4:0.014108 |
#           >> Test macro:725.670354 ± 725.324499 | micro:2.668938 ± 1.782793          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 66/500 | Train(sampled) L1:1.310990 L2:0.000000 L4:0.013988 |
#           >> Test macro:733.978925 ± 733.640630 | micro:3.868335 ± 2.193949          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 67/500 | Train(sampled) L1:1.410246 L2:0.000000 L4:0.013421 |
#           >> Test macro:847.913449 ± 847.578612 | micro:2.672054 ± 1.889003          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 68/500 | Train(sampled) L1:1.298844 L2:0.000000 L4:0.012900 |
#           >> Test macro:631.994732 ± 631.641207 | micro:2.746849 ± 1.653508          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 69/500 | Train(sampled) L1:1.334581 L2:0.000000 L4:0.012424 |
#           >> Test macro:701.521679 ± 701.190839 | micro:2.797269 ± 1.876786          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 70/500 | Train(sampled) L1:1.267188 L2:0.000000 L4:0.012079 |
#           >> Test macro:751.398518 ± 751.054542 | micro:3.076300 ± 2.033398          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 71/500 | Train(sampled) L1:1.310652 L2:0.000000 L4:0.011699 |
#           >> Test macro:684.401646 ± 684.062923 | micro:2.212809 ± 1.593276          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 72/500 | Train(sampled) L1:1.288515 L2:0.000000 L4:0.011743 |
#           >> Test macro:677.110305 ± 676.767581 | micro:2.547194 ± 1.636864          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 73/500 | Train(sampled) L1:1.244127 L2:0.000000 L4:0.011156 |
#           >> Test macro:700.642614 ± 700.290002 | micro:3.109103 ± 2.059091          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 74/500 | Train(sampled) L1:1.270786 L2:0.000000 L4:0.010623 |
#           >> Test macro:630.025978 ± 629.626023 | micro:2.478308 ± 1.554965          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 75/500 | Train(sampled) L1:1.316034 L2:0.000000 L4:0.010383 |
#           >> Test macro:611.895091 ± 611.489060 | micro:3.414616 ± 1.805277          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 76/500 | Train(sampled) L1:1.252950 L2:0.000000 L4:0.010271 |
#           >> Test macro:613.977277 ± 613.562259 | micro:2.384003 ± 1.453057          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 77/500 | Train(sampled) L1:1.258514 L2:0.000000 L4:0.010223 |
#           >> Test macro:664.948041 ± 664.525597 | micro:2.975596 ± 1.717260          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 78/500 | Train(sampled) L1:1.269175 L2:0.000000 L4:0.009607 |
#           >> Test macro:583.620662 ± 583.213224 | micro:2.597579 ± 1.662785          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 79/500 | Train(sampled) L1:1.263574 L2:0.000000 L4:0.009708 |
#           >> Test macro:657.518626 ± 657.075610 | micro:2.439401 ± 1.562064          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 80/500 | Train(sampled) L1:1.241037 L2:0.000000 L4:0.009710 |
#           >> Test macro:581.468777 ± 580.974658 | micro:2.464623 ± 1.538070          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 81/500 | Train(sampled) L1:1.245224 L2:0.000000 L4:0.009284 |
#           >> Test macro:572.886561 ± 572.407435 | micro:2.075628 ± 1.246831          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 82/500 | Train(sampled) L1:1.218920 L2:0.000000 L4:0.009279 |
#           >> Test macro:615.579009 ± 615.052436 | micro:2.200743 ± 1.323393          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 83/500 | Train(sampled) L1:1.246880 L2:0.000000 L4:0.009058 |
#           >> Test macro:637.578705 ± 637.081266 | micro:3.374929 ± 1.773196          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 84/500 | Train(sampled) L1:1.247581 L2:0.000000 L4:0.009100 |
#           >> Test macro:624.356739 ± 623.772575 | micro:2.744670 ± 1.519281          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 85/500 | Train(sampled) L1:1.200277 L2:0.000000 L4:0.008735 |
#           >> Test macro:554.597985 ± 554.016342 | micro:3.030596 ± 1.534614          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 86/500 | Train(sampled) L1:1.216994 L2:0.000000 L4:0.008243 |
#           >> Test macro:571.879926 ± 571.234168 | micro:2.627187 ± 1.412091          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 87/500 | Train(sampled) L1:1.191926 L2:0.000000 L4:0.008678 |
#           >> Test macro:549.935221 ± 549.305151 | micro:3.682864 ± 1.757875          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 88/500 | Train(sampled) L1:1.181728 L2:0.000000 L4:0.008963 |
#           >> Test macro:534.374233 ± 533.725763 | micro:2.075745 ± 1.181604          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 89/500 | Train(sampled) L1:1.133175 L2:0.000000 L4:0.008725 |
#           >> Test macro:491.286511 ± 490.574643 | micro:2.527699 ± 1.374571          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 90/500 | Train(sampled) L1:1.136605 L2:0.000000 L4:0.007745 |
#           >> Test macro:588.131626 ± 587.437467 | micro:2.649310 ± 1.434264          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 91/500 | Train(sampled) L1:1.156235 L2:0.000000 L4:0.006844 |
#           >> Test macro:588.359277 ± 587.604124 | micro:2.780386 ± 1.511769          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 92/500 | Train(sampled) L1:1.160383 L2:0.000000 L4:0.007475 |
#           >> Test macro:523.102537 ± 522.354172 | micro:1.972247 ± 1.056012          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 93/500 | Train(sampled) L1:1.151117 L2:0.000000 L4:0.007166 |
#           >> Test macro:552.643598 ± 551.931514 | micro:3.048649 ± 1.609459          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 94/500 | Train(sampled) L1:1.112923 L2:0.000000 L4:0.007208 |
#           >> Test macro:572.944788 ± 572.095608 | micro:2.677679 ± 1.342320          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 95/500 | Train(sampled) L1:1.105356 L2:0.000000 L4:0.007328 |
#           >> Test macro:474.556955 ± 473.679838 | micro:2.275241 ± 1.298098          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 96/500 | Train(sampled) L1:1.087571 L2:0.000000 L4:0.006967 |
#           >> Test macro:454.475583 ± 453.660731 | micro:2.192250 ± 1.055060          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 97/500 | Train(sampled) L1:1.070512 L2:0.000000 L4:0.007160 |
#           >> Test macro:475.024800 ± 474.136523 | micro:2.149003 ± 1.030119          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 98/500 | Train(sampled) L1:1.061985 L2:0.000000 L4:0.007547 |
#           >> Test macro:540.611246 ± 539.739816 | micro:2.677006 ± 1.312203          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 99/500 | Train(sampled) L1:1.070754 L2:0.000000 L4:0.006645 |
#           >> Test macro:454.823849 ± 453.925712 | micro:1.610905 ± 0.898023          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 100/500 | Train(sampled) L1:1.077113 L2:0.000000 L4:0.006643 |
#           >> Test macro:462.732490 ± 461.746720 | micro:2.655024 ± 1.194168          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 101/500 | Train(sampled) L1:1.080258 L2:0.000000 L4:0.006056 |
#           >> Test macro:523.390001 ± 522.461374 | micro:2.462169 ± 1.184490          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 102/500 | Train(sampled) L1:1.038192 L2:0.000000 L4:0.005998 |
#           >> Test macro:415.024270 ± 414.091118 | micro:2.625636 ± 1.193490          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 103/500 | Train(sampled) L1:1.046091 L2:0.000000 L4:0.005980 |
#           >> Test macro:531.391602 ± 530.431071 | micro:2.337617 ± 1.132644          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 104/500 | Train(sampled) L1:1.075400 L2:0.000000 L4:0.006003 |
#           >> Test macro:470.128943 ± 469.045978 | micro:2.546132 ± 1.106542          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 105/500 | Train(sampled) L1:1.059669 L2:0.000000 L4:0.005302 |
#           >> Test macro:438.278332 ± 437.198044 | micro:3.006979 ± 1.198532          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 106/500 | Train(sampled) L1:1.008131 L2:0.000000 L4:0.005554 |
#           >> Test macro:461.468042 ± 460.512638 | micro:2.268924 ± 1.044402          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 107/500 | Train(sampled) L1:1.062192 L2:0.000000 L4:0.005249 |
#           >> Test macro:412.498109 ± 411.550344 | micro:1.856708 ± 0.851053          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 108/500 | Train(sampled) L1:1.037664 L2:0.000000 L4:0.004943 |
#           >> Test macro:431.834290 ± 430.682172 | micro:1.964553 ± 0.800934          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 109/500 | Train(sampled) L1:1.033399 L2:0.000000 L4:0.005181 |
#           >> Test macro:461.238943 ± 460.216890 | micro:2.584492 ± 1.147676          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 110/500 | Train(sampled) L1:1.011547 L2:0.000000 L4:0.005028 |
#           >> Test macro:435.375702 ± 434.347604 | micro:2.205344 ± 0.953508          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 111/500 | Train(sampled) L1:1.039914 L2:0.000000 L4:0.004850 |
#           >> Test macro:459.071374 ± 457.986244 | micro:3.112774 ± 1.277736          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 112/500 | Train(sampled) L1:1.004389 L2:0.000000 L4:0.004887 |
#           >> Test macro:401.773273 ± 400.731067 | micro:2.615628 ± 1.041978          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 113/500 | Train(sampled) L1:1.001097 L2:0.000000 L4:0.004474 |
#           >> Test macro:423.543916 ± 422.384434 | micro:2.516113 ± 1.025676          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 114/500 | Train(sampled) L1:1.017128 L2:0.000000 L4:0.004647 |
#           >> Test macro:378.900302 ± 377.879496 | micro:2.813833 ± 1.066678          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 115/500 | Train(sampled) L1:1.025935 L2:0.000000 L4:0.004364 |
#           >> Test macro:401.529508 ± 400.491371 | micro:2.544184 ± 1.022946          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 116/500 | Train(sampled) L1:0.963225 L2:0.000000 L4:0.004167 |
#           >> Test macro:389.772120 ± 388.663933 | micro:2.933193 ± 1.116887          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 117/500 | Train(sampled) L1:0.989557 L2:0.000000 L4:0.003876 |
#           >> Test macro:452.516874 ± 451.381049 | micro:2.917226 ± 1.210060          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 118/500 | Train(sampled) L1:0.990972 L2:0.000000 L4:0.003886 |
#           >> Test macro:415.241618 ± 414.045639 | micro:2.437980 ± 1.082316          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 119/500 | Train(sampled) L1:1.007211 L2:0.000000 L4:0.003901 |
#           >> Test macro:406.097404 ± 404.995187 | micro:2.709174 ± 1.057709          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 120/500 | Train(sampled) L1:0.988772 L2:0.000000 L4:0.003882 |
#           >> Test macro:369.633504 ± 368.528948 | micro:2.189266 ± 0.927914          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 121/500 | Train(sampled) L1:0.977154 L2:0.000000 L4:0.003625 |
#           >> Test macro:387.222959 ± 385.994004 | micro:2.360072 ± 0.965122          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 122/500 | Train(sampled) L1:0.983579 L2:0.000000 L4:0.003449 |
#           >> Test macro:377.209277 ± 375.789128 | micro:2.840687 ± 1.062146          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 123/500 | Train(sampled) L1:0.988947 L2:0.000000 L4:0.003843 |
#           >> Test macro:342.133366 ± 340.911702 | micro:2.322995 ± 0.868736          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 124/500 | Train(sampled) L1:1.043926 L2:0.000000 L4:0.003439 |
#           >> Test macro:360.811048 ± 359.582485 | micro:2.318561 ± 0.841153          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 125/500 | Train(sampled) L1:0.983071 L2:0.000000 L4:0.003651 |
#           >> Test macro:369.878720 ± 368.592326 | micro:2.479077 ± 0.901861          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 126/500 | Train(sampled) L1:1.005289 L2:0.000000 L4:0.003037 |
#           >> Test macro:400.983191 ± 399.717006 | micro:2.825836 ± 1.048857          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 127/500 | Train(sampled) L1:0.983094 L2:0.000000 L4:0.003147 |
#           >> Test macro:365.337623 ± 364.155663 | micro:1.886471 ± 0.678125          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 128/500 | Train(sampled) L1:0.944772 L2:0.000000 L4:0.003173 |
#           >> Test macro:316.259635 ± 314.959437 | micro:2.287754 ± 0.731846          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 129/500 | Train(sampled) L1:0.951078 L2:0.000000 L4:0.003005 |
#           >> Test macro:316.925075 ± 315.729599 | micro:2.640601 ± 0.911032          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 130/500 | Train(sampled) L1:1.035843 L2:0.000000 L4:0.002834 |
#           >> Test macro:332.941740 ± 331.666931 | micro:2.551048 ± 0.876427          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 131/500 | Train(sampled) L1:0.973937 L2:0.000000 L4:0.002965 |
#           >> Test macro:343.482212 ± 342.347508 | micro:2.390975 ± 0.883174          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 132/500 | Train(sampled) L1:0.965031 L2:0.000000 L4:0.002673 |
#           >> Test macro:341.345591 ± 340.079977 | micro:3.063560 ± 1.053633          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 133/500 | Train(sampled) L1:0.957726 L2:0.000000 L4:0.002765 |
#           >> Test macro:338.735887 ± 337.443285 | micro:2.521366 ± 0.844510          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 134/500 | Train(sampled) L1:0.945859 L2:0.000000 L4:0.002810 |
#           >> Test macro:318.102521 ± 316.820216 | micro:2.436072 ± 0.799945          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 135/500 | Train(sampled) L1:0.978720 L2:0.000000 L4:0.003061 |
#           >> Test macro:304.579647 ± 303.306440 | micro:2.130999 ± 0.718132          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 136/500 | Train(sampled) L1:0.958615 L2:0.000000 L4:0.002780 |
#           >> Test macro:308.822595 ± 307.595202 | micro:2.426317 ± 0.806949          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 137/500 | Train(sampled) L1:0.956495 L2:0.000000 L4:0.002692 |
#           >> Test macro:315.171346 ± 313.914078 | micro:2.049534 ± 0.682217          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 138/500 | Train(sampled) L1:0.959195 L2:0.000000 L4:0.002512 |
#           >> Test macro:297.399694 ± 296.081387 | micro:2.344603 ± 0.822016          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 139/500 | Train(sampled) L1:0.957134 L2:0.000000 L4:0.002635 |
#           >> Test macro:281.012930 ± 279.725753 | micro:2.111671 ± 0.643014          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 140/500 | Train(sampled) L1:0.939740 L2:0.000000 L4:0.002835 |
#           >> Test macro:277.145011 ± 275.844010 | micro:2.122369 ± 0.641244          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 141/500 | Train(sampled) L1:0.946835 L2:0.000000 L4:0.002774 |
#           >> Test macro:317.938726 ± 316.734171 | micro:1.943482 ± 0.635306          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 142/500 | Train(sampled) L1:0.942702 L2:0.000000 L4:0.002524 |
#           >> Test macro:285.347224 ± 283.929851 | micro:2.819013 ± 0.872216          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 143/500 | Train(sampled) L1:0.946040 L2:0.000000 L4:0.002358 |
#           >> Test macro:241.618526 ± 240.377412 | micro:2.199132 ± 0.665797          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 144/500 | Train(sampled) L1:0.986930 L2:0.000000 L4:0.002467 |
#           >> Test macro:257.173188 ± 255.895840 | micro:1.934908 ± 0.561235          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 145/500 | Train(sampled) L1:0.942906 L2:0.000000 L4:0.002352 |
#           >> Test macro:267.445213 ± 266.155481 | micro:2.563574 ± 0.767110          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 146/500 | Train(sampled) L1:0.938143 L2:0.000000 L4:0.002309 |
#           >> Test macro:278.082701 ± 276.899200 | micro:2.049305 ± 0.647208          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 147/500 | Train(sampled) L1:0.923318 L2:0.000000 L4:0.002318 |
#           >> Test macro:269.673691 ± 268.296405 | micro:2.079193 ± 0.580022          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 148/500 | Train(sampled) L1:0.959344 L2:0.000000 L4:0.002168 |
#           >> Test macro:243.518557 ± 242.069868 | micro:2.211762 ± 0.599534          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 149/500 | Train(sampled) L1:0.929873 L2:0.000000 L4:0.002327 |
#           >> Test macro:278.986142 ± 277.742973 | micro:2.011261 ± 0.650044          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 150/500 | Train(sampled) L1:0.929617 L2:0.000000 L4:0.002300 |
#           >> Test macro:219.771627 ± 218.310181 | micro:1.909942 ± 0.424223          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 151/500 | Train(sampled) L1:0.939332 L2:0.000000 L4:0.002065 |
#           >> Test macro:276.461956 ± 275.043676 | micro:2.435748 ± 0.695581          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 152/500 | Train(sampled) L1:0.963229 L2:0.000000 L4:0.002051 |
#           >> Test macro:240.890482 ± 239.552038 | micro:2.108035 ± 0.573476          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 153/500 | Train(sampled) L1:0.928561 L2:0.000000 L4:0.002099 |
#           >> Test macro:253.943335 ± 252.493369 | micro:2.176796 ± 0.675173          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 154/500 | Train(sampled) L1:0.903234 L2:0.000000 L4:0.002183 |
#           >> Test macro:248.417986 ± 247.110127 | micro:2.001108 ± 0.545635          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 155/500 | Train(sampled) L1:0.949287 L2:0.000000 L4:0.001841 |
#           >> Test macro:238.283207 ± 236.847915 | micro:2.167008 ± 0.603090          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 156/500 | Train(sampled) L1:0.937466 L2:0.000000 L4:0.001662 |
#           >> Test macro:206.674596 ± 205.314472 | micro:2.116765 ± 0.526954          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 157/500 | Train(sampled) L1:0.896682 L2:0.000000 L4:0.001830 |
#           >> Test macro:197.564662 ± 196.085422 | micro:2.336404 ± 0.543992          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 158/500 | Train(sampled) L1:0.921608 L2:0.000000 L4:0.001794 |
#           >> Test macro:212.909449 ± 211.414475 | micro:2.541803 ± 0.618075          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 159/500 | Train(sampled) L1:0.958022 L2:0.000000 L4:0.001915 |
#           >> Test macro:221.352426 ± 220.041321 | micro:2.090740 ± 0.607903          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 160/500 | Train(sampled) L1:0.909443 L2:0.000000 L4:0.001828 |
#           >> Test macro:224.643644 ± 223.196010 | micro:2.122607 ± 0.548436          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 161/500 | Train(sampled) L1:0.936262 L2:0.000000 L4:0.001901 |
#           >> Test macro:211.792789 ± 210.207551 | micro:2.193248 ± 0.495322          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 162/500 | Train(sampled) L1:0.915008 L2:0.000000 L4:0.001784 |
#           >> Test macro:200.117296 ± 198.672058 | micro:2.401784 ± 0.578051          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 163/500 | Train(sampled) L1:0.944602 L2:0.000000 L4:0.001918 |
#           >> Test macro:187.784322 ± 186.252023 | micro:2.239310 ± 0.493036          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 164/500 | Train(sampled) L1:0.898559 L2:0.000000 L4:0.001696 |
#           >> Test macro:186.637000 ± 185.235349 | micro:1.938218 ± 0.451672          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 165/500 | Train(sampled) L1:0.913386 L2:0.000000 L4:0.001812 |
#           >> Test macro:196.417422 ± 194.889609 | micro:2.215278 ± 0.488678          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 166/500 | Train(sampled) L1:0.873211 L2:0.000000 L4:0.001633 |
#           >> Test macro:198.329290 ± 196.739464 | micro:2.270398 ± 0.506278          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 167/500 | Train(sampled) L1:0.961530 L2:0.000000 L4:0.001636 |
#           >> Test macro:189.844512 ± 188.279937 | micro:2.057820 ± 0.417649          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 168/500 | Train(sampled) L1:0.902956 L2:0.000000 L4:0.001647 |
#           >> Test macro:173.280919 ± 171.659021 | micro:1.876826 ± 0.292773          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 169/500 | Train(sampled) L1:0.926769 L2:0.000000 L4:0.001546 |
#           >> Test macro:170.219586 ± 168.792789 | micro:1.999638 ± 0.435930          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 170/500 | Train(sampled) L1:0.895846 L2:0.000000 L4:0.001572 |
#           >> Test macro:176.858366 ± 175.349090 | micro:2.000668 ± 0.437143          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 171/500 | Train(sampled) L1:0.907411 L2:0.000000 L4:0.001701 |
#           >> Test macro:140.090411 ± 138.578601 | micro:1.973505 ± 0.344855          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 172/500 | Train(sampled) L1:0.925445 L2:0.000000 L4:0.001401 |
#           >> Test macro:176.540926 ± 175.059259 | micro:1.732201 ± 0.329251          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 173/500 | Train(sampled) L1:0.930945 L2:0.000000 L4:0.001454 |
#           >> Test macro:153.521175 ± 151.929051 | micro:2.086962 ± 0.387333          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 174/500 | Train(sampled) L1:0.907697 L2:0.000000 L4:0.001449 |
#           >> Test macro:169.220570 ± 167.594106 | micro:2.107502 ± 0.371213          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 175/500 | Train(sampled) L1:0.951932 L2:0.000000 L4:0.001500 |
#           >> Test macro:158.919696 ± 157.323378 | micro:2.118260 ± 0.392070          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 176/500 | Train(sampled) L1:0.904911 L2:0.000000 L4:0.001420 |
#           >> Test macro:156.999144 ± 155.341973 | micro:2.159477 ± 0.382521          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 177/500 | Train(sampled) L1:0.899629 L2:0.000000 L4:0.001477 |
#           >> Test macro:170.768837 ± 169.197652 | micro:2.149346 ± 0.429255          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 178/500 | Train(sampled) L1:0.980357 L2:0.000000 L4:0.001389 |
#           >> Test macro:151.629610 ± 150.074993 | micro:1.905529 ± 0.328883          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 179/500 | Train(sampled) L1:0.905190 L2:0.000000 L4:0.001427 |
#           >> Test macro:143.169079 ± 141.370025 | micro:2.381943 ± 0.402994          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 180/500 | Train(sampled) L1:0.878406 L2:0.000000 L4:0.001400 |
#           >> Test macro:139.034949 ± 137.385023 | micro:2.132240 ± 0.352641          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 181/500 | Train(sampled) L1:0.892057 L2:0.000000 L4:0.001342 |
#           >> Test macro:166.267030 ± 164.632648 | micro:2.109070 ± 0.397754          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 182/500 | Train(sampled) L1:0.924259 L2:0.000000 L4:0.001309 |
#           >> Test macro:133.699623 ± 131.926836 | micro:2.370315 ± 0.381347          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 183/500 | Train(sampled) L1:1.063014 L2:0.000000 L4:0.001272 |
#           >> Test macro:133.397170 ± 131.840013 | micro:2.114488 ± 0.371923          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 184/500 | Train(sampled) L1:0.909048 L2:0.000000 L4:0.001212 |
#           >> Test macro:116.244188 ± 114.603705 | micro:2.094093 ± 0.319238          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 185/500 | Train(sampled) L1:0.900113 L2:0.000000 L4:0.001344 |
#           >> Test macro:144.802832 ± 143.147781 | micro:2.184629 ± 0.410762          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 186/500 | Train(sampled) L1:0.882980 L2:0.000000 L4:0.001315 |
#           >> Test macro:129.629975 ± 128.097143 | micro:1.784367 ± 0.257184          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 187/500 | Train(sampled) L1:0.891222 L2:0.000000 L4:0.001327 |
#           >> Test macro:119.721994 ± 118.189851 | micro:1.841216 ± 0.281796          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 188/500 | Train(sampled) L1:0.916179 L2:0.000000 L4:0.001249 |
#           >> Test macro:119.957288 ± 118.647841 | micro:1.654926 ± 0.290322          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 189/500 | Train(sampled) L1:0.873141 L2:0.000000 L4:0.001377 |
#           >> Test macro:112.396923 ± 110.956056 | micro:1.924608 ± 0.338837          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 190/500 | Train(sampled) L1:0.876210 L2:0.000000 L4:0.001285 |
#           >> Test macro:95.942415 ± 94.368296 | micro:1.911920 ± 0.271063          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 191/500 | Train(sampled) L1:0.921824 L2:0.000000 L4:0.001324 |
#           >> Test macro:112.412023 ± 110.704878 | micro:2.029675 ± 0.263084          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 192/500 | Train(sampled) L1:0.859041 L2:0.000000 L4:0.001153 |
#           >> Test macro:109.102019 ± 107.530689 | micro:1.879488 ± 0.283035          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 193/500 | Train(sampled) L1:0.847462 L2:0.000000 L4:0.001179 |
#           >> Test macro:97.738541 ± 96.162809 | micro:1.817588 ± 0.255072          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 194/500 | Train(sampled) L1:0.876498 L2:0.000000 L4:0.001336 |
#           >> Test macro:79.440173 ± 77.811476 | micro:1.938635 ± 0.232921          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 195/500 | Train(sampled) L1:0.975519 L2:0.000000 L4:0.001270 |
#           >> Test macro:78.037541 ± 76.597214 | micro:1.579032 ± 0.163349          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 196/500 | Train(sampled) L1:0.867400 L2:0.000000 L4:0.001145 |
#           >> Test macro:86.277768 ± 84.759264 | micro:1.696664 ± 0.191140          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 197/500 | Train(sampled) L1:0.867502 L2:0.000000 L4:0.001225 |
#           >> Test macro:84.224116 ± 82.532620 | micro:1.919050 ± 0.234333          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 198/500 | Train(sampled) L1:0.830742 L2:0.000000 L4:0.001170 |
#           >> Test macro:78.356279 ± 76.826988 | micro:1.826251 ± 0.219896          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 199/500 | Train(sampled) L1:0.844274 L2:0.000000 L4:0.001171 |
#           >> Test macro:65.135642 ± 63.423368 | micro:1.933109 ± 0.212443          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 200/500 | Train(sampled) L1:0.885550 L2:0.000000 L4:0.001155 |
#           >> Test macro:93.959100 ± 92.383665 | micro:1.785941 ± 0.219833          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 201/500 | Train(sampled) L1:0.889114 L2:0.000000 L4:0.001109 |
#           >> Test macro:62.575311 ± 61.032655 | micro:1.689609 ± 0.143902          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 202/500 | Train(sampled) L1:0.845896 L2:0.000000 L4:0.001081 |
#           >> Test macro:76.276300 ± 74.596998 | micro:1.855597 ± 0.179238          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 203/500 | Train(sampled) L1:0.932328 L2:0.000000 L4:0.001127 |
#           >> Test macro:73.865704 ± 72.435368 | micro:1.691132 ± 0.224875          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 204/500 | Train(sampled) L1:0.860892 L2:0.000000 L4:0.001132 |
#           >> Test macro:62.928152 ± 61.194808 | micro:1.905703 ± 0.166759          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 205/500 | Train(sampled) L1:0.896277 L2:0.000000 L4:0.001174 |
#           >> Test macro:62.716352 ± 61.260714 | micro:1.559261 ± 0.134678          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 206/500 | Train(sampled) L1:0.858485 L2:0.000000 L4:0.001037 |
#           >> Test macro:57.364123 ± 55.671928 | micro:1.821478 ± 0.152061          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 207/500 | Train(sampled) L1:0.855522 L2:0.000000 L4:0.001036 |
#           >> Test macro:68.374467 ± 66.684790 | micro:1.939724 ± 0.191125          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 208/500 | Train(sampled) L1:0.898384 L2:0.000000 L4:0.001197 |
#           >> Test macro:61.605477 ± 59.999897 | micro:1.770750 ± 0.156279          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 209/500 | Train(sampled) L1:0.864810 L2:0.000000 L4:0.001099 |
#           >> Test macro:57.966319 ± 56.336238 | micro:1.845171 ± 0.165086          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 210/500 | Train(sampled) L1:0.844690 L2:0.000000 L4:0.001018 |
#           >> Test macro:66.553192 ± 64.896291 | micro:1.786211 ± 0.156650          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 211/500 | Train(sampled) L1:0.862987 L2:0.000000 L4:0.000993 |
#           >> Test macro:54.506647 ± 52.892515 | micro:1.709881 ± 0.128094          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 212/500 | Train(sampled) L1:0.848838 L2:0.000000 L4:0.001030 |
#           >> Test macro:40.223928 ± 38.664059 | micro:1.682560 ± 0.126685          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 213/500 | Train(sampled) L1:0.863702 L2:0.000000 L4:0.000947 |
#           >> Test macro:46.408423 ± 44.647200 | micro:1.884815 ± 0.149006          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 214/500 | Train(sampled) L1:0.881182 L2:0.000000 L4:0.001080 |
# ...
#           >> Test macro:2.407090 ± 1.009496 | micro:1.392718 ± 0.066479          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 404/500 | Train(sampled) L1:70.144452 L2:0.000000 L4:0.000638 |
#           >> Test macro:1.482448 ± 0.050742 | micro:1.448051 ± 0.068487          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 405/500 | Train(sampled) L1:99.743822 L2:0.000000 L4:0.000595 |
#           >> Test macro:1.448542 ± 0.110554 | micro:1.455164 ± 0.072600          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 406/500 | Train(sampled) L1:2.583616 L2:0.000000 L4:0.000632 |
#           >> Test macro:1.527439 ± 0.065075 | micro:1.474291 ± 0.071730          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 407/500 | Train(sampled) L1:21.891768 L2:0.000000 L4:0.000749 |
#           >> Test macro:1.460758 ± 0.130539 | micro:1.544912 ± 0.081932          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 408/500 | Train(sampled) L1:54.407096 L2:0.000000 L4:0.000653 |
#           >> Test macro:3.929399 ± 2.547336 | micro:1.386891 ± 0.068524          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 409/500 | Train(sampled) L1:14.929179 L2:0.000000 L4:0.000715 |
#           >> Test macro:1.477639 ± 0.100826 | micro:1.528172 ± 0.072838          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 410/500 | Train(sampled) L1:29.082208 L2:0.000000 L4:0.000634 |
#           >> Test macro:1.659345 ± 0.129351 | micro:1.530578 ± 0.073040          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 411/500 | Train(sampled) L1:8.961883 L2:0.000000 L4:0.000649 |
#           >> Test macro:7.219008 ± 5.819784 | micro:1.399489 ± 0.077637          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 412/500 | Train(sampled) L1:27.308439 L2:0.000000 L4:0.000669 |
#           >> Test macro:7.966811 ± 6.438743 | micro:1.541691 ± 0.079392          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 413/500 | Train(sampled) L1:49.177952 L2:0.000000 L4:0.000594 |
#           >> Test macro:2.350500 ± 1.047374 | micro:1.296677 ± 0.067384          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 414/500 | Train(sampled) L1:106.049865 L2:0.000000 L4:0.000603 |
#           >> Test macro:2.008575 ± 0.528738 | micro:1.485392 ± 0.069460          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 415/500 | Train(sampled) L1:25.337174 L2:0.000000 L4:0.000665 |
#           >> Test macro:7.801868 ± 6.398871 | micro:1.421238 ± 0.075372          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 416/500 | Train(sampled) L1:84.555659 L2:0.000000 L4:0.000563 |
#           >> Test macro:6.434553 ± 4.922259 | micro:1.507701 ± 0.073445          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 417/500 | Train(sampled) L1:50.058636 L2:0.000000 L4:0.000571 |
#           >> Test macro:1.805437 ± 0.558326 | micro:1.237383 ± 0.061976          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 418/500 | Train(sampled) L1:139.890601 L2:0.000000 L4:0.000675 |
#           >> Test macro:2.202042 ± 0.793080 | micro:1.413441 ± 0.068120          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 419/500 | Train(sampled) L1:50.482741 L2:0.000000 L4:0.000637 |
#           >> Test macro:10.354129 ± 8.966620 | micro:1.404567 ± 0.072784          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 420/500 | Train(sampled) L1:48.378746 L2:0.000000 L4:0.000618 |
#           >> Test macro:7.143923 ± 5.700610 | micro:1.450731 ± 0.074205          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 421/500 | Train(sampled) L1:34.019453 L2:0.000000 L4:0.000595 |
#           >> Test macro:2.011496 ± 0.590766 | micro:1.409771 ± 0.068952          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 422/500 | Train(sampled) L1:45.969341 L2:0.000000 L4:0.000598 |
#           >> Test macro:1.240068 ± 0.244346 | micro:1.419504 ± 0.066363          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 423/500 | Train(sampled) L1:26.000774 L2:0.000000 L4:0.000601 |
#           >> Test macro:8.831824 ± 7.285856 | micro:1.559066 ± 0.077083          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 424/500 | Train(sampled) L1:58.700335 L2:0.000000 L4:0.000589 |
#           >> Test macro:8.076742 ± 6.458013 | micro:1.609479 ± 0.077961          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 425/500 | Train(sampled) L1:48.342311 L2:0.000000 L4:0.000666 |
#           >> Test macro:5.673478 ± 4.225433 | micro:1.449133 ± 0.074757          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 426/500 | Train(sampled) L1:46.962397 L2:0.000000 L4:0.000616 |
#           >> Test macro:6.257538 ± 4.831340 | micro:1.434293 ± 0.073242          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 427/500 | Train(sampled) L1:95.297806 L2:0.000000 L4:0.000622 |
#           >> Test macro:2.952517 ± 1.385844 | micro:1.566755 ± 0.075371          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 428/500 | Train(sampled) L1:29.666237 L2:0.000000 L4:0.000613 |
#           >> Test macro:5.151234 ± 3.577593 | micro:1.567683 ± 0.075322          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 429/500 | Train(sampled) L1:23.206783 L2:0.000000 L4:0.000596 |
#           >> Test macro:4.815833 ± 3.383525 | micro:1.420011 ± 0.075197          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 430/500 | Train(sampled) L1:121.133014 L2:0.000000 L4:0.000603 |
#           >> Test macro:6.082361 ± 4.486121 | micro:1.594651 ± 0.082665          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 431/500 | Train(sampled) L1:42.679599 L2:0.000000 L4:0.000642 |
#           >> Test macro:3.740941 ± 2.280714 | micro:1.448415 ± 0.072147          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 432/500 | Train(sampled) L1:55.131179 L2:0.000000 L4:0.000572 |
#           >> Test macro:2.453034 ± 1.004015 | micro:1.442437 ± 0.072895          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 433/500 | Train(sampled) L1:33.712620 L2:0.000000 L4:0.000595 |
#           >> Test macro:2.847053 ± 1.243526 | micro:1.591232 ± 0.072258          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 434/500 | Train(sampled) L1:94.902819 L2:0.000000 L4:0.000546 |
#           >> Test macro:5.369446 ± 3.760797 | micro:1.596848 ± 0.076847          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 435/500 | Train(sampled) L1:6.236345 L2:0.000000 L4:0.000551 |
#           >> Test macro:2.424659 ± 0.835183 | micro:1.581733 ± 0.074070          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 436/500 | Train(sampled) L1:37.925962 L2:0.000000 L4:0.000580 |
#           >> Test macro:7.049894 ± 5.588596 | micro:1.470520 ± 0.074434          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 437/500 | Train(sampled) L1:20.808183 L2:0.000000 L4:0.000554 |
#           >> Test macro:5.895152 ± 4.473106 | micro:1.419240 ± 0.067850          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 438/500 | Train(sampled) L1:16.280031 L2:0.000000 L4:0.000635 |
#           >> Test macro:1.483571 ± 0.094588 | micro:1.412159 ± 0.070241          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 439/500 | Train(sampled) L1:7.542359 L2:0.000000 L4:0.000571 |
#           >> Test macro:1.447111 ± 0.141609 | micro:1.522121 ± 0.074648          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 440/500 | Train(sampled) L1:72.600142 L2:0.000000 L4:0.000553 |
#           >> Test macro:2.110379 ± 0.563143 | micro:1.541487 ± 0.075595          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 441/500 | Train(sampled) L1:24.087573 L2:0.000000 L4:0.000567 |
#           >> Test macro:6.122186 ± 4.598976 | micro:1.508103 ± 0.072709          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 442/500 | Train(sampled) L1:17.350182 L2:0.000000 L4:0.000480 |
#           >> Test macro:2.644928 ± 1.167688 | micro:1.483163 ± 0.070865          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 443/500 | Train(sampled) L1:25.609524 L2:0.000000 L4:0.000521 |
#           >> Test macro:5.271591 ± 3.735862 | micro:1.534415 ± 0.075506          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 444/500 | Train(sampled) L1:131.294381 L2:0.000000 L4:0.000556 |
#           >> Test macro:5.799655 ± 4.293841 | micro:1.491690 ± 0.073481          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 445/500 | Train(sampled) L1:9.418419 L2:0.000000 L4:0.000559 |
#           >> Test macro:4.811155 ± 3.240045 | micro:1.580557 ± 0.074896          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 446/500 | Train(sampled) L1:6.955538 L2:0.000000 L4:0.000549 |
#           >> Test macro:5.966919 ± 4.527079 | micro:1.434175 ± 0.071967          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 447/500 | Train(sampled) L1:36.982576 L2:0.000000 L4:0.000596 |
#           >> Test macro:8.645423 ± 7.215894 | micro:1.444652 ± 0.075410          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 448/500 | Train(sampled) L1:38.144569 L2:0.000000 L4:0.000529 |
#           >> Test macro:1.391960 ± 0.118046 | micro:1.474267 ± 0.071204          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 449/500 | Train(sampled) L1:26.526800 L2:0.000000 L4:0.000634 |
#           >> Test macro:1.400661 ± 0.137151 | micro:1.463512 ± 0.074115          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 450/500 | Train(sampled) L1:91.446398 L2:0.000000 L4:0.000557 |
#           >> Test macro:4.056973 ± 2.406688 | micro:1.654021 ± 0.081270          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 451/500 | Train(sampled) L1:6.148448 L2:0.000000 L4:0.000502 |
#           >> Test macro:7.480678 ± 5.988798 | micro:1.513262 ± 0.078098          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 452/500 | Train(sampled) L1:51.383744 L2:0.000000 L4:0.000524 |
#           >> Test macro:2.107187 ± 0.621922 | micro:1.478226 ± 0.072776          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 453/500 | Train(sampled) L1:75.299949 L2:0.000000 L4:0.000542 |
#           >> Test macro:2.299074 ± 0.872682 | micro:1.422582 ± 0.069125          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 454/500 | Train(sampled) L1:28.747409 L2:0.000000 L4:0.000482 |
#           >> Test macro:4.158639 ± 2.613052 | micro:1.532727 ± 0.074956          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 455/500 | Train(sampled) L1:24.819897 L2:0.000000 L4:0.000526 |
#           >> Test macro:1.619766 ± 0.094054 | micro:1.586484 ± 0.077698          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 456/500 | Train(sampled) L1:41.307432 L2:0.000000 L4:0.000521 |
#           >> Test macro:1.329294 ± 0.283278 | micro:1.569077 ± 0.076739          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 457/500 | Train(sampled) L1:86.645892 L2:0.000000 L4:0.000543 |
#           >> Test macro:8.614204 ± 6.884586 | micro:1.728202 ± 0.082121          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 458/500 | Train(sampled) L1:34.937238 L2:0.000000 L4:0.000497 |
#           >> Test macro:7.353723 ± 5.869167 | micro:1.478351 ± 0.078693          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 459/500 | Train(sampled) L1:50.355478 L2:0.000000 L4:0.000540 |
#           >> Test macro:2.278265 ± 0.698491 | micro:1.580732 ± 0.077365          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 460/500 | Train(sampled) L1:92.926347 L2:0.000000 L4:0.000532 |
#           >> Test macro:1.334893 ± 0.259632 | micro:1.514618 ± 0.074555          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 461/500 | Train(sampled) L1:68.377817 L2:0.000000 L4:0.000501 |
#           >> Test macro:8.728529 ± 7.227046 | micro:1.519366 ± 0.078430          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 462/500 | Train(sampled) L1:8.067728 L2:0.000000 L4:0.000512 |
#           >> Test macro:2.620138 ± 1.161748 | micro:1.452622 ± 0.071319          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 463/500 | Train(sampled) L1:4.037382 L2:0.000000 L4:0.000560 |
#           >> Test macro:1.300299 ± 0.185234 | micro:1.462210 ± 0.075445          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 464/500 | Train(sampled) L1:74.477184 L2:0.000000 L4:0.000530 |
#           >> Test macro:2.719567 ± 1.041641 | micro:1.673695 ± 0.077851          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 465/500 | Train(sampled) L1:41.631392 L2:0.000000 L4:0.000608 |
#           >> Test macro:6.551762 ± 5.035838 | micro:1.528699 ± 0.077215          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 466/500 | Train(sampled) L1:45.730355 L2:0.000000 L4:0.000549 |
#           >> Test macro:3.758651 ± 2.167452 | micro:1.596089 ± 0.076979          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 467/500 | Train(sampled) L1:39.639192 L2:0.000000 L4:0.000581 |
#           >> Test macro:1.336609 ± 0.257715 | micro:1.543155 ± 0.075248          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 468/500 | Train(sampled) L1:52.426567 L2:0.000000 L4:0.000551 |
#           >> Test macro:1.313045 ± 0.248336 | micro:1.551498 ± 0.074986          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 469/500 | Train(sampled) L1:154.335543 L2:0.000000 L4:0.000586 |
#           >> Test macro:2.287735 ± 0.728140 | micro:1.547677 ± 0.072430          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 470/500 | Train(sampled) L1:25.546426 L2:0.000000 L4:0.000501 |
#           >> Test macro:4.023426 ± 2.575774 | micro:1.457455 ± 0.074131          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 471/500 | Train(sampled) L1:44.457728 L2:0.000000 L4:0.000472 |
#           >> Test macro:6.361861 ± 4.722635 | micro:1.647843 ± 0.080172          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 472/500 | Train(sampled) L1:108.812676 L2:0.000000 L4:0.000470 |
#           >> Test macro:3.240924 ± 1.657715 | micro:1.564365 ± 0.077342          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Early stopping at epoch 472/500 (best test macro-MSE(avg): 1.178064 @ epoch 422)
# TEST RESULTS | macro: 3.542477 ± 2.127549 | micro: 1.415757 ± 0.071261macro (noise): 0.000000 ± 0.000000 | micro (noise): 0.000000 ± 0.000000
#           >> per_group (weighted SE): {0: '1.828474 ± 0.119935 (n=777)', 1: '6.544801 ± 5.171748 (n=3)', 5: '1.349496 ± 0.099585 (n=1019)'}
#           >> per_group (weighted SE): {0: '0.000000 ± 0.000000 (n=777)', 1: '0.000000 ± 0.000000 (n=3)', 5: '0.000000 ± 0.000000 (n=1019)'}

# %%
tsdiffusion.lam=[0.95,0,0.05]
res_tsdiffusion = tsdiffusion.train_cognite(
    df=df_scaled,
    feature_cols=list(df_scaled.columns[:-1]),
    static_features_cols=None,
    timestamp_col='index',
    states_col='states',
    batch_size=256,
    window_size=30,
    window_step=30,
    epochs = 500,
    validate=False,
    patience=50
)
res_tsdiffusion = [r for r in res_tsdiffusion if r is not None]  # remove None results
# Out:
# GRUPOS (total): {0: 3886, 1: 15, 5: 5093}
# GRUPOS (train): {0: 3109, 1: 12, 5: 4074}
# GRUPOS (test):  {0: 777, 1: 3, 5: 1019}
# Epoch 1/500 | Train(sampled) L1:290.712452 L2:0.000000 L4:0.674231 |
#           >> Test macro:851.893473 ± 850.474677 | micro:4.622995 ± 2.302536          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 2/500 | Train(sampled) L1:178.778875 L2:0.000000 L4:0.618936 |
#           >> Test macro:1009.936978 ± 1008.621722 | micro:6.648151 ± 3.044525          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 3/500 | Train(sampled) L1:91.878884 L2:0.000000 L4:0.567173 |
#           >> Test macro:917.449774 ± 916.121150 | micro:6.066532 ± 2.776780          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 4/500 | Train(sampled) L1:35.400856 L2:0.000000 L4:0.547302 |
#           >> Test macro:1014.234063 ± 1012.841969 | micro:5.591002 ± 2.739254          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 5/500 | Train(sampled) L1:14.281346 L2:0.000000 L4:0.518071 |
#           >> Test macro:1016.991063 ± 1015.646750 | micro:6.243766 ± 2.935722          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 6/500 | Train(sampled) L1:6.069302 L2:0.000000 L4:0.506237 |
#           >> Test macro:921.096035 ± 919.770504 | micro:4.802870 ± 2.396432          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 7/500 | Train(sampled) L1:3.963347 L2:0.000000 L4:0.564241 |
#           >> Test macro:942.764928 ± 941.629167 | micro:3.465361 ± 1.967017          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 8/500 | Train(sampled) L1:3.081180 L2:0.000000 L4:0.599032 |
#           >> Test macro:938.911559 ± 937.942910 | micro:5.511259 ± 2.836949          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 9/500 | Train(sampled) L1:2.556324 L2:0.000000 L4:0.495229 |
#           >> Test macro:870.155659 ± 869.289198 | micro:3.311300 ± 2.064608          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 10/500 | Train(sampled) L1:2.387597 L2:0.000000 L4:0.470444 |
#           >> Test macro:950.289991 ± 949.454677 | micro:3.899534 ± 2.360970          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 11/500 | Train(sampled) L1:2.171350 L2:0.000000 L4:0.467884 |
#           >> Test macro:919.033295 ± 918.210690 | micro:3.917450 ± 2.256266          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 12/500 | Train(sampled) L1:2.128686 L2:0.000000 L4:0.466977 |
#           >> Test macro:897.569383 ± 896.759179 | micro:3.852110 ± 2.202690          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 13/500 | Train(sampled) L1:2.011971 L2:0.000000 L4:0.466185 |
#           >> Test macro:859.642211 ± 858.904122 | micro:4.158113 ± 2.297204          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 14/500 | Train(sampled) L1:2.102917 L2:0.000000 L4:0.458409 |
#           >> Test macro:928.074795 ± 927.336144 | micro:4.312116 ± 2.485606          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 15/500 | Train(sampled) L1:1.880373 L2:0.000000 L4:0.454779 |
#           >> Test macro:801.676019 ± 800.966895 | micro:3.317780 ± 1.960138          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 16/500 | Train(sampled) L1:1.870121 L2:0.000000 L4:0.445476 |
#           >> Test macro:972.753384 ± 972.068900 | micro:3.264088 ± 2.294089          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 17/500 | Train(sampled) L1:1.845070 L2:0.000000 L4:0.437021 |
#           >> Test macro:883.801398 ± 883.153211 | micro:2.678863 ± 1.805923          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 18/500 | Train(sampled) L1:1.816066 L2:0.000000 L4:0.424227 |
#           >> Test macro:907.858064 ± 907.174558 | micro:4.791572 ± 2.722083          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 19/500 | Train(sampled) L1:1.744529 L2:0.000000 L4:0.415029 |
#           >> Test macro:979.463292 ± 978.856949 | micro:3.444603 ± 2.222993          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 20/500 | Train(sampled) L1:1.714405 L2:0.000000 L4:0.401905 |
#           >> Test macro:979.106103 ± 978.491362 | micro:4.639218 ± 2.620687          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 21/500 | Train(sampled) L1:1.768847 L2:0.000000 L4:0.391940 |
#           >> Test macro:891.346385 ± 890.815412 | micro:3.761485 ± 2.236827          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 22/500 | Train(sampled) L1:1.587035 L2:0.000000 L4:0.384209 |
#           >> Test macro:927.416599 ± 926.928983 | micro:3.815992 ± 2.504614          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 23/500 | Train(sampled) L1:1.672625 L2:0.000000 L4:0.370351 |
#           >> Test macro:845.711998 ± 845.197983 | micro:3.788859 ± 2.264338          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 24/500 | Train(sampled) L1:1.610947 L2:0.000000 L4:0.355970 |
#           >> Test macro:924.125918 ± 923.680685 | micro:3.517570 ± 2.248130          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 25/500 | Train(sampled) L1:1.544975 L2:0.000000 L4:0.338788 |
#           >> Test macro:882.465335 ± 882.039933 | micro:3.273543 ± 2.141873          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 26/500 | Train(sampled) L1:1.496866 L2:0.000000 L4:0.310349 |
#           >> Test macro:930.319910 ± 929.898385 | micro:4.206034 ± 2.474124          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 27/500 | Train(sampled) L1:1.549213 L2:0.000000 L4:0.282544 |
#           >> Test macro:885.319621 ± 884.917754 | micro:2.531607 ± 1.964175          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 28/500 | Train(sampled) L1:1.436670 L2:0.000000 L4:0.252591 |
#           >> Test macro:874.709231 ± 874.325648 | micro:4.450512 ± 2.598877          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 29/500 | Train(sampled) L1:1.395656 L2:0.000000 L4:0.221621 |
#           >> Test macro:868.939989 ± 868.549947 | micro:3.517281 ± 2.177376          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 30/500 | Train(sampled) L1:1.428485 L2:0.000000 L4:0.200967 |
#           >> Test macro:875.775074 ± 875.397586 | micro:4.295280 ± 2.446786          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 31/500 | Train(sampled) L1:1.448607 L2:0.000000 L4:0.176382 |
#           >> Test macro:855.477429 ± 855.051011 | micro:4.211053 ± 2.443465          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 32/500 | Train(sampled) L1:1.465966 L2:0.000000 L4:0.167208 |
#           >> Test macro:900.581724 ± 900.203301 | micro:3.583212 ± 2.246351          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 33/500 | Train(sampled) L1:1.408303 L2:0.000000 L4:0.153664 |
#           >> Test macro:832.665794 ± 832.297763 | micro:2.850372 ± 1.888421          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 34/500 | Train(sampled) L1:1.374035 L2:0.000000 L4:0.133517 |
#           >> Test macro:790.872279 ± 790.539490 | micro:3.200187 ± 2.013319          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 35/500 | Train(sampled) L1:1.370258 L2:0.000000 L4:0.117289 |
#           >> Test macro:873.185946 ± 872.784422 | micro:3.673182 ± 2.313168          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 36/500 | Train(sampled) L1:1.324075 L2:0.000000 L4:0.107332 |
#           >> Test macro:870.296447 ± 869.931407 | micro:2.551843 ± 1.930193          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 37/500 | Train(sampled) L1:1.337849 L2:0.000000 L4:0.097913 |
#           >> Test macro:806.611603 ± 806.277689 | micro:3.646177 ± 2.197123          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 38/500 | Train(sampled) L1:1.331740 L2:0.000000 L4:0.087972 |
#           >> Test macro:826.519292 ± 826.213198 | micro:2.545630 ± 1.796132          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 39/500 | Train(sampled) L1:1.291765 L2:0.000000 L4:0.081081 |
#           >> Test macro:826.743186 ± 826.440083 | micro:3.110889 ± 1.992346          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 40/500 | Train(sampled) L1:1.314566 L2:0.000000 L4:0.079800 |
#           >> Test macro:757.476902 ± 757.149841 | micro:3.687018 ± 2.128182          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 41/500 | Train(sampled) L1:1.275051 L2:0.000000 L4:0.071560 |
#           >> Test macro:789.499859 ± 789.191699 | micro:2.559639 ± 1.767533          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 42/500 | Train(sampled) L1:1.255898 L2:0.000000 L4:0.075378 |
#           >> Test macro:823.854012 ± 823.560294 | micro:2.520320 ± 1.762487          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 43/500 | Train(sampled) L1:1.255990 L2:0.000000 L4:0.066841 |
#           >> Test macro:746.778794 ± 746.488096 | micro:2.007484 ± 1.495952          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 44/500 | Train(sampled) L1:1.255392 L2:0.000000 L4:0.065070 |
#           >> Test macro:770.590042 ± 770.299300 | micro:3.274312 ± 1.970248          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 45/500 | Train(sampled) L1:1.351320 L2:0.000000 L4:0.062061 |
#           >> Test macro:705.567215 ± 705.273183 | micro:1.979271 ± 1.443085          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 46/500 | Train(sampled) L1:1.253534 L2:0.000000 L4:0.056163 |
#           >> Test macro:722.407540 ± 722.152811 | micro:3.124545 ± 1.982762          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 47/500 | Train(sampled) L1:1.234832 L2:0.000000 L4:0.052701 |
#           >> Test macro:771.613943 ± 771.337134 | micro:3.554035 ± 2.063517          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 48/500 | Train(sampled) L1:1.182005 L2:0.000000 L4:0.051756 |
#           >> Test macro:644.255045 ± 643.942319 | micro:3.450339 ± 1.976087          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 49/500 | Train(sampled) L1:1.175105 L2:0.000000 L4:0.047074 |
#           >> Test macro:652.421504 ± 652.148138 | micro:3.139463 ± 1.911368          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 50/500 | Train(sampled) L1:1.226372 L2:0.000000 L4:0.046412 |
#           >> Test macro:596.585634 ± 596.310605 | micro:1.828911 ± 1.337851          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 51/500 | Train(sampled) L1:1.363897 L2:0.000000 L4:0.049941 |
#           >> Test macro:646.288442 ± 645.935854 | micro:3.171237 ± 1.773121          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 52/500 | Train(sampled) L1:1.195975 L2:0.000000 L4:0.048438 |
#           >> Test macro:644.642666 ± 644.337988 | micro:3.125818 ± 1.751052          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 53/500 | Train(sampled) L1:1.256985 L2:0.000000 L4:0.043352 |
#           >> Test macro:612.067989 ± 611.800046 | micro:2.011139 ± 1.347896          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 54/500 | Train(sampled) L1:1.164135 L2:0.000000 L4:0.043188 |
#           >> Test macro:649.174910 ± 648.892728 | micro:1.468829 ± 1.316926          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 55/500 | Train(sampled) L1:1.114133 L2:0.000000 L4:0.034997 |
#           >> Test macro:601.484712 ± 601.222749 | micro:2.101959 ± 1.513631          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 56/500 | Train(sampled) L1:1.112366 L2:0.000000 L4:0.033359 |
#           >> Test macro:597.228284 ± 596.958705 | micro:1.535838 ± 1.214997          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 57/500 | Train(sampled) L1:1.100084 L2:0.000000 L4:0.033127 |
#           >> Test macro:582.171690 ± 581.894759 | micro:2.474852 ± 1.523161          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 58/500 | Train(sampled) L1:1.070950 L2:0.000000 L4:0.031692 |
#           >> Test macro:601.389175 ± 601.097122 | micro:2.261365 ± 1.464884          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 59/500 | Train(sampled) L1:1.098809 L2:0.000000 L4:0.033609 |
#           >> Test macro:595.144219 ± 594.870065 | micro:1.722937 ± 1.240162          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 60/500 | Train(sampled) L1:1.055301 L2:0.000000 L4:0.032413 |
#           >> Test macro:553.289865 ± 553.020073 | micro:2.064545 ± 1.371264          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 61/500 | Train(sampled) L1:1.049154 L2:0.000000 L4:0.030946 |
#           >> Test macro:504.395574 ± 504.084727 | micro:2.159614 ± 1.288332          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 62/500 | Train(sampled) L1:1.029291 L2:0.000000 L4:0.028624 |
#           >> Test macro:609.525331 ± 609.270861 | micro:1.618384 ± 1.367977          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 63/500 | Train(sampled) L1:1.026837 L2:0.000000 L4:0.032259 |
#           >> Test macro:576.437287 ± 576.095715 | micro:2.259614 ± 1.380170          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 64/500 | Train(sampled) L1:1.033137 L2:0.000000 L4:0.028952 |
#           >> Test macro:536.609582 ± 536.265284 | micro:2.414869 ± 1.399744          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 65/500 | Train(sampled) L1:0.984564 L2:0.000000 L4:0.028992 |
#           >> Test macro:529.464365 ± 529.202017 | micro:2.014400 ± 1.360511          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 66/500 | Train(sampled) L1:1.093733 L2:0.000000 L4:0.026659 |
#           >> Test macro:519.480116 ± 519.169547 | micro:1.477275 ± 1.021371          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 67/500 | Train(sampled) L1:0.955081 L2:0.000000 L4:0.030526 |
#           >> Test macro:484.483966 ± 484.254017 | micro:1.625357 ± 1.132579          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 68/500 | Train(sampled) L1:0.927732 L2:0.000000 L4:0.030181 |
#           >> Test macro:503.075681 ± 502.810087 | micro:1.838094 ± 1.173712          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 69/500 | Train(sampled) L1:0.945271 L2:0.000000 L4:0.031677 |
#           >> Test macro:459.338381 ± 459.070828 | micro:1.798289 ± 1.121853          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 70/500 | Train(sampled) L1:0.862840 L2:0.000000 L4:0.028488 |
#           >> Test macro:508.375117 ± 508.083755 | micro:2.531456 ± 1.393363          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 71/500 | Train(sampled) L1:0.902710 L2:0.000000 L4:0.027092 |
# 4523.76s - pydev debugger: unable to find translation for: "vscode-notebook-cell://wsl%2Bubuntu/root/coppe/tp_esp_ap_mq/3w.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D" in ["/root/coppe/tp_esp_ap_mq/", "/root/coppe/tp_esp_ap_mq"] (please revise your path mappings).
#           >> Test macro:488.060526 ± 487.834618 | micro:1.520320 ± 1.065799          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 72/500 | Train(sampled) L1:1.100953 L2:0.000000 L4:0.024376 |
#           >> Test macro:429.860763 ± 429.595708 | micro:2.476180 ± 1.345461          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 73/500 | Train(sampled) L1:0.859150 L2:0.000000 L4:0.023331 |
#           >> Test macro:456.369352 ± 456.144965 | micro:2.020678 ± 1.272365          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 74/500 | Train(sampled) L1:0.888612 L2:0.000000 L4:0.021823 |
#           >> Test macro:478.124229 ± 477.910084 | micro:1.628675 ± 1.129326          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 75/500 | Train(sampled) L1:0.867607 L2:0.000000 L4:0.021342 |
#           >> Test macro:480.737550 ± 480.472124 | micro:1.680554 ± 1.076018          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 76/500 | Train(sampled) L1:0.893624 L2:0.000000 L4:0.020493 |
#           >> Test macro:419.592099 ± 419.382888 | micro:1.005282 ± 0.778343          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 77/500 | Train(sampled) L1:0.857776 L2:0.000000 L4:0.019949 |
#           >> Test macro:413.828081 ± 413.594216 | micro:1.392354 ± 0.959103          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 78/500 | Train(sampled) L1:0.877274 L2:0.000000 L4:0.019256 |
#           >> Test macro:472.620998 ± 472.410656 | micro:2.375544 ± 1.327827          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 79/500 | Train(sampled) L1:0.845770 L2:0.000000 L4:0.019051 |
#           >> Test macro:388.632571 ± 388.372452 | micro:1.893785 ± 1.126481          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 80/500 | Train(sampled) L1:0.897636 L2:0.000000 L4:0.018649 |
#           >> Test macro:391.688004 ± 391.422973 | micro:1.411696 ± 0.995710          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 81/500 | Train(sampled) L1:0.837295 L2:0.000000 L4:0.018113 |
#           >> Test macro:372.769869 ± 372.490680 | micro:1.735410 ± 0.967536          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 82/500 | Train(sampled) L1:0.844544 L2:0.000000 L4:0.019159 |
#           >> Test macro:343.298126 ± 343.035463 | micro:1.777311 ± 0.968845          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 83/500 | Train(sampled) L1:0.839468 L2:0.000000 L4:0.016260 |
#           >> Test macro:415.188083 ± 414.980579 | micro:1.790124 ± 1.060369          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 84/500 | Train(sampled) L1:0.854119 L2:0.000000 L4:0.015815 |
#           >> Test macro:354.578197 ± 354.303704 | micro:1.419235 ± 0.850924          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 85/500 | Train(sampled) L1:0.857092 L2:0.000000 L4:0.016568 |
#           >> Test macro:339.502375 ± 339.251594 | micro:1.465048 ± 0.875955          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 86/500 | Train(sampled) L1:0.865693 L2:0.000000 L4:0.015397 |
#           >> Test macro:324.349937 ± 324.130589 | micro:1.403166 ± 0.870567          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 87/500 | Train(sampled) L1:0.824073 L2:0.000000 L4:0.015287 |
#           >> Test macro:335.500762 ± 335.223997 | micro:1.889852 ± 0.959474          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 88/500 | Train(sampled) L1:0.897465 L2:0.000000 L4:0.014629 |
#           >> Test macro:353.034625 ± 352.703813 | micro:1.681294 ± 0.910894          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 89/500 | Train(sampled) L1:0.847951 L2:0.000000 L4:0.015793 |
#           >> Test macro:339.506416 ± 339.277514 | micro:1.565126 ± 0.896945          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 90/500 | Train(sampled) L1:0.836753 L2:0.000000 L4:0.015772 |
#           >> Test macro:327.086272 ± 326.885526 | micro:1.178450 ± 0.852777          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 91/500 | Train(sampled) L1:0.848784 L2:0.000000 L4:0.014241 |
#           >> Test macro:339.701554 ± 339.497265 | micro:1.199990 ± 0.781283          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 92/500 | Train(sampled) L1:0.824791 L2:0.000000 L4:0.014160 |
#           >> Test macro:307.438662 ± 307.179565 | micro:1.116683 ± 0.704288          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 93/500 | Train(sampled) L1:0.799531 L2:0.000000 L4:0.014611 |
#           >> Test macro:293.288285 ± 293.012282 | micro:1.360592 ± 0.781029          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 94/500 | Train(sampled) L1:0.829863 L2:0.000000 L4:0.013582 |
#           >> Test macro:296.893064 ± 296.647450 | micro:1.130832 ± 0.681515          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 95/500 | Train(sampled) L1:0.920847 L2:0.000000 L4:0.017401 |
#           >> Test macro:313.712807 ± 313.480062 | micro:1.287709 ± 0.758559          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 96/500 | Train(sampled) L1:0.810687 L2:0.000000 L4:0.015722 |
#           >> Test macro:267.307856 ± 267.016423 | micro:1.088170 ± 0.657754          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 97/500 | Train(sampled) L1:0.835413 L2:0.000000 L4:0.017076 |
#           >> Test macro:286.368478 ± 286.139297 | micro:0.748016 ± 0.526170          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 98/500 | Train(sampled) L1:0.805966 L2:0.000000 L4:0.014519 |
#           >> Test macro:275.416058 ± 275.017648 | micro:1.300522 ± 0.708682          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 99/500 | Train(sampled) L1:0.796889 L2:0.000000 L4:0.012733 |
#           >> Test macro:285.519125 ± 285.307856 | micro:1.046767 ± 0.666648          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 100/500 | Train(sampled) L1:0.931634 L2:0.000000 L4:0.013235 |
#           >> Test macro:273.379445 ± 273.168044 | micro:1.168024 ± 0.728364          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 101/500 | Train(sampled) L1:0.994550 L2:0.000000 L4:0.012716 |
#           >> Test macro:248.248552 ± 248.027881 | micro:1.314837 ± 0.745203          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 102/500 | Train(sampled) L1:0.817386 L2:0.000000 L4:0.014044 |
#           >> Test macro:249.891198 ± 249.445437 | micro:1.357461 ± 0.688053          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 103/500 | Train(sampled) L1:0.967301 L2:0.000000 L4:0.014674 |
#           >> Test macro:250.422530 ± 250.151740 | micro:1.233237 ± 0.644461          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 104/500 | Train(sampled) L1:0.831364 L2:0.000000 L4:0.012293 |
#           >> Test macro:226.149186 ± 225.901215 | micro:0.996998 ± 0.598559          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 105/500 | Train(sampled) L1:0.791255 L2:0.000000 L4:0.011974 |
#           >> Test macro:215.757220 ± 215.508377 | micro:1.122252 ± 0.596004          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 106/500 | Train(sampled) L1:0.775511 L2:0.000000 L4:0.011174 |
#           >> Test macro:224.700609 ± 224.485266 | micro:0.865505 ± 0.512258          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 107/500 | Train(sampled) L1:0.794175 L2:0.000000 L4:0.012051 |
#           >> Test macro:209.017420 ± 208.747544 | micro:1.076757 ± 0.545882          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 108/500 | Train(sampled) L1:0.785869 L2:0.000000 L4:0.012594 |
#           >> Test macro:241.745677 ± 241.488025 | micro:0.931189 ± 0.541489          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 109/500 | Train(sampled) L1:0.761118 L2:0.000000 L4:0.013897 |
#           >> Test macro:202.003326 ± 201.807971 | micro:0.832110 ± 0.488204          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 110/500 | Train(sampled) L1:0.794277 L2:0.000000 L4:0.011112 |
#           >> Test macro:222.311624 ± 222.093970 | micro:0.827815 ± 0.511252          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 111/500 | Train(sampled) L1:0.769854 L2:0.000000 L4:0.013097 |
#           >> Test macro:196.941088 ± 196.731146 | micro:0.858081 ± 0.475919          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 112/500 | Train(sampled) L1:0.777955 L2:0.000000 L4:0.010716 |
#           >> Test macro:187.045896 ± 186.796130 | micro:0.959099 ± 0.585742          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 113/500 | Train(sampled) L1:0.782939 L2:0.000000 L4:0.010487 |
#           >> Test macro:187.840680 ± 187.644163 | micro:0.747802 ± 0.455486          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 114/500 | Train(sampled) L1:0.752644 L2:0.000000 L4:0.009762 |
#           >> Test macro:167.865100 ± 167.580110 | micro:0.597977 ± 0.323410          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 115/500 | Train(sampled) L1:0.715309 L2:0.000000 L4:0.009162 |
#           >> Test macro:179.399997 ± 179.177043 | micro:1.014380 ± 0.535956          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 116/500 | Train(sampled) L1:0.843828 L2:0.000000 L4:0.010522 |
#           >> Test macro:157.981930 ± 157.789812 | micro:0.902236 ± 0.441186          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 117/500 | Train(sampled) L1:0.762799 L2:0.000000 L4:0.010194 |
#           >> Test macro:173.983246 ± 173.796256 | micro:0.707894 ± 0.395576          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 118/500 | Train(sampled) L1:0.775685 L2:0.000000 L4:0.008780 |
#           >> Test macro:168.445876 ± 168.151681 | micro:0.727695 ± 0.394739          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 119/500 | Train(sampled) L1:0.739035 L2:0.000000 L4:0.009478 |
#           >> Test macro:152.860018 ± 152.652301 | micro:0.693716 ± 0.397332          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 120/500 | Train(sampled) L1:0.741721 L2:0.000000 L4:0.009854 |
#           >> Test macro:149.513383 ± 149.330504 | micro:0.817123 ± 0.433853          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 121/500 | Train(sampled) L1:0.747477 L2:0.000000 L4:0.009356 |
#           >> Test macro:139.165834 ± 138.953482 | micro:0.833876 ± 0.386935          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 122/500 | Train(sampled) L1:0.743406 L2:0.000000 L4:0.009885 |
#           >> Test macro:145.304118 ± 145.090698 | micro:0.784558 ± 0.387456          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 123/500 | Train(sampled) L1:0.924114 L2:0.000000 L4:0.009396 |
#           >> Test macro:136.462271 ± 136.181506 | micro:0.572979 ± 0.276985          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 124/500 | Train(sampled) L1:0.730976 L2:0.000000 L4:0.008392 |
#           >> Test macro:128.405606 ± 128.124336 | micro:0.616771 ± 0.288206          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 125/500 | Train(sampled) L1:0.767892 L2:0.000000 L4:0.008564 |
#           >> Test macro:120.153441 ± 119.955112 | micro:0.478751 ± 0.244926          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 126/500 | Train(sampled) L1:0.732769 L2:0.000000 L4:0.008056 |
#           >> Test macro:122.482450 ± 122.277979 | micro:0.652136 ± 0.310795          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 127/500 | Train(sampled) L1:0.714597 L2:0.000000 L4:0.008470 |
#           >> Test macro:116.331355 ± 116.117607 | micro:0.537487 ± 0.304825          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 128/500 | Train(sampled) L1:0.741538 L2:0.000000 L4:0.008095 |
#           >> Test macro:102.457284 ± 102.267265 | micro:0.560853 ± 0.263687          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 129/500 | Train(sampled) L1:0.702277 L2:0.000000 L4:0.007803 |
#           >> Test macro:108.715293 ± 108.448178 | micro:0.553095 ± 0.255720          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 130/500 | Train(sampled) L1:0.738507 L2:0.000000 L4:0.009698 |
#           >> Test macro:95.770399 ± 95.564573 | micro:0.432076 ± 0.209720          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 131/500 | Train(sampled) L1:0.735314 L2:0.000000 L4:0.008634 |
#           >> Test macro:99.420344 ± 99.213612 | micro:0.394373 ± 0.203339          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 132/500 | Train(sampled) L1:0.739254 L2:0.000000 L4:0.008842 |
#           >> Test macro:94.383419 ± 94.065944 | micro:0.715722 ± 0.271352          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 133/500 | Train(sampled) L1:0.692757 L2:0.000000 L4:0.008274 |
#           >> Test macro:77.956727 ± 77.759699 | micro:0.490116 ± 0.209722          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 134/500 | Train(sampled) L1:0.706575 L2:0.000000 L4:0.007832 |
#           >> Test macro:84.489222 ± 84.212325 | micro:0.561925 ± 0.240267          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 135/500 | Train(sampled) L1:0.686449 L2:0.000000 L4:0.007948 |
#           >> Test macro:71.458629 ± 71.261304 | micro:0.394671 ± 0.167918          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 136/500 | Train(sampled) L1:0.703456 L2:0.000000 L4:0.007772 |
#           >> Test macro:75.574474 ± 75.383972 | micro:0.465727 ± 0.194001          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 137/500 | Train(sampled) L1:0.693994 L2:0.000000 L4:0.008336 |
#           >> Test macro:65.911225 ± 65.631393 | micro:0.492495 ± 0.173438          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 138/500 | Train(sampled) L1:0.694667 L2:0.000000 L4:0.007267 |
#           >> Test macro:61.213586 ± 60.908884 | micro:0.456855 ± 0.183617          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 139/500 | Train(sampled) L1:0.674417 L2:0.000000 L4:0.008205 |
#           >> Test macro:57.059791 ± 56.678210 | micro:0.491452 ± 0.166873          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 140/500 | Train(sampled) L1:0.852451 L2:0.000000 L4:0.007943 |
#           >> Test macro:59.331117 ± 58.813490 | micro:0.685029 ± 0.248510          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 141/500 | Train(sampled) L1:0.672707 L2:0.000000 L4:0.008428 |
#           >> Test macro:55.776064 ± 55.350339 | micro:0.654482 ± 0.205582          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 142/500 | Train(sampled) L1:0.673951 L2:0.000000 L4:0.007492 |
#           >> Test macro:50.114233 ± 49.922530 | micro:0.345200 ± 0.120982          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 143/500 | Train(sampled) L1:0.683392 L2:0.000000 L4:0.007503 |
#           >> Test macro:48.830634 ± 48.620056 | micro:0.437929 ± 0.145806          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 144/500 | Train(sampled) L1:0.666043 L2:0.000000 L4:0.007867 |
#           >> Test macro:39.811696 ± 39.395504 | micro:0.489572 ± 0.161146          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 145/500 | Train(sampled) L1:0.656839 L2:0.000000 L4:0.008224 |
#           >> Test macro:39.633207 ± 39.452623 | micro:0.267086 ± 0.084305          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 146/500 | Train(sampled) L1:0.657374 L2:0.000000 L4:0.007786 |
#           >> Test macro:31.678074 ± 31.347628 | micro:0.410353 ± 0.194850          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 147/500 | Train(sampled) L1:0.717434 L2:0.000000 L4:0.008258 |
#           >> Test macro:32.829079 ± 32.555532 | micro:0.349219 ± 0.107187          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 148/500 | Train(sampled) L1:0.637700 L2:0.000000 L4:0.008737 |
#           >> Test macro:31.504573 ± 31.313126 | micro:0.237997 ± 0.060040          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 149/500 | Train(sampled) L1:0.625987 L2:0.000000 L4:0.008070 |
#           >> Test macro:24.581713 ± 24.394722 | micro:0.279804 ± 0.067415          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 150/500 | Train(sampled) L1:0.625579 L2:0.000000 L4:0.007707 |
#           >> Test macro:23.374461 ± 23.175507 | micro:0.242461 ± 0.050730          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 151/500 | Train(sampled) L1:0.618505 L2:0.000000 L4:0.007565 |
#           >> Test macro:24.937132 ± 24.595195 | micro:0.411383 ± 0.116040          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 152/500 | Train(sampled) L1:0.613658 L2:0.000000 L4:0.007940 |
#           >> Test macro:18.315345 ± 18.142897 | micro:0.206941 ± 0.041556          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 153/500 | Train(sampled) L1:0.596325 L2:0.000000 L4:0.008346 |
#           >> Test macro:12.435446 ± 12.142674 | micro:0.329212 ± 0.118904          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 154/500 | Train(sampled) L1:0.582809 L2:0.000000 L4:0.007996 |
#           >> Test macro:11.200263 ± 10.926856 | micro:0.291306 ± 0.085606          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 155/500 | Train(sampled) L1:0.595230 L2:0.000000 L4:0.008011 |
#           >> Test macro:17.181934 ± 16.913139 | micro:0.332648 ± 0.099787          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 156/500 | Train(sampled) L1:0.593891 L2:0.000000 L4:0.008510 |
#           >> Test macro:12.055343 ± 11.854783 | micro:0.216335 ± 0.037213          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 157/500 | Train(sampled) L1:0.559541 L2:0.000000 L4:0.009140 |
#           >> Test macro:5.592050 ± 5.305722 | micro:0.270489 ± 0.080126          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 158/500 | Train(sampled) L1:0.550287 L2:0.000000 L4:0.008223 |
#           >> Test macro:3.827150 ± 3.643452 | micro:0.183593 ± 0.012904          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 159/500 | Train(sampled) L1:0.543507 L2:0.000000 L4:0.008370 |
#           >> Test macro:3.652530 ± 3.337453 | micro:0.326265 ± 0.199130          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 160/500 | Train(sampled) L1:0.510878 L2:0.000000 L4:0.008912 |
#           >> Test macro:23.578352 ± 23.247976 | micro:0.441277 ± 0.156863          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 161/500 | Train(sampled) L1:0.454287 L2:0.000000 L4:0.010546 |
#           >> Test macro:42.340443 ± 42.137196 | micro:0.375452 ± 0.166283          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 162/500 | Train(sampled) L1:0.434063 L2:0.000000 L4:0.011410 |
#           >> Test macro:31.402247 ± 31.117244 | micro:0.379689 ± 0.158199          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 163/500 | Train(sampled) L1:0.370324 L2:0.000000 L4:0.014093 |
#           >> Test macro:1.561068 ± 1.378191 | micro:0.172238 ± 0.013462          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 164/500 | Train(sampled) L1:1.243111 L2:0.000000 L4:0.015476 |
#           >> Test macro:1.605126 ± 1.326733 | micro:0.258980 ± 0.062243          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 165/500 | Train(sampled) L1:0.293506 L2:0.000000 L4:0.012212 |
#           >> Test macro:2.329502 ± 1.942847 | micro:0.357733 ± 0.147753          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 166/500 | Train(sampled) L1:0.299979 L2:0.000000 L4:0.009680 |
#           >> Test macro:2.068392 ± 1.759995 | micro:0.306427 ± 0.082631          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 167/500 | Train(sampled) L1:0.275465 L2:0.000000 L4:0.009149 |
#           >> Test macro:12.596112 ± 12.051004 | micro:0.568220 ± 0.237610          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 168/500 | Train(sampled) L1:0.823558 L2:0.000000 L4:0.008363 |
#           >> Test macro:3.048777 ± 2.662246 | micro:0.357019 ± 0.202750          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 169/500 | Train(sampled) L1:0.348760 L2:0.000000 L4:0.007602 |
#           >> Test macro:7.324249 ± 6.939061 | micro:0.367877 ± 0.172148          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 170/500 | Train(sampled) L1:0.399400 L2:0.000000 L4:0.007293 |
#           >> Test macro:4.882840 ± 4.693301 | micro:0.190836 ± 0.021486          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 171/500 | Train(sampled) L1:0.907853 L2:0.000000 L4:0.008020 |
#           >> Test macro:3.602515 ± 3.339464 | micro:0.261734 ± 0.046295          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 172/500 | Train(sampled) L1:2.166407 L2:0.000000 L4:0.007665 |
#           >> Test macro:0.937166 ± 0.569376 | micro:0.375656 ± 0.200978          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 173/500 | Train(sampled) L1:1.502819 L2:0.000000 L4:0.008085 |
#           >> Test macro:1.302912 ± 0.817319 | micro:0.469842 ± 0.219183          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 174/500 | Train(sampled) L1:1.087954 L2:0.000000 L4:0.007203 |
#           >> Test macro:1.862018 ± 1.690404 | micro:0.165031 ± 0.010988          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 175/500 | Train(sampled) L1:0.366018 L2:0.000000 L4:0.006664 |
#           >> Test macro:1.216694 ± 0.887171 | micro:0.306318 ± 0.119489          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 176/500 | Train(sampled) L1:0.271610 L2:0.000000 L4:0.006830 |
#           >> Test macro:1.530441 ± 1.172901 | micro:0.365900 ± 0.147117          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 177/500 | Train(sampled) L1:0.276114 L2:0.000000 L4:0.006658 |
#           >> Test macro:2.708218 ± 2.336207 | micro:0.337508 ± 0.141052          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 178/500 | Train(sampled) L1:0.261977 L2:0.000000 L4:0.006272 |
#           >> Test macro:7.150785 ± 6.946753 | micro:0.213450 ± 0.028807          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 179/500 | Train(sampled) L1:0.317889 L2:0.000000 L4:0.006152 |
#           >> Test macro:5.606254 ± 5.429256 | micro:0.187453 ± 0.031755          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 180/500 | Train(sampled) L1:0.417270 L2:0.000000 L4:0.006194 |
#           >> Test macro:25.778805 ± 25.477887 | micro:0.350557 ± 0.111410          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 181/500 | Train(sampled) L1:0.353370 L2:0.000000 L4:0.005993 |
#           >> Test macro:2.331474 ± 2.143862 | micro:0.180969 ± 0.015406          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 182/500 | Train(sampled) L1:0.609213 L2:0.000000 L4:0.006503 |
#           >> Test macro:29.220838 ± 28.838609 | micro:0.445700 ± 0.175577          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 183/500 | Train(sampled) L1:0.428142 L2:0.000000 L4:0.006716 |
#           >> Test macro:2.921413 ± 2.499279 | micro:0.427374 ± 0.249758          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 184/500 | Train(sampled) L1:0.269766 L2:0.000000 L4:0.006517 |
#           >> Test macro:9.237025 ± 8.654102 | micro:0.541852 ± 0.213970          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 185/500 | Train(sampled) L1:0.657897 L2:0.000000 L4:0.006035 |
#           >> Test macro:2.225788 ± 1.861139 | micro:0.332024 ± 0.167426          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 186/500 | Train(sampled) L1:0.449351 L2:0.000000 L4:0.006495 |
#           >> Test macro:35.709967 ± 35.522467 | micro:0.287887 ± 0.126664          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 187/500 | Train(sampled) L1:0.367354 L2:0.000000 L4:0.006456 |
#           >> Test macro:1.738693 ± 1.483047 | micro:0.234120 ± 0.061753          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 188/500 | Train(sampled) L1:0.622248 L2:0.000000 L4:0.006939 |
#           >> Test macro:1.732927 ± 1.541133 | micro:0.180843 ± 0.017074          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 189/500 | Train(sampled) L1:0.698856 L2:0.000000 L4:0.005690 |
#           >> Test macro:27.971672 ± 27.601518 | micro:0.508794 ± 0.235688          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 190/500 | Train(sampled) L1:1.029644 L2:0.000000 L4:0.005973 |
#           >> Test macro:1.544426 ± 1.374739 | micro:0.158295 ± 0.009285          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 191/500 | Train(sampled) L1:0.261727 L2:0.000000 L4:0.006019 |
#           >> Test macro:2.373881 ± 2.143799 | micro:0.213977 ± 0.042595          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 192/500 | Train(sampled) L1:0.684643 L2:0.000000 L4:0.005378 |
#           >> Test macro:4.143545 ± 3.964522 | micro:0.175739 ± 0.017156          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 193/500 | Train(sampled) L1:0.401529 L2:0.000000 L4:0.005552 |
#           >> Test macro:2.885757 ± 2.680323 | micro:0.197431 ± 0.021848          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 194/500 | Train(sampled) L1:0.952919 L2:0.000000 L4:0.006452 |
#           >> Test macro:1.675358 ± 1.484389 | micro:0.181003 ± 0.013985          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 195/500 | Train(sampled) L1:0.484388 L2:0.000000 L4:0.006333 |
#           >> Test macro:2.973577 ± 2.652579 | micro:0.329960 ± 0.159916          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 196/500 | Train(sampled) L1:0.264926 L2:0.000000 L4:0.005342 |
#           >> Test macro:23.542217 ± 23.153470 | micro:0.420227 ± 0.166519          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 197/500 | Train(sampled) L1:0.256264 L2:0.000000 L4:0.005588 |
#           >> Test macro:1.811963 ± 1.634281 | micro:0.167957 ± 0.009972          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 198/500 | Train(sampled) L1:0.285681 L2:0.000000 L4:0.005580 |
#           >> Test macro:0.563155 ± 0.254919 | micro:0.378031 ± 0.211548          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 199/500 | Train(sampled) L1:0.298876 L2:0.000000 L4:0.005279 |
#           >> Test macro:32.482219 ± 32.298113 | micro:0.289677 ± 0.146670          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 200/500 | Train(sampled) L1:2.442104 L2:0.000000 L4:0.005667 |
#           >> Test macro:31.499431 ± 31.144817 | micro:0.505705 ± 0.288071          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 201/500 | Train(sampled) L1:0.256656 L2:0.000000 L4:0.005755 |
#           >> Test macro:2.255373 ± 2.076550 | micro:0.171303 ± 0.014998          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 202/500 | Train(sampled) L1:0.258949 L2:0.000000 L4:0.005020 |
#           >> Test macro:1.067623 ± 0.868417 | micro:0.190734 ± 0.015145          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 203/500 | Train(sampled) L1:0.248592 L2:0.000000 L4:0.004940 |
#           >> Test macro:45.050862 ± 44.734345 | micro:0.510752 ± 0.283017          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 204/500 | Train(sampled) L1:0.253374 L2:0.000000 L4:0.005103 |
#           >> Test macro:1.161938 ± 0.980377 | micro:0.170676 ± 0.010518          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 205/500 | Train(sampled) L1:0.786349 L2:0.000000 L4:0.004807 |
#           >> Test macro:28.603289 ± 28.437961 | micro:0.281130 ± 0.137790          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 206/500 | Train(sampled) L1:0.250573 L2:0.000000 L4:0.005145 |
#           >> Test macro:1.190545 ± 0.707617 | micro:0.468289 ± 0.199688          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 207/500 | Train(sampled) L1:0.289168 L2:0.000000 L4:0.005343 |
#           >> Test macro:2.712481 ± 2.523585 | micro:0.181808 ± 0.018084          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 208/500 | Train(sampled) L1:0.247842 L2:0.000000 L4:0.004420 |
#           >> Test macro:5.801879 ± 5.448333 | micro:0.379539 ± 0.188540          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 209/500 | Train(sampled) L1:0.439040 L2:0.000000 L4:0.004977 |
#           >> Test macro:1.912176 ± 1.715692 | micro:0.185604 ± 0.026394          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 210/500 | Train(sampled) L1:0.247451 L2:0.000000 L4:0.005015 |
#           >> Test macro:2.448326 ± 2.275199 | micro:0.162995 ± 0.012617          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 211/500 | Train(sampled) L1:0.250468 L2:0.000000 L4:0.005293 |
#           >> Test macro:5.476708 ± 5.291783 | micro:0.182658 ± 0.019034          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 212/500 | Train(sampled) L1:0.250610 L2:0.000000 L4:0.004488 |
#           >> Test macro:3.271688 ± 2.965729 | micro:0.321026 ± 0.218800          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 213/500 | Train(sampled) L1:0.248264 L2:0.000000 L4:0.004758 |
#           >> Test macro:0.763713 ± 0.582099 | micro:0.171335 ± 0.009828          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 214/500 | Train(sampled) L1:0.247470 L2:0.000000 L4:0.004699 |
#           >> Test macro:0.488488 ± 0.121807 | micro:0.535894 ± 0.338081          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 215/500 | Train(sampled) L1:0.725726 L2:0.000000 L4:0.004317 |
#           >> Test macro:1.349874 ± 1.037385 | micro:0.321662 ± 0.145191          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 216/500 | Train(sampled) L1:0.422843 L2:0.000000 L4:0.003955 |
#           >> Test macro:30.933437 ± 30.541776 | micro:0.437912 ± 0.169981          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 217/500 | Train(sampled) L1:0.243517 L2:0.000000 L4:0.004085 |
#           >> Test macro:0.752504 ± 0.573772 | micro:0.168860 ± 0.010567          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 218/500 | Train(sampled) L1:0.272746 L2:0.000000 L4:0.004833 |
#           >> Test macro:1.480026 ± 1.260305 | micro:0.207166 ± 0.038151          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 219/500 | Train(sampled) L1:0.258914 L2:0.000000 L4:0.004122 |
#           >> Test macro:37.905615 ± 37.714025 | micro:0.363494 ± 0.172316          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 220/500 | Train(sampled) L1:0.296101 L2:0.000000 L4:0.004084 |
#           >> Test macro:1.563207 ± 1.242329 | micro:0.331905 ± 0.165709          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 221/500 | Train(sampled) L1:1.990792 L2:0.000000 L4:0.005192 |
#           >> Test macro:5.867217 ± 5.682655 | micro:0.179990 ± 0.019692          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 222/500 | Train(sampled) L1:0.245514 L2:0.000000 L4:0.004918 |
#           >> Test macro:1.939764 ± 1.548668 | micro:0.369140 ± 0.149534          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 223/500 | Train(sampled) L1:0.255264 L2:0.000000 L4:0.004536 |
#           >> Test macro:2.966035 ± 2.666023 | micro:0.308572 ± 0.138622          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 224/500 | Train(sampled) L1:0.275498 L2:0.000000 L4:0.005321 |
#           >> Test macro:1.503828 ± 1.321748 | micro:0.172415 ± 0.011027          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 225/500 | Train(sampled) L1:0.251414 L2:0.000000 L4:0.004929 |
#           >> Test macro:6.272676 ± 6.060594 | micro:0.202307 ± 0.031114          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 226/500 | Train(sampled) L1:1.797630 L2:0.000000 L4:0.004422 |
#           >> Test macro:4.200015 ± 3.601895 | micro:0.542839 ± 0.230448          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 227/500 | Train(sampled) L1:0.242251 L2:0.000000 L4:0.004611 |
#           >> Test macro:2.193505 ± 1.991603 | micro:0.193285 ± 0.021355          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 228/500 | Train(sampled) L1:0.242784 L2:0.000000 L4:0.004089 |
#           >> Test macro:1.642489 ± 1.475315 | micro:0.158791 ± 0.010164          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 229/500 | Train(sampled) L1:0.873747 L2:0.000000 L4:0.004292 |
#           >> Test macro:1.462706 ± 1.296127 | micro:0.156117 ± 0.010616          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 230/500 | Train(sampled) L1:0.242329 L2:0.000000 L4:0.004021 |
#           >> Test macro:0.610295 ± 0.282450 | micro:0.360269 ± 0.143040          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 231/500 | Train(sampled) L1:0.386737 L2:0.000000 L4:0.004019 |
#           >> Test macro:1.894748 ± 1.547414 | micro:0.364634 ± 0.186177          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 232/500 | Train(sampled) L1:0.311095 L2:0.000000 L4:0.004060 |
#           >> Test macro:2.864280 ± 2.533788 | micro:0.339707 ± 0.154743          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 233/500 | Train(sampled) L1:0.237450 L2:0.000000 L4:0.004155 |
#           >> Test macro:1.592913 ± 1.252354 | micro:0.356631 ± 0.203415          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 234/500 | Train(sampled) L1:0.238935 L2:0.000000 L4:0.004219 |
#           >> Test macro:1.991864 ± 1.781612 | micro:0.200755 ± 0.015264          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 235/500 | Train(sampled) L1:0.230907 L2:0.000000 L4:0.003629 |
#           >> Test macro:1.646378 ± 1.341769 | micro:0.312096 ± 0.144380          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 236/500 | Train(sampled) L1:0.243154 L2:0.000000 L4:0.004011 |
#           >> Test macro:2.183577 ± 1.955107 | micro:0.212547 ± 0.038540          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 237/500 | Train(sampled) L1:0.241394 L2:0.000000 L4:0.003895 |
#           >> Test macro:1.219189 ± 1.036822 | micro:0.172712 ± 0.012527          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 238/500 | Train(sampled) L1:0.236924 L2:0.000000 L4:0.003922 |
#           >> Test macro:1.845938 ± 1.460550 | micro:0.357360 ± 0.154260          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 239/500 | Train(sampled) L1:0.387535 L2:0.000000 L4:0.004108 |
#           >> Test macro:1.265916 ± 1.070592 | micro:0.186036 ± 0.026332          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 240/500 | Train(sampled) L1:0.677419 L2:0.000000 L4:0.003523 |
#           >> Test macro:3.843882 ± 3.667855 | micro:0.175656 ± 0.018765          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 241/500 | Train(sampled) L1:0.233323 L2:0.000000 L4:0.003654 |
#           >> Test macro:2.712153 ± 2.500470 | micro:0.204987 ± 0.027943          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 242/500 | Train(sampled) L1:0.236556 L2:0.000000 L4:0.003909 |
#           >> Test macro:2.933066 ± 2.755603 | micro:0.170678 ± 0.011887          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 243/500 | Train(sampled) L1:0.236660 L2:0.000000 L4:0.003655 |
#           >> Test macro:2.674539 ± 2.502464 | micro:0.160894 ± 0.012380          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 244/500 | Train(sampled) L1:0.235812 L2:0.000000 L4:0.003316 |
#           >> Test macro:39.480530 ± 39.288002 | micro:0.303155 ± 0.178623          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 245/500 | Train(sampled) L1:0.231683 L2:0.000000 L4:0.003783 |
#           >> Test macro:1.786788 ± 1.231353 | micro:0.541075 ± 0.257080          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 246/500 | Train(sampled) L1:0.232440 L2:0.000000 L4:0.003601 |
#           >> Test macro:1.498627 ± 1.321390 | micro:0.167053 ± 0.013716          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 247/500 | Train(sampled) L1:0.237291 L2:0.000000 L4:0.003740 |
#           >> Test macro:2.906935 ± 2.407596 | micro:0.542730 ± 0.325158          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 248/500 | Train(sampled) L1:0.229532 L2:0.000000 L4:0.003505 |
#           >> Test macro:1.207860 ± 0.710394 | micro:0.539430 ± 0.368576          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 249/500 | Train(sampled) L1:0.230162 L2:0.000000 L4:0.003760 |
#           >> Test macro:1.728806 ± 1.425726 | micro:0.312667 ± 0.244002          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 250/500 | Train(sampled) L1:0.226933 L2:0.000000 L4:0.003064 |
#           >> Test macro:9.011560 ± 8.529463 | micro:0.540991 ± 0.307202          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 251/500 | Train(sampled) L1:0.298656 L2:0.000000 L4:0.003886 |
#           >> Test macro:1.480749 ± 1.058793 | micro:0.448172 ± 0.196840          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 252/500 | Train(sampled) L1:0.221776 L2:0.000000 L4:0.003400 |
#           >> Test macro:2.120312 ± 1.769078 | micro:0.363311 ± 0.198282          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 253/500 | Train(sampled) L1:0.226515 L2:0.000000 L4:0.003327 |
#           >> Test macro:1.801360 ± 1.629656 | micro:0.162338 ± 0.010198          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 254/500 | Train(sampled) L1:0.225155 L2:0.000000 L4:0.003575 |
#           >> Test macro:16.135380 ± 15.810901 | micro:0.391457 ± 0.199460          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 255/500 | Train(sampled) L1:0.230706 L2:0.000000 L4:0.003564 |
#           >> Test macro:2.828414 ± 2.644509 | micro:0.176081 ± 0.019183          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 256/500 | Train(sampled) L1:0.223458 L2:0.000000 L4:0.003248 |
#           >> Test macro:2.961577 ± 2.781285 | micro:0.176273 ± 0.016507          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 257/500 | Train(sampled) L1:0.222673 L2:0.000000 L4:0.003206 |
#           >> Test macro:2.082038 ± 1.897464 | micro:0.172239 ± 0.011982          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 258/500 | Train(sampled) L1:0.225364 L2:0.000000 L4:0.003406 |
#           >> Test macro:0.738802 ± 0.263899 | micro:0.534584 ± 0.445460          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 259/500 | Train(sampled) L1:0.232616 L2:0.000000 L4:0.003349 |
#           >> Test macro:2.259090 ± 1.929307 | micro:0.339095 ± 0.185099          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 260/500 | Train(sampled) L1:0.219879 L2:0.000000 L4:0.002966 |
#           >> Test macro:2.135855 ± 1.950954 | micro:0.175706 ± 0.017367          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 261/500 | Train(sampled) L1:0.227265 L2:0.000000 L4:0.002935 |
#           >> Test macro:2.278898 ± 1.772513 | micro:0.541183 ± 0.343856          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 262/500 | Train(sampled) L1:0.224452 L2:0.000000 L4:0.003440 |
#           >> Test macro:33.681287 ± 33.505779 | micro:0.281143 ± 0.132634          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 263/500 | Train(sampled) L1:0.232826 L2:0.000000 L4:0.003306 |
#           >> Test macro:3.161394 ± 2.696369 | micro:0.455743 ± 0.290444          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Epoch 264/500 | Train(sampled) L1:0.218543 L2:0.000000 L4:0.002789 |
#           >> Test macro:2.255646 ± 1.950318 | micro:0.313146 ± 0.169908          >> Test (Noise) macro:0.000000 ± 0.000000 | micro:0.000000 ± 0.000000
# Early stopping at epoch 264/500 (best test macro-MSE(avg): 0.464063 @ epoch 214)
# TEST RESULTS | macro: 1.308410 ± 1.124694 | micro: 0.177263 ± 0.017413macro (noise): 0.000000 ± 0.000000 | micro (noise): 0.000000 ± 0.000000
#           >> per_group (weighted SE): {0: '0.275746 ± 0.014900 (n=777)', 1: '6.156132 ± 5.273376 (n=3)', 5: '0.335060 ± 0.297838 (n=1019)'}
#           >> per_group (weighted SE): {0: '0.000000 ± 0.000000 (n=777)', 1: '0.000000 ± 0.000000 (n=3)', 5: '0.000000 ± 0.000000 (n=1019)'}

# %%
tsdiffusion.lam=[0.45,0.5,0.05]
res_tsdiffusion = tsdiffusion.train_cognite(
    df=df_scaled,
    feature_cols=list(df_scaled.columns[:-1]),
    static_features_cols=None,
    timestamp_col='index',
    states_col='states',
    batch_size=256,
    window_size=30,
    window_step=30,
    epochs = 1000,
    validate=False,
    patience=100
)
res_tsdiffusion = [r for r in res_tsdiffusion if r is not None]  # remove None results
# Out:
# GRUPOS (total): {0: 3886, 1: 15, 5: 5093}
# GRUPOS (train): {0: 3109, 1: 12, 5: 4074}
# GRUPOS (test):  {0: 777, 1: 3, 5: 1019}
# Epoch 1/1000 | Train(sampled) L1:296.093087 L2:1.047663 L4:0.752773 |
#           >> Test macro:1069.271596 ± 1067.933099 | micro:4.691816 ± 2.505476          >> Test (Noise) macro:1.038969 ± 0.004665 | micro:1.043645 ± 0.000398
# Epoch 2/1000 | Train(sampled) L1:185.425685 L2:1.040211 L4:0.719312 |
#           >> Test macro:1014.954802 ± 1013.646633 | micro:4.304497 ± 2.305652          >> Test (Noise) macro:1.034964 ± 0.002022 | micro:1.032959 ± 0.000386
# Epoch 3/1000 | Train(sampled) L1:91.507922 L2:1.027186 L4:0.663538 |
#           >> Test macro:840.351934 ± 839.026435 | micro:4.245378 ± 2.215754          >> Test (Noise) macro:1.011635 ± 0.001228 | micro:1.012697 ± 0.000362
# Epoch 4/1000 | Train(sampled) L1:77.409980 L2:1.007968 L4:0.617451 |
#           >> Test macro:903.405654 ± 902.112138 | micro:4.359454 ± 2.246890          >> Test (Noise) macro:1.003366 ± 0.000145 | micro:1.003218 ± 0.000353
# Epoch 5/1000 | Train(sampled) L1:71.975157 L2:1.002875 L4:0.569203 |
#           >> Test macro:1078.529284 ± 1077.261725 | micro:4.220660 ± 2.376813          >> Test (Noise) macro:1.002636 ± 0.001614 | micro:1.001017 ± 0.000355
# Epoch 6/1000 | Train(sampled) L1:75.680674 L2:1.001947 L4:0.538220 |
#           >> Test macro:956.470882 ± 955.110263 | micro:4.336997 ± 2.392816          >> Test (Noise) macro:1.003948 ± 0.003374 | micro:1.000596 ± 0.000352
# Epoch 7/1000 | Train(sampled) L1:72.527098 L2:1.001083 L4:0.517080 |
#           >> Test macro:1009.592876 ± 1008.095008 | micro:4.805232 ± 2.417171          >> Test (Noise) macro:1.000587 ± 0.000346 | micro:1.000930 ± 0.000363
# Epoch 8/1000 | Train(sampled) L1:72.170864 L2:1.000593 L4:0.502223 |
#           >> Test macro:1013.792399 ± 1012.057955 | micro:4.195601 ± 2.251069          >> Test (Noise) macro:0.996121 ± 0.003983 | micro:1.000100 ± 0.000350
# Epoch 9/1000 | Train(sampled) L1:59.684665 L2:1.000648 L4:0.489376 |
#           >> Test macro:952.633849 ± 950.171462 | micro:5.039097 ± 2.170728          >> Test (Noise) macro:1.004122 ± 0.004769 | micro:0.999432 ± 0.000359
# Epoch 10/1000 | Train(sampled) L1:70.966419 L2:1.000233 L4:0.482709 |
#           >> Test macro:943.308686 ± 939.742194 | micro:6.718461 ± 2.289171          >> Test (Noise) macro:1.004139 ± 0.004171 | micro:1.000005 ± 0.000354
# Epoch 11/1000 | Train(sampled) L1:72.108875 L2:0.999983 L4:0.479386 |
#           >> Test macro:824.465888 ± 819.370937 | micro:8.307523 ± 2.125994          >> Test (Noise) macro:1.000219 ± 0.001077 | micro:0.999134 ± 0.000361
# Epoch 12/1000 | Train(sampled) L1:59.611996 L2:0.999640 L4:0.472349 |
#           >> Test macro:868.342287 ± 862.341147 | micro:8.723633 ± 2.022623          >> Test (Noise) macro:0.994200 ± 0.005160 | micro:0.999351 ± 0.000361
# Epoch 13/1000 | Train(sampled) L1:71.868009 L2:0.999253 L4:0.477449 |
#           >> Test macro:956.094380 ± 952.222124 | micro:6.633802 ± 2.129655          >> Test (Noise) macro:0.998259 ± 0.000279 | micro:0.998537 ± 0.000351
# Epoch 14/1000 | Train(sampled) L1:64.255119 L2:0.998399 L4:0.472081 |
#           >> Test macro:665.986638 ± 663.989589 | micro:4.360944 ± 1.752530          >> Test (Noise) macro:0.998114 ± 0.001067 | micro:0.997028 ± 0.000362
# Epoch 15/1000 | Train(sampled) L1:66.362947 L2:0.995487 L4:0.469865 |
#           >> Test macro:757.651075 ± 755.840298 | micro:4.954943 ± 2.068208          >> Test (Noise) macro:0.990434 ± 0.000520 | micro:0.990914 ± 0.000374
# Epoch 16/1000 | Train(sampled) L1:62.315877 L2:0.986394 L4:0.464800 |
#           >> Test macro:584.867473 ± 582.751830 | micro:4.199168 ± 1.514508          >> Test (Noise) macro:0.970945 ± 0.002142 | micro:0.972995 ± 0.000468
# Epoch 17/1000 | Train(sampled) L1:60.762143 L2:0.966173 L4:0.462689 |
#           >> Test macro:620.676770 ± 618.940323 | micro:3.888594 ± 1.621737          >> Test (Noise) macro:0.940521 ± 0.001406 | micro:0.941236 ± 0.000696
# Epoch 18/1000 | Train(sampled) L1:61.410385 L2:0.939896 L4:0.458301 |
#           >> Test macro:483.602663 ± 481.697583 | micro:4.043590 ± 1.499122          >> Test (Noise) macro:0.913135 ± 0.005125 | micro:0.907911 ± 0.000849
# Epoch 19/1000 | Train(sampled) L1:58.442992 L2:0.912644 L4:0.458100 |
#           >> Test macro:505.751858 ± 504.333351 | micro:3.191084 ± 1.286307          >> Test (Noise) macro:0.879850 ± 0.002562 | micro:0.877232 ± 0.001015
# Epoch 20/1000 | Train(sampled) L1:64.612574 L2:0.886781 L4:0.450324 |
#           >> Test macro:568.032953 ± 566.387931 | micro:3.598957 ± 1.420392          >> Test (Noise) macro:0.842399 ± 0.009552 | micro:0.851684 ± 0.001200
# Epoch 21/1000 | Train(sampled) L1:61.771567 L2:0.862702 L4:0.444978 |
#           >> Test macro:570.785592 ± 569.408482 | micro:2.866973 ± 1.268938          >> Test (Noise) macro:0.821136 ± 0.003042 | micro:0.823983 ± 0.001321
# Epoch 22/1000 | Train(sampled) L1:54.795013 L2:0.838337 L4:0.441415 |
#           >> Test macro:491.439410 ± 490.075338 | micro:2.846349 ± 1.178171          >> Test (Noise) macro:0.791284 ± 0.005910 | micro:0.797135 ± 0.001396
# Epoch 23/1000 | Train(sampled) L1:53.406571 L2:0.816620 L4:0.428731 |
#           >> Test macro:520.812102 ± 519.501324 | micro:2.968657 ± 1.245364          >> Test (Noise) macro:0.799491 ± 0.024729 | micro:0.774664 ± 0.001432
# Epoch 24/1000 | Train(sampled) L1:57.996850 L2:0.795559 L4:0.415480 |
#           >> Test macro:379.351235 ± 378.165385 | micro:2.583188 ± 0.999848          >> Test (Noise) macro:0.738335 ± 0.010080 | micro:0.748089 ± 0.001426
# Epoch 25/1000 | Train(sampled) L1:53.130559 L2:0.775767 L4:0.403676 |
#           >> Test macro:330.372673 ± 329.107402 | micro:2.538213 ± 0.901979          >> Test (Noise) macro:0.737198 ± 0.006884 | micro:0.730163 ± 0.001572
# Epoch 26/1000 | Train(sampled) L1:58.621207 L2:0.757600 L4:0.393768 |
#           >> Test macro:347.297360 ± 346.120102 | micro:2.076672 ± 0.771519          >> Test (Noise) macro:0.732037 ± 0.015167 | micro:0.716747 ± 0.001781
# Epoch 27/1000 | Train(sampled) L1:47.856698 L2:0.738067 L4:0.378240 |
#           >> Test macro:301.991414 ± 300.930469 | micro:2.013617 ± 0.739595          >> Test (Noise) macro:0.702988 ± 0.009765 | micro:0.693069 ± 0.001626
# Epoch 28/1000 | Train(sampled) L1:38.121304 L2:0.722165 L4:0.366479 |
#           >> Test macro:249.994765 ± 248.922840 | micro:1.963230 ± 0.655770          >> Test (Noise) macro:0.702083 ± 0.028759 | micro:0.673538 ± 0.001674
# Epoch 29/1000 | Train(sampled) L1:42.221990 L2:0.705680 L4:0.350833 |
#           >> Test macro:286.424375 ± 285.316051 | micro:1.706356 ± 0.594298          >> Test (Noise) macro:0.720646 ± 0.056327 | micro:0.663961 ± 0.001881
# Epoch 30/1000 | Train(sampled) L1:46.297515 L2:0.688445 L4:0.336825 |
#           >> Test macro:210.443435 ± 209.446460 | micro:1.544119 ± 0.520569          >> Test (Noise) macro:0.677504 ± 0.039032 | micro:0.638274 ± 0.001557
# Epoch 31/1000 | Train(sampled) L1:43.804369 L2:0.672571 L4:0.320396 |
#           >> Test macro:130.515181 ± 129.415823 | micro:1.446031 ± 0.373720          >> Test (Noise) macro:0.626051 ± 0.004460 | micro:0.621611 ± 0.001614
# Epoch 32/1000 | Train(sampled) L1:36.616902 L2:0.654139 L4:0.307097 |
#           >> Test macro:155.307885 ± 154.308611 | micro:1.389259 ± 0.361063          >> Test (Noise) macro:0.617551 ± 0.011618 | micro:0.605673 ± 0.001757
# Epoch 33/1000 | Train(sampled) L1:36.103832 L2:0.638938 L4:0.288921 |
#           >> Test macro:90.299410 ± 89.193643 | micro:1.325054 ± 0.246086          >> Test (Noise) macro:0.588126 ± 0.002145 | micro:0.587175 ± 0.001690
# Epoch 34/1000 | Train(sampled) L1:40.360842 L2:0.622652 L4:0.275364 |
#           >> Test macro:61.447633 ± 60.449776 | micro:1.161776 ± 0.186151          >> Test (Noise) macro:0.582607 ± 0.010054 | micro:0.572526 ± 0.001703
# Epoch 35/1000 | Train(sampled) L1:33.563740 L2:0.607076 L4:0.262615 |
#           >> Test macro:44.802696 ± 43.605989 | micro:1.243504 ± 0.200661          >> Test (Noise) macro:0.548480 ± 0.006079 | micro:0.554110 ± 0.001609
# Epoch 36/1000 | Train(sampled) L1:34.825841 L2:0.596470 L4:0.250281 |
#           >> Test macro:15.856318 ± 14.764244 | micro:1.080111 ± 0.251505          >> Test (Noise) macro:0.536119 ± 0.005063 | micro:0.541039 ± 0.001630
# Epoch 37/1000 | Train(sampled) L1:35.245309 L2:0.580964 L4:0.235902 |
#           >> Test macro:11.257510 ± 10.259914 | micro:0.970110 ± 0.123194          >> Test (Noise) macro:0.574713 ± 0.047957 | micro:0.526651 ± 0.001615
# Epoch 38/1000 | Train(sampled) L1:36.868421 L2:0.568408 L4:0.228007 |
#           >> Test macro:33.536809 ± 32.609630 | micro:0.992256 ± 0.161385          >> Test (Noise) macro:0.511499 ± 0.002570 | micro:0.511985 ± 0.001512
# Epoch 39/1000 | Train(sampled) L1:29.954878 L2:0.554987 L4:0.214191 |
#           >> Test macro:2.464913 ± 1.534231 | micro:0.894066 ± 0.137836          >> Test (Noise) macro:0.542652 ± 0.042422 | micro:0.500000 ± 0.001431
# Epoch 40/1000 | Train(sampled) L1:39.044746 L2:0.543619 L4:0.203971 |
#           >> Test macro:33.562233 ± 32.569141 | micro:1.049003 ± 0.190025          >> Test (Noise) macro:0.599366 ± 0.110057 | micro:0.489238 ± 0.001531
# Epoch 41/1000 | Train(sampled) L1:36.689901 L2:0.538944 L4:0.194649 |
#           >> Test macro:12.715043 ± 11.756218 | micro:0.948375 ± 0.205472          >> Test (Noise) macro:0.481721 ± 0.001394 | micro:0.482020 ± 0.001538
# Epoch 42/1000 | Train(sampled) L1:35.022833 L2:0.526723 L4:0.186412 |
#           >> Test macro:0.893304 ± 0.259696 | micro:0.820683 ± 0.081183          >> Test (Noise) macro:0.504566 ± 0.035469 | micro:0.469397 ± 0.001580
# Epoch 43/1000 | Train(sampled) L1:35.570035 L2:0.510005 L4:0.173229 |
#           >> Test macro:4.917958 ± 3.958669 | micro:0.928999 ± 0.227513          >> Test (Noise) macro:0.463006 ± 0.008821 | micro:0.454069 ± 0.001436
# Epoch 44/1000 | Train(sampled) L1:36.635179 L2:0.505414 L4:0.169157 |
#           >> Test macro:3.364602 ± 2.458091 | micro:0.863932 ± 0.114935          >> Test (Noise) macro:0.456105 ± 0.007305 | micro:0.448691 ± 0.001490
# Epoch 45/1000 | Train(sampled) L1:36.989137 L2:0.494679 L4:0.164855 |
#           >> Test macro:37.307546 ± 36.416819 | micro:0.985426 ± 0.188842          >> Test (Noise) macro:0.433768 ± 0.004510 | micro:0.437568 ± 0.001554
# Epoch 46/1000 | Train(sampled) L1:27.570348 L2:0.485674 L4:0.154908 |
#           >> Test macro:3.044726 ± 2.041896 | micro:0.961847 ± 0.203080          >> Test (Noise) macro:0.450076 ± 0.021419 | micro:0.428453 ± 0.001455
# Epoch 47/1000 | Train(sampled) L1:24.506599 L2:0.477303 L4:0.145137 |
#           >> Test macro:27.919585 ± 27.134223 | micro:0.819889 ± 0.109073          >> Test (Noise) macro:0.428370 ± 0.005641 | micro:0.422831 ± 0.001674
# Epoch 48/1000 | Train(sampled) L1:29.426922 L2:0.466437 L4:0.143089 |
#           >> Test macro:13.238199 ± 12.251442 | micro:0.970158 ± 0.155459          >> Test (Noise) macro:0.493612 ± 0.079797 | micro:0.413792 ± 0.001633
# Epoch 49/1000 | Train(sampled) L1:35.334632 L2:0.461002 L4:0.144222 |
#           >> Test macro:4.720175 ± 3.858522 | micro:0.822696 ± 0.131300          >> Test (Noise) macro:0.506850 ± 0.105387 | micro:0.401391 ± 0.001455
# Epoch 50/1000 | Train(sampled) L1:36.264976 L2:0.454052 L4:0.136861 |
#           >> Test macro:2.584213 ± 1.573705 | micro:0.979760 ± 0.215023          >> Test (Noise) macro:0.399834 ± 0.003872 | micro:0.402204 ± 0.001411
# Epoch 51/1000 | Train(sampled) L1:30.253937 L2:0.443525 L4:0.128140 |
#           >> Test macro:6.745719 ± 5.725826 | micro:0.994841 ± 0.151664          >> Test (Noise) macro:0.418611 ± 0.034100 | micro:0.384538 ± 0.001381
# Epoch 52/1000 | Train(sampled) L1:37.075314 L2:0.434594 L4:0.129303 |
#           >> Test macro:2.025489 ± 1.086918 | micro:0.909736 ± 0.155270          >> Test (Noise) macro:0.385647 ± 0.006891 | micro:0.378873 ± 0.001471
# Epoch 53/1000 | Train(sampled) L1:30.421324 L2:0.428755 L4:0.119385 |
#           >> Test macro:2.037396 ± 1.142637 | micro:0.866778 ± 0.122563          >> Test (Noise) macro:0.388387 ± 0.018173 | micro:0.370101 ± 0.001361
# Epoch 54/1000 | Train(sampled) L1:26.694835 L2:0.423697 L4:0.118233 |
#           >> Test macro:2.851706 ± 1.972940 | micro:0.844118 ± 0.167561          >> Test (Noise) macro:0.383073 ± 0.014916 | micro:0.367949 ± 0.001736
# Epoch 55/1000 | Train(sampled) L1:33.859950 L2:0.416043 L4:0.120602 |
#           >> Test macro:5.136073 ± 4.332074 | micro:0.767141 ± 0.076925          >> Test (Noise) macro:0.375325 ± 0.016504 | micro:0.358525 ± 0.001511
# Epoch 56/1000 | Train(sampled) L1:30.032945 L2:0.407621 L4:0.118442 |
#           >> Test macro:52.905383 ± 52.104848 | micro:0.931863 ± 0.248687          >> Test (Noise) macro:0.351029 ± 0.001993 | micro:0.349117 ± 0.001409
# Epoch 57/1000 | Train(sampled) L1:20.801280 L2:0.403020 L4:0.117000 |
#           >> Test macro:62.721655 ± 61.870756 | micro:0.947487 ± 0.191529          >> Test (Noise) macro:0.367847 ± 0.024771 | micro:0.342822 ± 0.001335
# Epoch 58/1000 | Train(sampled) L1:30.561424 L2:0.396942 L4:0.107898 |
#           >> Test macro:4.031858 ± 3.028301 | micro:0.982733 ± 0.178376          >> Test (Noise) macro:0.351908 ± 0.011890 | micro:0.339894 ± 0.001467
# Epoch 59/1000 | Train(sampled) L1:25.121353 L2:0.387523 L4:0.104218 |
#           >> Test macro:5.464779 ± 4.565325 | micro:0.869113 ± 0.132088          >> Test (Noise) macro:0.376409 ± 0.044426 | micro:0.332100 ± 0.001341
# Epoch 60/1000 | Train(sampled) L1:33.354871 L2:0.383897 L4:0.122984 |
#           >> Test macro:6.001497 ± 4.981706 | micro:0.991849 ± 0.162227          >> Test (Noise) macro:0.407270 ± 0.079242 | micro:0.328102 ± 0.001541
# Epoch 61/1000 | Train(sampled) L1:28.112464 L2:0.372683 L4:0.113952 |
#           >> Test macro:3.604002 ± 2.704004 | micro:0.880243 ± 0.188035          >> Test (Noise) macro:0.351606 ± 0.031618 | micro:0.319704 ± 0.001358
# Epoch 62/1000 | Train(sampled) L1:24.600370 L2:0.369828 L4:0.110020 |
#           >> Test macro:3.223449 ± 2.258529 | micro:0.937985 ± 0.169091          >> Test (Noise) macro:0.370898 ± 0.053090 | micro:0.317645 ± 0.001686
# Epoch 63/1000 | Train(sampled) L1:28.621631 L2:0.364909 L4:0.102655 |
#           >> Test macro:4.654678 ± 3.729631 | micro:0.876109 ± 0.098092          >> Test (Noise) macro:0.389089 ± 0.076197 | micro:0.312922 ± 0.001439
# Epoch 64/1000 | Train(sampled) L1:21.255792 L2:0.361736 L4:0.102445 |
#           >> Test macro:49.639776 ± 48.893323 | micro:0.873879 ± 0.184495          >> Test (Noise) macro:0.333747 ± 0.022332 | micro:0.311300 ± 0.001520
# Epoch 65/1000 | Train(sampled) L1:22.916425 L2:0.353499 L4:0.103476 |
#           >> Test macro:4.650477 ± 3.778880 | micro:0.823224 ± 0.148791          >> Test (Noise) macro:0.372369 ± 0.069292 | micro:0.303011 ± 0.001667
# Epoch 66/1000 | Train(sampled) L1:23.299359 L2:0.349679 L4:0.100140 |
#           >> Test macro:35.143377 ± 34.146399 | micro:1.099975 ± 0.210199          >> Test (Noise) macro:0.320955 ± 0.024141 | micro:0.296724 ± 0.001274
# Epoch 67/1000 | Train(sampled) L1:19.346161 L2:0.339248 L4:0.099335 |
#           >> Test macro:4.444796 ± 3.603382 | micro:0.806776 ± 0.138433          >> Test (Noise) macro:0.388140 ± 0.099639 | micro:0.288481 ± 0.001545
# Epoch 68/1000 | Train(sampled) L1:21.826334 L2:0.338027 L4:0.099215 |
#           >> Test macro:3.996127 ± 3.139138 | micro:0.828911 ± 0.133682          >> Test (Noise) macro:0.301650 ± 0.016837 | micro:0.284553 ± 0.001658
# Epoch 69/1000 | Train(sampled) L1:27.666921 L2:0.332437 L4:0.107316 |
#           >> Test macro:4.371408 ± 3.409910 | micro:0.939904 ± 0.162904          >> Test (Noise) macro:0.316063 ± 0.027630 | micro:0.288208 ± 0.001733
# Epoch 70/1000 | Train(sampled) L1:26.087492 L2:0.328723 L4:0.103875 |
#           >> Test macro:3.016570 ± 2.048089 | micro:0.938037 ± 0.206809          >> Test (Noise) macro:0.305946 ± 0.030236 | micro:0.275522 ± 0.001618
# Epoch 71/1000 | Train(sampled) L1:20.145753 L2:0.322000 L4:0.100683 |
#           >> Test macro:3.392877 ± 2.465250 | micro:0.895917 ± 0.186023          >> Test (Noise) macro:0.336519 ± 0.068360 | micro:0.268447 ± 0.001711
# Epoch 72/1000 | Train(sampled) L1:18.444279 L2:0.315210 L4:0.099451 |
#           >> Test macro:52.987258 ± 52.238327 | micro:0.891904 ± 0.277816          >> Test (Noise) macro:0.279705 ± 0.009996 | micro:0.269571 ± 0.001833
# Epoch 73/1000 | Train(sampled) L1:19.189743 L2:0.307814 L4:0.096443 |
#           >> Test macro:90.822075 ± 89.917883 | micro:1.070943 ± 0.263463          >> Test (Noise) macro:0.275099 ± 0.011651 | micro:0.263346 ± 0.001773
# Epoch 74/1000 | Train(sampled) L1:15.671295 L2:0.305957 L4:0.091801 |
#           >> Test macro:5.140186 ± 4.353622 | micro:0.749876 ± 0.054232          >> Test (Noise) macro:0.311360 ± 0.058804 | micro:0.252545 ± 0.001557
# Epoch 75/1000 | Train(sampled) L1:21.541360 L2:0.298910 L4:0.097652 |
#           >> Test macro:45.216135 ± 44.409385 | micro:0.962983 ± 0.201681          >> Test (Noise) macro:0.264738 ± 0.010776 | micro:0.253894 ± 0.001495
# Epoch 76/1000 | Train(sampled) L1:18.752822 L2:0.295192 L4:0.089250 |
#           >> Test macro:5.120405 ± 4.051845 | micro:1.054766 ± 0.198786          >> Test (Noise) macro:0.269742 ± 0.021058 | micro:0.248539 ± 0.001550
# Epoch 77/1000 | Train(sampled) L1:15.728268 L2:0.288421 L4:0.085250 |
#           >> Test macro:5.182327 ± 4.204564 | micro:0.953950 ± 0.174538          >> Test (Noise) macro:0.244152 ± 0.004610 | micro:0.239501 ± 0.001571
# Epoch 78/1000 | Train(sampled) L1:15.211418 L2:0.285555 L4:0.084108 |
#           >> Test macro:2.514153 ± 1.673124 | micro:0.812458 ± 0.133297          >> Test (Noise) macro:0.241865 ± 0.001217 | micro:0.240809 ± 0.002033
# Epoch 79/1000 | Train(sampled) L1:12.169887 L2:0.286311 L4:0.085774 |
#           >> Test macro:8.001823 ± 7.030138 | micro:0.964474 ± 0.207489          >> Test (Noise) macro:0.256114 ± 0.021077 | micro:0.234885 ± 0.001896
# Epoch 80/1000 | Train(sampled) L1:12.511279 L2:0.276116 L4:0.088364 |
#           >> Test macro:23.089488 ± 22.103399 | micro:1.029596 ± 0.279873          >> Test (Noise) macro:0.257232 ± 0.027186 | micro:0.229763 ± 0.001748
# Epoch 81/1000 | Train(sampled) L1:10.116642 L2:0.271246 L4:0.083003 |
#           >> Test macro:6.838855 ± 5.911539 | micro:0.903194 ± 0.163787          >> Test (Noise) macro:0.255357 ± 0.030842 | micro:0.224271 ± 0.001872
# Epoch 82/1000 | Train(sampled) L1:8.383860 L2:0.263393 L4:0.078200 |
#           >> Test macro:6.250923 ± 5.396953 | micro:0.826925 ± 0.128669          >> Test (Noise) macro:0.234148 ± 0.014221 | micro:0.219636 ± 0.002010
# Epoch 83/1000 | Train(sampled) L1:8.607956 L2:0.257357 L4:0.076285 |
#           >> Test macro:52.131889 ± 50.960265 | micro:1.296255 ± 0.261628          >> Test (Noise) macro:0.312677 ± 0.090986 | micro:0.222018 ± 0.001912
# Epoch 84/1000 | Train(sampled) L1:11.742471 L2:0.261762 L4:0.083756 |
#           >> Test macro:74.144116 ± 73.288628 | micro:1.022691 ± 0.241534          >> Test (Noise) macro:0.220233 ± 0.006170 | micro:0.213953 ± 0.001594
# Epoch 85/1000 | Train(sampled) L1:8.970583 L2:0.265084 L4:0.099575 |
#           >> Test macro:4.224092 ± 3.331602 | micro:0.862365 ± 0.186667          >> Test (Noise) macro:0.264028 ± 0.051982 | micro:0.212123 ± 0.001824
# Epoch 86/1000 | Train(sampled) L1:7.875836 L2:0.243211 L4:0.089702 |
#           >> Test macro:12.953429 ± 12.066645 | micro:0.880128 ± 0.137034          >> Test (Noise) macro:0.231889 ± 0.035602 | micro:0.196740 ± 0.001208
# Epoch 87/1000 | Train(sampled) L1:6.548723 L2:0.238710 L4:0.087323 |
#           >> Test macro:4.710833 ± 3.760047 | micro:0.932778 ± 0.142619          >> Test (Noise) macro:0.267223 ± 0.060064 | micro:0.206964 ± 0.001775
# Epoch 88/1000 | Train(sampled) L1:8.022457 L2:0.236724 L4:0.090928 |
#           >> Test macro:4.912894 ± 3.956064 | micro:0.934867 ± 0.156946          >> Test (Noise) macro:0.232435 ± 0.034889 | micro:0.197501 ± 0.001797
# Epoch 89/1000 | Train(sampled) L1:5.174612 L2:0.231908 L4:0.088548 |
#           >> Test macro:12.194038 ± 11.271107 | micro:0.929775 ± 0.136680          >> Test (Noise) macro:0.202178 ± 0.013563 | micro:0.188618 ± 0.001710
# Epoch 90/1000 | Train(sampled) L1:3.890645 L2:0.229161 L4:0.081619 |
#           >> Test macro:7.513340 ± 6.560696 | micro:0.928122 ± 0.129870          >> Test (Noise) macro:0.209906 ± 0.020216 | micro:0.189744 ± 0.001849
# Epoch 91/1000 | Train(sampled) L1:4.874430 L2:0.237909 L4:0.078378 |
#           >> Test macro:3.701876 ± 2.735427 | micro:0.939026 ± 0.124549          >> Test (Noise) macro:0.188691 ± 0.002061 | micro:0.186584 ± 0.001728
# Epoch 92/1000 | Train(sampled) L1:4.873999 L2:0.221117 L4:0.082075 |
#           >> Test macro:2403.854295 ± 2402.992711 | micro:9.116746 ± 8.899713          >> Test (Noise) macro:0.201543 ± 0.009312 | micro:0.192025 ± 0.001987
# Epoch 93/1000 | Train(sampled) L1:7.955124 L2:0.246169 L4:0.099529 |
#           >> Test macro:3.522231 ± 2.618205 | micro:0.857452 ± 0.089689          >> Test (Noise) macro:0.284510 ± 0.101378 | micro:0.183692 ± 0.002038
# Epoch 94/1000 | Train(sampled) L1:4.262867 L2:0.221154 L4:0.090526 |
#           >> Test macro:4.914056 ± 4.056356 | micro:0.814796 ± 0.066673          >> Test (Noise) macro:0.197683 ± 0.008085 | micro:0.189473 ± 0.001977
# Epoch 95/1000 | Train(sampled) L1:2.593467 L2:0.218959 L4:0.082540 |
#           >> Test macro:9.804972 ± 8.927664 | micro:0.856102 ± 0.077125          >> Test (Noise) macro:0.189500 ± 0.002076 | micro:0.187629 ± 0.002333
# Epoch 96/1000 | Train(sampled) L1:2.307841 L2:0.209451 L4:0.080400 |
#           >> Test macro:2.185498 ± 1.282444 | micro:0.874756 ± 0.139797          >> Test (Noise) macro:0.168197 ± 0.001672 | micro:0.166659 ± 0.001685
# Epoch 97/1000 | Train(sampled) L1:1.994672 L2:0.204274 L4:0.075458 |
#           >> Test macro:10.718186 ± 9.823993 | micro:0.881241 ± 0.093426          >> Test (Noise) macro:0.180495 ± 0.018595 | micro:0.161991 ± 0.001571
# Epoch 98/1000 | Train(sampled) L1:1.949504 L2:0.203942 L4:0.076629 |
#           >> Test macro:4.117987 ± 3.175457 | micro:0.920320 ± 0.156700          >> Test (Noise) macro:0.258848 ± 0.091594 | micro:0.168190 ± 0.002013
# Epoch 99/1000 | Train(sampled) L1:1.815348 L2:0.205226 L4:0.076350 |
#           >> Test macro:79.598519 ± 78.615454 | micro:1.157794 ± 0.280982          >> Test (Noise) macro:0.191585 ± 0.034194 | micro:0.157169 ± 0.001543
# Epoch 100/1000 | Train(sampled) L1:1.852637 L2:0.204560 L4:0.078287 |
#           >> Test macro:31.167648 ± 30.364191 | micro:0.889783 ± 0.140731          >> Test (Noise) macro:0.233203 ± 0.080801 | micro:0.152433 ± 0.001627
# Epoch 101/1000 | Train(sampled) L1:2.799349 L2:0.193407 L4:0.073847 |
#           >> Test macro:44.077245 ± 43.290941 | micro:0.820031 ± 0.148003          >> Test (Noise) macro:0.197854 ± 0.045674 | micro:0.152281 ± 0.001744
# Epoch 102/1000 | Train(sampled) L1:4.520216 L2:0.188845 L4:0.079248 |
#           >> Test macro:6.580563 ± 5.775681 | micro:0.775405 ± 0.068768          >> Test (Noise) macro:0.164585 ± 0.007102 | micro:0.157602 ± 0.001666
# Epoch 103/1000 | Train(sampled) L1:6.517088 L2:0.214376 L4:0.078373 |
#           >> Test macro:109.757943 ± 108.868867 | micro:1.070839 ± 0.283120          >> Test (Noise) macro:0.165004 ± 0.015216 | micro:0.149875 ± 0.001870
# Epoch 104/1000 | Train(sampled) L1:3.466976 L2:0.184503 L4:0.091414 |
#           >> Test macro:4.880300 ± 4.019099 | micro:0.821314 ± 0.093022          >> Test (Noise) macro:0.154547 ± 0.009645 | micro:0.145129 ± 0.001665
# Epoch 105/1000 | Train(sampled) L1:2.306845 L2:0.175215 L4:0.085486 |
#           >> Test macro:4.936527 ± 4.029499 | micro:0.869312 ± 0.096968          >> Test (Noise) macro:0.251002 ± 0.101681 | micro:0.149503 ± 0.002039
# Epoch 106/1000 | Train(sampled) L1:2.733536 L2:0.194516 L4:0.080935 |
#           >> Test macro:14.264957 ± 13.373204 | micro:0.891596 ± 0.116537          >> Test (Noise) macro:0.161033 ± 0.018199 | micro:0.142664 ± 0.002046
# Epoch 107/1000 | Train(sampled) L1:3.605238 L2:0.186150 L4:0.074008 |
#           >> Test macro:48.902665 ± 48.035322 | micro:1.040497 ± 0.288067          >> Test (Noise) macro:0.182766 ± 0.044489 | micro:0.138182 ± 0.001876
# Epoch 108/1000 | Train(sampled) L1:1.671632 L2:0.171596 L4:0.069081 |
#           >> Test macro:2.503571 ± 1.520259 | micro:0.959282 ± 0.226941          >> Test (Noise) macro:0.341561 ± 0.204087 | micro:0.138160 ± 0.001686
# Epoch 109/1000 | Train(sampled) L1:1.605931 L2:0.174038 L4:0.067058 |
#           >> Test macro:4.820231 ± 3.958109 | micro:0.835135 ± 0.100089          >> Test (Noise) macro:0.180865 ± 0.048079 | micro:0.132840 ± 0.001815
# Epoch 110/1000 | Train(sampled) L1:1.599436 L2:0.163258 L4:0.062176 |
#           >> Test macro:17.023086 ± 16.137240 | micro:0.905118 ± 0.104993          >> Test (Noise) macro:0.133074 ± 0.000826 | micro:0.133092 ± 0.002114
# Epoch 111/1000 | Train(sampled) L1:1.588484 L2:0.154806 L4:0.062358 |
#           >> Test macro:1.930174 ± 1.099212 | micro:0.806664 ± 0.136297          >> Test (Noise) macro:0.123950 ± 0.001835 | micro:0.122089 ± 0.001907
# Epoch 112/1000 | Train(sampled) L1:1.807987 L2:0.159907 L4:0.063340 |
#           >> Test macro:2.229490 ± 1.430998 | micro:0.763127 ± 0.056896          >> Test (Noise) macro:0.197127 ± 0.073925 | micro:0.123452 ± 0.001771
# Epoch 113/1000 | Train(sampled) L1:2.185311 L2:0.155168 L4:0.058880 |
#           >> Test macro:310.884622 ± 305.466128 | micro:6.918297 ± 4.451358          >> Test (Noise) macro:0.180265 ± 0.060569 | micro:0.119786 ± 0.002086
# Epoch 114/1000 | Train(sampled) L1:2.677993 L2:0.152904 L4:0.069027 |
#           >> Test macro:11.109062 ± 10.229608 | micro:0.863362 ± 0.148324          >> Test (Noise) macro:0.121831 ± 0.000860 | micro:0.122160 ± 0.001905
# Epoch 115/1000 | Train(sampled) L1:1.658288 L2:0.147082 L4:0.074392 |
#           >> Test macro:33.212730 ± 32.421082 | micro:0.808620 ± 0.126817          >> Test (Noise) macro:0.155568 ± 0.041874 | micro:0.113600 ± 0.001596
# Epoch 116/1000 | Train(sampled) L1:1.559333 L2:0.145704 L4:0.066890 |
#           >> Test macro:1.680496 ± 0.784058 | micro:0.880250 ± 0.174359          >> Test (Noise) macro:0.189485 ± 0.071209 | micro:0.118382 ± 0.001997
# Epoch 117/1000 | Train(sampled) L1:1.536677 L2:0.139115 L4:0.063310 |
#           >> Test macro:2.355695 ± 1.494641 | micro:0.832685 ± 0.096475          >> Test (Noise) macro:0.175196 ± 0.062461 | micro:0.113083 ± 0.001694
# Epoch 118/1000 | Train(sampled) L1:1.546089 L2:0.133802 L4:0.061641 |
#           >> Test macro:2.522397 ± 1.710263 | micro:0.779304 ± 0.097405          >> Test (Noise) macro:0.120387 ± 0.016338 | micro:0.103691 ± 0.001441
# Epoch 119/1000 | Train(sampled) L1:1.575102 L2:0.136009 L4:0.059271 |
#           >> Test macro:4.113611 ± 3.286822 | micro:0.791717 ± 0.082747          >> Test (Noise) macro:0.118426 ± 0.015349 | micro:0.103332 ± 0.001656
# Epoch 120/1000 | Train(sampled) L1:1.569308 L2:0.127193 L4:0.055836 |
#           >> Test macro:2.743328 ± 1.875856 | micro:0.840211 ± 0.162692          >> Test (Noise) macro:0.139591 ± 0.039106 | micro:0.100515 ± 0.001722
# Epoch 121/1000 | Train(sampled) L1:1.501154 L2:0.127247 L4:0.049926 |
#           >> Test macro:1.815285 ± 1.006431 | micro:0.780082 ± 0.103868          >> Test (Noise) macro:0.113784 ± 0.003813 | micro:0.110124 ± 0.001983
# Epoch 122/1000 | Train(sampled) L1:1.469110 L2:0.122841 L4:0.048591 |
#           >> Test macro:3.099837 ± 2.285104 | micro:0.779090 ± 0.060508          >> Test (Noise) macro:0.147991 ± 0.049507 | micro:0.098727 ± 0.001726
# Epoch 123/1000 | Train(sampled) L1:2.464404 L2:0.125366 L4:0.076950 |
#           >> Test macro:7.873213 ± 6.797512 | micro:1.044991 ± 0.050389          >> Test (Noise) macro:0.107440 ± 0.015888 | micro:0.091578 ± 0.001312
# Epoch 124/1000 | Train(sampled) L1:3.029092 L2:0.120890 L4:0.075518 |
#           >> Test macro:4.335905 ± 3.365933 | micro:0.942077 ± 0.140920          >> Test (Noise) macro:0.108391 ± 0.014074 | micro:0.094143 ± 0.001854
# Epoch 125/1000 | Train(sampled) L1:1.866443 L2:0.115732 L4:0.060365 |
#           >> Test macro:1.725962 ± 0.959003 | micro:0.750595 ± 0.065613          >> Test (Noise) macro:0.100706 ± 0.010678 | micro:0.089920 ± 0.001614
# Epoch 126/1000 | Train(sampled) L1:3.005351 L2:0.125607 L4:0.074006 |
#           >> Test macro:43.458073 ± 41.396152 | micro:2.211500 ± 0.195037          >> Test (Noise) macro:0.113189 ± 0.015451 | micro:0.098003 ± 0.001949
# Epoch 127/1000 | Train(sampled) L1:2.602458 L2:0.117351 L4:0.089021 |
#           >> Test macro:2.124007 ± 1.224832 | micro:0.873038 ± 0.121232          >> Test (Noise) macro:0.103416 ± 0.017208 | micro:0.086902 ± 0.001616
# Epoch 128/1000 | Train(sampled) L1:2.265552 L2:0.115140 L4:0.072670 |
#           >> Test macro:13.010877 ± 11.938540 | micro:1.078095 ± 0.075649          >> Test (Noise) macro:0.165681 ± 0.062958 | micro:0.102532 ± 0.001866
# Epoch 129/1000 | Train(sampled) L1:2.949326 L2:0.121786 L4:0.095169 |
#           >> Test macro:25.999647 ± 25.189974 | micro:0.844314 ± 0.079350          >> Test (Noise) macro:0.140533 ± 0.042095 | micro:0.098703 ± 0.001948
# Epoch 130/1000 | Train(sampled) L1:5.024856 L2:0.118701 L4:0.084105 |
#           >> Test macro:132.309416 ± 131.380948 | micro:1.423356 ± 0.388959          >> Test (Noise) macro:0.117918 ± 0.024459 | micro:0.093856 ± 0.002187
# Epoch 131/1000 | Train(sampled) L1:4.690366 L2:0.119322 L4:0.076071 |
#           >> Test macro:51.628630 ± 50.762467 | micro:0.986196 ± 0.171559          >> Test (Noise) macro:0.121639 ± 0.035627 | micro:0.086067 ± 0.001835
# Epoch 132/1000 | Train(sampled) L1:5.496352 L2:0.123208 L4:0.076634 |
#           >> Test macro:116.031243 ± 115.062074 | micro:1.183282 ± 0.338101          >> Test (Noise) macro:0.091363 ± 0.003009 | micro:0.088850 ± 0.001610
# Epoch 133/1000 | Train(sampled) L1:7.224671 L2:0.114043 L4:0.061221 |
#           >> Test macro:113.526486 ± 112.447918 | micro:1.300972 ± 0.353243          >> Test (Noise) macro:0.083744 ± 0.004652 | micro:0.078993 ± 0.001613
# Epoch 134/1000 | Train(sampled) L1:4.614857 L2:0.116935 L4:0.059061 |
#           >> Test macro:64.053215 ± 63.184135 | micro:1.073005 ± 0.242862          >> Test (Noise) macro:0.095758 ± 0.010007 | micro:0.085852 ± 0.001651
# Epoch 135/1000 | Train(sampled) L1:3.305441 L2:0.115252 L4:0.081009 |
#           >> Test macro:11.246537 ± 10.447947 | micro:0.760890 ± 0.064225          >> Test (Noise) macro:0.089203 ± 0.002096 | micro:0.087060 ± 0.001646
# Epoch 136/1000 | Train(sampled) L1:2.513518 L2:0.114513 L4:0.093786 |
#           >> Test macro:18.203733 ± 17.074235 | micro:1.163655 ± 0.219602          >> Test (Noise) macro:0.168614 ± 0.082994 | micro:0.085528 ± 0.001949
# Epoch 137/1000 | Train(sampled) L1:3.521724 L2:0.113963 L4:0.071575 |
#           >> Test macro:17.525840 ± 16.642183 | micro:0.911758 ± 0.081463          >> Test (Noise) macro:0.171808 ± 0.069934 | micro:0.101783 ± 0.001986
# Epoch 138/1000 | Train(sampled) L1:2.237969 L2:0.118478 L4:0.069931 |
#           >> Test macro:1.946982 ± 0.861469 | micro:1.064243 ± 0.231219          >> Test (Noise) macro:0.110772 ± 0.022808 | micro:0.088145 ± 0.001774
# Epoch 139/1000 | Train(sampled) L1:2.227758 L2:0.109772 L4:0.076715 |
#           >> Test macro:2.063322 ± 1.229438 | micro:0.802468 ± 0.069849          >> Test (Noise) macro:0.189361 ± 0.089933 | micro:0.099529 ± 0.001601
# Epoch 140/1000 | Train(sampled) L1:2.146282 L2:0.121371 L4:0.073260 |
#           >> Test macro:5.835502 ± 5.080855 | micro:0.704635 ± 0.031526          >> Test (Noise) macro:0.183819 ± 0.098847 | micro:0.085208 ± 0.001643
# Epoch 141/1000 | Train(sampled) L1:1.926032 L2:0.122514 L4:0.072860 |
#           >> Test macro:4.212625 ± 3.388516 | micro:0.799011 ± 0.163748          >> Test (Noise) macro:0.110306 ± 0.010961 | micro:0.099140 ± 0.002051
# Epoch 142/1000 | Train(sampled) L1:3.069065 L2:0.118331 L4:0.060343 |
#           >> Test macro:11.559866 ± 10.600384 | micro:0.947802 ± 0.157232          >> Test (Noise) macro:0.177646 ± 0.092874 | micro:0.085230 ± 0.001710
# Epoch 143/1000 | Train(sampled) L1:3.168460 L2:0.113692 L4:0.044013 |
#           >> Test macro:6.520106 ± 5.629173 | micro:0.869032 ± 0.103281          >> Test (Noise) macro:0.137791 ± 0.060081 | micro:0.078187 ± 0.002078
# Epoch 144/1000 | Train(sampled) L1:2.277536 L2:0.116278 L4:0.050080 |
#           >> Test macro:6.022854 ± 5.095415 | micro:0.911485 ± 0.131474          >> Test (Noise) macro:0.108715 ± 0.018116 | micro:0.090642 ± 0.001873
# Epoch 145/1000 | Train(sampled) L1:1.981001 L2:0.117456 L4:0.053250 |
#           >> Test macro:4.078407 ± 3.263363 | micro:0.777940 ± 0.101129          >> Test (Noise) macro:0.112328 ± 0.013623 | micro:0.098430 ± 0.001990
# Epoch 146/1000 | Train(sampled) L1:1.739519 L2:0.121019 L4:0.054637 |
#           >> Test macro:2.585481 ± 1.775929 | micro:0.778823 ± 0.082350          >> Test (Noise) macro:0.159949 ± 0.080523 | micro:0.079913 ± 0.001780
# Epoch 147/1000 | Train(sampled) L1:2.039205 L2:0.114930 L4:0.052074 |
#           >> Test macro:1.659556 ± 0.932937 | micro:0.702099 ± 0.033298          >> Test (Noise) macro:0.213412 ± 0.129684 | micro:0.083983 ± 0.001750
# Epoch 148/1000 | Train(sampled) L1:2.465648 L2:0.114092 L4:0.049219 |
#           >> Test macro:5.404679 ± 4.525000 | micro:0.832938 ± 0.087559          >> Test (Noise) macro:0.146605 ± 0.061053 | micro:0.085568 ± 0.001804
# Epoch 149/1000 | Train(sampled) L1:1.724626 L2:0.118146 L4:0.045582 |
#           >> Test macro:65.564123 ± 64.750424 | micro:0.957070 ± 0.233713          >> Test (Noise) macro:0.147621 ± 0.062803 | micro:0.084775 ± 0.001975
# Epoch 150/1000 | Train(sampled) L1:2.185639 L2:0.113227 L4:0.040553 |
#           >> Test macro:4.388450 ± 3.333294 | micro:1.039667 ± 0.189152          >> Test (Noise) macro:0.084697 ± 0.002676 | micro:0.086327 ± 0.001729
# Epoch 151/1000 | Train(sampled) L1:1.758968 L2:0.112631 L4:0.047085 |
#           >> Test macro:1.944150 ± 1.016598 | micro:0.904230 ± 0.144500          >> Test (Noise) macro:0.162706 ± 0.071986 | micro:0.091027 ± 0.001914
# Epoch 152/1000 | Train(sampled) L1:1.730666 L2:0.112499 L4:0.040455 |
#           >> Test macro:1.447513 ± 0.605205 | micro:0.832954 ± 0.135189          >> Test (Noise) macro:0.083116 ± 0.007406 | micro:0.075698 ± 0.001591
# Epoch 153/1000 | Train(sampled) L1:2.149312 L2:0.114498 L4:0.039508 |
#           >> Test macro:26.331442 ± 25.458203 | micro:0.934526 ± 0.149840          >> Test (Noise) macro:0.083516 ± 0.004914 | micro:0.078666 ± 0.001560
# Epoch 154/1000 | Train(sampled) L1:1.995571 L2:0.112784 L4:0.047445 |
#           >> Test macro:27.540405 ± 26.628455 | micro:0.963562 ± 0.182301          >> Test (Noise) macro:0.109896 ± 0.015908 | micro:0.094116 ± 0.002159
# Epoch 155/1000 | Train(sampled) L1:1.834311 L2:0.116517 L4:0.039947 |
#           >> Test macro:4.046231 ± 3.210016 | micro:0.806331 ± 0.115310          >> Test (Noise) macro:0.075307 ± 0.002530 | micro:0.072995 ± 0.001666
# Epoch 156/1000 | Train(sampled) L1:2.068088 L2:0.114688 L4:0.033250 |
#           >> Test macro:7.860953 ± 6.853595 | micro:0.979453 ± 0.144975          >> Test (Noise) macro:0.186879 ± 0.090428 | micro:0.096374 ± 0.002199
# Epoch 157/1000 | Train(sampled) L1:1.955809 L2:0.117308 L4:0.037749 |
#           >> Test macro:48.855071 ± 48.041140 | micro:0.989386 ± 0.215898          >> Test (Noise) macro:0.095117 ± 0.022089 | micro:0.072944 ± 0.001523
# Epoch 158/1000 | Train(sampled) L1:1.492167 L2:0.106322 L4:0.030778 |
#           >> Test macro:2.843537 ± 2.023402 | micro:0.788428 ± 0.078551          >> Test (Noise) macro:0.090104 ± 0.014487 | micro:0.075677 ± 0.001633
# Epoch 159/1000 | Train(sampled) L1:1.718292 L2:0.111417 L4:0.029376 |
#           >> Test macro:6.760474 ± 5.928788 | micro:0.802176 ± 0.073186          >> Test (Noise) macro:0.140864 ± 0.063309 | micro:0.077517 ± 0.001723
# Epoch 160/1000 | Train(sampled) L1:1.561831 L2:0.110929 L4:0.030593 |
#           >> Test macro:1.716453 ± 0.886549 | micro:0.806239 ± 0.148357          >> Test (Noise) macro:0.081685 ± 0.006488 | micro:0.075116 ± 0.001900
# Epoch 161/1000 | Train(sampled) L1:1.502343 L2:0.113811 L4:0.028461 |
#           >> Test macro:2.129185 ± 0.716374 | micro:1.448265 ± 0.293972          >> Test (Noise) macro:0.140223 ± 0.034786 | micro:0.104903 ± 0.002146
# Epoch 162/1000 | Train(sampled) L1:1.502481 L2:0.113398 L4:0.024851 |
#           >> Test macro:4.536608 ± 3.693789 | micro:0.813719 ± 0.132903          >> Test (Noise) macro:0.077047 ± 0.001312 | micro:0.075743 ± 0.001649
# Epoch 163/1000 | Train(sampled) L1:1.932364 L2:0.112289 L4:0.029809 |
#           >> Test macro:1.498251 ± 0.635705 | micro:0.849563 ± 0.141614          >> Test (Noise) macro:0.093783 ± 0.009465 | micro:0.084146 ± 0.001827
# Epoch 164/1000 | Train(sampled) L1:1.641473 L2:0.115615 L4:0.027218 |
#           >> Test macro:3.359517 ± 2.482064 | micro:0.843360 ± 0.132569          >> Test (Noise) macro:0.155908 ± 0.060738 | micro:0.095367 ± 0.001738
# Epoch 165/1000 | Train(sampled) L1:1.497008 L2:0.111621 L4:0.025411 |
#           >> Test macro:28.750011 ± 28.025008 | micro:0.787221 ± 0.111227          >> Test (Noise) macro:0.100524 ± 0.032613 | micro:0.067632 ± 0.001654
# Epoch 166/1000 | Train(sampled) L1:1.556025 L2:0.111288 L4:0.026241 |
#           >> Test macro:7.142573 ± 6.429505 | micro:0.679489 ± 0.062384          >> Test (Noise) macro:0.098439 ± 0.013983 | micro:0.084308 ± 0.001926
# Epoch 167/1000 | Train(sampled) L1:1.686468 L2:0.113816 L4:0.020119 |
#           >> Test macro:2.476876 ± 1.635688 | micro:0.806688 ± 0.072960          >> Test (Noise) macro:0.100568 ± 0.033675 | micro:0.066865 ± 0.001177
# Epoch 168/1000 | Train(sampled) L1:1.512255 L2:0.110009 L4:0.019807 |
#           >> Test macro:2.671579 ± 1.679281 | micro:0.972292 ± 0.202853          >> Test (Noise) macro:0.175636 ± 0.101418 | micro:0.074382 ± 0.001763
# Epoch 169/1000 | Train(sampled) L1:1.604136 L2:0.113325 L4:0.020350 |
#           >> Test macro:3.755856 ± 2.848846 | micro:0.869267 ± 0.091303          >> Test (Noise) macro:0.107358 ± 0.022584 | micro:0.084829 ± 0.001947
# Epoch 170/1000 | Train(sampled) L1:1.495332 L2:0.111569 L4:0.019881 |
#           >> Test macro:2.944090 ± 2.139692 | micro:0.773327 ± 0.139358          >> Test (Noise) macro:0.093872 ± 0.021738 | micro:0.072183 ± 0.001773
# Epoch 171/1000 | Train(sampled) L1:1.498212 L2:0.111233 L4:0.022477 |
#           >> Test macro:1.676658 ± 0.874361 | micro:0.782432 ± 0.064662          >> Test (Noise) macro:0.186881 ± 0.104850 | micro:0.082581 ± 0.001252
# Epoch 172/1000 | Train(sampled) L1:1.483264 L2:0.112480 L4:0.025562 |
#           >> Test macro:1.413710 ± 0.677154 | micro:0.724786 ± 0.086322          >> Test (Noise) macro:0.145747 ± 0.072567 | micro:0.073681 ± 0.001663
# Epoch 173/1000 | Train(sampled) L1:1.529091 L2:0.112677 L4:0.026447 |
#           >> Test macro:3.097967 ± 2.297241 | micro:0.763789 ± 0.087542          >> Test (Noise) macro:0.147970 ± 0.064860 | micro:0.083340 ± 0.001628
# Epoch 174/1000 | Train(sampled) L1:1.439899 L2:0.108411 L4:0.022768 |
#           >> Test macro:52.801526 ± 52.131562 | micro:0.817099 ± 0.236960          >> Test (Noise) macro:0.170932 ± 0.102139 | micro:0.069034 ± 0.001560
# Epoch 175/1000 | Train(sampled) L1:2.226933 L2:0.114441 L4:0.020179 |
#           >> Test macro:3.162591 ± 2.342397 | micro:0.791288 ± 0.106784          >> Test (Noise) macro:0.169802 ± 0.091980 | micro:0.078488 ± 0.001935
# Epoch 176/1000 | Train(sampled) L1:1.580145 L2:0.110862 L4:0.015945 |
#           >> Test macro:11.478351 ± 10.679371 | micro:0.800045 ± 0.081247          >> Test (Noise) macro:0.075151 ± 0.001071 | micro:0.075629 ± 0.001654
# Epoch 177/1000 | Train(sampled) L1:1.382220 L2:0.109072 L4:0.016016 |
#           >> Test macro:3.264931 ± 2.279147 | micro:0.971403 ± 0.167781          >> Test (Noise) macro:0.078869 ± 0.001591 | micro:0.078016 ± 0.001536
# Epoch 178/1000 | Train(sampled) L1:1.408910 L2:0.110368 L4:0.014511 |
#           >> Test macro:1.794835 ± 0.954076 | micro:0.814229 ± 0.146662          >> Test (Noise) macro:0.098506 ± 0.029362 | micro:0.069408 ± 0.001336
# Epoch 179/1000 | Train(sampled) L1:1.399850 L2:0.103873 L4:0.012542 |
#           >> Test macro:1.696140 ± 0.917925 | micro:0.764678 ± 0.129752          >> Test (Noise) macro:0.171926 ± 0.069368 | micro:0.102164 ± 0.002257
# Epoch 180/1000 | Train(sampled) L1:1.510978 L2:0.110288 L4:0.013761 |
#           >> Test macro:1.666340 ± 0.896043 | micro:0.747099 ± 0.145142          >> Test (Noise) macro:0.084994 ± 0.014718 | micro:0.070137 ± 0.001605
# Epoch 181/1000 | Train(sampled) L1:1.368247 L2:0.110358 L4:0.012859 |
#           >> Test macro:59.759632 ± 58.932368 | micro:1.066933 ± 0.284393          >> Test (Noise) macro:0.097644 ± 0.014183 | micro:0.083396 ± 0.001698
# Epoch 182/1000 | Train(sampled) L1:1.395463 L2:0.109212 L4:0.011768 |
#           >> Test macro:3.143447 ± 2.394876 | micro:0.717215 ± 0.075889          >> Test (Noise) macro:0.095701 ± 0.007819 | micro:0.087741 ± 0.001742
# Epoch 183/1000 | Train(sampled) L1:1.409115 L2:0.112909 L4:0.014959 |
#           >> Test macro:2.321114 ± 1.604163 | micro:0.674134 ± 0.036673          >> Test (Noise) macro:0.151925 ± 0.082914 | micro:0.069395 ± 0.001870
# Epoch 184/1000 | Train(sampled) L1:1.426175 L2:0.111081 L4:0.019722 |
#           >> Test macro:51.394832 ± 50.575703 | micro:0.924549 ± 0.257035          >> Test (Noise) macro:0.083004 ± 0.004717 | micro:0.078240 ± 0.001982
# Epoch 185/1000 | Train(sampled) L1:1.380346 L2:0.107868 L4:0.020347 |
#           >> Test macro:16.896461 ± 16.192731 | micro:0.698164 ± 0.077144          >> Test (Noise) macro:0.154984 ± 0.088463 | micro:0.066649 ± 0.001365
# Epoch 186/1000 | Train(sampled) L1:1.350996 L2:0.102498 L4:0.016982 |
#           >> Test macro:12.453276 ± 11.741170 | micro:0.711700 ± 0.065141          >> Test (Noise) macro:0.084705 ± 0.006789 | micro:0.077771 ± 0.001735
# Epoch 187/1000 | Train(sampled) L1:1.445288 L2:0.112460 L4:0.012241 |
#           >> Test macro:2.275462 ± 1.444616 | micro:0.800846 ± 0.151494          >> Test (Noise) macro:0.079569 ± 0.007911 | micro:0.071522 ± 0.001762
# Epoch 188/1000 | Train(sampled) L1:1.388286 L2:0.106898 L4:0.017723 |
#           >> Test macro:1.639710 ± 0.906209 | micro:0.709063 ± 0.082190          >> Test (Noise) macro:0.120763 ± 0.041094 | micro:0.079357 ± 0.001720
# Epoch 189/1000 | Train(sampled) L1:1.350621 L2:0.114324 L4:0.014894 |
#           >> Test macro:1.542459 ± 0.673124 | micro:0.851945 ± 0.154850          >> Test (Noise) macro:0.155456 ± 0.072236 | micro:0.083312 ± 0.001912
# Epoch 190/1000 | Train(sampled) L1:1.366067 L2:0.107577 L4:0.012970 |
#           >> Test macro:1.494009 ± 0.827974 | micro:0.643992 ± 0.046191          >> Test (Noise) macro:0.202179 ± 0.124058 | micro:0.079029 ± 0.001665
# Epoch 191/1000 | Train(sampled) L1:1.303648 L2:0.110684 L4:0.013818 |
#           >> Test macro:54.804732 ± 54.013102 | micro:0.954803 ± 0.218597          >> Test (Noise) macro:0.099824 ± 0.034266 | micro:0.065468 ± 0.001670
# Epoch 192/1000 | Train(sampled) L1:1.321796 L2:0.108665 L4:0.012945 |
#           >> Test macro:3.805795 ± 3.104385 | micro:0.656109 ± 0.038785          >> Test (Noise) macro:0.167826 ± 0.086944 | micro:0.081140 ± 0.001961
# Epoch 193/1000 | Train(sampled) L1:1.305836 L2:0.101962 L4:0.010840 |
#           >> Test macro:2.055319 ± 1.303590 | micro:0.725706 ± 0.085154          >> Test (Noise) macro:0.107272 ± 0.014957 | micro:0.092154 ± 0.001529
# Epoch 194/1000 | Train(sampled) L1:1.413640 L2:0.109499 L4:0.010098 |
#           >> Test macro:2.057916 ± 1.348917 | micro:0.677621 ± 0.061019          >> Test (Noise) macro:0.081995 ± 0.001496 | micro:0.080975 ± 0.001555
# Epoch 195/1000 | Train(sampled) L1:1.565624 L2:0.106039 L4:0.014860 |
#           >> Test macro:0.965379 ± 0.363148 | micro:0.637445 ± 0.039933          >> Test (Noise) macro:0.115490 ± 0.025488 | micro:0.089676 ± 0.002131
# Epoch 196/1000 | Train(sampled) L1:1.359741 L2:0.105760 L4:0.013555 |
#           >> Test macro:7.153926 ± 6.480691 | micro:0.639196 ± 0.047248          >> Test (Noise) macro:0.100659 ± 0.018702 | micro:0.081981 ± 0.001647
# Epoch 197/1000 | Train(sampled) L1:1.325084 L2:0.107727 L4:0.010449 |
#           >> Test macro:5.976247 ± 5.333454 | micro:0.606275 ± 0.034432          >> Test (Noise) macro:0.063927 ± 0.000680 | micro:0.063495 ± 0.001367
# Epoch 198/1000 | Train(sampled) L1:1.358074 L2:0.102477 L4:0.009437 |
#           >> Test macro:3.526837 ± 2.820455 | micro:0.668002 ± 0.068314          >> Test (Noise) macro:0.151562 ± 0.084699 | micro:0.067256 ± 0.001541
# Epoch 199/1000 | Train(sampled) L1:1.262698 L2:0.108342 L4:0.009654 |
#           >> Test macro:1.837280 ± 1.154257 | micro:0.657569 ± 0.089635          >> Test (Noise) macro:0.074793 ± 0.004719 | micro:0.070062 ± 0.001322
# Epoch 200/1000 | Train(sampled) L1:1.243360 L2:0.104265 L4:0.009926 |
#           >> Test macro:1.101806 ± 0.474455 | micro:0.620112 ± 0.066053          >> Test (Noise) macro:0.215911 ± 0.129883 | micro:0.086860 ± 0.001972
# Epoch 201/1000 | Train(sampled) L1:1.320196 L2:0.108230 L4:0.009279 |
#           >> Test macro:3.907970 ± 3.188518 | micro:0.703082 ± 0.101914          >> Test (Noise) macro:0.103085 ± 0.020458 | micro:0.082319 ± 0.002434
# Epoch 202/1000 | Train(sampled) L1:1.472553 L2:0.108637 L4:0.009367 |
#           >> Test macro:9.421861 ± 8.784300 | micro:0.625420 ± 0.058788          >> Test (Noise) macro:0.111502 ± 0.041630 | micro:0.070070 ± 0.001478
# Epoch 203/1000 | Train(sampled) L1:1.241912 L2:0.100878 L4:0.007132 |
#           >> Test macro:27.906144 ± 27.275415 | micro:0.679360 ± 0.121077          >> Test (Noise) macro:0.094816 ± 0.028868 | micro:0.065822 ± 0.001508
# Epoch 204/1000 | Train(sampled) L1:1.294066 L2:0.098968 L4:0.009355 |
#           >> Test macro:3.047193 ± 2.413665 | micro:0.602081 ± 0.057838          >> Test (Noise) macro:0.146556 ± 0.082990 | micro:0.064278 ± 0.001607
# Epoch 205/1000 | Train(sampled) L1:1.229279 L2:0.106758 L4:0.008727 |
#           >> Test macro:14.715402 ± 14.146975 | micro:0.554169 ± 0.046107          >> Test (Noise) macro:0.066412 ± 0.001851 | micro:0.064570 ± 0.001485
# Epoch 206/1000 | Train(sampled) L1:1.238316 L2:0.103903 L4:0.008353 |
#           >> Test macro:3.233826 ± 2.606212 | micro:0.603328 ± 0.044875          >> Test (Noise) macro:0.128353 ± 0.047603 | micro:0.080788 ± 0.001250
# Epoch 207/1000 | Train(sampled) L1:1.270465 L2:0.105613 L4:0.009492 |
#           >> Test macro:1.767519 ± 1.160198 | micro:0.581621 ± 0.044572          >> Test (Noise) macro:0.079834 ± 0.007217 | micro:0.072460 ± 0.001663
# Epoch 208/1000 | Train(sampled) L1:1.316701 L2:0.101501 L4:0.009195 |
#           >> Test macro:4.026441 ± 3.430861 | micro:0.569378 ± 0.030393          >> Test (Noise) macro:0.172365 ± 0.101370 | micro:0.071049 ± 0.001810
# Epoch 209/1000 | Train(sampled) L1:1.173679 L2:0.098763 L4:0.007644 |
#           >> Test macro:1.155225 ± 0.592875 | micro:0.550475 ± 0.057052          >> Test (Noise) macro:0.189588 ± 0.115140 | micro:0.074603 ± 0.001660
# Epoch 210/1000 | Train(sampled) L1:1.180958 L2:0.105993 L4:0.005714 |
#           >> Test macro:1.867535 ± 1.317920 | micro:0.522426 ± 0.023622          >> Test (Noise) macro:0.117675 ± 0.046345 | micro:0.071115 ± 0.001557
# Epoch 211/1000 | Train(sampled) L1:1.119812 L2:0.105073 L4:0.006816 |
#           >> Test macro:1.018796 ± 0.430625 | micro:0.583455 ± 0.053994          >> Test (Noise) macro:0.076143 ± 0.005816 | micro:0.070417 ± 0.001774
# Epoch 212/1000 | Train(sampled) L1:1.130584 L2:0.100631 L4:0.006787 |
#           >> Test macro:1.331992 ± 0.753004 | micro:0.557572 ± 0.058417          >> Test (Noise) macro:0.093453 ± 0.022819 | micro:0.070749 ± 0.001411
# Epoch 213/1000 | Train(sampled) L1:1.150186 L2:0.102154 L4:0.007463 |
#           >> Test macro:7.529561 ± 6.839471 | micro:0.686759 ± 0.134830          >> Test (Noise) macro:0.076447 ± 0.007895 | micro:0.068374 ± 0.001447
# Epoch 214/1000 | Train(sampled) L1:1.116441 L2:0.095415 L4:0.008480 |
#           >> Test macro:2.789661 ± 2.249545 | micro:0.512253 ± 0.024342          >> Test (Noise) macro:0.187570 ± 0.124182 | micro:0.063689 ± 0.001668
# Epoch 215/1000 | Train(sampled) L1:1.121244 L2:0.100878 L4:0.006559 |
# ...
#           >> Test macro:2.254532 ± 2.016788 | micro:0.225592 ± 0.013752          >> Test (Noise) macro:0.060995 ± 0.030605 | micro:0.030269 ± 0.000944
# Epoch 553/1000 | Train(sampled) L1:0.569084 L2:0.032370 L4:0.000374 |
#           >> Test macro:5.174779 ± 4.934983 | micro:0.227803 ± 0.031178          >> Test (Noise) macro:0.031646 ± 0.000440 | micro:0.031394 ± 0.000708
# Epoch 554/1000 | Train(sampled) L1:0.565705 L2:0.032131 L4:0.000352 |
#           >> Test macro:1.270010 ± 1.035395 | micro:0.220868 ± 0.011961          >> Test (Noise) macro:0.026988 ± 0.000500 | micro:0.027075 ± 0.000624
# Epoch 555/1000 | Train(sampled) L1:0.580509 L2:0.031256 L4:0.000359 |
#           >> Test macro:2.632107 ± 2.377586 | micro:0.242715 ± 0.015474          >> Test (Noise) macro:0.028668 ± 0.000682 | micro:0.029048 ± 0.000727
# Epoch 556/1000 | Train(sampled) L1:0.568702 L2:0.036260 L4:0.000419 |
#           >> Test macro:8.161521 ± 7.909502 | micro:0.257189 ± 0.033433          >> Test (Noise) macro:0.028456 ± 0.002591 | micro:0.030677 ± 0.000979
# Epoch 557/1000 | Train(sampled) L1:0.575989 L2:0.034645 L4:0.000408 |
#           >> Test macro:0.636986 ± 0.386680 | micro:0.239547 ± 0.016168          >> Test (Noise) macro:0.044152 ± 0.011793 | micro:0.032213 ± 0.000730
# Epoch 558/1000 | Train(sampled) L1:0.566145 L2:0.035113 L4:0.000293 |
#           >> Test macro:8.786378 ± 8.534463 | micro:0.261528 ± 0.040498          >> Test (Noise) macro:0.030412 ± 0.002053 | micro:0.032427 ± 0.000925
# Epoch 559/1000 | Train(sampled) L1:0.570355 L2:0.033072 L4:0.000383 |
#           >> Test macro:3.407833 ± 3.134029 | micro:0.257584 ± 0.022123          >> Test (Noise) macro:0.034741 ± 0.004942 | micro:0.029693 ± 0.000881
# Epoch 560/1000 | Train(sampled) L1:0.581383 L2:0.031425 L4:0.000378 |
#           >> Test macro:7.586462 ± 7.342194 | micro:0.257322 ± 0.039080          >> Test (Noise) macro:0.028052 ± 0.001424 | micro:0.026597 ± 0.000520
# Epoch 561/1000 | Train(sampled) L1:0.568616 L2:0.031952 L4:0.000323 |
#           >> Test macro:3.790040 ± 3.545032 | micro:0.234938 ± 0.017714          >> Test (Noise) macro:0.033112 ± 0.001936 | micro:0.032096 ± 0.000926
# Epoch 562/1000 | Train(sampled) L1:0.562633 L2:0.030999 L4:0.000289 |
#           >> Test macro:0.432278 ± 0.206043 | micro:0.226882 ± 0.013401          >> Test (Noise) macro:0.036035 ± 0.005970 | micro:0.029966 ± 0.000771
# Epoch 563/1000 | Train(sampled) L1:0.567799 L2:0.031649 L4:0.000320 |
#           >> Test macro:7.795013 ± 7.547173 | micro:0.249873 ± 0.036112          >> Test (Noise) macro:0.027680 ± 0.001371 | micro:0.026842 ± 0.000758
# Epoch 564/1000 | Train(sampled) L1:0.571670 L2:0.033045 L4:0.000280 |
#           >> Test macro:3.530329 ± 3.272820 | micro:0.252491 ± 0.023658          >> Test (Noise) macro:0.030112 ± 0.000916 | micro:0.030401 ± 0.000831
# Epoch 565/1000 | Train(sampled) L1:0.569080 L2:0.031586 L4:0.000415 |
#           >> Test macro:3.870008 ± 3.648709 | micro:0.215421 ± 0.018324          >> Test (Noise) macro:0.035892 ± 0.007503 | micro:0.028329 ± 0.000807
# Epoch 566/1000 | Train(sampled) L1:0.553030 L2:0.030997 L4:0.000244 |
#           >> Test macro:2.428185 ± 2.188802 | micro:0.226679 ± 0.015393          >> Test (Noise) macro:0.028598 ± 0.001287 | micro:0.028788 ± 0.000827
# Epoch 567/1000 | Train(sampled) L1:0.564980 L2:0.034395 L4:0.000230 |
#           >> Test macro:5.289313 ± 5.057595 | micro:0.225069 ± 0.018985          >> Test (Noise) macro:0.035138 ± 0.005647 | micro:0.029382 ± 0.000784
# Epoch 568/1000 | Train(sampled) L1:0.561804 L2:0.033515 L4:0.000325 |
#           >> Test macro:16.758552 ± 16.525264 | micro:0.249267 ± 0.061787          >> Test (Noise) macro:0.033462 ± 0.004445 | micro:0.028926 ± 0.000845
# Epoch 569/1000 | Train(sampled) L1:0.569553 L2:0.033370 L4:0.000383 |
#           >> Test macro:3.360155 ± 3.127627 | micro:0.220866 ± 0.021488          >> Test (Noise) macro:0.029117 ± 0.000511 | micro:0.029624 ± 0.000545
# Epoch 570/1000 | Train(sampled) L1:0.567388 L2:0.032335 L4:0.000304 |
#           >> Test macro:9.204301 ± 8.983053 | micro:0.242932 ± 0.044585          >> Test (Noise) macro:0.030574 ± 0.000805 | micro:0.029973 ± 0.000872
# Epoch 571/1000 | Train(sampled) L1:0.579367 L2:0.031580 L4:0.000347 |
#           >> Test macro:1.351097 ± 1.120796 | micro:0.214967 ± 0.013981          >> Test (Noise) macro:0.027652 ± 0.001940 | micro:0.028720 ± 0.000769
# Epoch 572/1000 | Train(sampled) L1:0.560843 L2:0.032328 L4:0.000405 |
#           >> Test macro:20.301466 ± 20.064299 | micro:0.296376 ± 0.094805          >> Test (Noise) macro:0.031211 ± 0.000791 | micro:0.031495 ± 0.001007
# Epoch 573/1000 | Train(sampled) L1:0.556507 L2:0.031255 L4:0.000312 |
#           >> Test macro:1.284225 ± 1.046596 | micro:0.223960 ± 0.012642          >> Test (Noise) macro:0.029493 ± 0.001616 | micro:0.029636 ± 0.000969
# Epoch 574/1000 | Train(sampled) L1:0.576666 L2:0.031874 L4:0.000337 |
#           >> Test macro:3.659929 ± 3.432418 | micro:0.218765 ± 0.015711          >> Test (Noise) macro:0.038770 ± 0.009066 | micro:0.029603 ± 0.000685
# Epoch 575/1000 | Train(sampled) L1:0.566683 L2:0.032574 L4:0.000312 |
#           >> Test macro:4.573527 ± 4.310420 | micro:0.253452 ± 0.022737          >> Test (Noise) macro:0.026625 ± 0.001114 | micro:0.027695 ± 0.000608
# Epoch 576/1000 | Train(sampled) L1:0.560109 L2:0.033706 L4:0.000350 |
#           >> Test macro:1.921226 ± 1.656745 | micro:0.251897 ± 0.025243          >> Test (Noise) macro:0.031919 ± 0.001589 | micro:0.032929 ± 0.000955
# Epoch 577/1000 | Train(sampled) L1:0.563054 L2:0.032182 L4:0.000346 |
#           >> Test macro:6.087287 ± 5.840297 | micro:0.245126 ± 0.022436          >> Test (Noise) macro:0.028854 ± 0.001270 | micro:0.029251 ± 0.000688
# Epoch 578/1000 | Train(sampled) L1:0.559198 L2:0.031810 L4:0.000307 |
#           >> Test macro:0.917396 ± 0.662031 | micro:0.243040 ± 0.019904          >> Test (Noise) macro:0.026307 ± 0.001761 | micro:0.027908 ± 0.000635
# Epoch 579/1000 | Train(sampled) L1:0.569872 L2:0.030533 L4:0.000317 |
#           >> Test macro:7.713188 ± 7.490370 | micro:0.232828 ± 0.028659          >> Test (Noise) macro:0.025672 ± 0.001031 | micro:0.026561 ± 0.000774
# Epoch 580/1000 | Train(sampled) L1:0.546256 L2:0.031276 L4:0.000346 |
#           >> Test macro:10.736498 ± 10.516128 | micro:0.224137 ± 0.031222          >> Test (Noise) macro:0.038165 ± 0.009798 | micro:0.028248 ± 0.000878
# Epoch 581/1000 | Train(sampled) L1:0.572110 L2:0.030521 L4:0.000317 |
#           >> Test macro:9.363831 ± 9.141566 | micro:0.239261 ± 0.039445          >> Test (Noise) macro:0.024740 ± 0.001331 | micro:0.025699 ± 0.000547
# Epoch 582/1000 | Train(sampled) L1:0.556340 L2:0.031022 L4:0.000267 |
#           >> Test macro:3.569047 ± 3.312976 | micro:0.243787 ± 0.022106          >> Test (Noise) macro:0.045486 ± 0.011712 | micro:0.033643 ± 0.000869
# Epoch 583/1000 | Train(sampled) L1:0.566679 L2:0.034190 L4:0.000293 |
#           >> Test macro:7.883597 ± 7.650706 | micro:0.236726 ± 0.029198          >> Test (Noise) macro:0.028413 ± 0.001051 | micro:0.029042 ± 0.000761
# Epoch 584/1000 | Train(sampled) L1:0.560405 L2:0.032421 L4:0.000353 |
#           >> Test macro:9.884299 ± 9.650680 | micro:0.258015 ± 0.046213          >> Test (Noise) macro:0.028814 ± 0.000952 | micro:0.029003 ± 0.000646
# Epoch 585/1000 | Train(sampled) L1:0.561300 L2:0.031377 L4:0.000250 |
#           >> Test macro:6.053390 ± 5.828815 | micro:0.223539 ± 0.028037          >> Test (Noise) macro:0.047727 ± 0.019445 | micro:0.028280 ± 0.000753
# Epoch 586/1000 | Train(sampled) L1:0.552465 L2:0.032227 L4:0.000296 |
#           >> Test macro:2.081259 ± 1.837655 | micro:0.230751 ± 0.013333          >> Test (Noise) macro:0.029501 ± 0.000777 | micro:0.028950 ± 0.000755
# Epoch 587/1000 | Train(sampled) L1:0.563092 L2:0.029895 L4:0.000335 |
#           >> Test macro:6.408011 ± 6.167004 | micro:0.239398 ± 0.033612          >> Test (Noise) macro:0.033491 ± 0.003518 | micro:0.029922 ± 0.000955
# Epoch 588/1000 | Train(sampled) L1:0.567456 L2:0.031314 L4:0.000295 |
#           >> Test macro:3.531746 ± 3.284979 | micro:0.236551 ± 0.020043          >> Test (Noise) macro:0.106117 ± 0.078815 | micro:0.027649 ± 0.000594
# Epoch 589/1000 | Train(sampled) L1:0.574285 L2:0.035660 L4:0.000377 |
#           >> Test macro:8.569231 ± 8.342029 | micro:0.235221 ± 0.030323          >> Test (Noise) macro:0.098345 ± 0.068153 | micro:0.030272 ± 0.000796
# Epoch 590/1000 | Train(sampled) L1:0.555600 L2:0.030883 L4:0.000279 |
#           >> Test macro:8.766197 ± 8.520356 | micro:0.255765 ± 0.035035          >> Test (Noise) macro:0.025620 ± 0.000703 | micro:0.025964 ± 0.000580
# Epoch 591/1000 | Train(sampled) L1:0.564028 L2:0.030173 L4:0.000280 |
#           >> Test macro:8.608129 ± 8.359863 | micro:0.249108 ± 0.029091          >> Test (Noise) macro:0.032528 ± 0.002125 | micro:0.030600 ± 0.001066
# Epoch 592/1000 | Train(sampled) L1:0.562276 L2:0.031540 L4:0.000307 |
#           >> Test macro:1.332793 ± 1.080784 | micro:0.234351 ± 0.014681          >> Test (Noise) macro:0.031258 ± 0.003594 | micro:0.027605 ± 0.000625
# Epoch 593/1000 | Train(sampled) L1:0.556871 L2:0.031940 L4:0.000301 |
#           >> Test macro:7.012242 ± 6.786146 | micro:0.234760 ± 0.032854          >> Test (Noise) macro:0.029839 ± 0.002679 | micro:0.032251 ± 0.000971
# Epoch 594/1000 | Train(sampled) L1:0.580625 L2:0.033010 L4:0.000353 |
#           >> Test macro:9.951640 ± 9.728868 | micro:0.228734 ± 0.039847          >> Test (Noise) macro:0.030472 ± 0.000975 | micro:0.030682 ± 0.000884
# Epoch 595/1000 | Train(sampled) L1:0.565526 L2:0.032123 L4:0.000363 |
#           >> Test macro:10.044078 ± 9.803427 | micro:0.240912 ± 0.034092          >> Test (Noise) macro:0.030163 ± 0.000479 | micro:0.030324 ± 0.000985
# Epoch 596/1000 | Train(sampled) L1:0.560805 L2:0.030469 L4:0.000311 |
#           >> Test macro:2.718846 ± 2.484555 | micro:0.223026 ± 0.017805          >> Test (Noise) macro:0.026129 ± 0.000927 | micro:0.025384 ± 0.000510
# Epoch 597/1000 | Train(sampled) L1:0.570208 L2:0.029491 L4:0.000322 |
#           >> Test macro:5.267523 ± 5.034174 | micro:0.235639 ± 0.024265          >> Test (Noise) macro:0.026434 ± 0.001887 | micro:0.027587 ± 0.000810
# Epoch 598/1000 | Train(sampled) L1:0.560435 L2:0.029583 L4:0.000267 |
#           >> Test macro:0.579515 ± 0.334887 | micro:0.237785 ± 0.029524          >> Test (Noise) macro:0.025490 ± 0.000899 | micro:0.025717 ± 0.000522
# Epoch 599/1000 | Train(sampled) L1:0.563655 L2:0.030068 L4:0.000317 |
#           >> Test macro:1.990200 ± 1.759330 | micro:0.216051 ± 0.012329          >> Test (Noise) macro:0.034315 ± 0.006809 | micro:0.027516 ± 0.000829
# Epoch 600/1000 | Train(sampled) L1:0.560493 L2:0.030588 L4:0.000440 |
#           >> Test macro:0.399447 ± 0.182725 | micro:0.221782 ± 0.012813          >> Test (Noise) macro:0.028561 ± 0.000907 | micro:0.029468 ± 0.000733
# Epoch 601/1000 | Train(sampled) L1:0.558507 L2:0.030499 L4:0.000295 |
#           >> Test macro:1.758739 ± 1.509909 | micro:0.228894 ± 0.018424          >> Test (Noise) macro:0.025658 ± 0.001325 | micro:0.026936 ± 0.000685
# Epoch 602/1000 | Train(sampled) L1:0.564031 L2:0.029698 L4:0.000273 |
#           >> Test macro:0.607469 ± 0.369759 | micro:0.227726 ± 0.016016          >> Test (Noise) macro:0.026954 ± 0.000674 | micro:0.026385 ± 0.000569
# Epoch 603/1000 | Train(sampled) L1:0.557017 L2:0.029528 L4:0.000327 |
#           >> Test macro:3.956185 ± 3.729992 | micro:0.217901 ± 0.016956          >> Test (Noise) macro:0.029867 ± 0.000688 | micro:0.030317 ± 0.000883
# Epoch 604/1000 | Train(sampled) L1:0.545222 L2:0.029654 L4:0.000366 |
#           >> Test macro:9.754628 ± 9.528244 | micro:0.242917 ± 0.041632          >> Test (Noise) macro:0.024441 ± 0.002036 | micro:0.025768 ± 0.000624
# Epoch 605/1000 | Train(sampled) L1:0.554651 L2:0.029887 L4:0.000248 |
#           >> Test macro:1.814557 ± 1.565090 | micro:0.234940 ± 0.018079          >> Test (Noise) macro:0.040335 ± 0.010979 | micro:0.029181 ± 0.000861
# Epoch 606/1000 | Train(sampled) L1:0.567845 L2:0.029535 L4:0.000292 |
#           >> Test macro:4.334715 ± 4.104730 | micro:0.229526 ± 0.023598          >> Test (Noise) macro:0.026818 ± 0.001434 | micro:0.027448 ± 0.000714
# Epoch 607/1000 | Train(sampled) L1:0.556298 L2:0.029984 L4:0.000320 |
#           >> Test macro:1.622564 ± 1.378528 | micro:0.227780 ± 0.013404          >> Test (Noise) macro:0.029651 ± 0.001108 | micro:0.029344 ± 0.000827
# Epoch 608/1000 | Train(sampled) L1:0.550628 L2:0.031301 L4:0.000288 |
#           >> Test macro:2.587989 ± 2.345551 | micro:0.234010 ± 0.023319          >> Test (Noise) macro:0.027243 ± 0.000689 | micro:0.027679 ± 0.000740
# Epoch 609/1000 | Train(sampled) L1:0.556351 L2:0.030396 L4:0.000360 |
#           >> Test macro:4.072323 ± 3.835962 | micro:0.230305 ± 0.020394          >> Test (Noise) macro:0.036911 ± 0.009616 | micro:0.027129 ± 0.000736
# Epoch 610/1000 | Train(sampled) L1:0.544618 L2:0.029202 L4:0.000320 |
#           >> Test macro:15.246565 ± 14.998307 | micro:0.263704 ± 0.044961          >> Test (Noise) macro:0.028476 ± 0.000811 | micro:0.028001 ± 0.000805
# Epoch 611/1000 | Train(sampled) L1:0.569553 L2:0.033344 L4:0.000263 |
#           >> Test macro:3.393481 ± 3.148678 | micro:0.231750 ± 0.014489          >> Test (Noise) macro:0.044326 ± 0.014025 | micro:0.030190 ± 0.000655
# Epoch 612/1000 | Train(sampled) L1:0.562898 L2:0.030876 L4:0.000323 |
#           >> Test macro:10.726669 ± 10.505039 | micro:0.231443 ± 0.039502          >> Test (Noise) macro:0.028227 ± 0.001270 | micro:0.028538 ± 0.000838
# Epoch 613/1000 | Train(sampled) L1:0.555529 L2:0.029383 L4:0.000282 |
#           >> Test macro:5.646126 ± 5.403353 | micro:0.243259 ± 0.025494          >> Test (Noise) macro:0.085658 ± 0.057577 | micro:0.027983 ± 0.000866
# Epoch 614/1000 | Train(sampled) L1:0.562368 L2:0.029374 L4:0.000248 |
#           >> Test macro:8.178714 ± 7.933362 | micro:0.254369 ± 0.033566          >> Test (Noise) macro:0.033485 ± 0.006447 | micro:0.026952 ± 0.000575
# Epoch 615/1000 | Train(sampled) L1:0.564408 L2:0.031953 L4:0.000247 |
#           >> Test macro:1.937194 ± 1.706365 | micro:0.215424 ± 0.014366          >> Test (Noise) macro:0.098808 ± 0.067106 | micro:0.031629 ± 0.000856
# Epoch 616/1000 | Train(sampled) L1:0.557657 L2:0.030971 L4:0.000299 |
#           >> Test macro:5.536535 ± 5.308053 | micro:0.233109 ± 0.024656          >> Test (Noise) macro:0.029007 ± 0.002752 | micro:0.026197 ± 0.000690
# Epoch 617/1000 | Train(sampled) L1:0.554291 L2:0.029250 L4:0.000278 |
#           >> Test macro:2.006350 ± 1.781589 | micro:0.212055 ± 0.012026          >> Test (Noise) macro:0.026883 ± 0.000789 | micro:0.026682 ± 0.000642
# Epoch 618/1000 | Train(sampled) L1:0.562018 L2:0.031163 L4:0.000309 |
#           >> Test macro:4.363657 ± 4.125702 | micro:0.230578 ± 0.019679          >> Test (Noise) macro:0.028776 ± 0.000651 | micro:0.029397 ± 0.000702
# Epoch 619/1000 | Train(sampled) L1:0.560364 L2:0.029004 L4:0.000308 |
#           >> Test macro:6.585139 ± 6.340825 | micro:0.252875 ± 0.032213          >> Test (Noise) macro:0.033663 ± 0.006187 | micro:0.027583 ± 0.000784
# Epoch 620/1000 | Train(sampled) L1:0.563397 L2:0.028654 L4:0.000322 |
#           >> Test macro:9.972528 ± 9.732455 | micro:0.267214 ± 0.047635          >> Test (Noise) macro:0.027020 ± 0.000592 | micro:0.026722 ± 0.000694
# Epoch 621/1000 | Train(sampled) L1:0.550347 L2:0.028754 L4:0.000366 |
#           >> Test macro:4.785506 ± 4.551969 | micro:0.222247 ± 0.020318          >> Test (Noise) macro:0.031163 ± 0.000458 | micro:0.031373 ± 0.000627
# Epoch 622/1000 | Train(sampled) L1:0.565670 L2:0.030912 L4:0.000329 |
#           >> Test macro:1.359702 ± 1.108708 | micro:0.232205 ± 0.016021          >> Test (Noise) macro:0.026492 ± 0.001560 | micro:0.027773 ± 0.000575
# Epoch 623/1000 | Train(sampled) L1:0.560357 L2:0.028985 L4:0.000322 |
#           >> Test macro:2.238293 ± 1.998476 | micro:0.226744 ± 0.015261          >> Test (Noise) macro:0.030651 ± 0.001576 | micro:0.029071 ± 0.000907
# Epoch 624/1000 | Train(sampled) L1:0.557923 L2:0.028387 L4:0.000300 |

# %% [markdown]
# ### Teste reconstrução com erro gaussiano

# %%
tsdiffusion.lam=[0.45,0.5,0.05]
res_tsdiffusion = tsdiffusion.train_cognite(
    df=df_scaled,
    feature_cols=list(df_scaled.columns[:-1]),
    static_features_cols=None,
    timestamp_col='index',
    states_col='states',
    batch_size=256,
    window_size=30,
    window_step=30,
    epochs = 1,
    validate=False,
    patience=100,
    lr=0,
    lr_t=0
)
res_tsdiffusion = [r for r in res_tsdiffusion if r is not None]  # remove None results
# Out:
# GRUPOS (total): {0: 3886, 1: 15, 5: 5093}
# GRUPOS (train): {0: 3109, 1: 12, 5: 4074}
# GRUPOS (test):  {0: 777, 1: 3, 5: 1019}
# Epoch 1/1 | Train(sampled) L1:0.541400 L2:0.030339 L4:0.000257 |
#           >> Test macro:0.510870 ± 0.279516 | micro:0.226991 ± 0.012244          >> Test (Noise) macro:0.028370 ± 0.001539 | micro:0.026861 ± 0.000581
# TEST RESULTS | macro: 2.596021 ± 2.371470 | micro: 0.212578 ± 0.014041macro (noise): 0.026559 ± 0.000688 | micro (noise): 0.026187 ± 0.000508
#           >> per_group (weighted SE): {0: '0.420741 ± 0.025302 (n=777)', 1: '1.033737 ± 0.689380 (n=3)', 5: '0.078132 ± 0.006473 (n=1019)'}
#           >> per_group (weighted SE): {0: '0.028390 ± 0.001070 (n=777)', 1: '0.031026 ± 0.003395 (n=3)', 5: '0.025694 ± 0.000621 (n=1019)'}

# %% [markdown]
# ### Teste reconstução

# %%
tsdiffusion.lam=[0.45,0.,0.05]
res_tsdiffusion = tsdiffusion.train_cognite(
    df=df_scaled,
    feature_cols=list(df_scaled.columns[:-1]),
    static_features_cols=None,
    timestamp_col='index',
    states_col='states',
    batch_size=256,
    window_size=30,
    window_step=30,
    epochs = 1,
    validate=False,
    patience=100,
    lr=0,
    lr_t=0
)
res_tsdiffusion = [r for r in res_tsdiffusion if r is not None]  # remove None results
# Out:
# GRUPOS (total): {0: 3886, 1: 15, 5: 5093}
# GRUPOS (train): {0: 3109, 1: 12, 5: 4074}
# GRUPOS (test):  {0: 777, 1: 3, 5: 1019}
# Epoch 1/1 | Train(sampled) L1:0.545370 L2:0.280063 L4:0.002866 |
#           >> Test macro:3.531110 ± 3.304723 | micro:0.218348 ± 0.019840          >> Test (Noise) macro:0.214643 ± 0.020998 | micro:0.235588 ± 0.001147
# TEST RESULTS | macro: 8.480589 ± 8.267367 | micro: 0.233033 ± 0.042135macro (noise): 0.220016 ± 0.015032 | micro (noise): 0.235116 ± 0.001137
#           >> per_group (weighted SE): {0: '0.390662 ± 0.031534 (n=777)', 1: '10.137878 ± 7.422426 (n=3)', 5: '0.064790 ± 0.001675 (n=1019)'}
#           >> per_group (weighted SE): {0: '0.235267 ± 0.001673 (n=777)', 1: '0.172648 ± 0.049303 (n=3)', 5: '0.236014 ± 0.001563 (n=1019)'}

# %% [markdown]
# ### Teste predição generativa

# %%
tsdiffusion.lam=[0.45,0.,0.05]
res_tsdiffusion = tsdiffusion.train_cognite(
    df=df_scaled,
    feature_cols=list(df_scaled.columns[:-1]),
    static_features_cols=None,
    timestamp_col='index',
    states_col='states',
    batch_size=256,
    window_size=30,
    window_step=30,
    epochs = 1,
    validate=False,
    patience=100,
    lr=0,
    lr_t=0,
    reconstruction_test=False
)
res_tsdiffusion = [r for r in res_tsdiffusion if r is not None]  # remove None results
# Out:
# GRUPOS (total): {0: 3886, 1: 15, 5: 5093}
# GRUPOS (train): {0: 3109, 1: 12, 5: 4074}
# GRUPOS (test):  {0: 777, 1: 3, 5: 1019}
# Epoch 1/1 | Train(sampled) L1:0.343715 L2:0.305624 L4:0.924123 |
#           >> Test macro:0.146652 ± 0.075361 | micro:0.211751 ± 0.011374          >> Test (Noise) macro:0.155417 ± 0.034511 | micro:0.189856 ± 0.000856
# TEST RESULTS | macro: 0.146652 ± 0.075361 | micro: 0.211751 ± 0.011374macro (noise): 0.155417 ± 0.034511 | micro (noise): 0.189856 ± 0.000856
#           >> per_group (weighted SE): {0: '0.260940 ± 0.023482 (n=777)', 1: '0.004410 ± 0.002079 (n=3)', 5: '0.174605 ± 0.008894 (n=1019)'}
#           >> per_group (weighted SE): {0: '0.189151 ± 0.001394 (n=777)', 1: '0.086402 ± 0.036864 (n=3)', 5: '0.190699 ± 0.001053 (n=1019)'}

# %%
tsdiffusion = tsdiffusion.load(
    'tsdiffusion_best.pt',
    in_channels=11,
    hidden_dim=11*32,
    lam=[0.45,0.5,0.05],
    n_layers=12,
    n_layers_g=2,
    #cost_columns=[
    #'PH (CBM) 1st Stg ActCompr Poly Head',
    #'PH (CBM) 1st Stage ActShaft Power',
    #'PH (CBM) 1st Stg ActCompr Poly Head',
    #'PH (CBM) 1st Stage ActPress Ratio'
    #],
)
# Out:
# /root/coppe/3Wve/lib/python3.12/site-packages/torch/nn/modules/transformer.py:382: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(

# %%
tsdiffusion.save("tsdiffusion_best.pt")

# %%
with open("cognite_tsdiffusion_res.jsit011cognite_tsdiffusion_results_denoiser.json", "w") as f:
    json.dump(r+res_tsdiffusion, f)

# %%
best = float('inf')
idx = None
for i,v in enumerate(res_tsdiffusion):
    r = (res_tsdiffusion[i]['macro_mse'] + res_tsdiffusion[i]['micro_mse'] + 2 *
         (res_tsdiffusion[i]['macro_se']+res_tsdiffusion[i]['micro_se']))/2
    if r<best:
        best=r; idx=i
print(idx+1,res_tsdiffusion[idx])
# Out:
# 230 {'macro_mse': 0.6102950370930789, 'macro_se': 0.2824504131065163, 'micro_mse': 0.3602692503773992, 'micro_se': 0.14303970542372818, 'per_group_mse': {0: 0.7510305870819344, 1: 1.0137202931988625, 5: 0.06613423099843964}, 'per_group_se_w': {0: 0.3322655354141639, 1: 0.717881417677019, 5: 0.00653629525293232}, 'per_group_se_unw': {0: 0.25760537050006443, 1: 0.8681478768543307, 5: 0.006767674453606205}, 'per_group_counts': {0: 777, 1: 3, 5: 1019}, 'per_group_sum_nobs': {0: 72418.0, 1: 248.0, 5: 96759.0}, 'macro_mse_n': 0.0, 'macro_se_n': 0.0, 'micro_mse_n': 0.0, 'micro_se_n': 0.0, 'per_group_mse_n': {0: 0.0, 1: 0.0, 5: 0.0}, 'per_group_se_w_n': {0: 0.0, 1: 0.0, 5: 0.0}, 'per_group_se_unw_n': {0: 0.0, 1: 0.0, 5: 0.0}, 'per_group_sum_nobs_n': {0: 72418.0, 1: 248.0, 5: 96759.0}}

# %%
res_tsdiffusion[0]
# Out:
# {'macro_mse': 851.8934726455383,
#  'macro_se': 850.4746773190818,
#  'micro_mse': 4.622995258872104,
#  'micro_se': 2.302536020425354,
#  'per_group_mse': {0: 2.2876065119453934,
#   1: 2552.842531536697,
#   5: 0.5502798879724612},
#  'per_group_se_w': {0: 0.09809538898418306,
#   1: 536.0651358879828,
#   5: 0.00760295345018279},
#  'per_group_se_unw': {0: 0.09999981523989508,
#   1: 734.2852305592897,
#   5: 0.0077182135419288},
#  'per_group_counts': {0: 777, 1: 3, 5: 1019},
#  'per_group_sum_nobs': {0: 74478.0, 1: 218.0, 5: 93691.0},
#  'macro_mse_n': 0.0,
#  'macro_se_n': 0.0,
#  'micro_mse_n': 0.0,
#  'micro_se_n': 0.0,
#  'per_group_mse_n': {0: 0.0, 1: 0.0, 5: 0.0},
#  'per_group_se_w_n': {0: 0.0, 1: 0.0, 5: 0.0},
#  'per_group_se_unw_n': {0: 0.0, 1: 0.0, 5: 0.0},
#  'per_group_sum_nobs_n': {0: 74478.0, 1: 218.0, 5: 93691.0}}

# %%
df_scaled_rebuilt,df_scaled_denoised = tsdiffusion.denoise_dataframe(
    df=df_scaled,
    feature_cols=list(df_scaled.columns[:-1]),
    static_features_cols=None,
    timestamp_col='index',
    window_size=30,
    window_step=30,   
    replace_only_missing=False,
    steps=50
)

# %%
# Interpola valores nulos para melhor visualização
df_plot = df_scaled[df_scaled.columns[:-1]].interpolate()
df_plot.plot(figsize=(15, 12), subplots=True, layout=(-1, 2), sharex=True, grid=True)
plt.suptitle("Séries Temporais do Compressor", y=0.92, fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.9]) # Ajuste de layout para evitar sobreposição do título
plt.show()

# %%
# Interpola valores nulos para melhor visualização
df_plot = df_scaled_rebuilt.interpolate()
df_plot.plot(figsize=(15, 12), subplots=True, layout=(-1, 2), sharex=True, grid=True)
plt.suptitle("Séries Temporais do Compressor", y=0.92, fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.9]) # Ajuste de layout para evitar sobreposição do título
plt.show()

# %%
# Interpola valores nulos para melhor visualização
df_plot = df_scaled_denoised.interpolate()
df_plot.plot(figsize=(15, 12), subplots=True, layout=(-1, 2), sharex=True, grid=True)
plt.suptitle("Séries Temporais do Compressor", y=0.92, fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.9]) # Ajuste de layout para evitar sobreposição do título
plt.show()

# %%
((df_scaled_denoised['PH (CBM) 1st Stage ExpPress Ratio'].to_numpy(). - 
 df_scaled['PH (CBM) 1st Stage ExpPress Ratio'].to_numpy())**2).mean()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[372], line 2
#       1 ((df_scaled_denoised['PH (CBM) 1st Stage ExpPress Ratio'].to_numpy() -
# ----> 2  df_scaled['PH (CBM) 1st Stage ExpPress Ratio'].to_numpy().nam_to_zero())**2).mean()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'nam_to_zero'

# %% [markdown]
# ### 14. ODEJump + Attention + TSDiffusion

# %%
odejump_encoder_diff = ODEJumpEncoder(
    in_channels=11,
    hidden_dim=11*32,
    n_layers=6
)
# Out:
# /root/coppe/3Wve/lib/python3.12/site-packages/torch/nn/modules/transformer.py:382: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(

# %%
res_odejump_encoder_diff = odejump_encoder_diff.train_cognite(
    df=df_scaled_denoised,
    feature_cols=list(df_scaled.columns[:-1]),
    static_features_cols=None,
    timestamp_col='index',
    states_col='states',
    batch_size=256,
    window_size=30,
    window_step=30,
    epochs = 100,
    validate=False
)
res_odejump_encoder_diff = [r for r in res_odejump_encoder_diff if r is not None]  # remove None results
# Out:
# GRUPOS (total): {0: 3886, 1: 15, 5: 5093}
# GRUPOS (train): {0: 3109, 1: 12, 5: 4074}
# GRUPOS (test):  {0: 777, 1: 3, 5: 1019}
# Epoch 1/100 | Train(sampled) L1:61.924870 L4:0.390687 |
#           >> Test macro:105.961532 ± 105.949499 | micro:0.541230 ± 0.305776
# Epoch 2/100 | Train(sampled) L1:51.216745 L4:0.149265 |
#           >> Test macro:89.339450 ± 89.328374 | micro:0.457191 ± 0.257808
# Epoch 3/100 | Train(sampled) L1:43.216515 L4:0.139004 |
#           >> Test macro:75.777416 ± 75.770938 | micro:0.384799 ± 0.218682
# Epoch 4/100 | Train(sampled) L1:35.965020 L4:0.134966 |
#           >> Test macro:64.702969 ± 64.697425 | micro:0.328513 ± 0.186725
# Epoch 5/100 | Train(sampled) L1:29.890911 L4:0.131707 |
#           >> Test macro:55.994788 ± 55.988943 | micro:0.285272 ± 0.161593
# Epoch 6/100 | Train(sampled) L1:25.871281 L4:0.127225 |
#           >> Test macro:48.521211 ± 48.515262 | micro:0.247939 ± 0.140027
# Epoch 7/100 | Train(sampled) L1:22.359451 L4:0.121705 |
#           >> Test macro:41.648225 ± 41.642442 | micro:0.213396 ± 0.120194
# Epoch 8/100 | Train(sampled) L1:19.553538 L4:0.114194 |
#           >> Test macro:35.434135 ± 35.428139 | micro:0.182517 ± 0.102263
# Epoch 9/100 | Train(sampled) L1:15.878383 L4:0.105553 |
#           >> Test macro:29.964975 ± 29.959351 | micro:0.154800 ± 0.086483
# Epoch 10/100 | Train(sampled) L1:13.476557 L4:0.090366 |
#           >> Test macro:25.041567 ± 25.035916 | micro:0.130202 ± 0.072278
# Epoch 11/100 | Train(sampled) L1:11.454788 L4:0.067020 |
#           >> Test macro:20.551960 ± 20.545661 | micro:0.108431 ± 0.059321
# Epoch 12/100 | Train(sampled) L1:9.283007 L4:0.032333 |
#           >> Test macro:16.422731 ± 16.414020 | micro:0.090074 ± 0.047414
# Epoch 13/100 | Train(sampled) L1:7.276728 L4:0.008292 |
#           >> Test macro:12.837968 ± 12.827746 | micro:0.073623 ± 0.037079
# Epoch 14/100 | Train(sampled) L1:5.848706 L4:0.004521 |
#           >> Test macro:9.524580 ± 9.518933 | micro:0.052566 ± 0.027537
# Epoch 15/100 | Train(sampled) L1:4.275034 L4:0.003667 |
#           >> Test macro:6.851618 ± 6.845851 | micro:0.039335 ± 0.019843
# Epoch 16/100 | Train(sampled) L1:2.918405 L4:0.002938 |
#           >> Test macro:4.699142 ± 4.691660 | micro:0.030194 ± 0.013694
# Epoch 17/100 | Train(sampled) L1:1.998392 L4:0.002140 |
#           >> Test macro:3.001478 ± 2.991773 | micro:0.023901 ± 0.008872
# Epoch 18/100 | Train(sampled) L1:1.156782 L4:0.001467 |
#           >> Test macro:1.750866 ± 1.744198 | micro:0.014666 ± 0.005385
# Epoch 19/100 | Train(sampled) L1:0.677664 L4:0.000850 |
#           >> Test macro:0.884920 ± 0.879169 | micro:0.009440 ± 0.003154
# Epoch 20/100 | Train(sampled) L1:0.298064 L4:0.000590 |
#           >> Test macro:0.384963 ± 0.378688 | micro:0.007506 ± 0.002099
# Epoch 21/100 | Train(sampled) L1:0.126761 L4:0.000475 |
#           >> Test macro:0.123008 ± 0.114249 | micro:0.008594 ± 0.002165
# Epoch 22/100 | Train(sampled) L1:0.039447 L4:0.000413 |
#           >> Test macro:0.025191 ± 0.019433 | micro:0.005381 ± 0.002089
# Epoch 23/100 | Train(sampled) L1:0.014401 L4:0.000376 |
#           >> Test macro:0.005815 ± 0.003114 | micro:0.005346 ± 0.002080
# Epoch 24/100 | Train(sampled) L1:0.008015 L4:0.000298 |
#           >> Test macro:0.008341 ± 0.003455 | micro:0.007468 ± 0.002282
# Epoch 25/100 | Train(sampled) L1:0.008980 L4:0.000305 |
#           >> Test macro:0.006329 ± 0.004443 | micro:0.008244 ± 0.002314
# Epoch 26/100 | Train(sampled) L1:0.007193 L4:0.000261 |
#           >> Test macro:0.004401 ± 0.003486 | micro:0.005204 ± 0.002099
# Epoch 27/100 | Train(sampled) L1:0.006465 L4:0.000208 |
#           >> Test macro:0.004219 ± 0.003596 | micro:0.005153 ± 0.002071
# Epoch 28/100 | Train(sampled) L1:0.006358 L4:0.000193 |
#           >> Test macro:0.004484 ± 0.003454 | micro:0.005086 ± 0.002114
# Epoch 29/100 | Train(sampled) L1:0.007959 L4:0.000168 |
#           >> Test macro:0.004515 ± 0.003547 | micro:0.005339 ± 0.002078
# Epoch 30/100 | Train(sampled) L1:0.006451 L4:0.000160 |
#           >> Test macro:0.005167 ± 0.003396 | micro:0.006306 ± 0.001807
# Epoch 31/100 | Train(sampled) L1:0.004650 L4:0.000159 |
#           >> Test macro:0.005933 ± 0.003825 | micro:0.007143 ± 0.002124
# Epoch 32/100 | Train(sampled) L1:0.005305 L4:0.000147 |
#           >> Test macro:0.004775 ± 0.003280 | micro:0.005336 ± 0.001996
# Early stopping at epoch 32/100 (best test macro-MSE: 0.004219 @ epoch 27)
# TEST RESULTS | macro: 0.004775 ± 0.003280 | micro: 0.005336 ± 0.001996
#           >> per_group (weighted SE): {0: '0.011284 ± 0.004612 (n=777)', 1: '0.002233 ± 0.000366 (n=3)', 5: '0.000809 ± 0.000022 (n=1019)'}

# %%
with open("cognite_jumpode_attention_tsdiffusion_results.json", "w") as f:
    json.dump(res_odejump_encoder_diff, f)

# %%
odejump_encoder_diff = odejump_encoder_diff.load(
    "ode_jump.pt",
    in_channels=11,
    hidden_dim=11*32,
    n_layers=6
    )
odejump_encoder_diff.save("cognite_jumpode_attention_tsdiffusion.pt")
# Out:
# /root/coppe/3Wve/lib/python3.12/site-packages/torch/nn/modules/transformer.py:382: UserWarning:
#
# enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True

# %% [markdown]
# 15. ODEJUMP + Denoised vs Raw prediction

# %%
import importlib
#importlib.reload(sys.modules['tsdiffusion_transformed.ode_jump'])
#importlib.reload(sys.modules['tsdiffusion_transformed.ode_jump_encoder'])
from tsdiffusion_transformed.ode_jump import ODEJump
from tsdiffusion_transformed.ode_jump_encoder import ODEJumpEncoder

# %%
odejump_diff_raw = ODEJump(
    in_channels=11,
    hidden_dim=11*32,
    denoised=True
)

# %%
res_odejump_diff_raw = odejump_diff_raw.train_cognite(
    df=df_scaled,
    feature_cols=list(df_scaled.columns[:-1]),
    static_features_cols=None,
    timestamp_col='index',
    states_col='states',
    batch_size=256,
    window_size=30,
    window_step=30,
    epochs = 200,
    validate=False,
    df_denoised=df_scaled_denoised,  # Passa o dataframe original sem denoising
)
res_odejump_diff_raw = [r for r in res_odejump_diff_raw if r is not None]  # remove None results
# Out:
# GRUPOS (total): {0: 3886, 1: 15, 5: 5093}
# GRUPOS (train): {0: 3109, 1: 12, 5: 4074}
# GRUPOS (test):  {0: 777, 1: 3, 5: 1019}
# Epoch 1/200 | Train(sampled) L1:521.388774 L4:0.460358 |
#           >> Test macro:994.333078 ± 993.046459 | micro:6.146981 ± 2.866821
# Epoch 2/200 | Train(sampled) L1:461.661940 L4:0.276861 |
#           >> Test macro:965.320841 ± 964.496692 | micro:5.567655 ± 2.784252
# Epoch 3/200 | Train(sampled) L1:466.246161 L4:0.170216 |
#           >> Test macro:935.377912 ± 934.698279 | micro:5.289726 ± 2.698121
# Epoch 4/200 | Train(sampled) L1:463.491310 L4:0.125826 |
#           >> Test macro:906.474025 ± 905.874201 | micro:5.074173 ± 2.614869
# Epoch 5/200 | Train(sampled) L1:446.868652 L4:0.112397 |
#           >> Test macro:879.070499 ± 878.516449 | micro:4.895736 ± 2.535862
# Epoch 6/200 | Train(sampled) L1:441.466184 L4:0.102783 |
#           >> Test macro:852.899558 ± 852.377693 | micro:4.735844 ± 2.460420
# Epoch 7/200 | Train(sampled) L1:438.963452 L4:0.094709 |
#           >> Test macro:826.435998 ± 825.941857 | micro:4.578752 ± 2.384109
# Epoch 8/200 | Train(sampled) L1:408.621231 L4:0.086699 |
#           >> Test macro:802.868660 ± 802.385268 | micro:4.450724 ± 2.316146
# Epoch 9/200 | Train(sampled) L1:412.148566 L4:0.078356 |
#           >> Test macro:778.969616 ± 778.503881 | micro:4.316250 ± 2.247164
# Epoch 10/200 | Train(sampled) L1:393.974279 L4:0.068767 |
#           >> Test macro:755.697047 ± 755.228265 | micro:4.201945 ± 2.180055
# Epoch 11/200 | Train(sampled) L1:387.633457 L4:0.058532 |
#           >> Test macro:732.634197 ± 732.179937 | micro:4.073448 ± 2.113540
# Epoch 12/200 | Train(sampled) L1:349.560474 L4:0.048281 |
#           >> Test macro:711.243334 ± 710.802627 | micro:3.954993 ± 2.051780
# Epoch 13/200 | Train(sampled) L1:361.525131 L4:0.038035 |
#           >> Test macro:689.708725 ± 689.271253 | micro:3.843871 ± 1.989683
# Epoch 14/200 | Train(sampled) L1:334.742437 L4:0.030252 |
#           >> Test macro:666.919435 ± 666.481003 | micro:3.730529 ± 1.923939
# Epoch 15/200 | Train(sampled) L1:318.308462 L4:0.024110 |
#           >> Test macro:646.439404 ± 646.004488 | micro:3.625603 ± 1.864762
# Epoch 16/200 | Train(sampled) L1:324.126007 L4:0.018302 |
#           >> Test macro:627.100585 ± 626.672803 | micro:3.521955 ± 1.809024
# Epoch 17/200 | Train(sampled) L1:320.447448 L4:0.013715 |
#           >> Test macro:608.555809 ± 608.135176 | micro:3.422868 ± 1.755535
# Epoch 18/200 | Train(sampled) L1:302.009704 L4:0.010058 |
#           >> Test macro:591.150167 ± 590.737944 | micro:3.328385 ± 1.705315
# Epoch 19/200 | Train(sampled) L1:289.395850 L4:0.007752 |
#           >> Test macro:574.099357 ± 573.687679 | micro:3.243432 ± 1.656113
# Epoch 20/200 | Train(sampled) L1:280.659880 L4:0.006411 |
#           >> Test macro:556.174152 ± 555.751019 | micro:3.163627 ± 1.604338
# Epoch 21/200 | Train(sampled) L1:282.715726 L4:0.005092 |
#           >> Test macro:539.620023 ± 539.224458 | micro:3.056270 ± 1.556657
# Epoch 22/200 | Train(sampled) L1:259.426177 L4:0.004054 |
#           >> Test macro:523.950110 ± 523.558852 | micro:2.973902 ± 1.511402
# Epoch 23/200 | Train(sampled) L1:258.302747 L4:0.003148 |
#           >> Test macro:508.668726 ± 508.283085 | micro:2.892410 ± 1.467340
# Epoch 24/200 | Train(sampled) L1:260.843589 L4:0.002444 |
#           >> Test macro:493.674390 ± 493.290729 | micro:2.815982 ± 1.424012
# Epoch 25/200 | Train(sampled) L1:248.800129 L4:0.001932 |
#           >> Test macro:479.526639 ± 479.152349 | micro:2.736932 ± 1.383210
# Epoch 26/200 | Train(sampled) L1:225.769101 L4:0.001597 |
#           >> Test macro:465.916290 ± 465.520855 | micro:2.688493 ± 1.343810
# Epoch 27/200 | Train(sampled) L1:221.936391 L4:0.001295 |
#           >> Test macro:452.891288 ± 452.510347 | micro:2.609673 ± 1.306265
# Epoch 28/200 | Train(sampled) L1:225.256289 L4:0.001065 |
#           >> Test macro:436.887673 ± 436.516490 | micro:2.520339 ± 1.260256
# Epoch 29/200 | Train(sampled) L1:219.281228 L4:0.000879 |
#           >> Test macro:422.846199 ± 422.484092 | micro:2.442414 ± 1.219733
# Epoch 30/200 | Train(sampled) L1:203.582957 L4:0.000742 |
#           >> Test macro:409.855342 ± 409.484081 | micro:2.385312 ± 1.182353
# Epoch 31/200 | Train(sampled) L1:202.575896 L4:0.000703 |
#           >> Test macro:393.645551 ± 393.285353 | micro:2.294390 ± 1.135493
# Epoch 32/200 | Train(sampled) L1:189.402920 L4:0.000658 |
#           >> Test macro:380.563319 ± 380.209665 | micro:2.223437 ± 1.097702
# Epoch 33/200 | Train(sampled) L1:193.260485 L4:0.000711 |
#           >> Test macro:366.925580 ± 366.540499 | micro:2.182121 ± 1.058539
# Epoch 34/200 | Train(sampled) L1:174.064308 L4:0.000588 |
#           >> Test macro:354.751603 ± 354.388417 | micro:2.102789 ± 1.023259
# Epoch 35/200 | Train(sampled) L1:166.604523 L4:0.000512 |
#           >> Test macro:342.866701 ± 342.513840 | micro:2.034170 ± 0.989038
# Epoch 36/200 | Train(sampled) L1:162.896399 L4:0.000423 |
#           >> Test macro:331.108471 ± 330.757478 | micro:1.974264 ± 0.955032
# Epoch 37/200 | Train(sampled) L1:169.535557 L4:0.000396 |
#           >> Test macro:318.232249 ± 317.868270 | micro:1.920019 ± 0.917992
# Epoch 38/200 | Train(sampled) L1:159.847419 L4:0.000366 |
#           >> Test macro:306.291588 ± 305.935928 | micro:1.854082 ± 0.883515
# Epoch 39/200 | Train(sampled) L1:152.540530 L4:0.000306 |
#           >> Test macro:294.906084 ± 294.550570 | micro:1.797366 ± 0.850527
# Epoch 40/200 | Train(sampled) L1:143.215835 L4:0.000272 |
#           >> Test macro:283.462215 ± 283.103222 | micro:1.742807 ± 0.817645
# Epoch 41/200 | Train(sampled) L1:134.231147 L4:0.000236 |
#           >> Test macro:272.645510 ± 272.291124 | micro:1.684066 ± 0.786570
# Epoch 42/200 | Train(sampled) L1:127.108198 L4:0.000210 |
#           >> Test macro:262.090567 ± 261.734051 | micro:1.633307 ± 0.755830
# Epoch 43/200 | Train(sampled) L1:131.484824 L4:0.000186 |
#           >> Test macro:251.302555 ± 250.948051 | micro:1.578011 ± 0.724792
# Epoch 44/200 | Train(sampled) L1:125.805044 L4:0.000192 |
#           >> Test macro:240.658125 ± 240.243895 | micro:1.577990 ± 0.693946
# Epoch 45/200 | Train(sampled) L1:117.440919 L4:0.000170 |
#           >> Test macro:230.696128 ± 230.339521 | micro:1.477135 ± 0.665480
# Epoch 46/200 | Train(sampled) L1:114.880911 L4:0.000156 |
#           >> Test macro:220.722693 ± 220.353886 | micro:1.437206 ± 0.636810
# Epoch 47/200 | Train(sampled) L1:103.615043 L4:0.000147 |
#           >> Test macro:211.112755 ± 210.771374 | micro:1.365245 ± 0.608862
# Epoch 48/200 | Train(sampled) L1:107.822811 L4:0.000156 |
#           >> Test macro:201.380128 ± 201.029259 | micro:1.324238 ± 0.581100
# Epoch 49/200 | Train(sampled) L1:98.936791 L4:0.000146 |
#           >> Test macro:192.134413 ± 191.772247 | micro:1.288108 ± 0.554424
# Epoch 50/200 | Train(sampled) L1:91.719961 L4:0.000139 |
#           >> Test macro:183.271824 ± 182.897656 | micro:1.254350 ± 0.529001
# Epoch 51/200 | Train(sampled) L1:90.600457 L4:0.000138 |
#           >> Test macro:174.359777 ± 173.983626 | micro:1.211322 ± 0.503147
# Epoch 52/200 | Train(sampled) L1:82.312704 L4:0.000126 |
#           >> Test macro:165.802300 ± 165.452939 | micro:1.145428 ± 0.478400
# Epoch 53/200 | Train(sampled) L1:78.839120 L4:0.000120 |
#           >> Test macro:157.481345 ± 157.140307 | micro:1.096907 ± 0.454370
# Epoch 54/200 | Train(sampled) L1:77.017859 L4:0.000121 |
#           >> Test macro:149.270592 ± 148.850833 | micro:1.123513 ± 0.430813
# Epoch 55/200 | Train(sampled) L1:67.613553 L4:0.000121 |
#           >> Test macro:141.507907 ± 141.145563 | micro:1.035097 ± 0.408567
# Epoch 56/200 | Train(sampled) L1:68.545099 L4:0.000124 |
#           >> Test macro:133.539422 ± 133.185019 | micro:0.988180 ± 0.385853
# Epoch 57/200 | Train(sampled) L1:64.467455 L4:0.000116 |
#           >> Test macro:125.960753 ± 125.596648 | micro:0.958867 ± 0.363626
# Epoch 58/200 | Train(sampled) L1:64.485514 L4:0.000113 |
#           >> Test macro:118.309678 ± 117.960664 | micro:0.907203 ± 0.341886
# Epoch 59/200 | Train(sampled) L1:59.016293 L4:0.000112 |
#           >> Test macro:111.207254 ± 110.858577 | micro:0.871733 ± 0.321101
# Epoch 60/200 | Train(sampled) L1:55.627652 L4:0.000115 |
#           >> Test macro:104.224614 ± 103.868576 | micro:0.842799 ± 0.301533
# Epoch 61/200 | Train(sampled) L1:49.255361 L4:0.000115 |
#           >> Test macro:97.684019 ± 97.337869 | micro:0.801541 ± 0.282518
# Epoch 62/200 | Train(sampled) L1:46.961658 L4:0.000111 |
#           >> Test macro:91.436545 ± 91.053029 | micro:0.803116 ± 0.264982
# Epoch 63/200 | Train(sampled) L1:44.871175 L4:0.000111 |
#           >> Test macro:85.221882 ± 84.877802 | micro:0.737461 ± 0.246778
# Epoch 64/200 | Train(sampled) L1:38.965290 L4:0.000107 |
#           >> Test macro:79.390281 ± 78.998048 | micro:0.749835 ± 0.230392
# Epoch 65/200 | Train(sampled) L1:36.529066 L4:0.000106 |
#           >> Test macro:73.771523 ± 73.415093 | micro:0.690891 ± 0.214664
# Epoch 66/200 | Train(sampled) L1:34.960607 L4:0.000107 |
#           >> Test macro:68.289407 ± 67.912439 | micro:0.683135 ± 0.198214
# Epoch 67/200 | Train(sampled) L1:32.220130 L4:0.000105 |
#           >> Test macro:62.836327 ± 62.484832 | micro:0.632115 ± 0.182494
# Epoch 68/200 | Train(sampled) L1:29.942153 L4:0.000104 |
#           >> Test macro:57.716893 ± 57.357128 | micro:0.613129 ± 0.169448
# Epoch 69/200 | Train(sampled) L1:26.750905 L4:0.000105 |
#           >> Test macro:52.819382 ± 52.467662 | micro:0.581851 ± 0.154441
# Epoch 70/200 | Train(sampled) L1:25.247827 L4:0.000103 |
#           >> Test macro:48.158550 ± 47.800806 | micro:0.564149 ± 0.140829
# Epoch 71/200 | Train(sampled) L1:22.933125 L4:0.000104 |
#           >> Test macro:43.757717 ± 43.407560 | micro:0.534995 ± 0.129358
# Epoch 72/200 | Train(sampled) L1:20.289451 L4:0.000103 |
#           >> Test macro:39.559025 ± 39.198908 | micro:0.522831 ± 0.116375
# Epoch 73/200 | Train(sampled) L1:18.965071 L4:0.000104 |
#           >> Test macro:35.500577 ± 35.167211 | micro:0.479641 ± 0.104769
# Epoch 74/200 | Train(sampled) L1:16.253658 L4:0.000102 |
#           >> Test macro:31.875155 ± 31.517467 | micro:0.482454 ± 0.096189
# Epoch 75/200 | Train(sampled) L1:14.973180 L4:0.000103 |
#           >> Test macro:28.397172 ± 28.036546 | micro:0.467873 ± 0.085559
# Epoch 76/200 | Train(sampled) L1:13.653022 L4:0.000102 |
#           >> Test macro:25.011657 ± 24.669726 | micro:0.434406 ± 0.076112
# Epoch 77/200 | Train(sampled) L1:11.632081 L4:0.000101 |
#           >> Test macro:21.960742 ± 21.618587 | micro:0.419213 ± 0.068169
# Epoch 78/200 | Train(sampled) L1:9.803839 L4:0.000101 |
#           >> Test macro:19.228920 ± 18.868547 | micro:0.422071 ± 0.062634
# Epoch 79/200 | Train(sampled) L1:8.901387 L4:0.000101 |
#           >> Test macro:16.579569 ± 16.227830 | micro:0.400826 ± 0.053504
# Epoch 80/200 | Train(sampled) L1:7.615384 L4:0.000101 |
#           >> Test macro:14.214444 ± 13.863917 | micro:0.387805 ± 0.047972
# Epoch 81/200 | Train(sampled) L1:6.781343 L4:0.000101 |
#           >> Test macro:11.986179 ± 11.627438 | micro:0.385002 ± 0.044470
# Epoch 82/200 | Train(sampled) L1:5.859350 L4:0.000101 |
#           >> Test macro:9.956230 ± 9.600868 | micro:0.370849 ± 0.041417
# Epoch 83/200 | Train(sampled) L1:4.494921 L4:0.000101 |
#           >> Test macro:8.271213 ± 7.908053 | micro:0.370346 ± 0.038162
# Epoch 84/200 | Train(sampled) L1:3.869254 L4:0.000101 |
#           >> Test macro:6.751716 ± 6.390598 | micro:0.361853 ± 0.032656
# Epoch 85/200 | Train(sampled) L1:3.176063 L4:0.000101 |
#           >> Test macro:5.389949 ± 5.037428 | micro:0.347386 ± 0.027523
# Epoch 86/200 | Train(sampled) L1:2.571909 L4:0.000101 |
#           >> Test macro:4.239474 ± 3.884273 | micro:0.343871 ± 0.026464
# Epoch 87/200 | Train(sampled) L1:2.365923 L4:0.000101 |
#           >> Test macro:3.229842 ± 2.893439 | micro:0.322870 ± 0.025046
# Epoch 88/200 | Train(sampled) L1:1.775074 L4:0.000101 |
#           >> Test macro:2.496027 ± 2.147965 | micro:0.330462 ± 0.028798
# Epoch 89/200 | Train(sampled) L1:1.604943 L4:0.000100 |
#           >> Test macro:1.885879 ± 1.527716 | micro:0.338388 ± 0.031540
# Epoch 90/200 | Train(sampled) L1:1.379642 L4:0.000100 |
#           >> Test macro:1.866519 ± 1.517466 | micro:0.329993 ± 0.030676
# Epoch 91/200 | Train(sampled) L1:1.122456 L4:0.000100 |
#           >> Test macro:3.176895 ± 2.831498 | micro:0.331012 ± 0.025985
# Epoch 92/200 | Train(sampled) L1:1.029672 L4:0.000102 |
#           >> Test macro:1.177127 ± 0.832884 | micro:0.327625 ± 0.024501
# Epoch 93/200 | Train(sampled) L1:0.826885 L4:0.000105 |
#           >> Test macro:1.171237 ± 0.828383 | micro:0.326094 ± 0.026147
# Epoch 94/200 | Train(sampled) L1:0.681967 L4:0.000104 |
#           >> Test macro:1.168060 ± 0.827590 | micro:0.323824 ± 0.025135
# Epoch 95/200 | Train(sampled) L1:0.526931 L4:0.000104 |
#           >> Test macro:0.747582 ± 0.419490 | micro:0.321582 ± 0.024275
# Epoch 96/200 | Train(sampled) L1:0.411875 L4:0.000103 |
#           >> Test macro:1.185834 ± 0.839259 | micro:0.329700 ± 0.024645
# Epoch 97/200 | Train(sampled) L1:0.350774 L4:0.000103 |
#           >> Test macro:0.625664 ± 0.312593 | micro:0.314298 ± 0.024320
# Epoch 98/200 | Train(sampled) L1:0.280348 L4:0.000107 |
#           >> Test macro:0.534299 ± 0.225593 | micro:0.327546 ± 0.025205
# Epoch 99/200 | Train(sampled) L1:0.232624 L4:0.000106 |
#           >> Test macro:0.454905 ± 0.170298 | micro:0.330377 ± 0.027295
# Epoch 100/200 | Train(sampled) L1:0.186004 L4:0.000105 |
#           >> Test macro:0.406037 ± 0.152865 | micro:0.332652 ± 0.023301
# Epoch 101/200 | Train(sampled) L1:0.176099 L4:0.000103 |
#           >> Test macro:0.359689 ± 0.143436 | micro:0.324162 ± 0.027137
# Epoch 102/200 | Train(sampled) L1:0.162953 L4:0.000102 |
#           >> Test macro:0.358195 ± 0.141846 | micro:0.318346 ± 0.027127
# Epoch 103/200 | Train(sampled) L1:0.136619 L4:0.000102 |
#           >> Test macro:0.287360 ± 0.177448 | micro:0.341664 ± 0.027223
# Epoch 104/200 | Train(sampled) L1:0.146604 L4:0.000101 |
#           >> Test macro:0.286919 ± 0.153377 | micro:0.319150 ± 0.024613
# Epoch 105/200 | Train(sampled) L1:0.133954 L4:0.000101 |
#           >> Test macro:0.290232 ± 0.149573 | micro:0.313612 ± 0.024685
# Epoch 106/200 | Train(sampled) L1:0.129309 L4:0.000101 |
#           >> Test macro:0.281458 ± 0.161449 | micro:0.322650 ± 0.023068
# Epoch 107/200 | Train(sampled) L1:0.123654 L4:0.000101 |
#           >> Test macro:0.274608 ± 0.169061 | micro:0.330577 ± 0.027995
# Epoch 108/200 | Train(sampled) L1:0.114724 L4:0.000101 |
#           >> Test macro:0.272511 ± 0.179916 | micro:0.335151 ± 0.024085
# Epoch 109/200 | Train(sampled) L1:0.114739 L4:0.000100 |
#           >> Test macro:0.269180 ± 0.173173 | micro:0.327021 ± 0.025898
# Epoch 110/200 | Train(sampled) L1:0.116791 L4:0.000100 |
#           >> Test macro:0.283381 ± 0.183752 | micro:0.344554 ± 0.024492
# Epoch 111/200 | Train(sampled) L1:0.112152 L4:0.000100 |
#           >> Test macro:0.274942 ± 0.175958 | micro:0.332652 ± 0.028186
# Epoch 112/200 | Train(sampled) L1:0.113860 L4:0.000101 |
#           >> Test macro:0.265729 ± 0.171895 | micro:0.324177 ± 0.025906
# Epoch 113/200 | Train(sampled) L1:0.104272 L4:0.000100 |
#           >> Test macro:0.265032 ± 0.173813 | micro:0.325469 ± 0.024744
# Epoch 114/200 | Train(sampled) L1:0.107901 L4:0.000100 |
#           >> Test macro:0.263400 ± 0.178115 | micro:0.329664 ± 0.025961
# Epoch 115/200 | Train(sampled) L1:0.107999 L4:0.000100 |
#           >> Test macro:0.256235 ± 0.176201 | micro:0.323559 ± 0.026402
# Epoch 116/200 | Train(sampled) L1:0.111242 L4:0.000100 |
#           >> Test macro:0.257888 ± 0.179644 | micro:0.328189 ± 0.025370
# Epoch 117/200 | Train(sampled) L1:0.100076 L4:0.000100 |
#           >> Test macro:0.255475 ± 0.183105 | micro:0.329609 ± 0.023684
# Epoch 118/200 | Train(sampled) L1:0.099559 L4:0.000100 |
#           >> Test macro:0.242379 ± 0.180759 | micro:0.321443 ± 0.024409
# Epoch 119/200 | Train(sampled) L1:0.101334 L4:0.000100 |
#           >> Test macro:0.261499 ± 0.199942 | micro:0.351583 ± 0.024250
# Epoch 120/200 | Train(sampled) L1:0.097820 L4:0.000100 |
#           >> Test macro:0.253803 ± 0.187996 | micro:0.332286 ± 0.025287
# Epoch 121/200 | Train(sampled) L1:0.097100 L4:0.000100 |
#           >> Test macro:0.256091 ± 0.190821 | micro:0.334053 ± 0.027395
# Epoch 122/200 | Train(sampled) L1:0.097381 L4:0.000100 |
#           >> Test macro:0.241637 ± 0.180831 | micro:0.319720 ± 0.024610
# Epoch 123/200 | Train(sampled) L1:0.089844 L4:0.000100 |
#           >> Test macro:0.237824 ± 0.180759 | micro:0.317629 ± 0.023967
# Epoch 124/200 | Train(sampled) L1:0.098670 L4:0.000100 |
#           >> Test macro:0.250877 ± 0.183952 | micro:0.327602 ± 0.025232
# Epoch 125/200 | Train(sampled) L1:0.094017 L4:0.000100 |
#           >> Test macro:0.243720 ± 0.187357 | micro:0.327483 ± 0.024808
# Epoch 126/200 | Train(sampled) L1:0.095175 L4:0.000100 |
#           >> Test macro:0.261003 ± 0.186091 | micro:0.337468 ± 0.024601
# Epoch 127/200 | Train(sampled) L1:0.092767 L4:0.000100 |
#           >> Test macro:0.247375 ± 0.193338 | micro:0.332048 ± 0.024067
# Epoch 128/200 | Train(sampled) L1:0.097586 L4:0.000100 |
#           >> Test macro:0.250510 ± 0.192324 | micro:0.335811 ± 0.023850
# Early stopping at epoch 128/200 (best test macro-MSE: 0.237824 @ epoch 123)
# TEST RESULTS | macro: 0.250510 ± 0.192324 | micro: 0.335811 ± 0.023850
#           >> per_group (weighted SE): {0: '0.630525 ± 0.052919 (n=777)', 1: '0.008957 ± 0.003596 (n=3)', 5: '0.112049 ± 0.005498 (n=1019)'}

# %%
odejump_diff_raw = odejump_diff_raw.load(
    "ode_jump.pt",
    in_channels=11,
    hidden_dim=11*32,
    denoised=True
    )
odejump_diff_raw.save("cognite_jumpode_tsdiffusion_raw.pt")

# %%
with open("cognite_jumpode_tsdiffusion_raw_results.json", "w") as f:
    json.dump(res_odejump_diff_raw, f)

# %% [markdown]
# 16. ODEJUMP + Attention + Denoised vs Raw prediction

# %%
importlib.reload(sys.modules['tsdiffusion_transformed.ode_jump_encoder_test'])
importlib.reload(sys.modules['tsdiffusion_transformed.ode_jump'])
from tsdiffusion_transformed.ode_jump_encoder_test import ODEJumpEncoder
from tsdiffusion_transformed.ode_jump_encoder import ODEJump

# %%
odejump_encoder_diff_raw = ODEJumpEncoder(
    in_channels=11,
    hidden_dim=11*32,
    n_layers=2,
    denoised=True
)
# Out:
# /root/coppe/3Wve/lib/python3.12/site-packages/torch/nn/modules/transformer.py:382: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(

# %%
res_odejump_encoder_diff_raw = odejump_encoder_diff_raw.train_cognite(
    df=df_scaled,
    feature_cols=list(df_scaled.columns[:-1]),
    static_features_cols=None,
    timestamp_col='index',
    states_col='states',
    batch_size=256,
    window_size=30,
    window_step=30,
    epochs = 200,
    validate=False,
    df_denoised=df_scaled_denoised,  # Passa o dataframe original sem denoising
)
res_odejump_encoder_diff_raw = [r for r in res_odejump_encoder_diff_raw if r is not None]  # remove None results
# Out:
# GRUPOS (total): {0: 3886, 1: 15, 5: 5093}
# GRUPOS (train): {0: 3109, 1: 12, 5: 4074}
# GRUPOS (test):  {0: 777, 1: 3, 5: 1019}
# Epoch 1/200 | Train(sampled) L1:521.399887 L4:0.394529 |
#           >> Test macro:993.860057 ± 992.743168 | micro:5.991270 ± 2.865838
# Epoch 2/200 | Train(sampled) L1:499.437045 L4:0.218793 |
#           >> Test macro:960.911465 ± 960.013746 | micro:5.610664 ± 2.771382
# Epoch 3/200 | Train(sampled) L1:468.214768 L4:0.190590 |
#           >> Test macro:931.972214 ± 931.177933 | micro:5.370794 ± 2.688109
# Epoch 4/200 | Train(sampled) L1:465.548568 L4:0.173286 |
#           >> Test macro:903.903670 ± 903.195297 | micro:5.153104 ± 2.607323
# Epoch 5/200 | Train(sampled) L1:426.879605 L4:0.169625 |
#           >> Test macro:877.787828 ± 877.138952 | micro:4.969891 ± 2.532068
# Epoch 6/200 | Train(sampled) L1:419.209926 L4:0.166779 |
#           >> Test macro:852.835946 ± 852.239086 | micro:4.799419 ± 2.460165
# Epoch 7/200 | Train(sampled) L1:417.654466 L4:0.164427 |
#           >> Test macro:828.518339 ± 827.951183 | micro:4.651697 ± 2.390041
# Epoch 8/200 | Train(sampled) L1:420.044381 L4:0.162696 |
#           >> Test macro:804.150750 ± 803.611686 | micro:4.504897 ± 2.319770
# Epoch 9/200 | Train(sampled) L1:399.817480 L4:0.160749 |
#           >> Test macro:780.056085 ± 779.538603 | micro:4.365513 ± 2.250290
# Epoch 10/200 | Train(sampled) L1:392.195346 L4:0.158738 |
#           >> Test macro:758.516400 ± 758.010800 | micro:4.247534 ± 2.188121
# Epoch 11/200 | Train(sampled) L1:385.269011 L4:0.156882 |
#           >> Test macro:737.556588 ± 737.067350 | micro:4.128114 ± 2.127700
# Epoch 12/200 | Train(sampled) L1:381.261799 L4:0.155362 |
#           >> Test macro:716.779161 ± 716.302505 | micro:4.013113 ± 2.067758
# Epoch 13/200 | Train(sampled) L1:351.154614 L4:0.152149 |
#           >> Test macro:696.922957 ± 696.452553 | micro:3.908604 ± 2.010440
# Epoch 14/200 | Train(sampled) L1:359.241928 L4:0.149525 |
#           >> Test macro:677.719746 ± 677.265805 | micro:3.797851 ± 1.955069
# Epoch 15/200 | Train(sampled) L1:341.839938 L4:0.146596 |
#           >> Test macro:659.240845 ± 658.791329 | micro:3.701346 ± 1.901801
# Epoch 16/200 | Train(sampled) L1:333.037648 L4:0.143073 |
#           >> Test macro:641.825057 ± 641.384490 | micro:3.606978 ± 1.851503
# Epoch 17/200 | Train(sampled) L1:310.918287 L4:0.139207 |
#           >> Test macro:624.859445 ± 624.427134 | micro:3.514159 ± 1.802579
# Epoch 18/200 | Train(sampled) L1:303.364182 L4:0.135666 |
#           >> Test macro:608.033356 ± 607.611454 | micro:3.420970 ± 1.754034
# Epoch 19/200 | Train(sampled) L1:301.277340 L4:0.131281 |
#           >> Test macro:592.379823 ± 591.964765 | micro:3.336960 ± 1.708900
# Epoch 20/200 | Train(sampled) L1:300.091255 L4:0.127101 |
#           >> Test macro:576.943391 ± 576.538242 | micro:3.250803 ± 1.664340
# Epoch 21/200 | Train(sampled) L1:281.214665 L4:0.125252 |
#           >> Test macro:558.936289 ± 558.535401 | micro:3.157187 ± 1.612394
# Epoch 22/200 | Train(sampled) L1:274.241657 L4:0.120734 |
#           >> Test macro:544.045001 ± 543.653837 | micro:3.073838 ± 1.569427
# Epoch 23/200 | Train(sampled) L1:268.945155 L4:0.115982 |
#           >> Test macro:529.678259 ± 529.288024 | micro:3.001646 ± 1.527928
# Epoch 24/200 | Train(sampled) L1:274.276117 L4:0.111741 |
#           >> Test macro:515.655002 ± 515.269883 | micro:2.926485 ± 1.487531
# Epoch 25/200 | Train(sampled) L1:257.145424 L4:0.106036 |
#           >> Test macro:502.236301 ± 501.858701 | micro:2.853118 ± 1.448797
# Epoch 26/200 | Train(sampled) L1:247.085159 L4:0.102723 |
#           >> Test macro:488.320626 ± 487.943196 | micro:2.783584 ± 1.408605
# Epoch 27/200 | Train(sampled) L1:248.610799 L4:0.100224 |
#           >> Test macro:475.370152 ± 474.993792 | micro:2.717489 ± 1.371290
# Epoch 28/200 | Train(sampled) L1:232.767196 L4:0.096100 |
#           >> Test macro:462.991859 ± 462.614965 | micro:2.656201 ± 1.335506
# Epoch 29/200 | Train(sampled) L1:222.364983 L4:0.095911 |
#           >> Test macro:451.003531 ± 450.628393 | micro:2.595007 ± 1.300894
# Epoch 30/200 | Train(sampled) L1:232.926460 L4:0.090671 |
#           >> Test macro:439.043399 ± 438.672838 | micro:2.531238 ± 1.266371
# Epoch 31/200 | Train(sampled) L1:224.812671 L4:0.085942 |
#           >> Test macro:427.490926 ± 427.127801 | micro:2.466495 ± 1.233043
# Epoch 32/200 | Train(sampled) L1:216.756092 L4:0.083038 |
#           >> Test macro:416.182725 ± 415.805474 | micro:2.422821 ± 1.200341
# Epoch 33/200 | Train(sampled) L1:209.025922 L4:0.083304 |
#           >> Test macro:404.874926 ± 404.514340 | micro:2.351339 ± 1.167870
# Epoch 34/200 | Train(sampled) L1:200.029879 L4:0.082553 |
#           >> Test macro:392.686126 ± 392.319398 | micro:2.295968 ± 1.132739
# Epoch 35/200 | Train(sampled) L1:192.481747 L4:0.085885 |
#           >> Test macro:381.890076 ± 381.534509 | micro:2.231730 ± 1.101482
# Epoch 36/200 | Train(sampled) L1:190.581759 L4:0.077459 |
#           >> Test macro:371.078804 ± 370.723261 | micro:2.177411 ± 1.070372
# Epoch 37/200 | Train(sampled) L1:182.620003 L4:0.076819 |
#           >> Test macro:360.649188 ± 360.296333 | micro:2.123287 ± 1.040222
# Epoch 38/200 | Train(sampled) L1:182.190824 L4:0.073177 |
#           >> Test macro:349.922846 ± 349.573065 | micro:2.066652 ± 1.009276
# Epoch 39/200 | Train(sampled) L1:177.242304 L4:0.077433 |
#           >> Test macro:337.899035 ± 337.540287 | micro:2.015176 ± 0.974535
# Epoch 40/200 | Train(sampled) L1:164.929962 L4:0.080472 |
#           >> Test macro:327.906570 ± 327.557841 | micro:1.955606 ± 0.945719
# Epoch 41/200 | Train(sampled) L1:160.977065 L4:0.080163 |
#           >> Test macro:318.058841 ± 317.705354 | micro:1.910774 ± 0.917255
# Epoch 42/200 | Train(sampled) L1:154.159746 L4:0.081498 |
#           >> Test macro:308.240844 ± 307.883265 | micro:1.865205 ± 0.889106
# Epoch 43/200 | Train(sampled) L1:151.132200 L4:0.076343 |
#           >> Test macro:298.562156 ± 298.212458 | micro:1.809664 ± 0.861156
# Epoch 44/200 | Train(sampled) L1:148.532589 L4:0.072778 |
#           >> Test macro:288.855410 ± 288.509679 | micro:1.757616 ± 0.833100
# Epoch 45/200 | Train(sampled) L1:143.038943 L4:0.074157 |
#           >> Test macro:279.557749 ± 279.192678 | micro:1.728816 ± 0.806333
# Epoch 46/200 | Train(sampled) L1:133.373742 L4:0.079067 |
#           >> Test macro:270.051380 ± 269.705330 | micro:1.663871 ± 0.778799
# Epoch 47/200 | Train(sampled) L1:136.059600 L4:0.069205 |
#           >> Test macro:260.964064 ± 260.608293 | micro:1.626815 ± 0.752760
# Epoch 48/200 | Train(sampled) L1:132.134658 L4:0.065687 |
#           >> Test macro:252.093133 ± 251.743688 | micro:1.576661 ± 0.727216
# Epoch 49/200 | Train(sampled) L1:121.069687 L4:0.069213 |
#           >> Test macro:243.172534 ± 242.834667 | micro:1.522208 ± 0.701263
# Epoch 50/200 | Train(sampled) L1:118.808846 L4:0.064764 |
#           >> Test macro:234.712944 ± 234.367939 | micro:1.486095 ± 0.676932
# Epoch 51/200 | Train(sampled) L1:118.496351 L4:0.066900 |
#           >> Test macro:225.231142 ± 224.884979 | micro:1.440103 ± 0.649504
# Epoch 52/200 | Train(sampled) L1:109.706354 L4:0.069168 |
#           >> Test macro:217.012425 ± 216.662532 | micro:1.401824 ± 0.625761
# Epoch 53/200 | Train(sampled) L1:106.518984 L4:0.067207 |
#           >> Test macro:208.728328 ± 208.377951 | micro:1.360738 ± 0.601837
# Epoch 54/200 | Train(sampled) L1:108.297766 L4:0.088228 |
#           >> Test macro:200.426498 ± 200.052905 | micro:1.339740 ± 0.577952
# Epoch 55/200 | Train(sampled) L1:96.044018 L4:0.067591 |
#           >> Test macro:192.597091 ± 192.255700 | micro:1.272242 ± 0.555457
# Epoch 56/200 | Train(sampled) L1:93.292294 L4:0.059515 |
#           >> Test macro:185.159425 ± 184.813928 | micro:1.238764 ± 0.533937
# Epoch 57/200 | Train(sampled) L1:89.842731 L4:0.055982 |
#           >> Test macro:177.637267 ± 177.283126 | micro:1.208228 ± 0.512628
# Epoch 58/200 | Train(sampled) L1:85.626345 L4:0.056789 |
#           >> Test macro:170.356552 ± 170.002496 | micro:1.172520 ± 0.491382
# Epoch 59/200 | Train(sampled) L1:79.158195 L4:0.052130 |
#           >> Test macro:163.376955 ± 163.022307 | micro:1.137142 ± 0.471522
# Epoch 60/200 | Train(sampled) L1:74.692139 L4:0.049483 |
#           >> Test macro:155.811609 ± 155.464444 | micro:1.093772 ± 0.449540
# Epoch 61/200 | Train(sampled) L1:77.303159 L4:0.052204 |
#           >> Test macro:148.611791 ± 148.268577 | micro:1.053539 ± 0.428708
# Epoch 62/200 | Train(sampled) L1:74.936888 L4:0.046346 |
#           >> Test macro:141.749123 ± 141.397375 | micro:1.027051 ± 0.408912
# Epoch 63/200 | Train(sampled) L1:71.709648 L4:0.048312 |
#           >> Test macro:135.003470 ± 134.656531 | micro:0.988665 ± 0.389644
# Epoch 64/200 | Train(sampled) L1:64.283245 L4:0.042270 |
#           >> Test macro:127.557928 ± 127.199188 | micro:0.961828 ± 0.368168
# Epoch 65/200 | Train(sampled) L1:63.239584 L4:0.044829 |
#           >> Test macro:121.204487 ± 120.859913 | micro:0.917815 ± 0.349956
# Epoch 66/200 | Train(sampled) L1:60.365611 L4:0.049801 |
#           >> Test macro:115.146750 ± 114.805960 | micro:0.884905 ± 0.332409
# Epoch 67/200 | Train(sampled) L1:57.173984 L4:0.043015 |
#           >> Test macro:109.103798 ± 108.745997 | micro:0.868819 ± 0.314968
# Epoch 68/200 | Train(sampled) L1:50.661349 L4:0.040996 |
#           >> Test macro:102.991808 ± 102.648303 | micro:0.825449 ± 0.297436
# Epoch 69/200 | Train(sampled) L1:50.758805 L4:0.040461 |
#           >> Test macro:97.419893 ± 97.022753 | micro:0.844139 ± 0.281695
# Epoch 70/200 | Train(sampled) L1:48.717615 L4:0.038863 |
#           >> Test macro:91.759767 ± 91.386482 | micro:0.795199 ± 0.265065
# Epoch 71/200 | Train(sampled) L1:44.829761 L4:0.037396 |
#           >> Test macro:86.424372 ± 86.075757 | micro:0.747522 ± 0.249680
# Epoch 72/200 | Train(sampled) L1:43.891623 L4:0.047442 |
#           >> Test macro:81.240108 ± 80.889476 | micro:0.723515 ± 0.234771
# Epoch 73/200 | Train(sampled) L1:39.454684 L4:0.037544 |
#           >> Test macro:76.273631 ± 75.936926 | micro:0.685955 ± 0.220665
# Epoch 74/200 | Train(sampled) L1:37.317338 L4:0.034183 |
#           >> Test macro:71.539727 ± 71.196176 | micro:0.668128 ± 0.207076
# Epoch 75/200 | Train(sampled) L1:34.498736 L4:0.033279 |
#           >> Test macro:66.963053 ± 66.612067 | micro:0.651369 ± 0.194600
# Epoch 76/200 | Train(sampled) L1:30.250913 L4:0.033019 |
#           >> Test macro:62.656260 ± 62.317208 | micro:0.620109 ± 0.181882
# Epoch 77/200 | Train(sampled) L1:29.455822 L4:0.033560 |
#           >> Test macro:58.316777 ± 57.973592 | micro:0.601928 ± 0.169564
# Epoch 78/200 | Train(sampled) L1:26.152535 L4:0.032034 |
#           >> Test macro:54.244710 ± 53.900698 | micro:0.582289 ± 0.158253
# Epoch 79/200 | Train(sampled) L1:25.939853 L4:0.032971 |
#           >> Test macro:50.163415 ± 49.810560 | micro:0.569515 ± 0.146371
# Epoch 80/200 | Train(sampled) L1:24.024073 L4:0.031304 |
#           >> Test macro:46.283575 ± 45.925420 | micro:0.554254 ± 0.135371
# Epoch 81/200 | Train(sampled) L1:21.252572 L4:0.031164 |
#           >> Test macro:42.650050 ± 42.310597 | micro:0.519807 ± 0.125010
# Epoch 82/200 | Train(sampled) L1:20.433123 L4:0.030077 |
#           >> Test macro:39.070035 ± 38.715945 | micro:0.515906 ± 0.115117
# Epoch 83/200 | Train(sampled) L1:19.326826 L4:0.031817 |
#           >> Test macro:35.572973 ± 35.225120 | micro:0.492188 ± 0.105117
# Epoch 84/200 | Train(sampled) L1:16.462084 L4:0.029771 |
#           >> Test macro:32.404078 ± 32.054206 | micro:0.477717 ± 0.095539
# Epoch 85/200 | Train(sampled) L1:15.926425 L4:0.028081 |
#           >> Test macro:29.348592 ± 29.012678 | micro:0.450550 ± 0.087335
# Epoch 86/200 | Train(sampled) L1:13.923622 L4:0.027782 |
#           >> Test macro:26.449471 ± 26.097386 | micro:0.450373 ± 0.079600
# Epoch 87/200 | Train(sampled) L1:12.121531 L4:0.026896 |
#           >> Test macro:23.789433 ± 23.434951 | micro:0.439361 ± 0.073325
# Epoch 88/200 | Train(sampled) L1:10.700768 L4:0.027778 |
#           >> Test macro:21.310858 ± 20.969742 | micro:0.415076 ± 0.066164
# Epoch 89/200 | Train(sampled) L1:9.604362 L4:0.025337 |
#           >> Test macro:18.927742 ± 18.590516 | micro:0.399328 ± 0.060756
# Epoch 90/200 | Train(sampled) L1:8.754317 L4:0.026823 |
#           >> Test macro:16.641344 ± 16.283415 | micro:0.407686 ± 0.053459
# Epoch 91/200 | Train(sampled) L1:7.398933 L4:0.023321 |
#           >> Test macro:14.522667 ± 14.185801 | micro:0.377802 ± 0.047653
# Epoch 92/200 | Train(sampled) L1:6.742215 L4:0.022559 |
#           >> Test macro:12.613822 ± 12.262135 | micro:0.381079 ± 0.044106
# Epoch 93/200 | Train(sampled) L1:5.603193 L4:0.022398 |
#           >> Test macro:10.855217 ± 10.501106 | micro:0.374882 ± 0.039101
# Epoch 94/200 | Train(sampled) L1:4.989857 L4:0.022052 |
#           >> Test macro:9.185142 ± 8.848286 | micro:0.351081 ± 0.034619
# Epoch 95/200 | Train(sampled) L1:4.147446 L4:0.022394 |
#           >> Test macro:7.702710 ± 7.350123 | micro:0.357466 ± 0.035678
# Epoch 96/200 | Train(sampled) L1:3.464455 L4:0.021328 |
#           >> Test macro:6.364949 ± 6.027854 | micro:0.337716 ± 0.032208
# Epoch 97/200 | Train(sampled) L1:2.775346 L4:0.020324 |
#           >> Test macro:5.201064 ± 4.825233 | micro:0.366109 ± 0.029543
# Epoch 98/200 | Train(sampled) L1:2.201371 L4:0.020806 |
#           >> Test macro:4.137544 ± 3.791171 | micro:0.335436 ± 0.030177
# Epoch 99/200 | Train(sampled) L1:1.776782 L4:0.018972 |
#           >> Test macro:3.222235 ± 2.886155 | micro:0.322087 ± 0.025180
# Epoch 100/200 | Train(sampled) L1:1.335457 L4:0.018130 |
#           >> Test macro:2.459430 ± 2.128572 | micro:0.315267 ± 0.026981
# Epoch 101/200 | Train(sampled) L1:1.038690 L4:0.018089 |
#           >> Test macro:1.830999 ± 1.492495 | micro:0.320578 ± 0.026408
# Epoch 102/200 | Train(sampled) L1:0.702525 L4:0.016979 |
#           >> Test macro:1.354217 ± 0.992134 | micro:0.343471 ± 0.026034
# Epoch 103/200 | Train(sampled) L1:0.497346 L4:0.016291 |
#           >> Test macro:0.952407 ± 0.627230 | micro:0.311479 ± 0.024808
# Epoch 104/200 | Train(sampled) L1:0.364072 L4:0.015490 |
#           >> Test macro:0.668225 ± 0.346895 | micro:0.319351 ± 0.028809
# Epoch 105/200 | Train(sampled) L1:0.244822 L4:0.015767 |
#           >> Test macro:0.463716 ± 0.185319 | micro:0.303538 ± 0.024222
# Epoch 106/200 | Train(sampled) L1:0.181540 L4:0.014137 |
#           >> Test macro:0.360336 ± 0.138164 | micro:0.317021 ± 0.023784
# Epoch 107/200 | Train(sampled) L1:0.144981 L4:0.014822 |
#           >> Test macro:0.295356 ± 0.149474 | micro:0.314328 ± 0.024577
# Epoch 108/200 | Train(sampled) L1:0.141065 L4:0.015375 |
#           >> Test macro:0.267847 ± 0.151266 | micro:0.306033 ± 0.026697
# Epoch 109/200 | Train(sampled) L1:0.123096 L4:0.014714 |
#           >> Test macro:0.263957 ± 0.161400 | micro:0.314058 ± 0.031394
# Epoch 110/200 | Train(sampled) L1:0.121149 L4:0.013633 |
#           >> Test macro:0.274142 ± 0.171634 | micro:0.328626 ± 0.028024
# Epoch 111/200 | Train(sampled) L1:0.118655 L4:0.012431 |
#           >> Test macro:0.260510 ± 0.159872 | micro:0.311433 ± 0.027717
# Epoch 112/200 | Train(sampled) L1:0.123795 L4:0.012851 |
#           >> Test macro:0.274446 ± 0.164994 | micro:0.330321 ± 0.024793
# Epoch 113/200 | Train(sampled) L1:0.120625 L4:0.012705 |
#           >> Test macro:0.273820 ± 0.169459 | micro:0.326291 ± 0.026148
# Epoch 114/200 | Train(sampled) L1:0.115275 L4:0.012449 |
#           >> Test macro:0.262117 ± 0.154920 | micro:0.307230 ± 0.024869
# Epoch 115/200 | Train(sampled) L1:0.110200 L4:0.012287 |
#           >> Test macro:0.271690 ± 0.167661 | micro:0.322667 ± 0.026172
# Epoch 116/200 | Train(sampled) L1:0.112955 L4:0.011918 |
#           >> Test macro:0.249483 ± 0.159171 | micro:0.306700 ± 0.023091
# Epoch 117/200 | Train(sampled) L1:0.111947 L4:0.011471 |
#           >> Test macro:0.258137 ± 0.163764 | micro:0.314014 ± 0.022261
# Epoch 118/200 | Train(sampled) L1:0.108189 L4:0.011082 |
#           >> Test macro:0.247809 ± 0.161963 | micro:0.305688 ± 0.022502
# Epoch 119/200 | Train(sampled) L1:0.102819 L4:0.011029 |
#           >> Test macro:0.255042 ± 0.155491 | micro:0.307794 ± 0.023765
# Epoch 120/200 | Train(sampled) L1:0.106968 L4:0.011295 |
#           >> Test macro:0.267841 ± 0.174247 | micro:0.327863 ± 0.029849
# Epoch 121/200 | Train(sampled) L1:0.110455 L4:0.010516 |
#           >> Test macro:0.252088 ± 0.162364 | micro:0.309220 ± 0.024889
# Epoch 122/200 | Train(sampled) L1:0.106891 L4:0.011350 |
#           >> Test macro:0.276642 ± 0.168747 | micro:0.329944 ± 0.025731
# Epoch 123/200 | Train(sampled) L1:0.106901 L4:0.012546 |
#           >> Test macro:0.266481 ± 0.168954 | micro:0.322390 ± 0.023407
# Early stopping at epoch 123/200 (best test macro-MSE: 0.247809 @ epoch 118)
# TEST RESULTS | macro: 0.266481 ± 0.168954 | micro: 0.322390 ± 0.023407
#           >> per_group (weighted SE): {0: '0.604167 ± 0.052060 (n=777)', 1: '0.087051 ± 0.070674 (n=3)', 5: '0.108225 ± 0.005221 (n=1019)'}

# %%
res_odejump_encoder_diff_raw = odejump_encoder_diff_raw.train_cognite(
    df=df_scaled,
    feature_cols=list(df_scaled.columns[:-1]),
    static_features_cols=None,
    timestamp_col='index',
    states_col='states',
    batch_size=256,
    window_size=30,
    window_step=30,
    epochs = 200,
    validate=False,
    df_denoised=df_scaled_denoised,  # Passa o dataframe original sem denoising
)
res_odejump_encoder_diff_raw = [r for r in res_odejump_encoder_diff_raw if r is not None]  # remove None results
# Out:
# GRUPOS (total): {0: 3886, 1: 15, 5: 5093}
# GRUPOS (train): {0: 3109, 1: 12, 5: 4074}
# GRUPOS (test):  {0: 777, 1: 3, 5: 1019}
# Epoch 1/200 | Train(sampled) L1:481.344474 L4:0.286859 |
#           >> Test macro:964.350974 ± 963.684369 | micro:5.425601 ± 2.781757
# Epoch 2/200 | Train(sampled) L1:490.676521 L4:0.163503 |
#           >> Test macro:935.811468 ± 935.233943 | micro:5.202369 ± 2.699513
# Epoch 3/200 | Train(sampled) L1:466.072518 L4:0.154350 |
#           >> Test macro:907.449298 ± 906.940827 | micro:4.998726 ± 2.617793
# Epoch 4/200 | Train(sampled) L1:444.391029 L4:0.148873 |
#           >> Test macro:879.100427 ± 878.641449 | micro:4.811517 ± 2.536078
# Epoch 5/200 | Train(sampled) L1:410.737372 L4:0.145620 |
#           >> Test macro:851.974545 ± 851.510764 | micro:4.681512 ± 2.457821
# Epoch 6/200 | Train(sampled) L1:419.340653 L4:0.144376 |
#           >> Test macro:824.280105 ± 823.858159 | micro:4.505025 ± 2.377958
# Epoch 7/200 | Train(sampled) L1:403.441126 L4:0.142164 |
#           >> Test macro:796.807048 ± 796.382093 | micro:4.370993 ± 2.298609
# Epoch 8/200 | Train(sampled) L1:405.314087 L4:0.140213 |
#           >> Test macro:769.979069 ± 769.576325 | micro:4.216273 ± 2.221250
# Epoch 9/200 | Train(sampled) L1:393.678771 L4:0.138851 |
#           >> Test macro:743.636473 ± 743.234662 | micro:4.084318 ± 2.145262
# Epoch 10/200 | Train(sampled) L1:363.446561 L4:0.137745 |
#           >> Test macro:718.550569 ± 718.157053 | micro:3.950357 ± 2.072920
# Epoch 11/200 | Train(sampled) L1:353.497710 L4:0.136667 |
#           >> Test macro:694.842856 ± 694.427492 | micro:3.849909 ± 2.004519
# Epoch 12/200 | Train(sampled) L1:322.195953 L4:0.135331 |
#           >> Test macro:671.852555 ± 671.473478 | micro:3.703618 ± 1.938172
# Epoch 13/200 | Train(sampled) L1:323.061724 L4:0.134028 |
#           >> Test macro:649.378155 ± 648.984237 | micro:3.604077 ± 1.873360
# Epoch 14/200 | Train(sampled) L1:311.380549 L4:0.132935 |
#           >> Test macro:626.842297 ± 626.399011 | micro:3.536297 ± 1.808089
# Epoch 15/200 | Train(sampled) L1:308.329190 L4:0.133647 |
#           >> Test macro:605.116253 ± 604.712697 | micro:3.392839 ± 1.745502
# Epoch 16/200 | Train(sampled) L1:301.206020 L4:0.129383 |
#           >> Test macro:583.858778 ± 583.465784 | micro:3.275943 ± 1.684288
# Epoch 17/200 | Train(sampled) L1:297.868179 L4:0.133475 |
#           >> Test macro:563.271139 ± 562.871555 | micro:3.178439 ± 1.624828
# Epoch 18/200 | Train(sampled) L1:286.033650 L4:0.128371 |
#           >> Test macro:543.106757 ± 542.719990 | micro:3.067887 ± 1.566616
# Epoch 19/200 | Train(sampled) L1:273.797517 L4:0.125274 |
#           >> Test macro:524.152691 ± 523.780269 | micro:2.958197 ± 1.512048
# Epoch 20/200 | Train(sampled) L1:250.361934 L4:0.121206 |
#           >> Test macro:505.854934 ± 505.453239 | micro:2.894159 ± 1.459125
# Epoch 21/200 | Train(sampled) L1:248.811311 L4:0.119087 |
#           >> Test macro:487.571131 ± 487.191626 | micro:2.782202 ± 1.406402
# Epoch 22/200 | Train(sampled) L1:241.615415 L4:0.115548 |
#           >> Test macro:469.687563 ± 469.302135 | micro:2.698194 ± 1.354761
# Epoch 23/200 | Train(sampled) L1:228.983950 L4:0.112560 |
#           >> Test macro:452.255573 ± 451.877342 | micro:2.604646 ± 1.304572
# Epoch 24/200 | Train(sampled) L1:238.474011 L4:0.110530 |
#           >> Test macro:434.808438 ± 434.426330 | micro:2.520082 ± 1.254189
# Epoch 25/200 | Train(sampled) L1:208.703658 L4:0.105455 |
#           >> Test macro:418.037173 ± 417.649277 | micro:2.441862 ± 1.205847
# Epoch 26/200 | Train(sampled) L1:208.499321 L4:0.101440 |
#           >> Test macro:401.536654 ± 401.127981 | micro:2.378759 ± 1.158302
# Epoch 27/200 | Train(sampled) L1:198.623306 L4:0.097787 |
#           >> Test macro:385.285560 ± 384.778795 | micro:2.390609 ± 1.111048
# Epoch 28/200 | Train(sampled) L1:188.427403 L4:0.095606 |
#           >> Test macro:368.781934 ± 368.355844 | micro:2.230508 ± 1.063650
# Epoch 29/200 | Train(sampled) L1:182.165366 L4:0.091235 |
#           >> Test macro:352.411093 ± 352.022561 | micro:2.112619 ± 1.016776
# Epoch 30/200 | Train(sampled) L1:175.197343 L4:0.086807 |
#           >> Test macro:336.490866 ± 336.104553 | micro:2.031560 ± 0.970809
# Epoch 31/200 | Train(sampled) L1:165.408913 L4:0.084751 |
#           >> Test macro:320.651560 ± 320.201045 | micro:2.007576 ± 0.925119
# Epoch 32/200 | Train(sampled) L1:144.025058 L4:0.078302 |
#           >> Test macro:305.657533 ± 305.251210 | micro:1.894296 ± 0.881872
# Epoch 33/200 | Train(sampled) L1:148.707414 L4:0.072475 |
#           >> Test macro:290.217732 ± 289.837035 | micro:1.794619 ± 0.837291
# Epoch 34/200 | Train(sampled) L1:140.001555 L4:0.066848 |
#           >> Test macro:274.667374 ± 274.250765 | micro:1.748641 ± 0.792319
# Epoch 35/200 | Train(sampled) L1:130.538229 L4:0.063484 |
#           >> Test macro:259.583450 ± 259.167613 | micro:1.672141 ± 0.749070
# Epoch 36/200 | Train(sampled) L1:122.619986 L4:0.060690 |
#           >> Test macro:244.991168 ± 244.581719 | micro:1.593752 ± 0.707006
# Epoch 37/200 | Train(sampled) L1:119.942834 L4:0.058853 |
#           >> Test macro:230.256804 ± 229.878152 | micro:1.492972 ± 0.664568
# Epoch 38/200 | Train(sampled) L1:112.848838 L4:0.053322 |
#           >> Test macro:215.509786 ± 215.147593 | micro:1.405693 ± 0.621810
# Epoch 39/200 | Train(sampled) L1:107.596159 L4:0.050574 |
#           >> Test macro:201.452367 ± 201.042460 | micro:1.377612 ± 0.581552
# Epoch 40/200 | Train(sampled) L1:101.640746 L4:0.049916 |
#           >> Test macro:187.686747 ± 187.289974 | micro:1.296526 ± 0.542114
# Epoch 41/200 | Train(sampled) L1:89.038400 L4:0.046085 |
#           >> Test macro:174.445069 ± 174.042175 | micro:1.235636 ± 0.503409
# Epoch 42/200 | Train(sampled) L1:83.318037 L4:0.044049 |
#           >> Test macro:161.829539 ± 161.273063 | micro:1.306576 ± 0.469087
# Epoch 43/200 | Train(sampled) L1:81.147989 L4:0.045118 |
#           >> Test macro:149.065454 ± 148.680570 | micro:1.092594 ± 0.430843
# Epoch 44/200 | Train(sampled) L1:70.726326 L4:0.041205 |
#           >> Test macro:136.992344 ± 136.609446 | micro:1.029813 ± 0.395878
# Epoch 45/200 | Train(sampled) L1:67.242395 L4:0.040436 |
#           >> Test macro:125.346779 ± 124.929297 | micro:1.001327 ± 0.362544
# Epoch 46/200 | Train(sampled) L1:60.133153 L4:0.039420 |
#           >> Test macro:113.864356 ± 113.369636 | micro:1.015282 ± 0.330513
# Epoch 47/200 | Train(sampled) L1:54.714450 L4:0.038289 |
#           >> Test macro:103.406667 ± 102.959205 | micro:0.918132 ± 0.301194
# Epoch 48/200 | Train(sampled) L1:47.383355 L4:0.037385 |
#           >> Test macro:93.010107 ± 92.629857 | micro:0.808636 ± 0.269551
# Epoch 49/200 | Train(sampled) L1:42.834361 L4:0.038438 |
#           >> Test macro:83.349130 ± 82.947178 | micro:0.778149 ± 0.242398
# Epoch 50/200 | Train(sampled) L1:39.044360 L4:0.035488 |
#           >> Test macro:73.788198 ± 73.370872 | micro:0.744248 ± 0.215041
# Epoch 51/200 | Train(sampled) L1:35.148953 L4:0.035798 |
#           >> Test macro:64.913601 ± 64.541715 | micro:0.659788 ± 0.189255
# Epoch 52/200 | Train(sampled) L1:31.118763 L4:0.035506 |
#           >> Test macro:56.422966 ± 56.060236 | micro:0.609804 ± 0.164664
# Epoch 53/200 | Train(sampled) L1:26.333218 L4:0.034421 |
#           >> Test macro:48.832372 ± 48.447061 | micro:0.591597 ± 0.145125
# Epoch 54/200 | Train(sampled) L1:21.560433 L4:0.032019 |
#           >> Test macro:42.038374 ± 41.635057 | micro:0.572800 ± 0.124975
# Epoch 55/200 | Train(sampled) L1:18.315844 L4:0.030417 |
#           >> Test macro:35.600327 ± 35.228473 | micro:0.512861 ± 0.107145
# Epoch 56/200 | Train(sampled) L1:15.244544 L4:0.030545 |
#           >> Test macro:29.554562 ± 29.177585 | micro:0.487511 ± 0.091164
# Epoch 57/200 | Train(sampled) L1:13.129943 L4:0.031284 |
#           >> Test macro:24.081242 ± 23.599994 | micro:0.552921 ± 0.080731
# Epoch 58/200 | Train(sampled) L1:10.486602 L4:0.032673 |
#           >> Test macro:19.285799 ± 18.902154 | micro:0.442680 ± 0.064098
# Epoch 59/200 | Train(sampled) L1:8.361058 L4:0.031638 |
#           >> Test macro:14.746437 ± 14.349888 | micro:0.431261 ± 0.054928
# Epoch 60/200 | Train(sampled) L1:6.321095 L4:0.030408 |
#           >> Test macro:11.067928 ± 10.637286 | micro:0.444202 ± 0.046394
# Epoch 61/200 | Train(sampled) L1:4.625572 L4:0.030826 |
#           >> Test macro:7.981823 ± 7.554082 | micro:0.425602 ± 0.042930
# Epoch 62/200 | Train(sampled) L1:3.274774 L4:0.029698 |
#           >> Test macro:5.462845 ± 5.091413 | micro:0.364267 ± 0.034144
# Epoch 63/200 | Train(sampled) L1:2.224261 L4:0.029449 |
#           >> Test macro:3.547311 ± 3.127304 | micro:0.400502 ± 0.037729
# Epoch 64/200 | Train(sampled) L1:1.312350 L4:0.028139 |
#           >> Test macro:2.184420 ± 1.802514 | micro:0.360331 ± 0.038055
# Epoch 65/200 | Train(sampled) L1:0.786165 L4:0.027959 |
#           >> Test macro:1.247943 ± 0.880288 | micro:0.349563 ± 0.036187
# Epoch 66/200 | Train(sampled) L1:0.436145 L4:0.026073 |
#           >> Test macro:0.728971 ± 0.370084 | micro:0.360650 ± 0.033771
# Epoch 67/200 | Train(sampled) L1:0.259514 L4:0.024292 |
#           >> Test macro:0.459980 ± 0.178359 | micro:0.367036 ± 0.036666
# Epoch 68/200 | Train(sampled) L1:0.163959 L4:0.021531 |
#           >> Test macro:0.328894 ± 0.175913 | micro:0.355661 ± 0.033599
# Epoch 69/200 | Train(sampled) L1:0.120641 L4:0.022582 |
#           >> Test macro:0.299297 ± 0.223055 | micro:0.385418 ± 0.034347
# Epoch 70/200 | Train(sampled) L1:0.111751 L4:0.020083 |
#           >> Test macro:0.264828 ± 0.203932 | micro:0.353045 ± 0.033895
# Early stopping at epoch 70/200 (best test micro-MSE: 0.349563 @ epoch 65)
# TEST RESULTS | macro: 0.264828 ± 0.203932 | micro: 0.353045 ± 0.033895
#           >> per_group (weighted SE): {0: '0.668498 ± 0.076602 (n=777)', 1: '0.012474 ± 0.003462 (n=3)', 5: '0.113511 ± 0.006166 (n=1019)'}

# %%
res_odejump_encoder_diff_raw = odejump_encoder_diff_raw.train_cognite(
    df=df_scaled,
    feature_cols=list(df_scaled.columns[:-1]),
    static_features_cols=None,
    timestamp_col='index',
    states_col='states',
    batch_size=256,
    window_size=30,
    window_step=30,
    epochs = 200,
    lr=1e-4,
    validate=False,
    df_denoised=df_scaled_denoised,  # Passa o dataframe original sem denoising
)
res_odejump_encoder_diff_raw = [r for r in res_odejump_encoder_diff_raw if r is not None]  # remove None results
# Out:
# GRUPOS (total): {0: 3886, 1: 15, 5: 5093}
# GRUPOS (train): {0: 3109, 1: 12, 5: 4074}
# GRUPOS (test):  {0: 777, 1: 3, 5: 1019}
# Epoch 1/200 | Train(sampled) L1:0.093225 L4:0.017043 |
#           >> Test macro:0.265862 ± 0.211356 | micro:0.358476 ± 0.033073
# Epoch 2/200 | Train(sampled) L1:0.086157 L4:0.014766 |
#           >> Test macro:0.260410 ± 0.207606 | micro:0.351283 ± 0.035120
# Epoch 3/200 | Train(sampled) L1:0.081683 L4:0.012495 |
#           >> Test macro:0.272484 ± 0.217442 | micro:0.367047 ± 0.033874
# Epoch 4/200 | Train(sampled) L1:0.082016 L4:0.011981 |
#           >> Test macro:0.262781 ± 0.206318 | micro:0.353054 ± 0.031620
# Epoch 5/200 | Train(sampled) L1:0.080955 L4:0.012085 |
#           >> Test macro:0.260590 ± 0.204877 | micro:0.349704 ± 0.031806
# Epoch 6/200 | Train(sampled) L1:0.075712 L4:0.010435 |
#           >> Test macro:0.263755 ± 0.208928 | micro:0.354579 ± 0.031866
# Epoch 7/200 | Train(sampled) L1:0.077233 L4:0.010541 |
#           >> Test macro:0.267448 ± 0.213849 | micro:0.359798 ± 0.032003
# Epoch 8/200 | Train(sampled) L1:0.073184 L4:0.010115 |
#           >> Test macro:0.265980 ± 0.207170 | micro:0.353734 ± 0.030658
# Epoch 9/200 | Train(sampled) L1:0.077090 L4:0.009337 |
#           >> Test macro:0.277366 ± 0.214386 | micro:0.366951 ± 0.031773
# Epoch 10/200 | Train(sampled) L1:0.075051 L4:0.010162 |
#           >> Test macro:0.274298 ± 0.213706 | micro:0.364261 ± 0.032833
# Early stopping at epoch 10/200 (best test micro-MSE: 0.349704 @ epoch 5)
# TEST RESULTS | macro: 0.274298 ± 0.213706 | micro: 0.364261 ± 0.032833
#           >> per_group (weighted SE): {0: '0.698048 ± 0.073955 (n=777)', 1: '0.014070 ± 0.011265 (n=3)', 5: '0.110775 ± 0.005767 (n=1019)'}

# %%
res_odejump_encoder_diff_raw = odejump_encoder_diff_raw.train_cognite(
    df=df_scaled,
    feature_cols=list(df_scaled.columns[:-1]),
    static_features_cols=None,
    timestamp_col='index',
    states_col='states',
    batch_size=256,
    window_size=30,
    window_step=30,
    epochs = 100,
    validate=False,
    df_denoised=df_scaled_denoised,
)
res_odejump_encoder_diff_raw = [r for r in res_odejump_encoder_diff_raw if r is not None]  # remove None results
# Out:
# GRUPOS (total): {0: 3886, 1: 15, 5: 5093}
# GRUPOS (train): {0: 3109, 1: 12, 5: 4074}
# GRUPOS (test):  {0: 777, 1: 3, 5: 1019}
# Epoch 1/100 | Train(sampled) L1:0.042575 L4:0.000860 |
#           >> Test macro:0.258873 ± 0.197724 | micro:0.352538 ± 0.027772
# Epoch 2/100 | Train(sampled) L1:0.039183 L4:0.000915 |
#           >> Test macro:0.256817 ± 0.197845 | micro:0.349409 ± 0.027021
# Epoch 3/100 | Train(sampled) L1:0.038509 L4:0.000808 |
#           >> Test macro:0.261696 ± 0.202549 | micro:0.355752 ± 0.026723
# Epoch 4/100 | Train(sampled) L1:0.037441 L4:0.000714 |
#           >> Test macro:0.256803 ± 0.199755 | micro:0.348804 ± 0.027403
# Epoch 5/100 | Train(sampled) L1:0.035666 L4:0.000727 |
#           >> Test macro:0.254899 ± 0.197116 | micro:0.346487 ± 0.025783
# Epoch 6/100 | Train(sampled) L1:0.034666 L4:0.000770 |
#           >> Test macro:0.251825 ± 0.193326 | micro:0.342762 ± 0.024895
# Epoch 7/100 | Train(sampled) L1:0.037113 L4:0.000746 |
#           >> Test macro:0.259447 ± 0.199139 | micro:0.353063 ± 0.026342
# Epoch 8/100 | Train(sampled) L1:0.037707 L4:0.000759 |
#           >> Test macro:0.256592 ± 0.194548 | micro:0.349671 ± 0.025939
# Epoch 9/100 | Train(sampled) L1:0.035083 L4:0.000844 |
#           >> Test macro:0.268008 ± 0.196962 | micro:0.366974 ± 0.026591
# Epoch 10/100 | Train(sampled) L1:0.036768 L4:0.000824 |
#           >> Test macro:0.255836 ± 0.195787 | micro:0.347802 ± 0.024557
# Epoch 11/100 | Train(sampled) L1:0.034651 L4:0.000703 |
#           >> Test macro:0.259097 ± 0.198923 | micro:0.351764 ± 0.026671
# Early stopping at epoch 11/100 (best test macro-MSE: 0.251825 @ epoch 6)
# TEST RESULTS | macro: 0.259097 ± 0.198923 | micro: 0.351764 ± 0.026671
#           >> per_group (weighted SE): {0: '0.650533 ± 0.059551 (n=777)', 1: '0.001779 ± 0.001417 (n=3)', 5: '0.124979 ± 0.006129 (n=1019)'}

# %%
odejump_encoder_diff_raw = odejump_encoder_diff_raw.load(
    "ode_jump.pt",
    in_channels=11,
    hidden_dim=11*32,
    n_layers=6,
    denoised=True
    )
odejump_encoder_diff_raw.save("cognite_jumpode_attention_tsdiffusion_raw.pt")
# Out:
# /root/coppe/3Wve/lib/python3.12/site-packages/torch/nn/modules/transformer.py:382: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(

# %%
with open("cognite_jumpode_attention_tsdiffusion_raw_results.json", "w") as f:
    json.dump(res_odejump_encoder_diff_raw, f)

# %% [markdown]
# ### Comparação ODEJump com Attention (com e sem denoising)

# %%
import math


comp_attn_macro_mse = pd.DataFrame({
    'Com Denoise':[v['macro_mse'] for v in res_odejump],
    })
comp_attn_macro_mse.plot(kind='line',ylabel='MSE Macro',xlabel='Épocas', logy=True,figsize=(15,7), title='Macro MSE - ODEJump')
comp_attn_macro_mse = pd.DataFrame({
    'Sem Denoise':[v['macro_mse'] for v in res_odejump_encoder],
    })
comp_attn_macro_mse.plot(kind='line',ylabel='MSE Macro',xlabel='Épocas', logy=True,figsize=(15,7), title='Macro MSE - ODEJump com Attention (sem denoise)')
comp_attn_macro_mse = pd.DataFrame({
    'Com Denoise':[v['macro_mse'] for v in res_odejump_encoder_diff],
    })
comp_attn_macro_mse.plot(kind='line',ylabel='MSE Macro',xlabel='Épocas', logy=True,figsize=(15,7), title='Macro MSE - ODEJump com Attention (com denoise)')
# Out:
# <Axes: title={'center': 'Macro MSE - ODEJump com Attention (com denoise)'}, xlabel='Épocas', ylabel='MSE Macro'>

# %%
def find_best_epoch(results):
    for idx, r in enumerate(results):
        if idx == 0:
            best_result = r['macro_mse']
            best_epoch = idx
        else:
            if r['macro_mse'] < best_result:
                best_result = r['macro_mse']
                best_epoch = idx
    return best_epoch

# %%
d_best_epoch = {
    'odejump': find_best_epoch(res_odejump),
    'odejump_encoder': find_best_epoch(res_odejump_encoder),
    'odejump_encoder_diff_raw': find_best_epoch(res_odejump_encoder_diff_raw),
    'odejump_encoder_diff': find_best_epoch(res_odejump_encoder_diff),
}

# %%
print(res_odejump[d_best_epoch['odejump']])
print(res_odejump_encoder[d_best_epoch['odejump_encoder']])
print(res_odejump_encoder_diff_raw[d_best_epoch['odejump_encoder_diff_raw']])
print(res_odejump_encoder_diff[d_best_epoch['odejump_encoder_diff']])
# Out:
# {'macro_mse': 0.29108369623561153, 'macro_se': 0.16377020717263382, 'micro_mse': 0.33147245136615927, 'micro_se': 0.025534026426697356, 'per_group_mse': {0: 0.6182173627442985, 1: 0.14164893464608627, 5: 0.11338479131644975}, 'per_group_se_w': {0: 0.057029372680673256, 1: 0.0886054161485585, 5: 0.005723954133484053}, 'per_group_se_unw': {0: 0.05706610658181269, 1: 0.10851902988957154, 5: 0.005726764814783761}, 'per_group_counts': {0: 777, 1: 3, 5: 1019}, 'per_group_sum_nobs': {0: 8547.0, 1: 33.0, 5: 11209.0}}
# {'macro_mse': 0.3714756071068684, 'macro_se': 0.1476047866757199, 'micro_mse': 0.3376810854863067, 'micro_se': 0.03587437222329996, 'per_group_mse': {0: 0.6277317200878133, 1: 0.3702771475143505, 5: 0.11641795371844135}, 'per_group_se_w': {0: 0.08157545905382158, 1: 0.2659513768544169, 5: 0.0055260691661953}, 'per_group_se_unw': {0: 0.0816280036311727, 1: 0.3257225935803896, 5: 0.005528782678176159}, 'per_group_counts': {0: 777, 1: 3, 5: 1019}, 'per_group_sum_nobs': {0: 8547.0, 1: 33.0, 5: 11209.0}}
# {'macro_mse': 0.5250685625013561, 'macro_se': 0.37669722135471645, 'micro_mse': 0.7104470248846763, 'micro_se': 0.05710114426982735, 'per_group_mse': {0: 1.2620902745848834, 1: 0.02127416471414494, 5: 0.29184124820504015}, 'per_group_se_w': {0: 0.1286805734771411, 1: 0.007917947511295573, 5: 0.01157087228312048}, 'per_group_se_unw': {0: 0.12876345951507784, 1: 0.009697465699276254, 5: 0.01157655404389182}, 'per_group_counts': {0: 777, 1: 3, 5: 1019}, 'per_group_sum_nobs': {0: 8547.0, 1: 33.0, 5: 11209.0}}
# {'macro_mse': 0.004218527399587322, 'macro_se': 0.0035964248126936645, 'micro_mse': 0.005153214606414326, 'micro_se': 0.002070807528703284, 'per_group_mse': {0: 0.01140660388118474, 1: 0.0008513848861735878, 5: 0.0003975934314036391}, 'per_group_se_w': {0: 0.004785272468839167, 1: 0.00012898949563749335, 5: 1.703973340058558e-05}, 'per_group_se_unw': {0: 0.004788354771203891, 1: 0.00015797921849246936, 5: 1.7048100546029158e-05}, 'per_group_counts': {0: 777, 1: 3, 5: 1019}, 'per_group_sum_nobs': {0: 8547.0, 1: 33.0, 5: 11209.0}}

# %%
print(res_odejump_encoder_diff_raw[find_best_epoch(res_odejump_encoder_diff_raw)])
# Out:
# {'macro_mse': 0.2609861679917503,
#  'macro_se': 0.16053366047345977,
#  'micro_mse': 0.32370800335179345,
#  'micro_se': 0.025023513909568373,
#  'per_group_mse': {0: 0.5804896476667981,
#   1: 0.07382433345033364,
#   5: 0.12864452285811906},
#  'per_group_se_w': {0: 0.05611792990087821,
#   1: 0.038484742569828166,
#   5: 0.005811944859152723},
#  'per_group_se_unw': {0: 0.05615407673910984,
#   1: 0.047133991527108336,
#   5: 0.005814798751480512},
#  'per_group_counts': {0: 777, 1: 3, 5: 1019},
#  'per_group_sum_nobs': {0: 8547.0, 1: 33.0, 5: 11209.0}}

# %%
res_odejump_encoder_diff_raw[find_best_epoch(res_odejump_encoder_diff_raw)]
# Out:
# {'macro_mse': 0.34340559900074613,
#  'macro_se': 0.1352644117266638,
#  'micro_mse': 0.3082470318480974,
#  'micro_se': 0.02688532275920712,
#  'per_group_mse': {0: 0.5739312950522579,
#   1: 0.3507511146140821,
#   5: 0.10553438733589844},
#  'per_group_se_w': {0: 0.06057583033251706,
#   1: 0.16420573590311854,
#   5: 0.005101812271905905},
#  'per_group_se_unw': {0: 0.060614848574457494,
#   1: 0.2011101374287671,
#   5: 0.005104317459836988},
#  'per_group_counts': {0: 777, 1: 3, 5: 1019},
#  'per_group_sum_nobs': {0: 8547.0, 1: 33.0, 5: 11209.0}}

# %% [markdown]
# ### 17 Validação

# %%
importlib.reload(sys.modules['tsdiffusion_transformed.ode_jump'])
importlib.reload(sys.modules['tsdiffusion_transformed.ode_jump_encoder'])
from tsdiffusion_transformed.ode_jump_encoder import ODEJumpEncoder

# %%
hdim_val={}
for hidden_dim in [11*8, 11*16, 11*32]:
    model = ODEJumpEncoder(
        in_channels=11,
        hidden_dim=hidden_dim,
    )
    gen = model.train_cognite(
        df=df_scaled_denoised,
        feature_cols=list(df_scaled.columns[:-1]),
        static_features_cols=None,
        timestamp_col='index',
        states_col='states',
        batch_size=256,
        window_size=30,
        window_step=30,
        epochs = 100,
        validate=True,
    )
    l = [r for r in gen if r is not None]  # remove None results
    best_epoch = find_best_epoch(l)
    hdim_val[hidden_dim] = l[best_epoch]
# Out:
# /root/coppe/3Wve/lib/python3.12/site-packages/torch/nn/modules/transformer.py:382: UserWarning:
#
# enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
# GRUPOS (total): {0: 3886, 1: 15, 5: 5093}
# GRUPOS (train): {0: 2332, 1: 9, 5: 3056}
# GRUPOS (valid): {0: 777, 1: 3, 5: 1019}
# GRUPOS (test):  {0: 777, 1: 3, 5: 1018}
# Epoch 1/100 | Train(sampled) L1:450.523796 L4:0.453677 | Val macro:667.423762 ± 665.248905 | Val micro:5.455025 ± 2.353171
#           >> Test macro:999.797874 ± 997.623102 | micro:7.119610 ± 2.881364
# Epoch 2/100 | Train(sampled) L1:457.604351 L4:0.237457 | Val macro:657.123530 ± 655.811920 | Val micro:4.511871 ± 2.320118
#           >> Test macro:985.049309 ± 983.751567 | micro:6.141090 ± 2.841690
# Epoch 3/100 | Train(sampled) L1:461.016400 L4:0.182397 | Val macro:647.715644 ± 646.468949 | Val micro:4.380104 ± 2.287480
#           >> Test macro:971.215099 ± 969.990972 | micro:5.979262 ± 2.802122
# Epoch 4/100 | Train(sampled) L1:456.817205 L4:0.167535 | Val macro:639.510423 ± 638.266242 | Val micro:4.335668 ± 2.258557
#           >> Test macro:958.878665 ± 957.657358 | micro:5.913834 ± 2.766531
# Epoch 5/100 | Train(sampled) L1:417.623011 L4:0.159669 | Val macro:631.717717 ± 630.488504 | Val micro:4.291008 ± 2.230981
#           >> Test macro:947.003320 ± 945.793345 | micro:5.852068 ± 2.732233
# Epoch 6/100 | Train(sampled) L1:437.749902 L4:0.154912 | Val macro:624.617626 ± 623.378965 | Val micro:4.255216 ± 2.206038
#           >> Test macro:936.319995 ± 935.104428 | micro:5.794723 ± 2.701451
# Epoch 7/100 | Train(sampled) L1:412.828519 L4:0.156750 | Val macro:617.497339 ± 616.276087 | Val micro:4.216874 ± 2.180889
#           >> Test macro:925.742267 ± 924.540371 | micro:5.742681 ± 2.670845
# Epoch 8/100 | Train(sampled) L1:427.996740 L4:0.157037 | Val macro:610.285648 ± 609.040330 | Val micro:4.238886 ± 2.154969
#           >> Test macro:914.905189 ± 913.665895 | micro:5.758578 ± 2.639176
# Epoch 9/100 | Train(sampled) L1:412.296968 L4:0.151720 | Val macro:602.986943 ± 601.900242 | Val micro:4.028086 ± 2.129669
#           >> Test macro:903.987336 ± 902.907782 | micro:5.527609 ± 2.608207
# Epoch 10/100 | Train(sampled) L1:409.520694 L4:0.152063 | Val macro:596.138579 ± 595.143458 | Val micro:3.898590 ± 2.105475
#           >> Test macro:893.700947 ± 892.709662 | micro:5.382770 ± 2.578731
# Epoch 11/100 | Train(sampled) L1:396.913447 L4:0.149928 | Val macro:589.402675 ± 588.410831 | Val micro:3.849847 ± 2.081947
#           >> Test macro:883.631024 ± 882.641159 | micro:5.318558 ± 2.549755
# Epoch 12/100 | Train(sampled) L1:403.015008 L4:0.147555 | Val macro:582.625284 ± 581.685527 | Val micro:3.773448 ± 2.057915
#           >> Test macro:873.413353 ± 872.474559 | micro:5.225535 ± 2.520311
# Epoch 13/100 | Train(sampled) L1:409.265522 L4:0.144761 | Val macro:575.472572 ± 574.517765 | Val micro:3.747455 ± 2.032739
#           >> Test macro:862.722140 ± 861.767827 | micro:5.182209 ± 2.489464
# Epoch 14/100 | Train(sampled) L1:378.269763 L4:0.143303 | Val macro:568.817519 ± 567.705199 | Val micro:3.901822 ± 2.007773
#           >> Test macro:852.385319 ± 851.283522 | micro:5.307992 ± 2.458886
# Epoch 15/100 | Train(sampled) L1:378.919656 L4:0.140831 | Val macro:561.624527 ± 560.722765 | Val micro:3.638012 ± 1.983789
#           >> Test macro:842.015032 ± 841.112956 | micro:5.039130 ± 2.429693
# Epoch 16/100 | Train(sampled) L1:399.288270 L4:0.140302 | Val macro:554.598628 ± 553.702476 | Val micro:3.594701 ± 1.959029
#           >> Test macro:831.464914 ± 830.569277 | micro:4.977270 ± 2.399293
# Epoch 17/100 | Train(sampled) L1:352.376021 L4:0.137788 | Val macro:548.051682 ± 547.150367 | Val micro:3.575335 ± 1.935685
#           >> Test macro:821.564538 ± 820.666380 | micro:4.938216 ± 2.370594
# Epoch 18/100 | Train(sampled) L1:374.128338 L4:0.136209 | Val macro:541.285795 ± 540.304345 | Val micro:3.599653 ± 1.911968
#           >> Test macro:811.538364 ± 810.548323 | micro:4.957244 ± 2.341648
# Epoch 19/100 | Train(sampled) L1:368.754167 L4:0.134441 | Val macro:534.399446 ± 533.519149 | Val micro:3.478534 ± 1.887741
#           >> Test macro:801.181647 ± 800.300163 | micro:4.812000 ± 2.311893
# Epoch 20/100 | Train(sampled) L1:370.007871 L4:0.131722 | Val macro:527.713232 ± 526.816376 | Val micro:3.458231 ± 1.864100
#           >> Test macro:791.144641 ± 790.245135 | micro:4.776505 ± 2.282918
# Epoch 21/100 | Train(sampled) L1:351.575007 L4:0.129868 | Val macro:521.029955 ± 520.121593 | Val micro:3.434343 ± 1.840536
#           >> Test macro:781.141942 ± 780.232166 | micro:4.734853 ± 2.254037
# Epoch 22/100 | Train(sampled) L1:340.433946 L4:0.127793 | Val macro:514.415970 ± 513.543429 | Val micro:3.371543 ± 1.817145
#           >> Test macro:771.255391 ± 770.381131 | micro:4.655774 ± 2.225510
# Epoch 23/100 | Train(sampled) L1:349.334819 L4:0.124716 | Val macro:507.974704 ± 507.064891 | Val micro:3.370223 ± 1.794395
#           >> Test macro:761.641779 ± 760.728965 | micro:4.639819 ± 2.197731
# Epoch 24/100 | Train(sampled) L1:359.599538 L4:0.122796 | Val macro:501.363149 ± 500.496893 | Val micro:3.300380 ± 1.771080
#           >> Test macro:751.737549 ± 750.872208 | micro:4.550062 ± 2.169183
# Epoch 25/100 | Train(sampled) L1:329.236156 L4:0.120328 | Val macro:495.082577 ± 494.177841 | Val micro:3.301564 ± 1.748871
#           >> Test macro:742.366534 ± 741.461699 | micro:4.536715 ± 2.142094
# Epoch 26/100 | Train(sampled) L1:324.043839 L4:0.118385 | Val macro:488.965752 ± 488.108565 | Val micro:3.232916 ± 1.727186
#           >> Test macro:733.026487 ± 732.170088 | micro:4.450513 ± 2.115100
# Epoch 27/100 | Train(sampled) L1:331.010302 L4:0.115472 | Val macro:482.630045 ± 481.775901 | Val micro:3.195404 ± 1.704926
#           >> Test macro:723.630073 ± 722.776859 | micro:4.397792 ± 2.088071
# Epoch 28/100 | Train(sampled) L1:328.386870 L4:0.112765 | Val macro:476.474664 ± 475.590230 | Val micro:3.202689 ± 1.682902
#           >> Test macro:714.260523 ± 713.382490 | micro:4.383060 ± 2.060848
# Epoch 29/100 | Train(sampled) L1:326.746626 L4:0.110302 | Val macro:470.055336 ± 469.197514 | Val micro:3.141347 ± 1.660384
#           >> Test macro:704.748386 ± 703.896169 | micro:4.307424 ± 2.033461
# Epoch 30/100 | Train(sampled) L1:305.258440 L4:0.108319 | Val macro:463.977826 ± 463.084718 | Val micro:3.135812 ± 1.639036
#           >> Test macro:695.686953 ± 694.794833 | micro:4.292047 ± 2.007390
# Epoch 31/100 | Train(sampled) L1:301.889582 L4:0.105149 | Val macro:458.130476 ± 457.288444 | Val micro:3.062317 ± 1.618363
#           >> Test macro:686.946996 ± 686.105201 | micro:4.204054 ± 1.982142
# Epoch 32/100 | Train(sampled) L1:322.884611 L4:0.101333 | Val macro:451.912666 ± 451.068767 | Val micro:3.033308 ± 1.596409
#           >> Test macro:677.606203 ± 676.762428 | micro:4.159685 ± 1.955246
# Epoch 33/100 | Train(sampled) L1:315.634159 L4:0.099569 | Val macro:445.790702 ± 444.935729 | Val micro:3.011703 ± 1.574826
#           >> Test macro:668.404256 ± 667.550048 | micro:4.122421 ± 1.928689
# Epoch 34/100 | Train(sampled) L1:310.227949 L4:0.097018 | Val macro:439.781742 ± 438.934265 | Val micro:2.974727 ± 1.553659
#           >> Test macro:659.488269 ± 658.645203 | micro:4.067566 ± 1.903002
# Epoch 35/100 | Train(sampled) L1:304.342249 L4:0.094646 | Val macro:433.773828 ± 432.916888 | Val micro:2.951215 ± 1.532447
#           >> Test macro:650.496829 ± 649.641878 | micro:4.031146 ± 1.877056
# Epoch 36/100 | Train(sampled) L1:292.908974 L4:0.092163 | Val macro:428.058964 ± 427.187772 | Val micro:2.938149 ± 1.512225
#           >> Test macro:641.927834 ± 641.062735 | micro:4.000565 ± 1.852280
# Epoch 37/100 | Train(sampled) L1:288.764649 L4:0.088419 | Val macro:422.316935 ± 421.494834 | Val micro:2.866876 ± 1.491916
#           >> Test macro:633.168963 ± 632.352376 | micro:3.913795 ± 1.826996
# Epoch 38/100 | Train(sampled) L1:281.747592 L4:0.085786 | Val macro:416.882183 ± 416.056353 | Val micro:2.842278 ± 1.472718
#           >> Test macro:624.963071 ± 624.145223 | micro:3.872910 ± 1.803346
# Epoch 39/100 | Train(sampled) L1:281.200874 L4:0.082056 | Val macro:411.261249 ± 410.447325 | Val micro:2.801333 ± 1.452867
#           >> Test macro:616.574393 ± 615.765820 | micro:3.820483 ± 1.779150
# Epoch 40/100 | Train(sampled) L1:278.576379 L4:0.078825 | Val macro:405.603433 ± 404.772843 | Val micro:2.787329 ± 1.432975
#           >> Test macro:608.108014 ± 607.279939 | micro:3.795533 ± 1.754742
# Epoch 41/100 | Train(sampled) L1:270.066750 L4:0.075290 | Val macro:400.038322 ± 399.189415 | Val micro:2.776922 ± 1.413266
#           >> Test macro:599.783766 ± 598.936858 | micro:3.771724 ± 1.730677
# Epoch 42/100 | Train(sampled) L1:262.937509 L4:0.072981 | Val macro:394.587740 ± 393.772455 | Val micro:2.720350 ± 1.394032
#           >> Test macro:591.551031 ± 590.743764 | micro:3.695624 ± 1.706901
# Epoch 43/100 | Train(sampled) L1:269.527514 L4:0.068957 | Val macro:389.308070 ± 388.480304 | Val micro:2.707911 ± 1.375163
#           >> Test macro:583.475764 ± 582.657788 | micro:3.666721 ± 1.683511
# Epoch 44/100 | Train(sampled) L1:270.293142 L4:0.065380 | Val macro:383.925584 ± 383.116548 | Val micro:2.660416 ± 1.356327
#           >> Test macro:575.444463 ± 574.638495 | micro:3.612501 ± 1.660417
# Epoch 45/100 | Train(sampled) L1:267.022337 L4:0.061248 | Val macro:378.502419 ± 377.659254 | Val micro:2.663420 ± 1.337316
#           >> Test macro:567.309924 ± 566.474268 | micro:3.598439 ± 1.636989
# Epoch 46/100 | Train(sampled) L1:261.347102 L4:0.057572 | Val macro:373.285949 ± 372.465715 | Val micro:2.618739 ± 1.318845
#           >> Test macro:559.515801 ± 558.710986 | micro:3.533342 ± 1.614477
# Epoch 47/100 | Train(sampled) L1:243.865307 L4:0.053711 | Val macro:368.278144 ± 367.415629 | Val micro:2.638800 ± 1.300736
#           >> Test macro:551.856149 ± 551.006391 | micro:3.542086 ± 1.592142
# Epoch 48/100 | Train(sampled) L1:245.054556 L4:0.051496 | Val macro:363.101383 ± 362.264216 | Val micro:2.583248 ± 1.282800
#           >> Test macro:544.155605 ± 543.322021 | micro:3.482938 ± 1.570096
# Epoch 49/100 | Train(sampled) L1:250.582126 L4:0.046902 | Val macro:357.854028 ± 357.045582 | Val micro:2.529177 ± 1.264343
#           >> Test macro:536.311751 ± 535.511881 | micro:3.411004 ± 1.547497
# Epoch 50/100 | Train(sampled) L1:224.741514 L4:0.041843 | Val macro:352.963831 ± 352.131289 | Val micro:2.529051 ± 1.247040
#           >> Test macro:529.057646 ± 528.227299 | micro:3.405011 ± 1.526534
# Epoch 51/100 | Train(sampled) L1:242.568746 L4:0.037406 | Val macro:348.191182 ± 347.354238 | Val micro:2.509332 ± 1.230095
#           >> Test macro:521.767039 ± 520.934927 | micro:3.369626 ± 1.505487
# Epoch 52/100 | Train(sampled) L1:232.031292 L4:0.034510 | Val macro:343.345162 ± 342.511111 | Val micro:2.483640 ± 1.213045
#           >> Test macro:514.608989 ± 513.774663 | micro:3.337350 ± 1.484868
# Epoch 53/100 | Train(sampled) L1:224.863992 L4:0.029696 | Val macro:338.632041 ± 337.695980 | Val micro:2.552799 ± 1.196453
#           >> Test macro:507.549864 ± 506.619498 | micro:3.390398 ± 1.464437
# Epoch 54/100 | Train(sampled) L1:228.615633 L4:0.027717 | Val macro:333.738005 ± 332.918632 | Val micro:2.416964 ± 1.179206
#           >> Test macro:500.217718 ± 499.400916 | micro:3.244134 ± 1.443407
# Epoch 55/100 | Train(sampled) L1:231.897188 L4:0.023967 | Val macro:328.765746 ± 327.960304 | Val micro:2.382921 ± 1.161587
#           >> Test macro:492.824777 ± 492.028497 | micro:3.191689 ± 1.422081
# Epoch 56/100 | Train(sampled) L1:217.122210 L4:0.020428 | Val macro:324.070779 ± 323.231186 | Val micro:2.387551 ± 1.145187
#           >> Test macro:485.826957 ± 484.990699 | micro:3.190717 ± 1.401956
# Epoch 57/100 | Train(sampled) L1:221.136556 L4:0.018458 | Val macro:319.419097 ± 318.596080 | Val micro:2.355070 ± 1.128467
#           >> Test macro:478.816705 ± 477.991504 | micro:3.150727 ± 1.381595
# Epoch 58/100 | Train(sampled) L1:199.758061 L4:0.016645 | Val macro:314.957376 ± 314.140551 | Val micro:2.323615 ± 1.112852
#           >> Test macro:472.185558 ± 471.365858 | micro:3.109162 ± 1.362524
# Epoch 59/100 | Train(sampled) L1:203.385697 L4:0.014164 | Val macro:310.426903 ± 309.606503 | Val micro:2.305326 ± 1.096685
#           >> Test macro:465.458755 ± 464.639222 | micro:3.076146 ± 1.342976
# Epoch 60/100 | Train(sampled) L1:200.152508 L4:0.012579 | Val macro:305.953777 ± 305.150080 | Val micro:2.266742 ± 1.081128
#           >> Test macro:458.768635 ± 457.969943 | micro:3.023086 ± 1.323837
# Epoch 61/100 | Train(sampled) L1:203.676828 L4:0.011208 | Val macro:301.323798 ± 300.484164 | Val micro:2.279562 ± 1.064504
#           >> Test macro:451.697676 ± 450.859755 | micro:3.026326 ± 1.303305
# Epoch 62/100 | Train(sampled) L1:195.023284 L4:0.011290 | Val macro:296.820609 ± 295.992406 | Val micro:2.245867 ± 1.048608
#           >> Test macro:444.998422 ± 444.176696 | micro:2.977402 ± 1.283971
# Epoch 63/100 | Train(sampled) L1:207.758445 L4:0.010422 | Val macro:292.200580 ± 291.389379 | Val micro:2.205133 ± 1.032321
#           >> Test macro:438.139386 ± 437.324571 | micro:2.934360 ± 1.264143
# Epoch 64/100 | Train(sampled) L1:185.869949 L4:0.009830 | Val macro:287.711644 ± 286.876619 | Val micro:2.206295 ± 1.016545
#           >> Test macro:431.301565 ± 430.459688 | micro:2.927188 ± 1.244457
# Epoch 65/100 | Train(sampled) L1:188.514849 L4:0.008372 | Val macro:283.258521 ± 282.459740 | Val micro:2.150326 ± 1.000900
#           >> Test macro:424.591978 ± 423.798892 | micro:2.848412 ± 1.225183
# Epoch 66/100 | Train(sampled) L1:175.744964 L4:0.007268 | Val macro:278.959961 ± 278.143395 | Val micro:2.141819 ± 0.985916
#           >> Test macro:418.167661 ± 417.356044 | micro:2.830369 ± 1.206764
# Epoch 67/100 | Train(sampled) L1:179.465060 L4:0.007318 | Val macro:274.610958 ± 273.789150 | Val micro:2.125178 ± 0.970415
#           >> Test macro:411.644037 ± 410.830498 | micro:2.799277 ± 1.187909
# Epoch 68/100 | Train(sampled) L1:179.308830 L4:0.006510 | Val macro:270.227592 ± 269.377444 | Val micro:2.135159 ± 0.954537
#           >> Test macro:405.040371 ± 404.199690 | micro:2.796556 ± 1.168635
# Epoch 69/100 | Train(sampled) L1:176.637047 L4:0.006551 | Val macro:265.718350 ± 264.854452 | Val micro:2.124729 ± 0.938552
#           >> Test macro:398.309579 ± 397.449223 | micro:2.780493 ± 1.149198
# Epoch 70/100 | Train(sampled) L1:187.899882 L4:0.006514 | Val macro:261.026936 ± 260.225670 | Val micro:2.039473 ± 0.922414
#           >> Test macro:391.266009 ± 390.462029 | micro:2.689277 ± 1.129101
# Epoch 71/100 | Train(sampled) L1:179.255557 L4:0.005624 | Val macro:256.735896 ± 255.873192 | Val micro:2.080523 ± 0.906935
#           >> Test macro:384.707896 ± 383.850470 | micro:2.711770 ± 1.109954
# Epoch 72/100 | Train(sampled) L1:172.774277 L4:0.006659 | Val macro:252.200935 ± 251.399047 | Val micro:1.995287 ± 0.891434
#           >> Test macro:378.056236 ± 377.261193 | micro:2.615095 ± 1.091036
# Epoch 73/100 | Train(sampled) L1:169.292346 L4:0.005205 | Val macro:247.946970 ± 247.121749 | Val micro:1.993004 ± 0.876592
#           >> Test macro:371.688561 ± 370.866509 | micro:2.605700 ± 1.072841
# Epoch 74/100 | Train(sampled) L1:160.064959 L4:0.004427 | Val macro:243.611450 ± 242.809114 | Val micro:1.954633 ± 0.860894
#           >> Test macro:365.225145 ± 364.431176 | micro:2.551462 ± 1.053875
# Epoch 75/100 | Train(sampled) L1:154.351925 L4:0.004462 | Val macro:239.303434 ± 238.491118 | Val micro:1.941777 ± 0.845887
#           >> Test macro:358.664390 ± 357.865617 | micro:2.522970 ± 1.035083
# Epoch 76/100 | Train(sampled) L1:155.289281 L4:0.004062 | Val macro:234.999889 ± 234.206969 | Val micro:1.902918 ± 0.830585
#           >> Test macro:352.265703 ± 351.477854 | micro:2.480638 ± 1.016582
# Epoch 77/100 | Train(sampled) L1:146.761126 L4:0.004110 | Val macro:230.737111 ± 229.896896 | Val micro:1.920473 ± 0.815894
#           >> Test macro:345.904263 ± 345.078166 | micro:2.480661 ± 0.998337
# Epoch 78/100 | Train(sampled) L1:149.978466 L4:0.003753 | Val macro:226.375928 ± 225.559988 | Val micro:1.883247 ± 0.800100
#           >> Test macro:339.399688 ± 338.591229 | micro:2.438213 ± 0.979351
# Epoch 79/100 | Train(sampled) L1:147.305756 L4:0.003479 | Val macro:222.064902 ± 221.269526 | Val micro:1.838626 ± 0.785202
#           >> Test macro:332.885407 ± 332.107093 | micro:2.374012 ± 0.960834
# Epoch 80/100 | Train(sampled) L1:147.223109 L4:0.003042 | Val macro:217.596486 ± 216.786550 | Val micro:1.829549 ± 0.769340
#           >> Test macro:326.193069 ± 325.395934 | micro:2.357724 ± 0.941371
# Epoch 81/100 | Train(sampled) L1:145.685874 L4:0.003053 | Val macro:213.266066 ± 212.468681 | Val micro:1.795729 ± 0.754219
#           >> Test macro:319.650457 ± 318.869715 | micro:2.309178 ± 0.922602
# Epoch 82/100 | Train(sampled) L1:145.365952 L4:0.003286 | Val macro:208.952560 ± 208.137178 | Val micro:1.791877 ± 0.738923
#           >> Test macro:313.245384 ± 312.450434 | micro:2.291485 ± 0.904090
# Epoch 83/100 | Train(sampled) L1:141.244225 L4:0.002990 | Val macro:204.676318 ± 203.873600 | Val micro:1.758653 ± 0.723798
#           >> Test macro:306.811731 ± 306.022911 | micro:2.252924 ± 0.885614
# Epoch 84/100 | Train(sampled) L1:145.808496 L4:0.002742 | Val macro:200.344560 ± 199.536406 | Val micro:1.745431 ± 0.708302
#           >> Test macro:300.263280 ± 299.471871 | micro:2.226136 ± 0.866618
# Epoch 85/100 | Train(sampled) L1:131.681865 L4:0.002782 | Val macro:196.123533 ± 195.268975 | Val micro:1.764495 ± 0.693827
#           >> Test macro:293.980609 ± 293.134734 | micro:2.242857 ± 0.848741
# Epoch 86/100 | Train(sampled) L1:128.841330 L4:0.002428 | Val macro:191.963167 ± 191.139237 | Val micro:1.715592 ± 0.678928
#           >> Test macro:287.690760 ± 286.886568 | micro:2.172791 ± 0.830533
# Epoch 87/100 | Train(sampled) L1:124.491661 L4:0.003264 | Val macro:187.823686 ± 187.010586 | Val micro:1.685303 ± 0.664535
#           >> Test macro:281.430423 ± 280.638079 | micro:2.131138 ± 0.812498
# Epoch 88/100 | Train(sampled) L1:121.480111 L4:0.002450 | Val macro:183.764493 ± 182.937198 | Val micro:1.676365 ± 0.650457
#           >> Test macro:275.450959 ± 274.644040 | micro:2.113630 ± 0.795343
# Epoch 89/100 | Train(sampled) L1:126.935924 L4:0.002406 | Val macro:179.686615 ± 178.879142 | Val micro:1.638583 ± 0.636041
#           >> Test macro:269.238401 ± 268.454963 | micro:2.061131 ± 0.777607
# Epoch 90/100 | Train(sampled) L1:116.309664 L4:0.001938 | Val macro:175.582386 ± 174.760455 | Val micro:1.631316 ± 0.620958
#           >> Test macro:263.126651 ± 262.317125 | micro:2.053728 ± 0.759707
# Epoch 91/100 | Train(sampled) L1:115.464736 L4:0.002512 | Val macro:171.652498 ± 170.857153 | Val micro:1.588642 ± 0.607441
#           >> Test macro:257.179314 ± 256.399281 | micro:1.998461 ± 0.742822
# Epoch 92/100 | Train(sampled) L1:114.773821 L4:0.008336 | Val macro:167.484972 ± 166.673795 | Val micro:1.580004 ± 0.593053
#           >> Test macro:251.053346 ± 250.258065 | micro:1.979727 ± 0.724912
# Epoch 93/100 | Train(sampled) L1:118.138021 L4:0.003851 | Val macro:163.409679 ± 162.620763 | Val micro:1.539400 ± 0.578347
#           >> Test macro:244.911429 ± 244.130774 | micro:1.935240 ± 0.707452
# Epoch 94/100 | Train(sampled) L1:107.074384 L4:0.002211 | Val macro:159.457970 ± 158.662263 | Val micro:1.526752 ± 0.564531
#           >> Test macro:238.893637 ± 238.111193 | micro:1.908007 ± 0.690232
# Epoch 95/100 | Train(sampled) L1:107.185021 L4:0.001986 | Val macro:155.505410 ± 154.709508 | Val micro:1.507104 ± 0.551015
#           >> Test macro:232.936804 ± 232.157755 | micro:1.875380 ± 0.673123
# Epoch 96/100 | Train(sampled) L1:99.901786 L4:0.001858 | Val macro:151.717423 ± 150.917979 | Val micro:1.490730 ± 0.537642
#           >> Test macro:227.259799 ± 226.478933 | micro:1.847963 ± 0.656740
# Epoch 97/100 | Train(sampled) L1:98.949990 L4:0.001917 | Val macro:147.826585 ± 147.030691 | Val micro:1.470181 ± 0.523717
#           >> Test macro:221.428162 ± 220.646559 | micro:1.821304 ± 0.639941
# Epoch 98/100 | Train(sampled) L1:101.233173 L4:0.002046 | Val macro:143.895420 ± 143.090588 | Val micro:1.455961 ± 0.510131
#           >> Test macro:215.575355 ± 214.782747 | micro:1.799733 ± 0.623286
# Epoch 99/100 | Train(sampled) L1:95.878541 L4:0.002039 | Val macro:140.106225 ± 139.284153 | Val micro:1.458333 ± 0.496819
#           >> Test macro:209.760617 ± 208.951012 | micro:1.791285 ± 0.606749
# Epoch 100/100 | Train(sampled) L1:88.098895 L4:0.001831 | Val macro:136.370593 ± 135.541259 | Val micro:1.441192 ± 0.483931
#           >> Test macro:204.289083 ± 203.480588 | micro:1.759255 ± 0.590695
# TEST RESULTS | macro: 204.289083 ± 203.480588 | micro: 1.759255 ± 0.590695
#           >> per_group (weighted SE): {0: '1.315907 ± 0.135380 (n=777)', 1: '611.249837 ± 2.118719 (n=3)', 5: '0.301503 ± 0.011305 (n=1018)'}
# GRUPOS (total): {0: 3886, 1: 15, 5: 5093}
# GRUPOS (train): {0: 2332, 1: 9, 5: 3056}
# GRUPOS (valid): {0: 777, 1: 3, 5: 1019}
# GRUPOS (test):  {0: 777, 1: 3, 5: 1018}
# /root/coppe/3Wve/lib/python3.12/site-packages/torch/nn/modules/transformer.py:382: UserWarning:
#
# enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
# Epoch 1/100 | Train(sampled) L1:449.205015 L4:0.485149 | Val macro:645.380570 ± 643.988582 | Val micro:4.520716 ± 2.278525
#           >> Test macro:967.496187 ± 966.125272 | micro:6.114355 ± 2.790823
# Epoch 2/100 | Train(sampled) L1:423.840919 L4:0.208729 | Val macro:627.665136 ± 626.424789 | Val micro:4.282333 ± 2.216565
#           >> Test macro:940.907209 ± 939.686837 | micro:5.832621 ± 2.714581
# Epoch 3/100 | Train(sampled) L1:443.843162 L4:0.158717 | Val macro:612.894869 ± 611.642730 | Val micro:4.211920 ± 2.164554
#           >> Test macro:918.733995 ± 917.504345 | micro:5.722752 ± 2.650634
# Epoch 4/100 | Train(sampled) L1:431.160371 L4:0.147410 | Val macro:599.036827 ± 597.786968 | Val micro:4.153767 ± 2.115603
#           >> Test macro:898.008636 ± 896.776773 | micro:5.634120 ± 2.590716
# Epoch 5/100 | Train(sampled) L1:404.340891 L4:0.141563 | Val macro:585.564832 ± 584.332492 | Val micro:4.061304 ± 2.068143
#           >> Test macro:877.839710 ± 876.628534 | micro:5.505268 ± 2.532605
# Epoch 6/100 | Train(sampled) L1:391.349661 L4:0.138840 | Val macro:572.469356 ± 571.239992 | Val micro:3.989854 ± 2.021992
#           >> Test macro:858.249827 ± 857.043896 | micro:5.399286 ± 2.476091
# Epoch 7/100 | Train(sampled) L1:391.977428 L4:0.137483 | Val macro:559.321036 ± 558.110339 | Val micro:3.928936 ± 1.975298
#           >> Test macro:838.557198 ± 837.361436 | micro:5.313287 ± 2.419070
# Epoch 8/100 | Train(sampled) L1:383.394873 L4:0.135221 | Val macro:546.594345 ± 545.412268 | Val micro:3.825157 ± 1.930606
#           >> Test macro:819.523742 ± 818.362087 | micro:5.172900 ± 2.364324
# Epoch 9/100 | Train(sampled) L1:370.965397 L4:0.133528 | Val macro:534.121663 ± 533.023015 | Val micro:3.694477 ± 1.886437
#           >> Test macro:800.855178 ± 799.771571 | micro:5.015459 ± 2.310479
# Epoch 10/100 | Train(sampled) L1:367.384943 L4:0.132003 | Val macro:521.969918 ± 520.911376 | Val micro:3.572546 ± 1.843852
#           >> Test macro:782.708127 ± 781.666518 | micro:4.860962 ± 2.258338
# Epoch 11/100 | Train(sampled) L1:346.513017 L4:0.130664 | Val macro:510.345941 ± 509.392830 | Val micro:3.426118 ± 1.802809
#           >> Test macro:765.367974 ± 764.424634 | micro:4.691572 ± 2.208330
# Epoch 12/100 | Train(sampled) L1:351.972906 L4:0.128457 | Val macro:498.919119 ± 497.993101 | Val micro:3.345454 ± 1.762315
#           >> Test macro:748.184208 ± 747.265507 | micro:4.583841 ± 2.158786
# Epoch 13/100 | Train(sampled) L1:342.623369 L4:0.126506 | Val macro:487.522591 ± 486.624965 | Val micro:3.261241 ± 1.722060
#           >> Test macro:731.110015 ± 730.216105 | micro:4.474082 ± 2.109542
# Epoch 14/100 | Train(sampled) L1:303.210955 L4:0.123663 | Val macro:476.678839 ± 475.782192 | Val micro:3.205665 ± 1.683781
#           >> Test macro:714.946339 ± 714.052976 | micro:4.392323 ± 2.062902
# Epoch 15/100 | Train(sampled) L1:342.608246 L4:0.120579 | Val macro:465.897100 ± 465.009793 | Val micro:3.149043 ± 1.645599
#           >> Test macro:698.786856 ± 697.902651 | micro:4.309100 ± 2.016249
# Epoch 16/100 | Train(sampled) L1:308.205416 L4:0.117848 | Val macro:455.381190 ± 454.487247 | Val micro:3.096885 ± 1.608516
#           >> Test macro:683.131450 ± 682.236671 | micro:4.234820 ± 1.971082
# Epoch 17/100 | Train(sampled) L1:319.766763 L4:0.114283 | Val macro:444.738980 ± 443.870702 | Val micro:3.019794 ± 1.570909
#           >> Test macro:667.109041 ± 666.235625 | micro:4.134084 ± 1.924821
# Epoch 18/100 | Train(sampled) L1:289.646379 L4:0.110316 | Val macro:434.568758 ± 433.706784 | Val micro:2.963938 ± 1.534902
#           >> Test macro:651.878175 ± 651.013728 | micro:4.050507 ± 1.880816
# Epoch 19/100 | Train(sampled) L1:279.471622 L4:0.106643 | Val macro:425.057418 ± 424.166463 | Val micro:2.940660 ± 1.501477
#           >> Test macro:637.564955 ± 636.676060 | micro:3.999346 ± 1.839608
# Epoch 20/100 | Train(sampled) L1:274.387472 L4:0.102294 | Val macro:415.488992 ± 414.622905 | Val micro:2.874679 ± 1.467452
#           >> Test macro:623.090435 ± 622.227378 | micro:3.906817 ± 1.797700
# Epoch 21/100 | Train(sampled) L1:276.977648 L4:0.097402 | Val macro:405.997566 ± 405.072404 | Val micro:2.890306 ± 1.433719
#           >> Test macro:608.908615 ± 607.996281 | micro:3.889192 ± 1.756569
# Epoch 22/100 | Train(sampled) L1:284.886833 L4:0.092504 | Val macro:396.611003 ± 395.668476 | Val micro:2.842290 ± 1.400945
#           >> Test macro:594.718909 ± 593.777878 | micro:3.829291 ± 1.715920
# Epoch 23/100 | Train(sampled) L1:260.015800 L4:0.088502 | Val macro:387.503134 ± 386.635737 | Val micro:2.737934 ± 1.368716
#           >> Test macro:581.088680 ± 580.230445 | micro:3.694190 ± 1.676518
# Epoch 24/100 | Train(sampled) L1:250.170572 L4:0.083046 | Val macro:378.565949 ± 377.702393 | Val micro:2.683099 ± 1.337336
#           >> Test macro:567.773554 ± 566.915455 | micro:3.622023 ± 1.638238
# Epoch 25/100 | Train(sampled) L1:271.754409 L4:0.076263 | Val macro:369.386587 ± 368.529347 | Val micro:2.631677 ± 1.304936
#           >> Test macro:553.824103 ± 552.970496 | micro:3.548240 ± 1.598007
# Epoch 26/100 | Train(sampled) L1:248.186144 L4:0.070348 | Val macro:360.635639 ± 359.659248 | Val micro:2.716191 ± 1.273280
#           >> Test macro:540.790761 ± 539.828681 | micro:3.598829 ± 1.559796
# Epoch 27/100 | Train(sampled) L1:243.613261 L4:0.064982 | Val macro:352.051353 ± 351.171555 | Val micro:2.564969 ± 1.243625
#           >> Test macro:528.031405 ± 527.148048 | micro:3.445792 ± 1.523513
# Epoch 28/100 | Train(sampled) L1:239.411194 L4:0.058962 | Val macro:343.677900 ± 342.828159 | Val micro:2.496997 ± 1.214229
#           >> Test macro:515.516396 ± 514.672323 | micro:3.348244 ± 1.487503
# Epoch 29/100 | Train(sampled) L1:234.058617 L4:0.051774 | Val macro:335.605919 ± 334.776414 | Val micro:2.437352 ± 1.185633
#           >> Test macro:503.361368 ± 502.534195 | micro:3.271044 ± 1.452365
# Epoch 30/100 | Train(sampled) L1:237.556496 L4:0.044397 | Val macro:327.452393 ± 326.609507 | Val micro:2.413410 ± 1.156680
#           >> Test macro:491.188721 ± 490.356011 | micro:3.219094 ± 1.417139
# Epoch 31/100 | Train(sampled) L1:194.520063 L4:0.035766 | Val macro:320.039639 ± 319.186566 | Val micro:2.381958 ± 1.130771
#           >> Test macro:480.149490 ± 479.300118 | micro:3.176790 ± 1.385474
# Epoch 32/100 | Train(sampled) L1:207.812258 L4:0.027284 | Val macro:312.476485 ± 311.614024 | Val micro:2.357643 ± 1.103938
#           >> Test macro:468.706059 ± 467.852955 | micro:3.126898 ± 1.352344
# Epoch 33/100 | Train(sampled) L1:210.275872 L4:0.023953 | Val macro:304.941191 ± 304.101205 | Val micro:2.295883 ± 1.077307
#           >> Test macro:457.549048 ± 456.715856 | micro:3.048743 ± 1.320200
# Epoch 34/100 | Train(sampled) L1:212.085862 L4:0.020859 | Val macro:297.289821 ± 296.466496 | Val micro:2.241418 ± 1.050354
#           >> Test macro:445.993385 ± 445.176128 | micro:2.975729 ± 1.286917
# Epoch 35/100 | Train(sampled) L1:195.745701 L4:0.015723 | Val macro:289.696950 ± 288.845005 | Val micro:2.237566 ± 1.023270
#           >> Test macro:434.673950 ± 433.831645 | micro:2.949455 ± 1.254082
# Epoch 36/100 | Train(sampled) L1:194.909808 L4:0.012946 | Val macro:282.377328 ± 281.410350 | Val micro:2.312696 ± 0.996956
#           >> Test macro:423.644436 ± 422.690135 | micro:3.002002 ± 1.221823
# Epoch 37/100 | Train(sampled) L1:186.753856 L4:0.012945 | Val macro:274.991487 ± 274.152648 | Val micro:2.143845 ± 0.971921
#           >> Test macro:412.669469 ± 411.836705 | micro:2.823752 ± 1.190866
# Epoch 38/100 | Train(sampled) L1:185.697834 L4:0.011332 | Val macro:267.722968 ± 266.902965 | Val micro:2.095198 ± 0.945927
#           >> Test macro:401.755884 ± 400.942157 | micro:2.755824 ± 1.159233
# Epoch 39/100 | Train(sampled) L1:173.916424 L4:0.008274 | Val macro:260.637240 ± 259.815553 | Val micro:2.054790 ± 0.921242
#           >> Test macro:391.177531 ± 390.359582 | micro:2.700914 ± 1.128946
# Epoch 40/100 | Train(sampled) L1:173.692443 L4:0.006381 | Val macro:253.701587 ± 252.712552 | Val micro:2.189371 ± 0.895818
#           >> Test macro:380.640605 ± 379.668021 | micro:2.804091 ± 1.097795
# Epoch 41/100 | Train(sampled) L1:155.709236 L4:0.006891 | Val macro:246.752821 ± 245.932391 | Val micro:1.984016 ± 0.872281
#           >> Test macro:370.384144 ± 369.571149 | micro:2.592032 ± 1.068917
# Epoch 42/100 | Train(sampled) L1:158.081202 L4:0.006119 | Val macro:239.787309 ± 238.969799 | Val micro:1.946569 ± 0.847780
#           >> Test macro:359.906803 ± 359.098204 | micro:2.535583 ± 1.038825
# Epoch 43/100 | Train(sampled) L1:166.277809 L4:0.005998 | Val macro:232.720814 ± 231.835153 | Val micro:1.986077 ± 0.822136
#           >> Test macro:349.261251 ± 348.381428 | micro:2.558819 ± 1.007646
# Epoch 44/100 | Train(sampled) L1:153.231792 L4:0.006148 | Val macro:225.598675 ± 224.792305 | Val micro:1.866505 ± 0.797705
#           >> Test macro:338.657128 ± 337.857898 | micro:2.421610 ± 0.977606
# Epoch 45/100 | Train(sampled) L1:143.006466 L4:0.005029 | Val macro:219.064405 ± 218.246368 | Val micro:1.845815 ± 0.774371
#           >> Test macro:328.844959 ± 328.032598 | micro:2.386018 ± 0.949107
# Epoch 46/100 | Train(sampled) L1:146.286017 L4:0.004519 | Val macro:212.175320 ± 211.366843 | Val micro:1.803519 ± 0.750352
#           >> Test macro:318.544880 ± 317.742413 | micro:2.326311 ± 0.919620
# Epoch 47/100 | Train(sampled) L1:131.108623 L4:0.003984 | Val macro:205.429227 ± 204.605980 | Val micro:1.785270 ± 0.726395
#           >> Test macro:308.422648 ± 307.600289 | micro:2.295503 ± 0.890360
# Epoch 48/100 | Train(sampled) L1:132.731889 L4:0.003723 | Val macro:198.726206 ± 197.911626 | Val micro:1.737682 ± 0.703232
#           >> Test macro:298.407065 ± 297.598782 | micro:2.227099 ± 0.861732
# Epoch 49/100 | Train(sampled) L1:126.642905 L4:0.003546 | Val macro:192.039598 ± 191.166750 | Val micro:1.759305 ± 0.679698
#           >> Test macro:288.358471 ± 287.486187 | micro:2.237545 ± 0.832784
# Epoch 50/100 | Train(sampled) L1:129.814620 L4:0.003429 | Val macro:185.318117 ± 184.472237 | Val micro:1.697606 ± 0.656342
#           >> Test macro:278.301673 ± 277.463283 | micro:2.152564 ± 0.803941
# Epoch 51/100 | Train(sampled) L1:120.820380 L4:0.003503 | Val macro:178.751255 ± 177.919900 | Val micro:1.654893 ± 0.633033
#           >> Test macro:268.357056 ± 267.540851 | micro:2.085431 ± 0.775246
# Epoch 52/100 | Train(sampled) L1:120.312414 L4:0.003532 | Val macro:172.318447 ± 171.450594 | Val micro:1.659715 ± 0.610421
#           >> Test macro:258.773871 ± 257.907143 | micro:2.087722 ± 0.747808
# Epoch 53/100 | Train(sampled) L1:118.410824 L4:0.003018 | Val macro:165.826945 ± 165.022376 | Val micro:1.569880 ± 0.587051
#           >> Test macro:249.104054 ± 248.311423 | micro:1.971420 ± 0.719467
# Epoch 54/100 | Train(sampled) L1:110.652862 L4:0.003651 | Val macro:159.381418 ± 158.572179 | Val micro:1.539750 ± 0.564500
#           >> Test macro:239.416177 ± 238.616947 | micro:1.927198 ± 0.691545
# Epoch 55/100 | Train(sampled) L1:104.703224 L4:0.003709 | Val macro:153.312712 ± 152.496103 | Val micro:1.513022 ± 0.543703
#           >> Test macro:230.347940 ± 229.549806 | micro:1.877924 ± 0.665669
# Epoch 56/100 | Train(sampled) L1:102.657990 L4:0.003093 | Val macro:147.294884 ± 146.341531 | Val micro:1.618333 ± 0.521033
#           >> Test macro:221.399193 ± 220.479869 | micro:1.953045 ± 0.638871
# Epoch 57/100 | Train(sampled) L1:101.169866 L4:0.002838 | Val macro:141.026482 ± 140.221019 | Val micro:1.444934 ± 0.499968
#           >> Test macro:211.986389 ± 211.198747 | micro:1.779706 ± 0.612526
# Epoch 58/100 | Train(sampled) L1:91.178548 L4:0.003532 | Val macro:135.330266 ± 134.486947 | Val micro:1.447397 ± 0.480935
#           >> Test macro:203.442402 ± 202.619181 | micro:1.767271 ± 0.588384
# Epoch 59/100 | Train(sampled) L1:84.299855 L4:0.002798 | Val macro:129.556175 ± 128.754173 | Val micro:1.381176 ± 0.460405
#           >> Test macro:194.764347 ± 193.980596 | micro:1.687027 ± 0.563569
# Epoch 60/100 | Train(sampled) L1:86.012327 L4:0.002807 | Val macro:123.913450 ± 123.105009 | Val micro:1.364934 ± 0.439802
#           >> Test macro:186.202142 ± 185.403541 | micro:1.663192 ± 0.538631
# Epoch 61/100 | Train(sampled) L1:87.128558 L4:0.002722 | Val macro:117.883344 ± 117.075443 | Val micro:1.327898 ± 0.419598
#           >> Test macro:177.302219 ± 176.506007 | micro:1.610671 ± 0.513571
# Epoch 62/100 | Train(sampled) L1:75.921248 L4:0.002610 | Val macro:112.450802 ± 111.635534 | Val micro:1.310413 ± 0.400207
#           >> Test macro:169.159991 ± 168.352402 | micro:1.583610 ± 0.489989
# Epoch 63/100 | Train(sampled) L1:73.192456 L4:0.002896 | Val macro:107.093012 ± 106.276780 | Val micro:1.282448 ± 0.381434
#           >> Test macro:161.255060 ± 160.448241 | micro:1.541641 ± 0.467393
# Epoch 64/100 | Train(sampled) L1:70.133404 L4:0.002323 | Val macro:101.942074 ± 101.066431 | Val micro:1.317412 ± 0.362800
#           >> Test macro:153.315847 ± 152.469886 | micro:1.543449 ± 0.443815
# Epoch 65/100 | Train(sampled) L1:72.216534 L4:0.002475 | Val macro:96.608018 ± 95.691628 | Val micro:1.320230 ± 0.346568
#           >> Test macro:145.365508 ± 144.467854 | micro:1.544967 ± 0.422651
# Epoch 66/100 | Train(sampled) L1:60.338803 L4:0.001972 | Val macro:91.549434 ± 90.684508 | Val micro:1.247111 ± 0.328038
#           >> Test macro:137.805525 ± 136.947601 | micro:1.469906 ± 0.400739
# Epoch 67/100 | Train(sampled) L1:59.785081 L4:0.002299 | Val macro:86.670095 ± 85.849944 | Val micro:1.183798 ± 0.310299
#           >> Test macro:130.556980 ± 129.752722 | micro:1.385968 ± 0.379519
# Epoch 68/100 | Train(sampled) L1:56.330356 L4:0.002689 | Val macro:81.692344 ± 80.873748 | Val micro:1.155308 ± 0.293415
#           >> Test macro:123.149001 ± 122.348355 | micro:1.343237 ± 0.358648
# Epoch 69/100 | Train(sampled) L1:53.863288 L4:0.002423 | Val macro:76.962578 ± 76.145498 | Val micro:1.132923 ± 0.278172
#           >> Test macro:115.804397 ± 115.023052 | micro:1.291670 ± 0.337698
# Epoch 70/100 | Train(sampled) L1:52.587466 L4:0.002564 | Val macro:72.251674 ± 71.419540 | Val micro:1.125021 ± 0.260913
#           >> Test macro:108.753732 ± 107.952054 | micro:1.275833 ± 0.317245
# Epoch 71/100 | Train(sampled) L1:45.394173 L4:0.002347 | Val macro:67.866456 ± 67.034912 | Val micro:1.102725 ± 0.246581
#           >> Test macro:102.316986 ± 101.530921 | micro:1.231851 ± 0.298987
# Epoch 72/100 | Train(sampled) L1:44.974059 L4:0.002784 | Val macro:63.424940 ± 62.610501 | Val micro:1.060739 ± 0.232044
#           >> Test macro:95.597318 ± 94.822022 | micro:1.184059 ± 0.280262
# Epoch 73/100 | Train(sampled) L1:42.978463 L4:0.002515 | Val macro:59.152862 ± 58.296188 | Val micro:1.080303 ± 0.215971
#           >> Test macro:89.207044 ± 88.364356 | micro:1.215706 ± 0.262991
# Epoch 74/100 | Train(sampled) L1:36.830293 L4:0.002208 | Val macro:55.124790 ± 54.300094 | Val micro:1.033271 ± 0.203172
#           >> Test macro:83.116986 ± 82.326958 | micro:1.139170 ± 0.245039
# Epoch 75/100 | Train(sampled) L1:35.847947 L4:0.002248 | Val macro:51.061334 ± 50.220633 | Val micro:1.024834 ± 0.189978
#           >> Test macro:77.065243 ± 76.280506 | micro:1.102605 ± 0.227640
# Epoch 76/100 | Train(sampled) L1:35.985521 L4:0.002916 | Val macro:47.138783 ± 46.324526 | Val micro:0.980456 ± 0.176284
#           >> Test macro:71.041014 ± 70.243525 | micro:1.081673 ± 0.211487
# Epoch 77/100 | Train(sampled) L1:27.839864 L4:0.002151 | Val macro:43.741691 ± 42.926333 | Val micro:0.965483 ± 0.167351
#           >> Test macro:65.869077 ± 65.082238 | micro:1.046770 ± 0.197893
# Epoch 78/100 | Train(sampled) L1:26.859746 L4:0.001834 | Val macro:40.382288 ± 39.500832 | Val micro:1.015982 ± 0.155237
#           >> Test macro:60.907388 ± 60.080936 | micro:1.066884 ± 0.183264
# Epoch 79/100 | Train(sampled) L1:27.531509 L4:0.002177 | Val macro:36.743536 ± 35.853241 | Val micro:0.999427 ± 0.146464
#           >> Test macro:55.436138 ± 54.564955 | micro:1.073145 ± 0.171462
# Epoch 80/100 | Train(sampled) L1:23.329909 L4:0.002675 | Val macro:33.461993 ± 32.584222 | Val micro:0.965712 ± 0.137862
#           >> Test macro:50.434139 ± 49.589442 | micro:1.018119 ± 0.158411
# Epoch 81/100 | Train(sampled) L1:20.501420 L4:0.002270 | Val macro:30.402357 ± 29.551093 | Val micro:0.937109 ± 0.123705
#           >> Test macro:45.810202 ± 45.002719 | micro:0.971579 ± 0.141827
# Epoch 82/100 | Train(sampled) L1:19.367787 L4:0.002203 | Val macro:27.398381 ± 26.553578 | Val micro:0.910851 ± 0.116262
#           >> Test macro:41.512570 ± 40.723094 | micro:0.929257 ± 0.131168
# Epoch 83/100 | Train(sampled) L1:18.557671 L4:0.002100 | Val macro:24.578570 ± 23.723607 | Val micro:0.911923 ± 0.106217
#           >> Test macro:37.073765 ± 36.260147 | micro:0.932781 ± 0.119512
# Epoch 84/100 | Train(sampled) L1:16.521503 L4:0.002101 | Val macro:21.724853 ± 20.892869 | Val micro:0.867535 ± 0.104037
#           >> Test macro:32.783911 ± 31.993398 | micro:0.882560 ± 0.114212
# Epoch 85/100 | Train(sampled) L1:13.975090 L4:0.001795 | Val macro:19.245786 ± 18.372258 | Val micro:0.893872 ± 0.096205
#           >> Test macro:29.134889 ± 28.315614 | micro:0.892348 ± 0.104285
# Epoch 86/100 | Train(sampled) L1:12.341459 L4:0.002248 | Val macro:16.935148 ± 16.083378 | Val micro:0.865603 ± 0.090242
#           >> Test macro:25.590054 ± 24.753241 | micro:0.890881 ± 0.098444
# Epoch 87/100 | Train(sampled) L1:10.635602 L4:0.001776 | Val macro:14.809987 ± 13.961359 | Val micro:0.852303 ± 0.085023
#           >> Test macro:22.340993 ± 21.548520 | micro:0.835862 ± 0.087208
# Epoch 88/100 | Train(sampled) L1:9.144648 L4:0.001904 | Val macro:12.849125 ± 12.006727 | Val micro:0.837491 ± 0.079886
#           >> Test macro:19.342493 ± 18.537795 | micro:0.832388 ± 0.084173
# Epoch 89/100 | Train(sampled) L1:7.983413 L4:0.002402 | Val macro:11.015290 ± 10.135883 | Val micro:0.862841 ± 0.082574
#           >> Test macro:16.528145 ± 15.668197 | micro:0.866870 ± 0.083170
# Epoch 90/100 | Train(sampled) L1:6.873651 L4:0.002315 | Val macro:9.362240 ± 8.496284 | Val micro:0.845441 ± 0.080898
#           >> Test macro:14.023814 ± 13.210591 | micro:0.812970 ± 0.075896
# Epoch 91/100 | Train(sampled) L1:5.926863 L4:0.001832 | Val macro:7.788807 ± 6.971610 | Val micro:0.789306 ± 0.074400
#           >> Test macro:11.750948 ± 10.966060 | micro:0.775665 ± 0.072267
# Epoch 92/100 | Train(sampled) L1:5.116205 L4:0.001944 | Val macro:6.391456 ± 5.550865 | Val micro:0.807357 ± 0.073716
#           >> Test macro:9.563206 ± 8.751267 | micro:0.792068 ± 0.069766
# Epoch 93/100 | Train(sampled) L1:3.911741 L4:0.001975 | Val macro:5.196752 ± 4.346246 | Val micro:0.814662 ± 0.073885
#           >> Test macro:7.693949 ± 6.915195 | micro:0.756248 ± 0.063940
# Epoch 94/100 | Train(sampled) L1:3.188550 L4:0.002443 | Val macro:4.155810 ± 3.335725 | Val micro:0.781055 ± 0.069352
#           >> Test macro:6.132672 ± 5.358731 | micro:0.742585 ± 0.062087
# Epoch 95/100 | Train(sampled) L1:2.491041 L4:0.001716 | Val macro:3.320827 ± 2.501128 | Val micro:0.780962 ± 0.064909
#           >> Test macro:4.804207 ± 4.014080 | micro:0.753245 ± 0.062227
# Epoch 96/100 | Train(sampled) L1:2.015533 L4:0.002127 | Val macro:2.573812 ± 1.756005 | Val micro:0.782019 ± 0.069493
#           >> Test macro:3.763611 ± 2.965034 | micro:0.758486 ± 0.064501
# Epoch 97/100 | Train(sampled) L1:1.572751 L4:0.001869 | Val macro:1.982676 ± 1.189213 | Val micro:0.767793 ± 0.070147
#           >> Test macro:2.762483 ± 1.993043 | micro:0.732716 ± 0.066234
# Epoch 98/100 | Train(sampled) L1:1.230955 L4:0.002183 | Val macro:1.530176 ± 0.749794 | Val micro:0.779296 ± 0.069789
#           >> Test macro:2.053560 ± 1.282330 | micro:0.743477 ± 0.065707
# Epoch 99/100 | Train(sampled) L1:0.967710 L4:0.001920 | Val macro:1.144282 ± 0.426301 | Val micro:0.766932 ± 0.070397
#           >> Test macro:1.475039 ± 0.749702 | micro:0.717169 ± 0.060580
# Epoch 100/100 | Train(sampled) L1:0.752152 L4:0.002289 | Val macro:0.950891 ± 0.325711 | Val micro:0.800400 ± 0.073245
#           >> Test macro:1.112684 ± 0.414279 | micro:0.786424 ± 0.070351
# TEST RESULTS | macro: 1.112684 ± 0.414279 | micro: 0.786424 ± 0.070351
#           >> per_group (weighted SE): {0: '1.432544 ± 0.159093 (n=777)', 1: '1.614683 ± 0.147812 (n=3)', 5: '0.290826 ± 0.011738 (n=1018)'}
# /root/coppe/3Wve/lib/python3.12/site-packages/torch/nn/modules/transformer.py:382: UserWarning:
#
# enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
# GRUPOS (total): {0: 3886, 1: 15, 5: 5093}
# GRUPOS (train): {0: 2332, 1: 9, 5: 3056}
# GRUPOS (valid): {0: 777, 1: 3, 5: 1019}
# GRUPOS (test):  {0: 777, 1: 3, 5: 1018}
# Epoch 1/100 | Train(sampled) L1:426.458186 L4:0.429719 | Val macro:616.839094 ± 615.568134 | Val micro:4.253762 ± 2.178245
#           >> Test macro:924.843821 ± 923.594518 | micro:5.776207 ± 2.668189
# Epoch 2/100 | Train(sampled) L1:433.052027 L4:0.162267 | Val macro:589.883355 ± 588.597307 | Val micro:4.117290 ± 2.083280
#           >> Test macro:884.276358 ± 883.018589 | micro:5.565464 ± 2.551201
# Epoch 3/100 | Train(sampled) L1:403.843510 L4:0.145856 | Val macro:566.174710 ± 564.919671 | Val micro:3.989593 ± 1.999558
#           >> Test macro:848.741155 ± 847.506555 | micro:5.385745 ± 2.448597
# Epoch 4/100 | Train(sampled) L1:362.961354 L4:0.146284 | Val macro:542.266493 ± 541.035489 | Val micro:3.852375 ± 1.915052
#           >> Test macro:812.880700 ± 811.669699 | micro:5.189019 ± 2.345063
# Epoch 5/100 | Train(sampled) L1:367.593240 L4:0.139506 | Val macro:518.727829 ± 517.473589 | Val micro:3.762542 ± 1.831777
#           >> Test macro:777.568192 ± 776.331600 | micro:5.042093 ± 2.243018
# Epoch 6/100 | Train(sampled) L1:340.910105 L4:0.137141 | Val macro:496.812158 ± 495.396586 | Val micro:3.842789 ± 1.753318
#           >> Test macro:744.583647 ± 743.174948 | micro:5.076607 ± 2.147029
# Epoch 7/100 | Train(sampled) L1:320.355717 L4:0.135212 | Val macro:476.172220 ± 474.974007 | Val micro:3.482684 ± 1.681986
#           >> Test macro:713.852195 ± 712.677851 | micro:4.650787 ± 2.059399
# Epoch 8/100 | Train(sampled) L1:306.189618 L4:0.133107 | Val macro:456.803722 ± 455.613527 | Val micro:3.370729 ± 1.613754
#           >> Test macro:684.836892 ± 683.673984 | micro:4.487315 ± 1.975746
# Epoch 9/100 | Train(sampled) L1:305.293623 L4:0.130615 | Val macro:437.550738 ± 436.432423 | Val micro:3.226519 ± 1.545457
#           >> Test macro:655.963829 ± 654.865526 | micro:4.301044 ± 1.892295
# Epoch 10/100 | Train(sampled) L1:292.957583 L4:0.127461 | Val macro:419.010297 ± 418.031913 | Val micro:2.997286 ± 1.480080
#           >> Test macro:628.180285 ± 627.218000 | micro:4.027603 ± 1.812320
# Epoch 11/100 | Train(sampled) L1:274.020528 L4:0.123624 | Val macro:401.652204 ± 400.685862 | Val micro:2.890057 ± 1.418877
#           >> Test macro:602.178608 ± 601.221707 | micro:3.882407 ± 1.737446
# Epoch 12/100 | Train(sampled) L1:259.432829 L4:0.120280 | Val macro:385.375314 ± 384.079650 | Val micro:3.180991 ± 1.359388
#           >> Test macro:577.561351 ± 576.288360 | micro:4.118175 ± 1.664897
# Epoch 13/100 | Train(sampled) L1:251.061823 L4:0.115617 | Val macro:369.440018 ± 368.329461 | Val micro:2.908277 ± 1.303864
#           >> Test macro:553.925560 ± 552.824933 | micro:3.818051 ± 1.597172
# Epoch 14/100 | Train(sampled) L1:247.472322 L4:0.110391 | Val macro:354.134253 ± 353.255409 | Val micro:2.585578 ± 1.250854
#           >> Test macro:530.985674 ± 530.109245 | micro:3.464397 ± 1.531846
# Epoch 15/100 | Train(sampled) L1:233.510759 L4:0.105075 | Val macro:339.115937 ± 338.261110 | Val micro:2.481580 ± 1.198029
#           >> Test macro:508.502014 ± 507.649236 | micro:3.323877 ± 1.467147
# Epoch 16/100 | Train(sampled) L1:214.580290 L4:0.100247 | Val macro:325.395165 ± 324.537022 | Val micro:2.413201 ± 1.149679
#           >> Test macro:487.973689 ± 487.116758 | micro:3.222243 ± 1.407975
# Epoch 17/100 | Train(sampled) L1:217.345625 L4:0.093449 | Val macro:311.977411 ± 311.068415 | Val micro:2.389591 ± 1.102347
#           >> Test macro:467.824321 ± 466.912631 | micro:3.168533 ± 1.349863
# Epoch 18/100 | Train(sampled) L1:218.267663 L4:0.087444 | Val macro:298.417953 ± 297.568656 | Val micro:2.276499 ± 1.054182
#           >> Test macro:447.460984 ± 446.608794 | micro:3.020649 ± 1.290956
# Epoch 19/100 | Train(sampled) L1:199.179144 L4:0.080748 | Val macro:285.302652 ± 284.443147 | Val micro:2.214714 ± 1.007864
#           >> Test macro:427.808610 ± 426.943826 | micro:2.927961 ± 1.234220
# Epoch 20/100 | Train(sampled) L1:192.885574 L4:0.074039 | Val macro:273.126896 ± 272.254127 | Val micro:2.163368 ± 0.965458
#           >> Test macro:409.467479 ± 408.600479 | micro:2.836728 ± 1.181703
# Epoch 21/100 | Train(sampled) L1:173.095006 L4:0.066700 | Val macro:261.413697 ± 260.360364 | Val micro:2.265479 ± 0.924126
#           >> Test macro:391.901783 ± 390.850886 | micro:2.913024 ± 1.131117
# Epoch 22/100 | Train(sampled) L1:181.203958 L4:0.059470 | Val macro:249.356801 ± 248.475120 | Val micro:2.056087 ± 0.881091
#           >> Test macro:373.861380 ± 372.957831 | micro:2.694242 ± 1.078858
# Epoch 23/100 | Train(sampled) L1:161.799119 L4:0.053429 | Val macro:237.679178 ± 236.812100 | Val micro:1.993422 ± 0.839760
#           >> Test macro:356.321796 ± 355.446751 | micro:2.589717 ± 1.027981
# Epoch 24/100 | Train(sampled) L1:160.948887 L4:0.045680 | Val macro:226.840346 ± 225.970289 | Val micro:1.934522 ± 0.801983
#           >> Test macro:339.775568 ± 338.894909 | micro:2.505328 ± 0.980689
# Epoch 25/100 | Train(sampled) L1:148.185012 L4:0.039728 | Val macro:215.269200 ± 214.418758 | Val micro:1.856027 ± 0.761345
#           >> Test macro:322.751031 ± 321.893147 | micro:2.396704 ± 0.931709
# Epoch 26/100 | Train(sampled) L1:143.422643 L4:0.032066 | Val macro:203.920362 ± 203.093725 | Val micro:1.776759 ± 0.721242
#           >> Test macro:305.715848 ± 304.881108 | micro:2.288810 ± 0.882587
# Epoch 27/100 | Train(sampled) L1:136.098851 L4:0.025833 | Val macro:193.325800 ± 192.514397 | Val micro:1.711547 ± 0.683665
#           >> Test macro:289.773961 ± 288.956258 | micro:2.194979 ± 0.836528
# Epoch 28/100 | Train(sampled) L1:124.719968 L4:0.021554 | Val macro:182.693268 ± 181.873419 | Val micro:1.666218 ± 0.646653
#           >> Test macro:273.757722 ± 272.930581 | micro:2.123360 ± 0.790636
# Epoch 29/100 | Train(sampled) L1:123.919312 L4:0.016977 | Val macro:172.281671 ± 171.429132 | Val micro:1.641486 ± 0.610283
#           >> Test macro:258.248482 ± 257.392039 | micro:2.071168 ± 0.746175
# Epoch 30/100 | Train(sampled) L1:115.575172 L4:0.014232 | Val macro:162.036007 ± 161.216306 | Val micro:1.565307 ± 0.573594
#           >> Test macro:242.761599 ± 241.923154 | micro:1.980488 ± 0.701482
# Epoch 31/100 | Train(sampled) L1:109.247597 L4:0.012302 | Val macro:151.995556 ± 151.168137 | Val micro:1.519242 ± 0.538676
#           >> Test macro:227.785029 ± 226.949237 | micro:1.900994 ± 0.658471
# Epoch 32/100 | Train(sampled) L1:98.905253 L4:0.010140 | Val macro:142.540241 ± 141.719559 | Val micro:1.467495 ± 0.505503
#           >> Test macro:213.600767 ± 212.776738 | micro:1.821164 ± 0.617700
# Epoch 33/100 | Train(sampled) L1:91.120519 L4:0.008572 | Val macro:132.985738 ± 132.142743 | Val micro:1.435525 ± 0.472567
#           >> Test macro:199.280720 ± 198.432554 | micro:1.767590 ± 0.576893
# Epoch 34/100 | Train(sampled) L1:86.532893 L4:0.007007 | Val macro:124.054649 ± 123.214546 | Val micro:1.390443 ± 0.441087
#           >> Test macro:185.889726 ± 185.045794 | micro:1.698412 ± 0.538386
# Epoch 35/100 | Train(sampled) L1:78.638056 L4:0.006098 | Val macro:115.170859 ± 114.268422 | Val micro:1.396580 ± 0.410942
#           >> Test macro:172.519464 ± 171.610029 | micro:1.685407 ± 0.501206
# Epoch 36/100 | Train(sampled) L1:74.797503 L4:0.005332 | Val macro:106.507642 ± 105.680474 | Val micro:1.289712 ± 0.379923
#           >> Test macro:159.619097 ± 158.796953 | micro:1.546432 ± 0.462815
# Epoch 37/100 | Train(sampled) L1:66.718810 L4:0.005382 | Val macro:98.361342 ± 97.540905 | Val micro:1.251217 ± 0.350397
#           >> Test macro:147.309127 ± 146.499257 | micro:1.480817 ± 0.427011
# Epoch 38/100 | Train(sampled) L1:67.028599 L4:0.004512 | Val macro:90.152310 ± 89.273055 | Val micro:1.261772 ± 0.320653
#           >> Test macro:134.963134 ± 134.090005 | micro:1.474395 ± 0.391247
# Epoch 39/100 | Train(sampled) L1:54.531611 L4:0.004154 | Val macro:82.644318 ± 81.800770 | Val micro:1.188361 ± 0.297389
#           >> Test macro:123.744240 ± 122.899147 | micro:1.391534 ± 0.360782
# Epoch 40/100 | Train(sampled) L1:53.897636 L4:0.004046 | Val macro:75.498694 ± 74.647772 | Val micro:1.156451 ± 0.271968
#           >> Test macro:113.041127 ± 112.166815 | micro:1.360216 ± 0.331107
# Epoch 41/100 | Train(sampled) L1:46.326098 L4:0.003843 | Val macro:68.593286 ± 67.791939 | Val micro:1.077583 ± 0.248157
#           >> Test macro:102.747846 ± 101.942899 | micro:1.246594 ± 0.300872
# Epoch 42/100 | Train(sampled) L1:42.697102 L4:0.003585 | Val macro:61.999809 ± 61.053325 | Val micro:1.183461 ± 0.227658
#           >> Test macro:92.766134 ± 91.810812 | micro:1.341941 ± 0.274285
# Epoch 43/100 | Train(sampled) L1:38.640595 L4:0.003203 | Val macro:55.559525 ± 54.648564 | Val micro:1.107810 ± 0.206719
#           >> Test macro:83.153234 ± 82.252398 | micro:1.232800 ± 0.246552
# Epoch 44/100 | Train(sampled) L1:34.538474 L4:0.002851 | Val macro:49.430924 ± 48.610479 | Val micro:1.000852 ± 0.183670
#           >> Test macro:73.934897 ± 73.128162 | micro:1.106336 ± 0.219232
# Epoch 45/100 | Train(sampled) L1:30.555678 L4:0.002493 | Val macro:43.799535 ± 42.963715 | Val micro:0.989008 ± 0.165741
#           >> Test macro:65.426154 ± 64.596683 | micro:1.086469 ± 0.196525
# Epoch 46/100 | Train(sampled) L1:25.810214 L4:0.002274 | Val macro:38.664336 ± 37.824325 | Val micro:0.965786 ± 0.146829
#           >> Test macro:57.698136 ± 56.879719 | micro:1.036194 ± 0.172985
# Epoch 47/100 | Train(sampled) L1:24.467308 L4:0.001982 | Val macro:33.610899 ± 32.826116 | Val micro:0.887569 ± 0.133115
#           >> Test macro:50.154786 ± 49.372528 | micro:0.962538 ± 0.155479
# Epoch 48/100 | Train(sampled) L1:20.669927 L4:0.001798 | Val macro:28.903184 ± 28.054951 | Val micro:0.927957 ± 0.120373
#           >> Test macro:43.102136 ± 42.254969 | micro:0.993554 ± 0.138715
# Epoch 49/100 | Train(sampled) L1:18.277299 L4:0.001656 | Val macro:24.666388 ± 23.759933 | Val micro:0.968359 ± 0.103154
#           >> Test macro:36.599518 ± 35.708819 | micro:1.007944 ± 0.118241
# Epoch 50/100 | Train(sampled) L1:15.300877 L4:0.001617 | Val macro:20.456957 ± 19.640881 | Val micro:0.848429 ± 0.098318
#           >> Test macro:30.441752 ± 29.641834 | micro:0.879377 ± 0.106848
# Epoch 51/100 | Train(sampled) L1:12.616897 L4:0.001547 | Val macro:16.966813 ± 16.169134 | Val micro:0.819029 ± 0.084092
#           >> Test macro:25.199590 ± 24.419544 | micro:0.839719 ± 0.090963
# Epoch 52/100 | Train(sampled) L1:10.231187 L4:0.001349 | Val macro:13.912780 ± 13.128791 | Val micro:0.791924 ± 0.077408
#           >> Test macro:20.606816 ± 19.821089 | micro:0.821120 ± 0.083923
# Epoch 53/100 | Train(sampled) L1:8.801924 L4:0.001239 | Val macro:11.088005 ± 10.197704 | Val micro:0.871176 ± 0.079968
#           >> Test macro:16.354538 ± 15.475613 | micro:0.883144 ± 0.083952
# Epoch 54/100 | Train(sampled) L1:6.748538 L4:0.001314 | Val macro:8.598798 ± 7.785963 | Val micro:0.790673 ± 0.073825
#           >> Test macro:12.596255 ± 11.793688 | micro:0.796309 ± 0.072023
# Epoch 55/100 | Train(sampled) L1:5.241567 L4:0.001165 | Val macro:6.572972 ± 5.767572 | Val micro:0.775153 ± 0.071542
#           >> Test macro:9.548666 ± 8.745343 | micro:0.782225 ± 0.071466
# Epoch 56/100 | Train(sampled) L1:3.868143 L4:0.001387 | Val macro:4.948722 ± 4.084396 | Val micro:0.827168 ± 0.069723
#           >> Test macro:6.987557 ± 6.144579 | micro:0.811658 ± 0.066803
# Epoch 57/100 | Train(sampled) L1:2.885509 L4:0.001338 | Val macro:3.515703 ± 2.719533 | Val micro:0.761420 ± 0.065300
#           >> Test macro:4.919695 ± 4.121919 | micro:0.762975 ± 0.064076
# Epoch 58/100 | Train(sampled) L1:2.004005 L4:0.001261 | Val macro:2.585579 ± 1.620687 | Val micro:0.929511 ± 0.074162
#           >> Test macro:3.462877 ± 2.540521 | micro:0.880112 ± 0.071992
# Epoch 59/100 | Train(sampled) L1:1.438244 L4:0.001313 | Val macro:1.811670 ± 1.008416 | Val micro:0.781942 ± 0.061693
#           >> Test macro:2.256144 ± 1.445453 | micro:0.779800 ± 0.065873
# Epoch 60/100 | Train(sampled) L1:1.037902 L4:0.001022 | Val macro:1.235788 ± 0.513237 | Val micro:0.747108 ± 0.062535
#           >> Test macro:1.468080 ± 0.730089 | micro:0.736476 ± 0.065771
# Epoch 61/100 | Train(sampled) L1:0.745205 L4:0.001096 | Val macro:0.956291 ± 0.308952 | Val micro:0.744205 ± 0.065496
#           >> Test macro:1.012458 ± 0.359430 | micro:0.734605 ± 0.063081
# Epoch 62/100 | Train(sampled) L1:0.642684 L4:0.001008 | Val macro:0.785511 ± 0.274889 | Val micro:0.746044 ± 0.061487
#           >> Test macro:0.734128 ± 0.298490 | micro:0.734322 ± 0.060286
# Epoch 63/100 | Train(sampled) L1:0.598868 L4:0.000834 | Val macro:0.755606 ± 0.329565 | Val micro:0.806418 ± 0.069084
#           >> Test macro:0.658678 ± 0.380408 | micro:0.790994 ± 0.067592
# Epoch 64/100 | Train(sampled) L1:0.538213 L4:0.001059 | Val macro:0.666010 ± 0.315283 | Val micro:0.774595 ± 0.065030
#           >> Test macro:0.586357 ± 0.356507 | micro:0.752493 ± 0.064568
# Epoch 65/100 | Train(sampled) L1:0.494891 L4:0.000822 | Val macro:0.653288 ± 0.314359 | Val micro:0.732622 ± 0.063127
#           >> Test macro:0.538908 ± 0.364464 | micro:0.703102 ± 0.062581
# Epoch 66/100 | Train(sampled) L1:0.526355 L4:0.000711 | Val macro:0.721527 ± 0.357444 | Val micro:0.800562 ± 0.072362
#           >> Test macro:0.663460 ± 0.384013 | micro:0.780409 ± 0.070138
# Epoch 67/100 | Train(sampled) L1:0.508722 L4:0.000666 | Val macro:0.713962 ± 0.408774 | Val micro:0.856642 ± 0.070498
#           >> Test macro:0.638333 ± 0.464760 | micro:0.852451 ± 0.072367
# Epoch 68/100 | Train(sampled) L1:0.579799 L4:0.000900 | Val macro:0.663798 ± 0.341743 | Val micro:0.766200 ± 0.069488
#           >> Test macro:0.571530 ± 0.396963 | micro:0.752312 ± 0.062502
# Epoch 69/100 | Train(sampled) L1:0.507855 L4:0.000954 | Val macro:0.657207 ± 0.336818 | Val micro:0.751473 ± 0.066187
#           >> Test macro:0.563536 ± 0.387792 | micro:0.732034 ± 0.065959
# Epoch 70/100 | Train(sampled) L1:0.506581 L4:0.000787 | Val macro:0.668942 ± 0.320549 | Val micro:0.753511 ± 0.068243
#           >> Test macro:0.556403 ± 0.361469 | micro:0.716240 ± 0.063003
# Early stopping at epoch 70/100 (best test macro-MSE: 0.538908 @ epoch 65)
# TEST RESULTS | macro: 0.556403 ± 0.361469 | micro: 0.716240 ± 0.063003
#           >> per_group (weighted SE): {0: '1.270874 ± 0.142553 (n=777)', 1: '0.103621 ± 0.067482 (n=3)', 5: '0.294714 ± 0.011726 (n=1018)'}

# %%
nlayer_val={}
for nlayer in [2, 4, 6]:
    model = ODEJumpEncoder(
        in_channels=11,
        hidden_dim=11*16,
        n_layers=nlayer
    )
    gen = model.train_cognite(
        df=df_scaled_denoised,
        feature_cols=list(df_scaled.columns[:-1]),
        static_features_cols=None,
        timestamp_col='index',
        states_col='states',
        batch_size=256,
        window_size=30,
        window_step=30,
        epochs = 100,
        validate=True
    )
    l = [r for r in gen if r is not None]  # remove None results
    best_epoch = find_best_epoch(l)
    nlayer_val[nlayer] = l[best_epoch]
# Out:
# /root/coppe/3Wve/lib/python3.12/site-packages/torch/nn/modules/transformer.py:382: UserWarning:
#
# enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
# GRUPOS (total): {0: 3886, 1: 15, 5: 5093}
# GRUPOS (train): {0: 2332, 1: 9, 5: 3056}
# GRUPOS (valid): {0: 777, 1: 3, 5: 1019}
# GRUPOS (test):  {0: 777, 1: 3, 5: 1018}
# Epoch 1/100 | Train(sampled) L1:480.544971 L4:0.364468 | Val macro:648.971624 ± 647.695728 | Val micro:4.413120 ± 2.291793
#           >> Test macro:972.765523 ± 971.514977 | micro:6.011287 ± 2.806498
# Epoch 2/100 | Train(sampled) L1:446.746634 L4:0.177772 | Val macro:632.867586 ± 631.609418 | Val micro:4.312240 ± 2.235074
#           >> Test macro:948.806889 ± 947.574528 | micro:5.870633 ± 2.737455
# Epoch 3/100 | Train(sampled) L1:418.716391 L4:0.157187 | Val macro:618.965828 ± 617.698362 | Val micro:4.250299 ± 2.186027
#           >> Test macro:927.944245 ± 926.703180 | micro:5.773410 ± 2.677235
# Epoch 4/100 | Train(sampled) L1:421.835921 L4:0.152020 | Val macro:605.306307 ± 604.075315 | Val micro:4.168243 ± 2.137613
#           >> Test macro:907.328325 ± 906.114912 | micro:5.664315 ± 2.617649
# Epoch 5/100 | Train(sampled) L1:425.237393 L4:0.144039 | Val macro:591.703385 ± 590.482516 | Val micro:4.088083 ± 2.089726
#           >> Test macro:886.952181 ± 885.750373 | micro:5.548952 ± 2.558896
# Epoch 6/100 | Train(sampled) L1:399.416704 L4:0.138413 | Val macro:578.232311 ± 577.024257 | Val micro:4.014993 ± 2.042249
#           >> Test macro:866.852592 ± 865.660834 | micro:5.445031 ± 2.500858
# Epoch 7/100 | Train(sampled) L1:398.311252 L4:0.136470 | Val macro:565.704900 ± 564.524058 | Val micro:3.909489 ± 1.998297
#           >> Test macro:848.109645 ± 846.951284 | micro:5.302581 ± 2.446946
# Epoch 8/100 | Train(sampled) L1:374.960654 L4:0.132941 | Val macro:553.314360 ± 552.220437 | Val micro:3.785455 ± 1.954175
#           >> Test macro:829.438590 ± 828.358414 | micro:5.154730 ± 2.393008
# Epoch 9/100 | Train(sampled) L1:380.042260 L4:0.131443 | Val macro:540.787245 ± 539.803166 | Val micro:3.611443 ± 1.909958
#           >> Test macro:810.610988 ± 809.637488 | micro:4.950231 ± 2.338836
# Epoch 10/100 | Train(sampled) L1:362.690795 L4:0.129278 | Val macro:528.812029 ± 527.800616 | Val micro:3.598124 ± 1.867402
#           >> Test macro:792.651314 ± 791.652659 | micro:4.904597 ± 2.286768
# Epoch 11/100 | Train(sampled) L1:350.933145 L4:0.127364 | Val macro:517.090529 ± 516.097783 | Val micro:3.519762 ± 1.826009
#           >> Test macro:775.114042 ± 774.132177 | micro:4.798194 ± 2.236124
# Epoch 12/100 | Train(sampled) L1:351.168225 L4:0.123834 | Val macro:505.576829 ± 504.556972 | Val micro:3.491100 ± 1.785288
#           >> Test macro:757.833920 ± 756.828285 | micro:4.737178 ± 2.186139
# Epoch 13/100 | Train(sampled) L1:337.028912 L4:0.122125 | Val macro:494.108002 ± 493.208234 | Val micro:3.301728 ± 1.745488
#           >> Test macro:740.805418 ± 739.909910 | micro:4.529961 ± 2.137483
# Epoch 14/100 | Train(sampled) L1:343.423172 L4:0.118299 | Val macro:482.851590 ± 481.934048 | Val micro:3.252920 ± 1.705646
#           >> Test macro:723.799674 ± 722.884040 | micro:4.454116 ± 2.088441
# Epoch 15/100 | Train(sampled) L1:316.136360 L4:0.115355 | Val macro:472.061176 ± 471.171992 | Val micro:3.176186 ± 1.667506
#           >> Test macro:707.646111 ± 706.760469 | micro:4.348989 ± 2.041810
# Epoch 16/100 | Train(sampled) L1:297.680930 L4:0.111629 | Val macro:461.760032 ± 460.841391 | Val micro:3.147897 ± 1.631129
#           >> Test macro:692.215803 ± 691.295329 | micro:4.300031 ± 1.997277
# Epoch 17/100 | Train(sampled) L1:301.505454 L4:0.108747 | Val macro:451.815299 ± 450.855198 | Val micro:3.133518 ± 1.595921
#           >> Test macro:677.254422 ± 676.288613 | micro:4.263925 ± 1.953998
# Epoch 18/100 | Train(sampled) L1:322.505045 L4:0.104877 | Val macro:441.128536 ± 440.263568 | Val micro:2.999801 ± 1.558299
#           >> Test macro:661.259561 ± 660.399175 | micro:4.094201 ± 1.907957
# Epoch 19/100 | Train(sampled) L1:309.490932 L4:0.101617 | Val macro:431.134529 ± 430.227361 | Val micro:2.985234 ± 1.522947
#           >> Test macro:646.227469 ± 645.318854 | micro:4.060002 ± 1.864603
# Epoch 20/100 | Train(sampled) L1:298.830941 L4:0.098351 | Val macro:421.443548 ± 420.554239 | Val micro:2.920422 ± 1.488778
#           >> Test macro:631.702085 ± 630.815829 | micro:3.967070 ± 1.822686
# Epoch 21/100 | Train(sampled) L1:290.024688 L4:0.095538 | Val macro:411.711793 ± 410.861803 | Val micro:2.840797 ± 1.454328
#           >> Test macro:617.091916 ± 616.249715 | micro:3.858523 ± 1.780477
# Epoch 22/100 | Train(sampled) L1:269.916497 L4:0.092509 | Val macro:402.602152 ± 401.725118 | Val micro:2.816097 ± 1.422178
#           >> Test macro:603.406951 ± 602.536519 | micro:3.812085 ± 1.740984
# Epoch 23/100 | Train(sampled) L1:242.678431 L4:0.090094 | Val macro:394.019570 ± 393.168860 | Val micro:2.752696 ± 1.391836
#           >> Test macro:590.539347 ± 589.696665 | micro:3.725592 ± 1.703819
# Epoch 24/100 | Train(sampled) L1:253.807402 L4:0.085006 | Val macro:385.427750 ± 384.557395 | Val micro:2.731283 ± 1.361451
#           >> Test macro:577.636169 ± 576.776034 | micro:3.680434 ± 1.666555
# Epoch 25/100 | Train(sampled) L1:250.607857 L4:0.079611 | Val macro:376.657761 ± 375.817703 | Val micro:2.654243 ± 1.330549
#           >> Test macro:564.479589 ± 563.645821 | micro:3.585111 ± 1.628648
# Epoch 26/100 | Train(sampled) L1:239.348669 L4:0.074598 | Val macro:367.882722 ± 367.033599 | Val micro:2.617699 ± 1.299679
#           >> Test macro:551.313515 ± 550.472176 | micro:3.525184 ± 1.590742
# Epoch 27/100 | Train(sampled) L1:245.128412 L4:0.068534 | Val macro:359.298287 ± 358.461177 | Val micro:2.564113 ± 1.269338
#           >> Test macro:538.343789 ± 537.513502 | micro:3.450424 ± 1.553367
# Epoch 28/100 | Train(sampled) L1:235.134438 L4:0.060921 | Val macro:350.580885 ± 349.661771 | Val micro:2.592387 ± 1.238427
#           >> Test macro:525.316267 ± 524.393326 | micro:3.467076 ± 1.515743
# Epoch 29/100 | Train(sampled) L1:224.602757 L4:0.057029 | Val macro:342.491490 ± 341.646883 | Val micro:2.484598 ± 1.210099
#           >> Test macro:513.288310 ± 512.445994 | micro:3.333790 ± 1.481133
# Epoch 30/100 | Train(sampled) L1:242.774195 L4:0.048182 | Val macro:334.121828 ± 333.291732 | Val micro:2.434862 ± 1.180275
#           >> Test macro:500.694191 ± 499.860613 | micro:3.267844 ± 1.444683
# Epoch 31/100 | Train(sampled) L1:240.229472 L4:0.042592 | Val macro:325.848661 ± 325.001474 | Val micro:2.408299 ± 1.151090
#           >> Test macro:488.274427 ± 487.432689 | micro:3.211850 ± 1.408798
# Epoch 32/100 | Train(sampled) L1:214.632703 L4:0.036859 | Val macro:318.069715 ± 317.244761 | Val micro:2.346836 ± 1.123665
#           >> Test macro:476.682434 ± 475.862995 | micro:3.131375 ± 1.375418
# Epoch 33/100 | Train(sampled) L1:202.386622 L4:0.031334 | Val macro:310.793733 ± 309.967919 | Val micro:2.309303 ± 1.097994
#           >> Test macro:465.837145 ± 465.008572 | micro:3.083629 ± 1.344134
# Epoch 34/100 | Train(sampled) L1:206.380191 L4:0.025628 | Val macro:303.507621 ± 302.685820 | Val micro:2.269718 ± 1.072353
#           >> Test macro:454.851837 ± 454.037490 | micro:3.016044 ± 1.312499
# Epoch 35/100 | Train(sampled) L1:197.124950 L4:0.020071 | Val macro:296.041288 ± 295.213110 | Val micro:2.237812 ± 1.046029
#           >> Test macro:443.649644 ± 442.827527 | micro:2.966672 ± 1.280250
# Epoch 36/100 | Train(sampled) L1:195.171822 L4:0.015706 | Val macro:288.764871 ± 287.945769 | Val micro:2.193458 ± 1.020413
#           >> Test macro:432.777815 ± 431.961299 | micro:2.907801 ± 1.248883
# Epoch 37/100 | Train(sampled) L1:199.615229 L4:0.011869 | Val macro:281.509098 ± 280.693025 | Val micro:2.154646 ± 0.994744
#           >> Test macro:421.867126 ± 421.057031 | micro:2.847811 ± 1.217348
# Epoch 38/100 | Train(sampled) L1:190.795802 L4:0.010728 | Val macro:274.185265 ± 273.340789 | Val micro:2.143521 ± 0.968999
#           >> Test macro:410.916419 ± 410.067659 | micro:2.827956 ± 1.185948
# Epoch 39/100 | Train(sampled) L1:185.880268 L4:0.010097 | Val macro:267.037445 ± 266.132946 | Val micro:2.166758 ± 0.943433
#           >> Test macro:400.191403 ± 399.279590 | micro:2.836285 ± 1.154705
# Epoch 40/100 | Train(sampled) L1:177.718617 L4:0.009366 | Val macro:259.953231 ± 259.120414 | Val micro:2.060050 ± 0.918786
#           >> Test macro:389.543659 ± 388.713548 | micro:2.702231 ± 1.124229
# Epoch 41/100 | Train(sampled) L1:171.619406 L4:0.007574 | Val macro:252.804760 ± 251.996791 | Val micro:2.005716 ± 0.893394
#           >> Test macro:378.806345 ± 378.007362 | micro:2.623808 ± 1.093172
# Epoch 42/100 | Train(sampled) L1:169.419489 L4:0.006403 | Val macro:245.873759 ± 245.035566 | Val micro:2.001508 ± 0.868812
#           >> Test macro:368.380796 ± 367.548589 | micro:2.604897 ± 1.063055
# Epoch 43/100 | Train(sampled) L1:163.354647 L4:0.005804 | Val macro:238.757657 ± 237.941418 | Val micro:1.942079 ± 0.843645
#           >> Test macro:357.774466 ± 356.962487 | micro:2.529336 ± 1.032457
# Epoch 44/100 | Train(sampled) L1:162.074546 L4:0.005580 | Val macro:231.708317 ± 230.883550 | Val micro:1.915711 ± 0.818935
#           >> Test macro:347.213043 ± 346.397953 | micro:2.480954 ± 1.001959
# Epoch 45/100 | Train(sampled) L1:150.598140 L4:0.004746 | Val macro:224.807476 ± 224.008143 | Val micro:1.855881 ± 0.794767
#           >> Test macro:336.842157 ± 336.047120 | micro:2.408792 ± 0.972345
# Epoch 46/100 | Train(sampled) L1:151.803552 L4:0.004297 | Val macro:217.963558 ± 217.131886 | Val micro:1.854434 ± 0.770514
#           >> Test macro:326.514787 ± 325.697724 | micro:2.380476 ± 0.942413
# Epoch 47/100 | Train(sampled) L1:140.368572 L4:0.003845 | Val macro:211.175335 ± 210.326156 | Val micro:1.833015 ± 0.746927
#           >> Test macro:316.386360 ± 315.545177 | micro:2.349367 ± 0.913439
# Epoch 48/100 | Train(sampled) L1:133.394826 L4:0.004205 | Val macro:204.577297 ± 203.771413 | Val micro:1.760121 ± 0.723404
#           >> Test macro:306.490466 ± 305.691303 | micro:2.260148 ± 0.884729
# Epoch 49/100 | Train(sampled) L1:129.076397 L4:0.004210 | Val macro:197.944947 ± 197.062232 | Val micro:1.796114 ± 0.700577
#           >> Test macro:296.551922 ± 295.682162 | micro:2.275490 ± 0.856461
# Epoch 50/100 | Train(sampled) L1:124.241465 L4:0.004004 | Val macro:191.778480 ± 190.930404 | Val micro:1.738779 ± 0.677970
#           >> Test macro:287.233731 ± 286.406926 | micro:2.193204 ± 0.828964
# Epoch 51/100 | Train(sampled) L1:129.132036 L4:0.003263 | Val macro:185.368009 ± 184.558641 | Val micro:1.666146 ± 0.656032
#           >> Test macro:277.667256 ± 276.868860 | micro:2.114954 ± 0.802102
# Epoch 52/100 | Train(sampled) L1:117.555827 L4:0.002851 | Val macro:178.978489 ± 178.127590 | Val micro:1.676917 ± 0.633020
#           >> Test macro:268.077588 ± 267.229687 | micro:2.117091 ± 0.774194
# Epoch 53/100 | Train(sampled) L1:109.530753 L4:0.002932 | Val macro:173.031963 ± 172.135018 | Val micro:1.692668 ± 0.611890
#           >> Test macro:259.027566 ± 258.151750 | micro:2.099607 ± 0.747870
# Epoch 54/100 | Train(sampled) L1:111.912812 L4:0.003004 | Val macro:166.538607 ± 165.730240 | Val micro:1.571413 ± 0.589657
#           >> Test macro:249.353775 ± 248.551140 | micro:1.976484 ± 0.720527
# Epoch 55/100 | Train(sampled) L1:111.359639 L4:0.003008 | Val macro:160.238964 ± 159.427771 | Val micro:1.544404 ± 0.567427
#           >> Test macro:239.940223 ± 239.135701 | micro:1.933393 ± 0.693216
# Epoch 56/100 | Train(sampled) L1:110.737938 L4:0.002411 | Val macro:153.893470 ± 153.093783 | Val micro:1.503273 ± 0.545127
#           >> Test macro:230.396493 ± 229.611457 | micro:1.869687 ± 0.666048
# Epoch 57/100 | Train(sampled) L1:105.198598 L4:0.002420 | Val macro:147.680160 ± 146.849442 | Val micro:1.496526 ± 0.523626
#           >> Test macro:221.116640 ± 220.289190 | micro:1.857490 ± 0.639580
# Epoch 58/100 | Train(sampled) L1:96.758223 L4:0.002183 | Val macro:141.668961 ± 140.850924 | Val micro:1.457739 ± 0.502301
#           >> Test macro:212.079793 ± 211.271577 | micro:1.798100 ± 0.613363
# Epoch 59/100 | Train(sampled) L1:87.023081 L4:0.002339 | Val macro:136.026849 ± 135.220975 | Val micro:1.417634 ± 0.482726
#           >> Test macro:203.583521 ± 202.793822 | micro:1.737783 ± 0.589134
# Epoch 60/100 | Train(sampled) L1:90.325623 L4:0.001962 | Val macro:130.410727 ± 129.513728 | Val micro:1.468020 ± 0.464183
#           >> Test macro:195.119533 ± 194.250676 | micro:1.763787 ± 0.565427
# Epoch 61/100 | Train(sampled) L1:86.607967 L4:0.002306 | Val macro:124.668594 ± 123.838602 | Val micro:1.387602 ± 0.442504
#           >> Test macro:186.502823 ± 185.676397 | micro:1.689351 ± 0.540077
# Epoch 62/100 | Train(sampled) L1:82.894958 L4:0.002421 | Val macro:118.939478 ± 118.135133 | Val micro:1.332497 ± 0.423073
#           >> Test macro:177.949346 ± 177.159217 | micro:1.611379 ± 0.515641
# Epoch 63/100 | Train(sampled) L1:79.824409 L4:0.001674 | Val macro:113.336378 ± 112.522771 | Val micro:1.310957 ± 0.403464
#           >> Test macro:169.516860 ± 168.727132 | micro:1.567418 ± 0.491448
# Epoch 64/100 | Train(sampled) L1:71.927713 L4:0.001389 | Val macro:108.129492 ± 107.285105 | Val micro:1.309975 ± 0.386117
#           >> Test macro:161.803817 ± 160.973110 | micro:1.563760 ± 0.470448
# Epoch 65/100 | Train(sampled) L1:67.715278 L4:0.001720 | Val macro:102.922191 ± 102.071595 | Val micro:1.292896 ± 0.367236
#           >> Test macro:153.999762 ± 153.145545 | micro:1.547852 ± 0.447703
# Epoch 66/100 | Train(sampled) L1:65.298835 L4:0.001871 | Val macro:97.803664 ± 96.994257 | Val micro:1.228043 ± 0.349532
#           >> Test macro:146.272439 ± 145.484947 | micro:1.448012 ± 0.425279
# Epoch 67/100 | Train(sampled) L1:65.091134 L4:0.001461 | Val macro:92.688174 ± 91.798680 | Val micro:1.280506 ± 0.330215
#           >> Test macro:138.593740 ± 137.739588 | micro:1.474445 ± 0.401879
# Epoch 68/100 | Train(sampled) L1:60.583326 L4:0.002031 | Val macro:87.543594 ± 86.689145 | Val micro:1.219337 ± 0.314384
#           >> Test macro:130.897516 ± 130.063658 | micro:1.415274 ± 0.381956
# Epoch 69/100 | Train(sampled) L1:54.297260 L4:0.001546 | Val macro:82.816181 ± 81.966213 | Val micro:1.186662 ± 0.299270
#           >> Test macro:123.760410 ± 122.944053 | micro:1.359175 ± 0.362075
# Epoch 70/100 | Train(sampled) L1:53.798221 L4:0.001197 | Val macro:78.065842 ± 77.252718 | Val micro:1.132933 ± 0.281294
#           >> Test macro:116.692725 ± 115.907253 | micro:1.298941 ± 0.341132
# Epoch 71/100 | Train(sampled) L1:48.857869 L4:0.001706 | Val macro:73.476597 ± 72.655750 | Val micro:1.116277 ± 0.265628
#           >> Test macro:109.857715 ± 109.067501 | micro:1.267851 ± 0.321336
# Epoch 72/100 | Train(sampled) L1:48.338874 L4:0.001715 | Val macro:69.010571 ± 68.175528 | Val micro:1.104841 ± 0.251960
#           >> Test macro:103.154043 ± 102.360295 | micro:1.236775 ± 0.303061
# Epoch 73/100 | Train(sampled) L1:44.704354 L4:0.001280 | Val macro:64.585206 ± 63.668318 | Val micro:1.168515 ± 0.236560
#           >> Test macro:96.426390 ± 95.555652 | micro:1.285022 ± 0.282975
# Epoch 74/100 | Train(sampled) L1:39.624441 L4:0.001270 | Val macro:60.350369 ± 59.516845 | Val micro:1.062047 ± 0.220573
#           >> Test macro:90.166328 ± 89.358329 | micro:1.186075 ± 0.266355
# Epoch 75/100 | Train(sampled) L1:38.196629 L4:0.001866 | Val macro:56.280889 ± 55.407763 | Val micro:1.087164 ± 0.206739
#           >> Test macro:83.964276 ± 83.131740 | micro:1.185963 ± 0.247774
# Epoch 76/100 | Train(sampled) L1:38.119520 L4:0.001105 | Val macro:52.179037 ± 51.360422 | Val micro:1.007214 ± 0.194914
#           >> Test macro:77.844648 ± 77.067894 | micro:1.095736 ± 0.231966
# Epoch 77/100 | Train(sampled) L1:33.933776 L4:0.001276 | Val macro:48.253990 ± 47.402722 | Val micro:1.015805 ± 0.183186
#           >> Test macro:71.922162 ± 71.110207 | micro:1.096588 ± 0.217503
# Epoch 78/100 | Train(sampled) L1:31.245246 L4:0.001213 | Val macro:44.558092 ± 43.732469 | Val micro:0.978076 ± 0.166412
#           >> Test macro:66.375860 ± 65.573671 | micro:1.062834 ± 0.200634
# Epoch 79/100 | Train(sampled) L1:28.114931 L4:0.001282 | Val macro:40.929443 ± 40.110106 | Val micro:0.952278 ± 0.157146
#           >> Test macro:61.015631 ± 60.227293 | micro:1.022204 ± 0.185779
# Epoch 80/100 | Train(sampled) L1:24.886723 L4:0.001340 | Val macro:37.591999 ± 36.769963 | Val micro:0.941415 ± 0.147743
#           >> Test macro:56.050526 ± 55.259707 | micro:1.002407 ± 0.172515
# Epoch 81/100 | Train(sampled) L1:23.890833 L4:0.001638 | Val macro:34.386760 ± 33.561646 | Val micro:0.925586 ± 0.137944
#           >> Test macro:51.152380 ± 50.361468 | micro:0.976369 ± 0.160419
# Epoch 82/100 | Train(sampled) L1:20.620482 L4:0.001259 | Val macro:31.344620 ± 30.510974 | Val micro:0.919251 ± 0.124541
#           >> Test macro:46.656557 ± 45.844307 | micro:0.973738 ± 0.146057
# Epoch 83/100 | Train(sampled) L1:19.916951 L4:0.001231 | Val macro:28.348500 ± 27.510873 | Val micro:0.912419 ± 0.117526
#           >> Test macro:42.078128 ± 41.278476 | micro:0.943725 ± 0.135569
# Epoch 84/100 | Train(sampled) L1:17.729666 L4:0.001404 | Val macro:25.523389 ± 24.678947 | Val micro:0.898518 ± 0.112661
#           >> Test macro:37.856158 ± 37.030266 | micro:0.940129 ± 0.128910
# Epoch 85/100 | Train(sampled) L1:16.257724 L4:0.001030 | Val macro:22.795601 ± 21.966245 | Val micro:0.874772 ± 0.102765
#           >> Test macro:33.769730 ± 32.969597 | micro:0.899875 ± 0.116291
# Epoch 86/100 | Train(sampled) L1:14.804815 L4:0.001168 | Val macro:20.283216 ± 19.378522 | Val micro:0.923487 ± 0.103163
#           >> Test macro:29.941436 ± 29.072075 | micro:0.937190 ± 0.113420
# Epoch 87/100 | Train(sampled) L1:14.054496 L4:0.000956 | Val macro:17.783924 ± 16.931391 | Val micro:0.866932 ± 0.094177
#           >> Test macro:26.262369 ± 25.464576 | micro:0.857459 ± 0.099572
# Epoch 88/100 | Train(sampled) L1:10.270981 L4:0.001428 | Val macro:15.644253 ± 14.815610 | Val micro:0.836690 ± 0.087531
#           >> Test macro:23.039514 ± 22.256256 | micro:0.829567 ± 0.090815
# Epoch 89/100 | Train(sampled) L1:9.840438 L4:0.001437 | Val macro:13.660721 ± 12.793996 | Val micro:0.858817 ± 0.084767
#           >> Test macro:20.030040 ± 19.241261 | micro:0.818258 ± 0.081316
# Epoch 90/100 | Train(sampled) L1:8.503442 L4:0.001255 | Val macro:11.723439 ± 10.866668 | Val micro:0.842316 ± 0.075238
#           >> Test macro:17.119819 ± 16.310209 | micro:0.822654 ± 0.075942
# Epoch 91/100 | Train(sampled) L1:7.361058 L4:0.001356 | Val macro:9.974577 ± 9.142274 | Val micro:0.812397 ± 0.077241
#           >> Test macro:14.622004 ± 13.834596 | micro:0.790791 ± 0.074548
# Epoch 92/100 | Train(sampled) L1:6.097551 L4:0.001461 | Val macro:8.450093 ± 7.581943 | Val micro:0.836904 ± 0.080326
#           >> Test macro:12.189818 ± 11.401067 | micro:0.780819 ± 0.071384
# Epoch 93/100 | Train(sampled) L1:5.215702 L4:0.001118 | Val macro:7.030681 ± 6.146355 | Val micro:0.849051 ± 0.073078
#           >> Test macro:10.090461 ± 9.258070 | micro:0.813802 ± 0.073235
# Epoch 94/100 | Train(sampled) L1:4.141365 L4:0.001093 | Val macro:5.787705 ± 4.940206 | Val micro:0.809023 ± 0.072558
#           >> Test macro:8.213193 ± 7.435338 | micro:0.753667 ± 0.065272
# Epoch 95/100 | Train(sampled) L1:3.353958 L4:0.001029 | Val macro:4.711958 ± 3.862954 | Val micro:0.808265 ± 0.072083
#           >> Test macro:6.575208 ± 5.757745 | micro:0.782966 ± 0.068655
# Epoch 96/100 | Train(sampled) L1:2.676219 L4:0.000983 | Val macro:3.807572 ± 2.981226 | Val micro:0.787471 ± 0.071704
#           >> Test macro:5.190186 ± 4.389116 | micro:0.764664 ± 0.068386
# Epoch 97/100 | Train(sampled) L1:2.256043 L4:0.001300 | Val macro:2.991608 ± 2.167404 | Val micro:0.786414 ± 0.065350
#           >> Test macro:3.988550 ± 3.182644 | micro:0.766179 ± 0.062054
# Epoch 98/100 | Train(sampled) L1:1.668537 L4:0.001416 | Val macro:2.326782 ± 1.523221 | Val micro:0.771147 ± 0.069729
#           >> Test macro:3.003914 ± 2.227768 | micro:0.738848 ± 0.065404
# Epoch 99/100 | Train(sampled) L1:1.337556 L4:0.001294 | Val macro:1.819952 ± 0.997396 | Val micro:0.806039 ± 0.064592
#           >> Test macro:2.240589 ± 1.428954 | micro:0.780599 ± 0.065620
# Epoch 100/100 | Train(sampled) L1:1.018709 L4:0.003266 | Val macro:1.464877 ± 0.662679 | Val micro:0.816556 ± 0.074278
#           >> Test macro:1.731701 ± 0.958092 | micro:0.758033 ± 0.067674
# TEST RESULTS | macro: 1.731701 ± 0.958092 | micro: 0.758033 ± 0.067674
#           >> per_group (weighted SE): {0: '1.368087 ± 0.152902 (n=777)', 1: '3.542820 ± 0.678436 (n=3)', 5: '0.284196 ± 0.011860 (n=1018)'}
# GRUPOS (total): {0: 3886, 1: 15, 5: 5093}
# GRUPOS (train): {0: 2332, 1: 9, 5: 3056}
# GRUPOS (valid): {0: 777, 1: 3, 5: 1019}
# GRUPOS (test):  {0: 777, 1: 3, 5: 1018}
# /root/coppe/3Wve/lib/python3.12/site-packages/torch/nn/modules/transformer.py:382: UserWarning:
#
# enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
# Epoch 1/100 | Train(sampled) L1:445.528222 L4:0.308554 | Val macro:648.929220 ± 647.537550 | Val micro:4.510569 ± 2.291544
#           >> Test macro:972.742647 ± 971.383488 | micro:6.102522 ± 2.806253
# Epoch 2/100 | Train(sampled) L1:440.565522 L4:0.180029 | Val macro:631.527541 ± 630.288614 | Val micro:4.298905 ± 2.230173
#           >> Test macro:946.776189 ± 945.557658 | micro:5.858725 ± 2.731548
# Epoch 3/100 | Train(sampled) L1:414.656129 L4:0.162201 | Val macro:617.266710 ± 615.994344 | Val micro:4.243770 ± 2.180007
#           >> Test macro:925.351826 ± 924.106227 | micro:5.761909 ± 2.669769
# Epoch 4/100 | Train(sampled) L1:401.082830 L4:0.157751 | Val macro:606.571813 ± 605.316392 | Val micro:4.181107 ± 2.142323
#           >> Test macro:908.604359 ± 907.373175 | micro:5.671368 ± 2.621420
# Epoch 5/100 | Train(sampled) L1:407.228713 L4:0.154237 | Val macro:591.556834 ± 590.317965 | Val micro:4.103580 ± 2.089137
#           >> Test macro:886.754397 ± 885.535821 | micro:5.563068 ± 2.558257
# Epoch 6/100 | Train(sampled) L1:431.848266 L4:0.143332 | Val macro:578.046974 ± 576.811561 | Val micro:4.029416 ± 2.041566
#           >> Test macro:866.550780 ± 865.336619 | micro:5.454449 ± 2.500009
# Epoch 7/100 | Train(sampled) L1:396.462782 L4:0.141827 | Val macro:564.989870 ± 563.765565 | Val micro:3.968296 ± 1.995332
#           >> Test macro:846.974587 ± 845.766025 | micro:5.365786 ± 2.443375
# Epoch 8/100 | Train(sampled) L1:377.779283 L4:0.141983 | Val macro:552.388977 ± 551.150434 | Val micro:3.925366 ± 1.950671
#           >> Test macro:828.062711 ± 826.837693 | micro:5.293226 ± 2.388657
# Epoch 9/100 | Train(sampled) L1:368.622052 L4:0.140008 | Val macro:540.162154 ± 538.956797 | Val micro:3.808698 ± 1.907907
#           >> Test macro:809.753440 ± 808.570614 | micro:5.137850 ± 2.336125
# Epoch 10/100 | Train(sampled) L1:377.154722 L4:0.138363 | Val macro:527.928985 ± 526.768726 | Val micro:3.713478 ± 1.864615
#           >> Test macro:791.394087 ± 790.250923 | micro:5.016615 ± 2.283124
# Epoch 11/100 | Train(sampled) L1:368.777036 L4:0.137659 | Val macro:515.777071 ± 514.724601 | Val micro:3.560208 ± 1.821382
#           >> Test macro:773.093221 ± 772.046073 | micro:4.841949 ± 2.230353
# Epoch 12/100 | Train(sampled) L1:352.320225 L4:0.135787 | Val macro:504.033122 ± 502.878845 | Val micro:3.566268 ± 1.780138
#           >> Test macro:755.605576 ± 754.449339 | micro:4.824596 ± 2.179827
# Epoch 13/100 | Train(sampled) L1:315.288994 L4:0.134328 | Val macro:492.775175 ± 491.869250 | Val micro:3.294409 ± 1.740544
#           >> Test macro:738.719768 ± 737.803782 | micro:4.530933 ± 2.131411
# Epoch 14/100 | Train(sampled) L1:335.640978 L4:0.132563 | Val macro:481.905487 ± 481.007015 | Val micro:3.243895 ± 1.702029
#           >> Test macro:722.421293 ± 721.519850 | micro:4.446653 ± 2.084317
# Epoch 15/100 | Train(sampled) L1:329.751390 L4:0.128869 | Val macro:470.748720 ± 469.826314 | Val micro:3.215164 ± 1.662448
#           >> Test macro:705.608335 ± 704.685972 | micro:4.386507 ± 2.035672
# Epoch 16/100 | Train(sampled) L1:323.620296 L4:0.126445 | Val macro:460.020913 ± 458.957931 | Val micro:3.309544 ± 1.623917
#           >> Test macro:689.489732 ± 688.423766 | micro:4.456052 ± 1.988623
# Epoch 17/100 | Train(sampled) L1:291.293566 L4:0.123557 | Val macro:449.550913 ± 448.689103 | Val micro:3.039808 ± 1.588025
#           >> Test macro:673.859653 ± 672.992416 | micro:4.163618 ± 1.944298
# Epoch 18/100 | Train(sampled) L1:298.415701 L4:0.119189 | Val macro:439.594207 ± 438.718807 | Val micro:2.999719 ± 1.552828
#           >> Test macro:658.939239 ± 658.057598 | micro:4.099704 ± 1.901296
# Epoch 19/100 | Train(sampled) L1:290.311511 L4:0.116456 | Val macro:429.410035 ± 428.529631 | Val micro:2.965719 ± 1.516658
#           >> Test macro:643.441747 ± 642.561618 | micro:4.032906 ± 1.856423
# Epoch 20/100 | Train(sampled) L1:272.677783 L4:0.112334 | Val macro:419.595385 ± 418.717381 | Val micro:2.902752 ± 1.482160
#           >> Test macro:628.898629 ± 628.017033 | micro:3.950064 ± 1.814570
# Epoch 21/100 | Train(sampled) L1:294.172595 L4:0.109142 | Val macro:409.651906 ± 408.777334 | Val micro:2.848409 ± 1.447098
#           >> Test macro:613.823376 ± 612.947863 | micro:3.867936 ± 1.771059
# Epoch 22/100 | Train(sampled) L1:264.283154 L4:0.105820 | Val macro:400.536463 ± 399.581209 | Val micro:2.891104 ± 1.414416
#           >> Test macro:600.104684 ± 599.161628 | micro:3.873611 ± 1.731074
# Epoch 23/100 | Train(sampled) L1:262.359114 L4:0.102876 | Val macro:391.052874 ± 390.202144 | Val micro:2.735983 ± 1.381455
#           >> Test macro:585.927353 ± 585.078219 | micro:3.706524 ± 1.690595
# Epoch 24/100 | Train(sampled) L1:253.327230 L4:0.100434 | Val macro:382.164214 ± 381.144898 | Val micro:2.868923 ± 1.349234
#           >> Test macro:572.646588 ± 571.644040 | micro:3.801315 ± 1.651603
# Epoch 25/100 | Train(sampled) L1:249.898204 L4:0.096696 | Val macro:373.284716 ± 372.427537 | Val micro:2.654228 ± 1.318460
#           >> Test macro:559.380663 ± 558.522141 | micro:3.582920 ± 1.613843
# Epoch 26/100 | Train(sampled) L1:257.286990 L4:0.093727 | Val macro:364.470434 ± 363.611251 | Val micro:2.614925 ± 1.287389
#           >> Test macro:546.069206 ± 545.209943 | micro:3.519793 ± 1.575408
# Epoch 27/100 | Train(sampled) L1:226.051309 L4:0.092476 | Val macro:355.887389 ± 355.044451 | Val micro:2.552342 ± 1.257292
#           >> Test macro:533.234656 ± 532.394390 | micro:3.434055 ± 1.538534
# Epoch 28/100 | Train(sampled) L1:246.467230 L4:0.087302 | Val macro:347.343185 ± 346.482411 | Val micro:2.525297 ± 1.227136
#           >> Test macro:520.257135 ± 519.397244 | micro:3.386618 ± 1.501146
# Epoch 29/100 | Train(sampled) L1:239.495667 L4:0.083635 | Val macro:338.825650 ± 337.945067 | Val micro:2.498986 ± 1.197113
#           >> Test macro:507.638141 ± 506.761055 | micro:3.337629 ± 1.464710
# Epoch 30/100 | Train(sampled) L1:220.510315 L4:0.080786 | Val macro:330.743756 ± 329.868062 | Val micro:2.454568 ± 1.168601
#           >> Test macro:495.494990 ± 494.622328 | micro:3.273562 ± 1.429698
# Epoch 31/100 | Train(sampled) L1:231.221210 L4:0.075008 | Val macro:322.344782 ± 321.515531 | Val micro:2.373812 ± 1.138806
#           >> Test macro:482.984443 ± 482.162402 | micro:3.167210 ± 1.393525
# Epoch 32/100 | Train(sampled) L1:212.517816 L4:0.070368 | Val macro:314.527680 ± 313.676434 | Val micro:2.353707 ± 1.111383
#           >> Test macro:471.263423 ± 470.417215 | micro:3.130179 ± 1.359834
# Epoch 33/100 | Train(sampled) L1:209.883489 L4:0.064735 | Val macro:306.895341 ± 305.990035 | Val micro:2.359858 ± 1.084563
#           >> Test macro:459.785560 ± 458.884471 | micro:3.118429 ± 1.326778
# Epoch 34/100 | Train(sampled) L1:200.887978 L4:0.061253 | Val macro:299.380677 ± 298.526486 | Val micro:2.280355 ± 1.057904
#           >> Test macro:448.566113 ± 447.712272 | micro:3.022902 ± 1.294331
# Epoch 35/100 | Train(sampled) L1:198.220999 L4:0.056641 | Val macro:291.998356 ± 291.181448 | Val micro:2.209383 ± 1.031772
#           >> Test macro:437.440339 ± 436.621287 | micro:2.934907 ± 1.262223
# Epoch 36/100 | Train(sampled) L1:186.169279 L4:0.051829 | Val macro:284.691854 ± 283.872329 | Val micro:2.173048 ± 1.006227
#           >> Test macro:426.561818 ± 425.744488 | micro:2.877495 ± 1.231009
# Epoch 37/100 | Train(sampled) L1:188.255418 L4:0.046871 | Val macro:277.579664 ± 276.673559 | Val micro:2.215109 ± 0.980999
#           >> Test macro:415.929699 ± 415.018396 | micro:2.908937 ± 1.200265
# Epoch 38/100 | Train(sampled) L1:181.764300 L4:0.042302 | Val macro:270.192192 ± 269.373943 | Val micro:2.100688 ± 0.954960
#           >> Test macro:404.910860 ± 404.091602 | micro:2.772161 ± 1.168521
# Epoch 39/100 | Train(sampled) L1:177.192200 L4:0.036768 | Val macro:263.361004 ± 262.521412 | Val micro:2.092418 ± 0.930563
#           >> Test macro:394.572990 ± 393.748227 | micro:2.731193 ± 1.138507
# Epoch 40/100 | Train(sampled) L1:182.770070 L4:0.031588 | Val macro:256.083812 ± 255.230862 | Val micro:2.066527 ± 0.905127
#           >> Test macro:383.702122 ± 382.844423 | micro:2.706146 ± 1.107350
# Epoch 41/100 | Train(sampled) L1:167.493545 L4:0.027221 | Val macro:248.973452 ± 248.155292 | Val micro:1.995944 ± 0.880112
#           >> Test macro:373.069802 ± 372.263761 | micro:2.601699 ± 1.076660
# Epoch 42/100 | Train(sampled) L1:159.233840 L4:0.023076 | Val macro:242.088860 ± 241.268673 | Val micro:1.959924 ± 0.855941
#           >> Test macro:362.792530 ± 361.981929 | micro:2.551198 ± 1.047129
# Epoch 43/100 | Train(sampled) L1:168.726908 L4:0.018907 | Val macro:234.946078 ± 234.118509 | Val micro:1.936220 ± 0.830603
#           >> Test macro:352.128091 ± 351.298483 | micro:2.520710 ± 1.016298
# Epoch 44/100 | Train(sampled) L1:158.623072 L4:0.016010 | Val macro:227.835868 ± 227.024210 | Val micro:1.881725 ± 0.805739
#           >> Test macro:341.474707 ± 340.673939 | micro:2.436848 ± 0.985572
# Epoch 45/100 | Train(sampled) L1:143.235008 L4:0.013434 | Val macro:221.236344 ± 220.416591 | Val micro:1.859055 ± 0.782119
#           >> Test macro:331.624420 ± 330.804604 | micro:2.407750 ± 0.957092
# Epoch 46/100 | Train(sampled) L1:147.696317 L4:0.012308 | Val macro:214.629083 ± 213.779399 | Val micro:1.858315 ± 0.758538
#           >> Test macro:321.585865 ± 320.752096 | micro:2.374692 ± 0.928019
# Epoch 47/100 | Train(sampled) L1:141.131207 L4:0.010091 | Val macro:207.835090 ± 207.021549 | Val micro:1.785724 ± 0.735294
#           >> Test macro:311.458813 ± 310.661321 | micro:2.286138 ± 0.899133
# Epoch 48/100 | Train(sampled) L1:136.596280 L4:0.008770 | Val macro:200.986650 ± 200.169122 | Val micro:1.752786 ± 0.710624
#           >> Test macro:301.202079 ± 300.401136 | micro:2.235596 ± 0.869326
# Epoch 49/100 | Train(sampled) L1:135.198374 L4:0.008905 | Val macro:194.255790 ± 193.421196 | Val micro:1.739719 ± 0.686735
#           >> Test macro:291.136648 ± 290.316700 | micro:2.207148 ± 0.840234
# Epoch 50/100 | Train(sampled) L1:130.947799 L4:0.007570 | Val macro:187.600454 ± 186.782939 | Val micro:1.685826 ± 0.664177
#           >> Test macro:281.073557 ± 280.273792 | micro:2.134147 ± 0.811698
# Epoch 51/100 | Train(sampled) L1:120.510795 L4:0.006670 | Val macro:181.030793 ± 180.221139 | Val micro:1.647708 ± 0.640652
#           >> Test macro:271.267293 ± 270.478600 | micro:2.076738 ± 0.783258
# Epoch 52/100 | Train(sampled) L1:118.014270 L4:0.005284 | Val macro:174.760772 ± 173.959034 | Val micro:1.606602 ± 0.618802
#           >> Test macro:261.896546 ± 261.113738 | micro:2.022476 ± 0.756345
# Epoch 53/100 | Train(sampled) L1:113.999538 L4:0.004502 | Val macro:168.642246 ± 167.815041 | Val micro:1.603800 ± 0.597068
#           >> Test macro:252.635788 ± 251.826500 | micro:2.004403 ± 0.729590
# Epoch 54/100 | Train(sampled) L1:110.726880 L4:0.005075 | Val macro:162.467227 ± 161.613235 | Val micro:1.589111 ± 0.576204
#           >> Test macro:243.405935 ± 242.566119 | micro:1.978138 ± 0.703627
# Epoch 55/100 | Train(sampled) L1:112.499686 L4:0.004767 | Val macro:156.321159 ± 155.509187 | Val micro:1.526885 ± 0.553875
#           >> Test macro:234.162796 ± 233.364912 | micro:1.899634 ± 0.676547
# Epoch 56/100 | Train(sampled) L1:104.270875 L4:0.005583 | Val macro:150.203246 ± 149.391874 | Val micro:1.497786 ± 0.532055
#           >> Test macro:225.002582 ± 224.220423 | micro:1.842365 ± 0.649924
# Epoch 57/100 | Train(sampled) L1:100.165349 L4:0.004580 | Val macro:144.253461 ± 143.438011 | Val micro:1.466370 ± 0.511511
#           >> Test macro:216.097299 ± 215.309088 | micro:1.798420 ± 0.624783
# Epoch 58/100 | Train(sampled) L1:97.411932 L4:0.004342 | Val macro:138.337328 ± 137.523246 | Val micro:1.435128 ± 0.491158
#           >> Test macro:207.233722 ± 206.442433 | micro:1.756129 ± 0.599288
# Epoch 59/100 | Train(sampled) L1:88.615870 L4:0.003685 | Val macro:132.524615 ± 131.694262 | Val micro:1.424806 ± 0.470609
#           >> Test macro:198.475081 ± 197.691758 | micro:1.709771 ± 0.574042
# Epoch 60/100 | Train(sampled) L1:84.596148 L4:0.003942 | Val macro:126.955046 ± 126.132365 | Val micro:1.387419 ± 0.451329
#           >> Test macro:190.103506 ± 189.309270 | micro:1.675086 ± 0.550028
# Epoch 61/100 | Train(sampled) L1:85.986203 L4:0.004556 | Val macro:121.064351 ± 120.260906 | Val micro:1.339965 ± 0.430600
#           >> Test macro:181.309381 ± 180.531969 | micro:1.615115 ± 0.525266
# Epoch 62/100 | Train(sampled) L1:78.658204 L4:0.003773 | Val macro:115.474588 ± 114.617107 | Val micro:1.358817 ± 0.409419
#           >> Test macro:172.998225 ± 172.157810 | micro:1.628385 ± 0.500597
# Epoch 63/100 | Train(sampled) L1:72.381860 L4:0.003863 | Val macro:110.199176 ± 109.388232 | Val micro:1.292814 ± 0.391858
#           >> Test macro:165.011701 ± 164.236438 | micro:1.532247 ± 0.477835
# Epoch 64/100 | Train(sampled) L1:71.658633 L4:0.003094 | Val macro:105.027531 ± 104.206594 | Val micro:1.276202 ± 0.374301
#           >> Test macro:157.271309 ± 156.476603 | micro:1.510686 ± 0.455983
# Epoch 65/100 | Train(sampled) L1:66.574777 L4:0.003138 | Val macro:99.762907 ± 98.952846 | Val micro:1.241225 ± 0.355228
#           >> Test macro:149.506945 ± 148.694621 | micro:1.487315 ± 0.433714
# Epoch 66/100 | Train(sampled) L1:65.759162 L4:0.003397 | Val macro:94.577997 ± 93.762526 | Val micro:1.221132 ± 0.338308
#           >> Test macro:141.620027 ± 140.826951 | micro:1.432696 ± 0.411133
# Epoch 67/100 | Train(sampled) L1:60.142690 L4:0.004034 | Val macro:89.594195 ± 88.782648 | Val micro:1.189568 ± 0.320071
#           >> Test macro:134.149958 ± 133.376708 | micro:1.374570 ± 0.389231
# Epoch 68/100 | Train(sampled) L1:57.355203 L4:0.003716 | Val macro:84.691343 ± 83.845790 | Val micro:1.194812 ± 0.304747
#           >> Test macro:126.804830 ± 125.988524 | micro:1.376149 ± 0.369400
# Epoch 69/100 | Train(sampled) L1:56.519929 L4:0.003823 | Val macro:80.023589 ± 79.190326 | Val micro:1.160578 ± 0.288509
#           >> Test macro:119.774367 ± 118.965024 | micro:1.334575 ± 0.349672
# Epoch 70/100 | Train(sampled) L1:55.229435 L4:0.002991 | Val macro:75.208071 ± 74.372655 | Val micro:1.138490 ± 0.272457
#           >> Test macro:112.538042 ± 111.738299 | micro:1.290424 ± 0.328700
# Epoch 71/100 | Train(sampled) L1:46.018152 L4:0.003232 | Val macro:70.779445 ± 69.919963 | Val micro:1.140993 ± 0.255457
#           >> Test macro:105.819985 ± 105.021078 | micro:1.260291 ± 0.308214
# Epoch 72/100 | Train(sampled) L1:45.962420 L4:0.002818 | Val macro:66.388612 ± 65.562093 | Val micro:1.090932 ± 0.241594
#           >> Test macro:99.309893 ± 98.507999 | micro:1.230206 ± 0.291640
# Epoch 73/100 | Train(sampled) L1:41.696308 L4:0.002534 | Val macro:62.143844 ± 61.284261 | Val micro:1.102313 ± 0.225913
#           >> Test macro:92.889517 ± 92.063655 | micro:1.223118 ± 0.272594
# Epoch 74/100 | Train(sampled) L1:40.800719 L4:0.002555 | Val macro:57.873521 ± 56.968299 | Val micro:1.116251 ± 0.213630
#           >> Test macro:86.512693 ± 85.636600 | micro:1.231506 ± 0.257081
# Epoch 75/100 | Train(sampled) L1:38.245838 L4:0.002543 | Val macro:53.752306 ± 52.829269 | Val micro:1.107428 ± 0.199658
#           >> Test macro:80.335747 ± 79.490290 | micro:1.170071 ± 0.237597
# Epoch 76/100 | Train(sampled) L1:34.842034 L4:0.003419 | Val macro:49.735242 ± 48.925804 | Val micro:0.992675 ± 0.185035
#           >> Test macro:74.678865 ± 73.881692 | micro:1.102206 ± 0.222034
# Epoch 77/100 | Train(sampled) L1:34.403965 L4:0.004232 | Val macro:45.888363 ± 45.010272 | Val micro:1.030095 ± 0.173372
#           >> Test macro:68.698201 ± 67.868366 | micro:1.099297 ± 0.204054
# Epoch 78/100 | Train(sampled) L1:28.840690 L4:0.003462 | Val macro:42.307276 ± 41.505820 | Val micro:0.944873 ± 0.159975
#           >> Test macro:63.215409 ± 62.440187 | micro:1.022609 ± 0.189361
# Epoch 79/100 | Train(sampled) L1:27.483547 L4:0.002806 | Val macro:38.789341 ± 37.987125 | Val micro:0.929342 ± 0.148905
#           >> Test macro:58.109703 ± 57.323972 | micro:1.007949 ± 0.176760
# Epoch 80/100 | Train(sampled) L1:24.560750 L4:0.003122 | Val macro:35.500846 ± 34.670420 | Val micro:0.936311 ± 0.136336
#           >> Test macro:53.007078 ± 52.204841 | micro:0.995173 ± 0.161461
# Epoch 81/100 | Train(sampled) L1:22.778620 L4:0.002771 | Val macro:32.410454 ± 31.570427 | Val micro:0.929461 ± 0.130311
#           >> Test macro:48.382877 ± 47.574094 | micro:0.978026 ± 0.151002
# Epoch 82/100 | Train(sampled) L1:20.297174 L4:0.005349 | Val macro:29.309928 ± 28.503802 | Val micro:0.885346 ± 0.119287
#           >> Test macro:43.610625 ± 42.837407 | micro:0.923692 ± 0.136776
# Epoch 83/100 | Train(sampled) L1:18.861967 L4:0.002999 | Val macro:26.432495 ± 25.592987 | Val micro:0.897253 ± 0.114019
#           >> Test macro:39.279661 ± 38.501293 | micro:0.904586 ± 0.126717
# Epoch 84/100 | Train(sampled) L1:16.416331 L4:0.002123 | Val macro:23.692530 ± 22.820054 | Val micro:0.912970 ± 0.108607
#           >> Test macro:35.242744 ± 34.430697 | micro:0.914001 ± 0.118294
# Epoch 85/100 | Train(sampled) L1:14.695603 L4:0.002450 | Val macro:21.140111 ± 20.290737 | Val micro:0.882029 ± 0.102163
#           >> Test macro:31.405504 ± 30.610762 | micro:0.881773 ± 0.108482
# Epoch 86/100 | Train(sampled) L1:13.088978 L4:0.002655 | Val macro:18.680111 ± 17.860218 | Val micro:0.845013 ± 0.091688
#           >> Test macro:28.241679 ± 27.447364 | micro:0.865569 ± 0.100216
# Epoch 87/100 | Train(sampled) L1:12.033156 L4:0.002761 | Val macro:16.399527 ± 15.556414 | Val micro:0.854260 ± 0.086702
#           >> Test macro:24.288021 ± 23.482665 | micro:0.856500 ± 0.094116
# Epoch 88/100 | Train(sampled) L1:9.565035 L4:0.002403 | Val macro:14.436318 ± 13.549778 | Val micro:0.890035 ± 0.083095
#           >> Test macro:21.286605 ± 20.430388 | micro:0.893097 ± 0.083435
# Epoch 89/100 | Train(sampled) L1:8.967324 L4:0.002577 | Val macro:12.414732 ± 11.590990 | Val micro:0.818416 ± 0.079415
#           >> Test macro:18.294177 ± 17.526273 | micro:0.794480 ± 0.077371
# Epoch 90/100 | Train(sampled) L1:7.440805 L4:0.002367 | Val macro:10.656107 ± 9.809762 | Val micro:0.830486 ± 0.074990
#           >> Test macro:15.636744 ± 14.848633 | micro:0.799421 ± 0.074844
# Epoch 91/100 | Train(sampled) L1:6.749945 L4:0.002310 | Val macro:9.023488 ± 8.153547 | Val micro:0.844047 ± 0.066463
#           >> Test macro:13.395350 ± 12.524553 | micro:0.860961 ± 0.072103
# Epoch 92/100 | Train(sampled) L1:5.822360 L4:0.004891 | Val macro:7.453315 ± 6.606467 | Val micro:0.814317 ± 0.070792
#           >> Test macro:10.909583 ± 10.121546 | micro:0.774763 ± 0.066258
# Epoch 93/100 | Train(sampled) L1:4.651081 L4:0.002695 | Val macro:6.214485 ± 5.216593 | Val micro:0.954474 ± 0.069048
#           >> Test macro:8.966225 ± 8.056315 | micro:0.883368 ± 0.064148
# Epoch 94/100 | Train(sampled) L1:3.628309 L4:0.003214 | Val macro:4.938059 ± 4.089736 | Val micro:0.807324 ± 0.069512
#           >> Test macro:7.126933 ± 6.297691 | micro:0.794768 ± 0.067862
# Epoch 95/100 | Train(sampled) L1:2.924102 L4:0.002760 | Val macro:3.968212 ± 3.140721 | Val micro:0.786056 ± 0.073486
#           >> Test macro:5.609427 ± 4.805866 | micro:0.764944 ± 0.066999
# Epoch 96/100 | Train(sampled) L1:2.296695 L4:0.002826 | Val macro:3.189389 ± 2.307755 | Val micro:0.839969 ± 0.076184
#           >> Test macro:4.513735 ± 3.694769 | micro:0.779769 ± 0.068183
# Epoch 97/100 | Train(sampled) L1:1.852032 L4:0.002565 | Val macro:2.500356 ± 1.669369 | Val micro:0.795766 ± 0.073734
#           >> Test macro:3.570623 ± 2.777482 | micro:0.753176 ± 0.065182
# Epoch 98/100 | Train(sampled) L1:1.368373 L4:0.002047 | Val macro:1.910045 ± 1.122990 | Val micro:0.762737 ± 0.063656
#           >> Test macro:2.729257 ± 1.970938 | micro:0.723649 ± 0.060483
# Epoch 99/100 | Train(sampled) L1:1.068052 L4:0.001897 | Val macro:1.557271 ± 0.690796 | Val micro:0.873867 ± 0.066648
#           >> Test macro:1.928613 ± 1.107812 | micro:0.797426 ± 0.056709
# Epoch 100/100 | Train(sampled) L1:0.847771 L4:0.002066 | Val macro:1.156305 ± 0.437627 | Val micro:0.766564 ± 0.062826
#           >> Test macro:1.378706 ± 0.636514 | micro:0.752427 ± 0.065560
# TEST RESULTS | macro: 1.378706 ± 0.636514 | micro: 0.752427 ± 0.065560
#           >> per_group (weighted SE): {0: '1.351325 ± 0.148073 (n=777)', 1: '2.494616 ± 0.602410 (n=3)', 5: '0.290177 ± 0.011993 (n=1018)'}
# /root/coppe/3Wve/lib/python3.12/site-packages/torch/nn/modules/transformer.py:382: UserWarning:
#
# enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
# GRUPOS (total): {0: 3886, 1: 15, 5: 5093}
# GRUPOS (train): {0: 2332, 1: 9, 5: 3056}
# GRUPOS (valid): {0: 777, 1: 3, 5: 1019}
# GRUPOS (test):  {0: 777, 1: 3, 5: 1018}
# Epoch 1/100 | Train(sampled) L1:457.142773 L4:0.517439 | Val macro:641.882762 ± 640.539458 | Val micro:4.448191 ± 2.266255
#           >> Test macro:961.892929 ± 960.571652 | micro:6.030567 ± 2.774815
# Epoch 2/100 | Train(sampled) L1:458.958391 L4:0.229323 | Val macro:623.013617 ± 621.762201 | Val micro:4.262723 ± 2.200149
#           >> Test macro:934.023128 ± 932.793398 | micro:5.799987 ± 2.694772
# Epoch 3/100 | Train(sampled) L1:423.085487 L4:0.168678 | Val macro:608.052352 ± 606.788963 | Val micro:4.192712 ± 2.147439
#           >> Test macro:911.571217 ± 910.333853 | micro:5.688735 ± 2.629984
# Epoch 4/100 | Train(sampled) L1:424.130817 L4:0.152453 | Val macro:594.474836 ± 593.223233 | Val micro:4.117760 ± 2.099583
#           >> Test macro:891.176591 ± 889.948240 | micro:5.582088 ± 2.571130
# Epoch 5/100 | Train(sampled) L1:409.835806 L4:0.158027 | Val macro:580.753575 ± 579.502292 | Val micro:4.048644 ± 2.051125
#           >> Test macro:870.616107 ± 869.388700 | micro:5.478089 ± 2.511793
# Epoch 6/100 | Train(sampled) L1:393.748677 L4:0.148475 | Val macro:567.161799 ± 565.933698 | Val micro:3.968656 ± 2.003094
#           >> Test macro:850.203558 ± 848.995345 | micro:5.367524 ± 2.452817
# Epoch 7/100 | Train(sampled) L1:386.975103 L4:0.145059 | Val macro:553.473995 ± 552.259833 | Val micro:3.888801 ± 1.954889
#           >> Test macro:829.727874 ± 828.534202 | micro:5.253230 ± 2.393753
# Epoch 8/100 | Train(sampled) L1:384.101930 L4:0.142527 | Val macro:540.563735 ± 539.273176 | Val micro:3.869692 ± 1.909424
#           >> Test macro:810.340352 ± 809.082054 | micro:5.190880 ± 2.337849
# Epoch 9/100 | Train(sampled) L1:352.415453 L4:0.137368 | Val macro:527.811977 ± 526.673768 | Val micro:3.703554 ± 1.863984
#           >> Test macro:791.171275 ± 790.047529 | micro:5.008396 ± 2.282435
# Epoch 10/100 | Train(sampled) L1:359.950026 L4:0.135312 | Val macro:515.399290 ± 514.404164 | Val micro:3.502573 ± 1.820053
#           >> Test macro:772.513899 ± 771.531607 | micro:4.775896 ± 2.228751
# Epoch 11/100 | Train(sampled) L1:355.521859 L4:0.134448 | Val macro:503.304901 ± 501.966846 | Val micro:3.730894 ± 1.777402
#           >> Test macro:754.399446 ± 753.072445 | micro:4.975689 ± 2.176117
# Epoch 12/100 | Train(sampled) L1:357.234248 L4:0.132972 | Val macro:490.856989 ± 489.935592 | Val micro:3.300093 ± 1.733901
#           >> Test macro:735.855148 ± 734.943473 | micro:4.515116 ± 2.123204
# Epoch 13/100 | Train(sampled) L1:329.033447 L4:0.129793 | Val macro:479.015338 ± 478.118436 | Val micro:3.219350 ± 1.691836
#           >> Test macro:718.014957 ± 717.125936 | micro:4.405486 ± 2.071698
# Epoch 14/100 | Train(sampled) L1:313.872872 L4:0.127465 | Val macro:467.704512 ± 466.780815 | Val micro:3.201546 ± 1.651655
#           >> Test macro:701.007203 ± 700.092209 | micro:4.358789 ± 2.022484
# Epoch 15/100 | Train(sampled) L1:299.288968 L4:0.124811 | Val macro:456.901240 ± 455.902971 | Val micro:3.191769 ± 1.613884
#           >> Test macro:684.902016 ± 683.900255 | micro:4.333212 ± 1.976129
# Epoch 16/100 | Train(sampled) L1:304.252436 L4:0.122804 | Val macro:446.306727 ± 445.410125 | Val micro:3.063114 ± 1.576265
#           >> Test macro:668.974180 ± 668.081627 | micro:4.170311 ± 1.930098
# Epoch 17/100 | Train(sampled) L1:324.380649 L4:0.117781 | Val macro:435.360847 ± 434.384606 | Val micro:3.093526 ± 1.537067
#           >> Test macro:652.517744 ± 651.547911 | micro:4.169962 ± 1.882206
# Epoch 18/100 | Train(sampled) L1:287.862399 L4:0.116351 | Val macro:424.523942 ± 423.660420 | Val micro:2.917868 ± 1.499545
#           >> Test macro:636.380520 ± 635.518647 | micro:3.973669 ± 1.836134
# Epoch 19/100 | Train(sampled) L1:287.245888 L4:0.113447 | Val macro:414.385163 ± 413.521956 | Val micro:2.869096 ± 1.463673
#           >> Test macro:621.138690 ± 620.280302 | micro:3.896229 ± 1.792116
# Epoch 20/100 | Train(sampled) L1:284.032924 L4:0.109814 | Val macro:404.404500 ± 403.528484 | Val micro:2.832021 ± 1.428349
#           >> Test macro:606.152191 ± 605.271482 | micro:3.843031 ± 1.748837
# Epoch 21/100 | Train(sampled) L1:271.037022 L4:0.106355 | Val macro:394.537396 ± 393.680591 | Val micro:2.763187 ± 1.393659
#           >> Test macro:591.350508 ± 590.496840 | micro:3.742112 ± 1.706187
# Epoch 22/100 | Train(sampled) L1:272.818459 L4:0.102535 | Val macro:384.915993 ± 384.034445 | Val micro:2.740476 ± 1.359408
#           >> Test macro:576.937682 ± 576.064287 | micro:3.689914 ± 1.664446
# Epoch 23/100 | Train(sampled) L1:255.475768 L4:0.099996 | Val macro:375.325277 ± 374.479982 | Val micro:2.652821 ± 1.325885
#           >> Test macro:562.542276 ± 561.697990 | micro:3.585355 ± 1.623127
# Epoch 24/100 | Train(sampled) L1:253.777049 L4:0.096119 | Val macro:366.147042 ± 365.296250 | Val micro:2.613491 ± 1.293397
#           >> Test macro:548.702437 ± 547.852195 | micro:3.523091 ± 1.583166
# Epoch 25/100 | Train(sampled) L1:252.405388 L4:0.093158 | Val macro:357.354910 ± 356.505405 | Val micro:2.570702 ± 1.262226
#           >> Test macro:535.496146 ± 534.646744 | micro:3.458188 ± 1.544978
# Epoch 26/100 | Train(sampled) L1:243.079823 L4:0.089574 | Val macro:348.109650 ± 347.209319 | Val micro:2.564240 ± 1.229857
#           >> Test macro:521.724101 ± 520.822923 | micro:3.430748 ± 1.505371
# Epoch 27/100 | Train(sampled) L1:219.580624 L4:0.086035 | Val macro:339.726851 ± 338.891173 | Val micro:2.467343 ± 1.200037
#           >> Test macro:509.205048 ± 508.364064 | micro:3.316476 ± 1.469127
# Epoch 28/100 | Train(sampled) L1:232.358694 L4:0.080055 | Val macro:331.246353 ± 330.376908 | Val micro:2.459405 ± 1.169877
#           >> Test macro:496.255375 ± 495.388425 | micro:3.278454 ± 1.431650
# Epoch 29/100 | Train(sampled) L1:211.606673 L4:0.076024 | Val macro:323.017602 ± 322.148560 | Val micro:2.419042 ± 1.140865
#           >> Test macro:484.108142 ± 483.243157 | micro:3.216835 ± 1.396614
# Epoch 30/100 | Train(sampled) L1:213.649623 L4:0.070934 | Val macro:314.781040 ± 313.842934 | Val micro:2.428929 ± 1.112171
#           >> Test macro:471.922885 ± 470.980429 | micro:3.216005 ± 1.361627
# Epoch 31/100 | Train(sampled) L1:201.618031 L4:0.066937 | Val macro:306.994929 ± 306.164404 | Val micro:2.296862 ± 1.084679
#           >> Test macro:460.077083 ± 459.242779 | micro:3.062698 ± 1.327518
# Epoch 32/100 | Train(sampled) L1:206.120605 L4:0.060852 | Val macro:298.677441 ± 297.826104 | Val micro:2.277890 ± 1.055113
#           >> Test macro:447.632169 ± 446.785310 | micro:3.014398 ± 1.291548
# Epoch 33/100 | Train(sampled) L1:200.623998 L4:0.055902 | Val macro:290.761733 ± 289.931996 | Val micro:2.220838 ± 1.027112
#           >> Test macro:435.675226 ± 434.841632 | micro:2.945213 ± 1.257055
# Epoch 34/100 | Train(sampled) L1:187.130898 L4:0.052124 | Val macro:283.704959 ± 282.858473 | Val micro:2.193477 ± 1.002217
#           >> Test macro:425.085359 ± 424.236914 | micro:2.898397 ± 1.226392
# Epoch 35/100 | Train(sampled) L1:195.781416 L4:0.047123 | Val macro:275.370091 ± 274.521721 | Val micro:2.157869 ± 0.972957
#           >> Test macro:412.631650 ± 411.778830 | micro:2.845490 ± 1.190638
# Epoch 36/100 | Train(sampled) L1:186.153735 L4:0.042004 | Val macro:267.703277 ± 266.882578 | Val micro:2.090747 ± 0.945892
#           >> Test macro:401.049677 ± 400.234034 | micro:2.749172 ± 1.157238
# Epoch 37/100 | Train(sampled) L1:169.517896 L4:0.036636 | Val macro:260.427584 ± 259.569496 | Val micro:2.088439 ± 0.920634
#           >> Test macro:390.269418 ± 389.409599 | micro:2.736591 ± 1.126335
# Epoch 38/100 | Train(sampled) L1:164.032457 L4:0.032766 | Val macro:253.153765 ± 252.332316 | Val micro:2.017292 ± 0.894869
#           >> Test macro:379.438688 ± 378.615875 | micro:2.646803 ± 1.095041
# Epoch 39/100 | Train(sampled) L1:162.418859 L4:0.029314 | Val macro:245.877084 ± 245.079894 | Val micro:1.960857 ± 0.869088
#           >> Test macro:368.508568 ± 367.717775 | micro:2.564696 ± 1.063345
# Epoch 40/100 | Train(sampled) L1:155.985102 L4:0.025776 | Val macro:238.577723 ± 237.774420 | Val micro:1.931208 ± 0.843419
#           >> Test macro:357.593430 ± 356.800697 | micro:2.513647 ± 1.031975
# Epoch 41/100 | Train(sampled) L1:154.472886 L4:0.022330 | Val macro:231.285615 ± 230.482060 | Val micro:1.893828 ± 0.817681
#           >> Test macro:346.606519 ± 345.814682 | micro:2.456606 ± 1.000287
# Epoch 42/100 | Train(sampled) L1:149.650539 L4:0.018836 | Val macro:223.963448 ± 223.136718 | Val micro:1.881697 ± 0.791752
#           >> Test macro:335.638220 ± 334.826647 | micro:2.422863 ± 0.968608
# Epoch 43/100 | Train(sampled) L1:142.084250 L4:0.017884 | Val macro:217.012737 ± 216.204177 | Val micro:1.828143 ± 0.767311
#           >> Test macro:325.194248 ± 324.401549 | micro:2.351109 ± 0.938554
# Epoch 44/100 | Train(sampled) L1:144.556793 L4:0.015363 | Val macro:209.584718 ± 208.774699 | Val micro:1.789878 ± 0.741279
#           >> Test macro:314.135456 ± 313.339784 | micro:2.296141 ± 0.906818
# Epoch 45/100 | Train(sampled) L1:129.891070 L4:0.013193 | Val macro:202.690562 ± 201.889882 | Val micro:1.746786 ± 0.717185
#           >> Test macro:303.859417 ± 303.078476 | micro:2.231614 ± 0.877209
# Epoch 46/100 | Train(sampled) L1:127.859560 L4:0.011419 | Val macro:196.049157 ± 195.157569 | Val micro:1.808578 ± 0.693102
#           >> Test macro:293.818167 ± 292.946643 | micro:2.275257 ± 0.847947
# Epoch 47/100 | Train(sampled) L1:129.708885 L4:0.009961 | Val macro:188.952980 ± 188.125575 | Val micro:1.700382 ± 0.668951
#           >> Test macro:283.383561 ± 282.568684 | micro:2.158347 ± 0.818408
# Epoch 48/100 | Train(sampled) L1:124.370913 L4:0.008902 | Val macro:182.023514 ± 181.213803 | Val micro:1.650476 ± 0.644419
#           >> Test macro:272.980394 ± 272.181309 | micro:2.092382 ± 0.788576
# Epoch 49/100 | Train(sampled) L1:121.944638 L4:0.008130 | Val macro:175.275334 ± 174.439960 | Val micro:1.640391 ± 0.620830
#           >> Test macro:262.853159 ± 262.027359 | micro:2.066791 ± 0.759636
# Epoch 50/100 | Train(sampled) L1:113.143741 L4:0.008173 | Val macro:168.623975 ± 167.805112 | Val micro:1.593798 ± 0.597412
#           >> Test macro:252.811505 ± 252.011568 | micro:1.994411 ± 0.730419
# Epoch 51/100 | Train(sampled) L1:101.559972 L4:0.007669 | Val macro:162.075074 ± 161.268467 | Val micro:1.547292 ± 0.574106
#           >> Test macro:243.046595 ± 242.253373 | micro:1.936629 ± 0.702146
# Epoch 52/100 | Train(sampled) L1:99.259487 L4:0.006313 | Val macro:156.092926 ± 155.112578 | Val micro:1.687923 ± 0.551962
#           >> Test macro:233.916493 ± 232.976256 | micro:2.036101 ± 0.674925
# Epoch 53/100 | Train(sampled) L1:98.474142 L4:0.006259 | Val macro:149.526539 ± 148.703527 | Val micro:1.499545 ± 0.529938
#           >> Test macro:224.267141 ± 223.467271 | micro:1.849882 ± 0.648121
# Epoch 54/100 | Train(sampled) L1:99.549448 L4:0.006163 | Val macro:143.170898 ± 142.347645 | Val micro:1.470309 ± 0.507665
#           >> Test macro:214.599396 ± 213.797160 | micro:1.804610 ± 0.620425
# Epoch 55/100 | Train(sampled) L1:94.736222 L4:0.005740 | Val macro:136.753369 ± 135.950444 | Val micro:1.418757 ± 0.485242
#           >> Test macro:205.090737 ± 204.308039 | micro:1.738792 ± 0.593221
# Epoch 56/100 | Train(sampled) L1:84.549250 L4:0.004846 | Val macro:130.873799 ± 130.046423 | Val micro:1.408606 ± 0.465176
#           >> Test macro:196.228417 ± 195.424684 | micro:1.711536 ± 0.568209
# Epoch 57/100 | Train(sampled) L1:89.584506 L4:0.004563 | Val macro:124.764145 ± 123.938449 | Val micro:1.385201 ± 0.442397
#           >> Test macro:187.062524 ± 186.262880 | micro:1.669303 ± 0.540928
# Epoch 58/100 | Train(sampled) L1:76.985710 L4:0.004279 | Val macro:118.831680 ± 117.995985 | Val micro:1.357731 ± 0.422973
#           >> Test macro:178.045893 ± 177.243630 | micro:1.620766 ± 0.515643
# Epoch 59/100 | Train(sampled) L1:76.519982 L4:0.004249 | Val macro:113.309782 ± 112.465154 | Val micro:1.344152 ± 0.402590
#           >> Test macro:169.777335 ± 168.973430 | micro:1.587413 ± 0.491248
# Epoch 60/100 | Train(sampled) L1:74.860423 L4:0.003963 | Val macro:107.587227 ± 106.765078 | Val micro:1.289395 ± 0.383914
#           >> Test macro:161.304889 ± 160.498076 | micro:1.541196 ± 0.467796
# Epoch 61/100 | Train(sampled) L1:74.635217 L4:0.003938 | Val macro:101.872244 ± 101.063990 | Val micro:1.251226 ± 0.363233
#           >> Test macro:152.745922 ± 151.976180 | micro:1.466759 ± 0.442633
# Epoch 62/100 | Train(sampled) L1:66.624586 L4:0.004183 | Val macro:96.646085 ± 95.822794 | Val micro:1.237813 ± 0.344559
#           >> Test macro:144.804721 ± 144.012228 | micro:1.447472 ± 0.419942
# Epoch 63/100 | Train(sampled) L1:65.378165 L4:0.003460 | Val macro:91.337667 ± 90.540848 | Val micro:1.188127 ± 0.326797
#           >> Test macro:136.995433 ± 136.232876 | micro:1.382420 ± 0.397734
# Epoch 64/100 | Train(sampled) L1:59.472442 L4:0.003649 | Val macro:86.254648 ± 85.392571 | Val micro:1.215991 ± 0.310876
#           >> Test macro:129.346654 ± 128.533077 | micro:1.386946 ± 0.376907
# Epoch 65/100 | Train(sampled) L1:57.176106 L4:0.003358 | Val macro:81.266207 ± 80.427905 | Val micro:1.175450 ± 0.291710
#           >> Test macro:121.747555 ± 120.934350 | micro:1.350880 ± 0.353884
# Epoch 66/100 | Train(sampled) L1:48.762071 L4:0.003124 | Val macro:76.556749 ± 75.755287 | Val micro:1.116665 ± 0.275758
#           >> Test macro:114.683869 ± 113.908410 | micro:1.280199 ± 0.334357
# Epoch 67/100 | Train(sampled) L1:49.032930 L4:0.002776 | Val macro:71.890612 ± 71.078167 | Val micro:1.106366 ± 0.259353
#           >> Test macro:107.690827 ± 106.917573 | micro:1.246218 ± 0.313880
# Epoch 68/100 | Train(sampled) L1:47.149867 L4:0.002989 | Val macro:67.134486 ± 66.317574 | Val micro:1.083803 ± 0.243884
#           >> Test macro:100.930859 ± 100.150689 | micro:1.215867 ± 0.295298
# Epoch 69/100 | Train(sampled) L1:42.397394 L4:0.002806 | Val macro:62.618560 ± 61.768848 | Val micro:1.088314 ± 0.229982
#           >> Test macro:93.925545 ± 93.106971 | micro:1.212784 ± 0.276641
# Epoch 70/100 | Train(sampled) L1:40.861928 L4:0.002307 | Val macro:58.160397 ± 57.358970 | Val micro:1.023032 ± 0.213603
#           >> Test macro:87.326061 ± 86.541230 | micro:1.151009 ± 0.257603
# Epoch 71/100 | Train(sampled) L1:38.204686 L4:0.002077 | Val macro:53.982072 ± 53.140363 | Val micro:1.043414 ± 0.197941
#           >> Test macro:80.981484 ± 80.170650 | micro:1.145969 ± 0.238604
# Epoch 72/100 | Train(sampled) L1:33.949540 L4:0.002204 | Val macro:49.936667 ± 49.113947 | Val micro:1.001107 ± 0.185391
#           >> Test macro:74.812961 ± 74.029159 | micro:1.087051 ± 0.222162
# Epoch 73/100 | Train(sampled) L1:30.666293 L4:0.001942 | Val macro:46.161111 ± 45.303027 | Val micro:1.024350 ± 0.173519
#           >> Test macro:69.083521 ± 68.244329 | micro:1.117406 ± 0.206222
# Epoch 74/100 | Train(sampled) L1:29.589693 L4:0.001737 | Val macro:42.371572 ± 41.494659 | Val micro:1.024055 ± 0.159697
#           >> Test macro:63.446155 ± 62.599541 | micro:1.097240 ± 0.189897
# Epoch 75/100 | Train(sampled) L1:26.399520 L4:0.001897 | Val macro:38.730827 ± 37.857461 | Val micro:0.997564 ± 0.150043
#           >> Test macro:58.111296 ± 57.293167 | micro:1.040104 ± 0.175667
# Epoch 76/100 | Train(sampled) L1:23.999683 L4:0.001758 | Val macro:35.263064 ± 34.395078 | Val micro:0.969067 ± 0.142940
#           >> Test macro:52.869388 ± 52.030518 | micro:1.026322 ± 0.165185
# Epoch 77/100 | Train(sampled) L1:21.837796 L4:0.001680 | Val macro:31.872803 ± 31.036445 | Val micro:0.925996 ± 0.127224
#           >> Test macro:47.731782 ± 46.928476 | micro:0.972767 ± 0.148408
# Epoch 78/100 | Train(sampled) L1:19.802075 L4:0.001908 | Val macro:28.793688 ± 27.965496 | Val micro:0.903086 ± 0.115100
#           >> Test macro:43.882648 ± 43.058768 | micro:0.970455 ± 0.140194
# Epoch 79/100 | Train(sampled) L1:18.145414 L4:0.001775 | Val macro:25.785800 ± 24.959414 | Val micro:0.890928 ± 0.107708
#           >> Test macro:38.908524 ± 38.097636 | micro:0.938038 ± 0.125040
# Epoch 80/100 | Train(sampled) L1:17.167470 L4:0.001504 | Val macro:22.814890 ± 22.006245 | Val micro:0.852467 ± 0.104603
#           >> Test macro:34.570030 ± 33.782034 | micro:0.889595 ± 0.117659
# Epoch 81/100 | Train(sampled) L1:14.740601 L4:0.001229 | Val macro:20.248043 ± 19.437396 | Val micro:0.844091 ± 0.097954
#           >> Test macro:30.478181 ± 29.709408 | micro:0.852972 ± 0.105764
# Epoch 82/100 | Train(sampled) L1:12.248550 L4:0.001146 | Val macro:17.788717 ± 16.983563 | Val micro:0.828112 ± 0.088256
#           >> Test macro:26.732185 ± 25.941592 | micro:0.856026 ± 0.095148
# Epoch 83/100 | Train(sampled) L1:11.858608 L4:0.001021 | Val macro:15.494831 ± 14.679194 | Val micro:0.825914 ± 0.083885
#           >> Test macro:23.219802 ± 22.430568 | micro:0.837602 ± 0.090400
# Epoch 84/100 | Train(sampled) L1:9.497424 L4:0.001462 | Val macro:13.481389 ± 12.664863 | Val micro:0.819499 ± 0.079740
#           >> Test macro:20.451082 ± 19.630599 | micro:0.852397 ± 0.084619
# Epoch 85/100 | Train(sampled) L1:8.276248 L4:0.001698 | Val macro:11.487643 ± 10.700218 | Val micro:0.779316 ± 0.074027
#           >> Test macro:17.946787 ± 17.174679 | micro:0.793657 ± 0.080432
# Epoch 86/100 | Train(sampled) L1:6.997019 L4:0.001249 | Val macro:9.690952 ± 8.888606 | Val micro:0.784378 ± 0.074489
#           >> Test macro:14.711808 ± 13.916680 | micro:0.798383 ± 0.073997
# Epoch 87/100 | Train(sampled) L1:5.739158 L4:0.001234 | Val macro:8.178388 ± 7.316268 | Val micro:0.840199 ± 0.066750
#           >> Test macro:12.323222 ± 11.501612 | micro:0.819936 ± 0.064519
# Epoch 88/100 | Train(sampled) L1:4.999463 L4:0.001369 | Val macro:6.718571 ± 5.895606 | Val micro:0.795906 ± 0.067166
#           >> Test macro:9.946568 ± 9.128143 | micro:0.801058 ± 0.065636
# Epoch 89/100 | Train(sampled) L1:4.067102 L4:0.001258 | Val macro:5.390345 ± 4.608255 | Val micro:0.749843 ± 0.068828
#           >> Test macro:8.010230 ± 7.256491 | micro:0.731691 ± 0.062597
# Epoch 90/100 | Train(sampled) L1:3.129008 L4:0.000972 | Val macro:4.300367 ± 3.518488 | Val micro:0.746011 ± 0.065264
#           >> Test macro:6.279824 ± 5.514944 | micro:0.733955 ± 0.060000
# Epoch 91/100 | Train(sampled) L1:2.537108 L4:0.001012 | Val macro:3.426182 ± 2.609446 | Val micro:0.777809 ± 0.074104
#           >> Test macro:5.000680 ± 4.194713 | micro:0.765953 ± 0.063136
# Epoch 92/100 | Train(sampled) L1:2.000540 L4:0.000973 | Val macro:2.683878 ± 1.854022 | Val micro:0.795365 ± 0.062657
#           >> Test macro:3.968004 ± 3.171901 | micro:0.759904 ± 0.057507
# Epoch 93/100 | Train(sampled) L1:1.566987 L4:0.000876 | Val macro:2.094605 ± 1.165017 | Val micro:0.907140 ± 0.073081
#           >> Test macro:3.013485 ± 2.110450 | micro:0.862978 ± 0.066430
# Epoch 94/100 | Train(sampled) L1:1.300169 L4:0.000785 | Val macro:1.577822 ± 0.787264 | Val micro:0.785174 ± 0.073418
#           >> Test macro:2.151093 ± 1.362451 | micro:0.759051 ± 0.069050
# Epoch 95/100 | Train(sampled) L1:0.929106 L4:0.000897 | Val macro:1.201145 ± 0.480678 | Val micro:0.748535 ± 0.068765
#           >> Test macro:1.449362 ± 0.728774 | micro:0.716702 ± 0.064468
# Epoch 96/100 | Train(sampled) L1:0.706566 L4:0.000966 | Val macro:0.982980 ± 0.334553 | Val micro:0.759733 ± 0.066702
#           >> Test macro:1.112258 ± 0.442795 | micro:0.707119 ± 0.060164
# Epoch 97/100 | Train(sampled) L1:0.563367 L4:0.000979 | Val macro:0.825263 ± 0.281352 | Val micro:0.718825 ± 0.066605
#           >> Test macro:0.915363 ± 0.321668 | micro:0.696122 ± 0.062932
# Epoch 98/100 | Train(sampled) L1:0.572875 L4:0.000835 | Val macro:0.824964 ± 0.291373 | Val micro:0.846081 ± 0.091405
#           >> Test macro:0.735213 ± 0.322386 | micro:0.748120 ± 0.059980
# Epoch 99/100 | Train(sampled) L1:0.555624 L4:0.001395 | Val macro:0.735046 ± 0.314113 | Val micro:0.768512 ± 0.070406
#           >> Test macro:0.752116 ± 0.316923 | micro:0.748895 ± 0.067109
# Epoch 100/100 | Train(sampled) L1:0.494516 L4:0.000915 | Val macro:0.683562 ± 0.304088 | Val micro:0.738425 ± 0.062995
#           >> Test macro:0.670777 ± 0.313602 | micro:0.721729 ± 0.064226
# TEST RESULTS | macro: 0.670777 ± 0.313602 | micro: 0.721729 ± 0.064226
#           >> per_group (weighted SE): {0: '1.292302 ± 0.145408 (n=777)', 1: '0.432946 ± 0.307555 (n=3)', 5: '0.287084 ± 0.010931 (n=1018)'}

# %%
nheads_val={}
for nheads in [2, 4, 8]:
    model = ODEJumpEncoder(
        in_channels=11,
        hidden_dim=11*16,
        n_heads=nheads
    )
    gen = model.train_cognite(
        df=df_scaled_denoised,
        feature_cols=list(df_scaled.columns[:-1]),
        static_features_cols=None,
        timestamp_col='index',
        states_col='states',
        batch_size=256,
        window_size=30,
        window_step=30,
        epochs = 100,
        validate=True
    )
    l = [r for r in gen if r is not None]  # remove None results
    best_epoch = find_best_epoch(l)
    nheads_val[nheads] = l[best_epoch]
# Out:
# /root/coppe/3Wve/lib/python3.12/site-packages/torch/nn/modules/transformer.py:382: UserWarning:
#
# enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
# GRUPOS (total): {0: 3886, 1: 15, 5: 5093}
# GRUPOS (train): {0: 2332, 1: 9, 5: 3056}
# GRUPOS (valid): {0: 777, 1: 3, 5: 1019}
# GRUPOS (test):  {0: 777, 1: 3, 5: 1018}
# Epoch 1/100 | Train(sampled) L1:483.164762 L4:0.468016 | Val macro:645.037713 ± 643.735955 | Val micro:4.417099 ± 2.277903
#           >> Test macro:966.981133 ± 965.704881 | micro:6.005779 ± 2.789840
# Epoch 2/100 | Train(sampled) L1:431.412850 L4:0.224011 | Val macro:627.325823 ± 626.064764 | Val micro:4.284877 ± 2.215487
#           >> Test macro:940.560076 ± 939.325101 | micro:5.829372 ± 2.713666
# Epoch 3/100 | Train(sampled) L1:412.775036 L4:0.166077 | Val macro:613.086457 ± 611.829517 | Val micro:4.210844 ± 2.165199
#           >> Test macro:919.103695 ± 917.872568 | micro:5.719491 ± 2.651740
# Epoch 4/100 | Train(sampled) L1:421.349598 L4:0.151116 | Val macro:599.328617 ± 598.093977 | Val micro:4.134887 ± 2.116686
#           >> Test macro:898.503050 ± 897.288542 | micro:5.614467 ± 2.592240
# Epoch 5/100 | Train(sampled) L1:413.956382 L4:0.149620 | Val macro:586.064236 ± 584.826691 | Val micro:4.070463 ± 2.069885
#           >> Test macro:878.651205 ± 877.435112 | micro:5.515855 ± 2.534955
# Epoch 6/100 | Train(sampled) L1:406.812111 L4:0.145762 | Val macro:572.569477 ± 571.343896 | Val micro:3.994863 ± 2.022181
#           >> Test macro:858.395024 ± 857.190121 | micro:5.407054 ± 2.476448
# Epoch 7/100 | Train(sampled) L1:379.278640 L4:0.136685 | Val macro:559.892143 ± 558.658633 | Val micro:3.928014 ± 1.977628
#           >> Test macro:839.431525 ± 838.223356 | micro:5.304487 ± 2.421811
# Epoch 8/100 | Train(sampled) L1:371.191663 L4:0.134510 | Val macro:547.245586 ± 546.045234 | Val micro:3.855040 ± 1.932625
#           >> Test macro:820.438740 ± 819.254863 | micro:5.207635 ± 2.366824
# Epoch 9/100 | Train(sampled) L1:381.370158 L4:0.135059 | Val macro:534.762121 ± 533.568810 | Val micro:3.767123 ± 1.888941
#           >> Test macro:801.799617 ± 800.631220 | micro:5.081262 ± 2.313231
# Epoch 10/100 | Train(sampled) L1:361.356367 L4:0.133922 | Val macro:522.316277 ± 521.185464 | Val micro:3.656100 ± 1.844800
#           >> Test macro:783.099879 ± 781.988818 | micro:4.943442 ± 2.259245
# Epoch 11/100 | Train(sampled) L1:346.333132 L4:0.133522 | Val macro:510.563612 ± 509.463734 | Val micro:3.592248 ± 1.802697
#           >> Test macro:765.367544 ± 764.279928 | micro:4.855629 ± 2.207873
# Epoch 12/100 | Train(sampled) L1:329.978846 L4:0.133689 | Val macro:499.471028 ± 498.166759 | Val micro:3.760310 ± 1.762217
#           >> Test macro:748.580180 ± 747.293291 | micro:4.989286 ± 2.158595
# Epoch 13/100 | Train(sampled) L1:312.581974 L4:0.131249 | Val macro:487.856678 ± 486.898347 | Val micro:3.329472 ± 1.723071
#           >> Test macro:731.506256 ± 730.559222 | micro:4.536816 ± 2.110506
# Epoch 14/100 | Train(sampled) L1:328.578694 L4:0.129425 | Val macro:476.446147 ± 475.429196 | Val micro:3.306302 ± 1.682905
#           >> Test macro:714.443856 ± 713.431682 | micro:4.490644 ± 2.061311
# Epoch 15/100 | Train(sampled) L1:313.394661 L4:0.127025 | Val macro:465.173749 ± 464.278674 | Val micro:3.150681 ± 1.642947
#           >> Test macro:697.515161 ± 696.626601 | micro:4.304535 ± 2.012519
# Epoch 16/100 | Train(sampled) L1:292.783086 L4:0.124824 | Val macro:454.860365 ± 453.963001 | Val micro:3.095238 ± 1.606627
#           >> Test macro:682.059452 ± 681.166082 | micro:4.225750 ± 1.967981
# Epoch 17/100 | Train(sampled) L1:319.119917 L4:0.120571 | Val macro:443.849482 ± 442.964806 | Val micro:3.033503 ± 1.567653
#           >> Test macro:665.520521 ± 664.639846 | micro:4.136435 ± 1.920219
# Epoch 18/100 | Train(sampled) L1:285.086304 L4:0.117980 | Val macro:433.683257 ± 432.743192 | Val micro:3.042106 ± 1.531121
#           >> Test macro:650.127178 ± 649.203136 | micro:4.106377 ± 1.875469
# Epoch 19/100 | Train(sampled) L1:302.091192 L4:0.114340 | Val macro:423.538939 ± 422.630210 | Val micro:2.949293 ± 1.496144
#           >> Test macro:635.146074 ± 634.239048 | micro:4.004247 ± 1.832630
# Epoch 20/100 | Train(sampled) L1:283.034770 L4:0.111725 | Val macro:413.655932 ± 412.782993 | Val micro:2.871992 ± 1.460931
#           >> Test macro:620.242369 ± 619.379717 | micro:3.893196 ± 1.789506
# Epoch 21/100 | Train(sampled) L1:278.146521 L4:0.107749 | Val macro:404.335776 ± 403.254227 | Val micro:3.034296 ± 1.427134
#           >> Test macro:606.145826 ± 605.095160 | micro:4.009889 ± 1.748105
# Epoch 22/100 | Train(sampled) L1:271.871277 L4:0.104585 | Val macro:394.773943 ± 393.906198 | Val micro:2.772949 ± 1.394324
#           >> Test macro:591.892173 ± 591.036173 | micro:3.745693 ± 1.707715
# Epoch 23/100 | Train(sampled) L1:262.904403 L4:0.101536 | Val macro:385.505324 ± 384.526901 | Val micro:2.843659 ± 1.361098
#           >> Test macro:578.002156 ± 577.045208 | micro:3.783033 ± 1.667227
# Epoch 24/100 | Train(sampled) L1:263.879342 L4:0.097952 | Val macro:375.879717 ± 375.023013 | Val micro:2.666670 ± 1.327634
#           >> Test macro:563.559840 ± 562.708029 | micro:3.598115 ± 1.626018
# Epoch 25/100 | Train(sampled) L1:252.841147 L4:0.094001 | Val macro:367.139408 ± 366.239950 | Val micro:2.656977 ± 1.296818
#           >> Test macro:550.472982 ± 549.569753 | micro:3.574774 ± 1.588279
# Epoch 26/100 | Train(sampled) L1:234.722814 L4:0.091471 | Val macro:358.425380 ± 357.548417 | Val micro:2.595286 ± 1.266221
#           >> Test macro:537.390722 ± 536.510939 | micro:3.490228 ± 1.550589
# Epoch 27/100 | Train(sampled) L1:235.711303 L4:0.086847 | Val macro:350.025364 ± 349.164918 | Val micro:2.537915 ± 1.236507
#           >> Test macro:524.824830 ± 523.963836 | micro:3.409921 ± 1.514332
# Epoch 28/100 | Train(sampled) L1:225.745139 L4:0.082075 | Val macro:341.717501 ± 340.869625 | Val micro:2.487284 ± 1.207076
#           >> Test macro:512.354807 ± 511.504654 | micro:3.339564 ± 1.478298
# Epoch 29/100 | Train(sampled) L1:221.593092 L4:0.076797 | Val macro:333.746539 ± 332.664519 | Val micro:2.650386 ± 1.178995
#           >> Test macro:500.365836 ± 499.273447 | micro:3.490126 ± 1.443660
# Epoch 30/100 | Train(sampled) L1:218.930108 L4:0.072283 | Val macro:325.443199 ± 324.544635 | Val micro:2.447320 ± 1.149811
#           >> Test macro:488.079858 ± 487.175495 | micro:3.263110 ± 1.408365
# Epoch 31/100 | Train(sampled) L1:219.017176 L4:0.067558 | Val macro:317.352135 ± 316.321229 | Val micro:2.553136 ± 1.120126
#           >> Test macro:475.677932 ± 474.661326 | micro:3.326843 ± 1.371685
# Epoch 32/100 | Train(sampled) L1:208.301495 L4:0.063051 | Val macro:309.563288 ± 308.641430 | Val micro:2.389517 ± 1.093661
#           >> Test macro:464.125615 ± 463.194252 | micro:3.168187 ± 1.339206
# Epoch 33/100 | Train(sampled) L1:211.062609 L4:0.057731 | Val macro:301.771238 ± 300.927038 | Val micro:2.282676 ± 1.066183
#           >> Test macro:452.457744 ± 451.614378 | micro:3.032011 ± 1.305536
# Epoch 34/100 | Train(sampled) L1:210.881379 L4:0.051573 | Val macro:293.950927 ± 293.037344 | Val micro:2.320444 ± 1.038201
#           >> Test macro:440.761522 ± 439.860862 | micro:3.038357 ± 1.271420
# Epoch 35/100 | Train(sampled) L1:184.003771 L4:0.046992 | Val macro:286.795615 ± 285.855036 | Val micro:2.293576 ± 1.013387
#           >> Test macro:430.048615 ± 429.104506 | micro:3.010451 ± 1.240918
# Epoch 36/100 | Train(sampled) L1:191.870832 L4:0.040413 | Val macro:279.517301 ± 278.612723 | Val micro:2.236235 ± 0.987258
#           >> Test macro:419.151924 ± 418.257000 | micro:2.920801 ± 1.209100
# Epoch 37/100 | Train(sampled) L1:193.745329 L4:0.034610 | Val macro:272.080451 ± 271.239639 | Val micro:2.129591 ± 0.961456
#           >> Test macro:408.028648 ± 407.182044 | micro:2.811227 ± 1.177475
# Epoch 38/100 | Train(sampled) L1:186.518371 L4:0.029221 | Val macro:264.644299 ± 263.805309 | Val micro:2.094330 ± 0.935075
#           >> Test macro:396.894633 ± 396.056363 | micro:2.751194 ± 1.145133
# Epoch 39/100 | Train(sampled) L1:165.026911 L4:0.025659 | Val macro:257.609861 ± 256.763608 | Val micro:2.064505 ± 0.910635
#           >> Test macro:386.359369 ± 385.511930 | micro:2.706781 ± 1.114999
# Epoch 40/100 | Train(sampled) L1:168.274820 L4:0.022390 | Val macro:250.540308 ± 249.673796 | Val micro:2.046896 ± 0.885553
#           >> Test macro:375.752515 ± 374.878110 | micro:2.676971 ± 1.084407
# Epoch 41/100 | Train(sampled) L1:163.318281 L4:0.019844 | Val macro:243.553755 ± 242.684708 | Val micro:2.019666 ± 0.860531
#           >> Test macro:365.256884 ± 364.391034 | micro:2.620699 ± 1.053740
# Epoch 42/100 | Train(sampled) L1:158.444131 L4:0.017338 | Val macro:236.615803 ± 235.775382 | Val micro:1.952957 ± 0.836529
#           >> Test macro:354.859547 ± 354.020629 | micro:2.539867 ± 1.024105
# Epoch 43/100 | Train(sampled) L1:151.732591 L4:0.015775 | Val macro:229.699493 ± 228.837571 | Val micro:1.938661 ± 0.812263
#           >> Test macro:344.507279 ± 343.643505 | micro:2.511493 ± 0.994351
# Epoch 44/100 | Train(sampled) L1:146.344899 L4:0.013267 | Val macro:222.848540 ± 222.028517 | Val micro:1.864969 ± 0.788165
#           >> Test macro:334.256787 ± 333.442249 | micro:2.413234 ± 0.964845
# Epoch 45/100 | Train(sampled) L1:145.908850 L4:0.011685 | Val macro:216.051877 ± 215.149511 | Val micro:1.911990 ± 0.764150
#           >> Test macro:324.022906 ± 323.116681 | micro:2.452619 ± 0.935421
# Epoch 46/100 | Train(sampled) L1:137.567574 L4:0.010581 | Val macro:209.039316 ± 208.189367 | Val micro:1.821473 ± 0.739743
#           >> Test macro:313.544506 ± 312.696055 | micro:2.339392 ± 0.905428
# Epoch 47/100 | Train(sampled) L1:142.609003 L4:0.009585 | Val macro:202.071536 ± 201.234205 | Val micro:1.777203 ± 0.714800
#           >> Test macro:303.126544 ± 302.284781 | micro:2.282753 ± 0.875128
# Epoch 48/100 | Train(sampled) L1:130.853728 L4:0.009141 | Val macro:195.433762 ± 194.576660 | Val micro:1.758836 ± 0.692027
#           >> Test macro:293.131312 ± 292.280584 | micro:2.238237 ± 0.846664
# Epoch 49/100 | Train(sampled) L1:133.588536 L4:0.007879 | Val macro:188.653805 ± 187.850097 | Val micro:1.680359 ± 0.667857
#           >> Test macro:282.976110 ± 282.180081 | micro:2.140580 ± 0.817158
# Epoch 50/100 | Train(sampled) L1:121.082009 L4:0.006807 | Val macro:181.914240 ± 181.112012 | Val micro:1.643872 ± 0.644110
#           >> Test macro:272.855183 ± 272.060423 | micro:2.087703 ± 0.788050
# Epoch 51/100 | Train(sampled) L1:117.349682 L4:0.005857 | Val macro:175.539248 ± 174.734823 | Val micro:1.614191 ± 0.621799
#           >> Test macro:263.298645 ± 262.500142 | micro:2.043486 ± 0.760539
# Epoch 52/100 | Train(sampled) L1:119.151957 L4:0.005186 | Val macro:169.071811 ± 168.212365 | Val micro:1.633527 ± 0.599086
#           >> Test macro:253.549670 ± 252.683575 | micro:2.058275 ± 0.732908
# Epoch 53/100 | Train(sampled) L1:109.733184 L4:0.004791 | Val macro:162.595142 ± 161.772697 | Val micro:1.564414 ± 0.576291
#           >> Test macro:243.882401 ± 243.060065 | micro:1.966805 ± 0.704802
# Epoch 54/100 | Train(sampled) L1:110.234481 L4:0.004204 | Val macro:156.348010 ± 155.501133 | Val micro:1.554978 ± 0.554332
#           >> Test macro:234.570375 ± 233.722324 | micro:1.943012 ± 0.678037
# Epoch 55/100 | Train(sampled) L1:102.308946 L4:0.003989 | Val macro:150.046045 ± 149.242661 | Val micro:1.484771 ± 0.532182
#           >> Test macro:225.136228 ± 224.334117 | micro:1.854778 ± 0.650791
# Epoch 56/100 | Train(sampled) L1:101.483060 L4:0.003921 | Val macro:144.117383 ± 143.286348 | Val micro:1.480027 ± 0.511459
#           >> Test macro:216.312127 ± 215.471894 | micro:1.845201 ± 0.625675
# Epoch 57/100 | Train(sampled) L1:94.873013 L4:0.003854 | Val macro:137.936864 ± 137.129088 | Val micro:1.432053 ± 0.489712
#           >> Test macro:207.010621 ± 206.212167 | micro:1.764243 ± 0.598498
# Epoch 58/100 | Train(sampled) L1:89.862514 L4:0.003305 | Val macro:132.248452 ± 131.360659 | Val micro:1.483498 ± 0.469235
#           >> Test macro:198.391518 ± 197.517291 | micro:1.797219 ± 0.573401
# Epoch 59/100 | Train(sampled) L1:88.054445 L4:0.003060 | Val macro:126.461890 ± 125.635412 | Val micro:1.392215 ± 0.449481
#           >> Test macro:189.724078 ± 188.898771 | micro:1.703596 ± 0.549065
# Epoch 60/100 | Train(sampled) L1:80.671116 L4:0.003095 | Val macro:120.842026 ± 119.989199 | Val micro:1.393353 ± 0.429685
#           >> Test macro:181.274291 ± 180.437993 | micro:1.675908 ± 0.524306
# Epoch 61/100 | Train(sampled) L1:76.422005 L4:0.003049 | Val macro:115.352656 ± 114.538268 | Val micro:1.322010 ± 0.410420
#           >> Test macro:173.065550 ± 172.254225 | micro:1.603344 ± 0.501151
# Epoch 62/100 | Train(sampled) L1:74.027948 L4:0.002644 | Val macro:109.803095 ± 108.981440 | Val micro:1.302414 ± 0.391461
#           >> Test macro:164.775952 ± 163.969438 | micro:1.558926 ± 0.477482
# Epoch 63/100 | Train(sampled) L1:74.726810 L4:0.002407 | Val macro:104.296079 ± 103.494053 | Val micro:1.255275 ± 0.372457
#           >> Test macro:156.471035 ± 155.678406 | micro:1.503241 ± 0.453994
# Epoch 64/100 | Train(sampled) L1:69.596739 L4:0.002069 | Val macro:98.916446 ± 98.070398 | Val micro:1.268804 ± 0.354167
#           >> Test macro:148.415378 ± 147.570206 | micro:1.511777 ± 0.431497
# Epoch 65/100 | Train(sampled) L1:62.521553 L4:0.002026 | Val macro:93.826895 ± 93.015797 | Val micro:1.214084 ± 0.335726
#           >> Test macro:140.798874 ± 139.999548 | micro:1.433584 ± 0.408708
# Epoch 66/100 | Train(sampled) L1:63.950992 L4:0.001857 | Val macro:88.687472 ± 87.889453 | Val micro:1.175008 ± 0.318212
#           >> Test macro:133.033570 ± 132.251946 | micro:1.377501 ± 0.386732
# Epoch 67/100 | Train(sampled) L1:56.576369 L4:0.002300 | Val macro:83.655924 ± 82.850568 | Val micro:1.155300 ± 0.300657
#           >> Test macro:125.447797 ± 124.661736 | micro:1.342418 ± 0.364776
# Epoch 68/100 | Train(sampled) L1:55.517243 L4:0.001945 | Val macro:78.849121 ± 78.045162 | Val micro:1.129422 ± 0.284638
#           >> Test macro:118.219512 ± 117.437284 | micro:1.302484 ± 0.344773
# Epoch 69/100 | Train(sampled) L1:54.246619 L4:0.001715 | Val macro:74.077061 ± 73.256378 | Val micro:1.120907 ± 0.268202
#           >> Test macro:111.094978 ± 110.292233 | micro:1.285922 ± 0.324265
# Epoch 70/100 | Train(sampled) L1:48.327607 L4:0.001376 | Val macro:69.538232 ± 68.711163 | Val micro:1.108131 ± 0.253052
#           >> Test macro:104.275618 ± 103.456940 | micro:1.269830 ± 0.305566
# Epoch 71/100 | Train(sampled) L1:43.367213 L4:0.001438 | Val macro:65.109270 ± 64.306939 | Val micro:1.060828 ± 0.238106
#           >> Test macro:97.669894 ± 96.892895 | micro:1.196638 ± 0.286074
# Epoch 72/100 | Train(sampled) L1:43.632904 L4:0.001308 | Val macro:60.768416 ± 59.936349 | Val micro:1.063242 ± 0.222130
#           >> Test macro:91.159469 ± 90.336659 | micro:1.202728 ± 0.268226
# Epoch 73/100 | Train(sampled) L1:39.387898 L4:0.001346 | Val macro:56.613322 ± 55.770137 | Val micro:1.054449 ± 0.207360
#           >> Test macro:84.893889 ± 84.061369 | micro:1.180762 ± 0.250327
# Epoch 74/100 | Train(sampled) L1:37.460132 L4:0.001521 | Val macro:52.648461 ± 51.808854 | Val micro:1.034054 ± 0.196526
#           >> Test macro:78.862241 ± 78.028065 | micro:1.154946 ± 0.234868
# Epoch 75/100 | Train(sampled) L1:33.679376 L4:0.002335 | Val macro:48.683522 ± 47.880635 | Val micro:0.979483 ± 0.182829
#           >> Test macro:72.963707 ± 72.159090 | micro:1.096860 ± 0.217884
# Epoch 76/100 | Train(sampled) L1:30.473175 L4:0.002176 | Val macro:44.997588 ± 44.160768 | Val micro:0.990219 ± 0.171996
#           >> Test macro:67.444561 ± 66.615644 | micro:1.090375 ± 0.204310
# Epoch 77/100 | Train(sampled) L1:27.986301 L4:0.001382 | Val macro:41.497263 ± 40.667506 | Val micro:0.971578 ± 0.159383
#           >> Test macro:62.138250 ± 61.323736 | micro:1.056061 ± 0.188446
# Epoch 78/100 | Train(sampled) L1:25.429568 L4:0.001324 | Val macro:38.026260 ± 37.215979 | Val micro:0.933574 ± 0.148858
#           >> Test macro:56.945124 ± 56.156372 | micro:1.004154 ± 0.173686
# Epoch 79/100 | Train(sampled) L1:25.736530 L4:0.001307 | Val macro:34.725519 ± 33.843706 | Val micro:0.989476 ± 0.137399
#           >> Test macro:51.963130 ± 51.108381 | micro:1.046434 ± 0.159640
# Epoch 80/100 | Train(sampled) L1:22.101057 L4:0.001239 | Val macro:31.436434 ± 30.601698 | Val micro:0.922807 ± 0.126074
#           >> Test macro:47.060479 ± 46.245110 | micro:0.978204 ± 0.147122
# Epoch 81/100 | Train(sampled) L1:20.364480 L4:0.001740 | Val macro:28.330005 ± 27.473207 | Val micro:0.926901 ± 0.119637
#           >> Test macro:42.406707 ± 41.563416 | micro:0.981143 ± 0.136464
# Epoch 82/100 | Train(sampled) L1:18.591544 L4:0.001549 | Val macro:25.385068 ± 24.559783 | Val micro:0.883235 ± 0.111364
#           >> Test macro:38.027322 ± 37.219555 | micro:0.926145 ± 0.126813
# Epoch 83/100 | Train(sampled) L1:16.087993 L4:0.001585 | Val macro:22.711051 ± 21.866863 | Val micro:0.885458 ± 0.104163
#           >> Test macro:33.937376 ± 33.140203 | micro:0.895487 ± 0.114188
# Epoch 84/100 | Train(sampled) L1:14.412656 L4:0.002397 | Val macro:20.133693 ± 19.321115 | Val micro:0.844098 ± 0.093676
#           >> Test macro:30.053137 ± 29.259097 | micro:0.871875 ± 0.104392
# Epoch 85/100 | Train(sampled) L1:12.533774 L4:0.001589 | Val macro:17.809611 ± 16.978890 | Val micro:0.849352 ± 0.094668
#           >> Test macro:26.574864 ± 25.765881 | micro:0.868784 ± 0.100458
# Epoch 86/100 | Train(sampled) L1:11.166600 L4:0.001417 | Val macro:15.622510 ± 14.818879 | Val micro:0.815907 ± 0.084969
#           >> Test macro:23.289165 ± 22.525368 | micro:0.813293 ± 0.087008
# Epoch 87/100 | Train(sampled) L1:10.044427 L4:0.001177 | Val macro:13.523421 ± 12.694422 | Val micro:0.826352 ± 0.083463
#           >> Test macro:20.139803 ± 19.337267 | micro:0.830715 ± 0.088562
# Epoch 88/100 | Train(sampled) L1:8.590311 L4:0.001211 | Val macro:11.663878 ± 10.828249 | Val micro:0.825361 ± 0.079072
#           >> Test macro:17.303045 ± 16.510676 | micro:0.809782 ± 0.074612
# Epoch 89/100 | Train(sampled) L1:7.393537 L4:0.001234 | Val macro:9.863050 ± 8.978145 | Val micro:0.863585 ± 0.070756
#           >> Test macro:14.551876 ± 13.686272 | micro:0.863487 ± 0.075375
# Epoch 90/100 | Train(sampled) L1:6.159236 L4:0.001330 | Val macro:8.231058 ± 7.388753 | Val micro:0.815616 ± 0.076992
#           >> Test macro:12.189695 ± 11.375898 | micro:0.803988 ± 0.072240
# Epoch 91/100 | Train(sampled) L1:5.111759 L4:0.001429 | Val macro:6.859160 ± 6.017937 | Val micro:0.806791 ± 0.074675
#           >> Test macro:10.007883 ± 9.176617 | micro:0.807270 ± 0.075142
# Epoch 92/100 | Train(sampled) L1:4.067836 L4:0.001374 | Val macro:5.650265 ± 4.845570 | Val micro:0.773618 ± 0.069293
#           >> Test macro:8.235834 ± 7.443638 | micro:0.768412 ± 0.066037
# Epoch 93/100 | Train(sampled) L1:3.508675 L4:0.001319 | Val macro:4.565891 ± 3.740406 | Val micro:0.786326 ± 0.073518
#           >> Test macro:6.573926 ± 5.770051 | micro:0.769413 ± 0.069839
# Epoch 94/100 | Train(sampled) L1:2.719621 L4:0.001213 | Val macro:3.625553 ± 2.787371 | Val micro:0.796746 ± 0.072893
#           >> Test macro:5.124752 ± 4.319486 | micro:0.765691 ± 0.069189
# Epoch 95/100 | Train(sampled) L1:2.142380 L4:0.001161 | Val macro:2.834939 ± 2.011712 | Val micro:0.786955 ± 0.063840
#           >> Test macro:3.993327 ± 3.176825 | micro:0.776771 ± 0.061895
# Epoch 96/100 | Train(sampled) L1:1.806655 L4:0.000979 | Val macro:2.184553 ± 1.341381 | Val micro:0.813811 ± 0.074707
#           >> Test macro:3.021949 ± 2.203490 | micro:0.779298 ± 0.067663
# Epoch 97/100 | Train(sampled) L1:1.373067 L4:0.001077 | Val macro:1.656432 ± 0.868877 | Val micro:0.773885 ± 0.068485
#           >> Test macro:2.183843 ± 1.416705 | micro:0.736694 ± 0.063352
# Epoch 98/100 | Train(sampled) L1:1.064175 L4:0.001018 | Val macro:1.364831 ± 0.517626 | Val micro:0.925264 ± 0.068684
#           >> Test macro:1.633902 ± 0.764040 | micro:0.882144 ± 0.069537
# Epoch 99/100 | Train(sampled) L1:0.832738 L4:0.001740 | Val macro:1.013378 ± 0.348262 | Val micro:0.786894 ± 0.072705
#           >> Test macro:1.163748 ± 0.461848 | micro:0.751496 ± 0.065212
# Epoch 100/100 | Train(sampled) L1:0.654236 L4:0.001599 | Val macro:0.862590 ± 0.281589 | Val micro:0.779268 ± 0.069045
#           >> Test macro:0.838581 ± 0.286205 | micro:0.746875 ± 0.063159
# TEST RESULTS | macro: 0.838581 ± 0.286205 | micro: 0.746875 ± 0.063159
#           >> per_group (weighted SE): {0: '1.306650 ± 0.142830 (n=777)', 1: '0.889894 ± 0.081779 (n=3)', 5: '0.319198 ± 0.012026 (n=1018)'}
# GRUPOS (total): {0: 3886, 1: 15, 5: 5093}
# GRUPOS (train): {0: 2332, 1: 9, 5: 3056}
# GRUPOS (valid): {0: 777, 1: 3, 5: 1019}
# GRUPOS (test):  {0: 777, 1: 3, 5: 1018}
# /root/coppe/3Wve/lib/python3.12/site-packages/torch/nn/modules/transformer.py:382: UserWarning:
#
# enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
# Epoch 1/100 | Train(sampled) L1:464.369055 L4:0.564317 | Val macro:650.720586 ± 649.370235 | Val micro:4.512291 ± 2.297368
#           >> Test macro:975.059958 ± 973.728111 | micro:6.119726 ± 2.812711
# Epoch 2/100 | Train(sampled) L1:440.020634 L4:0.207197 | Val macro:632.172798 ± 630.920518 | Val micro:4.309843 ± 2.232492
#           >> Test macro:947.668568 ± 946.437857 | micro:5.869854 ± 2.734133
# Epoch 3/100 | Train(sampled) L1:428.898688 L4:0.162746 | Val macro:616.998937 ± 615.748100 | Val micro:4.232873 ± 2.178938
#           >> Test macro:924.928671 ± 923.699734 | micro:5.754781 ± 2.668487
# Epoch 4/100 | Train(sampled) L1:407.805081 L4:0.152019 | Val macro:602.519196 ± 601.266191 | Val micro:4.170000 ± 2.127878
#           >> Test macro:903.207716 ± 901.973938 | micro:5.657849 ± 2.605775
# Epoch 5/100 | Train(sampled) L1:425.246357 L4:0.141562 | Val macro:587.730488 ± 586.480399 | Val micro:4.098908 ± 2.075491
#           >> Test macro:881.009893 ± 879.776439 | micro:5.551918 ± 2.541637
# Epoch 6/100 | Train(sampled) L1:393.206108 L4:0.133001 | Val macro:573.778705 ± 572.551616 | Val micro:3.998110 ± 2.026405
#           >> Test macro:860.096987 ± 858.889929 | micro:5.413194 ± 2.481410
# Epoch 7/100 | Train(sampled) L1:378.204683 L4:0.131812 | Val macro:560.378971 ± 559.161181 | Val micro:3.932912 ± 1.978966
#           >> Test macro:840.001153 ± 838.799540 | micro:5.317905 ± 2.423306
# Epoch 8/100 | Train(sampled) L1:357.166862 L4:0.130836 | Val macro:547.384242 ± 546.179189 | Val micro:3.861910 ± 1.933072
#           >> Test macro:820.522389 ± 819.331644 | micro:5.216189 ± 2.367066
# Epoch 9/100 | Train(sampled) L1:365.639098 L4:0.128760 | Val macro:534.764151 ± 533.601572 | Val micro:3.747000 ± 1.888819
#           >> Test macro:801.666314 ± 800.522898 | micro:5.065546 ± 2.312808
# Epoch 10/100 | Train(sampled) L1:348.223105 L4:0.128872 | Val macro:522.000296 ± 520.860494 | Val micro:3.692032 ± 1.842900
#           >> Test macro:782.365187 ± 781.234021 | micro:4.986256 ± 2.256762
# Epoch 11/100 | Train(sampled) L1:364.829022 L4:0.126030 | Val macro:508.868869 ± 507.817331 | Val micro:3.499023 ± 1.797463
#           >> Test macro:762.840158 ± 761.796149 | micro:4.761336 ± 2.200922
# Epoch 12/100 | Train(sampled) L1:350.235152 L4:0.123224 | Val macro:496.377548 ± 495.402714 | Val micro:3.371403 ± 1.753367
#           >> Test macro:744.087099 ± 743.118946 | micro:4.603049 ± 2.146920
# Epoch 13/100 | Train(sampled) L1:334.619597 L4:0.120490 | Val macro:484.423857 ± 483.509837 | Val micro:3.265041 ± 1.710955
#           >> Test macro:726.121533 ± 725.213536 | micro:4.466283 ± 2.095028
# Epoch 14/100 | Train(sampled) L1:315.022836 L4:0.119268 | Val macro:473.212357 ± 472.305232 | Val micro:3.206878 ± 1.671411
#           >> Test macro:709.370290 ± 708.465097 | micro:4.384506 ± 2.046681
# Epoch 15/100 | Train(sampled) L1:330.833238 L4:0.115756 | Val macro:461.619218 ± 460.732105 | Val micro:3.123909 ± 1.630571
#           >> Test macro:691.939837 ± 691.057199 | micro:4.269806 ± 1.996501
# Epoch 16/100 | Train(sampled) L1:300.818512 L4:0.114761 | Val macro:450.418235 ± 449.467205 | Val micro:3.118669 ± 1.590952
#           >> Test macro:675.050566 ± 674.096089 | micro:4.243192 ± 1.947735
# Epoch 17/100 | Train(sampled) L1:309.149552 L4:0.110611 | Val macro:439.388731 ± 438.519084 | Val micro:2.995522 ± 1.552036
#           >> Test macro:658.558229 ± 657.691573 | micro:4.086693 ± 1.900176
# Epoch 18/100 | Train(sampled) L1:290.936001 L4:0.108976 | Val macro:429.059441 ± 428.192549 | Val micro:2.944444 ± 1.515497
#           >> Test macro:643.008796 ± 642.143043 | micro:4.010998 ± 1.855244
# Epoch 19/100 | Train(sampled) L1:274.396436 L4:0.107415 | Val macro:418.885698 ± 417.898300 | Val micro:2.993050 ± 1.479579
#           >> Test macro:627.754607 ± 626.757584 | micro:4.043758 ± 1.811147
# Epoch 20/100 | Train(sampled) L1:275.135829 L4:0.105303 | Val macro:408.705905 ± 407.817975 | Val micro:2.855638 ± 1.443785
#           >> Test macro:612.540053 ± 611.649572 | micro:3.874756 ± 1.767348
# Epoch 21/100 | Train(sampled) L1:263.167428 L4:0.102279 | Val macro:398.904699 ± 397.975486 | Val micro:2.842177 ± 1.409031
#           >> Test macro:597.701385 ± 596.761721 | micro:3.843201 ± 1.724513
# Epoch 22/100 | Train(sampled) L1:269.721639 L4:0.099370 | Val macro:389.217615 ± 388.359434 | Val micro:2.732662 ± 1.374881
#           >> Test macro:583.222470 ± 582.359200 | micro:3.704758 ± 1.682787
# Epoch 23/100 | Train(sampled) L1:262.402377 L4:0.095793 | Val macro:379.629821 ± 378.770695 | Val micro:2.690696 ± 1.340912
#           >> Test macro:568.762825 ± 567.903938 | micro:3.633357 ± 1.640961
# Epoch 24/100 | Train(sampled) L1:255.997958 L4:0.092625 | Val macro:370.142203 ± 369.275081 | Val micro:2.647860 ± 1.307555
#           >> Test macro:554.593159 ± 553.729487 | micro:3.564453 ± 1.600200
# Epoch 25/100 | Train(sampled) L1:253.972964 L4:0.089505 | Val macro:360.696450 ± 359.838625 | Val micro:2.594837 ± 1.274017
#           >> Test macro:540.362096 ± 539.507479 | micro:3.487241 ± 1.559008
# Epoch 26/100 | Train(sampled) L1:256.165211 L4:0.085740 | Val macro:351.494159 ± 350.634835 | Val micro:2.550776 ± 1.241526
#           >> Test macro:526.429724 ± 525.572299 | micro:3.420564 ± 1.518794
# Epoch 27/100 | Train(sampled) L1:227.217471 L4:0.082864 | Val macro:342.795069 ± 341.862522 | Val micro:2.584287 ± 1.210436
#           >> Test macro:513.547779 ± 512.619769 | micro:3.430006 ± 1.481307
# Epoch 28/100 | Train(sampled) L1:222.883881 L4:0.078403 | Val macro:334.243414 ± 333.378557 | Val micro:2.469786 ± 1.180568
#           >> Test macro:500.679919 ± 499.811229 | micro:3.301869 ± 1.444449
# Epoch 29/100 | Train(sampled) L1:219.204313 L4:0.074721 | Val macro:326.144223 ± 325.204653 | Val micro:2.487280 ± 1.152301
#           >> Test macro:488.475362 ± 487.534691 | micro:3.297492 ± 1.409393
# Epoch 30/100 | Train(sampled) L1:208.380472 L4:0.070628 | Val macro:318.133525 ± 317.247122 | Val micro:2.400157 ± 1.124077
#           >> Test macro:476.388809 ± 475.501308 | micro:3.189819 ± 1.374558
# Epoch 31/100 | Train(sampled) L1:222.346346 L4:0.064495 | Val macro:309.907267 ± 309.033311 | Val micro:2.348910 ± 1.095014
#           >> Test macro:464.195963 ± 463.324716 | micro:3.115585 ± 1.339357
# Epoch 32/100 | Train(sampled) L1:208.572616 L4:0.059679 | Val macro:301.749550 ± 300.914349 | Val micro:2.275364 ± 1.066158
#           >> Test macro:451.937233 ± 451.103365 | micro:3.021913 ± 1.303994
# Epoch 33/100 | Train(sampled) L1:193.053123 L4:0.054260 | Val macro:294.027845 ± 293.080071 | Val micro:2.335405 ± 1.038969
#           >> Test macro:440.361865 ± 439.415462 | micro:3.063505 ± 1.270655
# Epoch 34/100 | Train(sampled) L1:199.151594 L4:0.049168 | Val macro:286.154737 ± 285.320253 | Val micro:2.195556 ± 1.011205
#           >> Test macro:428.600795 ± 427.764373 | micro:2.906452 ± 1.236778
# Epoch 35/100 | Train(sampled) L1:196.368141 L4:0.043569 | Val macro:278.259117 ± 277.419130 | Val micro:2.161616 ± 0.983411
#           >> Test macro:416.877578 ± 416.037115 | micro:2.852431 ± 1.202920
# Epoch 36/100 | Train(sampled) L1:181.230208 L4:0.039241 | Val macro:270.616155 ± 269.772461 | Val micro:2.127548 ± 0.956430
#           >> Test macro:405.344459 ± 404.502096 | micro:2.797260 ± 1.169657
# Epoch 37/100 | Train(sampled) L1:183.162520 L4:0.033357 | Val macro:263.038327 ± 262.212698 | Val micro:2.070738 ± 0.929585
#           >> Test macro:394.087021 ± 393.262009 | micro:2.721648 ± 1.137163
# Epoch 38/100 | Train(sampled) L1:166.511125 L4:0.028627 | Val macro:256.009463 ± 254.955083 | Val micro:2.261764 ± 0.903647
#           >> Test macro:383.341598 ± 382.303678 | micro:2.877193 ± 1.105302
# Epoch 39/100 | Train(sampled) L1:172.873098 L4:0.026303 | Val macro:248.610004 ± 247.622375 | Val micro:2.143856 ± 0.878888
#           >> Test macro:372.480885 ± 371.489950 | micro:2.763520 ± 1.074999
# Epoch 40/100 | Train(sampled) L1:164.491734 L4:0.024677 | Val macro:241.223774 ± 240.374466 | Val micro:1.985595 ± 0.852602
#           >> Test macro:361.511067 ± 360.655628 | micro:2.589034 ± 1.043250
# Epoch 41/100 | Train(sampled) L1:155.793916 L4:0.021389 | Val macro:233.738113 ± 232.914233 | Val micro:1.922800 ± 0.826557
#           >> Test macro:350.255695 ± 349.435791 | micro:2.498393 ± 1.011058
# Epoch 42/100 | Train(sampled) L1:152.759141 L4:0.017532 | Val macro:226.723429 ± 225.887445 | Val micro:1.897889 ± 0.801834
#           >> Test macro:339.762937 ± 338.927183 | micro:2.459299 ± 0.980834
# Epoch 43/100 | Train(sampled) L1:147.953366 L4:0.014177 | Val macro:219.556249 ± 218.733946 | Val micro:1.852361 ± 0.776251
#           >> Test macro:328.950041 ± 328.136044 | micro:2.387260 ± 0.949454
# Epoch 44/100 | Train(sampled) L1:146.073587 L4:0.012586 | Val macro:212.291686 ± 211.478901 | Val micro:1.807161 ± 0.750793
#           >> Test macro:318.089399 ± 317.279169 | micro:2.329894 ± 0.918287
# Epoch 45/100 | Train(sampled) L1:140.618438 L4:0.011048 | Val macro:205.197074 ± 204.368255 | Val micro:1.787505 ± 0.725875
#           >> Test macro:307.366068 ± 306.538165 | micro:2.294117 ± 0.887299
# Epoch 46/100 | Train(sampled) L1:132.572162 L4:0.009929 | Val macro:198.201802 ± 197.362564 | Val micro:1.763136 ± 0.701049
#           >> Test macro:296.922104 ± 296.099873 | micro:2.237262 ± 0.857039
# Epoch 47/100 | Train(sampled) L1:125.125436 L4:0.008385 | Val macro:191.729992 ± 190.925657 | Val micro:1.696406 ± 0.678195
#           >> Test macro:287.217331 ± 286.420870 | micro:2.162346 ± 0.829192
# Epoch 48/100 | Train(sampled) L1:127.208689 L4:0.006727 | Val macro:185.171842 ± 184.348614 | Val micro:1.682012 ± 0.655424
#           >> Test macro:277.390932 ± 276.574649 | micro:2.132937 ± 0.801050
# Epoch 49/100 | Train(sampled) L1:113.040059 L4:0.005805 | Val macro:178.686057 ± 177.876769 | Val micro:1.638333 ± 0.632158
#           >> Test macro:267.635189 ± 266.828939 | micro:2.075670 ± 0.772911
# Epoch 50/100 | Train(sampled) L1:119.001441 L4:0.005191 | Val macro:171.921879 ± 171.104939 | Val micro:1.608338 ± 0.608662
#           >> Test macro:257.615985 ± 256.790183 | micro:2.040882 ± 0.744370
# Epoch 51/100 | Train(sampled) L1:102.495542 L4:0.005811 | Val macro:165.682115 ± 164.846361 | Val micro:1.596407 ± 0.586192
#           >> Test macro:248.208459 ± 247.358495 | micro:2.017453 ± 0.716821
# Epoch 52/100 | Train(sampled) L1:111.272717 L4:0.006035 | Val macro:159.016104 ± 158.212379 | Val micro:1.532480 ± 0.563316
#           >> Test macro:238.208694 ± 237.402219 | micro:1.926966 ± 0.688307
# Epoch 53/100 | Train(sampled) L1:104.192498 L4:0.004511 | Val macro:152.381581 ± 151.519203 | Val micro:1.548285 ± 0.540485
#           >> Test macro:228.260548 ± 227.397051 | micro:1.925250 ± 0.659887
# Epoch 54/100 | Train(sampled) L1:100.776484 L4:0.003554 | Val macro:145.945385 ± 145.117808 | Val micro:1.489550 ± 0.516819
#           >> Test macro:218.543119 ± 217.721736 | micro:1.842047 ± 0.631345
# Epoch 55/100 | Train(sampled) L1:91.618339 L4:0.003224 | Val macro:139.762522 ± 138.928898 | Val micro:1.468314 ± 0.495348
#           >> Test macro:209.235188 ± 208.410768 | micro:1.802471 ± 0.604708
# Epoch 56/100 | Train(sampled) L1:86.834966 L4:0.002872 | Val macro:133.740000 ± 132.915907 | Val micro:1.422505 ± 0.474478
#           >> Test macro:200.316392 ± 199.486349 | micro:1.756487 ± 0.579456
# Epoch 57/100 | Train(sampled) L1:87.400561 L4:0.002634 | Val macro:127.777160 ± 126.876083 | Val micro:1.473997 ± 0.452925
#           >> Test macro:191.216298 ± 190.334502 | micro:1.768151 ± 0.552510
# Epoch 58/100 | Train(sampled) L1:81.985647 L4:0.002988 | Val macro:121.530531 ± 120.715716 | Val micro:1.354041 ± 0.431494
#           >> Test macro:182.032057 ± 181.212343 | micro:1.656387 ± 0.526669
# Epoch 59/100 | Train(sampled) L1:79.460407 L4:0.003190 | Val macro:115.719404 ± 114.869397 | Val micro:1.359532 ± 0.411930
#           >> Test macro:173.275884 ± 172.430369 | micro:1.640067 ± 0.501958
# Epoch 60/100 | Train(sampled) L1:73.341109 L4:0.003014 | Val macro:110.158476 ± 109.353350 | Val micro:1.288361 ± 0.392169
#           >> Test macro:164.927578 ± 164.130762 | micro:1.550701 ± 0.477702
# Epoch 61/100 | Train(sampled) L1:70.107338 L4:0.002614 | Val macro:104.664480 ± 103.862318 | Val micro:1.258693 ± 0.372994
#           >> Test macro:156.680690 ± 155.890455 | micro:1.504079 ± 0.454354
# Epoch 62/100 | Train(sampled) L1:66.887224 L4:0.002614 | Val macro:99.275699 ± 98.398047 | Val micro:1.299699 ± 0.354793
#           >> Test macro:148.662705 ± 147.786609 | micro:1.542036 ± 0.431961
# Epoch 63/100 | Train(sampled) L1:66.057363 L4:0.002616 | Val macro:93.805674 ± 92.975338 | Val micro:1.227421 ± 0.335889
#           >> Test macro:140.420364 ± 139.599824 | micro:1.448238 ± 0.408312
# Epoch 64/100 | Train(sampled) L1:60.674996 L4:0.002064 | Val macro:88.468735 ± 87.670859 | Val micro:1.173426 ± 0.317238
#           >> Test macro:132.464813 ± 131.687029 | micro:1.371378 ± 0.385284
# Epoch 65/100 | Train(sampled) L1:58.218465 L4:0.001718 | Val macro:83.305353 ± 82.485095 | Val micro:1.165226 ± 0.299509
#           >> Test macro:124.677750 ± 123.876720 | micro:1.351175 ± 0.363401
# Epoch 66/100 | Train(sampled) L1:52.263313 L4:0.001900 | Val macro:78.459657 ± 77.650633 | Val micro:1.132017 ± 0.283279
#           >> Test macro:117.385080 ± 116.592563 | micro:1.307764 ± 0.343242
# Epoch 67/100 | Train(sampled) L1:47.456586 L4:0.001664 | Val macro:73.780276 ± 72.969046 | Val micro:1.110419 ± 0.266927
#           >> Test macro:110.392859 ± 109.588777 | micro:1.282913 ± 0.323336
# Epoch 68/100 | Train(sampled) L1:46.082934 L4:0.001490 | Val macro:69.064356 ± 68.250986 | Val micro:1.089323 ± 0.249517
#           >> Test macro:103.408833 ± 102.607925 | micro:1.246018 ± 0.302539
# Epoch 69/100 | Train(sampled) L1:45.131985 L4:0.001964 | Val macro:64.500478 ± 63.706190 | Val micro:1.050309 ± 0.233949
#           >> Test macro:96.383017 ± 95.600779 | micro:1.194211 ± 0.282325
# Epoch 70/100 | Train(sampled) L1:40.340170 L4:0.001558 | Val macro:59.960386 ± 59.115064 | Val micro:1.079095 ± 0.218843
#           >> Test macro:89.551770 ± 88.737454 | micro:1.195698 ± 0.262462
# Epoch 71/100 | Train(sampled) L1:39.086745 L4:0.001538 | Val macro:55.772843 ± 54.882672 | Val micro:1.103862 ± 0.204360
#           >> Test macro:83.233981 ± 82.373814 | micro:1.209340 ± 0.245125
# Epoch 72/100 | Train(sampled) L1:35.349050 L4:0.001532 | Val macro:51.480077 ± 50.647284 | Val micro:1.018057 ± 0.192595
#           >> Test macro:76.901313 ± 76.091082 | micro:1.121049 ± 0.229491
# Epoch 73/100 | Train(sampled) L1:31.973262 L4:0.001708 | Val macro:47.640077 ± 46.794009 | Val micro:1.011391 ± 0.179953
#           >> Test macro:71.169182 ± 70.350631 | micro:1.101793 ± 0.213454
# Epoch 74/100 | Train(sampled) L1:30.530151 L4:0.001612 | Val macro:43.990929 ± 43.122438 | Val micro:1.019717 ± 0.164815
#           >> Test macro:65.578821 ± 64.757202 | micro:1.082082 ± 0.195449
# Epoch 75/100 | Train(sampled) L1:27.481031 L4:0.001372 | Val macro:40.238437 ± 39.442998 | Val micro:0.929985 ± 0.154936
#           >> Test macro:60.025179 ± 59.268716 | micro:0.990852 ± 0.181789
# Epoch 76/100 | Train(sampled) L1:25.313461 L4:0.001494 | Val macro:36.788271 ± 35.976627 | Val micro:0.925879 ± 0.144864
#           >> Test macro:54.821050 ± 54.039919 | micro:0.984860 ± 0.168210
# Epoch 77/100 | Train(sampled) L1:24.030747 L4:0.001460 | Val macro:33.426787 ± 32.577683 | Val micro:0.953388 ± 0.133212
#           >> Test macro:49.688500 ± 48.872947 | micro:1.000093 ± 0.153833
# Epoch 78/100 | Train(sampled) L1:20.800051 L4:0.001472 | Val macro:30.046792 ± 29.223205 | Val micro:0.901892 ± 0.123019
#           >> Test macro:44.713762 ± 43.908427 | micro:0.955848 ± 0.142307
# Epoch 79/100 | Train(sampled) L1:19.457753 L4:0.001199 | Val macro:26.979730 ± 26.110434 | Val micro:0.928105 ± 0.116870
#           >> Test macro:40.165718 ± 39.313191 | micro:0.975808 ± 0.132296
# Epoch 80/100 | Train(sampled) L1:17.362315 L4:0.001535 | Val macro:24.051279 ± 23.231471 | Val micro:0.876448 ± 0.102510
#           >> Test macro:35.695019 ± 34.893225 | micro:0.913247 ± 0.115818
# Epoch 81/100 | Train(sampled) L1:14.185135 L4:0.001191 | Val macro:21.432862 ± 20.583951 | Val micro:0.882534 ± 0.102507
#           >> Test macro:31.813600 ± 30.990772 | micro:0.908088 ± 0.111965
# Epoch 82/100 | Train(sampled) L1:13.262682 L4:0.001243 | Val macro:18.914387 ± 18.098673 | Val micro:0.840974 ± 0.090970
#           >> Test macro:28.054373 ± 27.263177 | micro:0.861645 ± 0.100426
# Epoch 83/100 | Train(sampled) L1:11.426658 L4:0.001396 | Val macro:16.575523 ± 15.750124 | Val micro:0.839199 ± 0.086892
#           >> Test macro:24.556991 ± 23.778613 | micro:0.833337 ± 0.090664
# Epoch 84/100 | Train(sampled) L1:10.177568 L4:0.001330 | Val macro:14.389586 ± 13.542595 | Val micro:0.851493 ± 0.081733
#           >> Test macro:21.196667 ± 20.370176 | micro:0.863665 ± 0.085009
# Epoch 85/100 | Train(sampled) L1:8.876475 L4:0.001310 | Val macro:12.325935 ± 11.504698 | Val micro:0.813943 ± 0.079261
#           >> Test macro:18.039102 ± 17.273980 | micro:0.789200 ± 0.077739
# Epoch 86/100 | Train(sampled) L1:7.977279 L4:0.001113 | Val macro:10.412942 ± 9.583192 | Val micro:0.814845 ± 0.077599
#           >> Test macro:15.240120 ± 14.427488 | micro:0.819727 ± 0.075719
# Epoch 87/100 | Train(sampled) L1:6.529996 L4:0.001044 | Val macro:8.729333 ± 7.910147 | Val micro:0.797378 ± 0.074579
#           >> Test macro:12.741599 ± 11.971432 | micro:0.769617 ± 0.069446
# Epoch 88/100 | Train(sampled) L1:5.489383 L4:0.001196 | Val macro:7.223473 ± 6.411884 | Val micro:0.783306 ± 0.071550
#           >> Test macro:10.463981 ± 9.709191 | micro:0.743695 ± 0.062602
# Epoch 89/100 | Train(sampled) L1:4.319231 L4:0.001163 | Val macro:5.916847 ± 5.089186 | Val micro:0.791490 ± 0.068090
#           >> Test macro:8.531516 ± 7.727393 | micro:0.777722 ± 0.069719
# Epoch 90/100 | Train(sampled) L1:3.488269 L4:0.001035 | Val macro:4.758022 ± 3.967433 | Val micro:0.755012 ± 0.066049
#           >> Test macro:6.811875 ± 6.053507 | micro:0.730669 ± 0.062019
# Epoch 91/100 | Train(sampled) L1:2.856093 L4:0.000945 | Val macro:3.803072 ± 2.988140 | Val micro:0.774814 ± 0.070773
#           >> Test macro:5.428197 ± 4.644569 | micro:0.747403 ± 0.068004
# Epoch 92/100 | Train(sampled) L1:2.235472 L4:0.001156 | Val macro:3.034461 ± 2.245962 | Val micro:0.751386 ± 0.066224
#           >> Test macro:4.098457 ± 3.344748 | micro:0.716848 ± 0.063504
# Epoch 93/100 | Train(sampled) L1:1.681254 L4:0.001003 | Val macro:2.380424 ± 1.570399 | Val micro:0.776419 ± 0.072705
#           >> Test macro:3.108974 ± 2.335769 | micro:0.734539 ± 0.067108
# Epoch 94/100 | Train(sampled) L1:1.325141 L4:0.001002 | Val macro:1.830931 ± 1.044087 | Val micro:0.764894 ± 0.068349
#           >> Test macro:2.289978 ± 1.535945 | micro:0.722141 ± 0.063790
# Epoch 95/100 | Train(sampled) L1:1.029866 L4:0.001082 | Val macro:1.430060 ± 0.667769 | Val micro:0.765959 ± 0.067878
#           >> Test macro:1.677044 ± 0.928664 | micro:0.732287 ± 0.063070
# Epoch 96/100 | Train(sampled) L1:0.772565 L4:0.001112 | Val macro:1.149639 ± 0.439587 | Val micro:0.748613 ± 0.064471
#           >> Test macro:1.210401 ± 0.511433 | micro:0.722512 ± 0.059078
# Epoch 97/100 | Train(sampled) L1:0.649613 L4:0.000897 | Val macro:0.911682 ± 0.309641 | Val micro:0.754361 ± 0.066480
#           >> Test macro:0.886876 ± 0.308276 | micro:0.705476 ± 0.059820
# Epoch 98/100 | Train(sampled) L1:0.541731 L4:0.000901 | Val macro:0.744998 ± 0.321940 | Val micro:0.773252 ± 0.062459
#           >> Test macro:0.725831 ± 0.305030 | micro:0.728208 ± 0.059192
# Epoch 99/100 | Train(sampled) L1:0.531040 L4:0.000881 | Val macro:0.791916 ± 0.288708 | Val micro:0.752261 ± 0.064650
#           >> Test macro:0.612956 ± 0.325297 | micro:0.711649 ± 0.059972
# Epoch 100/100 | Train(sampled) L1:0.510600 L4:0.000856 | Val macro:0.725179 ± 0.336584 | Val micro:0.774521 ± 0.066894
#           >> Test macro:0.594687 ± 0.357233 | micro:0.723179 ± 0.059632
# TEST RESULTS | macro: 0.594687 ± 0.357233 | micro: 0.723179 ± 0.059632
#           >> per_group (weighted SE): {0: '1.307626 ± 0.134283 (n=777)', 1: '0.197793 ± 0.140632 (n=3)', 5: '0.278642 ± 0.011689 (n=1018)'}
# GRUPOS (total): {0: 3886, 1: 15, 5: 5093}
# GRUPOS (train): {0: 2332, 1: 9, 5: 3056}
# GRUPOS (valid): {0: 777, 1: 3, 5: 1019}
# GRUPOS (test):  {0: 777, 1: 3, 5: 1018}
# /root/coppe/3Wve/lib/python3.12/site-packages/torch/nn/modules/transformer.py:382: UserWarning:
#
# enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
# Epoch 1/100 | Train(sampled) L1:436.715384 L4:0.409740 | Val macro:648.645583 ± 647.323665 | Val micro:4.476356 ± 2.290222
#           >> Test macro:972.102087 ± 970.798425 | micro:6.079661 ± 2.804238
# Epoch 2/100 | Train(sampled) L1:438.411627 L4:0.207387 | Val macro:630.170841 ± 628.930906 | Val micro:4.289777 ± 2.225465
#           >> Test macro:944.722584 ± 943.505128 | micro:5.844368 ± 2.725619
# Epoch 3/100 | Train(sampled) L1:447.512932 L4:0.157334 | Val macro:615.466343 ± 614.205544 | Val micro:4.226258 ± 2.173661
#           >> Test macro:922.739116 ± 921.504076 | micro:5.741266 ± 2.662235
# Epoch 4/100 | Train(sampled) L1:436.688060 L4:0.149086 | Val macro:600.968372 ± 599.710816 | Val micro:4.161546 ± 2.122453
#           >> Test macro:900.954941 ± 899.719357 | micro:5.643387 ± 2.599310
# Epoch 5/100 | Train(sampled) L1:411.481878 L4:0.141906 | Val macro:586.119847 ± 584.885303 | Val micro:4.062759 ± 2.070128
#           >> Test macro:878.731920 ± 877.520001 | micro:5.507109 ± 2.535205
# Epoch 6/100 | Train(sampled) L1:391.583633 L4:0.138881 | Val macro:572.334237 ± 571.138900 | Val micro:3.980142 ± 2.021192
#           >> Test macro:858.086829 ± 856.903524 | micro:5.399698 ± 2.475489
# Epoch 7/100 | Train(sampled) L1:395.586479 L4:0.137846 | Val macro:559.206984 ± 557.990150 | Val micro:3.963639 ± 1.974179
#           >> Test macro:838.300734 ± 837.085896 | micro:5.358454 ± 2.418033
# Epoch 8/100 | Train(sampled) L1:356.370441 L4:0.135860 | Val macro:546.470365 ± 545.321395 | Val micro:3.833716 ± 1.929065
#           >> Test macro:819.226413 ± 818.082574 | micro:5.192848 ± 2.363058
# Epoch 9/100 | Train(sampled) L1:351.407479 L4:0.134740 | Val macro:533.669827 ± 532.667319 | Val micro:3.581355 ± 1.885038
#           >> Test macro:800.203228 ± 799.205652 | micro:4.908788 ± 2.308932
# Epoch 10/100 | Train(sampled) L1:353.388349 L4:0.134064 | Val macro:521.006155 ± 520.096476 | Val micro:3.444878 ± 1.840162
#           >> Test macro:781.307908 ± 780.402066 | micro:4.741407 ± 2.254361
# Epoch 11/100 | Train(sampled) L1:348.530651 L4:0.132661 | Val macro:508.394236 ± 507.448833 | Val micro:3.427129 ± 1.795172
#           >> Test macro:762.295927 ± 761.358474 | micro:4.687512 ± 2.199274
# Epoch 12/100 | Train(sampled) L1:353.245372 L4:0.131384 | Val macro:495.956702 ± 495.064779 | Val micro:3.301713 ± 1.751728
#           >> Test macro:743.767728 ± 742.883303 | micro:4.532015 ± 2.146024
# Epoch 13/100 | Train(sampled) L1:343.908804 L4:0.130551 | Val macro:484.009899 ± 483.125669 | Val micro:3.232374 ± 1.709591
#           >> Test macro:726.024213 ± 725.143117 | micro:4.437883 ± 2.094888
# Epoch 14/100 | Train(sampled) L1:318.148614 L4:0.128295 | Val macro:472.479752 ± 471.608205 | Val micro:3.164566 ± 1.668794
#           >> Test macro:708.675019 ± 707.807383 | micro:4.340126 ± 2.044766
# Epoch 15/100 | Train(sampled) L1:326.024573 L4:0.125981 | Val macro:461.265220 ± 460.360848 | Val micro:3.144431 ± 1.628989
#           >> Test macro:691.858013 ± 690.963426 | micro:4.285624 ± 1.996031
# Epoch 16/100 | Train(sampled) L1:309.721876 L4:0.124437 | Val macro:450.263157 ± 449.373756 | Val micro:3.064738 ± 1.590464
#           >> Test macro:675.363568 ± 674.479518 | micro:4.183715 ± 1.948688
# Epoch 17/100 | Train(sampled) L1:298.178537 L4:0.121660 | Val macro:439.760304 ± 438.904156 | Val micro:2.986640 ± 1.553366
#           >> Test macro:659.571108 ± 658.720965 | micro:4.078160 ± 1.903109
# Epoch 18/100 | Train(sampled) L1:299.070542 L4:0.118774 | Val macro:428.926830 ± 428.044929 | Val micro:2.951547 ± 1.515092
#           >> Test macro:643.355191 ± 642.473293 | micro:4.021835 ± 1.856301
# Epoch 19/100 | Train(sampled) L1:297.825130 L4:0.115985 | Val macro:418.514344 ± 417.649564 | Val micro:2.892279 ± 1.478214
#           >> Test macro:627.774720 ± 626.911120 | micro:3.934701 ± 1.811289
# Epoch 20/100 | Train(sampled) L1:279.617776 L4:0.114065 | Val macro:408.812289 ± 407.918915 | Val micro:2.860871 ± 1.444106
#           >> Test macro:613.265508 ± 612.374705 | micro:3.879014 ± 1.769512
# Epoch 21/100 | Train(sampled) L1:281.642450 L4:0.111201 | Val macro:399.001015 ± 398.160019 | Val micro:2.768568 ± 1.409366
#           >> Test macro:598.542583 ± 597.697150 | micro:3.767402 ± 1.726950
# Epoch 22/100 | Train(sampled) L1:268.445907 L4:0.108300 | Val macro:389.486840 ± 388.610196 | Val micro:2.749130 ± 1.375801
#           >> Test macro:584.203912 ± 583.325131 | micro:3.722469 ± 1.685575
# Epoch 23/100 | Train(sampled) L1:263.590620 L4:0.105614 | Val macro:380.208319 ± 379.294577 | Val micro:2.734882 ± 1.343138
#           >> Test macro:570.278854 ± 569.371271 | micro:3.677781 ± 1.645436
# Epoch 24/100 | Train(sampled) L1:259.720729 L4:0.101759 | Val macro:370.829319 ± 369.989349 | Val micro:2.625089 ± 1.309906
#           >> Test macro:556.255769 ± 555.416558 | micro:3.549031 ± 1.604945
# Epoch 25/100 | Train(sampled) L1:250.459090 L4:0.097849 | Val macro:362.089190 ± 361.239350 | Val micro:2.593392 ± 1.278933
#           >> Test macro:543.091070 ± 542.245029 | micro:3.491774 ± 1.566841
# Epoch 26/100 | Train(sampled) L1:247.529311 L4:0.094141 | Val macro:353.232610 ± 352.175526 | Val micro:2.728640 ± 1.247637
#           >> Test macro:529.734198 ± 528.664549 | micro:3.620120 ± 1.528304
# Epoch 27/100 | Train(sampled) L1:246.084126 L4:0.090762 | Val macro:344.341417 ± 343.509049 | Val micro:2.484645 ± 1.216508
#           >> Test macro:516.626155 ± 515.791742 | micro:3.345209 ± 1.490688
# Epoch 28/100 | Train(sampled) L1:236.267887 L4:0.086100 | Val macro:335.977657 ± 335.100185 | Val micro:2.481509 ± 1.187017
#           >> Test macro:503.959807 ± 503.081373 | micro:3.320101 ± 1.454150
# Epoch 29/100 | Train(sampled) L1:230.569657 L4:0.081612 | Val macro:327.468786 ± 326.644280 | Val micro:2.393997 ± 1.157003
#           >> Test macro:491.235305 ± 490.414147 | micro:3.206646 ± 1.417485
# Epoch 30/100 | Train(sampled) L1:219.488816 L4:0.076116 | Val macro:319.118891 ± 318.294144 | Val micro:2.349875 ± 1.127562
#           >> Test macro:478.753736 ± 477.931649 | micro:3.142455 ± 1.381486
# Epoch 31/100 | Train(sampled) L1:205.432621 L4:0.070401 | Val macro:311.421773 ± 310.591936 | Val micro:2.316135 ± 1.100524
#           >> Test macro:467.320532 ± 466.497048 | micro:3.086832 ± 1.348582
# Epoch 32/100 | Train(sampled) L1:205.741981 L4:0.063560 | Val macro:303.744245 ± 302.937594 | Val micro:2.258628 ± 1.073210
#           >> Test macro:455.681230 ± 454.876575 | micro:3.012830 ± 1.314959
# Epoch 33/100 | Train(sampled) L1:199.543983 L4:0.057611 | Val macro:295.905160 ± 295.061594 | Val micro:2.257248 ± 1.045405
#           >> Test macro:443.942352 ± 443.110594 | micro:2.982840 ± 1.281013
# Epoch 34/100 | Train(sampled) L1:187.806091 L4:0.051394 | Val macro:288.241455 ± 287.390839 | Val micro:2.224901 ± 1.018312
#           >> Test macro:432.702219 ± 431.856008 | micro:2.939555 ± 1.248494
# Epoch 35/100 | Train(sampled) L1:195.059670 L4:0.044901 | Val macro:280.559109 ± 279.687303 | Val micro:2.203217 ± 0.991429
#           >> Test macro:421.001164 ± 420.116741 | micro:2.913637 ± 1.215034
# Epoch 36/100 | Train(sampled) L1:181.246573 L4:0.039248 | Val macro:273.080934 ± 272.236773 | Val micro:2.141554 ± 0.964686
#           >> Test macro:409.780918 ± 408.936757 | micro:2.821110 ± 1.182306
# Epoch 37/100 | Train(sampled) L1:177.366927 L4:0.034092 | Val macro:265.752605 ± 264.941549 | Val micro:2.070098 ± 0.939184
#           >> Test macro:398.937120 ± 398.116568 | micro:2.740907 ± 1.151335
# Epoch 38/100 | Train(sampled) L1:168.600111 L4:0.029289 | Val macro:258.174134 ± 257.306216 | Val micro:2.087985 ± 0.912437
#           >> Test macro:387.477113 ± 386.599890 | micro:2.739940 ± 1.118249
# Epoch 39/100 | Train(sampled) L1:173.731065 L4:0.026333 | Val macro:250.846262 ± 250.043255 | Val micro:1.989450 ± 0.886609
#           >> Test macro:376.559327 ± 375.753897 | micro:2.616432 ± 1.086850
# Epoch 40/100 | Train(sampled) L1:165.242926 L4:0.022524 | Val macro:243.692750 ± 242.881552 | Val micro:1.959489 ± 0.861510
#           >> Test macro:365.756942 ± 364.944356 | micro:2.567365 ± 1.055844
# Epoch 41/100 | Train(sampled) L1:153.114535 L4:0.018807 | Val macro:236.552023 ± 235.745620 | Val micro:1.921815 ± 0.836141
#           >> Test macro:355.097092 ± 354.289027 | micro:2.512171 ± 1.025012
# Epoch 42/100 | Train(sampled) L1:154.989130 L4:0.015566 | Val macro:229.470721 ± 228.645829 | Val micro:1.906909 ± 0.810989
#           >> Test macro:344.562986 ± 343.730855 | micro:2.484551 ± 0.994562
# Epoch 43/100 | Train(sampled) L1:148.366931 L4:0.013584 | Val macro:222.214884 ± 221.410514 | Val micro:1.846446 ± 0.785478
#           >> Test macro:333.643815 ± 332.824931 | micro:2.412469 ± 0.963183
# Epoch 44/100 | Train(sampled) L1:144.083848 L4:0.012111 | Val macro:215.288715 ± 214.489813 | Val micro:1.807391 ± 0.761248
#           >> Test macro:323.272720 ± 322.463557 | micro:2.352343 ± 0.933369
# Epoch 45/100 | Train(sampled) L1:139.530377 L4:0.010717 | Val macro:208.260917 ± 207.405129 | Val micro:1.828070 ± 0.736233
#           >> Test macro:312.786096 ± 311.914323 | micro:2.361502 ± 0.902955
# Epoch 46/100 | Train(sampled) L1:147.738019 L4:0.009324 | Val macro:200.851765 ± 200.057077 | Val micro:1.731472 ± 0.710275
#           >> Test macro:301.775920 ± 300.977276 | micro:2.235764 ± 0.871267
# Epoch 47/100 | Train(sampled) L1:132.987235 L4:0.007766 | Val macro:194.020436 ± 193.214631 | Val micro:1.707868 ± 0.686381
#           >> Test macro:291.430919 ± 290.625146 | micro:2.191023 ± 0.841714
# Epoch 48/100 | Train(sampled) L1:127.915766 L4:0.006743 | Val macro:187.329518 ± 186.422219 | Val micro:1.768404 ± 0.662743
#           >> Test macro:281.396242 ± 280.478418 | micro:2.245136 ± 0.812838
# Epoch 49/100 | Train(sampled) L1:121.033851 L4:0.006610 | Val macro:180.788392 ± 179.961802 | Val micro:1.665454 ± 0.639191
#           >> Test macro:271.695724 ± 270.870097 | micro:2.114086 ± 0.784496
# Epoch 50/100 | Train(sampled) L1:109.344045 L4:0.006061 | Val macro:174.675196 ± 173.872689 | Val micro:1.607785 ± 0.618429
#           >> Test macro:262.418236 ± 261.611280 | micro:2.046553 ± 0.758291
# Epoch 51/100 | Train(sampled) L1:122.481445 L4:0.005561 | Val macro:167.770049 ± 166.899867 | Val micro:1.636856 ± 0.594002
#           >> Test macro:252.113677 ± 251.231213 | micro:2.066140 ± 0.728580
# Epoch 52/100 | Train(sampled) L1:110.086121 L4:0.005558 | Val macro:161.292025 ± 160.418151 | Val micro:1.604176 ± 0.571351
#           >> Test macro:242.443638 ± 241.555251 | micro:2.019347 ± 0.700971
# Epoch 53/100 | Train(sampled) L1:102.901236 L4:0.005942 | Val macro:155.171008 ± 154.357864 | Val micro:1.521628 ± 0.549003
#           >> Test macro:233.294077 ± 232.467531 | micro:1.919486 ± 0.674004
# Epoch 54/100 | Train(sampled) L1:96.734108 L4:0.005173 | Val macro:149.010462 ± 148.202765 | Val micro:1.487119 ± 0.527552
#           >> Test macro:223.930905 ± 223.125830 | micro:1.854696 ± 0.647072
# Epoch 55/100 | Train(sampled) L1:98.024284 L4:0.004180 | Val macro:142.689019 ± 141.876225 | Val micro:1.460881 ± 0.505147
#           >> Test macro:214.518216 ± 213.694801 | micro:1.824199 ± 0.620242
# Epoch 56/100 | Train(sampled) L1:95.296528 L4:0.003930 | Val macro:136.406359 ± 135.600647 | Val micro:1.418586 ± 0.484020
#           >> Test macro:205.045688 ± 204.226637 | micro:1.769497 ± 0.593695
# Epoch 57/100 | Train(sampled) L1:87.048387 L4:0.003635 | Val macro:130.273968 ± 129.441706 | Val micro:1.413312 ± 0.462742
#           >> Test macro:195.925886 ± 195.087935 | micro:1.742985 ± 0.567317
# Epoch 58/100 | Train(sampled) L1:79.042482 L4:0.004011 | Val macro:124.660626 ± 123.854708 | Val micro:1.359918 ± 0.443363
#           >> Test macro:187.586301 ± 186.788727 | micro:1.663461 ± 0.543386
# Epoch 59/100 | Train(sampled) L1:80.064372 L4:0.003761 | Val macro:118.922910 ± 118.107067 | Val micro:1.342007 ± 0.423078
#           >> Test macro:178.933327 ± 178.125717 | micro:1.630128 ± 0.518409
# Epoch 60/100 | Train(sampled) L1:80.494720 L4:0.003029 | Val macro:112.989474 ± 112.186538 | Val micro:1.298507 ± 0.402429
#           >> Test macro:170.094125 ± 169.310420 | micro:1.563553 ± 0.493188
# Epoch 61/100 | Train(sampled) L1:70.236419 L4:0.002586 | Val macro:107.421136 ± 106.574618 | Val micro:1.316685 ± 0.381728
#           >> Test macro:161.843051 ± 161.000769 | micro:1.582703 ± 0.468952
# Epoch 62/100 | Train(sampled) L1:71.448407 L4:0.002787 | Val macro:102.000317 ± 101.137914 | Val micro:1.295557 ± 0.364708
#           >> Test macro:153.672108 ± 152.825289 | micro:1.537704 ± 0.446923
# Epoch 63/100 | Train(sampled) L1:66.882787 L4:0.002858 | Val macro:96.478946 ± 95.671290 | Val micro:1.220286 ± 0.344975
#           >> Test macro:145.450071 ± 144.643132 | micro:1.460516 ± 0.423007
# Epoch 64/100 | Train(sampled) L1:61.055483 L4:0.002637 | Val macro:91.299669 ± 90.457779 | Val micro:1.229243 ± 0.326987
#           >> Test macro:137.467902 ± 136.624765 | micro:1.458128 ± 0.400409
# Epoch 65/100 | Train(sampled) L1:64.221457 L4:0.002517 | Val macro:86.212218 ± 85.281943 | Val micro:1.292162 ± 0.307414
#           >> Test macro:129.763818 ± 128.859956 | micro:1.481629 ± 0.376682
# Epoch 66/100 | Train(sampled) L1:55.555910 L4:0.002553 | Val macro:81.032460 ± 80.193245 | Val micro:1.171744 ± 0.291553
#           >> Test macro:122.069064 ± 121.242522 | micro:1.362684 ± 0.356609
# Epoch 67/100 | Train(sampled) L1:53.200431 L4:0.002493 | Val macro:76.087129 ± 75.271690 | Val micro:1.124598 ± 0.274994
#           >> Test macro:114.592393 ± 113.795829 | micro:1.297301 ± 0.335515
# Epoch 68/100 | Train(sampled) L1:49.366887 L4:0.002054 | Val macro:71.519688 ± 70.707211 | Val micro:1.104378 ± 0.258884
#           >> Test macro:107.825823 ± 107.020775 | micro:1.273845 ± 0.316155
# Epoch 69/100 | Train(sampled) L1:46.410168 L4:0.002135 | Val macro:66.980653 ± 66.131658 | Val micro:1.108580 ± 0.244385
#           >> Test macro:100.970417 ± 100.143945 | micro:1.255960 ± 0.297474
# Epoch 70/100 | Train(sampled) L1:43.170616 L4:0.002529 | Val macro:62.555542 ± 61.752617 | Val micro:1.048249 ± 0.227350
#           >> Test macro:94.243038 ± 93.450799 | micro:1.193001 ± 0.277678
# Epoch 71/100 | Train(sampled) L1:41.517316 L4:0.002169 | Val macro:58.087654 ± 57.268464 | Val micro:1.040821 ± 0.212067
#           >> Test macro:87.553396 ± 86.738343 | micro:1.180599 ± 0.259686
# Epoch 72/100 | Train(sampled) L1:35.922888 L4:0.002377 | Val macro:54.041211 ± 53.209351 | Val micro:1.029336 ± 0.197708
#           >> Test macro:81.507941 ± 80.690053 | micro:1.150764 ± 0.242387
# Epoch 73/100 | Train(sampled) L1:34.574981 L4:0.002276 | Val macro:50.010663 ± 49.204300 | Val micro:0.989634 ± 0.185672
#           >> Test macro:75.415821 ± 74.620154 | micro:1.103644 ± 0.225434
# Epoch 74/100 | Train(sampled) L1:31.634244 L4:0.001986 | Val macro:46.075035 ± 45.253773 | Val micro:0.978919 ± 0.174164
#           >> Test macro:69.577060 ± 68.785586 | micro:1.067470 ± 0.209886
# Epoch 75/100 | Train(sampled) L1:27.629406 L4:0.001867 | Val macro:42.365155 ± 41.507076 | Val micro:0.993862 ± 0.164731
#           >> Test macro:63.862789 ± 63.016042 | micro:1.087547 ± 0.196150
# Epoch 76/100 | Train(sampled) L1:28.250547 L4:0.001742 | Val macro:38.783058 ± 37.933229 | Val micro:0.968532 ± 0.151208
#           >> Test macro:58.427236 ± 57.608836 | micro:1.035939 ± 0.180590
# Epoch 77/100 | Train(sampled) L1:25.138868 L4:0.001627 | Val macro:35.387244 ± 34.585267 | Val micro:0.911854 ± 0.138291
#           >> Test macro:53.235071 ± 52.446085 | micro:0.985481 ± 0.165333
# Epoch 78/100 | Train(sampled) L1:23.418396 L4:0.001850 | Val macro:31.959370 ± 31.150220 | Val micro:0.899855 ± 0.125923
#           >> Test macro:48.233539 ± 47.427024 | micro:0.974648 ± 0.152037
# Epoch 79/100 | Train(sampled) L1:20.988074 L4:0.001727 | Val macro:28.858564 ± 28.016045 | Val micro:0.918778 ± 0.119407
#           >> Test macro:43.485064 ± 42.660835 | micro:0.972219 ± 0.139921
# Epoch 80/100 | Train(sampled) L1:18.096826 L4:0.001729 | Val macro:25.929776 ± 25.059615 | Val micro:0.928848 ± 0.109129
#           >> Test macro:39.209189 ± 38.324575 | micro:1.004165 ± 0.132533
# Epoch 81/100 | Train(sampled) L1:15.834980 L4:0.001673 | Val macro:23.205993 ± 22.376466 | Val micro:0.875850 ± 0.101257
#           >> Test macro:35.093788 ± 34.277936 | micro:0.919006 ± 0.117971
# Epoch 82/100 | Train(sampled) L1:13.673685 L4:0.001429 | Val macro:20.735494 ± 19.925126 | Val micro:0.845410 ± 0.097772
#           >> Test macro:31.274960 ± 30.494108 | micro:0.868377 ± 0.110674
# Epoch 83/100 | Train(sampled) L1:12.885488 L4:0.001410 | Val macro:18.314242 ± 17.482643 | Val micro:0.850299 ± 0.094240
#           >> Test macro:27.580822 ± 26.779403 | micro:0.866350 ± 0.104212
# Epoch 84/100 | Train(sampled) L1:11.174117 L4:0.001553 | Val macro:16.036364 ± 15.156272 | Val micro:0.888050 ± 0.084596
#           >> Test macro:24.115858 ± 23.266877 | micro:0.895091 ± 0.094268
# Epoch 85/100 | Train(sampled) L1:9.894706 L4:0.001608 | Val macro:13.841954 ± 13.014817 | Val micro:0.833305 ± 0.082338
#           >> Test macro:20.744151 ± 19.934719 | micro:0.847628 ± 0.087533
# Epoch 86/100 | Train(sampled) L1:8.948716 L4:0.001837 | Val macro:11.750307 ± 10.951272 | Val micro:0.796554 ± 0.074110
#           >> Test macro:17.725697 ± 16.915217 | micro:0.830730 ± 0.083054
# Epoch 87/100 | Train(sampled) L1:6.895283 L4:0.001765 | Val macro:9.983915 ± 9.179883 | Val micro:0.788802 ± 0.072466
#           >> Test macro:15.002892 ± 14.203850 | micro:0.804544 ± 0.079401
# Epoch 88/100 | Train(sampled) L1:6.051353 L4:0.001521 | Val macro:8.446808 ± 7.483129 | Val micro:0.922071 ± 0.082425
#           >> Test macro:12.563967 ± 11.669832 | micro:0.876136 ± 0.080090
# Epoch 89/100 | Train(sampled) L1:5.082195 L4:0.001635 | Val macro:6.957754 ± 6.133174 | Val micro:0.792272 ± 0.076372
#           >> Test macro:10.258871 ± 9.435783 | micro:0.801947 ± 0.077034
# Epoch 90/100 | Train(sampled) L1:4.223872 L4:0.001788 | Val macro:5.712262 ± 4.933668 | Val micro:0.747959 ± 0.066444
#           >> Test macro:8.308039 ± 7.521211 | micro:0.761863 ± 0.070362
# Epoch 91/100 | Train(sampled) L1:3.450565 L4:0.001424 | Val macro:4.604996 ± 3.817446 | Val micro:0.752448 ± 0.064311
#           >> Test macro:6.606615 ± 5.829740 | micro:0.746715 ± 0.064900
# Epoch 92/100 | Train(sampled) L1:2.688772 L4:0.001226 | Val macro:3.675574 ± 2.869339 | Val micro:0.767314 ± 0.065203
#           >> Test macro:5.250853 ± 4.463356 | micro:0.751132 ± 0.063906
# Epoch 93/100 | Train(sampled) L1:2.080860 L4:0.001203 | Val macro:2.845780 ± 2.040681 | Val micro:0.768026 ± 0.069942
#           >> Test macro:4.022505 ± 3.233635 | micro:0.749946 ± 0.070100
# Epoch 94/100 | Train(sampled) L1:1.647666 L4:0.001095 | Val macro:2.206239 ± 1.428091 | Val micro:0.747516 ± 0.064697
#           >> Test macro:3.000340 ± 2.220222 | micro:0.742144 ± 0.066724
# Epoch 95/100 | Train(sampled) L1:1.210453 L4:0.001022 | Val macro:1.730753 ± 0.949964 | Val micro:0.762460 ± 0.070020
#           >> Test macro:2.210144 ± 1.420873 | micro:0.758546 ± 0.069841
# Epoch 96/100 | Train(sampled) L1:0.979498 L4:0.001229 | Val macro:1.307220 ± 0.567613 | Val micro:0.755711 ± 0.065926
#           >> Test macro:1.617110 ± 0.875964 | micro:0.727705 ± 0.064338
# Epoch 97/100 | Train(sampled) L1:0.718424 L4:0.000936 | Val macro:1.067101 ± 0.385646 | Val micro:0.752223 ± 0.062925
#           >> Test macro:1.193280 ± 0.501631 | micro:0.722330 ± 0.064552
# Epoch 98/100 | Train(sampled) L1:0.592784 L4:0.001568 | Val macro:0.896024 ± 0.303643 | Val micro:0.790746 ± 0.071451
#           >> Test macro:0.958305 ± 0.327252 | micro:0.757696 ± 0.068627
# Epoch 99/100 | Train(sampled) L1:0.531826 L4:0.001376 | Val macro:0.822196 ± 0.339726 | Val micro:0.808802 ± 0.076007
#           >> Test macro:0.787132 ± 0.339156 | micro:0.779980 ± 0.071407
# Epoch 100/100 | Train(sampled) L1:0.507787 L4:0.001237 | Val macro:0.755669 ± 0.301991 | Val micro:0.777577 ± 0.064529
#           >> Test macro:0.690819 ± 0.346612 | micro:0.765505 ± 0.066242
# TEST RESULTS | macro: 0.690819 ± 0.346612 | micro: 0.765505 ± 0.066242
#           >> per_group (weighted SE): {0: '1.381720 ± 0.149722 (n=777)', 1: '0.394471 ± 0.225322 (n=3)', 5: '0.296266 ± 0.011290 (n=1018)'}

# %%
dsteps_val={}
for dsteps in [50, 100, 150]:
    model = ODEJumpEncoder(
        in_channels=11,
        hidden_dim=11*16,
    )
    gen = model.train_cognite(
        df=tsdiffusion.denoise_dataframe(
            df=df_scaled,
            feature_cols=list(df_scaled.columns[:-1]),
            static_features_cols=None,
            timestamp_col='index',
            window_size=30,
            window_step=30,   
            replace_only_missing=False,
            steps=dsteps
        ),
        feature_cols=list(df_scaled.columns[:-1]),
        static_features_cols=None,
        timestamp_col='index',
        states_col='states',
        batch_size=256,
        window_size=30,
        window_step=30,
        epochs = 100,
        validate=True
    )
    l = [r for r in gen if r is not None]  # remove None results
    best_epoch = find_best_epoch(l)
    dsteps_val[dsteps] = l[best_epoch]
# Out:
# /root/coppe/3Wve/lib/python3.12/site-packages/torch/nn/modules/transformer.py:382: UserWarning:
#
# enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
# GRUPOS (total): {0: 3886, 1: 15, 5: 5093}
# GRUPOS (train): {0: 2332, 1: 9, 5: 3056}
# GRUPOS (valid): {0: 777, 1: 3, 5: 1019}
# GRUPOS (test):  {0: 777, 1: 3, 5: 1018}
# Epoch 1/100 | Train(sampled) L1:231.017587 L4:0.424915 | Val macro:341.299390 ± 341.207123 | Val micro:1.794086 ± 1.206465
#           >> Test macro:512.083099 ± 511.996389 | micro:2.645161 ± 1.478474
# Epoch 2/100 | Train(sampled) L1:220.667937 L4:0.196990 | Val macro:322.703647 ± 322.663449 | Val micro:1.649605 ± 1.140893
#           >> Test macro:484.393273 ± 484.358836 | micro:2.454907 ± 1.398664
# Epoch 3/100 | Train(sampled) L1:218.777924 L4:0.154652 | Val macro:307.195870 ± 307.159284 | Val micro:1.568608 ± 1.086077
#           >> Test macro:461.076629 ± 461.045759 | micro:2.334802 ± 1.331346
# Epoch 4/100 | Train(sampled) L1:191.085354 L4:0.145378 | Val macro:292.977837 ± 292.940537 | Val micro:1.497984 ± 1.035816
#           >> Test macro:439.730239 ± 439.698728 | micro:2.228410 ± 1.269709
# Epoch 5/100 | Train(sampled) L1:185.171871 L4:0.142002 | Val macro:279.610237 ± 279.562931 | Val micro:1.440813 ± 0.988533
#           >> Test macro:419.645908 ± 419.604574 | micro:2.137443 ± 1.211692
# Epoch 6/100 | Train(sampled) L1:189.086346 L4:0.141994 | Val macro:266.245271 ± 266.203629 | Val micro:1.368430 ± 0.941301
#           >> Test macro:399.613951 ± 399.578486 | micro:2.031468 ± 1.153865
# Epoch 7/100 | Train(sampled) L1:163.758159 L4:0.140636 | Val macro:253.774951 ± 253.737480 | Val micro:1.302031 ± 0.897225
#           >> Test macro:380.885841 ± 380.854606 | micro:1.933648 ± 1.099799
# Epoch 8/100 | Train(sampled) L1:160.036953 L4:0.137198 | Val macro:241.684909 ± 241.648343 | Val micro:1.240676 ± 0.854488
#           >> Test macro:362.747268 ± 362.716787 | micro:1.842112 ± 1.047429
# Epoch 9/100 | Train(sampled) L1:157.773946 L4:0.134807 | Val macro:229.102141 ± 229.063849 | Val micro:1.179370 ± 0.810006
#           >> Test macro:343.871741 ± 343.839417 | micro:1.749380 ± 0.992925
# Epoch 10/100 | Train(sampled) L1:144.900552 L4:0.132701 | Val macro:217.543293 ± 217.500256 | Val micro:1.126832 ± 0.769097
#           >> Test macro:326.511970 ± 326.475254 | micro:1.667421 ± 0.942775
# Epoch 11/100 | Train(sampled) L1:135.495012 L4:0.131301 | Val macro:206.253925 ± 206.217728 | Val micro:1.063092 ± 0.729241
#           >> Test macro:309.587490 ± 309.557537 | micro:1.575547 ± 0.893937
# Epoch 12/100 | Train(sampled) L1:133.471283 L4:0.128339 | Val macro:195.237921 ± 195.200536 | Val micro:1.009080 ± 0.690300
#           >> Test macro:293.070557 ± 293.039873 | micro:1.493583 ± 0.846243
# Epoch 13/100 | Train(sampled) L1:135.229986 L4:0.125438 | Val macro:184.011975 ± 183.973459 | Val micro:0.954038 ± 0.650616
#           >> Test macro:276.230617 ± 276.199130 | micro:1.410128 ± 0.797617
# Epoch 14/100 | Train(sampled) L1:122.778370 L4:0.122748 | Val macro:173.343545 ± 173.305203 | Val micro:0.900489 ± 0.612909
#           >> Test macro:260.178175 ± 260.146915 | micro:1.329556 ± 0.751270
# Epoch 15/100 | Train(sampled) L1:106.328802 L4:0.120466 | Val macro:163.428929 ± 163.387521 | Val micro:0.853861 ± 0.577861
#           >> Test macro:245.314689 ± 245.280822 | micro:1.257744 ± 0.708346
# Epoch 16/100 | Train(sampled) L1:101.443407 L4:0.117419 | Val macro:153.902313 ± 153.863448 | Val micro:0.803719 ± 0.544196
#           >> Test macro:231.059420 ± 231.028033 | micro:1.183951 ± 0.667194
# Epoch 17/100 | Train(sampled) L1:103.175722 L4:0.113580 | Val macro:144.434853 ± 144.390764 | Val micro:0.761460 ± 0.510725
#           >> Test macro:216.830160 ± 216.794090 | micro:1.117377 ± 0.626095
# Epoch 18/100 | Train(sampled) L1:97.696935 L4:0.110099 | Val macro:135.055861 ± 135.020095 | Val micro:0.706508 ± 0.477588
#           >> Test macro:202.732313 ± 202.704060 | micro:1.039188 ± 0.585413
# Epoch 19/100 | Train(sampled) L1:88.154757 L4:0.106904 | Val macro:126.407209 ± 126.365242 | Val micro:0.669730 ± 0.446971
#           >> Test macro:189.806389 ± 189.772314 | micro:0.980612 ± 0.548062
# Epoch 20/100 | Train(sampled) L1:78.960019 L4:0.103800 | Val macro:118.657379 ± 118.620218 | Val micro:0.625772 ± 0.419642
#           >> Test macro:178.099199 ± 178.071051 | micro:0.915902 ± 0.514281
# Epoch 21/100 | Train(sampled) L1:79.099473 L4:0.098479 | Val macro:110.986925 ± 110.950553 | Val micro:0.586637 ± 0.392539
#           >> Test macro:166.518074 ± 166.490224 | micro:0.857593 ± 0.480853
# Epoch 22/100 | Train(sampled) L1:73.696755 L4:0.092945 | Val macro:103.463033 ± 103.427321 | Val micro:0.548400 ± 0.365952
#           >> Test macro:155.296023 ± 155.268641 | micro:0.800981 ± 0.448457
# Epoch 23/100 | Train(sampled) L1:63.991821 L4:0.087058 | Val macro:96.920850 ± 96.875933 | Val micro:0.524552 ± 0.342843
#           >> Test macro:145.390153 ± 145.353634 | micro:0.760254 ± 0.419847
# Epoch 24/100 | Train(sampled) L1:57.638415 L4:0.077975 | Val macro:90.845205 ± 90.808623 | Val micro:0.486073 ± 0.321387
#           >> Test macro:136.258443 ± 136.229932 | micro:0.706715 ± 0.393504
# Epoch 25/100 | Train(sampled) L1:61.209363 L4:0.064487 | Val macro:84.481063 ± 84.444996 | Val micro:0.453751 ± 0.298908
#           >> Test macro:126.748032 ± 126.719890 | micro:0.658747 ± 0.366052
# Epoch 26/100 | Train(sampled) L1:55.473663 L4:0.050193 | Val macro:78.541290 ± 78.504741 | Val micro:0.424498 ± 0.277935
#           >> Test macro:117.871356 ± 117.842236 | micro:0.615205 ± 0.340438
# Epoch 27/100 | Train(sampled) L1:52.476906 L4:0.033343 | Val macro:72.927758 ± 72.887817 | Val micro:0.399690 ± 0.258120
#           >> Test macro:109.488638 ± 109.455630 | micro:0.576961 ± 0.316250
# Epoch 28/100 | Train(sampled) L1:45.835512 L4:0.019908 | Val macro:67.853279 ± 67.815542 | Val micro:0.372164 ± 0.240212
#           >> Test macro:101.865343 ± 101.834490 | micro:0.536698 ± 0.294252
# Epoch 29/100 | Train(sampled) L1:43.542973 L4:0.011268 | Val macro:63.099517 ± 63.063227 | Val micro:0.347016 ± 0.223433
#           >> Test macro:94.709366 ± 94.680064 | micro:0.499418 ± 0.273599
# Epoch 30/100 | Train(sampled) L1:40.429492 L4:0.007877 | Val macro:58.472589 ± 58.437117 | Val micro:0.323186 ± 0.207094
#           >> Test macro:87.787713 ± 87.758936 | micro:0.464326 ± 0.253628
# Epoch 31/100 | Train(sampled) L1:37.970339 L4:0.005964 | Val macro:54.124749 ± 54.084023 | Val micro:0.306442 ± 0.191786
#           >> Test macro:81.248606 ± 81.214795 | micro:0.436444 ± 0.234765
# Epoch 32/100 | Train(sampled) L1:33.236081 L4:0.004683 | Val macro:50.209993 ± 50.172303 | Val micro:0.283896 ± 0.177985
#           >> Test macro:75.343742 ± 75.312517 | micro:0.404305 ± 0.217748
# Epoch 33/100 | Train(sampled) L1:32.196350 L4:0.003597 | Val macro:46.418670 ± 46.380576 | Val micro:0.265322 ± 0.164628
#           >> Test macro:69.668514 ± 69.637066 | micro:0.376136 ± 0.201375
# Epoch 34/100 | Train(sampled) L1:30.938072 L4:0.003001 | Val macro:42.691005 ± 42.653894 | Val micro:0.245736 ± 0.151499
#           >> Test macro:64.072291 ± 64.041726 | micro:0.347269 ± 0.185241
# Epoch 35/100 | Train(sampled) L1:28.531031 L4:0.002815 | Val macro:39.280404 ± 39.244671 | Val micro:0.227343 ± 0.139488
#           >> Test macro:58.945747 ± 58.917279 | micro:0.319645 ± 0.170426
# Epoch 36/100 | Train(sampled) L1:24.431360 L4:0.002350 | Val macro:36.231970 ± 36.185799 | Val micro:0.222826 ± 0.128633
#           >> Test macro:54.355413 ± 54.316146 | micro:0.307666 ± 0.157128
# Epoch 37/100 | Train(sampled) L1:21.105756 L4:0.002148 | Val macro:33.493419 ± 33.458069 | Val micro:0.198109 ± 0.119116
#           >> Test macro:50.246369 ± 50.218258 | micro:0.275829 ± 0.145349
# Epoch 38/100 | Train(sampled) L1:22.049341 L4:0.001805 | Val macro:30.791929 ± 30.756660 | Val micro:0.184481 ± 0.109649
#           >> Test macro:46.193306 ± 46.165327 | micro:0.255390 ± 0.133682
# Epoch 39/100 | Train(sampled) L1:20.131034 L4:0.001502 | Val macro:28.166093 ± 28.130547 | Val micro:0.171673 ± 0.100424
#           >> Test macro:42.244083 ± 42.215708 | micro:0.236044 ± 0.122305
# Epoch 40/100 | Train(sampled) L1:17.880346 L4:0.001367 | Val macro:25.766837 ± 25.727356 | Val micro:0.163380 ± 0.092112
#           >> Test macro:38.635944 ± 38.603928 | micro:0.221475 ± 0.111942
# Epoch 41/100 | Train(sampled) L1:17.251171 L4:0.001265 | Val macro:23.498645 ± 23.461530 | Val micro:0.149733 ± 0.084180
#           >> Test macro:35.239429 ± 35.209638 | micro:0.202285 ± 0.102176
# Epoch 42/100 | Train(sampled) L1:14.588341 L4:0.001121 | Val macro:21.413018 ± 21.374527 | Val micro:0.140612 ± 0.076942
#           >> Test macro:32.093756 ± 32.062394 | micro:0.188025 ± 0.093167
# Epoch 43/100 | Train(sampled) L1:14.288873 L4:0.000948 | Val macro:19.441168 ± 19.405715 | Val micro:0.127848 ± 0.070059
#           >> Test macro:29.140779 ± 29.112025 | micro:0.170695 ± 0.084705
# Epoch 44/100 | Train(sampled) L1:12.360628 L4:0.000882 | Val macro:17.536080 ± 17.500782 | Val micro:0.118203 ± 0.063456
#           >> Test macro:26.278078 ± 26.249206 | micro:0.156482 ± 0.076517
# Epoch 45/100 | Train(sampled) L1:10.725637 L4:0.000740 | Val macro:15.781535 ± 15.745022 | Val micro:0.110569 ± 0.057464
#           >> Test macro:23.637297 ± 23.606980 | micro:0.144621 ± 0.069040
# Epoch 46/100 | Train(sampled) L1:10.384293 L4:0.000665 | Val macro:14.103803 ± 14.067459 | Val micro:0.102034 ± 0.051726
#           >> Test macro:21.123853 ± 21.093757 | micro:0.131853 ± 0.061892
# Epoch 47/100 | Train(sampled) L1:9.286560 L4:0.000614 | Val macro:12.479200 ± 12.442834 | Val micro:0.094102 ± 0.046086
#           >> Test macro:18.685554 ± 18.655263 | micro:0.119958 ± 0.054895
# Epoch 48/100 | Train(sampled) L1:7.696474 L4:0.000565 | Val macro:11.005935 ± 10.970697 | Val micro:0.085497 ± 0.041242
#           >> Test macro:16.472272 ± 16.443008 | micro:0.107744 ± 0.048707
# Epoch 49/100 | Train(sampled) L1:7.056685 L4:0.000517 | Val macro:9.591712 ± 9.548498 | Val micro:0.086046 ± 0.036809
#           >> Test macro:14.346482 ± 14.309465 | micro:0.104570 ± 0.042832
# Epoch 50/100 | Train(sampled) L1:5.921918 L4:0.000439 | Val macro:8.280558 ± 8.245194 | Val micro:0.071954 ± 0.032367
#           >> Test macro:12.385177 ± 12.355804 | micro:0.087364 ± 0.037293
# Epoch 51/100 | Train(sampled) L1:5.006610 L4:0.000411 | Val macro:7.087701 ± 7.052230 | Val micro:0.066082 ± 0.028647
#           >> Test macro:10.596546 ± 10.567118 | micro:0.078463 ± 0.032411
# Epoch 52/100 | Train(sampled) L1:4.306514 L4:0.000382 | Val macro:6.012036 ± 5.976789 | Val micro:0.060507 ± 0.025367
#           >> Test macro:8.981183 ± 8.951900 | micro:0.070246 ± 0.028080
# Epoch 53/100 | Train(sampled) L1:3.661578 L4:0.000362 | Val macro:4.989348 ± 4.954104 | Val micro:0.055409 ± 0.022417
#           >> Test macro:7.448151 ± 7.418844 | micro:0.062610 ± 0.024075
# Epoch 54/100 | Train(sampled) L1:2.844656 L4:0.000318 | Val macro:4.108152 ± 4.073042 | Val micro:0.050913 ± 0.020008
#           >> Test macro:6.123516 ± 6.094455 | micro:0.055789 ± 0.020709
# Epoch 55/100 | Train(sampled) L1:2.490525 L4:0.000290 | Val macro:3.282909 ± 3.245826 | Val micro:0.048648 ± 0.018261
#           >> Test macro:4.888806 ± 4.857909 | micro:0.051368 ± 0.017904
# Epoch 56/100 | Train(sampled) L1:1.937872 L4:0.000280 | Val macro:2.568948 ± 2.530441 | Val micro:0.046505 ± 0.016826
#           >> Test macro:3.817433 ± 3.785566 | micro:0.047042 ± 0.015410
# Epoch 57/100 | Train(sampled) L1:1.445373 L4:0.000295 | Val macro:1.968030 ± 1.932744 | Val micro:0.040391 ± 0.015564
#           >> Test macro:2.918820 ± 2.889912 | micro:0.039632 ± 0.013620
# Epoch 58/100 | Train(sampled) L1:1.109629 L4:0.000287 | Val macro:1.473396 ± 1.438557 | Val micro:0.037547 ± 0.014762
#           >> Test macro:2.175032 ± 2.146438 | micro:0.035632 ± 0.012413
# Epoch 59/100 | Train(sampled) L1:0.810089 L4:0.000277 | Val macro:1.062452 ± 1.027668 | Val micro:0.035493 ± 0.014303
#           >> Test macro:1.558492 ± 1.529895 | micro:0.032572 ± 0.011655
# Epoch 60/100 | Train(sampled) L1:0.594159 L4:0.000262 | Val macro:0.721836 ± 0.684691 | Val micro:0.036148 ± 0.014354
#           >> Test macro:1.047128 ± 1.016374 | micro:0.032163 ± 0.011248
# Epoch 61/100 | Train(sampled) L1:0.383256 L4:0.000252 | Val macro:0.456163 ± 0.421500 | Val micro:0.032659 ± 0.013726
#           >> Test macro:0.652989 ± 0.624588 | micro:0.028038 ± 0.010601
# Epoch 62/100 | Train(sampled) L1:0.241682 L4:0.000291 | Val macro:0.267847 ± 0.233629 | Val micro:0.031603 ± 0.013853
#           >> Test macro:0.372670 ± 0.344274 | micro:0.026735 ± 0.010777
# Epoch 63/100 | Train(sampled) L1:0.136112 L4:0.000238 | Val macro:0.150058 ± 0.115996 | Val micro:0.031747 ± 0.013503
#           >> Test macro:0.193065 ± 0.164428 | micro:0.026541 ± 0.010490
# Epoch 64/100 | Train(sampled) L1:0.066352 L4:0.000215 | Val macro:0.080504 ± 0.049739 | Val micro:0.030492 ± 0.013800
#           >> Test macro:0.096215 ± 0.069506 | micro:0.025201 ± 0.010755
# Epoch 65/100 | Train(sampled) L1:0.045021 L4:0.000201 | Val macro:0.051553 ± 0.023967 | Val micro:0.034164 ± 0.014170
#           >> Test macro:0.046423 ± 0.021555 | micro:0.029120 ± 0.011313
# Epoch 66/100 | Train(sampled) L1:0.019835 L4:0.000194 | Val macro:0.035426 ± 0.020006 | Val micro:0.031033 ± 0.013935
#           >> Test macro:0.029500 ± 0.016654 | micro:0.026059 ± 0.011177
# Epoch 67/100 | Train(sampled) L1:0.029343 L4:0.000200 | Val macro:0.031863 ± 0.019703 | Val micro:0.030615 ± 0.013526
#           >> Test macro:0.023632 ± 0.017047 | micro:0.025494 ± 0.010744
# Epoch 68/100 | Train(sampled) L1:0.016334 L4:0.000212 | Val macro:0.029993 ± 0.020433 | Val micro:0.030461 ± 0.013782
#           >> Test macro:0.021703 ± 0.017544 | micro:0.024943 ± 0.010597
# Epoch 69/100 | Train(sampled) L1:0.035464 L4:0.000239 | Val macro:0.031426 ± 0.019929 | Val micro:0.032335 ± 0.013138
#           >> Test macro:0.022335 ± 0.017666 | micro:0.026844 ± 0.010112
# Epoch 70/100 | Train(sampled) L1:0.022021 L4:0.000208 | Val macro:0.025540 ± 0.021450 | Val micro:0.029814 ± 0.013512
#           >> Test macro:0.021587 ± 0.017079 | micro:0.024294 ± 0.010354
# Epoch 71/100 | Train(sampled) L1:0.023688 L4:0.000202 | Val macro:0.027751 ± 0.022834 | Val micro:0.034200 ± 0.013909
#           >> Test macro:0.024209 ± 0.017912 | micro:0.028521 ± 0.010475
# Epoch 72/100 | Train(sampled) L1:0.024495 L4:0.000186 | Val macro:0.023985 ± 0.021871 | Val micro:0.029560 ± 0.013381
#           >> Test macro:0.019697 ± 0.017793 | micro:0.024191 ± 0.010230
# Epoch 73/100 | Train(sampled) L1:0.024638 L4:0.000183 | Val macro:0.024159 ± 0.021663 | Val micro:0.029736 ± 0.013096
#           >> Test macro:0.019353 ± 0.017782 | micro:0.024272 ± 0.009988
# Epoch 74/100 | Train(sampled) L1:0.020961 L4:0.000195 | Val macro:0.026716 ± 0.021476 | Val micro:0.032418 ± 0.012807
#           >> Test macro:0.021062 ± 0.018191 | micro:0.027020 ± 0.009853
# Epoch 75/100 | Train(sampled) L1:0.032885 L4:0.000174 | Val macro:0.024751 ± 0.021491 | Val micro:0.029536 ± 0.012986
#           >> Test macro:0.019603 ± 0.017148 | micro:0.023578 ± 0.009379
# Epoch 76/100 | Train(sampled) L1:0.011979 L4:0.000162 | Val macro:0.023956 ± 0.022000 | Val micro:0.029661 ± 0.013375
#           >> Test macro:0.018884 ± 0.017509 | micro:0.023604 ± 0.009814
# Epoch 77/100 | Train(sampled) L1:0.015824 L4:0.000172 | Val macro:0.023560 ± 0.022148 | Val micro:0.029614 ± 0.013333
#           >> Test macro:0.018574 ± 0.017320 | micro:0.023283 ± 0.009629
# Epoch 78/100 | Train(sampled) L1:0.024804 L4:0.000159 | Val macro:0.025644 ± 0.022004 | Val micro:0.032302 ± 0.012849
#           >> Test macro:0.020825 ± 0.017023 | micro:0.025812 ± 0.009162
# Epoch 79/100 | Train(sampled) L1:0.025372 L4:0.000172 | Val macro:0.023799 ± 0.022115 | Val micro:0.029669 ± 0.013282
#           >> Test macro:0.018684 ± 0.017125 | micro:0.023149 ± 0.009522
# Epoch 80/100 | Train(sampled) L1:0.020096 L4:0.000156 | Val macro:0.023634 ± 0.022374 | Val micro:0.029841 ± 0.013366
#           >> Test macro:0.018255 ± 0.016645 | micro:0.022559 ± 0.009060
# Epoch 81/100 | Train(sampled) L1:0.024779 L4:0.000156 | Val macro:0.023849 ± 0.022603 | Val micro:0.030300 ± 0.013420
#           >> Test macro:0.018825 ± 0.016587 | micro:0.022959 ± 0.009138
# Epoch 82/100 | Train(sampled) L1:0.025330 L4:0.000169 | Val macro:0.024149 ± 0.022317 | Val micro:0.030081 ± 0.013462
#           >> Test macro:0.018676 ± 0.017106 | micro:0.023242 ± 0.009418
# Epoch 83/100 | Train(sampled) L1:0.017702 L4:0.000178 | Val macro:0.023906 ± 0.022091 | Val micro:0.029704 ± 0.013369
#           >> Test macro:0.019036 ± 0.016884 | micro:0.023094 ± 0.009535
# Epoch 84/100 | Train(sampled) L1:0.014801 L4:0.000161 | Val macro:0.023680 ± 0.021877 | Val micro:0.029453 ± 0.013049
#           >> Test macro:0.018701 ± 0.017393 | micro:0.023445 ± 0.009721
# Epoch 85/100 | Train(sampled) L1:0.010047 L4:0.000158 | Val macro:0.024269 ± 0.022463 | Val micro:0.030352 ± 0.013510
#           >> Test macro:0.018619 ± 0.017124 | micro:0.023333 ± 0.009392
# Early stopping at epoch 85/100 (best test macro-MSE: 0.018255 @ epoch 80)
# TEST RESULTS | macro: 0.018619 ± 0.017124 | micro: 0.023333 ± 0.009392
#           >> per_group (weighted SE): {0: '0.052859 ± 0.021687 (n=777)', 1: '0.002140 ± 0.000231 (n=3)', 5: '0.000859 ± 0.000036 (n=1018)'}
# /root/coppe/3Wve/lib/python3.12/site-packages/torch/nn/modules/transformer.py:382: UserWarning:
#
# enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
# GRUPOS (total): {0: 3886, 1: 15, 5: 5093}
# GRUPOS (train): {0: 2332, 1: 9, 5: 3056}
# GRUPOS (valid): {0: 777, 1: 3, 5: 1019}
# GRUPOS (test):  {0: 777, 1: 3, 5: 1018}
# Epoch 1/100 | Train(sampled) L1:244.211469 L4:0.558789 | Val macro:349.139952 ± 349.043249 | Val micro:1.838375 ± 1.234124
#           >> Test macro:524.285433 ± 524.194642 | micro:2.710984 ± 1.513683
# Epoch 2/100 | Train(sampled) L1:240.537784 L4:0.225134 | Val macro:332.465836 ± 332.421840 | Val micro:1.702467 ± 1.175389
#           >> Test macro:499.482077 ± 499.443917 | micro:2.534395 ± 1.442218
# Epoch 3/100 | Train(sampled) L1:219.946541 L4:0.168875 | Val macro:318.727552 ± 318.689942 | Val micro:1.627257 ± 1.126846
#           >> Test macro:478.807286 ± 478.775690 | micro:2.424266 ± 1.382540
# Epoch 4/100 | Train(sampled) L1:201.697993 L4:0.153947 | Val macro:306.310975 ± 306.272017 | Val micro:1.566284 ± 1.082950
#           >> Test macro:460.147192 ± 460.114614 | micro:2.331675 ± 1.328658
# Epoch 5/100 | Train(sampled) L1:206.742140 L4:0.146984 | Val macro:293.999720 ± 293.962597 | Val micro:1.503033 ± 1.039429
#           >> Test macro:441.699233 ± 441.668406 | micro:2.237758 ± 1.275393
# Epoch 6/100 | Train(sampled) L1:190.182630 L4:0.144660 | Val macro:281.978855 ± 281.938417 | Val micro:1.445962 ± 0.996928
#           >> Test macro:423.621290 ± 423.587704 | micro:2.149838 ± 1.223187
# Epoch 7/100 | Train(sampled) L1:180.534088 L4:0.143756 | Val macro:270.223601 ± 270.186295 | Val micro:1.384181 ± 0.955378
#           >> Test macro:405.985551 ± 405.955201 | micro:2.058512 ± 1.172271
# Epoch 8/100 | Train(sampled) L1:182.477336 L4:0.140791 | Val macro:258.525968 ± 258.489149 | Val micro:1.325290 ± 0.914023
#           >> Test macro:388.422513 ± 388.392703 | micro:1.970192 ± 1.121558
# Epoch 9/100 | Train(sampled) L1:169.908067 L4:0.137681 | Val macro:247.313893 ± 247.275995 | Val micro:1.270098 ± 0.874389
#           >> Test macro:371.574097 ± 371.543385 | micro:1.886591 ± 1.072909
# Epoch 10/100 | Train(sampled) L1:163.354788 L4:0.135321 | Val macro:236.160940 ± 236.120047 | Val micro:1.217147 ± 0.834958
#           >> Test macro:354.832339 ± 354.798911 | micro:1.805383 ± 1.024563
# Epoch 11/100 | Train(sampled) L1:156.874399 L4:0.132724 | Val macro:225.925491 ± 225.885886 | Val micro:1.164711 ± 0.798778
#           >> Test macro:339.476181 ± 339.444364 | micro:1.727011 ± 0.980225
# Epoch 12/100 | Train(sampled) L1:147.646668 L4:0.130002 | Val macro:215.801120 ± 215.763872 | Val micro:1.111850 ± 0.762993
#           >> Test macro:324.293934 ± 324.264196 | micro:1.649055 ± 0.936393
# Epoch 13/100 | Train(sampled) L1:149.335389 L4:0.126031 | Val macro:205.720944 ± 205.684030 | Val micro:1.061144 ± 0.727359
#           >> Test macro:309.162534 ± 309.133340 | micro:1.572860 ± 0.892702
# Epoch 14/100 | Train(sampled) L1:135.209870 L4:0.123089 | Val macro:196.026730 ± 195.989139 | Val micro:1.013228 ± 0.693093
#           >> Test macro:294.662673 ± 294.633360 | micro:1.500376 ± 0.850833
# Epoch 15/100 | Train(sampled) L1:126.054285 L4:0.118934 | Val macro:186.213877 ± 186.174226 | Val micro:0.966093 ± 0.658405
#           >> Test macro:279.939041 ± 279.907685 | micro:1.428609 ± 0.808318
# Epoch 16/100 | Train(sampled) L1:120.101194 L4:0.114742 | Val macro:176.965903 ± 176.928872 | Val micro:0.917384 ± 0.625717
#           >> Test macro:266.112588 ± 266.083725 | micro:1.357078 ± 0.768400
# Epoch 17/100 | Train(sampled) L1:113.930059 L4:0.109470 | Val macro:167.712770 ± 167.674690 | Val micro:0.872059 ± 0.593012
#           >> Test macro:252.136563 ± 252.106716 | micro:1.288023 ± 0.728047
# Epoch 18/100 | Train(sampled) L1:110.567464 L4:0.104678 | Val macro:159.010378 ± 158.970148 | Val micro:0.830580 ± 0.562252
#           >> Test macro:239.111610 ± 239.079524 | micro:1.224951 ± 0.690438
# Epoch 19/100 | Train(sampled) L1:110.367192 L4:0.097573 | Val macro:150.415772 ± 150.376109 | Val micro:0.787048 ± 0.531876
#           >> Test macro:226.165251 ± 226.133758 | micro:1.159592 ± 0.653059
# Epoch 20/100 | Train(sampled) L1:101.799317 L4:0.089068 | Val macro:142.062809 ± 142.025335 | Val micro:0.743177 ± 0.502355
#           >> Test macro:213.661233 ± 213.632208 | micro:1.094687 ± 0.616959
# Epoch 21/100 | Train(sampled) L1:88.504635 L4:0.081027 | Val macro:134.397902 ± 134.360190 | Val micro:0.705296 ± 0.475249
#           >> Test macro:202.048009 ± 202.018351 | micro:1.037381 ± 0.583424
# Epoch 22/100 | Train(sampled) L1:87.629622 L4:0.071064 | Val macro:126.902052 ± 126.858043 | Val micro:0.673651 ± 0.448774
#           >> Test macro:190.791951 ± 190.756480 | micro:0.986441 ± 0.550921
# Epoch 23/100 | Train(sampled) L1:85.609050 L4:0.059364 | Val macro:119.284685 ± 119.244384 | Val micro:0.631935 ± 0.421863
#           >> Test macro:179.352435 ± 179.320550 | micro:0.925684 ± 0.517902
# Epoch 24/100 | Train(sampled) L1:77.859258 L4:0.047402 | Val macro:112.260929 ± 112.213098 | Val micro:0.604145 ± 0.397036
#           >> Test macro:168.806245 ± 168.767399 | micro:0.879739 ± 0.487436
# Epoch 25/100 | Train(sampled) L1:65.076554 L4:0.033683 | Val macro:105.892814 ± 105.854278 | Val micro:0.563220 ± 0.374550
#           >> Test macro:159.286066 ± 159.255960 | micro:0.823514 ± 0.459974
# Epoch 26/100 | Train(sampled) L1:67.139541 L4:0.020641 | Val macro:99.804211 ± 99.762018 | Val micro:0.536264 ± 0.353040
#           >> Test macro:150.100484 ± 150.066843 | micro:0.780925 ± 0.433451
# Epoch 27/100 | Train(sampled) L1:62.813306 L4:0.013096 | Val macro:93.535781 ± 93.487272 | Val micro:0.511071 ± 0.330888
#           >> Test macro:140.664361 ± 140.624438 | micro:0.739819 ± 0.406200
# Epoch 28/100 | Train(sampled) L1:61.149319 L4:0.009658 | Val macro:87.794446 ± 87.756339 | Val micro:0.472272 ± 0.310622
#           >> Test macro:132.037962 ± 132.007831 | micro:0.687109 ± 0.381323
# Epoch 29/100 | Train(sampled) L1:60.293889 L4:0.007128 | Val macro:82.043439 ± 82.002165 | Val micro:0.446555 ± 0.290313
#           >> Test macro:123.434905 ± 123.401811 | micro:0.646915 ± 0.356483
# Epoch 30/100 | Train(sampled) L1:51.966849 L4:0.005731 | Val macro:76.794153 ± 76.757473 | Val micro:0.416016 ± 0.271764
#           >> Test macro:115.492080 ± 115.463016 | micro:0.603387 ± 0.333562
# Epoch 31/100 | Train(sampled) L1:51.019462 L4:0.004454 | Val macro:71.948674 ± 71.912017 | Val micro:0.391715 ± 0.254662
#           >> Test macro:108.201655 ± 108.173184 | micro:0.566339 ± 0.312512
# Epoch 32/100 | Train(sampled) L1:46.830797 L4:0.003280 | Val macro:67.224435 ± 67.185237 | Val micro:0.370461 ± 0.237997
#           >> Test macro:101.102538 ± 101.072038 | micro:0.532732 ± 0.292018
# Epoch 33/100 | Train(sampled) L1:43.758412 L4:0.002627 | Val macro:62.730723 ± 62.693481 | Val micro:0.346119 ± 0.222138
#           >> Test macro:94.339076 ± 94.309793 | micro:0.497656 ± 0.272516
# Epoch 34/100 | Train(sampled) L1:40.448226 L4:0.002117 | Val macro:58.539316 ± 58.497602 | Val micro:0.329490 ± 0.207358
#           >> Test macro:88.035697 ± 88.002409 | micro:0.470032 ± 0.254316
# Epoch 35/100 | Train(sampled) L1:36.436436 L4:0.001799 | Val macro:54.639754 ± 54.599472 | Val micro:0.308559 ± 0.193609
#           >> Test macro:82.154488 ± 82.122912 | micro:0.438929 ± 0.237341
# Epoch 36/100 | Train(sampled) L1:35.135298 L4:0.001683 | Val macro:50.827433 ± 50.790272 | Val micro:0.286471 ± 0.180164
#           >> Test macro:76.422232 ± 76.393304 | micro:0.407638 ± 0.220817
# Epoch 37/100 | Train(sampled) L1:33.281169 L4:0.001383 | Val macro:47.227090 ± 47.189917 | Val micro:0.268662 ± 0.167440
#           >> Test macro:71.011055 ± 70.981982 | micro:0.380885 ± 0.205190
# Epoch 38/100 | Train(sampled) L1:32.940424 L4:0.001123 | Val macro:43.785578 ± 43.742909 | Val micro:0.257056 ± 0.155262
#           >> Test macro:65.826927 ± 65.792464 | micro:0.360466 ± 0.190197
# Epoch 39/100 | Train(sampled) L1:28.575338 L4:0.000995 | Val macro:40.504688 ± 40.467980 | Val micro:0.234429 ± 0.143804
#           >> Test macro:60.917131 ± 60.888790 | micro:0.329512 ± 0.176090
# Epoch 40/100 | Train(sampled) L1:25.284731 L4:0.000884 | Val macro:37.605466 ± 37.568300 | Val micro:0.220363 ± 0.133615
#           >> Test macro:56.539930 ± 56.510719 | micro:0.308390 ± 0.163491
# Epoch 41/100 | Train(sampled) L1:24.280761 L4:0.000736 | Val macro:34.843726 ± 34.807496 | Val micro:0.205682 ± 0.123893
#           >> Test macro:52.376440 ± 52.348318 | micro:0.286559 ± 0.151478
# Epoch 42/100 | Train(sampled) L1:21.279686 L4:0.000594 | Val macro:32.287282 ± 32.250203 | Val micro:0.193684 ± 0.114934
#           >> Test macro:48.545577 ± 48.516647 | micro:0.268134 ± 0.140450
# Epoch 43/100 | Train(sampled) L1:20.743176 L4:0.000518 | Val macro:29.851781 ± 29.813251 | Val micro:0.182887 ± 0.106412
#           >> Test macro:44.870334 ± 44.839731 | micro:0.251313 ± 0.129886
# Epoch 44/100 | Train(sampled) L1:19.537551 L4:0.000470 | Val macro:27.505436 ± 27.467889 | Val micro:0.170417 ± 0.098111
#           >> Test macro:41.344023 ± 41.314145 | micro:0.233173 ± 0.119699
# Epoch 45/100 | Train(sampled) L1:17.051485 L4:0.000433 | Val macro:25.269688 ± 25.232660 | Val micro:0.158514 ± 0.090376
#           >> Test macro:37.982884 ± 37.953169 | micro:0.215918 ± 0.110100
# Epoch 46/100 | Train(sampled) L1:16.699265 L4:0.000401 | Val macro:23.162694 ± 23.124971 | Val micro:0.148657 ± 0.083034
#           >> Test macro:34.818175 ± 34.788159 | micro:0.200419 ± 0.100986
# Epoch 47/100 | Train(sampled) L1:13.939879 L4:0.000379 | Val macro:21.259995 ± 21.222703 | Val micro:0.138926 ± 0.076317
#           >> Test macro:31.956746 ± 31.926891 | micro:0.186135 ± 0.092730
# Epoch 48/100 | Train(sampled) L1:13.336959 L4:0.000364 | Val macro:19.486699 ± 19.450459 | Val micro:0.128869 ± 0.070235
#           >> Test macro:29.282720 ± 29.254095 | micro:0.171398 ± 0.085087
# Epoch 49/100 | Train(sampled) L1:13.290372 L4:0.000337 | Val macro:17.680529 ± 17.644248 | Val micro:0.119934 ± 0.063970
#           >> Test macro:26.581062 ± 26.552086 | micro:0.158250 ± 0.077356
# Epoch 50/100 | Train(sampled) L1:11.754352 L4:0.000301 | Val macro:15.979337 ± 15.942714 | Val micro:0.111656 ± 0.058170
#           >> Test macro:24.023615 ± 23.994272 | micro:0.145694 ± 0.070078
# Epoch 51/100 | Train(sampled) L1:10.036125 L4:0.000268 | Val macro:14.400948 ± 14.364394 | Val micro:0.103701 ± 0.052772
#           >> Test macro:21.651739 ± 21.622672 | micro:0.133584 ± 0.063291
# Epoch 52/100 | Train(sampled) L1:9.231025 L4:0.000243 | Val macro:12.947731 ± 12.911370 | Val micro:0.096281 ± 0.047816
#           >> Test macro:19.461789 ± 19.433011 | micro:0.122387 ± 0.057046
# Epoch 53/100 | Train(sampled) L1:7.878807 L4:0.000220 | Val macro:11.610630 ± 11.570172 | Val micro:0.093488 ± 0.043455
#           >> Test macro:17.454188 ± 17.421286 | micro:0.116244 ± 0.051430
# Epoch 54/100 | Train(sampled) L1:7.115821 L4:0.000227 | Val macro:10.319660 ± 10.282744 | Val micro:0.083618 ± 0.039090
#           >> Test macro:15.510965 ± 15.481476 | micro:0.103227 ± 0.045924
# Epoch 55/100 | Train(sampled) L1:6.486347 L4:0.000205 | Val macro:9.076880 ± 9.038156 | Val micro:0.079138 ± 0.035102
#           >> Test macro:13.642679 ± 13.611752 | micro:0.095285 ± 0.040662
# Epoch 56/100 | Train(sampled) L1:5.551175 L4:0.000188 | Val macro:7.896502 ± 7.860161 | Val micro:0.070995 ± 0.031201
#           >> Test macro:11.868661 ± 11.839892 | micro:0.084374 ± 0.035696
# Epoch 57/100 | Train(sampled) L1:5.097368 L4:0.000182 | Val macro:6.812242 ± 6.775985 | Val micro:0.065489 ± 0.027849
#           >> Test macro:10.240105 ± 10.211736 | micro:0.075863 ± 0.031148
# Epoch 58/100 | Train(sampled) L1:4.238340 L4:0.000165 | Val macro:5.813518 ± 5.776504 | Val micro:0.061364 ± 0.024713
#           >> Test macro:8.736985 ± 8.707829 | micro:0.069245 ± 0.026960
# Epoch 59/100 | Train(sampled) L1:3.489238 L4:0.000175 | Val macro:4.916033 ± 4.876684 | Val micro:0.058948 ± 0.022550
#           >> Test macro:7.385510 ± 7.353911 | micro:0.064619 ± 0.023692
# Epoch 60/100 | Train(sampled) L1:3.007983 L4:0.000153 | Val macro:4.079702 ± 4.043105 | Val micro:0.052149 ± 0.020181
#           >> Test macro:6.127169 ± 6.098203 | micro:0.055813 ± 0.020422
# Epoch 61/100 | Train(sampled) L1:2.367637 L4:0.000147 | Val macro:3.338230 ± 3.301646 | Val micro:0.048435 ± 0.018419
#           >> Test macro:5.011471 ± 4.982349 | micro:0.050363 ± 0.017797
# Epoch 62/100 | Train(sampled) L1:2.105167 L4:0.000148 | Val macro:2.647856 ± 2.608653 | Val micro:0.047520 ± 0.017159
#           >> Test macro:3.971643 ± 3.940269 | micro:0.047364 ± 0.015447
# Epoch 63/100 | Train(sampled) L1:1.494515 L4:0.000152 | Val macro:2.079758 ± 2.041438 | Val micro:0.043853 ± 0.016101
#           >> Test macro:3.118695 ± 3.087998 | micro:0.042438 ± 0.013794
# Epoch 64/100 | Train(sampled) L1:1.226166 L4:0.000157 | Val macro:1.584877 ± 1.548846 | Val micro:0.039258 ± 0.015058
#           >> Test macro:2.369506 ± 2.340769 | micro:0.036851 ± 0.012375
# Epoch 65/100 | Train(sampled) L1:0.935780 L4:0.000144 | Val macro:1.162460 ± 1.125619 | Val micro:0.038069 ± 0.014368
#           >> Test macro:1.728704 ± 1.699673 | micro:0.034107 ± 0.010967
# Epoch 66/100 | Train(sampled) L1:0.639985 L4:0.000140 | Val macro:0.829922 ± 0.791900 | Val micro:0.037476 ± 0.014617
#           >> Test macro:1.228954 ± 1.199097 | micro:0.032302 ± 0.010660
# Epoch 67/100 | Train(sampled) L1:0.456075 L4:0.000145 | Val macro:0.565264 ± 0.529280 | Val micro:0.034384 ± 0.014035
#           >> Test macro:0.831303 ± 0.802746 | micro:0.029141 ± 0.010349
# Epoch 68/100 | Train(sampled) L1:0.304918 L4:0.000152 | Val macro:0.375949 ± 0.336770 | Val micro:0.036662 ± 0.014543
#           >> Test macro:0.538155 ± 0.505928 | micro:0.031164 ± 0.010942
# Epoch 69/100 | Train(sampled) L1:0.189927 L4:0.000150 | Val macro:0.224369 ± 0.188044 | Val micro:0.033609 ± 0.014317
#           >> Test macro:0.311194 ± 0.281615 | micro:0.027677 ± 0.010638
# Epoch 70/100 | Train(sampled) L1:0.119427 L4:0.000141 | Val macro:0.124436 ± 0.088840 | Val micro:0.033650 ± 0.014331
#           >> Test macro:0.163683 ± 0.134449 | micro:0.027133 ± 0.010373
# Epoch 71/100 | Train(sampled) L1:0.066085 L4:0.000133 | Val macro:0.075790 ± 0.043936 | Val micro:0.032272 ± 0.014153
#           >> Test macro:0.107332 ± 0.080474 | micro:0.025164 ± 0.009778
# Epoch 72/100 | Train(sampled) L1:0.063676 L4:0.000132 | Val macro:0.046386 ± 0.022174 | Val micro:0.031825 ± 0.013819
#           >> Test macro:0.042109 ± 0.020533 | micro:0.024740 ± 0.009643
# Epoch 73/100 | Train(sampled) L1:0.026147 L4:0.000142 | Val macro:0.035824 ± 0.020969 | Val micro:0.034568 ± 0.014409
#           >> Test macro:0.044732 ± 0.021005 | micro:0.027472 ± 0.010187
# Epoch 74/100 | Train(sampled) L1:0.020725 L4:0.000140 | Val macro:0.029973 ± 0.021238 | Val micro:0.031687 ± 0.014137
#           >> Test macro:0.024917 ± 0.016262 | micro:0.024983 ± 0.010213
# Epoch 75/100 | Train(sampled) L1:0.016213 L4:0.000135 | Val macro:0.028525 ± 0.022170 | Val micro:0.032320 ± 0.014250
#           >> Test macro:0.022851 ± 0.017362 | micro:0.025655 ± 0.010347
# Epoch 76/100 | Train(sampled) L1:0.018748 L4:0.000134 | Val macro:0.026040 ± 0.022873 | Val micro:0.031820 ± 0.014175
#           >> Test macro:0.024358 ± 0.016720 | micro:0.025353 ± 0.010395
# Epoch 77/100 | Train(sampled) L1:0.020301 L4:0.000121 | Val macro:0.026860 ± 0.022282 | Val micro:0.031648 ± 0.014064
#           >> Test macro:0.031647 ± 0.015639 | micro:0.024012 ± 0.009467
# Epoch 78/100 | Train(sampled) L1:0.046432 L4:0.000121 | Val macro:0.025578 ± 0.023225 | Val micro:0.032050 ± 0.014020
#           >> Test macro:0.018939 ± 0.016202 | micro:0.023044 ± 0.008627
# Epoch 79/100 | Train(sampled) L1:0.038141 L4:0.000123 | Val macro:0.027943 ± 0.023783 | Val micro:0.034392 ± 0.014165
#           >> Test macro:0.019213 ± 0.016779 | micro:0.024478 ± 0.008382
# Epoch 80/100 | Train(sampled) L1:0.022740 L4:0.000173 | Val macro:0.026887 ± 0.023623 | Val micro:0.033402 ± 0.014142
#           >> Test macro:0.022263 ± 0.014947 | micro:0.023571 ± 0.008473
# Epoch 81/100 | Train(sampled) L1:0.014200 L4:0.000148 | Val macro:0.029525 ± 0.022016 | Val micro:0.035793 ± 0.013449
#           >> Test macro:0.022792 ± 0.017099 | micro:0.028657 ± 0.009212
# Epoch 82/100 | Train(sampled) L1:0.047446 L4:0.000127 | Val macro:0.025753 ± 0.023024 | Val micro:0.031994 ± 0.014026
#           >> Test macro:0.019764 ± 0.016719 | micro:0.023881 ± 0.009240
# Epoch 83/100 | Train(sampled) L1:0.022082 L4:0.000129 | Val macro:0.024999 ± 0.022920 | Val micro:0.031376 ± 0.013887
#           >> Test macro:0.019452 ± 0.016580 | micro:0.023443 ± 0.009213
# Early stopping at epoch 83/100 (best test macro-MSE: 0.018939 @ epoch 78)
# TEST RESULTS | macro: 0.019452 ± 0.016580 | micro: 0.023443 ± 0.009213
#           >> per_group (weighted SE): {0: '0.052559 ± 0.021275 (n=777)', 1: '0.004522 ± 0.002012 (n=3)', 5: '0.001275 ± 0.000050 (n=1018)'}
# /root/coppe/3Wve/lib/python3.12/site-packages/torch/nn/modules/transformer.py:382: UserWarning:
#
# enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
# GRUPOS (total): {0: 3886, 1: 15, 5: 5093}
# GRUPOS (train): {0: 2332, 1: 9, 5: 3056}
# GRUPOS (valid): {0: 777, 1: 3, 5: 1019}
# GRUPOS (test):  {0: 777, 1: 3, 5: 1018}
# Epoch 1/100 | Train(sampled) L1:254.034997 L4:0.288988 | Val macro:358.670727 ± 358.367589 | Val micro:2.092517 ± 1.267002
#           >> Test macro:538.358971 ± 538.060098 | micro:2.989426 ± 1.553699
# Epoch 2/100 | Train(sampled) L1:239.995536 L4:0.196044 | Val macro:341.069437 ± 341.024656 | Val micro:1.746192 ± 1.205810
#           >> Test macro:512.855312 ± 512.817106 | micro:2.601346 ± 1.480832
# Epoch 3/100 | Train(sampled) L1:211.117217 L4:0.145451 | Val macro:325.925375 ± 325.884734 | Val micro:1.666218 ± 1.152289
#           >> Test macro:490.181652 ± 490.147914 | micro:2.483344 ± 1.415377
# Epoch 4/100 | Train(sampled) L1:209.289390 L4:0.143394 | Val macro:311.175231 ± 311.133842 | Val micro:1.592936 ± 1.100146
#           >> Test macro:467.968501 ± 467.934547 | micro:2.372175 ± 1.351240
# Epoch 5/100 | Train(sampled) L1:209.589347 L4:0.143762 | Val macro:296.934886 ± 296.894840 | Val micro:1.520424 ± 1.049808
#           >> Test macro:446.627476 ± 446.594909 | micro:2.264044 ± 1.289621
# Epoch 6/100 | Train(sampled) L1:203.341079 L4:0.143625 | Val macro:282.988993 ± 282.941106 | Val micro:1.458238 ± 1.000490
#           >> Test macro:425.733044 ± 425.693122 | micro:2.166593 ± 1.229273
# Epoch 7/100 | Train(sampled) L1:196.618016 L4:0.142819 | Val macro:269.299531 ± 269.259801 | Val micro:1.381864 ± 0.952116
#           >> Test macro:405.237120 ± 405.204845 | micro:2.056579 ± 1.170112
# Epoch 8/100 | Train(sampled) L1:170.550578 L4:0.140221 | Val macro:256.701567 ± 256.662266 | Val micro:1.318460 ± 0.907583
#           >> Test macro:386.340394 ± 386.308393 | micro:1.961752 ± 1.115551
# Epoch 9/100 | Train(sampled) L1:176.250123 L4:0.136809 | Val macro:244.132491 ± 244.082465 | Val micro:1.265903 ± 0.863129
#           >> Test macro:367.465986 ± 367.424027 | micro:1.876896 ± 1.061032
# Epoch 10/100 | Train(sampled) L1:159.154759 L4:0.133825 | Val macro:231.866189 ± 231.826286 | Val micro:1.194747 ± 0.819793
#           >> Test macro:349.097617 ± 349.065184 | micro:1.775710 ± 1.008018
# Epoch 11/100 | Train(sampled) L1:148.856184 L4:0.129972 | Val macro:220.485221 ± 220.444611 | Val micro:1.138479 ± 0.779562
#           >> Test macro:332.030692 ± 331.997764 | micro:1.690762 ± 0.958739
# Epoch 12/100 | Train(sampled) L1:146.485508 L4:0.125062 | Val macro:208.815657 ± 208.775681 | Val micro:1.079502 ± 0.738314
#           >> Test macro:314.429847 ± 314.397618 | micro:1.602010 ± 0.907921
# Epoch 13/100 | Train(sampled) L1:136.307913 L4:0.120618 | Val macro:197.530046 ± 197.490580 | Val micro:1.022579 ± 0.698422
#           >> Test macro:297.491310 ± 297.459557 | micro:1.516794 ± 0.859015
# Epoch 14/100 | Train(sampled) L1:129.509883 L4:0.115493 | Val macro:186.732532 ± 186.692736 | Val micro:0.968874 ± 0.660257
#           >> Test macro:281.232472 ± 281.200659 | micro:1.435486 ± 0.812071
# Epoch 15/100 | Train(sampled) L1:127.581352 L4:0.110323 | Val macro:175.998728 ± 175.959229 | Val micro:0.914896 ± 0.622319
#           >> Test macro:265.217605 ± 265.186283 | micro:1.354880 ± 0.765831
# Epoch 16/100 | Train(sampled) L1:118.918400 L4:0.105821 | Val macro:165.836928 ± 165.797551 | Val micro:0.863966 ± 0.586401
#           >> Test macro:249.882293 ± 249.851460 | micro:1.277712 ± 0.721552
# Epoch 17/100 | Train(sampled) L1:104.302751 L4:0.101982 | Val macro:155.984913 ± 155.944728 | Val micro:0.815423 ± 0.551584
#           >> Test macro:235.058078 ± 235.026485 | micro:1.204204 ± 0.678753
# Epoch 18/100 | Train(sampled) L1:102.625082 L4:0.095071 | Val macro:146.993280 ± 146.950871 | Val micro:0.772526 ± 0.519807
#           >> Test macro:221.530986 ± 221.497484 | micro:1.138298 ± 0.639697
# Epoch 19/100 | Train(sampled) L1:97.172736 L4:0.088260 | Val macro:138.125506 ± 138.084171 | Val micro:0.727161 ± 0.488467
#           >> Test macro:208.199768 ± 208.167932 | micro:1.070062 ± 0.601203
# Epoch 20/100 | Train(sampled) L1:93.424907 L4:0.079610 | Val macro:129.283623 ± 129.240470 | Val micro:0.684669 ± 0.457222
#           >> Test macro:194.963925 ± 194.930739 | micro:1.005137 ± 0.562986
# Epoch 21/100 | Train(sampled) L1:83.427162 L4:0.070073 | Val macro:121.249259 ± 121.204876 | Val micro:0.645667 ± 0.428829
#           >> Test macro:182.817754 ± 182.783388 | micro:0.945484 ± 0.527918
# Epoch 22/100 | Train(sampled) L1:79.403095 L4:0.056871 | Val macro:113.538784 ± 113.498576 | Val micro:0.603080 ± 0.401589
#           >> Test macro:171.200741 ± 171.170693 | micro:0.883215 ± 0.494381
# Epoch 23/100 | Train(sampled) L1:76.177487 L4:0.041690 | Val macro:106.064436 ± 106.019877 | Val micro:0.569925 ± 0.375180
#           >> Test macro:159.975985 ± 159.941932 | micro:0.830949 ± 0.461969
# Epoch 24/100 | Train(sampled) L1:66.327437 L4:0.026156 | Val macro:99.136460 ± 99.096761 | Val micro:0.530569 ± 0.350706
#           >> Test macro:149.572253 ± 149.542081 | micro:0.775041 ± 0.431946
# Epoch 25/100 | Train(sampled) L1:67.529514 L4:0.016629 | Val macro:92.651968 ± 92.607604 | Val micro:0.502654 ± 0.327800
#           >> Test macro:139.764083 ± 139.729354 | micro:0.730356 ± 0.403632
# Epoch 26/100 | Train(sampled) L1:62.138979 L4:0.011324 | Val macro:86.658680 ± 86.616993 | Val micro:0.470025 ± 0.306636
#           >> Test macro:130.746944 ± 130.714730 | micro:0.682722 ± 0.377609
# Epoch 27/100 | Train(sampled) L1:53.232305 L4:0.008729 | Val macro:81.195774 ± 81.154707 | Val micro:0.442091 ± 0.287342
#           >> Test macro:122.516489 ± 122.484677 | micro:0.641114 ± 0.353853
# Epoch 28/100 | Train(sampled) L1:52.764339 L4:0.007082 | Val macro:75.606993 ± 75.564551 | Val micro:0.415447 ± 0.267612
#           >> Test macro:114.143790 ± 114.110660 | micro:0.600462 ± 0.329688
# Epoch 29/100 | Train(sampled) L1:47.363259 L4:0.005680 | Val macro:70.454226 ± 70.414264 | Val micro:0.387288 ± 0.249419
#           >> Test macro:106.401912 ± 106.370785 | micro:0.559754 ± 0.307349
# Epoch 30/100 | Train(sampled) L1:45.622725 L4:0.004452 | Val macro:65.467913 ± 65.424896 | Val micro:0.365274 ± 0.231826
#           >> Test macro:98.908854 ± 98.874746 | micro:0.525097 ± 0.285733
# Epoch 31/100 | Train(sampled) L1:41.981489 L4:0.003892 | Val macro:60.793459 ± 60.751321 | Val micro:0.341021 ± 0.215336
#           >> Test macro:91.848577 ± 91.815670 | micro:0.488616 ± 0.265352
# Epoch 32/100 | Train(sampled) L1:37.509431 L4:0.003206 | Val macro:56.428365 ± 56.388478 | Val micro:0.317056 ± 0.199934
#           >> Test macro:85.255986 ± 85.224943 | micro:0.453837 ± 0.246333
# Epoch 33/100 | Train(sampled) L1:36.581573 L4:0.002639 | Val macro:52.243520 ± 52.203852 | Val micro:0.295926 ± 0.185178
#           >> Test macro:78.902562 ± 78.871778 | micro:0.421810 ± 0.228000
# Epoch 34/100 | Train(sampled) L1:33.448842 L4:0.002579 | Val macro:48.230867 ± 48.190802 | Val micro:0.276369 ± 0.171014
#           >> Test macro:72.848373 ± 72.817074 | micro:0.392139 ± 0.210514
# Epoch 35/100 | Train(sampled) L1:31.146301 L4:0.001987 | Val macro:44.372570 ± 44.333185 | Val micro:0.256314 ± 0.157443
#           >> Test macro:67.024159 ± 66.993819 | micro:0.361981 ± 0.193725
# Epoch 36/100 | Train(sampled) L1:28.895477 L4:0.001565 | Val macro:40.936497 ± 40.895977 | Val micro:0.240361 ± 0.145322
#           >> Test macro:61.841373 ± 61.809653 | micro:0.337499 ± 0.178765
# Epoch 37/100 | Train(sampled) L1:24.771232 L4:0.001389 | Val macro:37.795289 ± 37.754395 | Val micro:0.224812 ± 0.134328
#           >> Test macro:57.086549 ± 57.054719 | micro:0.313605 ± 0.165109
# Epoch 38/100 | Train(sampled) L1:24.655750 L4:0.001292 | Val macro:34.796100 ± 34.755930 | Val micro:0.209165 ± 0.123779
#           >> Test macro:52.531744 ± 52.500887 | micro:0.289950 ± 0.151964
# Epoch 39/100 | Train(sampled) L1:21.794410 L4:0.001011 | Val macro:32.024759 ± 31.983907 | Val micro:0.195928 ± 0.114066
#           >> Test macro:48.338007 ± 48.306624 | micro:0.269451 ± 0.139881
# Epoch 40/100 | Train(sampled) L1:19.930129 L4:0.000984 | Val macro:29.436047 ± 29.395317 | Val micro:0.182862 ± 0.104997
#           >> Test macro:44.421759 ± 44.390519 | micro:0.249713 ± 0.128605
# Epoch 41/100 | Train(sampled) L1:20.041374 L4:0.000861 | Val macro:26.904061 ± 26.862916 | Val micro:0.170800 ± 0.096050
#           >> Test macro:40.600230 ± 40.568052 | micro:0.231668 ± 0.117556
# Epoch 42/100 | Train(sampled) L1:17.323648 L4:0.000650 | Val macro:24.591263 ± 24.550738 | Val micro:0.158415 ± 0.088072
#           >> Test macro:37.111933 ± 37.080896 | micro:0.212915 ± 0.107579
# Epoch 43/100 | Train(sampled) L1:15.423997 L4:0.000712 | Val macro:22.459462 ± 22.419881 | Val micro:0.146858 ± 0.080633
#           >> Test macro:33.895544 ± 33.865397 | micro:0.195975 ± 0.098325
# Epoch 44/100 | Train(sampled) L1:14.012928 L4:0.000603 | Val macro:20.485960 ± 20.445402 | Val micro:0.137928 ± 0.073805
#           >> Test macro:30.910435 ± 30.878959 | micro:0.182273 ± 0.089806
# Epoch 45/100 | Train(sampled) L1:12.913347 L4:0.000499 | Val macro:18.585578 ± 18.542861 | Val micro:0.130515 ± 0.067265
#           >> Test macro:28.049210 ± 28.015661 | micro:0.169960 ± 0.081627
# Epoch 46/100 | Train(sampled) L1:12.077825 L4:0.000457 | Val macro:16.789075 ± 16.741730 | Val micro:0.126504 ± 0.060809
#           >> Test macro:25.337575 ± 25.298496 | micro:0.162197 ± 0.073708
# Epoch 47/100 | Train(sampled) L1:10.499856 L4:0.000554 | Val macro:15.011520 ± 14.972282 | Val micro:0.109330 ± 0.054888
#           >> Test macro:22.657078 ± 22.627000 | micro:0.139684 ± 0.066137
# Epoch 48/100 | Train(sampled) L1:9.182584 L4:0.000523 | Val macro:13.415995 ± 13.374680 | Val micro:0.103355 ± 0.049556
#           >> Test macro:20.246239 ± 20.214210 | micro:0.129507 ± 0.059330
# Epoch 49/100 | Train(sampled) L1:8.500201 L4:0.000445 | Val macro:11.886038 ± 11.846903 | Val micro:0.093605 ± 0.044318
#           >> Test macro:17.954203 ± 17.924039 | micro:0.116221 ± 0.052774
# Epoch 50/100 | Train(sampled) L1:7.450596 L4:0.000427 | Val macro:10.394196 ± 10.354596 | Val micro:0.086649 ± 0.039314
#           >> Test macro:15.707465 ± 15.676607 | micro:0.105684 ± 0.046415
# Epoch 51/100 | Train(sampled) L1:6.611671 L4:0.000369 | Val macro:9.059083 ± 9.019857 | Val micro:0.079533 ± 0.035071
#           >> Test macro:13.706179 ± 13.675852 | micro:0.095084 ± 0.040873
# Epoch 52/100 | Train(sampled) L1:5.885041 L4:0.000353 | Val macro:7.774566 ± 7.735014 | Val micro:0.073512 ± 0.030871
#           >> Test macro:11.771404 ± 11.740463 | micro:0.086061 ± 0.035438
# Epoch 53/100 | Train(sampled) L1:4.786443 L4:0.000324 | Val macro:6.613900 ± 6.574901 | Val micro:0.067110 ± 0.027384
#           >> Test macro:10.025370 ± 9.995153 | micro:0.076569 ± 0.030691
# Epoch 54/100 | Train(sampled) L1:4.313754 L4:0.000288 | Val macro:5.547936 ± 5.506256 | Val micro:0.064346 ± 0.024492
#           >> Test macro:8.413345 ± 8.380925 | micro:0.070638 ± 0.026452
# Epoch 55/100 | Train(sampled) L1:3.389276 L4:0.000266 | Val macro:4.585996 ± 4.546946 | Val micro:0.057004 ± 0.021679
#           >> Test macro:6.967815 ± 6.937857 | micro:0.061029 ± 0.022548
# Epoch 56/100 | Train(sampled) L1:2.688545 L4:0.000250 | Val macro:3.767743 ± 3.728368 | Val micro:0.053301 ± 0.019462
#           >> Test macro:5.732657 ± 5.702335 | micro:0.055270 ± 0.019303
# Epoch 57/100 | Train(sampled) L1:2.365872 L4:0.000242 | Val macro:2.996299 ± 2.957211 | Val micro:0.049141 ± 0.017809
#           >> Test macro:4.569083 ± 4.539369 | micro:0.048858 ± 0.016482
# Epoch 58/100 | Train(sampled) L1:1.873256 L4:0.000221 | Val macro:2.310060 ± 2.270952 | Val micro:0.045746 ± 0.016510
#           >> Test macro:3.528275 ± 3.498033 | micro:0.044111 ± 0.014431
# Epoch 59/100 | Train(sampled) L1:1.398615 L4:0.000187 | Val macro:1.749483 ± 1.710061 | Val micro:0.043232 ± 0.015819
#           >> Test macro:2.676693 ± 2.646128 | micro:0.040120 ± 0.013023
# Epoch 60/100 | Train(sampled) L1:1.051987 L4:0.000180 | Val macro:1.250257 ± 1.211338 | Val micro:0.040318 ± 0.015139
#           >> Test macro:1.921985 ± 1.891640 | micro:0.036147 ± 0.011892
# Epoch 61/100 | Train(sampled) L1:0.763578 L4:0.000180 | Val macro:0.866114 ± 0.823837 | Val micro:0.041731 ± 0.015165
#           >> Test macro:1.331940 ± 1.299028 | micro:0.035776 ± 0.011215
# Epoch 62/100 | Train(sampled) L1:0.533737 L4:0.000179 | Val macro:0.564022 ± 0.525199 | Val micro:0.037021 ± 0.014601
#           >> Test macro:0.869633 ± 0.840406 | micro:0.029996 ± 0.010051
# Epoch 63/100 | Train(sampled) L1:0.340134 L4:0.000199 | Val macro:0.338727 ± 0.300469 | Val micro:0.035654 ± 0.014454
#           >> Test macro:0.525666 ± 0.496000 | micro:0.028737 ± 0.010266
# Epoch 64/100 | Train(sampled) L1:0.202101 L4:0.000184 | Val macro:0.194145 ± 0.156455 | Val micro:0.035011 ± 0.014504
#           >> Test macro:0.298046 ± 0.267983 | micro:0.028138 ± 0.010636
# Epoch 65/100 | Train(sampled) L1:0.119336 L4:0.000165 | Val macro:0.103552 ± 0.066115 | Val micro:0.036274 ± 0.014670
#           >> Test macro:0.153915 ± 0.122946 | micro:0.028888 ± 0.010752
# Epoch 66/100 | Train(sampled) L1:0.068641 L4:0.000159 | Val macro:0.053923 ± 0.025506 | Val micro:0.034099 ± 0.014257
#           >> Test macro:0.076733 ± 0.049431 | micro:0.026449 ± 0.010110
# Epoch 67/100 | Train(sampled) L1:0.086580 L4:0.000226 | Val macro:0.035529 ± 0.020807 | Val micro:0.034028 ± 0.014262
#           >> Test macro:0.042638 ± 0.020202 | micro:0.026509 ± 0.010354
# Epoch 68/100 | Train(sampled) L1:0.039593 L4:0.000290 | Val macro:0.030463 ± 0.022144 | Val micro:0.034204 ± 0.014108
#           >> Test macro:0.028963 ± 0.015938 | micro:0.026845 ± 0.010277
# Epoch 69/100 | Train(sampled) L1:0.025288 L4:0.000249 | Val macro:0.028956 ± 0.023327 | Val micro:0.034820 ± 0.014445
#           >> Test macro:0.027759 ± 0.016253 | micro:0.027123 ± 0.010472
# Epoch 70/100 | Train(sampled) L1:0.022017 L4:0.000183 | Val macro:0.028892 ± 0.022788 | Val micro:0.033926 ± 0.014260
#           >> Test macro:0.025409 ± 0.016501 | micro:0.026400 ± 0.010262
# Epoch 71/100 | Train(sampled) L1:0.029858 L4:0.000171 | Val macro:0.029789 ± 0.023429 | Val micro:0.035638 ± 0.014547
#           >> Test macro:0.029416 ± 0.016238 | micro:0.027954 ± 0.010614
# Epoch 72/100 | Train(sampled) L1:0.030406 L4:0.000163 | Val macro:0.029657 ± 0.023452 | Val micro:0.035724 ± 0.014494
#           >> Test macro:0.027022 ± 0.016787 | micro:0.028121 ± 0.010683
# Epoch 73/100 | Train(sampled) L1:0.032283 L4:0.000154 | Val macro:0.032032 ± 0.022385 | Val micro:0.035617 ± 0.014449
#           >> Test macro:0.026121 ± 0.016641 | micro:0.027628 ± 0.010388
# Epoch 74/100 | Train(sampled) L1:0.026913 L4:0.000149 | Val macro:0.028562 ± 0.022987 | Val micro:0.034443 ± 0.014029
#           >> Test macro:0.026179 ± 0.016417 | micro:0.027098 ± 0.010165
# Epoch 75/100 | Train(sampled) L1:0.031600 L4:0.000152 | Val macro:0.028409 ± 0.023128 | Val micro:0.034012 ± 0.014313
#           >> Test macro:0.032320 ± 0.016265 | micro:0.026915 ± 0.010572
# Early stopping at epoch 75/100 (best test macro-MSE: 0.025409 @ epoch 70)
# TEST RESULTS | macro: 0.032320 ± 0.016265 | micro: 0.026915 ± 0.010572
#           >> per_group (weighted SE): {0: '0.058688 ± 0.024416 (n=777)', 1: '0.035634 ± 0.006641 (n=3)', 5: '0.002638 ± 0.000108 (n=1018)'}

# %%
l = [hdim_val, nlayer_val, nheads_val, dsteps_val]
for i in l:
    ls=[f'{hp}: {i[hp]["macro_mse"]}' for hp in i]
    print(' - '.join(ls))
# Out:
# 88: 136.3705933347038 - 176: 0.9508907429491109 - 352: 0.6532884090545087
# 2: 1.4648769808596327 - 4: 1.1563050135196948 - 6: 0.6835620647393377
# 2: 0.862589740157012 - 4: 0.7251794005880026 - 8: 0.7556685850654324
# 50: 0.023560187915694433 - 100: 0.024999074783959088 - 150: 0.028408698901702324

# %% [markdown]
# ### 18. Treino do Modelo Campeão

# %%
df_scaled_denoised = tsdiffusion.denoise_dataframe(
            df=df_scaled,
            feature_cols=list(df_scaled.columns[:-1]),
            static_features_cols=None,
            timestamp_col='index',
            window_size=30,
            window_step=30,   
            replace_only_missing=False,
            steps=50
        )

# %%
model = ODEJumpEncoder(
    in_channels=11,
    hidden_dim=11*32,
    n_layers=6,
)
gen = model.train_cognite(
    df=df_scaled_denoised,
    feature_cols=list(df_scaled.columns[:-1]),
    static_features_cols=None,
    timestamp_col='index',
    states_col='states',
    batch_size=256,
    window_size=30,
    window_step=30,
    epochs = 100,
    validate=False
)
l = [r for r in gen if r is not None]  # remove None results
# Out:
# /root/coppe/3Wve/lib/python3.12/site-packages/torch/nn/modules/transformer.py:382: UserWarning:
#
# enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
# GRUPOS (total): {0: 3886, 1: 15, 5: 5093}
# GRUPOS (train): {0: 3109, 1: 12, 5: 4074}
# GRUPOS (test):  {0: 777, 1: 3, 5: 1019}
# Epoch 1/100 | Train(sampled) L1:247.183606 L4:0.386627 |
#           >> Test macro:451.945236 ± 451.893904 | micro:2.307812 ± 1.304202
# Epoch 2/100 | Train(sampled) L1:218.565810 L4:0.160823 |
#           >> Test macro:400.205184 ± 400.171541 | micro:2.031579 ± 1.154934
# Epoch 3/100 | Train(sampled) L1:185.772341 L4:0.148917 |
#           >> Test macro:354.878345 ± 354.815326 | micro:1.835136 ± 1.024018
# Epoch 4/100 | Train(sampled) L1:173.608517 L4:0.144790 |
#           >> Test macro:311.938021 ± 311.904880 | micro:1.590214 ± 0.900192
# Epoch 5/100 | Train(sampled) L1:147.641453 L4:0.142910 |
#           >> Test macro:274.947650 ± 274.876302 | micro:1.443715 ± 0.793323
# Epoch 6/100 | Train(sampled) L1:129.282720 L4:0.140889 |
#           >> Test macro:239.216740 ± 239.188010 | micro:1.221667 ± 0.690356
# Epoch 7/100 | Train(sampled) L1:108.996796 L4:0.139456 |
#           >> Test macro:206.109687 ± 206.023268 | micro:1.112941 ± 0.594654
# Epoch 8/100 | Train(sampled) L1:94.842613 L4:0.137843 |
#           >> Test macro:176.366652 ± 176.338684 | micro:0.906546 ± 0.508989
# Epoch 9/100 | Train(sampled) L1:83.729836 L4:0.133920 |
#           >> Test macro:149.838236 ± 149.806994 | micro:0.777010 ± 0.432434
# Epoch 10/100 | Train(sampled) L1:72.830995 L4:0.130640 |
#           >> Test macro:126.935793 ± 126.906609 | micro:0.660423 ± 0.366364
# Epoch 11/100 | Train(sampled) L1:60.092661 L4:0.125719 |
#           >> Test macro:107.352466 ± 107.316218 | micro:0.569374 ± 0.309852
# Epoch 12/100 | Train(sampled) L1:48.767591 L4:0.119704 |
#           >> Test macro:90.951489 ± 90.924307 | micro:0.478627 ± 0.262554
# Epoch 13/100 | Train(sampled) L1:42.733155 L4:0.111729 |
#           >> Test macro:76.080817 ± 76.053946 | micro:0.403822 ± 0.219668
# Epoch 14/100 | Train(sampled) L1:34.329829 L4:0.101956 |
#           >> Test macro:63.562043 ± 63.525095 | micro:0.351565 ± 0.183521
# Epoch 15/100 | Train(sampled) L1:30.657084 L4:0.085417 |
#           >> Test macro:52.265813 ± 52.237178 | micro:0.286312 ± 0.151044
# Epoch 16/100 | Train(sampled) L1:23.384054 L4:0.064593 |
#           >> Test macro:42.969579 ± 42.937847 | micro:0.242772 ± 0.124300
# Epoch 17/100 | Train(sampled) L1:20.576830 L4:0.041371 |
#           >> Test macro:34.879170 ± 34.851739 | micro:0.198168 ± 0.101025
# Epoch 18/100 | Train(sampled) L1:16.681356 L4:0.025432 |
#           >> Test macro:27.915751 ± 27.884728 | micro:0.166715 ± 0.081089
# Epoch 19/100 | Train(sampled) L1:12.251281 L4:0.016530 |
#           >> Test macro:22.275976 ± 22.248532 | micro:0.135151 ± 0.064892
# Epoch 20/100 | Train(sampled) L1:10.033314 L4:0.011481 |
#           >> Test macro:17.382183 ± 17.351419 | micro:0.113763 ± 0.051047
# Epoch 21/100 | Train(sampled) L1:7.816536 L4:0.008197 |
#           >> Test macro:13.085274 ± 13.054583 | micro:0.092599 ± 0.038711
# Epoch 22/100 | Train(sampled) L1:5.648194 L4:0.006154 |
#           >> Test macro:9.593626 ± 9.565402 | micro:0.072410 ± 0.029227
# Epoch 23/100 | Train(sampled) L1:4.220504 L4:0.004861 |
#           >> Test macro:6.627471 ± 6.586602 | micro:0.069830 ± 0.021735
# Epoch 24/100 | Train(sampled) L1:2.702390 L4:0.003754 |
#           >> Test macro:4.318552 ± 4.287289 | micro:0.049260 ± 0.015474
# Epoch 25/100 | Train(sampled) L1:1.679494 L4:0.003111 |
#           >> Test macro:2.527833 ± 2.494473 | micro:0.042029 ± 0.012523
# Epoch 26/100 | Train(sampled) L1:0.948409 L4:0.002637 |
#           >> Test macro:1.330699 ± 1.294069 | micro:0.039283 ± 0.011058
# Epoch 27/100 | Train(sampled) L1:0.473743 L4:0.001964 |
#           >> Test macro:0.589341 ± 0.558837 | micro:0.029755 ± 0.010149
# Epoch 28/100 | Train(sampled) L1:0.188368 L4:0.001615 |
#           >> Test macro:0.216967 ± 0.188399 | micro:0.026441 ± 0.009952
# Epoch 29/100 | Train(sampled) L1:0.085951 L4:0.001216 |
#           >> Test macro:0.080539 ± 0.038182 | micro:0.042750 ± 0.010856
# Epoch 30/100 | Train(sampled) L1:0.023847 L4:0.001050 |
#           >> Test macro:0.026582 ± 0.016560 | micro:0.025198 ± 0.010295
# Epoch 31/100 | Train(sampled) L1:0.018090 L4:0.000805 |
#           >> Test macro:0.024127 ± 0.018374 | micro:0.027820 ± 0.010476
# Epoch 32/100 | Train(sampled) L1:0.032077 L4:0.000616 |
#           >> Test macro:0.022380 ± 0.017360 | micro:0.024783 ± 0.010308
# Epoch 33/100 | Train(sampled) L1:0.043501 L4:0.000542 |
#           >> Test macro:0.028072 ± 0.018490 | micro:0.030124 ± 0.011186
# Epoch 34/100 | Train(sampled) L1:0.023541 L4:0.000427 |
#           >> Test macro:0.022704 ± 0.017675 | micro:0.025260 ± 0.010802
# Epoch 35/100 | Train(sampled) L1:0.027374 L4:0.000351 |
#           >> Test macro:0.025319 ± 0.017873 | micro:0.030865 ± 0.010107
# Epoch 36/100 | Train(sampled) L1:0.014059 L4:0.000320 |
#           >> Test macro:0.022018 ± 0.018527 | micro:0.026425 ± 0.010551
# Epoch 37/100 | Train(sampled) L1:0.034485 L4:0.000298 |
#           >> Test macro:0.021647 ± 0.017347 | micro:0.024686 ± 0.010161
# Epoch 38/100 | Train(sampled) L1:0.033559 L4:0.000259 |
#           >> Test macro:0.022028 ± 0.017357 | micro:0.024914 ± 0.010129
# Epoch 39/100 | Train(sampled) L1:0.011941 L4:0.000234 |
#           >> Test macro:0.021889 ± 0.018239 | micro:0.025783 ± 0.010579
# Epoch 40/100 | Train(sampled) L1:0.018664 L4:0.000206 |
#           >> Test macro:0.021902 ± 0.017493 | micro:0.024886 ± 0.010344
# Epoch 41/100 | Train(sampled) L1:0.029455 L4:0.000193 |
#           >> Test macro:0.024234 ± 0.016136 | micro:0.025005 ± 0.009739
# Epoch 42/100 | Train(sampled) L1:0.016161 L4:0.000173 |
#           >> Test macro:0.022920 ± 0.017094 | micro:0.024714 ± 0.010437
# Early stopping at epoch 42/100 (best test macro-MSE: 0.021647 @ epoch 37)
# TEST RESULTS | macro: 0.022920 ± 0.017094 | micro: 0.024714 ± 0.010437
#           >> per_group (weighted SE): {0: '0.056489 ± 0.024118 (n=777)', 1: '0.011747 ± 0.007310 (n=3)', 5: '0.000523 ± 0.000019 (n=1019)'}

# %%
t_dict = {
    'Macro MSE':[v['macro_mse'] for v in res_odejump_encoder_diff],
    'Micro MSE':[v['micro_mse'] for v in res_odejump_encoder_diff],
    'Macro MSE SE':[v['macro_se'] for v in res_odejump_encoder_diff],
    'Micro MSE SE':[v['micro_se'] for v in res_odejump_encoder_diff],
    }
treinamento = pd.DataFrame(t_dict)
treinamento.index = np.arange(1, len(treinamento) + 1)
treinamento.index.name = 'Épocas'

# Z-score para ~95% (normal aprox.)
z = 1.96

# ----- Gráfico 1: Macro -----
plt.figure(figsize=(15,7))
macro_mean = treinamento['Macro MSE']
macro_se   = treinamento['Macro MSE SE'].fillna(0.0)

lower = macro_mean - z*macro_se
upper = macro_mean + z*macro_se

plt.plot(treinamento.index, macro_mean, label='Macro MSE')
plt.fill_between(treinamento.index, lower, upper, alpha=0.2, label='IC 95%')

plt.title('Macro MSE — Modelo ODEJump com Atenção (denoising no pré-processamento)')
plt.xlabel('Épocas')
plt.ylabel('MSE')
plt.yscale('log')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# ----- Gráfico 2: Micro -----
plt.figure(figsize=(15,7))
micro_mean = treinamento['Micro MSE']
micro_se   = treinamento['Micro MSE SE'].fillna(0.0)

lower = micro_mean - z*micro_se
upper = micro_mean + z*micro_se

plt.plot(treinamento.index, micro_mean, label='Micro MSE')
plt.fill_between(treinamento.index, lower, upper, alpha=0.2, label='IC 95%')

plt.title('Micro MSE — Modelo ODEJump com Atenção (denoising no pré-processamento)')
plt.xlabel('Épocas')
plt.ylabel('MSE')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### teste raw

# %%
model = ODEJumpEncoder(
    in_channels=11,
    hidden_dim=11*32,
    n_layers=6,
)
gen = model.train_cognite(
    df=df_scaled_denoised,
    feature_cols=list(df_scaled.columns[:-1]),
    static_features_cols=None,
    timestamp_col='index',
    states_col='states',
    batch_size=256,
    window_size=30,
    window_step=30,
    epochs = 100,
    validate=False,
    df_raw=df_scaled,  # Passa o dataframe original sem denoising
)
l = [r for r in gen if r is not None]  # remove None results
# Out:
# /root/coppe/3Wve/lib/python3.12/site-packages/torch/nn/modules/transformer.py:382: UserWarning:
#
# enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#
# /root/coppe/tp_esp_ap_mq/CPE883-2025-02/models/tsdiffusion_transformed/ode_jump_encoder.py:203: FutureWarning:
#
# ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# /root/coppe/tp_esp_ap_mq/CPE883-2025-02/models/tsdiffusion_transformed/ode_jump_encoder.py:203: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /root/coppe/tp_esp_ap_mq/CPE883-2025-02/models/tsdiffusion_transformed/ode_jump_encoder.py:203: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-1.942966012305979' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# /root/coppe/tp_esp_ap_mq/CPE883-2025-02/models/tsdiffusion_transformed/ode_jump_encoder.py:203: FutureWarning:
#
# ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# /root/coppe/tp_esp_ap_mq/CPE883-2025-02/models/tsdiffusion_transformed/ode_jump_encoder.py:203: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /root/coppe/tp_esp_ap_mq/CPE883-2025-02/models/tsdiffusion_transformed/ode_jump_encoder.py:203: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.7773095732647686' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# /root/coppe/tp_esp_ap_mq/CPE883-2025-02/models/tsdiffusion_transformed/ode_jump_encoder.py:203: FutureWarning:
#
# ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# /root/coppe/tp_esp_ap_mq/CPE883-2025-02/models/tsdiffusion_transformed/ode_jump_encoder.py:203: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /root/coppe/tp_esp_ap_mq/CPE883-2025-02/models/tsdiffusion_transformed/ode_jump_encoder.py:203: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.5214865354267368' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# /root/coppe/tp_esp_ap_mq/CPE883-2025-02/models/tsdiffusion_transformed/ode_jump_encoder.py:203: FutureWarning:
#
# ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# /root/coppe/tp_esp_ap_mq/CPE883-2025-02/models/tsdiffusion_transformed/ode_jump_encoder.py:203: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /root/coppe/tp_esp_ap_mq/CPE883-2025-02/models/tsdiffusion_transformed/ode_jump_encoder.py:203: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.6613023927499557' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# /root/coppe/tp_esp_ap_mq/CPE883-2025-02/models/tsdiffusion_transformed/ode_jump_encoder.py:203: FutureWarning:
#
# ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# /root/coppe/tp_esp_ap_mq/CPE883-2025-02/models/tsdiffusion_transformed/ode_jump_encoder.py:203: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /root/coppe/tp_esp_ap_mq/CPE883-2025-02/models/tsdiffusion_transformed/ode_jump_encoder.py:203: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.014257168915932603' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# /root/coppe/tp_esp_ap_mq/CPE883-2025-02/models/tsdiffusion_transformed/ode_jump_encoder.py:203: FutureWarning:
#
# ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# /root/coppe/tp_esp_ap_mq/CPE883-2025-02/models/tsdiffusion_transformed/ode_jump_encoder.py:203: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /root/coppe/tp_esp_ap_mq/CPE883-2025-02/models/tsdiffusion_transformed/ode_jump_encoder.py:203: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.3595286678435285' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# /root/coppe/tp_esp_ap_mq/CPE883-2025-02/models/tsdiffusion_transformed/ode_jump_encoder.py:203: FutureWarning:
#
# ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# /root/coppe/tp_esp_ap_mq/CPE883-2025-02/models/tsdiffusion_transformed/ode_jump_encoder.py:203: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /root/coppe/tp_esp_ap_mq/CPE883-2025-02/models/tsdiffusion_transformed/ode_jump_encoder.py:203: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.9124145929090143' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# /root/coppe/tp_esp_ap_mq/CPE883-2025-02/models/tsdiffusion_transformed/ode_jump_encoder.py:203: FutureWarning:
#
# ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# /root/coppe/tp_esp_ap_mq/CPE883-2025-02/models/tsdiffusion_transformed/ode_jump_encoder.py:203: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /root/coppe/tp_esp_ap_mq/CPE883-2025-02/models/tsdiffusion_transformed/ode_jump_encoder.py:203: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-7.475620055725291' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# /root/coppe/tp_esp_ap_mq/CPE883-2025-02/models/tsdiffusion_transformed/ode_jump_encoder.py:203: FutureWarning:
#
# ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# /root/coppe/tp_esp_ap_mq/CPE883-2025-02/models/tsdiffusion_transformed/ode_jump_encoder.py:203: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /root/coppe/tp_esp_ap_mq/CPE883-2025-02/models/tsdiffusion_transformed/ode_jump_encoder.py:203: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.38111427720023316' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# /root/coppe/tp_esp_ap_mq/CPE883-2025-02/models/tsdiffusion_transformed/ode_jump_encoder.py:203: FutureWarning:
#
# ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# /root/coppe/tp_esp_ap_mq/CPE883-2025-02/models/tsdiffusion_transformed/ode_jump_encoder.py:203: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /root/coppe/tp_esp_ap_mq/CPE883-2025-02/models/tsdiffusion_transformed/ode_jump_encoder.py:203: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.02968797253473909' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# /root/coppe/tp_esp_ap_mq/CPE883-2025-02/models/tsdiffusion_transformed/ode_jump_encoder.py:203: FutureWarning:
#
# ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# /root/coppe/tp_esp_ap_mq/CPE883-2025-02/models/tsdiffusion_transformed/ode_jump_encoder.py:203: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /root/coppe/tp_esp_ap_mq/CPE883-2025-02/models/tsdiffusion_transformed/ode_jump_encoder.py:203: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-2.0483941339605596' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
# GRUPOS (total): {0: 3886, 1: 15, 5: 5093}
# GRUPOS (train): {0: 3109, 1: 12, 5: 4074}
# GRUPOS (test):  {0: 777, 1: 3, 5: 1019}
# Epoch 1/100 | Train(sampled) L1:489.523613 L4:0.230795 |
#           >> Test macro:896.636239 ± 895.295747 | micro:5.730298 ± 2.584947
# Epoch 2/100 | Train(sampled) L1:460.591542 L4:0.149807 |
#           >> Test macro:842.287656 ± 841.027504 | micro:5.355722 ± 2.428673
# Epoch 3/100 | Train(sampled) L1:429.349633 L4:0.149923 |
#           >> Test macro:793.811461 ± 792.567738 | micro:5.102319 ± 2.288807
# Epoch 4/100 | Train(sampled) L1:399.390154 L4:0.142309 |
#           >> Test macro:749.079317 ± 747.858837 | micro:4.864586 ± 2.159839
# Epoch 5/100 | Train(sampled) L1:368.247502 L4:0.142779 |
#           >> Test macro:703.875507 ± 702.664697 | micro:4.631105 ± 2.029439
# Epoch 6/100 | Train(sampled) L1:367.651813 L4:0.138492 |
#           >> Test macro:661.518843 ± 660.320553 | micro:4.404063 ± 1.907356
# Epoch 7/100 | Train(sampled) L1:333.073653 L4:0.136185 |
#           >> Test macro:622.060431 ± 620.886294 | micro:4.194732 ± 1.793482
# Epoch 8/100 | Train(sampled) L1:308.298003 L4:0.132266 |
#           >> Test macro:586.654602 ± 585.528911 | micro:3.978480 ± 1.691297
# Epoch 9/100 | Train(sampled) L1:307.140431 L4:0.128328 |
#           >> Test macro:551.964892 ± 550.790679 | micro:3.823160 ± 1.591551
# Epoch 10/100 | Train(sampled) L1:269.248604 L4:0.124302 |
#           >> Test macro:520.894250 ± 519.898980 | micro:3.519083 ± 1.501946
# Epoch 11/100 | Train(sampled) L1:265.194987 L4:0.118413 |
#           >> Test macro:490.409367 ± 489.425168 | micro:3.377417 ± 1.413493
# Epoch 12/100 | Train(sampled) L1:233.481927 L4:0.114072 |
#           >> Test macro:462.495309 ± 461.475433 | micro:3.233851 ± 1.333660
# Epoch 13/100 | Train(sampled) L1:226.729285 L4:0.107622 |
#           >> Test macro:434.996816 ± 434.090301 | micro:3.012018 ± 1.253950
# Epoch 14/100 | Train(sampled) L1:211.701998 L4:0.101645 |
#           >> Test macro:408.494358 ± 407.639938 | micro:2.826457 ± 1.177772
# Epoch 15/100 | Train(sampled) L1:199.759222 L4:0.094773 |
#           >> Test macro:383.831362 ± 382.783563 | micro:2.898631 ± 1.105898
# Epoch 16/100 | Train(sampled) L1:186.324997 L4:0.086826 |
#           >> Test macro:358.778275 ± 357.906981 | micro:2.594589 ± 1.034298
# Epoch 17/100 | Train(sampled) L1:181.541664 L4:0.078071 |
#           >> Test macro:333.913840 ± 333.014102 | micro:2.494388 ± 0.963049
# Epoch 18/100 | Train(sampled) L1:165.875204 L4:0.069236 |
#           >> Test macro:309.963232 ± 309.112867 | micro:2.321298 ± 0.894209
# Epoch 19/100 | Train(sampled) L1:148.439456 L4:0.060186 |
#           >> Test macro:287.742102 ± 286.931540 | micro:2.177349 ± 0.830132
# Epoch 20/100 | Train(sampled) L1:143.140126 L4:0.049023 |
#           >> Test macro:265.786100 ± 264.610677 | micro:2.437828 ± 0.765258
# Epoch 21/100 | Train(sampled) L1:126.895493 L4:0.041735 |
#           >> Test macro:244.190616 ± 243.313510 | micro:2.019186 ± 0.704817
# Epoch 22/100 | Train(sampled) L1:115.415914 L4:0.034406 |
#           >> Test macro:223.380135 ± 222.490814 | micro:1.927697 ± 0.644956
# Epoch 23/100 | Train(sampled) L1:105.054816 L4:0.028205 |
#           >> Test macro:203.301779 ± 202.448535 | micro:1.793033 ± 0.587160
# Epoch 24/100 | Train(sampled) L1:93.737357 L4:0.021764 |
#           >> Test macro:184.451773 ± 183.547506 | micro:1.743279 ± 0.533466
# Epoch 25/100 | Train(sampled) L1:82.557938 L4:0.017243 |
#           >> Test macro:166.552398 ± 165.663239 | micro:1.649946 ± 0.480965
# Epoch 26/100 | Train(sampled) L1:80.781152 L4:0.013157 |
#           >> Test macro:148.806409 ± 147.950225 | micro:1.523297 ± 0.431374
# Epoch 27/100 | Train(sampled) L1:71.227719 L4:0.011210 |
#           >> Test macro:131.267298 ± 130.448681 | micro:1.401067 ± 0.381130
# Epoch 28/100 | Train(sampled) L1:61.856965 L4:0.008988 |
#           >> Test macro:115.830103 ± 114.844857 | micro:1.474564 ± 0.338992
# Epoch 29/100 | Train(sampled) L1:56.846028 L4:0.007456 |
#           >> Test macro:100.561313 ± 99.709509 | micro:1.286653 ± 0.293126
# Epoch 30/100 | Train(sampled) L1:44.713202 L4:0.006425 |
#           >> Test macro:87.160454 ± 86.349428 | micro:1.173565 ± 0.255410
# Epoch 31/100 | Train(sampled) L1:38.637818 L4:0.005283 |
#           >> Test macro:74.414271 ± 73.600149 | micro:1.114523 ± 0.220563
# Epoch 32/100 | Train(sampled) L1:35.105066 L4:0.004540 |
#           >> Test macro:62.186334 ± 61.396903 | micro:1.031086 ± 0.185865
# Epoch 33/100 | Train(sampled) L1:28.079320 L4:0.003590 |
#           >> Test macro:51.422055 ± 50.501853 | micro:1.108916 ± 0.157815
# Epoch 34/100 | Train(sampled) L1:24.338724 L4:0.003211 |
#           >> Test macro:41.643712 ± 40.802971 | micro:0.977735 ± 0.130020
# Epoch 35/100 | Train(sampled) L1:19.114955 L4:0.002779 |
#           >> Test macro:32.551150 ± 31.742093 | micro:0.901176 ± 0.107466
# Epoch 36/100 | Train(sampled) L1:14.375682 L4:0.002482 |
#           >> Test macro:25.239892 ± 24.366312 | micro:0.919187 ± 0.097682
# Epoch 37/100 | Train(sampled) L1:11.122025 L4:0.002377 |
#           >> Test macro:19.044744 ± 18.185325 | micro:0.886596 ± 0.076819
# Epoch 38/100 | Train(sampled) L1:8.150158 L4:0.002124 |
#           >> Test macro:13.654362 ± 12.840746 | micro:0.812355 ± 0.068867
# Epoch 39/100 | Train(sampled) L1:5.875405 L4:0.001778 |
#           >> Test macro:9.305342 ± 8.492771 | micro:0.789541 ± 0.066702
# Epoch 40/100 | Train(sampled) L1:4.096054 L4:0.001596 |
#           >> Test macro:5.886191 ± 5.036930 | micro:0.818250 ± 0.057993
# Epoch 41/100 | Train(sampled) L1:2.510794 L4:0.001397 |
#           >> Test macro:3.605477 ± 2.694007 | micro:0.863442 ± 0.098872
# Epoch 42/100 | Train(sampled) L1:1.597162 L4:0.001453 |
#           >> Test macro:1.930932 ± 1.173197 | micro:0.732189 ± 0.057123
# Epoch 43/100 | Train(sampled) L1:0.988863 L4:0.001362 |
#           >> Test macro:1.094521 ± 0.386204 | micro:0.757373 ± 0.055641
# Epoch 44/100 | Train(sampled) L1:0.682460 L4:0.001184 |
#           >> Test macro:0.721000 ± 0.351952 | micro:0.773925 ± 0.067762
# Epoch 45/100 | Train(sampled) L1:0.583685 L4:0.001078 |
#           >> Test macro:0.598266 ± 0.386704 | micro:0.768633 ± 0.064054
# Epoch 46/100 | Train(sampled) L1:0.502335 L4:0.000862 |
#           >> Test macro:0.547247 ± 0.393661 | micro:0.725504 ± 0.063592
# Epoch 47/100 | Train(sampled) L1:0.522017 L4:0.000714 |
#           >> Test macro:0.573282 ± 0.402100 | micro:0.766186 ± 0.063563
# Epoch 48/100 | Train(sampled) L1:0.512941 L4:0.000714 |
#           >> Test macro:0.613609 ± 0.441892 | micro:0.829680 ± 0.067457
# Epoch 49/100 | Train(sampled) L1:0.548302 L4:0.000677 |
#           >> Test macro:0.550035 ± 0.396597 | micro:0.741866 ± 0.060556
# Epoch 50/100 | Train(sampled) L1:0.530749 L4:0.000700 |
#           >> Test macro:0.564831 ± 0.426656 | micro:0.767009 ± 0.067714
# Epoch 51/100 | Train(sampled) L1:0.510195 L4:0.000545 |
#           >> Test macro:0.548544 ± 0.390445 | micro:0.747257 ± 0.058462
# Early stopping at epoch 51/100 (best test macro-MSE: 0.547247 @ epoch 46)
# TEST RESULTS | macro: 0.548544 ± 0.390445 | micro: 0.747257 ± 0.058462
#           >> per_group (weighted SE): {0: '1.309271 ± 0.131922 (n=777)', 1: '0.015494 ± 0.004958 (n=3)', 5: '0.320869 ± 0.010842 (n=1019)'}

# %%
t_dict = {
    'Macro MSE':[v['macro_mse'] for v in res_odejump_encoder_diff_raw],
    'Micro MSE':[v['micro_mse'] for v in res_odejump_encoder_diff_raw],
    'Macro MSE SE':[v['macro_se'] for v in res_odejump_encoder_diff_raw],
    'Micro MSE SE':[v['micro_se'] for v in res_odejump_encoder_diff_raw],
    }
treinamento = pd.DataFrame(t_dict)
treinamento.index = np.arange(1, len(treinamento) + 1)
treinamento.index.name = 'Épocas'

# Z-score para ~95% (normal aprox.)
z = 1.96

# ----- Gráfico 1: Macro -----
plt.figure(figsize=(15,7))
macro_mean = treinamento['Macro MSE']
macro_se   = treinamento['Macro MSE SE'].fillna(0.0)

lower = macro_mean - z*macro_se
upper = macro_mean + z*macro_se

plt.plot(treinamento.index, macro_mean, label='Macro MSE')
plt.fill_between(treinamento.index, lower, upper, alpha=0.2, label='IC 95%')

plt.title('Macro MSE — Modelo ODEJump com Atenção (denoising no pré-processamento) - Target Raw')
plt.xlabel('Épocas')
plt.ylabel('MSE')
plt.legend()
plt.yscale('log')
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# ----- Gráfico 2: Micro -----
plt.figure(figsize=(15,7))
micro_mean = treinamento['Micro MSE']
micro_se   = treinamento['Micro MSE SE'].fillna(0.0)

lower = micro_mean - z*micro_se
upper = micro_mean + z*micro_se

plt.plot(treinamento.index, micro_mean, label='Micro MSE')
plt.fill_between(treinamento.index, lower, upper, alpha=0.2, label='IC 95%')

plt.title('Micro MSE — Modelo ODEJump com Atenção (denoising no pré-processamento) - Target Raw')
plt.xlabel('Épocas')
plt.ylabel('MSE')

plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
